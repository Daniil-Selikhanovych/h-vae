# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
from torch.distributions.normal import Normal
import torch.optim as optim
from torch.distributions.multivariate_normal import MultivariateNormal
from torch.nn import Parameter
from torch import nn
from torch.utils.data import Dataset, DataLoader


import scipy.stats
import time
import pickle
import os
import sys

# %%
# !rm -r h-vae/

# %%
# !git clone https://github.com/Daniil-Selikhanovych/h-vae
# Out:
# Cloning into 'h-vae'...
# remote: Enumerating objects: 106, done.
# remote: Counting objects: 100% (106/106), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 106 (delta 32), reused 97 (delta 26), pack-reused 0
# Receiving objects: 100% (106/106), 400.62 KiB | 15.41 MiB/s, done.
# Resolving deltas: 100% (32/32), done.

# %%
# !pip install pyro-ppl

from pyro.nn import AutoRegressiveNN
# Out:
# Requirement already satisfied: pyro-ppl in /usr/local/lib/python3.6/dist-packages (1.5.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from pyro-ppl) (1.18.5)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from pyro-ppl) (1.6.0+cu101)
# Requirement already satisfied: tqdm>=4.36 in /usr/local/lib/python3.6/dist-packages (from pyro-ppl) (4.41.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from pyro-ppl) (3.3.0)
# Requirement already satisfied: pyro-api>=0.1.1 in /usr/local/lib/python3.6/dist-packages (from pyro-ppl) (0.1.2)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch>=1.6.0->pyro-ppl) (0.16.0)

# %%
path_to_gaussians = os.path.join(os.getcwd(), 'h-vae', 'gaussians')
path_to_gaussians_api = os.path.join(path_to_gaussians, 'api')

sys.path.append(path_to_gaussians)
sys.path.append(path_to_gaussians_api)

# %%
from models import HVAE, NF, VB, IAF

# %%
class gaussian_dataset(Dataset):
    def __init__(self, x):
          'Initialization'
          self.x = x

    def __len__(self):
          'Denotes the total number of samples'
          return self.x.shape[0]

    def __getitem__(self, index):
          'Generates one sample of data'
          x_index = self.x[index]

          return x_index

# %%
def run_test(d, params, 
             batch_size=256,
             clip_value=None,
             dtype=torch.float32, 
             device=torch.device("cpu")):
    """ 
    Run the gaussian test with dimension d 
    """

    ######### Problem Specification

    # Data generation parameters
    prior_mu_z = torch.zeros(d, dtype=dtype)    # Prior mean
    prior_sigma_z = torch.eye(d, dtype=dtype)   # Prior covariance matrix

    # True model parameters
    num_range = torch.arange(-(d-1)/2, (d+1)/2, dtype=dtype)

    t_delta =  num_range / 5 

    print(f"true delta = {t_delta.numpy()}")

    if d == 1:
        t_sigma = torch.ones(1, dtype=dtype)
    else: 
        # Allow sigma to range from 0.1 to 1
        t_sigma = 36/(10*(d-1)**2) * num_range**2 + 0.1 
    print(f"true sigma = {t_sigma.numpy()}")

    ######### Variable Initialization

    # Initial model parameters - same across all methods
    init_delta = prior_mu_z.clone().to(device)
    init_log_sigma = 3 * torch.ones(d).to(device)

    # Initial HVAE variational parameters
    init_T = torch.tensor(5., dtype=dtype, device=device)
    init_eps = 0.005 * torch.ones(d, dtype=dtype)
    max_eps = params['max_eps'] * torch.ones(d, dtype=dtype)
    init_logit_eps = torch.log(init_eps/(max_eps - init_eps)).to(device)
    init_log_T_0 = torch.log(init_T - 1)

    # Initial NF variational parameters
    init_u_pre_reparam = torch.tensor(scipy.stats.truncnorm.rvs(-2, 2, 
                                                                scale=0.1, 
                                                                size=d),
                                      dtype=dtype, device=device)
    init_w = torch.tensor(scipy.stats.truncnorm.rvs(-2, 2, scale=0.1, size=d),
                          dtype=dtype, device=device)
    init_b = torch.tensor(0.1, dtype=dtype, device=device)

    # Initial VAE parameters
    init_mu_z = prior_mu_z.clone()
    init_log_sigma_z = torch.ones(d, dtype=dtype)

    ######### Set up models
    init_params = [[init_delta, init_log_sigma, init_logit_eps, init_log_T_0],
                   [init_delta, init_log_sigma, init_logit_eps, init_log_T_0],
                   [init_delta, init_log_sigma, init_u_pre_reparam, init_w, init_b],
                   [init_delta, init_log_sigma, init_u_pre_reparam, init_w, init_b],
                   [init_delta, init_log_sigma, init_mu_z, init_log_sigma_z]]

    HVAE_model_1 = HVAE(params,
        ['delta', 'log_sigma', 'logit_eps', 'log_T_0'],
        init_params[0], 
        'HVAE_1', d, params['HVAE_K_1'])
    HVAE_model_2 = HVAE(params,
        ['delta', 'log_sigma', 'logit_eps', 'log_T_0'],
        init_params[1], 
        'HVAE_2', d, params['HVAE_K_2'])
    
    
    NF_model_1 = NF(params,
        ['delta', 'log_sigma', 'u_pre_reparam', 'w', 'b'],
        init_params[2],
        'NF_1', d, params['NF_K_1'])
    
    NF_model_2 = NF(params,
        ['delta', 'log_sigma', 'u_pre_reparam', 'w', 'b'],
        init_params[3],
        'NF_2', d, params['NF_K_2'])
    
    VB_model = VB(params,
        ['delta', 'log_sigma', 'mu_z', 'log_sigma_z'], 
        init_params[4], 'VB', d)

    #model_list = [HVAE_model_1, HVAE_model_2, NF_model_1]
    #model_list = [HVAE_model_1, NF_model_1]
    model_list = [HVAE_model_1, HVAE_model_2, NF_model_1, NF_model_2, VB_model]

    print("Models were initialized!")
    
    ######### Generate Training Data & Save - One for each test

    train_data_list = []

    for i in range(params['n_tests']):
        z = MultivariateNormal(prior_mu_z, prior_sigma_z).sample()
        x = MultivariateNormal(z + t_delta, 
                               torch.diag(t_sigma**2)).sample([params['n_data']])
        x = x.to(device)
        train_data_list.append(x)

    # Folder should have already been created in the initializations
    data_path = os.path.join('save', str(d), 'train_data.p')
    pickle.dump(train_data_list, open(data_path, 'wb')) 

    # Store the final parameter values for all test runs in this dictionary
    final_params = {}

    for i in range(len(model_list)):
        final_values = []
        m = model_list[i]
        model_init_params = init_params[i]

        for j in range(params['n_tests']):
            print("------------------------------------------------------")
            print(f"Test = {j}")
            print("------------------------------------------------------")
            m._reinitialize(model_init_params)
            gaussian_data = gaussian_dataset(train_data_list[j])
            train_dataloader = DataLoader(gaussian_data, batch_size=batch_size,
                                          shuffle=False, num_workers=0)
            (delta, sigma) = m.train(train_dataloader, j, 
                                     t_delta, t_sigma,
                                     clip_value)
            final_values.append((delta, sigma))

        final_params[m.model_name] = final_values.copy()

    ######### Test models using difference between parameters

    param_diffs = {}

    for m in model_list:
        
        diffs = []

        for i in range(params['n_tests']):
            delta = final_params[m.model_name][i][0]
            sigma = final_params[m.model_name][i][1]

            delta_diff = np.sum((delta - t_delta.numpy())**2)
            sigma_diff = np.sum((sigma - t_sigma.numpy())**2)
            theta_diff = delta_diff + sigma_diff
            print(f"Model {m.model_name}, test = {i}, result delta diff = {delta_diff}")
            print(f"Model {m.model_name}, test = {i}, result sigma diff = {sigma_diff}")
            print(f"Model {m.model_name}, test = {i}, result theta diff = {theta_diff}")

            diffs.append((delta_diff, sigma_diff, theta_diff))

        param_diffs[m.model_name] = diffs.copy()

    # Save parameter differences in a pickle file
    diff_path = os.path.join('save', str(d), 'all_diffs.p')
    pickle.dump(param_diffs, open(diff_path, 'wb'))

# %%
params = {

    # PROBLEM SPECIFICATION
    #'dims': [1, 2, 3, 5, 11, 25, 51, 101, 201, 301], # Dimensions to test
    'dims': [300],
    'n_data': 10000,                                 # Number of data points

    # TEST HYPERPARAMETERS
    'n_tests': 3,      # Number of experiments to run

    # GLOBAL OPTIMIZATION PARAMETERS
    'n_iter': 2000,    # Number of optimization iterations
    'n_batch': 10,      # Number of points for ELBO estimate
    'rms_eta': 0.001,   # Stepsize for RMSProp
    'save_every': 20,   # Save parameter information every so often
    'print_every': 20, # Print less often than save

    # HVAE HYPERPARAMETERS
    'HVAE_K_1': 1,    # Number of leapfrog/cooling steps for HVAE flow 1
    'HVAE_K_2': 10,   # Number of leapfrog/cooling steps for HVAE flow 2
    'max_eps': 0.5,   # Maximum leapfrog step size per dimension 

    # NF HYPERPARAMETERS
    'NF_K_1': 1,    # Number of flow steps for NF flow 1
    'NF_K_2': 30,   # Number of flow steps for NF flow 2
    
}

# %%
device = torch.device("cpu")
dtype = torch.float32
clip_value = 1e-4
batch_size = 256

# %%
dims = params['dims']
seed = 12345
np.random.seed(seed)
torch.manual_seed(seed)
for d in dims:
    print('**** Running test for d={0:d} ****'.format(d))
    run_test(d, params, batch_size, clip_value, dtype, device)
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# HVAE_2, d: 300, Iter: 3-420, s/iter: 3.424e-01, ELBO: -2.807e+06
# Cur diff delta = 9378.787109375
# Cur diff sigma = 3276.275146484375
# Cur diff theta = 12655.062255859375
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-440, s/iter: 3.431e-01, ELBO: -2.638e+06
# Cur diff delta = 7977.6875
# Cur diff sigma = 2558.181884765625
# Cur diff theta = 10535.869384765625
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-460, s/iter: 3.416e-01, ELBO: -2.476e+06
# Cur diff delta = 6729.39697265625
# Cur diff sigma = 1829.490478515625
# Cur diff theta = 8558.887451171875
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-480, s/iter: 3.468e-01, ELBO: -2.310e+06
# Cur diff delta = 5630.25732421875
# Cur diff sigma = 1202.855712890625
# Cur diff theta = 6833.113037109375
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-500, s/iter: 3.430e-01, ELBO: -2.170e+06
# Cur diff delta = 4662.4755859375
# Cur diff sigma = 793.0405883789062
# Cur diff theta = 5455.516174316406
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-520, s/iter: 3.458e-01, ELBO: -2.053e+06
# Cur diff delta = 3817.332763671875
# Cur diff sigma = 528.3982543945312
# Cur diff theta = 4345.731018066406
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-540, s/iter: 3.439e-01, ELBO: -1.944e+06
# Cur diff delta = 3089.529052734375
# Cur diff sigma = 203.07264709472656
# Cur diff theta = 3292.6016998291016
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-560, s/iter: 3.448e-01, ELBO: -1.852e+06
# Cur diff delta = 2470.766357421875
# Cur diff sigma = 85.05914306640625
# Cur diff theta = 2555.8255004882812
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-580, s/iter: 3.471e-01, ELBO: -1.781e+06
# Cur diff delta = 1950.7957763671875
# Cur diff sigma = 23.3428897857666
# Cur diff theta = 1974.138666152954
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-600, s/iter: 3.473e-01, ELBO: -1.725e+06
# Cur diff delta = 1520.8284912109375
# Cur diff sigma = 10.678154945373535
# Cur diff theta = 1531.506646156311
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-620, s/iter: 3.401e-01, ELBO: -1.688e+06
# Cur diff delta = 1176.9532470703125
# Cur diff sigma = 5.570600986480713
# Cur diff theta = 1182.5238480567932
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-640, s/iter: 3.384e-01, ELBO: -1.656e+06
# Cur diff delta = 906.2423706054688
# Cur diff sigma = 3.1885437965393066
# Cur diff theta = 909.430914402008
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-660, s/iter: 3.458e-01, ELBO: -1.634e+06
# Cur diff delta = 698.39501953125
# Cur diff sigma = 1.9120473861694336
# Cur diff theta = 700.3070669174194
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-680, s/iter: 3.411e-01, ELBO: -1.614e+06
# Cur diff delta = 546.2741088867188
# Cur diff sigma = 1.1814756393432617
# Cur diff theta = 547.455584526062
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-700, s/iter: 3.408e-01, ELBO: -1.596e+06
# Cur diff delta = 442.7396545410156
# Cur diff sigma = 0.8021369576454163
# Cur diff theta = 443.54179149866104
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-720, s/iter: 3.385e-01, ELBO: -1.595e+06
# Cur diff delta = 380.1708068847656
# Cur diff sigma = 0.5998051762580872
# Cur diff theta = 380.7706120610237
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-740, s/iter: 3.407e-01, ELBO: -1.589e+06
# Cur diff delta = 346.5638732910156
# Cur diff sigma = 0.49942657351493835
# Cur diff theta = 347.06329986453056
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-760, s/iter: 3.417e-01, ELBO: -1.588e+06
# Cur diff delta = 333.1557312011719
# Cur diff sigma = 0.4602363109588623
# Cur diff theta = 333.61596751213074
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-780, s/iter: 3.376e-01, ELBO: -1.584e+06
# Cur diff delta = 330.1679382324219
# Cur diff sigma = 0.4469093978404999
# Cur diff theta = 330.6148476302624
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-800, s/iter: 3.402e-01, ELBO: -1.583e+06
# Cur diff delta = 333.1280212402344
# Cur diff sigma = 0.4452182650566101
# Cur diff theta = 333.573239505291
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-820, s/iter: 3.408e-01, ELBO: -1.581e+06
# Cur diff delta = 337.5209045410156
# Cur diff sigma = 0.4493120312690735
# Cur diff theta = 337.9702165722847
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-840, s/iter: 3.482e-01, ELBO: -1.580e+06
# Cur diff delta = 339.5678405761719
# Cur diff sigma = 0.44967737793922424
# Cur diff theta = 340.0175179541111
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-860, s/iter: 3.488e-01, ELBO: -1.576e+06
# Cur diff delta = 339.7864685058594
# Cur diff sigma = 0.44902899861335754
# Cur diff theta = 340.23549750447273
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-880, s/iter: 3.392e-01, ELBO: -1.584e+06
# Cur diff delta = 339.4646911621094
# Cur diff sigma = 0.4473738372325897
# Cur diff theta = 339.91206499934196
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-900, s/iter: 3.386e-01, ELBO: -1.585e+06
# Cur diff delta = 340.43988037109375
# Cur diff sigma = 0.4495806097984314
# Cur diff theta = 340.8894609808922
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-920, s/iter: 3.420e-01, ELBO: -1.583e+06
# Cur diff delta = 340.06622314453125
# Cur diff sigma = 0.4483066201210022
# Cur diff theta = 340.51452976465225
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-940, s/iter: 3.426e-01, ELBO: -1.583e+06
# Cur diff delta = 339.5749206542969
# Cur diff sigma = 0.4516315460205078
# Cur diff theta = 340.0265522003174
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-960, s/iter: 3.359e-01, ELBO: -1.583e+06
# Cur diff delta = 339.8536071777344
# Cur diff sigma = 0.4488130509853363
# Cur diff theta = 340.3024202287197
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-980, s/iter: 3.362e-01, ELBO: -1.576e+06
# Cur diff delta = 339.777099609375
# Cur diff sigma = 0.4472997486591339
# Cur diff theta = 340.22439935803413
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1000, s/iter: 3.335e-01, ELBO: -1.580e+06
# Cur diff delta = 340.4235534667969
# Cur diff sigma = 0.4503220319747925
# Cur diff theta = 340.87387549877167
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1020, s/iter: 3.347e-01, ELBO: -1.584e+06
# Cur diff delta = 340.4140930175781
# Cur diff sigma = 0.4499013423919678
# Cur diff theta = 340.8639943599701
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1040, s/iter: 3.358e-01, ELBO: -1.578e+06
# Cur diff delta = 339.9560546875
# Cur diff sigma = 0.45038899779319763
# Cur diff theta = 340.4064436852932
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1060, s/iter: 3.397e-01, ELBO: -1.579e+06
# Cur diff delta = 339.7865295410156
# Cur diff sigma = 0.45189806818962097
# Cur diff theta = 340.23842760920525
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1080, s/iter: 3.392e-01, ELBO: -1.585e+06
# Cur diff delta = 340.8729248046875
# Cur diff sigma = 0.4511418342590332
# Cur diff theta = 341.32406663894653
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1100, s/iter: 3.339e-01, ELBO: -1.585e+06
# Cur diff delta = 340.8273620605469
# Cur diff sigma = 0.4508707523345947
# Cur diff theta = 341.27823281288147
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1120, s/iter: 3.407e-01, ELBO: -1.580e+06
# Cur diff delta = 340.203857421875
# Cur diff sigma = 0.4500114321708679
# Cur diff theta = 340.65386885404587
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1140, s/iter: 3.387e-01, ELBO: -1.579e+06
# Cur diff delta = 340.0737609863281
# Cur diff sigma = 0.45130059123039246
# Cur diff theta = 340.5250615775585
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1160, s/iter: 3.354e-01, ELBO: -1.584e+06
# Cur diff delta = 339.5638122558594
# Cur diff sigma = 0.45040464401245117
# Cur diff theta = 340.0142168998718
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1180, s/iter: 3.376e-01, ELBO: -1.579e+06
# Cur diff delta = 339.6719970703125
# Cur diff sigma = 0.45000800490379333
# Cur diff theta = 340.1220050752163
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1200, s/iter: 3.392e-01, ELBO: -1.581e+06
# Cur diff delta = 341.4117431640625
# Cur diff sigma = 0.45211973786354065
# Cur diff theta = 341.86386290192604
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1220, s/iter: 3.332e-01, ELBO: -1.581e+06
# Cur diff delta = 339.9119567871094
# Cur diff sigma = 0.4509386122226715
# Cur diff theta = 340.36289539933205
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1240, s/iter: 3.312e-01, ELBO: -1.580e+06
# Cur diff delta = 339.7547302246094
# Cur diff sigma = 0.4498145878314972
# Cur diff theta = 340.2045448124409
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1260, s/iter: 3.342e-01, ELBO: -1.579e+06
# Cur diff delta = 340.3878173828125
# Cur diff sigma = 0.44870710372924805
# Cur diff theta = 340.83652448654175
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1280, s/iter: 3.384e-01, ELBO: -1.583e+06
# Cur diff delta = 340.2666320800781
# Cur diff sigma = 0.45066937804222107
# Cur diff theta = 340.71730145812035
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1300, s/iter: 3.388e-01, ELBO: -1.577e+06
# Cur diff delta = 339.60345458984375
# Cur diff sigma = 0.45131877064704895
# Cur diff theta = 340.0547733604908
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1320, s/iter: 3.368e-01, ELBO: -1.585e+06
# Cur diff delta = 340.1773376464844
# Cur diff sigma = 0.45038893818855286
# Cur diff theta = 340.6277265846729
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1340, s/iter: 3.281e-01, ELBO: -1.579e+06
# Cur diff delta = 339.98199462890625
# Cur diff sigma = 0.44960132241249084
# Cur diff theta = 340.43159595131874
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1360, s/iter: 3.288e-01, ELBO: -1.584e+06
# Cur diff delta = 340.1984558105469
# Cur diff sigma = 0.44996827840805054
# Cur diff theta = 340.6484240889549
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1380, s/iter: 3.285e-01, ELBO: -1.581e+06
# Cur diff delta = 339.8346252441406
# Cur diff sigma = 0.45143982768058777
# Cur diff theta = 340.2860650718212
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1400, s/iter: 3.336e-01, ELBO: -1.581e+06
# Cur diff delta = 339.39068603515625
# Cur diff sigma = 0.4498613774776459
# Cur diff theta = 339.8405474126339
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1420, s/iter: 3.383e-01, ELBO: -1.583e+06
# Cur diff delta = 340.31927490234375
# Cur diff sigma = 0.45109039545059204
# Cur diff theta = 340.77036529779434
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1440, s/iter: 3.323e-01, ELBO: -1.587e+06
# Cur diff delta = 340.5532531738281
# Cur diff sigma = 0.45188549160957336
# Cur diff theta = 341.0051386654377
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1460, s/iter: 3.316e-01, ELBO: -1.578e+06
# Cur diff delta = 340.9029235839844
# Cur diff sigma = 0.44967976212501526
# Cur diff theta = 341.3526033461094
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1480, s/iter: 3.296e-01, ELBO: -1.579e+06
# Cur diff delta = 339.70257568359375
# Cur diff sigma = 0.448718398809433
# Cur diff theta = 340.1512940824032
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1500, s/iter: 3.373e-01, ELBO: -1.577e+06
# Cur diff delta = 339.56085205078125
# Cur diff sigma = 0.4507962763309479
# Cur diff theta = 340.0116483271122
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1520, s/iter: 3.291e-01, ELBO: -1.582e+06
# Cur diff delta = 340.4685974121094
# Cur diff sigma = 0.44820281863212585
# Cur diff theta = 340.9168002307415
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1540, s/iter: 3.312e-01, ELBO: -1.583e+06
# Cur diff delta = 339.75787353515625
# Cur diff sigma = 0.4479525685310364
# Cur diff theta = 340.2058261036873
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1560, s/iter: 3.411e-01, ELBO: -1.586e+06
# Cur diff delta = 340.0634765625
# Cur diff sigma = 0.4505998492240906
# Cur diff theta = 340.5140764117241
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1580, s/iter: 3.336e-01, ELBO: -1.581e+06
# Cur diff delta = 339.8736572265625
# Cur diff sigma = 0.45066073536872864
# Cur diff theta = 340.32431796193123
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1600, s/iter: 3.307e-01, ELBO: -1.579e+06
# Cur diff delta = 339.9207763671875
# Cur diff sigma = 0.45006805658340454
# Cur diff theta = 340.3708444237709
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1620, s/iter: 3.299e-01, ELBO: -1.583e+06
# Cur diff delta = 340.3217468261719
# Cur diff sigma = 0.4509482681751251
# Cur diff theta = 340.772695094347
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1640, s/iter: 3.285e-01, ELBO: -1.583e+06
# Cur diff delta = 340.81256103515625
# Cur diff sigma = 0.4489270746707916
# Cur diff theta = 341.26148810982704
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1660, s/iter: 3.301e-01, ELBO: -1.581e+06
# Cur diff delta = 340.3214416503906
# Cur diff sigma = 0.4504741132259369
# Cur diff theta = 340.77191576361656
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1680, s/iter: 3.272e-01, ELBO: -1.585e+06
# Cur diff delta = 339.8408203125
# Cur diff sigma = 0.44974982738494873
# Cur diff theta = 340.29057013988495
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1700, s/iter: 3.272e-01, ELBO: -1.581e+06
# Cur diff delta = 339.89031982421875
# Cur diff sigma = 0.4510747492313385
# Cur diff theta = 340.3413945734501
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1720, s/iter: 3.223e-01, ELBO: -1.582e+06
# Cur diff delta = 339.83026123046875
# Cur diff sigma = 0.44911181926727295
# Cur diff theta = 340.279373049736
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1740, s/iter: 3.273e-01, ELBO: -1.579e+06
# Cur diff delta = 340.3196105957031
# Cur diff sigma = 0.44980061054229736
# Cur diff theta = 340.7694112062454
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1760, s/iter: 3.280e-01, ELBO: -1.582e+06
# Cur diff delta = 339.50518798828125
# Cur diff sigma = 0.45008566975593567
# Cur diff theta = 339.9552736580372
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1780, s/iter: 3.340e-01, ELBO: -1.584e+06
# Cur diff delta = 339.6517028808594
# Cur diff sigma = 0.4513992369174957
# Cur diff theta = 340.10310211777687
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1800, s/iter: 3.417e-01, ELBO: -1.584e+06
# Cur diff delta = 340.85174560546875
# Cur diff sigma = 0.45255517959594727
# Cur diff theta = 341.3043007850647
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1820, s/iter: 3.289e-01, ELBO: -1.580e+06
# Cur diff delta = 340.4649353027344
# Cur diff sigma = 0.44863441586494446
# Cur diff theta = 340.9135697185993
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1840, s/iter: 3.255e-01, ELBO: -1.580e+06
# Cur diff delta = 340.1478576660156
# Cur diff sigma = 0.4480559825897217
# Cur diff theta = 340.59591364860535
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1860, s/iter: 3.306e-01, ELBO: -1.577e+06
# Cur diff delta = 341.2352600097656
# Cur diff sigma = 0.4497798979282379
# Cur diff theta = 341.68503990769386
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1880, s/iter: 3.302e-01, ELBO: -1.580e+06
# Cur diff delta = 340.05517578125
# Cur diff sigma = 0.4517006278038025
# Cur diff theta = 340.5068764090538
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1900, s/iter: 3.303e-01, ELBO: -1.575e+06
# Cur diff delta = 340.0072021484375
# Cur diff sigma = 0.4490489959716797
# Cur diff theta = 340.4562511444092
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1920, s/iter: 3.289e-01, ELBO: -1.579e+06
# Cur diff delta = 339.7502136230469
# Cur diff sigma = 0.4507659673690796
# Cur diff theta = 340.20097959041595
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1940, s/iter: 3.239e-01, ELBO: -1.576e+06
# Cur diff delta = 340.2520446777344
# Cur diff sigma = 0.44804081320762634
# Cur diff theta = 340.700085490942
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1960, s/iter: 3.292e-01, ELBO: -1.583e+06
# Cur diff delta = 340.0895690917969
# Cur diff sigma = 0.44734323024749756
# Cur diff theta = 340.5369123220444
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-1980, s/iter: 3.308e-01, ELBO: -1.578e+06
# Cur diff delta = 339.7230224609375
# Cur diff sigma = 0.45004749298095703
# Cur diff theta = 340.17306995391846
# ---------------------------------------
# HVAE_2, d: 300, Iter: 3-2000, s/iter: 3.247e-01, ELBO: -1.581e+06
# Cur diff delta = 340.1567687988281
# Cur diff sigma = 0.44657421112060547
# Cur diff theta = 340.60334300994873
# ---------------------------------------
# ------------------------------------------------------
# Test = 2
# ------------------------------------------------------
# Init diff delta = 89999.0078125
# Init diff sigma = 116254.2890625
# Init diff theta = 206253.296875
# NF_1, d: 300, Iter: 1-20, s/iter: 1.198e-01, ELBO: -1.269e+07
# Cur diff delta = 82349.609375
# Cur diff sigma = 158095.359375
# Cur diff theta = 240444.96875
# ---------------------------------------
# NF_1, d: 300, Iter: 1-40, s/iter: 1.215e-01, ELBO: -1.221e+07
# Cur diff delta = 78008.2734375
# Cur diff sigma = 145849.015625
# Cur diff theta = 223857.2890625
# ---------------------------------------
# NF_1, d: 300, Iter: 1-60, s/iter: 1.238e-01, ELBO: -1.199e+07
# Cur diff delta = 76146.7578125
# Cur diff sigma = 140714.796875
# Cur diff theta = 216861.5546875
# ---------------------------------------
# NF_1, d: 300, Iter: 1-80, s/iter: 1.219e-01, ELBO: -1.164e+07
# Cur diff delta = 72914.8515625
# Cur diff sigma = 133543.25
# Cur diff theta = 206458.1015625
# ---------------------------------------
# NF_1, d: 300, Iter: 1-100, s/iter: 1.227e-01, ELBO: -1.126e+07
# Cur diff delta = 68035.578125
# Cur diff sigma = 121044.6640625
# Cur diff theta = 189080.2421875
# ---------------------------------------
# NF_1, d: 300, Iter: 1-120, s/iter: 1.222e-01, ELBO: -1.096e+07
# Cur diff delta = 63109.22265625
# Cur diff sigma = 108876.421875
# Cur diff theta = 171985.64453125
# ---------------------------------------
# NF_1, d: 300, Iter: 1-140, s/iter: 1.219e-01, ELBO: -1.071e+07
# Cur diff delta = 58849.4765625
# Cur diff sigma = 99437.0078125
# Cur diff theta = 158286.484375
# ---------------------------------------
# NF_1, d: 300, Iter: 1-160, s/iter: 1.219e-01, ELBO: -1.047e+07
# Cur diff delta = 55030.46484375
# Cur diff sigma = 91168.7265625
# Cur diff theta = 146199.19140625
# ---------------------------------------
# NF_1, d: 300, Iter: 1-180, s/iter: 1.223e-01, ELBO: -1.024e+07
# Cur diff delta = 51608.8125
# Cur diff sigma = 84195.625
# Cur diff theta = 135804.4375
# ---------------------------------------
# NF_1, d: 300, Iter: 1-200, s/iter: 1.236e-01, ELBO: -1.004e+07
# Cur diff delta = 48570.546875
# Cur diff sigma = 78234.703125
# Cur diff theta = 126805.25
# ---------------------------------------
# NF_1, d: 300, Iter: 1-220, s/iter: 1.188e-01, ELBO: -9.836e+06
# Cur diff delta = 45867.96484375
# Cur diff sigma = 73040.7421875
# Cur diff theta = 118908.70703125
# ---------------------------------------
# NF_1, d: 300, Iter: 1-240, s/iter: 1.213e-01, ELBO: -9.656e+06
# Cur diff delta = 43415.05078125
# Cur diff sigma = 68497.6640625
# Cur diff theta = 111912.71484375
# ---------------------------------------
# NF_1, d: 300, Iter: 1-260, s/iter: 1.197e-01, ELBO: -9.484e+06
# Cur diff delta = 41110.546875
# Cur diff sigma = 64312.17578125
# Cur diff theta = 105422.72265625
# ---------------------------------------
# NF_1, d: 300, Iter: 1-280, s/iter: 1.229e-01, ELBO: -9.317e+06
# Cur diff delta = 38954.27734375
# Cur diff sigma = 60440.8984375
# Cur diff theta = 99395.17578125
# ---------------------------------------
# NF_1, d: 300, Iter: 1-300, s/iter: 1.213e-01, ELBO: -9.155e+06
# Cur diff delta = 36948.7265625
# Cur diff sigma = 56912.5546875
# Cur diff theta = 93861.28125
# ---------------------------------------
# NF_1, d: 300, Iter: 1-320, s/iter: 1.208e-01, ELBO: -8.997e+06
# Cur diff delta = 35090.5078125
# Cur diff sigma = 53656.9375
# Cur diff theta = 88747.4453125
# ---------------------------------------
# NF_1, d: 300, Iter: 1-340, s/iter: 1.209e-01, ELBO: -8.830e+06
# Cur diff delta = 33365.5390625
# Cur diff sigma = 50699.03515625
# Cur diff theta = 84064.57421875
# ---------------------------------------
# NF_1, d: 300, Iter: 1-360, s/iter: 1.196e-01, ELBO: -8.690e+06
# Cur diff delta = 31764.88671875
# Cur diff sigma = 47981.83203125
# Cur diff theta = 79746.71875
# ---------------------------------------
# NF_1, d: 300, Iter: 1-380, s/iter: 1.217e-01, ELBO: -8.556e+06
# Cur diff delta = 30243.169921875
# Cur diff sigma = 45411.7890625
# Cur diff theta = 75654.958984375
# ---------------------------------------
# NF_1, d: 300, Iter: 1-400, s/iter: 1.221e-01, ELBO: -8.425e+06
# Cur diff delta = 28775.326171875
# Cur diff sigma = 42921.4453125
# Cur diff theta = 71696.771484375
# ---------------------------------------
# NF_1, d: 300, Iter: 1-420, s/iter: 1.214e-01, ELBO: -8.294e+06
# Cur diff delta = 27334.900390625
# Cur diff sigma = 40486.87890625
# Cur diff theta = 67821.779296875
# ---------------------------------------
# NF_1, d: 300, Iter: 1-440, s/iter: 1.215e-01, ELBO: -8.170e+06
# Cur diff delta = 25931.83984375
# Cur diff sigma = 38125.58203125
# Cur diff theta = 64057.421875
# ---------------------------------------
# NF_1, d: 300, Iter: 1-460, s/iter: 1.218e-01, ELBO: -8.034e+06
# Cur diff delta = 24560.46875
# Cur diff sigma = 35863.6328125
# Cur diff theta = 60424.1015625
# ---------------------------------------
# NF_1, d: 300, Iter: 1-480, s/iter: 1.190e-01, ELBO: -7.922e+06
# Cur diff delta = 23210.197265625
# Cur diff sigma = 33627.64453125
# Cur diff theta = 56837.841796875
# ---------------------------------------
# NF_1, d: 300, Iter: 1-500, s/iter: 1.196e-01, ELBO: -7.797e+06
# Cur diff delta = 21872.888671875
# Cur diff sigma = 31419.919921875
# Cur diff theta = 53292.80859375
# ---------------------------------------
# NF_1, d: 300, Iter: 1-520, s/iter: 1.210e-01, ELBO: -7.683e+06
# Cur diff delta = 20546.537109375
# Cur diff sigma = 29230.083984375
# Cur diff theta = 49776.62109375
# ---------------------------------------
# NF_1, d: 300, Iter: 1-540, s/iter: 1.210e-01, ELBO: -7.569e+06
# Cur diff delta = 19240.404296875
# Cur diff sigma = 27120.17578125
# Cur diff theta = 46360.580078125
# ---------------------------------------
# NF_1, d: 300, Iter: 1-560, s/iter: 1.205e-01, ELBO: -7.448e+06
# Cur diff delta = 17957.751953125
# Cur diff sigma = 25046.53125
# Cur diff theta = 43004.283203125
# ---------------------------------------
# NF_1, d: 300, Iter: 1-580, s/iter: 1.212e-01, ELBO: -7.324e+06
# Cur diff delta = 16708.86328125
# Cur diff sigma = 23053.7890625
# Cur diff theta = 39762.65234375
# ---------------------------------------
# NF_1, d: 300, Iter: 1-600, s/iter: 1.200e-01, ELBO: -7.199e+06
# Cur diff delta = 15511.013671875
# Cur diff sigma = 21175.736328125
# Cur diff theta = 36686.75
# ---------------------------------------
# NF_1, d: 300, Iter: 1-620, s/iter: 1.216e-01, ELBO: -7.082e+06
# Cur diff delta = 14368.0263671875
# Cur diff sigma = 19401.021484375
# Cur diff theta = 33769.0478515625
# ---------------------------------------
# NF_1, d: 300, Iter: 1-640, s/iter: 1.226e-01, ELBO: -6.965e+06
# Cur diff delta = 13273.5595703125
# Cur diff sigma = 17717.345703125
# Cur diff theta = 30990.9052734375
# ---------------------------------------
# NF_1, d: 300, Iter: 1-660, s/iter: 1.201e-01, ELBO: -6.853e+06
# Cur diff delta = 12225.7392578125
# Cur diff sigma = 16114.28125
# Cur diff theta = 28340.0205078125
# ---------------------------------------
# NF_1, d: 300, Iter: 1-680, s/iter: 1.214e-01, ELBO: -6.746e+06
# Cur diff delta = 11211.978515625
# Cur diff sigma = 14587.9189453125
# Cur diff theta = 25799.8974609375
# ---------------------------------------
# NF_1, d: 300, Iter: 1-700, s/iter: 1.207e-01, ELBO: -6.634e+06
# Cur diff delta = 10227.9228515625
# Cur diff sigma = 13133.0654296875
# Cur diff theta = 23360.98828125
# ---------------------------------------
# NF_1, d: 300, Iter: 1-720, s/iter: 1.249e-01, ELBO: -6.518e+06
# Cur diff delta = 9288.3134765625
# Cur diff sigma = 11784.572265625
# Cur diff theta = 21072.8857421875
# ---------------------------------------
# NF_1, d: 300, Iter: 1-740, s/iter: 1.230e-01, ELBO: -6.409e+06
# Cur diff delta = 8389.0224609375
# Cur diff sigma = 10516.818359375
# Cur diff theta = 18905.8408203125
# ---------------------------------------
# NF_1, d: 300, Iter: 1-760, s/iter: 1.223e-01, ELBO: -6.302e+06
# Cur diff delta = 7523.65283203125
# Cur diff sigma = 9354.6162109375
# Cur diff theta = 16878.26904296875
# ---------------------------------------
# NF_1, d: 300, Iter: 1-780, s/iter: 1.240e-01, ELBO: -6.202e+06
# Cur diff delta = 6683.82421875
# Cur diff sigma = 8250.857421875
# Cur diff theta = 14934.681640625
# ---------------------------------------
# NF_1, d: 300, Iter: 1-800, s/iter: 1.205e-01, ELBO: -6.099e+06
# Cur diff delta = 5877.4150390625
# Cur diff sigma = 7215.77783203125
# Cur diff theta = 13093.19287109375
# ---------------------------------------
# NF_1, d: 300, Iter: 1-820, s/iter: 1.242e-01, ELBO: -5.982e+06
# Cur diff delta = 5113.27294921875
# Cur diff sigma = 6236.49951171875
# Cur diff theta = 11349.7724609375
# ---------------------------------------
# NF_1, d: 300, Iter: 1-840, s/iter: 1.216e-01, ELBO: -5.897e+06
# Cur diff delta = 4405.513671875
# Cur diff sigma = 5343.4951171875
# Cur diff theta = 9749.0087890625
# ---------------------------------------
# NF_1, d: 300, Iter: 1-860, s/iter: 1.210e-01, ELBO: -5.781e+06
# Cur diff delta = 3764.777099609375
# Cur diff sigma = 4569.4501953125
# Cur diff theta = 8334.227294921875
# ---------------------------------------
# NF_1, d: 300, Iter: 1-880, s/iter: 1.236e-01, ELBO: -5.674e+06
# Cur diff delta = 3198.346923828125
# Cur diff sigma = 3874.83203125
# Cur diff theta = 7073.178955078125
# ---------------------------------------
# NF_1, d: 300, Iter: 1-900, s/iter: 1.242e-01, ELBO: -5.580e+06
# Cur diff delta = 2697.95458984375
# Cur diff sigma = 3280.57275390625
# Cur diff theta = 5978.52734375
# ---------------------------------------
# NF_1, d: 300, Iter: 1-920, s/iter: 1.210e-01, ELBO: -5.489e+06
# Cur diff delta = 2252.341796875
# Cur diff sigma = 2741.214111328125
# Cur diff theta = 4993.555908203125
# ---------------------------------------
# NF_1, d: 300, Iter: 1-940, s/iter: 1.225e-01, ELBO: -5.401e+06
# Cur diff delta = 1861.135009765625
# Cur diff sigma = 2273.960693359375
# Cur diff theta = 4135.095703125
# ---------------------------------------
# NF_1, d: 300, Iter: 1-960, s/iter: 1.207e-01, ELBO: -5.316e+06
# Cur diff delta = 1522.299072265625
# Cur diff sigma = 1873.3472900390625
# Cur diff theta = 3395.6463623046875
# ---------------------------------------
# NF_1, d: 300, Iter: 1-980, s/iter: 1.220e-01, ELBO: -5.230e+06
# Cur diff delta = 1233.9375
# Cur diff sigma = 1542.4300537109375
# Cur diff theta = 2776.3675537109375
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1000, s/iter: 1.213e-01, ELBO: -5.162e+06
# Cur diff delta = 995.7396850585938
# Cur diff sigma = 1270.92529296875
# Cur diff theta = 2266.6649780273438
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1020, s/iter: 1.207e-01, ELBO: -5.089e+06
# Cur diff delta = 803.3794555664062
# Cur diff sigma = 1046.632080078125
# Cur diff theta = 1850.0115356445312
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1040, s/iter: 1.206e-01, ELBO: -5.038e+06
# Cur diff delta = 651.6074829101562
# Cur diff sigma = 858.0521240234375
# Cur diff theta = 1509.6596069335938
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1060, s/iter: 1.218e-01, ELBO: -4.985e+06
# Cur diff delta = 535.1908569335938
# Cur diff sigma = 698.533447265625
# Cur diff theta = 1233.7243041992188
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1080, s/iter: 1.230e-01, ELBO: -4.931e+06
# Cur diff delta = 457.9495849609375
# Cur diff sigma = 496.7312316894531
# Cur diff theta = 954.6808166503906
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1100, s/iter: 1.221e-01, ELBO: -4.890e+06
# Cur diff delta = 394.39447021484375
# Cur diff sigma = 408.22412109375
# Cur diff theta = 802.6185913085938
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1120, s/iter: 1.238e-01, ELBO: -4.852e+06
# Cur diff delta = 348.34765625
# Cur diff sigma = 346.31536865234375
# Cur diff theta = 694.6630249023438
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1140, s/iter: 1.219e-01, ELBO: -4.834e+06
# Cur diff delta = 318.8796691894531
# Cur diff sigma = 305.5300598144531
# Cur diff theta = 624.4097290039062
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1160, s/iter: 1.257e-01, ELBO: -4.804e+06
# Cur diff delta = 302.49346923828125
# Cur diff sigma = 275.1549072265625
# Cur diff theta = 577.6483764648438
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1180, s/iter: 1.246e-01, ELBO: -4.798e+06
# Cur diff delta = 292.4364929199219
# Cur diff sigma = 249.5113525390625
# Cur diff theta = 541.9478454589844
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1200, s/iter: 1.228e-01, ELBO: nan
# Cur diff delta = nan
# Cur diff sigma = nan
# Cur diff theta = nan
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1220, s/iter: 1.237e-01, ELBO: nan
# Cur diff delta = nan
# Cur diff sigma = nan
# Cur diff theta = nan
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1240, s/iter: 1.229e-01, ELBO: nan
# Cur diff delta = nan
# Cur diff sigma = nan
# Cur diff theta = nan
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1260, s/iter: 1.212e-01, ELBO: nan
# Cur diff delta = nan
# Cur diff sigma = nan
# Cur diff theta = nan
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1280, s/iter: 1.230e-01, ELBO: nan
# Cur diff delta = nan
# Cur diff sigma = nan
# Cur diff theta = nan
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1300, s/iter: 1.219e-01, ELBO: nan
# Cur diff delta = nan
# Cur diff sigma = nan
# Cur diff theta = nan
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1320, s/iter: 1.231e-01, ELBO: nan
# Cur diff delta = nan
# Cur diff sigma = nan
# Cur diff theta = nan
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1340, s/iter: 1.230e-01, ELBO: nan
# Cur diff delta = nan
# Cur diff sigma = nan
# Cur diff theta = nan
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1360, s/iter: 1.209e-01, ELBO: nan
# Cur diff delta = nan
# Cur diff sigma = nan
# Cur diff theta = nan
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1380, s/iter: 1.233e-01, ELBO: nan
# Cur diff delta = nan
# Cur diff sigma = nan
# Cur diff theta = nan
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1400, s/iter: 1.220e-01, ELBO: nan
# Cur diff delta = nan
# Cur diff sigma = nan
# Cur diff theta = nan
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1420, s/iter: 1.214e-01, ELBO: nan
# Cur diff delta = nan
# Cur diff sigma = nan
# Cur diff theta = nan
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1440, s/iter: 1.198e-01, ELBO: nan
# Cur diff delta = nan
# Cur diff sigma = nan
# Cur diff theta = nan
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1460, s/iter: 1.216e-01, ELBO: nan
# Cur diff delta = nan
# Cur diff sigma = nan
# Cur diff theta = nan
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1480, s/iter: 1.206e-01, ELBO: nan
# Cur diff delta = nan
# Cur diff sigma = nan
# Cur diff theta = nan
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1500, s/iter: 1.217e-01, ELBO: nan
# Cur diff delta = nan
# Cur diff sigma = nan
# Cur diff theta = nan
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1520, s/iter: 1.185e-01, ELBO: nan
# Cur diff delta = nan
# Cur diff sigma = nan
# Cur diff theta = nan
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1540, s/iter: 1.196e-01, ELBO: nan
# Cur diff delta = nan
# Cur diff sigma = nan
# Cur diff theta = nan
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1560, s/iter: 1.220e-01, ELBO: nan
# Cur diff delta = nan
# Cur diff sigma = nan
# Cur diff theta = nan
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1580, s/iter: 1.338e-01, ELBO: nan
# Cur diff delta = nan
# Cur diff sigma = nan
# Cur diff theta = nan
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1600, s/iter: 1.296e-01, ELBO: nan
# Cur diff delta = nan
# Cur diff sigma = nan
# Cur diff theta = nan
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1620, s/iter: 1.270e-01, ELBO: nan
# Cur diff delta = nan
# Cur diff sigma = nan
# Cur diff theta = nan
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1640, s/iter: 1.297e-01, ELBO: nan
# Cur diff delta = nan
# Cur diff sigma = nan
# Cur diff theta = nan
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1660, s/iter: 1.319e-01, ELBO: nan
# Cur diff delta = nan
# Cur diff sigma = nan
# Cur diff theta = nan
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1680, s/iter: 1.256e-01, ELBO: nan
# Cur diff delta = nan
# Cur diff sigma = nan
# Cur diff theta = nan
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1700, s/iter: 1.265e-01, ELBO: nan
# Cur diff delta = nan
# Cur diff sigma = nan
# Cur diff theta = nan
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1720, s/iter: 1.265e-01, ELBO: nan
# Cur diff delta = nan
# Cur diff sigma = nan
# Cur diff theta = nan
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1740, s/iter: 1.314e-01, ELBO: nan
# Cur diff delta = nan
# Cur diff sigma = nan
# Cur diff theta = nan
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1760, s/iter: 1.256e-01, ELBO: nan
# Cur diff delta = nan
# Cur diff sigma = nan
# Cur diff theta = nan
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1780, s/iter: 1.281e-01, ELBO: nan
# Cur diff delta = nan
# Cur diff sigma = nan
# Cur diff theta = nan
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1800, s/iter: 1.274e-01, ELBO: nan
# Cur diff delta = nan
# Cur diff sigma = nan
# Cur diff theta = nan
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1820, s/iter: 1.287e-01, ELBO: nan
# Cur diff delta = nan
# Cur diff sigma = nan
# Cur diff theta = nan
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1840, s/iter: 1.258e-01, ELBO: nan
# Cur diff delta = nan
# Cur diff sigma = nan
# Cur diff theta = nan
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1860, s/iter: 1.287e-01, ELBO: nan
# Cur diff delta = nan
# Cur diff sigma = nan
# Cur diff theta = nan
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1880, s/iter: 1.316e-01, ELBO: nan
# Cur diff delta = nan
# Cur diff sigma = nan
# Cur diff theta = nan
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1900, s/iter: 1.307e-01, ELBO: nan
# Cur diff delta = nan
# Cur diff sigma = nan
# Cur diff theta = nan
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1920, s/iter: 1.307e-01, ELBO: nan
# Cur diff delta = nan
# Cur diff sigma = nan
# Cur diff theta = nan
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1940, s/iter: 1.305e-01, ELBO: nan
# Cur diff delta = nan
# Cur diff sigma = nan
# Cur diff theta = nan
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1960, s/iter: 1.331e-01, ELBO: nan
# Cur diff delta = nan
# Cur diff sigma = nan
# Cur diff theta = nan
# ---------------------------------------
# NF_1, d: 300, Iter: 1-1980, s/iter: 1.339e-01, ELBO: nan
# Cur diff delta = nan
# Cur diff sigma = nan
# Cur diff theta = nan
# ---------------------------------------
# NF_1, d: 300, Iter: 1-2000, s/iter: 1.322e-01, ELBO: nan
# Cur diff delta = nan
# Cur diff sigma = nan
# Cur diff theta = nan
# ---------------------------------------
# ------------------------------------------------------
# Test = 2
# ------------------------------------------------------
# Init diff delta = 89999.0078125
# Init diff sigma = 116254.2890625
# Init diff theta = 206253.296875
# NF_1, d: 300, Iter: 2-20, s/iter: 1.334e-01, ELBO: -1.271e+07
# Cur diff delta = 82339.546875
# Cur diff sigma = 158222.65625
# Cur diff theta = 240562.203125
# ---------------------------------------
# NF_1, d: 300, Iter: 2-40, s/iter: 1.321e-01, ELBO: -1.224e+07
# Cur diff delta = 78095.9921875
# Cur diff sigma = 145624.09375
# Cur diff theta = 223720.0859375
# ---------------------------------------
# NF_1, d: 300, Iter: 2-60, s/iter: 1.334e-01, ELBO: -1.203e+07
# Cur diff delta = 76253.90625
# Cur diff sigma = 140560.3125
# Cur diff theta = 216814.21875
# ---------------------------------------
# NF_1, d: 300, Iter: 2-80, s/iter: 1.310e-01, ELBO: -1.168e+07
# Cur diff delta = 73083.4453125
# Cur diff sigma = 133597.078125
# Cur diff theta = 206680.5234375
# ---------------------------------------
# NF_1, d: 300, Iter: 2-100, s/iter: 1.281e-01, ELBO: -1.132e+07
# Cur diff delta = 68355.0234375
# Cur diff sigma = 121720.1875
# Cur diff theta = 190075.2109375
# ---------------------------------------
# NF_1, d: 300, Iter: 2-120, s/iter: 1.295e-01, ELBO: -1.102e+07
# Cur diff delta = 63354.29296875
# Cur diff sigma = 109269.78125
# Cur diff theta = 172624.07421875
# ---------------------------------------
# NF_1, d: 300, Iter: 2-140, s/iter: 1.286e-01, ELBO: -1.075e+07
# Cur diff delta = 58971.57421875
# Cur diff sigma = 99311.4296875
# Cur diff theta = 158283.00390625
# ---------------------------------------
# NF_1, d: 300, Iter: 2-160, s/iter: 1.279e-01, ELBO: -1.051e+07
# Cur diff delta = 55051.6171875
# Cur diff sigma = 90675.171875
# Cur diff theta = 145726.7890625
# ---------------------------------------
# NF_1, d: 300, Iter: 2-180, s/iter: 1.276e-01, ELBO: -1.028e+07
# Cur diff delta = 51583.7890625
# Cur diff sigma = 83613.1640625
# Cur diff theta = 135196.953125
# ---------------------------------------
# NF_1, d: 300, Iter: 2-200, s/iter: 1.301e-01, ELBO: -1.005e+07
# Cur diff delta = 48510.9375
# Cur diff sigma = 77514.046875
# Cur diff theta = 126024.984375
# ---------------------------------------
# NF_1, d: 300, Iter: 2-220, s/iter: 1.300e-01, ELBO: -9.845e+06
# Cur diff delta = 45804.43359375
# Cur diff sigma = 72407.7109375
# Cur diff theta = 118212.14453125
# ---------------------------------------
# NF_1, d: 300, Iter: 2-240, s/iter: 1.279e-01, ELBO: -9.662e+06
# Cur diff delta = 43412.734375
# Cur diff sigma = 67958.0546875
# Cur diff theta = 111370.7890625
# ---------------------------------------
# NF_1, d: 300, Iter: 2-260, s/iter: 1.279e-01, ELBO: -9.486e+06
# Cur diff delta = 41238.25
# Cur diff sigma = 64042.87109375
# Cur diff theta = 105281.12109375
# ---------------------------------------
# NF_1, d: 300, Iter: 2-280, s/iter: 1.284e-01, ELBO: -9.329e+06
# Cur diff delta = 39228.27734375
# Cur diff sigma = 60405.3828125
# Cur diff theta = 99633.66015625
# ---------------------------------------
# NF_1, d: 300, Iter: 2-300, s/iter: 1.289e-01, ELBO: -9.176e+06
# Cur diff delta = 37346.2421875
# Cur diff sigma = 57067.64453125
# Cur diff theta = 94413.88671875
# ---------------------------------------
# NF_1, d: 300, Iter: 2-320, s/iter: 1.289e-01, ELBO: -9.028e+06
# Cur diff delta = 35550.30859375
# Cur diff sigma = 53886.8203125
# Cur diff theta = 89437.12890625
# ---------------------------------------
# NF_1, d: 300, Iter: 2-340, s/iter: 1.290e-01, ELBO: -8.884e+06
# Cur diff delta = 33829.22265625
# Cur diff sigma = 50877.328125
# Cur diff theta = 84706.55078125
# ---------------------------------------
# NF_1, d: 300, Iter: 2-360, s/iter: 1.274e-01, ELBO: -8.735e+06
# Cur diff delta = 32174.55859375
# Cur diff sigma = 48047.12109375
# Cur diff theta = 80221.6796875
# ---------------------------------------
# NF_1, d: 300, Iter: 2-380, s/iter: 1.289e-01, ELBO: -8.601e+06
# Cur diff delta = 30582.29296875
# Cur diff sigma = 45298.7734375
# Cur diff theta = 75881.06640625
# ---------------------------------------
# NF_1, d: 300, Iter: 2-400, s/iter: 1.276e-01, ELBO: -8.472e+06
# Cur diff delta = 29035.494140625
# Cur diff sigma = 42660.421875
# Cur diff theta = 71695.916015625
# ---------------------------------------
# NF_1, d: 300, Iter: 2-420, s/iter: 1.274e-01, ELBO: -8.328e+06
# Cur diff delta = 27517.318359375
# Cur diff sigma = 40076.6953125
# Cur diff theta = 67594.013671875
# ---------------------------------------
# NF_1, d: 300, Iter: 2-440, s/iter: 1.313e-01, ELBO: -8.204e+06
# Cur diff delta = 26035.462890625
# Cur diff sigma = 37594.41015625
# Cur diff theta = 63629.873046875
# ---------------------------------------
# NF_1, d: 300, Iter: 2-460, s/iter: 1.295e-01, ELBO: -8.073e+06
# Cur diff delta = 24607.814453125
# Cur diff sigma = 35233.71875
# Cur diff theta = 59841.533203125
# ---------------------------------------
# NF_1, d: 300, Iter: 2-480, s/iter: 1.302e-01, ELBO: -7.939e+06
# Cur diff delta = 23246.623046875
# Cur diff sigma = 32996.2734375
# Cur diff theta = 56242.896484375
# ---------------------------------------
# NF_1, d: 300, Iter: 2-500, s/iter: 1.289e-01, ELBO: -7.813e+06
# Cur diff delta = 21940.09765625
# Cur diff sigma = 30866.76953125
# Cur diff theta = 52806.8671875
# ---------------------------------------
# NF_1, d: 300, Iter: 2-520, s/iter: 1.299e-01, ELBO: -7.694e+06
# Cur diff delta = 20664.11328125
# Cur diff sigma = 28779.294921875
# Cur diff theta = 49443.408203125
# ---------------------------------------
# NF_1, d: 300, Iter: 2-540, s/iter: 1.291e-01, ELBO: -7.577e+06
# Cur diff delta = 19414.18359375
# Cur diff sigma = 26750.9609375
# Cur diff theta = 46165.14453125
# ---------------------------------------
# NF_1, d: 300, Iter: 2-560, s/iter: 1.279e-01, ELBO: -7.457e+06
# Cur diff delta = 18180.267578125
# Cur diff sigma = 24762.5234375
# Cur diff theta = 42942.791015625
# ---------------------------------------
# NF_1, d: 300, Iter: 2-580, s/iter: 1.278e-01, ELBO: -7.339e+06
# Cur diff delta = 16961.31640625
# Cur diff sigma = 22812.341796875
# Cur diff theta = 39773.658203125
# ---------------------------------------
# NF_1, d: 300, Iter: 2-600, s/iter: 1.269e-01, ELBO: -7.229e+06
# Cur diff delta = 15757.8125
# Cur diff sigma = 20892.205078125
# Cur diff theta = 36650.017578125
# ---------------------------------------
# NF_1, d: 300, Iter: 2-620, s/iter: 1.274e-01, ELBO: -7.113e+06
# Cur diff delta = 14581.365234375
# Cur diff sigma = 19072.125
# Cur diff theta = 33653.490234375
# ---------------------------------------
# NF_1, d: 300, Iter: 2-640, s/iter: 1.298e-01, ELBO: -7.002e+06
# Cur diff delta = 13441.0908203125
# Cur diff sigma = 17321.849609375
# Cur diff theta = 30762.9404296875
# ---------------------------------------
# NF_1, d: 300, Iter: 2-660, s/iter: 1.283e-01, ELBO: -6.882e+06
# Cur diff delta = 12348.2021484375
# Cur diff sigma = 15663.53515625
# Cur diff theta = 28011.7373046875
# ---------------------------------------
# NF_1, d: 300, Iter: 2-680, s/iter: 1.314e-01, ELBO: -6.768e+06
# Cur diff delta = 11307.1259765625
# Cur diff sigma = 14109.03515625
# Cur diff theta = 25416.1611328125
# ---------------------------------------
# NF_1, d: 300, Iter: 2-700, s/iter: 1.321e-01, ELBO: -6.645e+06
# Cur diff delta = 10317.3916015625
# Cur diff sigma = 12643.982421875
# Cur diff theta = 22961.3740234375
# ---------------------------------------
# NF_1, d: 300, Iter: 2-720, s/iter: 1.315e-01, ELBO: -6.534e+06
# Cur diff delta = 9374.3916015625
# Cur diff sigma = 11287.0751953125
# Cur diff theta = 20661.466796875
# ---------------------------------------
# NF_1, d: 300, Iter: 2-740, s/iter: 1.287e-01, ELBO: -6.424e+06
# Cur diff delta = 8476.423828125
# Cur diff sigma = 10026.9609375
# Cur diff theta = 18503.384765625
# ---------------------------------------
# NF_1, d: 300, Iter: 2-760, s/iter: 1.290e-01, ELBO: -6.314e+06
# Cur diff delta = 7613.0478515625
# Cur diff sigma = 8863.9677734375
# Cur diff theta = 16477.015625
# ---------------------------------------
# NF_1, d: 300, Iter: 2-780, s/iter: 1.317e-01, ELBO: -6.199e+06
# Cur diff delta = 6778.814453125
# Cur diff sigma = 7802.3271484375
# Cur diff theta = 14581.1416015625
# ---------------------------------------
# NF_1, d: 300, Iter: 2-800, s/iter: 1.316e-01, ELBO: -6.101e+06
# Cur diff delta = 5981.5615234375
# Cur diff sigma = 6820.9716796875
# Cur diff theta = 12802.533203125
# ---------------------------------------
# NF_1, d: 300, Iter: 2-820, s/iter: 1.290e-01, ELBO: -5.973e+06
# Cur diff delta = 5231.2138671875
# Cur diff sigma = 5922.138671875
# Cur diff theta = 11153.3525390625
# ---------------------------------------
# NF_1, d: 300, Iter: 2-840, s/iter: 1.277e-01, ELBO: -5.878e+06
# Cur diff delta = 4533.7265625
# Cur diff sigma = 5060.9853515625
# Cur diff theta = 9594.7119140625
# ---------------------------------------
# NF_1, d: 300, Iter: 2-860, s/iter: 1.284e-01, ELBO: -5.783e+06
# Cur diff delta = 3894.853271484375
# Cur diff sigma = 4262.169921875
# Cur diff theta = 8157.023193359375
# ---------------------------------------
# NF_1, d: 300, Iter: 2-880, s/iter: 1.279e-01, ELBO: -5.687e+06
# Cur diff delta = 3314.43505859375
# Cur diff sigma = 3544.61572265625
# Cur diff theta = 6859.05078125
# ---------------------------------------
# NF_1, d: 300, Iter: 2-900, s/iter: 1.268e-01, ELBO: -5.594e+06
# Cur diff delta = 2793.0673828125
# Cur diff sigma = 2926.371826171875
# Cur diff theta = 5719.439208984375
# ---------------------------------------
# NF_1, d: 300, Iter: 2-920, s/iter: 1.292e-01, ELBO: -5.488e+06
# Cur diff delta = 2335.8984375
# Cur diff sigma = 2387.315673828125
# Cur diff theta = 4723.214111328125
# ---------------------------------------
# NF_1, d: 300, Iter: 2-940, s/iter: 1.275e-01, ELBO: -5.407e+06
# Cur diff delta = 1939.0205078125
# Cur diff sigma = 1937.61669921875
# Cur diff theta = 3876.63720703125
# ---------------------------------------
# NF_1, d: 300, Iter: 2-960, s/iter: 1.290e-01, ELBO: -5.323e+06
# Cur diff delta = 1597.6624755859375
# Cur diff sigma = 1563.2896728515625
# Cur diff theta = 3160.9521484375
# ---------------------------------------
# NF_1, d: 300, Iter: 2-980, s/iter: 1.283e-01, ELBO: -5.240e+06
# Cur diff delta = 1306.8232421875
# Cur diff sigma = 1244.346923828125
# Cur diff theta = 2551.170166015625
# ---------------------------------------
# NF_1, d: 300, Iter: 2-1000, s/iter: 1.280e-01, ELBO: -5.157e+06
# Cur diff delta = 1062.833251953125
# Cur diff sigma = 980.7318115234375
# Cur diff theta = 2043.5650634765625
# ---------------------------------------
# NF_1, d: 300, Iter: 2-1020, s/iter: 1.277e-01, ELBO: -5.091e+06
# Cur diff delta = 863.7601928710938
# Cur diff sigma = 762.31689453125
# Cur diff theta = 1626.0770874023438
# ---------------------------------------
# NF_1, d: 300, Iter: 2-1040, s/iter: 1.293e-01, ELBO: -5.022e+06
# Cur diff delta = 703.3797607421875
# Cur diff sigma = 594.8460693359375
# Cur diff theta = 1298.225830078125
# ---------------------------------------
# NF_1, d: 300, Iter: 2-1060, s/iter: 1.276e-01, ELBO: -4.966e+06
# Cur diff delta = 580.4949951171875
# Cur diff sigma = 463.3812255859375
# Cur diff theta = 1043.876220703125
# ---------------------------------------
# NF_1, d: 300, Iter: 2-1080, s/iter: 1.281e-01, ELBO: -4.916e+06
# Cur diff delta = 488.18621826171875
# Cur diff sigma = 367.6943054199219
# Cur diff theta = 855.8805236816406
# ---------------------------------------
# NF_1, d: 300, Iter: 2-1100, s/iter: 1.279e-01, ELBO: -4.877e+06
# Cur diff delta = 429.7330017089844
# Cur diff sigma = 295.8042297363281
# Cur diff theta = 725.5372314453125
# ---------------------------------------
# NF_1, d: 300, Iter: 2-1120, s/iter: 1.273e-01, ELBO: -4.828e+06
# Cur diff delta = 390.12408447265625
# Cur diff sigma = 250.04481506347656
# Cur diff theta = 640.1688995361328
# ---------------------------------------
# NF_1, d: 300, Iter: 2-1140, s/iter: 1.272e-01, ELBO: -4.792e+06
# Cur diff delta = 368.966064453125
# Cur diff sigma = 221.65907287597656
# Cur diff theta = 590.6251373291016
# ---------------------------------------
# NF_1, d: 300, Iter: 2-1160, s/iter: 1.272e-01, ELBO: -4.783e+06
# Cur diff delta = 358.98974609375
# Cur diff sigma = 205.2174072265625
# Cur diff theta = 564.2071533203125
# ---------------------------------------
# NF_1, d: 300, Iter: 2-1180, s/iter: 1.311e-01, ELBO: -4.766e+06
# Cur diff delta = 355.2322082519531
# Cur diff sigma = 196.5161895751953
# Cur diff theta = 551.7483978271484
# ---------------------------------------
# NF_1, d: 300, Iter: 2-1200, s/iter: 1.282e-01, ELBO: -4.769e+06
# Cur diff delta = 354.9599304199219
# Cur diff sigma = 192.68154907226562
# Cur diff theta = 547.6414794921875
# ---------------------------------------
# ...
# VB, d: 300, Iter: 3-740, s/iter: 1.402e-01, ELBO: -1.037e+06
# Cur diff delta = 10777.9560546875
# Cur diff sigma = 0.003982724621891975
# Cur diff theta = 10777.960037412122
# ---------------------------------------
# VB, d: 300, Iter: 3-760, s/iter: 1.397e-01, ELBO: -1.031e+06
# Cur diff delta = 10453.6484375
# Cur diff sigma = 0.003982280381023884
# Cur diff theta = 10453.652419780381
# ---------------------------------------
# VB, d: 300, Iter: 3-780, s/iter: 1.390e-01, ELBO: -1.024e+06
# Cur diff delta = 10140.6455078125
# Cur diff sigma = 0.003981377929449081
# Cur diff theta = 10140.64948919043
# ---------------------------------------
# VB, d: 300, Iter: 3-800, s/iter: 1.389e-01, ELBO: -1.018e+06
# Cur diff delta = 9838.54296875
# Cur diff sigma = 0.003982567694038153
# Cur diff theta = 9838.546951317694
# ---------------------------------------
# VB, d: 300, Iter: 3-820, s/iter: 1.410e-01, ELBO: -1.012e+06
# Cur diff delta = 9546.955078125
# Cur diff sigma = 0.00398204755038023
# Cur diff theta = 9546.95906017255
# ---------------------------------------
# VB, d: 300, Iter: 3-840, s/iter: 1.384e-01, ELBO: -1.007e+06
# Cur diff delta = 9265.5146484375
# Cur diff sigma = 0.003981150686740875
# Cur diff theta = 9265.518629588187
# ---------------------------------------
# VB, d: 300, Iter: 3-860, s/iter: 1.369e-01, ELBO: -1.001e+06
# Cur diff delta = 8993.8466796875
# Cur diff sigma = 0.0039812298491597176
# Cur diff theta = 8993.85066091735
# ---------------------------------------
# VB, d: 300, Iter: 3-880, s/iter: 1.396e-01, ELBO: -9.961e+05
# Cur diff delta = 8731.6123046875
# Cur diff sigma = 0.003981360699981451
# Cur diff theta = 8731.6162860482
# ---------------------------------------
# VB, d: 300, Iter: 3-900, s/iter: 1.388e-01, ELBO: -9.911e+05
# Cur diff delta = 8478.4580078125
# Cur diff sigma = 0.00398116884753108
# Cur diff theta = 8478.461988981348
# ---------------------------------------
# VB, d: 300, Iter: 3-920, s/iter: 1.387e-01, ELBO: -9.862e+05
# Cur diff delta = 8234.0654296875
# Cur diff sigma = 0.003980892710387707
# Cur diff theta = 8234.06941058021
# ---------------------------------------
# VB, d: 300, Iter: 3-940, s/iter: 1.388e-01, ELBO: -9.815e+05
# Cur diff delta = 7998.11328125
# Cur diff sigma = 0.003980632871389389
# Cur diff theta = 7998.117261882871
# ---------------------------------------
# VB, d: 300, Iter: 3-960, s/iter: 1.378e-01, ELBO: -9.769e+05
# Cur diff delta = 7770.2958984375
# Cur diff sigma = 0.003980165813118219
# Cur diff theta = 7770.299878603313
# ---------------------------------------
# VB, d: 300, Iter: 3-980, s/iter: 1.368e-01, ELBO: -9.725e+05
# Cur diff delta = 7550.314453125
# Cur diff sigma = 0.003979952074587345
# Cur diff theta = 7550.318433077075
# ---------------------------------------
# VB, d: 300, Iter: 3-1000, s/iter: 1.377e-01, ELBO: -9.683e+05
# Cur diff delta = 7337.8857421875
# Cur diff sigma = 0.003980184905230999
# Cur diff theta = 7337.889722372405
# ---------------------------------------
# VB, d: 300, Iter: 3-1020, s/iter: 1.403e-01, ELBO: -9.641e+05
# Cur diff delta = 7132.73291015625
# Cur diff sigma = 0.0039802491664886475
# Cur diff theta = 7132.7368904054165
# ---------------------------------------
# VB, d: 300, Iter: 3-1040, s/iter: 1.388e-01, ELBO: -9.602e+05
# Cur diff delta = 6934.587890625
# Cur diff sigma = 0.003979847300797701
# Cur diff theta = 6934.591870472301
# ---------------------------------------
# VB, d: 300, Iter: 3-1060, s/iter: 1.380e-01, ELBO: -9.563e+05
# Cur diff delta = 6743.19677734375
# Cur diff sigma = 0.003979800269007683
# Cur diff theta = 6743.200757144019
# ---------------------------------------
# VB, d: 300, Iter: 3-1080, s/iter: 1.395e-01, ELBO: -9.527e+05
# Cur diff delta = 6558.30810546875
# Cur diff sigma = 0.003979276865720749
# Cur diff theta = 6558.312084745616
# ---------------------------------------
# VB, d: 300, Iter: 3-1100, s/iter: 1.376e-01, ELBO: -9.491e+05
# Cur diff delta = 6379.68359375
# Cur diff sigma = 0.003979589324444532
# Cur diff theta = 6379.687573339324
# ---------------------------------------
# VB, d: 300, Iter: 3-1120, s/iter: 1.380e-01, ELBO: -9.456e+05
# Cur diff delta = 6207.0966796875
# Cur diff sigma = 0.003979560453444719
# Cur diff theta = 6207.100659247953
# ---------------------------------------
# VB, d: 300, Iter: 3-1140, s/iter: 1.378e-01, ELBO: -9.423e+05
# Cur diff delta = 6040.31884765625
# Cur diff sigma = 0.003979236353188753
# Cur diff theta = 6040.322826892603
# ---------------------------------------
# VB, d: 300, Iter: 3-1160, s/iter: 1.386e-01, ELBO: -9.391e+05
# Cur diff delta = 5879.1416015625
# Cur diff sigma = 0.003979411907494068
# Cur diff theta = 5879.1455809744075
# ---------------------------------------
# VB, d: 300, Iter: 3-1180, s/iter: 1.382e-01, ELBO: -9.359e+05
# Cur diff delta = 5723.3623046875
# Cur diff sigma = 0.003979171626269817
# Cur diff theta = 5723.366283859126
# ---------------------------------------
# VB, d: 300, Iter: 3-1200, s/iter: 1.378e-01, ELBO: -9.329e+05
# Cur diff delta = 5572.77392578125
# Cur diff sigma = 0.003979220520704985
# Cur diff theta = 5572.777905001771
# ---------------------------------------
# VB, d: 300, Iter: 3-1220, s/iter: 1.383e-01, ELBO: -9.300e+05
# Cur diff delta = 5427.1904296875
# Cur diff sigma = 0.003978915512561798
# Cur diff theta = 5427.194408603013
# ---------------------------------------
# VB, d: 300, Iter: 3-1240, s/iter: 1.385e-01, ELBO: -9.272e+05
# Cur diff delta = 5286.42578125
# Cur diff sigma = 0.003978780936449766
# Cur diff theta = 5286.429760030936
# ---------------------------------------
# VB, d: 300, Iter: 3-1260, s/iter: 1.381e-01, ELBO: -9.245e+05
# Cur diff delta = 5150.30859375
# Cur diff sigma = 0.003979061264544725
# Cur diff theta = 5150.3125728112645
# ---------------------------------------
# VB, d: 300, Iter: 3-1280, s/iter: 1.377e-01, ELBO: -9.218e+05
# Cur diff delta = 5018.6640625
# Cur diff sigma = 0.003978846129029989
# Cur diff theta = 5018.668041346129
# ---------------------------------------
# VB, d: 300, Iter: 3-1300, s/iter: 1.358e-01, ELBO: -9.193e+05
# Cur diff delta = 4891.328125
# Cur diff sigma = 0.003978938329964876
# Cur diff theta = 4891.33210393833
# ---------------------------------------
# VB, d: 300, Iter: 3-1320, s/iter: 1.361e-01, ELBO: -9.168e+05
# Cur diff delta = 4768.14697265625
# Cur diff sigma = 0.003979097586125135
# Cur diff theta = 4768.150951753836
# ---------------------------------------
# VB, d: 300, Iter: 3-1340, s/iter: 1.339e-01, ELBO: -9.144e+05
# Cur diff delta = 4648.96240234375
# Cur diff sigma = 0.003978713881224394
# Cur diff theta = 4648.966381057631
# ---------------------------------------
# VB, d: 300, Iter: 3-1360, s/iter: 1.331e-01, ELBO: -9.121e+05
# Cur diff delta = 4533.63427734375
# Cur diff sigma = 0.003978911321610212
# Cur diff theta = 4533.638256255072
# ---------------------------------------
# VB, d: 300, Iter: 3-1380, s/iter: 1.353e-01, ELBO: -9.099e+05
# Cur diff delta = 4422.0224609375
# Cur diff sigma = 0.003978599328547716
# Cur diff theta = 4422.026439536829
# ---------------------------------------
# VB, d: 300, Iter: 3-1400, s/iter: 1.346e-01, ELBO: -9.077e+05
# Cur diff delta = 4313.9892578125
# Cur diff sigma = 0.003978573717176914
# Cur diff theta = 4313.993236386217
# ---------------------------------------
# VB, d: 300, Iter: 3-1420, s/iter: 1.348e-01, ELBO: -9.056e+05
# Cur diff delta = 4209.40966796875
# Cur diff sigma = 0.003978821448981762
# Cur diff theta = 4209.413646790199
# ---------------------------------------
# VB, d: 300, Iter: 3-1440, s/iter: 1.345e-01, ELBO: -9.036e+05
# Cur diff delta = 4108.1513671875
# Cur diff sigma = 0.003978762309998274
# Cur diff theta = 4108.15534594981
# ---------------------------------------
# VB, d: 300, Iter: 3-1460, s/iter: 1.355e-01, ELBO: -9.016e+05
# Cur diff delta = 4010.09912109375
# Cur diff sigma = 0.003978586755692959
# Cur diff theta = 4010.1030996805057
# ---------------------------------------
# VB, d: 300, Iter: 3-1480, s/iter: 1.331e-01, ELBO: -8.997e+05
# Cur diff delta = 3915.135009765625
# Cur diff sigma = 0.0039786361157894135
# Cur diff theta = 3915.138988401741
# ---------------------------------------
# VB, d: 300, Iter: 3-1500, s/iter: 1.332e-01, ELBO: -8.979e+05
# Cur diff delta = 3823.152099609375
# Cur diff sigma = 0.003978895489126444
# Cur diff theta = 3823.156078504864
# ---------------------------------------
# VB, d: 300, Iter: 3-1520, s/iter: 1.349e-01, ELBO: -8.961e+05
# Cur diff delta = 3734.039306640625
# Cur diff sigma = 0.003978889435529709
# Cur diff theta = 3734.0432855300605
# ---------------------------------------
# VB, d: 300, Iter: 3-1540, s/iter: 1.334e-01, ELBO: -8.943e+05
# Cur diff delta = 3647.69921875
# Cur diff sigma = 0.003978785127401352
# Cur diff theta = 3647.7031975351274
# ---------------------------------------
# VB, d: 300, Iter: 3-1560, s/iter: 1.332e-01, ELBO: -8.927e+05
# Cur diff delta = 3564.027587890625
# Cur diff sigma = 0.003978808876127005
# Cur diff theta = 3564.031566699501
# ---------------------------------------
# VB, d: 300, Iter: 3-1580, s/iter: 1.338e-01, ELBO: -8.910e+05
# Cur diff delta = 3482.93310546875
# Cur diff sigma = 0.003978733904659748
# Cur diff theta = 3482.9370842026547
# ---------------------------------------
# VB, d: 300, Iter: 3-1600, s/iter: 1.327e-01, ELBO: -8.895e+05
# Cur diff delta = 3404.32421875
# Cur diff sigma = 0.003978682681918144
# Cur diff theta = 3404.328197432682
# ---------------------------------------
# VB, d: 300, Iter: 3-1620, s/iter: 1.353e-01, ELBO: -8.880e+05
# Cur diff delta = 3328.111572265625
# Cur diff sigma = 0.0039787814021110535
# Cur diff theta = 3328.115551047027
# ---------------------------------------
# VB, d: 300, Iter: 3-1640, s/iter: 1.384e-01, ELBO: -8.864e+05
# Cur diff delta = 3254.214111328125
# Cur diff sigma = 0.0039787450805306435
# Cur diff theta = 3254.2180900732055
# ---------------------------------------
# VB, d: 300, Iter: 3-1660, s/iter: 1.361e-01, ELBO: -8.850e+05
# Cur diff delta = 3182.545654296875
# Cur diff sigma = 0.003978732507675886
# Cur diff theta = 3182.5496330293827
# ---------------------------------------
# VB, d: 300, Iter: 3-1680, s/iter: 1.353e-01, ELBO: -8.836e+05
# Cur diff delta = 3113.03125
# Cur diff sigma = 0.003978619817644358
# Cur diff theta = 3113.0352286198176
# ---------------------------------------
# VB, d: 300, Iter: 3-1700, s/iter: 1.345e-01, ELBO: -8.823e+05
# Cur diff delta = 3045.596923828125
# Cur diff sigma = 0.003978664055466652
# Cur diff theta = 3045.6009024921805
# ---------------------------------------
# VB, d: 300, Iter: 3-1720, s/iter: 1.338e-01, ELBO: -8.809e+05
# Cur diff delta = 2980.16845703125
# Cur diff sigma = 0.003978902008384466
# Cur diff theta = 2980.1724359332584
# ---------------------------------------
# VB, d: 300, Iter: 3-1740, s/iter: 1.319e-01, ELBO: -8.797e+05
# Cur diff delta = 2916.675048828125
# Cur diff sigma = 0.003978818189352751
# Cur diff theta = 2916.6790276463144
# ---------------------------------------
# VB, d: 300, Iter: 3-1760, s/iter: 1.327e-01, ELBO: -8.784e+05
# Cur diff delta = 2855.052734375
# Cur diff sigma = 0.003978764172643423
# Cur diff theta = 2855.0567131391726
# ---------------------------------------
# VB, d: 300, Iter: 3-1780, s/iter: 1.337e-01, ELBO: -8.772e+05
# Cur diff delta = 2795.235595703125
# Cur diff sigma = 0.003979003056883812
# Cur diff theta = 2795.239574706182
# ---------------------------------------
# VB, d: 300, Iter: 3-1800, s/iter: 1.339e-01, ELBO: -8.761e+05
# Cur diff delta = 2737.161865234375
# Cur diff sigma = 0.003978873137384653
# Cur diff theta = 2737.1658441075124
# ---------------------------------------
# VB, d: 300, Iter: 3-1820, s/iter: 1.343e-01, ELBO: -8.749e+05
# Cur diff delta = 2680.7724609375
# Cur diff sigma = 0.0039787283167243
# Cur diff theta = 2680.7764396658167
# ---------------------------------------
# VB, d: 300, Iter: 3-1840, s/iter: 1.343e-01, ELBO: -8.738e+05
# Cur diff delta = 2626.012939453125
# Cur diff sigma = 0.0039789327420294285
# Cur diff theta = 2626.016918385867
# ---------------------------------------
# VB, d: 300, Iter: 3-1860, s/iter: 1.324e-01, ELBO: -8.727e+05
# Cur diff delta = 2572.82275390625
# Cur diff sigma = 0.003978963475674391
# Cur diff theta = 2572.8267328697257
# ---------------------------------------
# VB, d: 300, Iter: 3-1880, s/iter: 1.317e-01, ELBO: -8.717e+05
# Cur diff delta = 2521.152587890625
# Cur diff sigma = 0.003978965803980827
# Cur diff theta = 2521.156566856429
# ---------------------------------------
# VB, d: 300, Iter: 3-1900, s/iter: 1.331e-01, ELBO: -8.707e+05
# Cur diff delta = 2470.950927734375
# Cur diff sigma = 0.003978861961513758
# Cur diff theta = 2470.9549065963365
# ---------------------------------------
# VB, d: 300, Iter: 3-1920, s/iter: 1.324e-01, ELBO: -8.697e+05
# Cur diff delta = 2422.1650390625
# Cur diff sigma = 0.00397883728146553
# Cur diff theta = 2422.1690178997815
# ---------------------------------------
# VB, d: 300, Iter: 3-1940, s/iter: 1.322e-01, ELBO: -8.688e+05
# Cur diff delta = 2374.751708984375
# Cur diff sigma = 0.00397892901673913
# Cur diff theta = 2374.7556879133917
# ---------------------------------------
# VB, d: 300, Iter: 3-1960, s/iter: 1.325e-01, ELBO: -8.678e+05
# Cur diff delta = 2328.66552734375
# Cur diff sigma = 0.003978883381932974
# Cur diff theta = 2328.669506227132
# ---------------------------------------
# VB, d: 300, Iter: 3-1980, s/iter: 1.323e-01, ELBO: -8.669e+05
# Cur diff delta = 2283.860107421875
# Cur diff sigma = 0.00397886848077178
# Cur diff theta = 2283.8640862903558
# ---------------------------------------
# VB, d: 300, Iter: 3-2000, s/iter: 1.321e-01, ELBO: -8.660e+05
# Cur diff delta = 2240.29296875
# Cur diff sigma = 0.003979062661528587
# Cur diff theta = 2240.2969478126615
# ---------------------------------------
# Model HVAE_1, test = 0, result delta diff = 296.2413024902344
# Model HVAE_1, test = 0, result sigma diff = 0.4965432286262512
# Model HVAE_1, test = 0, result theta diff = 296.73785400390625
# Model HVAE_1, test = 1, result delta diff = 356.5992736816406
# Model HVAE_1, test = 1, result sigma diff = 0.5063630938529968
# Model HVAE_1, test = 1, result theta diff = 357.10565185546875
# Model HVAE_1, test = 2, result delta diff = 339.4721374511719
# Model HVAE_1, test = 2, result sigma diff = 0.4985133409500122
# Model HVAE_1, test = 2, result theta diff = 339.97064208984375
# Model HVAE_2, test = 0, result delta diff = 296.9627685546875
# Model HVAE_2, test = 0, result sigma diff = 0.4473910927772522
# Model HVAE_2, test = 0, result theta diff = 297.41015625
# Model HVAE_2, test = 1, result delta diff = 356.7081298828125
# Model HVAE_2, test = 1, result sigma diff = 0.4567033350467682
# Model HVAE_2, test = 1, result theta diff = 357.1648254394531
# Model HVAE_2, test = 2, result delta diff = 340.15679931640625
# Model HVAE_2, test = 2, result sigma diff = 0.44657421112060547
# Model HVAE_2, test = 2, result theta diff = 340.6033630371094
# Model NF_1, test = 0, result delta diff = nan
# Model NF_1, test = 0, result sigma diff = nan
# Model NF_1, test = 0, result theta diff = nan
# Model NF_1, test = 1, result delta diff = 356.4604187011719
# Model NF_1, test = 1, result sigma diff = 188.6686553955078
# Model NF_1, test = 1, result theta diff = 545.1290893554688
# Model NF_1, test = 2, result delta diff = nan
# Model NF_1, test = 2, result sigma diff = nan
# Model NF_1, test = 2, result theta diff = nan
# Model NF_2, test = 0, result delta diff = 296.52960205078125
# Model NF_2, test = 0, result sigma diff = 188.46731567382812
# Model NF_2, test = 0, result theta diff = 484.9969177246094
# Model NF_2, test = 1, result delta diff = 357.256591796875
# Model NF_2, test = 1, result sigma diff = 189.06533813476562
# Model NF_2, test = 1, result theta diff = 546.3218994140625
# Model NF_2, test = 2, result delta diff = 340.48101806640625
# Model NF_2, test = 2, result sigma diff = 189.0795440673828
# Model NF_2, test = 2, result theta diff = 529.560546875
# Model VB, test = 0, result delta diff = 2118.43603515625
# Model VB, test = 0, result sigma diff = 0.0045000119134783745
# Model VB, test = 0, result theta diff = 2118.4404296875
# Model VB, test = 1, result delta diff = 2089.39892578125
# Model VB, test = 1, result sigma diff = 0.00443264190107584
# Model VB, test = 1, result theta diff = 2089.4033203125
# Model VB, test = 2, result delta diff = 2240.29248046875
# Model VB, test = 2, result sigma diff = 0.0039790621958673
# Model VB, test = 2, result theta diff = 2240.29638671875

# %%
model_names = ['HVAE_1', 'HVAE_2', 'NF_1', 'NF_2', 'VB']
diff_delta_results = {}
diff_sigma_results = {}
diff_results = {}
for name in model_names:
    diff_delta_tests = np.zeros(params['n_tests'])
    diff_sigma_tests = np.zeros(params['n_tests'])
    diff_tests = np.zeros(params['n_tests'])
    for i in range(params['n_tests']):
        file_name = name + '_train_' + str(i) + '.p'
        diff_path = os.path.join('save', str(params['dims'][0]), file_name)
        with open(diff_path, 'rb') as f:
            data = pickle.load(f)
            elbo = data['elbo']
            diff_delta = data['diff_delta']
            diff_sigma = data['diff_sigma']
            diff = diff_delta + diff_sigma
            diff_delta_is_not_nan = diff_delta[~np.isnan(diff_delta)]
            diff_sigma_is_not_nan = diff_sigma[~np.isnan(diff_sigma)]
            diff_is_not_nan = diff[~np.isnan(diff)]
            diff_delta_tests[i] = diff_delta_is_not_nan[-1]
            diff_sigma_tests[i] = diff_sigma_is_not_nan[-1]
            diff_tests[i] = diff_is_not_nan[-1]
    diff_delta_results[name] = diff_delta_tests
    diff_sigma_results[name] = diff_sigma_tests
    diff_results[name] = diff_tests
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, diff delta = {diff_delta_tests}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, diff sigma = {diff_sigma_tests}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, diff = {diff_tests}")
# Out:
# Model = HVAE_1, dimensionality = 300, diff delta = [296.24130249 356.59918213 339.47210693]
# Model = HVAE_1, dimensionality = 300, diff sigma = [0.49654326 0.50636309 0.49851337]
# Model = HVAE_1, dimensionality = 300, diff = [296.737854   357.1055603  339.97061157]
# Model = HVAE_2, dimensionality = 300, diff delta = [296.96273804 356.70812988 340.1567688 ]
# Model = HVAE_2, dimensionality = 300, diff sigma = [0.44739103 0.45670336 0.44657421]
# Model = HVAE_2, dimensionality = 300, diff = [297.41012573 357.16482544 340.60333252]
# Model = NF_1, dimensionality = 300, diff delta = [309.61495972 356.4604187  339.98864746]
# Model = NF_1, dimensionality = 300, diff sigma = [289.18704224 188.66868591 190.65641785]
# Model = NF_1, dimensionality = 300, diff = [598.80200195 545.12908936 530.64508057]
# Model = NF_2, dimensionality = 300, diff delta = [296.52960205 357.2565918  340.48098755]
# Model = NF_2, dimensionality = 300, diff sigma = [188.46731567 189.06533813 189.07955933]
# Model = NF_2, dimensionality = 300, diff = [484.99691772 546.32189941 529.56054688]
# Model = VB, dimensionality = 300, diff delta = [2118.4362793  2089.39892578 2240.29296875]
# Model = VB, dimensionality = 300, diff sigma = [0.00450001 0.00443264 0.00397906]
# Model = VB, dimensionality = 300, diff = [2118.44067383 2089.40332031 2240.296875  ]

# %%
for name in model_names:
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, mean diff delta = {diff_delta_results[name].mean()}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, mean diff sigma = {diff_sigma_results[name].mean()}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, mean diff = {diff_results[name].mean()}")
# Out:
# Model = HVAE_1, dimensionality = 300, mean diff delta = 330.77086385091144
# Model = HVAE_1, dimensionality = 300, mean diff sigma = 0.5004732410113016
# Model = HVAE_1, dimensionality = 300, mean diff = 331.27134195963544
# Model = HVAE_2, dimensionality = 300, mean diff delta = 331.27587890625
# Model = HVAE_2, dimensionality = 300, mean diff sigma = 0.45022286971410114
# Model = HVAE_2, dimensionality = 300, mean diff = 331.72609456380206
# Model = NF_1, dimensionality = 300, mean diff delta = 335.35467529296875
# Model = NF_1, dimensionality = 300, mean diff sigma = 222.8373819986979
# Model = NF_1, dimensionality = 300, mean diff = 558.1920572916666
# Model = NF_2, dimensionality = 300, mean diff delta = 331.4223937988281
# Model = NF_2, dimensionality = 300, mean diff sigma = 188.87073771158853
# Model = NF_2, dimensionality = 300, mean diff = 520.2931213378906
# Model = VB, dimensionality = 300, mean diff delta = 2149.3760579427085
# Model = VB, dimensionality = 300, mean diff sigma = 0.004303906578570604
# Model = VB, dimensionality = 300, mean diff = 2149.3802897135415

# %%
params = {

    # PROBLEM SPECIFICATION
    #'dims': [1, 2, 3, 5, 11, 25, 51, 101, 201, 301], # Dimensions to test
    'dims': [300],
    'n_data': 10000,                                 # Number of data points

    # TEST HYPERPARAMETERS
    'n_tests': 3,      # Number of experiments to run

    # GLOBAL OPTIMIZATION PARAMETERS
    'n_iter': 4000,    # Number of optimization iterations
    'n_batch': 10,      # Number of points for ELBO estimate
    'rms_eta': 0.001,   # Stepsize for RMSProp
    'save_every': 20,   # Save parameter information every so often
    'print_every': 20, # Print less often than save

    # HVAE HYPERPARAMETERS
    'HVAE_K_1': 1,    # Number of leapfrog/cooling steps for HVAE flow 1
    'HVAE_K_2': 10,   # Number of leapfrog/cooling steps for HVAE flow 2
    'max_eps': 0.5,   # Maximum leapfrog step size per dimension 

    # NF HYPERPARAMETERS
    'NF_K_1': 1,    # Number of flow steps for NF flow 1
    'NF_K_2': 30,   # Number of flow steps for NF flow 2
    
}

# %%
def run_test(d, params, 
             batch_size=256,
             clip_value=None,
             dtype=torch.float32, 
             device=torch.device("cpu")):
    """ 
    Run the gaussian test with dimension d 
    """

    ######### Problem Specification

    # Data generation parameters
    prior_mu_z = torch.zeros(d, dtype=dtype)    # Prior mean
    prior_sigma_z = torch.eye(d, dtype=dtype)   # Prior covariance matrix

    # True model parameters
    num_range = torch.arange(-(d-1)/2, (d+1)/2, dtype=dtype)

    t_delta =  num_range / 5 

    print(f"true delta = {t_delta.numpy()}")

    if d == 1:
        t_sigma = torch.ones(1, dtype=dtype)
    else: 
        # Allow sigma to range from 0.1 to 1
        t_sigma = 36/(10*(d-1)**2) * num_range**2 + 0.1 
    print(f"true sigma = {t_sigma.numpy()}")

    ######### Variable Initialization

    # Initial model parameters - same across all methods
    init_delta = prior_mu_z.clone().to(device)
    init_log_sigma = 3 * torch.ones(d).to(device)

    # Initial HVAE variational parameters
    init_T = torch.tensor(5., dtype=dtype, device=device)
    init_eps = 0.005 * torch.ones(d, dtype=dtype)
    max_eps = params['max_eps'] * torch.ones(d, dtype=dtype)
    init_logit_eps = torch.log(init_eps/(max_eps - init_eps)).to(device)
    init_log_T_0 = torch.log(init_T - 1)

    # Initial NF variational parameters
    init_u_pre_reparam = torch.tensor(scipy.stats.truncnorm.rvs(-2, 2, 
                                                                scale=0.1, 
                                                                size=d),
                                      dtype=dtype, device=device)
    init_w = torch.tensor(scipy.stats.truncnorm.rvs(-2, 2, scale=0.1, size=d),
                          dtype=dtype, device=device)
    init_b = torch.tensor(0.1, dtype=dtype, device=device)

    # Initial VAE parameters
    init_mu_z = prior_mu_z.clone()
    init_log_sigma_z = torch.ones(d, dtype=dtype)

    ######### Set up models
    init_params = [[init_delta, init_log_sigma, init_logit_eps, init_log_T_0],
                   [init_delta, init_log_sigma, init_logit_eps, init_log_T_0],
                   [init_delta, init_log_sigma, init_u_pre_reparam, init_w, init_b],
                   [init_delta, init_log_sigma, init_u_pre_reparam, init_w, init_b],
                   [init_delta, init_log_sigma, init_mu_z, init_log_sigma_z]]
    
    VB_model = VB(params,
        ['delta', 'log_sigma', 'mu_z', 'log_sigma_z'], 
        init_params[4], 'VB', d)

    #model_list = [HVAE_model_1, HVAE_model_2, NF_model_1]
    #model_list = [HVAE_model_1, NF_model_1]
    model_list = [VB_model]

    print("Models were initialized!")
    
    ######### Generate Training Data & Save - One for each test

    train_data_list = []

    for i in range(params['n_tests']):
        z = MultivariateNormal(prior_mu_z, prior_sigma_z).sample()
        x = MultivariateNormal(z + t_delta, 
                               torch.diag(t_sigma**2)).sample([params['n_data']])
        x = x.to(device)
        train_data_list.append(x)

    # Folder should have already been created in the initializations
    data_path = os.path.join('save', str(d), 'train_data.p')
    pickle.dump(train_data_list, open(data_path, 'wb')) 

    # Store the final parameter values for all test runs in this dictionary
    final_params = {}

    for i in range(len(model_list)):
        final_values = []
        m = model_list[i]
        model_init_params = init_params[i]

        for j in range(params['n_tests']):
            print("------------------------------------------------------")
            print(f"Test = {j}")
            print("------------------------------------------------------")
            m._reinitialize(model_init_params)
            gaussian_data = gaussian_dataset(train_data_list[j])
            train_dataloader = DataLoader(gaussian_data, batch_size=batch_size,
                                          shuffle=False, num_workers=0)
            (delta, sigma) = m.train(train_dataloader, j, 
                                     t_delta, t_sigma,
                                     clip_value)
            final_values.append((delta, sigma))

        final_params[m.model_name] = final_values.copy()

    ######### Test models using difference between parameters

    param_diffs = {}

    for m in model_list:
        
        diffs = []

        for i in range(params['n_tests']):
            delta = final_params[m.model_name][i][0]
            sigma = final_params[m.model_name][i][1]

            delta_diff = np.sum((delta - t_delta.numpy())**2)
            sigma_diff = np.sum((sigma - t_sigma.numpy())**2)
            theta_diff = delta_diff + sigma_diff
            print(f"Model {m.model_name}, test = {i}, result delta diff = {delta_diff}")
            print(f"Model {m.model_name}, test = {i}, result sigma diff = {sigma_diff}")
            print(f"Model {m.model_name}, test = {i}, result theta diff = {theta_diff}")

            diffs.append((delta_diff, sigma_diff, theta_diff))

        param_diffs[m.model_name] = diffs.copy()

    # Save parameter differences in a pickle file
    diff_path = os.path.join('save', str(d), 'all_diffs.p')
    pickle.dump(param_diffs, open(diff_path, 'wb'))

# %%
device = torch.device("cuda")
dtype = torch.float32
clip_value = None
batch_size = 256

# %%
dims = params['dims']
seed = 12345
np.random.seed(seed)
torch.manual_seed(seed)
for d in dims:
    print('**** Running test for d={0:d} ****'.format(d))
    run_test(d, params, batch_size, clip_value, dtype, device)
# Out:
# **** Running test for d=300 ****
# true delta = [-29.9 -29.7 -29.5 -29.3 -29.1 -28.9 -28.7 -28.5 -28.3 -28.1 -27.9 -27.7
#  -27.5 -27.3 -27.1 -26.9 -26.7 -26.5 -26.3 -26.1 -25.9 -25.7 -25.5 -25.3
#  -25.1 -24.9 -24.7 -24.5 -24.3 -24.1 -23.9 -23.7 -23.5 -23.3 -23.1 -22.9
#  -22.7 -22.5 -22.3 -22.1 -21.9 -21.7 -21.5 -21.3 -21.1 -20.9 -20.7 -20.5
#  -20.3 -20.1 -19.9 -19.7 -19.5 -19.3 -19.1 -18.9 -18.7 -18.5 -18.3 -18.1
#  -17.9 -17.7 -17.5 -17.3 -17.1 -16.9 -16.7 -16.5 -16.3 -16.1 -15.9 -15.7
#  -15.5 -15.3 -15.1 -14.9 -14.7 -14.5 -14.3 -14.1 -13.9 -13.7 -13.5 -13.3
#  -13.1 -12.9 -12.7 -12.5 -12.3 -12.1 -11.9 -11.7 -11.5 -11.3 -11.1 -10.9
#  -10.7 -10.5 -10.3 -10.1  -9.9  -9.7  -9.5  -9.3  -9.1  -8.9  -8.7  -8.5
#   -8.3  -8.1  -7.9  -7.7  -7.5  -7.3  -7.1  -6.9  -6.7  -6.5  -6.3  -6.1
#   -5.9  -5.7  -5.5  -5.3  -5.1  -4.9  -4.7  -4.5  -4.3  -4.1  -3.9  -3.7
#   -3.5  -3.3  -3.1  -2.9  -2.7  -2.5  -2.3  -2.1  -1.9  -1.7  -1.5  -1.3
#   -1.1  -0.9  -0.7  -0.5  -0.3  -0.1   0.1   0.3   0.5   0.7   0.9   1.1
#    1.3   1.5   1.7   1.9   2.1   2.3   2.5   2.7   2.9   3.1   3.3   3.5
#    3.7   3.9   4.1   4.3   4.5   4.7   4.9   5.1   5.3   5.5   5.7   5.9
#    6.1   6.3   6.5   6.7   6.9   7.1   7.3   7.5   7.7   7.9   8.1   8.3
#    8.5   8.7   8.9   9.1   9.3   9.5   9.7   9.9  10.1  10.3  10.5  10.7
#   10.9  11.1  11.3  11.5  11.7  11.9  12.1  12.3  12.5  12.7  12.9  13.1
#   13.3  13.5  13.7  13.9  14.1  14.3  14.5  14.7  14.9  15.1  15.3  15.5
#   15.7  15.9  16.1  16.3  16.5  16.7  16.9  17.1  17.3  17.5  17.7  17.9
#   18.1  18.3  18.5  18.7  18.9  19.1  19.3  19.5  19.7  19.9  20.1  20.3
#   20.5  20.7  20.9  21.1  21.3  21.5  21.7  21.9  22.1  22.3  22.5  22.7
#   22.9  23.1  23.3  23.5  23.7  23.9  24.1  24.3  24.5  24.7  24.9  25.1
#   25.3  25.5  25.7  25.9  26.1  26.3  26.5  26.7  26.9  27.1  27.3  27.5
#   27.7  27.9  28.1  28.3  28.5  28.7  28.9  29.1  29.3  29.5  29.7  29.9]
# true sigma = [1.         0.98800015 0.97608083 0.96424204 0.9524838  0.94080603
#  0.9292089  0.9176922  0.9062561  0.8949005  0.88362545 0.872431
#  0.861317   0.85028356 0.8393307  0.8284583  0.8176665  0.8069552
#  0.79632443 0.78577423 0.77530456 0.7649154  0.7546068  0.7443787
#  0.7342312  0.7241642  0.7141777  0.7042718  0.6944464  0.6847015
#  0.6750372  0.66545343 0.6559502  0.64652747 0.6371853  0.62792367
#  0.6187425  0.60964197 0.60062194 0.59168243 0.58282346 0.57404506
#  0.56534714 0.5567298  0.548193   0.5397367  0.5313609  0.52306575
#  0.5148511  0.5067169  0.4986633  0.49069026 0.4827977  0.47498572
#  0.46725428 0.45960334 0.45203295 0.44454312 0.4371338  0.429805
#  0.4225568  0.4153891  0.40830192 0.40129527 0.39436918 0.38752362
#  0.38075858 0.3740741  0.36747015 0.36094674 0.35450384 0.34814152
#  0.3418597  0.33565843 0.3295377  0.3234975  0.31753784 0.3116587
#  0.3058601  0.30014205 0.29450452 0.28894755 0.2834711  0.2780752
#  0.27275982 0.26752496 0.26237068 0.2572969  0.25230366 0.24739096
#  0.2425588  0.23780718 0.23313609 0.22854555 0.22403553 0.21960604
#  0.21525711 0.2109887  0.20680082 0.20269349 0.19866669 0.19472042
#  0.1908547  0.1870695  0.18336484 0.17974073 0.17619714 0.17273408
#  0.16935158 0.1660496  0.16282815 0.15968725 0.15662688 0.15364705
#  0.15074775 0.147929   0.14519078 0.14253308 0.13995594 0.13745931
#  0.13504323 0.13270769 0.13045268 0.12827821 0.12618427 0.12417087
#  0.12223801 0.12038568 0.11861388 0.11692263 0.11531191 0.11378173
#  0.11233208 0.11096296 0.10967439 0.10846635 0.10733885 0.10629188
#  0.10532545 0.10443955 0.10363419 0.10290936 0.10226507 0.10170133
#  0.10121811 0.10081543 0.10049328 0.10025167 0.10009061 0.10001007
#  0.10001007 0.10009061 0.10025167 0.10049328 0.10081543 0.10121811
#  0.10170133 0.10226507 0.10290936 0.10363419 0.10443955 0.10532545
#  0.10629188 0.10733885 0.10846635 0.10967439 0.11096296 0.11233208
#  0.11378173 0.11531191 0.11692263 0.11861388 0.12038568 0.12223801
#  0.12417087 0.12618427 0.12827821 0.13045268 0.13270769 0.13504323
#  0.13745931 0.13995594 0.14253308 0.14519078 0.147929   0.15074775
#  0.15364705 0.15662688 0.15968725 0.16282815 0.1660496  0.16935158
#  0.17273408 0.17619714 0.17974073 0.18336484 0.1870695  0.1908547
#  0.19472042 0.19866669 0.20269349 0.20680082 0.2109887  0.21525711
#  0.21960604 0.22403553 0.22854555 0.23313609 0.23780718 0.2425588
#  0.24739096 0.25230366 0.2572969  0.26237068 0.26752496 0.27275982
#  0.2780752  0.2834711  0.28894755 0.29450452 0.30014205 0.3058601
#  0.3116587  0.31753784 0.3234975  0.3295377  0.33565843 0.3418597
#  0.34814152 0.35450384 0.36094674 0.36747015 0.3740741  0.38075858
#  0.38752362 0.39436918 0.40129527 0.40830192 0.4153891  0.4225568
#  0.429805   0.4371338  0.44454312 0.45203295 0.45960334 0.46725428
#  0.47498572 0.4827977  0.49069026 0.4986633  0.5067169  0.5148511
#  0.52306575 0.5313609  0.5397367  0.548193   0.5567298  0.56534714
#  0.57404506 0.58282346 0.59168243 0.60062194 0.60964197 0.6187425
#  0.62792367 0.6371853  0.64652747 0.6559502  0.66545343 0.6750372
#  0.6847015  0.6944464  0.7042718  0.7141777  0.7241642  0.7342312
#  0.7443787  0.7546068  0.7649154  0.77530456 0.78577423 0.79632443
#  0.8069552  0.8176665  0.8284583  0.8393307  0.85028356 0.861317
#  0.872431   0.88362545 0.8949005  0.9062561  0.9176922  0.9292089
#  0.94080603 0.9524838  0.96424204 0.97608083 0.98800015 1.        ]
# Models were initialized!
# ------------------------------------------------------
# Test = 0
# ------------------------------------------------------
# Init diff delta = 89999.0078125
# Init diff sigma = 116254.2890625
# Init diff theta = 206253.296875
# VB, d: 300, Iter: 1-20, s/iter: 1.184e-01, ELBO: -1.190e+07
# Cur diff delta = 82082.34375
# Cur diff sigma = 82490.421875
# Cur diff theta = 164572.765625
# ---------------------------------------
# VB, d: 300, Iter: 1-40, s/iter: 1.154e-01, ELBO: -1.102e+07
# Cur diff delta = 75489.0625
# Cur diff sigma = 65737.0859375
# Cur diff theta = 141226.1484375
# ---------------------------------------
# VB, d: 300, Iter: 1-60, s/iter: 1.167e-01, ELBO: -1.007e+07
# Cur diff delta = 69257.5625
# Cur diff sigma = 54402.53125
# Cur diff theta = 123660.09375
# ---------------------------------------
# VB, d: 300, Iter: 1-80, s/iter: 1.137e-01, ELBO: -8.972e+06
# Cur diff delta = 63438.7109375
# Cur diff sigma = 44956.59375
# Cur diff theta = 108395.3046875
# ---------------------------------------
# VB, d: 300, Iter: 1-100, s/iter: 1.155e-01, ELBO: -7.795e+06
# Cur diff delta = 58148.3046875
# Cur diff sigma = 36794.1953125
# Cur diff theta = 94942.5
# ---------------------------------------
# VB, d: 300, Iter: 1-120, s/iter: 1.163e-01, ELBO: -6.803e+06
# Cur diff delta = 53293.52734375
# Cur diff sigma = 29724.46875
# Cur diff theta = 83017.99609375
# ---------------------------------------
# VB, d: 300, Iter: 1-140, s/iter: 1.147e-01, ELBO: -6.059e+06
# Cur diff delta = 48783.7109375
# Cur diff sigma = 23659.5546875
# Cur diff theta = 72443.265625
# ---------------------------------------
# VB, d: 300, Iter: 1-160, s/iter: 1.152e-01, ELBO: -5.387e+06
# Cur diff delta = 44619.3125
# Cur diff sigma = 18528.25390625
# Cur diff theta = 63147.56640625
# ---------------------------------------
# VB, d: 300, Iter: 1-180, s/iter: 1.160e-01, ELBO: -4.783e+06
# Cur diff delta = 40834.55078125
# Cur diff sigma = 14241.6455078125
# Cur diff theta = 55076.1962890625
# ---------------------------------------
# VB, d: 300, Iter: 1-200, s/iter: 1.152e-01, ELBO: -4.213e+06
# Cur diff delta = 37408.484375
# Cur diff sigma = 10722.4306640625
# Cur diff theta = 48130.9150390625
# ---------------------------------------
# VB, d: 300, Iter: 1-220, s/iter: 1.170e-01, ELBO: -3.669e+06
# Cur diff delta = 34309.48828125
# Cur diff sigma = 7891.455078125
# Cur diff theta = 42200.943359375
# ---------------------------------------
# VB, d: 300, Iter: 1-240, s/iter: 1.151e-01, ELBO: -3.157e+06
# Cur diff delta = 31557.796875
# Cur diff sigma = 5666.7265625
# Cur diff theta = 37224.5234375
# ---------------------------------------
# VB, d: 300, Iter: 1-260, s/iter: 1.150e-01, ELBO: -2.757e+06
# Cur diff delta = 29188.900390625
# Cur diff sigma = 3944.908203125
# Cur diff theta = 33133.80859375
# ---------------------------------------
# VB, d: 300, Iter: 1-280, s/iter: 1.146e-01, ELBO: -2.408e+06
# Cur diff delta = 27149.501953125
# Cur diff sigma = 2644.19189453125
# Cur diff theta = 29793.69384765625
# ---------------------------------------
# VB, d: 300, Iter: 1-300, s/iter: 1.147e-01, ELBO: -2.107e+06
# Cur diff delta = 25392.33203125
# Cur diff sigma = 1687.41455078125
# Cur diff theta = 27079.74658203125
# ---------------------------------------
# VB, d: 300, Iter: 1-320, s/iter: 1.138e-01, ELBO: -1.876e+06
# Cur diff delta = 23901.984375
# Cur diff sigma = 1002.69921875
# Cur diff theta = 24904.68359375
# ---------------------------------------
# VB, d: 300, Iter: 1-340, s/iter: 1.152e-01, ELBO: -1.684e+06
# Cur diff delta = 22589.939453125
# Cur diff sigma = 534.1195678710938
# Cur diff theta = 23124.059020996094
# ---------------------------------------
# VB, d: 300, Iter: 1-360, s/iter: 1.140e-01, ELBO: -1.502e+06
# Cur diff delta = 21430.4765625
# Cur diff sigma = 243.85369873046875
# Cur diff theta = 21674.33026123047
# ---------------------------------------
# VB, d: 300, Iter: 1-380, s/iter: 1.156e-01, ELBO: -1.346e+06
# Cur diff delta = 20425.185546875
# Cur diff sigma = 88.91163635253906
# Cur diff theta = 20514.09718322754
# ---------------------------------------
# VB, d: 300, Iter: 1-400, s/iter: 1.155e-01, ELBO: -1.235e+06
# Cur diff delta = 19581.1953125
# Cur diff sigma = 23.28030776977539
# Cur diff theta = 19604.475620269775
# ---------------------------------------
# VB, d: 300, Iter: 1-420, s/iter: 1.156e-01, ELBO: -1.170e+06
# Cur diff delta = 18872.6875
# Cur diff sigma = 3.847456932067871
# Cur diff theta = 18876.534956932068
# ---------------------------------------
# VB, d: 300, Iter: 1-440, s/iter: 1.150e-01, ELBO: -1.145e+06
# Cur diff delta = 18264.203125
# Cur diff sigma = 0.21158993244171143
# Cur diff theta = 18264.41471493244
# ---------------------------------------
# VB, d: 300, Iter: 1-460, s/iter: 1.166e-01, ELBO: -1.130e+06
# Cur diff delta = 17694.771484375
# Cur diff sigma = 0.004063721280544996
# Cur diff theta = 17694.77554809628
# ---------------------------------------
# VB, d: 300, Iter: 1-480, s/iter: 1.164e-01, ELBO: -1.119e+06
# Cur diff delta = 17148.873046875
# Cur diff sigma = 0.004062870517373085
# Cur diff theta = 17148.877109745517
# ---------------------------------------
# VB, d: 300, Iter: 1-500, s/iter: 1.157e-01, ELBO: -1.109e+06
# Cur diff delta = 16621.25
# Cur diff sigma = 0.004063508473336697
# Cur diff theta = 16621.254063508473
# ---------------------------------------
# VB, d: 300, Iter: 1-520, s/iter: 1.146e-01, ELBO: -1.099e+06
# Cur diff delta = 16111.4921875
# Cur diff sigma = 0.0040640998631715775
# Cur diff theta = 16111.496251599863
# ---------------------------------------
# VB, d: 300, Iter: 1-540, s/iter: 1.139e-01, ELBO: -1.089e+06
# Cur diff delta = 15619.0146484375
# Cur diff sigma = 0.00406503863632679
# Cur diff theta = 15619.018713476136
# ---------------------------------------
# VB, d: 300, Iter: 1-560, s/iter: 1.150e-01, ELBO: -1.079e+06
# Cur diff delta = 15143.2421875
# Cur diff sigma = 0.004065453540533781
# Cur diff theta = 15143.24625295354
# ---------------------------------------
# VB, d: 300, Iter: 1-580, s/iter: 1.139e-01, ELBO: -1.070e+06
# Cur diff delta = 14683.6240234375
# Cur diff sigma = 0.0040659415535628796
# Cur diff theta = 14683.628089379054
# ---------------------------------------
# VB, d: 300, Iter: 1-600, s/iter: 1.135e-01, ELBO: -1.061e+06
# Cur diff delta = 14239.619140625
# Cur diff sigma = 0.004066480789333582
# Cur diff theta = 14239.62320710579
# ---------------------------------------
# VB, d: 300, Iter: 1-620, s/iter: 1.131e-01, ELBO: -1.052e+06
# Cur diff delta = 13810.697265625
# Cur diff sigma = 0.004067078232765198
# Cur diff theta = 13810.701332703233
# ---------------------------------------
# VB, d: 300, Iter: 1-640, s/iter: 1.152e-01, ELBO: -1.044e+06
# Cur diff delta = 13396.345703125
# Cur diff sigma = 0.004067567177116871
# Cur diff theta = 13396.349770692177
# ---------------------------------------
# VB, d: 300, Iter: 1-660, s/iter: 1.128e-01, ELBO: -1.036e+06
# Cur diff delta = 12996.076171875
# Cur diff sigma = 0.0040679313242435455
# Cur diff theta = 12996.080239806324
# ---------------------------------------
# VB, d: 300, Iter: 1-680, s/iter: 1.136e-01, ELBO: -1.028e+06
# Cur diff delta = 12609.408203125
# Cur diff sigma = 0.004068494774401188
# Cur diff theta = 12609.412271619774
# ---------------------------------------
# VB, d: 300, Iter: 1-700, s/iter: 1.149e-01, ELBO: -1.020e+06
# Cur diff delta = 12235.8623046875
# Cur diff sigma = 0.004068886861205101
# Cur diff theta = 12235.866373574361
# ---------------------------------------
# VB, d: 300, Iter: 1-720, s/iter: 1.153e-01, ELBO: -1.013e+06
# Cur diff delta = 11874.99609375
# Cur diff sigma = 0.004069318529218435
# Cur diff theta = 11875.00016306853
# ---------------------------------------
# VB, d: 300, Iter: 1-740, s/iter: 1.165e-01, ELBO: -1.006e+06
# Cur diff delta = 11526.36328125
# Cur diff sigma = 0.004069661255925894
# Cur diff theta = 11526.367350911256
# ---------------------------------------
# VB, d: 300, Iter: 1-760, s/iter: 1.156e-01, ELBO: -9.989e+05
# Cur diff delta = 11189.541015625
# Cur diff sigma = 0.004069918766617775
# Cur diff theta = 11189.545085543767
# ---------------------------------------
# VB, d: 300, Iter: 1-780, s/iter: 1.151e-01, ELBO: -9.923e+05
# Cur diff delta = 10864.1142578125
# Cur diff sigma = 0.00407029502093792
# Cur diff theta = 10864.118328107521
# ---------------------------------------
# VB, d: 300, Iter: 1-800, s/iter: 1.127e-01, ELBO: -9.859e+05
# Cur diff delta = 10549.6845703125
# Cur diff sigma = 0.004070714581757784
# Cur diff theta = 10549.688641027082
# ---------------------------------------
# VB, d: 300, Iter: 1-820, s/iter: 1.139e-01, ELBO: -9.798e+05
# Cur diff delta = 10245.869140625
# Cur diff sigma = 0.004071044735610485
# Cur diff theta = 10245.873211669736
# ---------------------------------------
# VB, d: 300, Iter: 1-840, s/iter: 1.128e-01, ELBO: -9.738e+05
# Cur diff delta = 9952.2890625
# Cur diff sigma = 0.0040713413618505
# Cur diff theta = 9952.293133841362
# ---------------------------------------
# VB, d: 300, Iter: 1-860, s/iter: 1.164e-01, ELBO: -9.681e+05
# Cur diff delta = 9668.5849609375
# Cur diff sigma = 0.004071672912687063
# Cur diff theta = 9668.589032610413
# ---------------------------------------
# VB, d: 300, Iter: 1-880, s/iter: 1.164e-01, ELBO: -9.625e+05
# Cur diff delta = 9394.4111328125
# Cur diff sigma = 0.004071854520589113
# Cur diff theta = 9394.41520466702
# ---------------------------------------
# VB, d: 300, Iter: 1-900, s/iter: 1.178e-01, ELBO: -9.571e+05
# Cur diff delta = 9129.4248046875
# Cur diff sigma = 0.004072153475135565
# Cur diff theta = 9129.428876840975
# ---------------------------------------
# VB, d: 300, Iter: 1-920, s/iter: 1.135e-01, ELBO: -9.519e+05
# Cur diff delta = 8873.302734375
# Cur diff sigma = 0.004072508309036493
# Cur diff theta = 8873.306806883309
# ---------------------------------------
# VB, d: 300, Iter: 1-940, s/iter: 1.130e-01, ELBO: -9.468e+05
# Cur diff delta = 8625.7294921875
# Cur diff sigma = 0.0040726810693740845
# Cur diff theta = 8625.73356486857
# ---------------------------------------
# VB, d: 300, Iter: 1-960, s/iter: 1.144e-01, ELBO: -9.419e+05
# Cur diff delta = 8386.3955078125
# Cur diff sigma = 0.004072825890034437
# Cur diff theta = 8386.39958063839
# ---------------------------------------
# VB, d: 300, Iter: 1-980, s/iter: 1.137e-01, ELBO: -9.372e+05
# Cur diff delta = 8155.01416015625
# Cur diff sigma = 0.004073087591677904
# Cur diff theta = 8155.018233243842
# ---------------------------------------
# VB, d: 300, Iter: 1-1000, s/iter: 1.146e-01, ELBO: -9.327e+05
# Cur diff delta = 7931.30126953125
# Cur diff sigma = 0.004073365591466427
# Cur diff theta = 7931.3053428968415
# ---------------------------------------
# VB, d: 300, Iter: 1-1020, s/iter: 1.144e-01, ELBO: -9.283e+05
# Cur diff delta = 7714.97998046875
# Cur diff sigma = 0.00407354487106204
# Cur diff theta = 7714.984054013621
# ---------------------------------------
# VB, d: 300, Iter: 1-1040, s/iter: 1.164e-01, ELBO: -9.240e+05
# Cur diff delta = 7505.7900390625
# Cur diff sigma = 0.004073652904480696
# Cur diff theta = 7505.7941127154045
# ---------------------------------------
# VB, d: 300, Iter: 1-1060, s/iter: 1.144e-01, ELBO: -9.199e+05
# Cur diff delta = 7303.47705078125
# Cur diff sigma = 0.004073841031640768
# Cur diff theta = 7303.481124622282
# ---------------------------------------
# VB, d: 300, Iter: 1-1080, s/iter: 1.145e-01, ELBO: -9.159e+05
# Cur diff delta = 7107.794921875
# Cur diff sigma = 0.0040740398690104485
# Cur diff theta = 7107.798995914869
# ---------------------------------------
# VB, d: 300, Iter: 1-1100, s/iter: 1.139e-01, ELBO: -9.120e+05
# Cur diff delta = 6918.50634765625
# Cur diff sigma = 0.004074153956025839
# Cur diff theta = 6918.510421810206
# ---------------------------------------
# VB, d: 300, Iter: 1-1120, s/iter: 1.137e-01, ELBO: -9.083e+05
# Cur diff delta = 6735.3857421875
# Cur diff sigma = 0.004074313677847385
# Cur diff theta = 6735.389816501178
# ---------------------------------------
# VB, d: 300, Iter: 1-1140, s/iter: 1.128e-01, ELBO: -9.047e+05
# Cur diff delta = 6558.20849609375
# Cur diff sigma = 0.004074444528669119
# Cur diff theta = 6558.212570538279
# ---------------------------------------
# VB, d: 300, Iter: 1-1160, s/iter: 1.129e-01, ELBO: -9.012e+05
# Cur diff delta = 6386.771484375
# Cur diff sigma = 0.004074654076248407
# Cur diff theta = 6386.775559029076
# ---------------------------------------
# VB, d: 300, Iter: 1-1180, s/iter: 1.124e-01, ELBO: -8.978e+05
# Cur diff delta = 6220.86474609375
# Cur diff sigma = 0.0040746512822806835
# Cur diff theta = 6220.868820745032
# ---------------------------------------
# VB, d: 300, Iter: 1-1200, s/iter: 1.139e-01, ELBO: -8.945e+05
# Cur diff delta = 6060.29345703125
# Cur diff sigma = 0.0040748231112957
# Cur diff theta = 6060.297531854361
# ---------------------------------------
# VB, d: 300, Iter: 1-1220, s/iter: 1.116e-01, ELBO: -8.913e+05
# Cur diff delta = 5904.865234375
# Cur diff sigma = 0.004074950702488422
# Cur diff theta = 5904.8693093257025
# ---------------------------------------
# VB, d: 300, Iter: 1-1240, s/iter: 1.126e-01, ELBO: -8.882e+05
# Cur diff delta = 5754.4013671875
# Cur diff sigma = 0.0040750568732619286
# Cur diff theta = 5754.405442244373
# ---------------------------------------
# VB, d: 300, Iter: 1-1260, s/iter: 1.122e-01, ELBO: -8.853e+05
# Cur diff delta = 5608.72705078125
# Cur diff sigma = 0.004075177945196629
# Cur diff theta = 5608.731125959195
# ---------------------------------------
# VB, d: 300, Iter: 1-1280, s/iter: 1.130e-01, ELBO: -8.824e+05
# Cur diff delta = 5467.669921875
# Cur diff sigma = 0.004075310193002224
# Cur diff theta = 5467.673997185193
# ---------------------------------------
# VB, d: 300, Iter: 1-1300, s/iter: 1.128e-01, ELBO: -8.796e+05
# Cur diff delta = 5331.0673828125
# Cur diff sigma = 0.004075365141034126
# Cur diff theta = 5331.071458177641
# ---------------------------------------
# VB, d: 300, Iter: 1-1320, s/iter: 1.142e-01, ELBO: -8.769e+05
# Cur diff delta = 5198.767578125
# Cur diff sigma = 0.0040753991343081
# Cur diff theta = 5198.771653524134
# ---------------------------------------
# VB, d: 300, Iter: 1-1340, s/iter: 1.118e-01, ELBO: -8.742e+05
# Cur diff delta = 5070.61181640625
# Cur diff sigma = 0.0040755001828074455
# Cur diff theta = 5070.615891906433
# ---------------------------------------
# VB, d: 300, Iter: 1-1360, s/iter: 1.116e-01, ELBO: -8.717e+05
# Cur diff delta = 4946.4599609375
# Cur diff sigma = 0.004075620323419571
# Cur diff theta = 4946.464036557823
# ---------------------------------------
# VB, d: 300, Iter: 1-1380, s/iter: 1.130e-01, ELBO: -8.692e+05
# Cur diff delta = 4826.1728515625
# Cur diff sigma = 0.004075709264725447
# Cur diff theta = 4826.176927271765
# ---------------------------------------
# VB, d: 300, Iter: 1-1400, s/iter: 1.126e-01, ELBO: -8.668e+05
# Cur diff delta = 4709.61279296875
# Cur diff sigma = 0.004075728356838226
# Cur diff theta = 4709.616868697107
# ---------------------------------------
# VB, d: 300, Iter: 1-1420, s/iter: 1.133e-01, ELBO: -8.645e+05
# Cur diff delta = 4596.65185546875
# Cur diff sigma = 0.00407580379396677
# Cur diff theta = 4596.655931272544
# ---------------------------------------
# VB, d: 300, Iter: 1-1440, s/iter: 1.148e-01, ELBO: -8.623e+05
# Cur diff delta = 4487.1640625
# Cur diff sigma = 0.004075860138982534
# Cur diff theta = 4487.168138360139
# ---------------------------------------
# VB, d: 300, Iter: 1-1460, s/iter: 1.140e-01, ELBO: -8.601e+05
# Cur diff delta = 4381.025390625
# Cur diff sigma = 0.0040758829563856125
# Cur diff theta = 4381.029466507956
# ---------------------------------------
# VB, d: 300, Iter: 1-1480, s/iter: 1.133e-01, ELBO: -8.580e+05
# Cur diff delta = 4278.12255859375
# Cur diff sigma = 0.00407595606520772
# Cur diff theta = 4278.126634549815
# ---------------------------------------
# VB, d: 300, Iter: 1-1500, s/iter: 1.124e-01, ELBO: -8.559e+05
# Cur diff delta = 4178.34814453125
# Cur diff sigma = 0.004075998906046152
# Cur diff theta = 4178.352220530156
# ---------------------------------------
# VB, d: 300, Iter: 1-1520, s/iter: 1.131e-01, ELBO: -8.539e+05
# Cur diff delta = 4081.588134765625
# Cur diff sigma = 0.004076013807207346
# Cur diff theta = 4081.592210779432
# ---------------------------------------
# VB, d: 300, Iter: 1-1540, s/iter: 1.122e-01, ELBO: -8.520e+05
# Cur diff delta = 3987.742431640625
# Cur diff sigma = 0.004076080396771431
# Cur diff theta = 3987.7465077210218
# ---------------------------------------
# VB, d: 300, Iter: 1-1560, s/iter: 1.138e-01, ELBO: -8.501e+05
# Cur diff delta = 3896.711181640625
# Cur diff sigma = 0.0040761264972388744
# Cur diff theta = 3896.7152577671222
# ---------------------------------------
# VB, d: 300, Iter: 1-1580, s/iter: 1.142e-01, ELBO: -8.483e+05
# Cur diff delta = 3808.395263671875
# Cur diff sigma = 0.004076129291206598
# Cur diff theta = 3808.399339801166
# ---------------------------------------
# VB, d: 300, Iter: 1-1600, s/iter: 1.132e-01, ELBO: -8.465e+05
# Cur diff delta = 3722.708251953125
# Cur diff sigma = 0.004076170269399881
# Cur diff theta = 3722.7123281233944
# ---------------------------------------
# VB, d: 300, Iter: 1-1620, s/iter: 1.140e-01, ELBO: -8.448e+05
# Cur diff delta = 3639.557861328125
# Cur diff sigma = 0.004076209384948015
# Cur diff theta = 3639.56193753751
# ---------------------------------------
# VB, d: 300, Iter: 1-1640, s/iter: 1.128e-01, ELBO: -8.431e+05
# Cur diff delta = 3558.853515625
# Cur diff sigma = 0.004076294135302305
# Cur diff theta = 3558.8575919191353
# ---------------------------------------
# VB, d: 300, Iter: 1-1660, s/iter: 1.130e-01, ELBO: -8.415e+05
# Cur diff delta = 3480.51904296875
# Cur diff sigma = 0.0040762764401733875
# Cur diff theta = 3480.52311924519
# ---------------------------------------
# VB, d: 300, Iter: 1-1680, s/iter: 1.125e-01, ELBO: -8.399e+05
# Cur diff delta = 3404.474853515625
# Cur diff sigma = 0.004076389595866203
# Cur diff theta = 3404.478929905221
# ---------------------------------------
# VB, d: 300, Iter: 1-1700, s/iter: 1.144e-01, ELBO: -8.384e+05
# Cur diff delta = 3330.63671875
# Cur diff sigma = 0.004076413344591856
# Cur diff theta = 3330.6407951633446
# ---------------------------------------
# VB, d: 300, Iter: 1-1720, s/iter: 1.123e-01, ELBO: -8.369e+05
# Cur diff delta = 3258.938720703125
# Cur diff sigma = 0.0040764170698821545
# Cur diff theta = 3258.942797120195
# ---------------------------------------
# VB, d: 300, Iter: 1-1740, s/iter: 1.132e-01, ELBO: -8.355e+05
# Cur diff delta = 3189.306396484375
# Cur diff sigma = 0.004076410084962845
# Cur diff theta = 3189.31047289446
# ---------------------------------------
# VB, d: 300, Iter: 1-1760, s/iter: 1.133e-01, ELBO: -8.341e+05
# Cur diff delta = 3121.671142578125
# Cur diff sigma = 0.004076432902365923
# Cur diff theta = 3121.6752190110274
# ---------------------------------------
# VB, d: 300, Iter: 1-1780, s/iter: 1.133e-01, ELBO: -8.327e+05
# Cur diff delta = 3055.96826171875
# Cur diff sigma = 0.004076504614204168
# Cur diff theta = 3055.972338223364
# ---------------------------------------
# VB, d: 300, Iter: 1-1800, s/iter: 1.126e-01, ELBO: -8.314e+05
# Cur diff delta = 2992.1318359375
# Cur diff sigma = 0.004076479934155941
# Cur diff theta = 2992.135912417434
# ---------------------------------------
# VB, d: 300, Iter: 1-1820, s/iter: 1.132e-01, ELBO: -8.301e+05
# Cur diff delta = 2930.1005859375
# Cur diff sigma = 0.004076491575688124
# Cur diff theta = 2930.1046624290757
# ---------------------------------------
# VB, d: 300, Iter: 1-1840, s/iter: 1.131e-01, ELBO: -8.288e+05
# Cur diff delta = 2869.815185546875
# Cur diff sigma = 0.004076540004462004
# Cur diff theta = 2869.8192620868795
# ---------------------------------------
# VB, d: 300, Iter: 1-1860, s/iter: 1.144e-01, ELBO: -8.276e+05
# Cur diff delta = 2811.222412109375
# Cur diff sigma = 0.004076526965945959
# Cur diff theta = 2811.226488636341
# ---------------------------------------
# VB, d: 300, Iter: 1-1880, s/iter: 1.139e-01, ELBO: -8.264e+05
# Cur diff delta = 2754.261474609375
# Cur diff sigma = 0.004076565615832806
# Cur diff theta = 2754.265551174991
# ---------------------------------------
# VB, d: 300, Iter: 1-1900, s/iter: 1.125e-01, ELBO: -8.253e+05
# Cur diff delta = 2698.881591796875
# Cur diff sigma = 0.004076535813510418
# Cur diff theta = 2698.8856683326885
# ---------------------------------------
# VB, d: 300, Iter: 1-1920, s/iter: 1.131e-01, ELBO: -8.241e+05
# Cur diff delta = 2645.033935546875
# Cur diff sigma = 0.004076636862009764
# Cur diff theta = 2645.038012183737
# ---------------------------------------
# VB, d: 300, Iter: 1-1940, s/iter: 1.133e-01, ELBO: -8.231e+05
# Cur diff delta = 2592.666259765625
# Cur diff sigma = 0.0040766154415905476
# Cur diff theta = 2592.6703363810666
# ---------------------------------------
# VB, d: 300, Iter: 1-1960, s/iter: 1.124e-01, ELBO: -8.220e+05
# Cur diff delta = 2541.732177734375
# Cur diff sigma = 0.004076626151800156
# Cur diff theta = 2541.736254360527
# ---------------------------------------
# VB, d: 300, Iter: 1-1980, s/iter: 1.125e-01, ELBO: -8.210e+05
# Cur diff delta = 2492.18701171875
# Cur diff sigma = 0.004076632671058178
# Cur diff theta = 2492.191088351421
# ---------------------------------------
# VB, d: 300, Iter: 1-2000, s/iter: 1.130e-01, ELBO: -8.200e+05
# Cur diff delta = 2443.984130859375
# Cur diff sigma = 0.004076634533703327
# Cur diff theta = 2443.9882074939087
# ---------------------------------------
# VB, d: 300, Iter: 1-2020, s/iter: 1.127e-01, ELBO: -8.190e+05
# Cur diff delta = 2397.083740234375
# Cur diff sigma = 0.004076675046235323
# Cur diff theta = 2397.0878169094212
# ---------------------------------------
# VB, d: 300, Iter: 1-2040, s/iter: 1.142e-01, ELBO: -8.180e+05
# Cur diff delta = 2351.44482421875
# Cur diff sigma = 0.0040766517631709576
# Cur diff theta = 2351.448900870513
# ---------------------------------------
# VB, d: 300, Iter: 1-2060, s/iter: 1.121e-01, ELBO: -8.171e+05
# Cur diff delta = 2307.022216796875
# Cur diff sigma = 0.004076659679412842
# Cur diff theta = 2307.0262934565544
# ---------------------------------------
# VB, d: 300, Iter: 1-2080, s/iter: 1.123e-01, ELBO: -8.162e+05
# Cur diff delta = 2263.78271484375
# Cur diff sigma = 0.004076680634170771
# Cur diff theta = 2263.786791524384
# ---------------------------------------
# VB, d: 300, Iter: 1-2100, s/iter: 1.156e-01, ELBO: -8.153e+05
# Cur diff delta = 2221.68994140625
# Cur diff sigma = 0.004076663870364428
# Cur diff theta = 2221.6940180701204
# ---------------------------------------
# VB, d: 300, Iter: 1-2120, s/iter: 1.165e-01, ELBO: -8.144e+05
# Cur diff delta = 2180.70458984375
# Cur diff sigma = 0.004076674114912748
# Cur diff theta = 2180.708666517865
# ---------------------------------------
# VB, d: 300, Iter: 1-2140, s/iter: 1.143e-01, ELBO: -8.136e+05
# Cur diff delta = 2140.7939453125
# Cur diff sigma = 0.004076656419783831
# Cur diff theta = 2140.79802196892
# ---------------------------------------
# VB, d: 300, Iter: 1-2160, s/iter: 1.159e-01, ELBO: -8.128e+05
# Cur diff delta = 2101.921875
# Cur diff sigma = 0.004076679702848196
# Cur diff theta = 2101.925951679703
# ---------------------------------------
# VB, d: 300, Iter: 1-2180, s/iter: 1.159e-01, ELBO: -8.120e+05
# Cur diff delta = 2064.066650390625
# Cur diff sigma = 0.004076672717928886
# Cur diff theta = 2064.070727063343
# ---------------------------------------
# VB, d: 300, Iter: 1-2200, s/iter: 1.138e-01, ELBO: -8.112e+05
# Cur diff delta = 2027.1824951171875
# Cur diff sigma = 0.004076684359461069
# Cur diff theta = 2027.186571801547
# ---------------------------------------
# VB, d: 300, Iter: 1-2220, s/iter: 1.147e-01, ELBO: -8.105e+05
# Cur diff delta = 1991.25048828125
# Cur diff sigma = 0.004076692275702953
# Cur diff theta = 1991.2545649735257
# ---------------------------------------
# VB, d: 300, Iter: 1-2240, s/iter: 1.129e-01, ELBO: -8.097e+05
# Cur diff delta = 1956.2362060546875
# Cur diff sigma = 0.004076720681041479
# Cur diff theta = 1956.2402827753685
# ---------------------------------------
# VB, d: 300, Iter: 1-2260, s/iter: 1.138e-01, ELBO: -8.090e+05
# Cur diff delta = 1922.1146240234375
# Cur diff sigma = 0.004076733719557524
# Cur diff theta = 1922.118700757157
# ---------------------------------------
# VB, d: 300, Iter: 1-2280, s/iter: 1.136e-01, ELBO: -8.083e+05
# Cur diff delta = 1888.8594970703125
# Cur diff sigma = 0.00407673604786396
# Cur diff theta = 1888.8635738063604
# ---------------------------------------
# VB, d: 300, Iter: 1-2300, s/iter: 1.123e-01, ELBO: -8.076e+05
# Cur diff delta = 1856.439697265625
# Cur diff sigma = 0.004076727665960789
# Cur diff theta = 1856.443773993291
# ---------------------------------------
# VB, d: 300, Iter: 1-2320, s/iter: 1.128e-01, ELBO: -8.070e+05
# Cur diff delta = 1824.8350830078125
# Cur diff sigma = 0.004076751880347729
# Cur diff theta = 1824.8391597596928
# ---------------------------------------
# VB, d: 300, Iter: 1-2340, s/iter: 1.122e-01, ELBO: -8.063e+05
# Cur diff delta = 1794.020263671875
# Cur diff sigma = 0.004076748620718718
# Cur diff theta = 1794.0243404204957
# ---------------------------------------
# VB, d: 300, Iter: 1-2360, s/iter: 1.136e-01, ELBO: -8.057e+05
# Cur diff delta = 1763.970703125
# Cur diff sigma = 0.004076783079653978
# Cur diff theta = 1763.9747799080797
# ---------------------------------------
# VB, d: 300, Iter: 1-2380, s/iter: 1.129e-01, ELBO: -8.051e+05
# Cur diff delta = 1734.662109375
# Cur diff sigma = 0.004076773766428232
# Cur diff theta = 1734.6661861487664
# ---------------------------------------
# VB, d: 300, Iter: 1-2400, s/iter: 1.150e-01, ELBO: -8.044e+05
# Cur diff delta = 1706.076416015625
# Cur diff sigma = 0.004076783545315266
# Cur diff theta = 1706.0804927991703
# ---------------------------------------
# VB, d: 300, Iter: 1-2420, s/iter: 1.131e-01, ELBO: -8.039e+05
# Cur diff delta = 1678.1920166015625
# Cur diff sigma = 0.00407677236944437
# Cur diff theta = 1678.196093373932
# ---------------------------------------
# VB, d: 300, Iter: 1-2440, s/iter: 1.145e-01, ELBO: -8.033e+05
# Cur diff delta = 1650.986572265625
# Cur diff sigma = 0.004076771438121796
# Cur diff theta = 1650.9906490370631
# ---------------------------------------
# VB, d: 300, Iter: 1-2460, s/iter: 1.125e-01, ELBO: -8.027e+05
# Cur diff delta = 1624.44189453125
# Cur diff sigma = 0.004076775629073381
# Cur diff theta = 1624.445971306879
# ---------------------------------------
# VB, d: 300, Iter: 1-2480, s/iter: 1.125e-01, ELBO: -8.022e+05
# Cur diff delta = 1598.5380859375
# Cur diff sigma = 0.0040767681784927845
# Cur diff theta = 1598.5421627056785
# ---------------------------------------
# VB, d: 300, Iter: 1-2500, s/iter: 1.125e-01, ELBO: -8.016e+05
# Cur diff delta = 1573.2567138671875
# Cur diff sigma = 0.004076755605638027
# Cur diff theta = 1573.2607906227931
# ---------------------------------------
# VB, d: 300, Iter: 1-2520, s/iter: 1.125e-01, ELBO: -8.011e+05
# Cur diff delta = 1548.5780029296875
# Cur diff sigma = 0.004076793324202299
# Cur diff theta = 1548.5820797230117
# ---------------------------------------
# VB, d: 300, Iter: 1-2540, s/iter: 1.133e-01, ELBO: -8.006e+05
# Cur diff delta = 1524.4879150390625
# Cur diff sigma = 0.004076777026057243
# Cur diff theta = 1524.4919918160886
# ---------------------------------------
# VB, d: 300, Iter: 1-2560, s/iter: 1.190e-01, ELBO: -8.001e+05
# Cur diff delta = 1500.96826171875
# Cur diff sigma = 0.004076768644154072
# Cur diff theta = 1500.9723384873942
# ---------------------------------------
# VB, d: 300, Iter: 1-2580, s/iter: 1.172e-01, ELBO: -7.996e+05
# Cur diff delta = 1478.0009765625
# Cur diff sigma = 0.004076777026057243
# Cur diff theta = 1478.005053339526
# ---------------------------------------
# VB, d: 300, Iter: 1-2600, s/iter: 1.174e-01, ELBO: -7.991e+05
# Cur diff delta = 1455.5726318359375
# Cur diff sigma = 0.004076799377799034
# Cur diff theta = 1455.5767086353153
# ---------------------------------------
# VB, d: 300, Iter: 1-2620, s/iter: 1.179e-01, ELBO: -7.987e+05
# Cur diff delta = 1433.6689453125
# Cur diff sigma = 0.004076784010976553
# Cur diff theta = 1433.673022096511
# ---------------------------------------
# VB, d: 300, Iter: 1-2640, s/iter: 1.147e-01, ELBO: -7.982e+05
# Cur diff delta = 1412.2745361328125
# Cur diff sigma = 0.004076775163412094
# Cur diff theta = 1412.278612907976
# ---------------------------------------
# VB, d: 300, Iter: 1-2660, s/iter: 1.140e-01, ELBO: -7.978e+05
# Cur diff delta = 1391.3736572265625
# Cur diff sigma = 0.004076797980815172
# Cur diff theta = 1391.3777340245433
# ---------------------------------------
# VB, d: 300, Iter: 1-2680, s/iter: 1.121e-01, ELBO: -7.973e+05
# Cur diff delta = 1370.9520263671875
# Cur diff sigma = 0.004076795652508736
# Cur diff theta = 1370.95610316284
# ---------------------------------------
# VB, d: 300, Iter: 1-2700, s/iter: 1.121e-01, ELBO: -7.969e+05
# Cur diff delta = 1350.9974365234375
# Cur diff sigma = 0.004076807759702206
# Cur diff theta = 1351.0015133311972
# ---------------------------------------
# VB, d: 300, Iter: 1-2720, s/iter: 1.135e-01, ELBO: -7.965e+05
# Cur diff delta = 1331.4970703125
# Cur diff sigma = 0.004076801240444183
# Cur diff theta = 1331.5011471137404
# ---------------------------------------
# VB, d: 300, Iter: 1-2740, s/iter: 1.121e-01, ELBO: -7.961e+05
# Cur diff delta = 1312.4395751953125
# Cur diff sigma = 0.004076813347637653
# Cur diff theta = 1312.4436520086601
# ---------------------------------------
# VB, d: 300, Iter: 1-2760, s/iter: 1.132e-01, ELBO: -7.957e+05
# Cur diff delta = 1293.8126220703125
# Cur diff sigma = 0.004076805431395769
# Cur diff theta = 1293.816698875744
# ---------------------------------------
# VB, d: 300, Iter: 1-2780, s/iter: 1.115e-01, ELBO: -7.953e+05
# Cur diff delta = 1275.6029052734375
# Cur diff sigma = 0.004076813813298941
# Cur diff theta = 1275.6069820872508
# ---------------------------------------
# VB, d: 300, Iter: 1-2800, s/iter: 1.135e-01, ELBO: -7.949e+05
# Cur diff delta = 1257.8004150390625
# Cur diff sigma = 0.004076806362718344
# Cur diff theta = 1257.8044918454252
# ---------------------------------------
# VB, d: 300, Iter: 1-2820, s/iter: 1.129e-01, ELBO: -7.945e+05
# Cur diff delta = 1240.395263671875
# Cur diff sigma = 0.004076782613992691
# Cur diff theta = 1240.399340454489
# ---------------------------------------
# VB, d: 300, Iter: 1-2840, s/iter: 1.136e-01, ELBO: -7.942e+05
# Cur diff delta = 1223.373291015625
# Cur diff sigma = 0.004076788667589426
# Cur diff theta = 1223.3773678042926
# ---------------------------------------
# VB, d: 300, Iter: 1-2860, s/iter: 1.135e-01, ELBO: -7.938e+05
# Cur diff delta = 1206.7235107421875
# Cur diff sigma = 0.004076791927218437
# Cur diff theta = 1206.7275875341147
# ---------------------------------------
# VB, d: 300, Iter: 1-2880, s/iter: 1.138e-01, ELBO: -7.934e+05
# Cur diff delta = 1190.4415283203125
# Cur diff sigma = 0.004076801240444183
# Cur diff theta = 1190.445605121553
# ---------------------------------------
# VB, d: 300, Iter: 1-2900, s/iter: 1.130e-01, ELBO: -7.931e+05
# Cur diff delta = 1174.5166015625
# Cur diff sigma = 0.004076814278960228
# Cur diff theta = 1174.520678376779
# ---------------------------------------
# VB, d: 300, Iter: 1-2920, s/iter: 1.120e-01, ELBO: -7.928e+05
# Cur diff delta = 1158.9378662109375
# Cur diff sigma = 0.004076802637428045
# Cur diff theta = 1158.941943013575
# ---------------------------------------
# VB, d: 300, Iter: 1-2940, s/iter: 1.134e-01, ELBO: -7.924e+05
# Cur diff delta = 1143.6937255859375
# Cur diff sigma = 0.00407680356875062
# Cur diff theta = 1143.6978023895063
# ---------------------------------------
# VB, d: 300, Iter: 1-2960, s/iter: 1.138e-01, ELBO: -7.921e+05
# Cur diff delta = 1128.7760009765625
# Cur diff sigma = 0.004076800774782896
# Cur diff theta = 1128.7800777773373
# ---------------------------------------
# VB, d: 300, Iter: 1-2980, s/iter: 1.126e-01, ELBO: -7.918e+05
# Cur diff delta = 1114.17919921875
# Cur diff sigma = 0.004076784010976553
# Cur diff theta = 1114.183276002761
# ---------------------------------------
# VB, d: 300, Iter: 1-3000, s/iter: 1.114e-01, ELBO: -7.915e+05
# Cur diff delta = 1099.8948974609375
# Cur diff sigma = 0.004076813813298941
# Cur diff theta = 1099.8989742747508
# ---------------------------------------
# VB, d: 300, Iter: 1-3020, s/iter: 1.126e-01, ELBO: -7.912e+05
# Cur diff delta = 1085.91455078125
# Cur diff sigma = 0.004076788201928139
# Cur diff theta = 1085.918627569452
# ---------------------------------------
# VB, d: 300, Iter: 1-3040, s/iter: 1.116e-01, ELBO: -7.909e+05
# Cur diff delta = 1072.2259521484375
# Cur diff sigma = 0.004076807294040918
# Cur diff theta = 1072.2300289557315
# ---------------------------------------
# VB, d: 300, Iter: 1-3060, s/iter: 1.113e-01, ELBO: -7.906e+05
# Cur diff delta = 1058.8253173828125
# Cur diff sigma = 0.004076800774782896
# Cur diff theta = 1058.8293941835873
# ---------------------------------------
# VB, d: 300, Iter: 1-3080, s/iter: 1.118e-01, ELBO: -7.903e+05
# Cur diff delta = 1045.7066650390625
# Cur diff sigma = 0.00407680869102478
# Cur diff theta = 1045.7107418477535
# ---------------------------------------
# VB, d: 300, Iter: 1-3100, s/iter: 1.127e-01, ELBO: -7.900e+05
# Cur diff delta = 1032.863037109375
# Cur diff sigma = 0.004076814278960228
# Cur diff theta = 1032.867113923654
# ---------------------------------------
# VB, d: 300, Iter: 1-3120, s/iter: 1.124e-01, ELBO: -7.898e+05
# Cur diff delta = 1020.2850952148438
# Cur diff sigma = 0.0040768105536699295
# Cur diff theta = 1020.2891720253974
# ---------------------------------------
# VB, d: 300, Iter: 1-3140, s/iter: 1.117e-01, ELBO: -7.895e+05
# Cur diff delta = 1007.964111328125
# Cur diff sigma = 0.004076823592185974
# Cur diff theta = 1007.9681881517172
# ---------------------------------------
# VB, d: 300, Iter: 1-3160, s/iter: 1.132e-01, ELBO: -7.892e+05
# Cur diff delta = 995.89501953125
# Cur diff sigma = 0.004076837562024593
# Cur diff theta = 995.899096368812
# ---------------------------------------
# VB, d: 300, Iter: 1-3180, s/iter: 1.129e-01, ELBO: -7.890e+05
# Cur diff delta = 984.0739135742188
# Cur diff sigma = 0.004076836630702019
# Cur diff theta = 984.0779904108495
# ---------------------------------------
# VB, d: 300, Iter: 1-3200, s/iter: 1.128e-01, ELBO: -7.887e+05
# Cur diff delta = 972.49609375
# Cur diff sigma = 0.004076811950653791
# Cur diff theta = 972.5001705619507
# ---------------------------------------
# VB, d: 300, Iter: 1-3220, s/iter: 1.121e-01, ELBO: -7.885e+05
# Cur diff delta = 961.1514892578125
# Cur diff sigma = 0.00407681567594409
# Cur diff theta = 961.1555660734884
# ---------------------------------------
# VB, d: 300, Iter: 1-3240, s/iter: 1.124e-01, ELBO: -7.882e+05
# Cur diff delta = 950.0338134765625
# Cur diff sigma = 0.004076834302395582
# Cur diff theta = 950.0378903108649
# ---------------------------------------
# VB, d: 300, Iter: 1-3260, s/iter: 1.116e-01, ELBO: -7.880e+05
# Cur diff delta = 939.1386108398438
# Cur diff sigma = 0.004076812881976366
# Cur diff theta = 939.1426876527257
# ---------------------------------------
# VB, d: 300, Iter: 1-3280, s/iter: 1.141e-01, ELBO: -7.878e+05
# Cur diff delta = 928.4640502929688
# Cur diff sigma = 0.004076809622347355
# Cur diff theta = 928.4681271025911
# ---------------------------------------
# VB, d: 300, Iter: 1-3300, s/iter: 1.120e-01, ELBO: -7.875e+05
# Cur diff delta = 918.002685546875
# Cur diff sigma = 0.004076818004250526
# Cur diff theta = 918.0067623648793
# ---------------------------------------
# VB, d: 300, Iter: 1-3320, s/iter: 1.122e-01, ELBO: -7.873e+05
# Cur diff delta = 907.749267578125
# Cur diff sigma = 0.004076821263879538
# Cur diff theta = 907.7533443993889
# ---------------------------------------
# VB, d: 300, Iter: 1-3340, s/iter: 1.110e-01, ELBO: -7.871e+05
# Cur diff delta = 897.69873046875
# Cur diff sigma = 0.004076830111443996
# Cur diff theta = 897.7028072988614
# ---------------------------------------
# VB, d: 300, Iter: 1-3360, s/iter: 1.112e-01, ELBO: -7.869e+05
# Cur diff delta = 887.8446044921875
# Cur diff sigma = 0.004076831508427858
# Cur diff theta = 887.8486813236959
# ---------------------------------------
# VB, d: 300, Iter: 1-3380, s/iter: 1.108e-01, ELBO: -7.867e+05
# Cur diff delta = 878.1815795898438
# Cur diff sigma = 0.004076830577105284
# Cur diff theta = 878.1856564204209
# ---------------------------------------
# VB, d: 300, Iter: 1-3400, s/iter: 1.115e-01, ELBO: -7.865e+05
# Cur diff delta = 868.7073974609375
# Cur diff sigma = 0.004076836630702019
# Cur diff theta = 868.7114742975682
# ---------------------------------------
# VB, d: 300, Iter: 1-3420, s/iter: 1.114e-01, ELBO: -7.863e+05
# Cur diff delta = 859.4169311523438
# Cur diff sigma = 0.004076842218637466
# Cur diff theta = 859.4210079945624
# ---------------------------------------
# VB, d: 300, Iter: 1-3440, s/iter: 1.112e-01, ELBO: -7.860e+05
# Cur diff delta = 850.3078002929688
# Cur diff sigma = 0.004076836165040731
# Cur diff theta = 850.3118771291338
# ---------------------------------------
# VB, d: 300, Iter: 1-3460, s/iter: 1.114e-01, ELBO: -7.859e+05
# Cur diff delta = 841.373046875
# Cur diff sigma = 0.00407682778313756
# Cur diff theta = 841.3771237027831
# ---------------------------------------
# VB, d: 300, Iter: 1-3480, s/iter: 1.117e-01, ELBO: -7.857e+05
# Cur diff delta = 832.6092529296875
# Cur diff sigma = 0.004076837096363306
# Cur diff theta = 832.6133297667839
# ---------------------------------------
# VB, d: 300, Iter: 1-3500, s/iter: 1.130e-01, ELBO: -7.855e+05
# Cur diff delta = 824.013916015625
# Cur diff sigma = 0.004076838493347168
# Cur diff theta = 824.0179928541183
# ---------------------------------------
# VB, d: 300, Iter: 1-3520, s/iter: 1.118e-01, ELBO: -7.853e+05
# Cur diff delta = 815.5819091796875
# Cur diff sigma = 0.004076838493347168
# Cur diff theta = 815.5859860181808
# ---------------------------------------
# VB, d: 300, Iter: 1-3540, s/iter: 1.129e-01, ELBO: -7.851e+05
# Cur diff delta = 807.3092651367188
# Cur diff sigma = 0.004076835699379444
# Cur diff theta = 807.3133419724181
# ---------------------------------------
# VB, d: 300, Iter: 1-3560, s/iter: 1.168e-01, ELBO: -7.849e+05
# Cur diff delta = 799.1920166015625
# Cur diff sigma = 0.0040768468752503395
# Cur diff theta = 799.1960934484378
# ---------------------------------------
# VB, d: 300, Iter: 1-3580, s/iter: 1.148e-01, ELBO: -7.847e+05
# Cur diff delta = 791.22412109375
# Cur diff sigma = 0.004076836165040731
# Cur diff theta = 791.228197929915
# ---------------------------------------
# VB, d: 300, Iter: 1-3600, s/iter: 1.159e-01, ELBO: -7.846e+05
# Cur diff delta = 783.4056396484375
# Cur diff sigma = 0.004076844081282616
# Cur diff theta = 783.4097164925188
# ---------------------------------------
# VB, d: 300, Iter: 1-3620, s/iter: 1.106e-01, ELBO: -7.844e+05
# Cur diff delta = 775.7340698242188
# Cur diff sigma = 0.004076831508427858
# Cur diff theta = 775.7381466557272
# ---------------------------------------
# VB, d: 300, Iter: 1-3640, s/iter: 1.106e-01, ELBO: -7.842e+05
# Cur diff delta = 768.2056274414062
# Cur diff sigma = 0.004076850134879351
# Cur diff theta = 768.2097042915411
# ---------------------------------------
# VB, d: 300, Iter: 1-3660, s/iter: 1.115e-01, ELBO: -7.841e+05
# Cur diff delta = 760.8157348632812
# Cur diff sigma = 0.004076849203556776
# Cur diff theta = 760.8198117124848
# ---------------------------------------
# VB, d: 300, Iter: 1-3680, s/iter: 1.106e-01, ELBO: -7.839e+05
# Cur diff delta = 753.56298828125
# Cur diff sigma = 0.004076839424669743
# Cur diff theta = 753.5670651206747
# ---------------------------------------
# VB, d: 300, Iter: 1-3700, s/iter: 1.122e-01, ELBO: -7.838e+05
# Cur diff delta = 746.4418334960938
# Cur diff sigma = 0.004076835699379444
# Cur diff theta = 746.4459103317931
# ---------------------------------------
# VB, d: 300, Iter: 1-3720, s/iter: 1.117e-01, ELBO: -7.836e+05
# Cur diff delta = 739.45068359375
# Cur diff sigma = 0.004076838493347168
# Cur diff theta = 739.4547604322433
# ---------------------------------------
# VB, d: 300, Iter: 1-3740, s/iter: 1.112e-01, ELBO: -7.834e+05
# Cur diff delta = 732.5860595703125
# Cur diff sigma = 0.004076849669218063
# Cur diff theta = 732.5901364199817
# ---------------------------------------
# VB, d: 300, Iter: 1-3760, s/iter: 1.113e-01, ELBO: -7.833e+05
# Cur diff delta = 725.8465576171875
# Cur diff sigma = 0.004076855722814798
# Cur diff theta = 725.8506344729103
# ---------------------------------------
# VB, d: 300, Iter: 1-3780, s/iter: 1.128e-01, ELBO: -7.831e+05
# Cur diff delta = 719.22900390625
# Cur diff sigma = 0.004076847340911627
# Cur diff theta = 719.2330807535909
# ---------------------------------------
# VB, d: 300, Iter: 1-3800, s/iter: 1.117e-01, ELBO: -7.830e+05
# Cur diff delta = 712.7299194335938
# Cur diff sigma = 0.00407685711979866
# Cur diff theta = 712.7339962907135
# ---------------------------------------
# VB, d: 300, Iter: 1-3820, s/iter: 1.124e-01, ELBO: -7.829e+05
# Cur diff delta = 706.3471069335938
# Cur diff sigma = 0.004076861310750246
# Cur diff theta = 706.3511837949045
# ---------------------------------------
# VB, d: 300, Iter: 1-3840, s/iter: 1.138e-01, ELBO: -7.827e+05
# Cur diff delta = 700.0779418945312
# Cur diff sigma = 0.004076882265508175
# Cur diff theta = 700.0820187767968
# ---------------------------------------
# VB, d: 300, Iter: 1-3860, s/iter: 1.122e-01, ELBO: -7.826e+05
# Cur diff delta = 693.917236328125
# Cur diff sigma = 0.004076870623975992
# Cur diff theta = 693.921313198749
# ---------------------------------------
# VB, d: 300, Iter: 1-3880, s/iter: 1.113e-01, ELBO: -7.824e+05
# Cur diff delta = 687.865478515625
# Cur diff sigma = 0.004076874349266291
# Cur diff theta = 687.8695553899743
# ---------------------------------------
# VB, d: 300, Iter: 1-3900, s/iter: 1.110e-01, ELBO: -7.823e+05
# Cur diff delta = 681.9202880859375
# Cur diff sigma = 0.004076856188476086
# Cur diff theta = 681.924364942126
# ---------------------------------------
# VB, d: 300, Iter: 1-3920, s/iter: 1.109e-01, ELBO: -7.822e+05
# Cur diff delta = 676.0789794921875
# Cur diff sigma = 0.004076875280588865
# Cur diff theta = 676.0830563674681
# ---------------------------------------
# VB, d: 300, Iter: 1-3940, s/iter: 1.115e-01, ELBO: -7.821e+05
# Cur diff delta = 670.3408813476562
# Cur diff sigma = 0.004076867364346981
# Cur diff theta = 670.3449582150206
# ---------------------------------------
# VB, d: 300, Iter: 1-3960, s/iter: 1.102e-01, ELBO: -7.819e+05
# Cur diff delta = 664.7042846679688
# Cur diff sigma = 0.004076862242072821
# Cur diff theta = 664.7083615302108
# ---------------------------------------
# VB, d: 300, Iter: 1-3980, s/iter: 1.108e-01, ELBO: -7.818e+05
# Cur diff delta = 659.1640625
# Cur diff sigma = 0.004076867364346981
# Cur diff theta = 659.1681393673643
# ---------------------------------------
# VB, d: 300, Iter: 1-4000, s/iter: 1.106e-01, ELBO: -7.817e+05
# Cur diff delta = 653.7200317382812
# Cur diff sigma = 0.004076877608895302
# Cur diff theta = 653.7241086158901
# ---------------------------------------
# ------------------------------------------------------
# Test = 1
# ------------------------------------------------------
# Init diff delta = 89999.0078125
# Init diff sigma = 116254.2890625
# Init diff theta = 206253.296875
# VB, d: 300, Iter: 2-20, s/iter: 1.111e-01, ELBO: -1.191e+07
# Cur diff delta = 82102.6953125
# Cur diff sigma = 82290.5078125
# Cur diff theta = 164393.203125
# ---------------------------------------
# VB, d: 300, Iter: 2-40, s/iter: 1.116e-01, ELBO: -1.105e+07
# Cur diff delta = 75507.9375
# Cur diff sigma = 65593.46875
# Cur diff theta = 141101.40625
# ---------------------------------------
# VB, d: 300, Iter: 2-60, s/iter: 1.119e-01, ELBO: -1.011e+07
# Cur diff delta = 69283.5234375
# Cur diff sigma = 54254.8046875
# Cur diff theta = 123538.328125
# ---------------------------------------
# VB, d: 300, Iter: 2-80, s/iter: 1.102e-01, ELBO: -9.017e+06
# Cur diff delta = 63472.71875
# Cur diff sigma = 44798.35546875
# Cur diff theta = 108271.07421875
# ...
# Cur diff theta = 1621.2995603673626
# ---------------------------------------
# VB, d: 300, Iter: 3-2560, s/iter: 1.114e-01, ELBO: -7.997e+05
# Cur diff delta = 1597.0594482421875
# Cur diff sigma = 0.003784033004194498
# Cur diff theta = 1597.0632322751917
# ---------------------------------------
# VB, d: 300, Iter: 3-2580, s/iter: 1.131e-01, ELBO: -7.992e+05
# Cur diff delta = 1573.380126953125
# Cur diff sigma = 0.0037840353325009346
# Cur diff theta = 1573.3839109884575
# ---------------------------------------
# VB, d: 300, Iter: 3-2600, s/iter: 1.129e-01, ELBO: -7.988e+05
# Cur diff delta = 1550.246337890625
# Cur diff sigma = 0.0037840690929442644
# Cur diff theta = 1550.250121959718
# ---------------------------------------
# VB, d: 300, Iter: 3-2620, s/iter: 1.116e-01, ELBO: -7.983e+05
# Cur diff delta = 1527.642822265625
# Cur diff sigma = 0.0037840690929442644
# Cur diff theta = 1527.646606334718
# ---------------------------------------
# VB, d: 300, Iter: 3-2640, s/iter: 1.115e-01, ELBO: -7.979e+05
# Cur diff delta = 1505.5546875
# Cur diff sigma = 0.0037841040175408125
# Cur diff theta = 1505.5584716040175
# ---------------------------------------
# VB, d: 300, Iter: 3-2660, s/iter: 1.118e-01, ELBO: -7.974e+05
# Cur diff delta = 1483.9637451171875
# Cur diff sigma = 0.0037841261364519596
# Cur diff theta = 1483.967529243324
# ---------------------------------------
# VB, d: 300, Iter: 3-2680, s/iter: 1.115e-01, ELBO: -7.970e+05
# Cur diff delta = 1462.85986328125
# Cur diff sigma = 0.0037841463927179575
# Cur diff theta = 1462.8636474276427
# ---------------------------------------
# VB, d: 300, Iter: 3-2700, s/iter: 1.118e-01, ELBO: -7.966e+05
# Cur diff delta = 1442.231201171875
# Cur diff sigma = 0.0037841503508388996
# Cur diff theta = 1442.2349853222258
# ---------------------------------------
# VB, d: 300, Iter: 3-2720, s/iter: 1.133e-01, ELBO: -7.962e+05
# Cur diff delta = 1422.0638427734375
# Cur diff sigma = 0.003784162225201726
# Cur diff theta = 1422.0676269356627
# ---------------------------------------
# VB, d: 300, Iter: 3-2740, s/iter: 1.135e-01, ELBO: -7.958e+05
# Cur diff delta = 1402.344970703125
# Cur diff sigma = 0.0037842090241611004
# Cur diff theta = 1402.3487549121492
# ---------------------------------------
# VB, d: 300, Iter: 3-2760, s/iter: 1.126e-01, ELBO: -7.954e+05
# Cur diff delta = 1383.057861328125
# Cur diff sigma = 0.003784241620451212
# Cur diff theta = 1383.0616455697455
# ---------------------------------------
# VB, d: 300, Iter: 3-2780, s/iter: 1.143e-01, ELBO: -7.950e+05
# Cur diff delta = 1364.1981201171875
# Cur diff sigma = 0.0037842560559511185
# Cur diff theta = 1364.2019043732435
# ---------------------------------------
# VB, d: 300, Iter: 3-2800, s/iter: 1.130e-01, ELBO: -7.946e+05
# Cur diff delta = 1345.75439453125
# Cur diff sigma = 0.0037842642050236464
# Cur diff theta = 1345.758178795455
# ---------------------------------------
# VB, d: 300, Iter: 3-2820, s/iter: 1.127e-01, ELBO: -7.942e+05
# Cur diff delta = 1327.7088623046875
# Cur diff sigma = 0.003784289350733161
# Cur diff theta = 1327.7126465940382
# ---------------------------------------
# VB, d: 300, Iter: 3-2840, s/iter: 1.145e-01, ELBO: -7.939e+05
# Cur diff delta = 1310.0557861328125
# Cur diff sigma = 0.003784304019063711
# Cur diff theta = 1310.0595704368316
# ---------------------------------------
# VB, d: 300, Iter: 3-2860, s/iter: 1.177e-01, ELBO: -7.935e+05
# Cur diff delta = 1292.7845458984375
# Cur diff sigma = 0.0037843321915715933
# Cur diff theta = 1292.788330230629
# ---------------------------------------
# VB, d: 300, Iter: 3-2880, s/iter: 1.170e-01, ELBO: -7.932e+05
# Cur diff delta = 1275.8846435546875
# Cur diff sigma = 0.0037843419704586267
# Cur diff theta = 1275.888427896658
# ---------------------------------------
# VB, d: 300, Iter: 3-2900, s/iter: 1.174e-01, ELBO: -7.928e+05
# Cur diff delta = 1259.3447265625
# Cur diff sigma = 0.003784346394240856
# Cur diff theta = 1259.3485109088942
# ---------------------------------------
# VB, d: 300, Iter: 3-2920, s/iter: 1.165e-01, ELBO: -7.925e+05
# Cur diff delta = 1243.1590576171875
# Cur diff sigma = 0.0037843508180230856
# Cur diff theta = 1243.1628419680055
# ---------------------------------------
# VB, d: 300, Iter: 3-2940, s/iter: 1.125e-01, ELBO: -7.922e+05
# Cur diff delta = 1227.3175048828125
# Cur diff sigma = 0.0037843745667487383
# Cur diff theta = 1227.3212892573792
# ---------------------------------------
# VB, d: 300, Iter: 3-2960, s/iter: 1.118e-01, ELBO: -7.919e+05
# Cur diff delta = 1211.810791015625
# Cur diff sigma = 0.0037843924947082996
# Cur diff theta = 1211.8145754081197
# ---------------------------------------
# VB, d: 300, Iter: 3-2980, s/iter: 1.113e-01, ELBO: -7.916e+05
# Cur diff delta = 1196.628662109375
# Cur diff sigma = 0.0037844162434339523
# Cur diff theta = 1196.6324465256184
# ---------------------------------------
# VB, d: 300, Iter: 3-3000, s/iter: 1.108e-01, ELBO: -7.913e+05
# Cur diff delta = 1181.763916015625
# Cur diff sigma = 0.0037844155449420214
# Cur diff theta = 1181.76770043117
# ---------------------------------------
# VB, d: 300, Iter: 3-3020, s/iter: 1.100e-01, ELBO: -7.910e+05
# Cur diff delta = 1167.209228515625
# Cur diff sigma = 0.0037844227626919746
# Cur diff theta = 1167.2130129383877
# ---------------------------------------
# VB, d: 300, Iter: 3-3040, s/iter: 1.115e-01, ELBO: -7.907e+05
# Cur diff delta = 1152.9564208984375
# Cur diff sigma = 0.0037844418548047543
# Cur diff theta = 1152.9602053402923
# ---------------------------------------
# VB, d: 300, Iter: 3-3060, s/iter: 1.126e-01, ELBO: -7.904e+05
# Cur diff delta = 1138.9971923828125
# Cur diff sigma = 0.0037844576872885227
# Cur diff theta = 1139.0009768404998
# ---------------------------------------
# VB, d: 300, Iter: 3-3080, s/iter: 1.116e-01, ELBO: -7.901e+05
# Cur diff delta = 1125.3248291015625
# Cur diff sigma = 0.003784461412578821
# Cur diff theta = 1125.328613562975
# ---------------------------------------
# VB, d: 300, Iter: 3-3100, s/iter: 1.125e-01, ELBO: -7.898e+05
# Cur diff delta = 1111.93505859375
# Cur diff sigma = 0.0037844800390303135
# Cur diff theta = 1111.938843073789
# ---------------------------------------
# VB, d: 300, Iter: 3-3120, s/iter: 1.110e-01, ELBO: -7.896e+05
# Cur diff delta = 1098.818603515625
# Cur diff sigma = 0.0037844849284738302
# Cur diff theta = 1098.8223880005535
# ---------------------------------------
# VB, d: 300, Iter: 3-3140, s/iter: 1.124e-01, ELBO: -7.893e+05
# Cur diff delta = 1085.9649658203125
# Cur diff sigma = 0.003784493077546358
# Cur diff theta = 1085.96875031339
# ---------------------------------------
# VB, d: 300, Iter: 3-3160, s/iter: 1.116e-01, ELBO: -7.890e+05
# Cur diff delta = 1073.3701171875
# Cur diff sigma = 0.003784502623602748
# Cur diff theta = 1073.3739016901236
# ---------------------------------------
# VB, d: 300, Iter: 3-3180, s/iter: 1.119e-01, ELBO: -7.888e+05
# Cur diff delta = 1061.029296875
# Cur diff sigma = 0.0037845305632799864
# Cur diff theta = 1061.0330814055633
# ---------------------------------------
# VB, d: 300, Iter: 3-3200, s/iter: 1.114e-01, ELBO: -7.885e+05
# Cur diff delta = 1048.935546875
# Cur diff sigma = 0.0037845305632799864
# Cur diff theta = 1048.9393314055633
# ---------------------------------------
# VB, d: 300, Iter: 3-3220, s/iter: 1.113e-01, ELBO: -7.883e+05
# Cur diff delta = 1037.084228515625
# Cur diff sigma = 0.003784540109336376
# Cur diff theta = 1037.0880130557343
# ---------------------------------------
# VB, d: 300, Iter: 3-3240, s/iter: 1.121e-01, ELBO: -7.880e+05
# Cur diff delta = 1025.46826171875
# Cur diff sigma = 0.0037845473270863295
# Cur diff theta = 1025.472046266077
# ---------------------------------------
# VB, d: 300, Iter: 3-3260, s/iter: 1.113e-01, ELBO: -7.878e+05
# Cur diff delta = 1014.0816040039062
# Cur diff sigma = 0.003784546162933111
# Cur diff theta = 1014.0853885500692
# ---------------------------------------
# VB, d: 300, Iter: 3-3280, s/iter: 1.115e-01, ELBO: -7.876e+05
# Cur diff delta = 1002.9214477539062
# Cur diff sigma = 0.0037845789920538664
# Cur diff theta = 1002.9252323328983
# ---------------------------------------
# VB, d: 300, Iter: 3-3300, s/iter: 1.120e-01, ELBO: -7.874e+05
# Cur diff delta = 991.9786987304688
# Cur diff sigma = 0.0037845841143280268
# Cur diff theta = 991.9824833145831
# ---------------------------------------
# VB, d: 300, Iter: 3-3320, s/iter: 1.126e-01, ELBO: -7.871e+05
# Cur diff delta = 981.2467651367188
# Cur diff sigma = 0.003784586675465107
# Cur diff theta = 981.2505497233942
# ---------------------------------------
# VB, d: 300, Iter: 3-3340, s/iter: 1.122e-01, ELBO: -7.869e+05
# Cur diff delta = 970.7251586914062
# Cur diff sigma = 0.0037845929618924856
# Cur diff theta = 970.7289432843681
# ---------------------------------------
# VB, d: 300, Iter: 3-3360, s/iter: 1.123e-01, ELBO: -7.867e+05
# Cur diff delta = 960.4080810546875
# Cur diff sigma = 0.00378461298532784
# Cur diff theta = 960.4118656676728
# ---------------------------------------
# VB, d: 300, Iter: 3-3380, s/iter: 1.108e-01, ELBO: -7.865e+05
# Cur diff delta = 950.2903442382812
# Cur diff sigma = 0.0037846199702471495
# Cur diff theta = 950.2941288582515
# ---------------------------------------
# VB, d: 300, Iter: 3-3400, s/iter: 1.112e-01, ELBO: -7.863e+05
# Cur diff delta = 940.3681640625
# Cur diff sigma = 0.003784626955166459
# Cur diff theta = 940.3719486894552
# ---------------------------------------
# VB, d: 300, Iter: 3-3420, s/iter: 1.115e-01, ELBO: -7.861e+05
# Cur diff delta = 930.6351928710938
# Cur diff sigma = 0.00378463719971478
# Cur diff theta = 930.6389775082935
# ---------------------------------------
# VB, d: 300, Iter: 3-3440, s/iter: 1.130e-01, ELBO: -7.859e+05
# Cur diff delta = 921.08544921875
# Cur diff sigma = 0.003784643020480871
# Cur diff theta = 921.0892338617705
# ---------------------------------------
# VB, d: 300, Iter: 3-3460, s/iter: 1.136e-01, ELBO: -7.857e+05
# Cur diff delta = 911.71728515625
# Cur diff sigma = 0.003784642554819584
# Cur diff theta = 911.7210697988048
# ---------------------------------------
# VB, d: 300, Iter: 3-3480, s/iter: 1.125e-01, ELBO: -7.855e+05
# Cur diff delta = 902.52685546875
# Cur diff sigma = 0.0037846639752388
# Cur diff theta = 902.5306401327252
# ---------------------------------------
# VB, d: 300, Iter: 3-3500, s/iter: 1.123e-01, ELBO: -7.853e+05
# Cur diff delta = 893.5108032226562
# Cur diff sigma = 0.003784674685448408
# Cur diff theta = 893.5145878973417
# ---------------------------------------
# VB, d: 300, Iter: 3-3520, s/iter: 1.127e-01, ELBO: -7.851e+05
# Cur diff delta = 884.6650390625
# Cur diff sigma = 0.0037846784107387066
# Cur diff theta = 884.6688237409107
# ---------------------------------------
# VB, d: 300, Iter: 3-3540, s/iter: 1.112e-01, ELBO: -7.849e+05
# Cur diff delta = 875.9844970703125
# Cur diff sigma = 0.003784690285101533
# Cur diff theta = 875.9882817605976
# ---------------------------------------
# VB, d: 300, Iter: 3-3560, s/iter: 1.110e-01, ELBO: -7.848e+05
# Cur diff delta = 867.4649658203125
# Cur diff sigma = 0.0037846833001822233
# Cur diff theta = 867.4687505036127
# ---------------------------------------
# VB, d: 300, Iter: 3-3580, s/iter: 1.116e-01, ELBO: -7.846e+05
# Cur diff delta = 859.100341796875
# Cur diff sigma = 0.0037846954073756933
# Cur diff theta = 859.1041264922824
# ---------------------------------------
# VB, d: 300, Iter: 3-3600, s/iter: 1.110e-01, ELBO: -7.844e+05
# Cur diff delta = 850.890380859375
# Cur diff sigma = 0.0037847021594643593
# Cur diff theta = 850.8941655615345
# ---------------------------------------
# VB, d: 300, Iter: 3-3620, s/iter: 1.129e-01, ELBO: -7.843e+05
# Cur diff delta = 842.8328247070312
# Cur diff sigma = 0.0037847098428756
# Cur diff theta = 842.8366094168741
# ---------------------------------------
# VB, d: 300, Iter: 3-3640, s/iter: 1.122e-01, ELBO: -7.841e+05
# Cur diff delta = 834.9237060546875
# Cur diff sigma = 0.0037847082130610943
# Cur diff theta = 834.9274907629006
# ---------------------------------------
# VB, d: 300, Iter: 3-3660, s/iter: 1.124e-01, ELBO: -7.839e+05
# Cur diff delta = 827.1596069335938
# Cur diff sigma = 0.0037847261410206556
# Cur diff theta = 827.1633916597348
# ---------------------------------------
# VB, d: 300, Iter: 3-3680, s/iter: 1.125e-01, ELBO: -7.838e+05
# Cur diff delta = 819.5372924804688
# Cur diff sigma = 0.0037847210187464952
# Cur diff theta = 819.5410772014875
# ---------------------------------------
# VB, d: 300, Iter: 3-3700, s/iter: 1.139e-01, ELBO: -7.836e+05
# Cur diff delta = 812.05419921875
# Cur diff sigma = 0.003784726606681943
# Cur diff theta = 812.0579839453567
# ---------------------------------------
# VB, d: 300, Iter: 3-3720, s/iter: 1.139e-01, ELBO: -7.835e+05
# Cur diff delta = 804.7071533203125
# Cur diff sigma = 0.003784727770835161
# Cur diff theta = 804.7109380480833
# ---------------------------------------
# VB, d: 300, Iter: 3-3740, s/iter: 1.145e-01, ELBO: -7.833e+05
# Cur diff delta = 797.4910888671875
# Cur diff sigma = 0.003784723347052932
# Cur diff theta = 797.4948735905346
# ---------------------------------------
# VB, d: 300, Iter: 3-3760, s/iter: 1.150e-01, ELBO: -7.832e+05
# Cur diff delta = 790.4044189453125
# Cur diff sigma = 0.003784739412367344
# Cur diff theta = 790.4082036847249
# ---------------------------------------
# VB, d: 300, Iter: 3-3780, s/iter: 1.123e-01, ELBO: -7.830e+05
# Cur diff delta = 783.4432983398438
# Cur diff sigma = 0.0037847335916012526
# Cur diff theta = 783.4470830734354
# ---------------------------------------
# VB, d: 300, Iter: 3-3800, s/iter: 1.121e-01, ELBO: -7.829e+05
# Cur diff delta = 776.6061401367188
# Cur diff sigma = 0.0037847517523914576
# Cur diff theta = 776.6099248884711
# ---------------------------------------
# VB, d: 300, Iter: 3-3820, s/iter: 1.118e-01, ELBO: -7.827e+05
# Cur diff delta = 769.890380859375
# Cur diff sigma = 0.003784753615036607
# Cur diff theta = 769.89416561299
# ---------------------------------------
# VB, d: 300, Iter: 3-3840, s/iter: 1.136e-01, ELBO: -7.826e+05
# Cur diff delta = 763.2946166992188
# Cur diff sigma = 0.003784754779189825
# Cur diff theta = 763.2984014539979
# ---------------------------------------
# VB, d: 300, Iter: 3-3860, s/iter: 1.138e-01, ELBO: -7.825e+05
# Cur diff delta = 756.8147583007812
# Cur diff sigma = 0.003784753615036607
# Cur diff theta = 756.8185430543963
# ---------------------------------------
# VB, d: 300, Iter: 3-3880, s/iter: 1.129e-01, ELBO: -7.823e+05
# Cur diff delta = 750.4488525390625
# Cur diff sigma = 0.0037847638595849276
# Cur diff theta = 750.4526373029221
# ---------------------------------------
# VB, d: 300, Iter: 3-3900, s/iter: 1.125e-01, ELBO: -7.822e+05
# Cur diff delta = 744.1942749023438
# Cur diff sigma = 0.0037847617641091347
# Cur diff theta = 744.1980596641079
# ---------------------------------------
# VB, d: 300, Iter: 3-3920, s/iter: 1.122e-01, ELBO: -7.821e+05
# Cur diff delta = 738.047119140625
# Cur diff sigma = 0.003784775733947754
# Cur diff theta = 738.050903916359
# ---------------------------------------
# VB, d: 300, Iter: 3-3940, s/iter: 1.137e-01, ELBO: -7.819e+05
# Cur diff delta = 732.0079956054688
# Cur diff sigma = 0.003784778993576765
# Cur diff theta = 732.0117803844623
# ---------------------------------------
# VB, d: 300, Iter: 3-3960, s/iter: 1.127e-01, ELBO: -7.818e+05
# Cur diff delta = 726.0753173828125
# Cur diff sigma = 0.0037847666535526514
# Cur diff theta = 726.079102149466
# ---------------------------------------
# VB, d: 300, Iter: 3-3980, s/iter: 1.139e-01, ELBO: -7.817e+05
# Cur diff delta = 720.2463989257812
# Cur diff sigma = 0.0037847820203751326
# Cur diff theta = 720.2501837078016
# ---------------------------------------
# VB, d: 300, Iter: 3-4000, s/iter: 1.118e-01, ELBO: -7.816e+05
# Cur diff delta = 714.5173950195312
# Cur diff sigma = 0.003784787841141224
# Cur diff theta = 714.5211798073724
# ---------------------------------------
# Model VB, test = 0, result delta diff = 653.7200927734375
# Model VB, test = 0, result sigma diff = 0.004076874814927578
# Model VB, test = 0, result theta diff = 653.7241821289062
# Model VB, test = 1, result delta diff = 671.3016357421875
# Model VB, test = 1, result sigma diff = 0.0038490486331284046
# Model VB, test = 1, result theta diff = 671.3054809570312
# Model VB, test = 2, result delta diff = 714.5173950195312
# Model VB, test = 2, result sigma diff = 0.003784788306802511
# Model VB, test = 2, result theta diff = 714.5211791992188

# %%
model_names = ['HVAE_1', 'HVAE_2', 'NF_1', 'NF_2', 'VB']
diff_delta_results = {}
diff_sigma_results = {}
diff_results = {}
for name in model_names:
    diff_delta_tests = np.zeros(params['n_tests'])
    diff_sigma_tests = np.zeros(params['n_tests'])
    diff_tests = np.zeros(params['n_tests'])
    for i in range(params['n_tests']):
        file_name = name + '_train_' + str(i) + '.p'
        diff_path = os.path.join('save', str(params['dims'][0]), file_name)
        with open(diff_path, 'rb') as f:
            data = pickle.load(f)
            elbo = data['elbo']
            diff_delta = data['diff_delta']
            diff_sigma = data['diff_sigma']
            diff = diff_delta + diff_sigma
            diff_delta_is_not_nan = diff_delta[~np.isnan(diff_delta)]
            diff_sigma_is_not_nan = diff_sigma[~np.isnan(diff_sigma)]
            diff_is_not_nan = diff[~np.isnan(diff)]
            diff_delta_tests[i] = diff_delta_is_not_nan[-1]
            diff_sigma_tests[i] = diff_sigma_is_not_nan[-1]
            diff_tests[i] = diff_is_not_nan[-1]
    diff_delta_results[name] = diff_delta_tests
    diff_sigma_results[name] = diff_sigma_tests
    diff_results[name] = diff_tests
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, diff delta = {diff_delta_tests}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, diff sigma = {diff_sigma_tests}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, diff = {diff_tests}")
# Out:
# Model = HVAE_1, dimensionality = 300, diff delta = [296.24130249 356.59918213 339.47210693]
# Model = HVAE_1, dimensionality = 300, diff sigma = [0.49654326 0.50636309 0.49851337]
# Model = HVAE_1, dimensionality = 300, diff = [296.737854   357.1055603  339.97061157]
# Model = HVAE_2, dimensionality = 300, diff delta = [296.96273804 356.70812988 340.1567688 ]
# Model = HVAE_2, dimensionality = 300, diff sigma = [0.44739103 0.45670336 0.44657421]
# Model = HVAE_2, dimensionality = 300, diff = [297.41012573 357.16482544 340.60333252]
# Model = NF_1, dimensionality = 300, diff delta = [309.61495972 356.4604187  339.98864746]
# Model = NF_1, dimensionality = 300, diff sigma = [289.18704224 188.66868591 190.65641785]
# Model = NF_1, dimensionality = 300, diff = [598.80200195 545.12908936 530.64508057]
# Model = NF_2, dimensionality = 300, diff delta = [296.52960205 357.2565918  340.48098755]
# Model = NF_2, dimensionality = 300, diff sigma = [188.46731567 189.06533813 189.07955933]
# Model = NF_2, dimensionality = 300, diff = [484.99691772 546.32189941 529.56054688]
# Model = VB, dimensionality = 300, diff delta = [653.72003174 671.30175781 714.51739502]
# Model = VB, dimensionality = 300, diff sigma = [0.00407688 0.00384905 0.00378479]
# Model = VB, dimensionality = 300, diff = [653.72412109 671.30560303 714.5211792 ]

# %%
def run_test(d, params, 
             batch_size=256,
             clip_value=None,
             dtype=torch.float32, 
             device=torch.device("cpu")):
    """ 
    Run the gaussian test with dimension d 
    """

    ######### Problem Specification

    # Data generation parameters
    prior_mu_z = torch.zeros(d, dtype=dtype)    # Prior mean
    prior_sigma_z = torch.eye(d, dtype=dtype)   # Prior covariance matrix

    # True model parameters
    num_range = torch.arange(-(d-1)/2, (d+1)/2, dtype=dtype)

    t_delta =  num_range / 5 

    print(f"true delta = {t_delta.numpy()}")

    if d == 1:
        t_sigma = torch.ones(1, dtype=dtype)
    else: 
        # Allow sigma to range from 0.1 to 1
        t_sigma = 36/(10*(d-1)**2) * num_range**2 + 0.1 
    print(f"true sigma = {t_sigma.numpy()}")

    ######### Variable Initialization

    # Initial model parameters - same across all methods
    init_delta = prior_mu_z.clone().to(device)
    init_log_sigma = 3 * torch.ones(d).to(device)

    # Initial HVAE variational parameters
    init_T = torch.tensor(5., dtype=dtype, device=device)
    init_eps = 0.005 * torch.ones(d, dtype=dtype)
    max_eps = params['max_eps'] * torch.ones(d, dtype=dtype)
    init_logit_eps = torch.log(init_eps/(max_eps - init_eps)).to(device)
    init_log_T_0 = torch.log(init_T - 1)

    # Initial NF variational parameters
    init_u_pre_reparam = torch.tensor(scipy.stats.truncnorm.rvs(-2, 2, 
                                                                scale=0.1, 
                                                                size=d),
                                      dtype=dtype, device=device)
    init_w = torch.tensor(scipy.stats.truncnorm.rvs(-2, 2, scale=0.1, size=d),
                          dtype=dtype, device=device)
    init_b = torch.tensor(0.1, dtype=dtype, device=device)

    # Initial VAE parameters
    init_mu_z = prior_mu_z.clone()
    init_log_sigma_z = torch.ones(d, dtype=dtype)

    ######### Set up models
    init_params = [[init_delta, init_log_sigma, init_logit_eps],
                   [init_delta, init_log_sigma, init_logit_eps]]
    
    HVAE_model_notemp_1 = HVAE(params,
        ['delta', 'log_sigma', 'logit_eps'],
        init_params[0], 
        'HVAE_notemp_1', d, params['HVAE_K_1'])
    HVAE_model_notemp_2 = HVAE(params,
        ['delta', 'log_sigma', 'logit_eps'], 
        init_params[1],
        'HVAE_notemp_2', d, params['HVAE_K_2'])

    #model_list = [HVAE_model_1, HVAE_model_2, NF_model_1]
    #model_list = [HVAE_model_1, NF_model_1]
    model_list = [HVAE_model_notemp_1, HVAE_model_notemp_2]

    print("Models were initialized!")
    
    ######### Generate Training Data & Save - One for each test

    train_data_list = []

    for i in range(params['n_tests']):
        z = MultivariateNormal(prior_mu_z, prior_sigma_z).sample()
        x = MultivariateNormal(z + t_delta, 
                               torch.diag(t_sigma**2)).sample([params['n_data']])
        x = x.to(device)
        train_data_list.append(x)

    # Folder should have already been created in the initializations
    data_path = os.path.join('save', str(d), 'train_data.p')
    pickle.dump(train_data_list, open(data_path, 'wb')) 

    # Store the final parameter values for all test runs in this dictionary
    final_params = {}

    for i in range(len(model_list)):
        final_values = []
        m = model_list[i]
        model_init_params = init_params[i]

        for j in range(params['n_tests']):
            print("------------------------------------------------------")
            print(f"Test = {j}")
            print("------------------------------------------------------")
            m._reinitialize(model_init_params)
            gaussian_data = gaussian_dataset(train_data_list[j])
            train_dataloader = DataLoader(gaussian_data, batch_size=batch_size,
                                          shuffle=False, num_workers=0)
            (delta, sigma) = m.train(train_dataloader, j, 
                                     t_delta, t_sigma,
                                     clip_value)
            final_values.append((delta, sigma))

        final_params[m.model_name] = final_values.copy()

    ######### Test models using difference between parameters

    param_diffs = {}

    for m in model_list:
        
        diffs = []

        for i in range(params['n_tests']):
            delta = final_params[m.model_name][i][0]
            sigma = final_params[m.model_name][i][1]

            delta_diff = np.sum((delta - t_delta.numpy())**2)
            sigma_diff = np.sum((sigma - t_sigma.numpy())**2)
            theta_diff = delta_diff + sigma_diff
            print(f"Model {m.model_name}, test = {i}, result delta diff = {delta_diff}")
            print(f"Model {m.model_name}, test = {i}, result sigma diff = {sigma_diff}")
            print(f"Model {m.model_name}, test = {i}, result theta diff = {theta_diff}")

            diffs.append((delta_diff, sigma_diff, theta_diff))

        param_diffs[m.model_name] = diffs.copy()

    # Save parameter differences in a pickle file
    diff_path = os.path.join('save', str(d), 'all_diffs.p')
    pickle.dump(param_diffs, open(diff_path, 'wb'))

# %%
params = {

    # PROBLEM SPECIFICATION
    #'dims': [1, 2, 3, 5, 11, 25, 51, 101, 201, 301], # Dimensions to test
    'dims': [300],
    'n_data': 10000,                                 # Number of data points

    # TEST HYPERPARAMETERS
    'n_tests': 3,      # Number of experiments to run

    # GLOBAL OPTIMIZATION PARAMETERS
    'n_iter': 2000,    # Number of optimization iterations
    'n_batch': 10,      # Number of points for ELBO estimate
    'rms_eta': 0.001,   # Stepsize for RMSProp
    'save_every': 20,   # Save parameter information every so often
    'print_every': 20, # Print less often than save

    # HVAE HYPERPARAMETERS
    'HVAE_K_1': 1,    # Number of leapfrog/cooling steps for HVAE flow 1
    'HVAE_K_2': 10,   # Number of leapfrog/cooling steps for HVAE flow 2
    'max_eps': 0.5,   # Maximum leapfrog step size per dimension 

    # NF HYPERPARAMETERS
    'NF_K_1': 1,    # Number of flow steps for NF flow 1
    'NF_K_2': 30,   # Number of flow steps for NF flow 2
    
}

# %%
device = torch.device("cuda")
dtype = torch.float32
clip_value = None
batch_size = 256

# %%
dims = params['dims']
seed = 12345
np.random.seed(seed)
torch.manual_seed(seed)
for d in dims:
    print('**** Running test for d={0:d} ****'.format(d))
    run_test(d, params, batch_size, clip_value, dtype, device)
# Out:
# **** Running test for d=300 ****
# true delta = [-29.9 -29.7 -29.5 -29.3 -29.1 -28.9 -28.7 -28.5 -28.3 -28.1 -27.9 -27.7
#  -27.5 -27.3 -27.1 -26.9 -26.7 -26.5 -26.3 -26.1 -25.9 -25.7 -25.5 -25.3
#  -25.1 -24.9 -24.7 -24.5 -24.3 -24.1 -23.9 -23.7 -23.5 -23.3 -23.1 -22.9
#  -22.7 -22.5 -22.3 -22.1 -21.9 -21.7 -21.5 -21.3 -21.1 -20.9 -20.7 -20.5
#  -20.3 -20.1 -19.9 -19.7 -19.5 -19.3 -19.1 -18.9 -18.7 -18.5 -18.3 -18.1
#  -17.9 -17.7 -17.5 -17.3 -17.1 -16.9 -16.7 -16.5 -16.3 -16.1 -15.9 -15.7
#  -15.5 -15.3 -15.1 -14.9 -14.7 -14.5 -14.3 -14.1 -13.9 -13.7 -13.5 -13.3
#  -13.1 -12.9 -12.7 -12.5 -12.3 -12.1 -11.9 -11.7 -11.5 -11.3 -11.1 -10.9
#  -10.7 -10.5 -10.3 -10.1  -9.9  -9.7  -9.5  -9.3  -9.1  -8.9  -8.7  -8.5
#   -8.3  -8.1  -7.9  -7.7  -7.5  -7.3  -7.1  -6.9  -6.7  -6.5  -6.3  -6.1
#   -5.9  -5.7  -5.5  -5.3  -5.1  -4.9  -4.7  -4.5  -4.3  -4.1  -3.9  -3.7
#   -3.5  -3.3  -3.1  -2.9  -2.7  -2.5  -2.3  -2.1  -1.9  -1.7  -1.5  -1.3
#   -1.1  -0.9  -0.7  -0.5  -0.3  -0.1   0.1   0.3   0.5   0.7   0.9   1.1
#    1.3   1.5   1.7   1.9   2.1   2.3   2.5   2.7   2.9   3.1   3.3   3.5
#    3.7   3.9   4.1   4.3   4.5   4.7   4.9   5.1   5.3   5.5   5.7   5.9
#    6.1   6.3   6.5   6.7   6.9   7.1   7.3   7.5   7.7   7.9   8.1   8.3
#    8.5   8.7   8.9   9.1   9.3   9.5   9.7   9.9  10.1  10.3  10.5  10.7
#   10.9  11.1  11.3  11.5  11.7  11.9  12.1  12.3  12.5  12.7  12.9  13.1
#   13.3  13.5  13.7  13.9  14.1  14.3  14.5  14.7  14.9  15.1  15.3  15.5
#   15.7  15.9  16.1  16.3  16.5  16.7  16.9  17.1  17.3  17.5  17.7  17.9
#   18.1  18.3  18.5  18.7  18.9  19.1  19.3  19.5  19.7  19.9  20.1  20.3
#   20.5  20.7  20.9  21.1  21.3  21.5  21.7  21.9  22.1  22.3  22.5  22.7
#   22.9  23.1  23.3  23.5  23.7  23.9  24.1  24.3  24.5  24.7  24.9  25.1
#   25.3  25.5  25.7  25.9  26.1  26.3  26.5  26.7  26.9  27.1  27.3  27.5
#   27.7  27.9  28.1  28.3  28.5  28.7  28.9  29.1  29.3  29.5  29.7  29.9]
# true sigma = [1.         0.98800015 0.97608083 0.96424204 0.9524838  0.94080603
#  0.9292089  0.9176922  0.9062561  0.8949005  0.88362545 0.872431
#  0.861317   0.85028356 0.8393307  0.8284583  0.8176665  0.8069552
#  0.79632443 0.78577423 0.77530456 0.7649154  0.7546068  0.7443787
#  0.7342312  0.7241642  0.7141777  0.7042718  0.6944464  0.6847015
#  0.6750372  0.66545343 0.6559502  0.64652747 0.6371853  0.62792367
#  0.6187425  0.60964197 0.60062194 0.59168243 0.58282346 0.57404506
#  0.56534714 0.5567298  0.548193   0.5397367  0.5313609  0.52306575
#  0.5148511  0.5067169  0.4986633  0.49069026 0.4827977  0.47498572
#  0.46725428 0.45960334 0.45203295 0.44454312 0.4371338  0.429805
#  0.4225568  0.4153891  0.40830192 0.40129527 0.39436918 0.38752362
#  0.38075858 0.3740741  0.36747015 0.36094674 0.35450384 0.34814152
#  0.3418597  0.33565843 0.3295377  0.3234975  0.31753784 0.3116587
#  0.3058601  0.30014205 0.29450452 0.28894755 0.2834711  0.2780752
#  0.27275982 0.26752496 0.26237068 0.2572969  0.25230366 0.24739096
#  0.2425588  0.23780718 0.23313609 0.22854555 0.22403553 0.21960604
#  0.21525711 0.2109887  0.20680082 0.20269349 0.19866669 0.19472042
#  0.1908547  0.1870695  0.18336484 0.17974073 0.17619714 0.17273408
#  0.16935158 0.1660496  0.16282815 0.15968725 0.15662688 0.15364705
#  0.15074775 0.147929   0.14519078 0.14253308 0.13995594 0.13745931
#  0.13504323 0.13270769 0.13045268 0.12827821 0.12618427 0.12417087
#  0.12223801 0.12038568 0.11861388 0.11692263 0.11531191 0.11378173
#  0.11233208 0.11096296 0.10967439 0.10846635 0.10733885 0.10629188
#  0.10532545 0.10443955 0.10363419 0.10290936 0.10226507 0.10170133
#  0.10121811 0.10081543 0.10049328 0.10025167 0.10009061 0.10001007
#  0.10001007 0.10009061 0.10025167 0.10049328 0.10081543 0.10121811
#  0.10170133 0.10226507 0.10290936 0.10363419 0.10443955 0.10532545
#  0.10629188 0.10733885 0.10846635 0.10967439 0.11096296 0.11233208
#  0.11378173 0.11531191 0.11692263 0.11861388 0.12038568 0.12223801
#  0.12417087 0.12618427 0.12827821 0.13045268 0.13270769 0.13504323
#  0.13745931 0.13995594 0.14253308 0.14519078 0.147929   0.15074775
#  0.15364705 0.15662688 0.15968725 0.16282815 0.1660496  0.16935158
#  0.17273408 0.17619714 0.17974073 0.18336484 0.1870695  0.1908547
#  0.19472042 0.19866669 0.20269349 0.20680082 0.2109887  0.21525711
#  0.21960604 0.22403553 0.22854555 0.23313609 0.23780718 0.2425588
#  0.24739096 0.25230366 0.2572969  0.26237068 0.26752496 0.27275982
#  0.2780752  0.2834711  0.28894755 0.29450452 0.30014205 0.3058601
#  0.3116587  0.31753784 0.3234975  0.3295377  0.33565843 0.3418597
#  0.34814152 0.35450384 0.36094674 0.36747015 0.3740741  0.38075858
#  0.38752362 0.39436918 0.40129527 0.40830192 0.4153891  0.4225568
#  0.429805   0.4371338  0.44454312 0.45203295 0.45960334 0.46725428
#  0.47498572 0.4827977  0.49069026 0.4986633  0.5067169  0.5148511
#  0.52306575 0.5313609  0.5397367  0.548193   0.5567298  0.56534714
#  0.57404506 0.58282346 0.59168243 0.60062194 0.60964197 0.6187425
#  0.62792367 0.6371853  0.64652747 0.6559502  0.66545343 0.6750372
#  0.6847015  0.6944464  0.7042718  0.7141777  0.7241642  0.7342312
#  0.7443787  0.7546068  0.7649154  0.77530456 0.78577423 0.79632443
#  0.8069552  0.8176665  0.8284583  0.8393307  0.85028356 0.861317
#  0.872431   0.88362545 0.8949005  0.9062561  0.9176922  0.9292089
#  0.94080603 0.9524838  0.96424204 0.97608083 0.98800015 1.        ]
# Models were initialized!
# ------------------------------------------------------
# Test = 0
# ------------------------------------------------------
# Init diff delta = 89999.0078125
# Init diff sigma = 116254.2890625
# Init diff theta = 206253.296875
# HVAE_notemp_1, d: 300, Iter: 1-20, s/iter: 1.641e-01, ELBO: -1.188e+07
# Cur diff delta = 81978.421875
# Cur diff sigma = 82879.734375
# Cur diff theta = 164858.15625
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-40, s/iter: 1.637e-01, ELBO: -1.131e+07
# Cur diff delta = 75416.4296875
# Cur diff sigma = 72595.75
# Cur diff theta = 148012.1796875
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-60, s/iter: 1.628e-01, ELBO: -1.085e+07
# Cur diff delta = 69255.7890625
# Cur diff sigma = 66149.75
# Cur diff theta = 135405.5390625
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-80, s/iter: 1.653e-01, ELBO: -1.050e+07
# Cur diff delta = 63447.07421875
# Cur diff sigma = 60409.1796875
# Cur diff theta = 123856.25390625
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-100, s/iter: 1.629e-01, ELBO: -9.967e+06
# Cur diff delta = 57972.3203125
# Cur diff sigma = 55026.60546875
# Cur diff theta = 112998.92578125
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-120, s/iter: 1.641e-01, ELBO: -9.600e+06
# Cur diff delta = 52820.91796875
# Cur diff sigma = 49908.1015625
# Cur diff theta = 102729.01953125
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-140, s/iter: 1.628e-01, ELBO: -9.274e+06
# Cur diff delta = 47978.78515625
# Cur diff sigma = 44849.65625
# Cur diff theta = 92828.44140625
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-160, s/iter: 1.632e-01, ELBO: -8.917e+06
# Cur diff delta = 43441.765625
# Cur diff sigma = 40097.36328125
# Cur diff theta = 83539.12890625
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-180, s/iter: 1.642e-01, ELBO: -8.594e+06
# Cur diff delta = 39203.875
# Cur diff sigma = 35566.07421875
# Cur diff theta = 74769.94921875
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-200, s/iter: 1.643e-01, ELBO: -8.307e+06
# Cur diff delta = 35254.15234375
# Cur diff sigma = 31424.623046875
# Cur diff theta = 66678.775390625
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-220, s/iter: 1.618e-01, ELBO: -8.018e+06
# Cur diff delta = 31572.69140625
# Cur diff sigma = 27337.380859375
# Cur diff theta = 58910.072265625
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-240, s/iter: 1.639e-01, ELBO: -7.718e+06
# Cur diff delta = 28154.845703125
# Cur diff sigma = 23554.88671875
# Cur diff theta = 51709.732421875
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-260, s/iter: 1.674e-01, ELBO: -7.429e+06
# Cur diff delta = 24996.05078125
# Cur diff sigma = 20096.19921875
# Cur diff theta = 45092.25
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-280, s/iter: 1.688e-01, ELBO: -7.130e+06
# Cur diff delta = 22089.181640625
# Cur diff sigma = 17001.091796875
# Cur diff theta = 39090.2734375
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-300, s/iter: 1.688e-01, ELBO: -6.870e+06
# Cur diff delta = 19422.099609375
# Cur diff sigma = 14377.1533203125
# Cur diff theta = 33799.2529296875
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-320, s/iter: 1.632e-01, ELBO: -6.622e+06
# Cur diff delta = 16977.435546875
# Cur diff sigma = 11866.8115234375
# Cur diff theta = 28844.2470703125
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-340, s/iter: 1.639e-01, ELBO: -6.370e+06
# Cur diff delta = 14745.3359375
# Cur diff sigma = 9635.7236328125
# Cur diff theta = 24381.0595703125
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-360, s/iter: 1.643e-01, ELBO: -6.129e+06
# Cur diff delta = 12720.5009765625
# Cur diff sigma = 7823.0458984375
# Cur diff theta = 20543.546875
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-380, s/iter: 1.626e-01, ELBO: -5.912e+06
# Cur diff delta = 10894.2314453125
# Cur diff sigma = 6226.2060546875
# Cur diff theta = 17120.4375
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-400, s/iter: 1.635e-01, ELBO: -5.693e+06
# Cur diff delta = 9254.0732421875
# Cur diff sigma = 4809.4375
# Cur diff theta = 14063.5107421875
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-420, s/iter: 1.641e-01, ELBO: -5.457e+06
# Cur diff delta = 7793.6689453125
# Cur diff sigma = 3673.788330078125
# Cur diff theta = 11467.457275390625
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-440, s/iter: 1.635e-01, ELBO: -5.251e+06
# Cur diff delta = 6504.61669921875
# Cur diff sigma = 2924.120849609375
# Cur diff theta = 9428.737548828125
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-460, s/iter: 1.616e-01, ELBO: -5.043e+06
# Cur diff delta = 5369.75244140625
# Cur diff sigma = 2135.97705078125
# Cur diff theta = 7505.7294921875
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-480, s/iter: 1.630e-01, ELBO: -4.869e+06
# Cur diff delta = 4385.63916015625
# Cur diff sigma = 1763.78564453125
# Cur diff theta = 6149.4248046875
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-500, s/iter: 1.635e-01, ELBO: -4.711e+06
# Cur diff delta = 3537.78466796875
# Cur diff sigma = 1521.2562255859375
# Cur diff theta = 5059.0408935546875
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-520, s/iter: 1.620e-01, ELBO: -4.564e+06
# Cur diff delta = 2814.22314453125
# Cur diff sigma = 1261.682861328125
# Cur diff theta = 4075.906005859375
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-540, s/iter: 1.627e-01, ELBO: -4.443e+06
# Cur diff delta = 2208.734375
# Cur diff sigma = 1080.621337890625
# Cur diff theta = 3289.355712890625
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-560, s/iter: 1.652e-01, ELBO: -4.321e+06
# Cur diff delta = 1705.423095703125
# Cur diff sigma = 923.5113525390625
# Cur diff theta = 2628.9344482421875
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-580, s/iter: 1.629e-01, ELBO: -4.191e+06
# Cur diff delta = 1296.27587890625
# Cur diff sigma = 807.66259765625
# Cur diff theta = 2103.9384765625
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-600, s/iter: 1.625e-01, ELBO: -4.089e+06
# Cur diff delta = 973.5396118164062
# Cur diff sigma = 699.9132080078125
# Cur diff theta = 1673.4528198242188
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-620, s/iter: 1.620e-01, ELBO: -4.012e+06
# Cur diff delta = 726.7747802734375
# Cur diff sigma = 598.1857299804688
# Cur diff theta = 1324.9605102539062
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-640, s/iter: 1.614e-01, ELBO: -3.927e+06
# Cur diff delta = 543.781494140625
# Cur diff sigma = 499.3333740234375
# Cur diff theta = 1043.1148681640625
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-660, s/iter: 1.617e-01, ELBO: -3.851e+06
# Cur diff delta = 420.9835205078125
# Cur diff sigma = 406.87353515625
# Cur diff theta = 827.8570556640625
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-680, s/iter: 1.631e-01, ELBO: -3.785e+06
# Cur diff delta = 345.8658752441406
# Cur diff sigma = 325.4797058105469
# Cur diff theta = 671.3455810546875
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-700, s/iter: 1.615e-01, ELBO: -3.723e+06
# Cur diff delta = 304.1029968261719
# Cur diff sigma = 256.2825012207031
# Cur diff theta = 560.385498046875
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-720, s/iter: 1.620e-01, ELBO: -3.664e+06
# Cur diff delta = 285.55767822265625
# Cur diff sigma = 201.741455078125
# Cur diff theta = 487.29913330078125
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-740, s/iter: 1.615e-01, ELBO: -3.622e+06
# Cur diff delta = 282.1396484375
# Cur diff sigma = 162.82183837890625
# Cur diff theta = 444.96148681640625
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-760, s/iter: 1.609e-01, ELBO: -3.594e+06
# Cur diff delta = 283.2547302246094
# Cur diff sigma = 130.6751251220703
# Cur diff theta = 413.9298553466797
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-780, s/iter: 1.618e-01, ELBO: -3.565e+06
# Cur diff delta = 286.6291198730469
# Cur diff sigma = 103.77561950683594
# Cur diff theta = 390.4047393798828
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-800, s/iter: 1.632e-01, ELBO: -3.540e+06
# Cur diff delta = 291.8218078613281
# Cur diff sigma = 84.22526550292969
# Cur diff theta = 376.0470733642578
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-820, s/iter: 1.640e-01, ELBO: -3.527e+06
# Cur diff delta = 295.80438232421875
# Cur diff sigma = 72.72989654541016
# Cur diff theta = 368.5342788696289
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-840, s/iter: 1.622e-01, ELBO: -3.513e+06
# Cur diff delta = 296.48358154296875
# Cur diff sigma = 66.23249816894531
# Cur diff theta = 362.71607971191406
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-860, s/iter: 1.618e-01, ELBO: -3.517e+06
# Cur diff delta = 296.9319152832031
# Cur diff sigma = 61.272579193115234
# Cur diff theta = 358.20449447631836
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-880, s/iter: 1.619e-01, ELBO: -3.503e+06
# Cur diff delta = 296.5590515136719
# Cur diff sigma = 56.76529312133789
# Cur diff theta = 353.32434463500977
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-900, s/iter: 1.630e-01, ELBO: -3.502e+06
# Cur diff delta = 297.00836181640625
# Cur diff sigma = 53.36272430419922
# Cur diff theta = 350.37108612060547
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-920, s/iter: 1.625e-01, ELBO: -3.489e+06
# Cur diff delta = 297.62359619140625
# Cur diff sigma = 50.733428955078125
# Cur diff theta = 348.3570251464844
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-940, s/iter: 1.632e-01, ELBO: -3.492e+06
# Cur diff delta = 296.56219482421875
# Cur diff sigma = 49.292240142822266
# Cur diff theta = 345.854434967041
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-960, s/iter: 1.617e-01, ELBO: -3.487e+06
# Cur diff delta = 297.1741638183594
# Cur diff sigma = 48.55399703979492
# Cur diff theta = 345.7281608581543
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-980, s/iter: 1.623e-01, ELBO: -3.492e+06
# Cur diff delta = 297.1762390136719
# Cur diff sigma = 48.44473648071289
# Cur diff theta = 345.62097549438477
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1000, s/iter: 1.617e-01, ELBO: -3.489e+06
# Cur diff delta = 297.118896484375
# Cur diff sigma = 48.55131530761719
# Cur diff theta = 345.6702117919922
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1020, s/iter: 1.613e-01, ELBO: -3.489e+06
# Cur diff delta = 296.70989990234375
# Cur diff sigma = 48.535614013671875
# Cur diff theta = 345.2455139160156
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1040, s/iter: 1.625e-01, ELBO: -3.479e+06
# Cur diff delta = 296.6493225097656
# Cur diff sigma = 48.319828033447266
# Cur diff theta = 344.9691505432129
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1060, s/iter: 1.617e-01, ELBO: -3.488e+06
# Cur diff delta = 297.48187255859375
# Cur diff sigma = 48.532470703125
# Cur diff theta = 346.01434326171875
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1080, s/iter: 1.605e-01, ELBO: -3.503e+06
# Cur diff delta = 297.2469787597656
# Cur diff sigma = 48.53064727783203
# Cur diff theta = 345.77762603759766
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1100, s/iter: 1.608e-01, ELBO: -3.488e+06
# Cur diff delta = 297.06640625
# Cur diff sigma = 48.44197082519531
# Cur diff theta = 345.5083770751953
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1120, s/iter: 1.618e-01, ELBO: -3.483e+06
# Cur diff delta = 296.7767639160156
# Cur diff sigma = 48.45323181152344
# Cur diff theta = 345.22999572753906
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1140, s/iter: 1.611e-01, ELBO: -3.494e+06
# Cur diff delta = 296.7012023925781
# Cur diff sigma = 48.55272674560547
# Cur diff theta = 345.2539291381836
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1160, s/iter: 1.605e-01, ELBO: -3.482e+06
# Cur diff delta = 297.40301513671875
# Cur diff sigma = 48.429325103759766
# Cur diff theta = 345.8323402404785
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1180, s/iter: 1.616e-01, ELBO: -3.491e+06
# Cur diff delta = 297.47052001953125
# Cur diff sigma = 48.51234817504883
# Cur diff theta = 345.9828681945801
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1200, s/iter: 1.621e-01, ELBO: -3.494e+06
# Cur diff delta = 297.2900390625
# Cur diff sigma = 48.5862922668457
# Cur diff theta = 345.8763313293457
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1220, s/iter: 1.610e-01, ELBO: -3.491e+06
# Cur diff delta = 296.38958740234375
# Cur diff sigma = 48.62362289428711
# Cur diff theta = 345.01321029663086
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1240, s/iter: 1.619e-01, ELBO: -3.488e+06
# Cur diff delta = 296.70745849609375
# Cur diff sigma = 48.45850372314453
# Cur diff theta = 345.1659622192383
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1260, s/iter: 1.623e-01, ELBO: -3.486e+06
# Cur diff delta = 296.6456298828125
# Cur diff sigma = 48.44362258911133
# Cur diff theta = 345.0892524719238
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1280, s/iter: 1.628e-01, ELBO: -3.490e+06
# Cur diff delta = 296.68463134765625
# Cur diff sigma = 48.59861373901367
# Cur diff theta = 345.2832450866699
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1300, s/iter: 1.623e-01, ELBO: -3.485e+06
# Cur diff delta = 297.05084228515625
# Cur diff sigma = 48.494712829589844
# Cur diff theta = 345.5455551147461
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1320, s/iter: 1.638e-01, ELBO: -3.493e+06
# Cur diff delta = 296.8993225097656
# Cur diff sigma = 48.59907531738281
# Cur diff theta = 345.49839782714844
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1340, s/iter: 1.619e-01, ELBO: -3.492e+06
# Cur diff delta = 297.55670166015625
# Cur diff sigma = 48.45350646972656
# Cur diff theta = 346.0102081298828
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1360, s/iter: 1.622e-01, ELBO: -3.485e+06
# Cur diff delta = 297.441650390625
# Cur diff sigma = 48.39165115356445
# Cur diff theta = 345.83330154418945
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1380, s/iter: 1.615e-01, ELBO: -3.483e+06
# Cur diff delta = 297.13885498046875
# Cur diff sigma = 48.3368034362793
# Cur diff theta = 345.47565841674805
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1400, s/iter: 1.616e-01, ELBO: -3.487e+06
# Cur diff delta = 297.16119384765625
# Cur diff sigma = 48.53750228881836
# Cur diff theta = 345.6986961364746
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1420, s/iter: 1.623e-01, ELBO: -3.492e+06
# Cur diff delta = 297.132080078125
# Cur diff sigma = 48.593929290771484
# Cur diff theta = 345.7260093688965
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1440, s/iter: 1.611e-01, ELBO: -3.487e+06
# Cur diff delta = 297.0287780761719
# Cur diff sigma = 48.4987907409668
# Cur diff theta = 345.5275688171387
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1460, s/iter: 1.617e-01, ELBO: -3.480e+06
# Cur diff delta = 296.53656005859375
# Cur diff sigma = 48.4365119934082
# Cur diff theta = 344.97307205200195
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1480, s/iter: 1.618e-01, ELBO: -3.495e+06
# Cur diff delta = 297.0445556640625
# Cur diff sigma = 48.58081817626953
# Cur diff theta = 345.62537384033203
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1500, s/iter: 1.597e-01, ELBO: -3.484e+06
# Cur diff delta = 297.37884521484375
# Cur diff sigma = 48.36349105834961
# Cur diff theta = 345.74233627319336
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1520, s/iter: 1.595e-01, ELBO: -3.484e+06
# Cur diff delta = 296.95318603515625
# Cur diff sigma = 48.589935302734375
# Cur diff theta = 345.5431213378906
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1540, s/iter: 1.619e-01, ELBO: -3.488e+06
# Cur diff delta = 297.6091003417969
# Cur diff sigma = 48.4947509765625
# Cur diff theta = 346.1038513183594
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1560, s/iter: 1.598e-01, ELBO: -3.493e+06
# Cur diff delta = 296.566650390625
# Cur diff sigma = 48.50751876831055
# Cur diff theta = 345.07416915893555
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1580, s/iter: 1.598e-01, ELBO: -3.489e+06
# Cur diff delta = 296.43023681640625
# Cur diff sigma = 48.4248161315918
# Cur diff theta = 344.85505294799805
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1600, s/iter: 1.606e-01, ELBO: -3.486e+06
# Cur diff delta = 296.7137145996094
# Cur diff sigma = 48.44232177734375
# Cur diff theta = 345.1560363769531
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1620, s/iter: 1.651e-01, ELBO: -3.495e+06
# Cur diff delta = 297.2476806640625
# Cur diff sigma = 48.6143684387207
# Cur diff theta = 345.8620491027832
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1640, s/iter: 1.626e-01, ELBO: -3.485e+06
# Cur diff delta = 297.15692138671875
# Cur diff sigma = 48.477210998535156
# Cur diff theta = 345.6341323852539
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1660, s/iter: 1.629e-01, ELBO: -3.486e+06
# Cur diff delta = 296.57586669921875
# Cur diff sigma = 48.53364944458008
# Cur diff theta = 345.1095161437988
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1680, s/iter: 1.623e-01, ELBO: -3.501e+06
# Cur diff delta = 296.75726318359375
# Cur diff sigma = 48.62103271484375
# Cur diff theta = 345.3782958984375
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1700, s/iter: 1.625e-01, ELBO: -3.495e+06
# Cur diff delta = 297.525146484375
# Cur diff sigma = 48.65364456176758
# Cur diff theta = 346.1787910461426
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1720, s/iter: 1.617e-01, ELBO: -3.491e+06
# Cur diff delta = 297.1121826171875
# Cur diff sigma = 48.527374267578125
# Cur diff theta = 345.6395568847656
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1740, s/iter: 1.604e-01, ELBO: -3.495e+06
# Cur diff delta = 296.490966796875
# Cur diff sigma = 48.56745147705078
# Cur diff theta = 345.0584182739258
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1760, s/iter: 1.610e-01, ELBO: -3.490e+06
# Cur diff delta = 296.8658142089844
# Cur diff sigma = 48.529502868652344
# Cur diff theta = 345.3953170776367
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1780, s/iter: 1.636e-01, ELBO: -3.486e+06
# Cur diff delta = 297.498291015625
# Cur diff sigma = 48.57072448730469
# Cur diff theta = 346.0690155029297
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1800, s/iter: 1.633e-01, ELBO: -3.488e+06
# Cur diff delta = 297.4959411621094
# Cur diff sigma = 48.6467399597168
# Cur diff theta = 346.1426811218262
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1820, s/iter: 1.621e-01, ELBO: -3.493e+06
# Cur diff delta = 297.0086975097656
# Cur diff sigma = 48.68056106567383
# Cur diff theta = 345.68925857543945
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1840, s/iter: 1.612e-01, ELBO: -3.485e+06
# Cur diff delta = 296.5954284667969
# Cur diff sigma = 48.4890251159668
# Cur diff theta = 345.0844535827637
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1860, s/iter: 1.604e-01, ELBO: -3.489e+06
# Cur diff delta = 297.6400146484375
# Cur diff sigma = 48.555023193359375
# Cur diff theta = 346.1950378417969
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1880, s/iter: 1.626e-01, ELBO: -3.478e+06
# Cur diff delta = 296.5641784667969
# Cur diff sigma = 48.3171272277832
# Cur diff theta = 344.8813056945801
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1900, s/iter: 1.626e-01, ELBO: -3.495e+06
# Cur diff delta = 296.88226318359375
# Cur diff sigma = 48.559120178222656
# Cur diff theta = 345.4413833618164
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1920, s/iter: 1.623e-01, ELBO: -3.480e+06
# Cur diff delta = 296.8242492675781
# Cur diff sigma = 48.478633880615234
# Cur diff theta = 345.30288314819336
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1940, s/iter: 1.619e-01, ELBO: -3.492e+06
# Cur diff delta = 296.89495849609375
# Cur diff sigma = 48.543270111083984
# Cur diff theta = 345.43822860717773
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1960, s/iter: 1.622e-01, ELBO: -3.493e+06
# Cur diff delta = 297.0592041015625
# Cur diff sigma = 48.42267608642578
# Cur diff theta = 345.4818801879883
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-1980, s/iter: 1.618e-01, ELBO: -3.485e+06
# Cur diff delta = 297.1930236816406
# Cur diff sigma = 48.562294006347656
# Cur diff theta = 345.7553176879883
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 1-2000, s/iter: 1.624e-01, ELBO: -3.499e+06
# Cur diff delta = 296.613037109375
# Cur diff sigma = 48.62711715698242
# Cur diff theta = 345.2401542663574
# ---------------------------------------
# ------------------------------------------------------
# Test = 1
# ------------------------------------------------------
# Init diff delta = 89999.0078125
# Init diff sigma = 116254.2890625
# Init diff theta = 206253.296875
# HVAE_notemp_1, d: 300, Iter: 2-20, s/iter: 1.621e-01, ELBO: -1.188e+07
# Cur diff delta = 81973.6953125
# Cur diff sigma = 82577.9765625
# Cur diff theta = 164551.671875
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-40, s/iter: 1.619e-01, ELBO: -1.133e+07
# Cur diff delta = 75410.0625
# Cur diff sigma = 72428.625
# Cur diff theta = 147838.6875
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-60, s/iter: 1.616e-01, ELBO: -1.087e+07
# Cur diff delta = 69246.8359375
# Cur diff sigma = 65940.9140625
# Cur diff theta = 135187.75
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-80, s/iter: 1.587e-01, ELBO: -1.054e+07
# Cur diff delta = 63436.83984375
# Cur diff sigma = 60154.98046875
# Cur diff theta = 123591.8203125
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-100, s/iter: 1.586e-01, ELBO: -1.002e+07
# Cur diff delta = 57964.375
# Cur diff sigma = 54766.65625
# Cur diff theta = 112731.03125
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-120, s/iter: 1.578e-01, ELBO: -9.641e+06
# Cur diff delta = 52816.1953125
# Cur diff sigma = 49567.890625
# Cur diff theta = 102384.0859375
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-140, s/iter: 1.589e-01, ELBO: -9.288e+06
# Cur diff delta = 47983.30078125
# Cur diff sigma = 44591.37890625
# Cur diff theta = 92574.6796875
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-160, s/iter: 1.616e-01, ELBO: -8.951e+06
# Cur diff delta = 43451.19140625
# Cur diff sigma = 39890.26171875
# Cur diff theta = 83341.453125
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-180, s/iter: 1.638e-01, ELBO: -8.622e+06
# Cur diff delta = 39212.5234375
# Cur diff sigma = 35319.4921875
# Cur diff theta = 74532.015625
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-200, s/iter: 1.635e-01, ELBO: -8.295e+06
# Cur diff delta = 35265.12109375
# Cur diff sigma = 31067.513671875
# Cur diff theta = 66332.634765625
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-220, s/iter: 1.650e-01, ELBO: -7.997e+06
# Cur diff delta = 31597.404296875
# Cur diff sigma = 27195.546875
# Cur diff theta = 58792.951171875
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-240, s/iter: 1.605e-01, ELBO: -7.710e+06
# Cur diff delta = 28191.478515625
# Cur diff sigma = 23444.416015625
# Cur diff theta = 51635.89453125
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-260, s/iter: 1.604e-01, ELBO: -7.434e+06
# Cur diff delta = 25039.767578125
# Cur diff sigma = 19898.783203125
# Cur diff theta = 44938.55078125
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-280, s/iter: 1.603e-01, ELBO: -7.163e+06
# Cur diff delta = 22134.744140625
# Cur diff sigma = 16709.609375
# Cur diff theta = 38844.353515625
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-300, s/iter: 1.620e-01, ELBO: -6.892e+06
# Cur diff delta = 19464.7265625
# Cur diff sigma = 13872.8779296875
# Cur diff theta = 33337.6044921875
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-320, s/iter: 1.617e-01, ELBO: -6.643e+06
# Cur diff delta = 17021.04296875
# Cur diff sigma = 11522.6533203125
# Cur diff theta = 28543.6962890625
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-340, s/iter: 1.599e-01, ELBO: -6.393e+06
# Cur diff delta = 14792.3359375
# Cur diff sigma = 9425.0205078125
# Cur diff theta = 24217.3564453125
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-360, s/iter: 1.594e-01, ELBO: -6.145e+06
# Cur diff delta = 12773.8037109375
# Cur diff sigma = 7620.80224609375
# Cur diff theta = 20394.60595703125
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-380, s/iter: 1.595e-01, ELBO: -5.905e+06
# Cur diff delta = 10953.0986328125
# Cur diff sigma = 6018.03271484375
# Cur diff theta = 16971.13134765625
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-400, s/iter: 1.588e-01, ELBO: -5.685e+06
# Cur diff delta = 9318.5478515625
# Cur diff sigma = 4652.75830078125
# Cur diff theta = 13971.30615234375
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-420, s/iter: 1.593e-01, ELBO: -5.461e+06
# Cur diff delta = 7860.8388671875
# Cur diff sigma = 3505.2333984375
# Cur diff theta = 11366.072265625
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-440, s/iter: 1.644e-01, ELBO: -5.261e+06
# Cur diff delta = 6569.82421875
# Cur diff sigma = 2614.025634765625
# Cur diff theta = 9183.849853515625
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-460, s/iter: 1.616e-01, ELBO: -5.052e+06
# Cur diff delta = 5435.76611328125
# Cur diff sigma = 1856.7626953125
# Cur diff theta = 7292.52880859375
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-480, s/iter: 1.599e-01, ELBO: -4.869e+06
# Cur diff delta = 4454.32373046875
# Cur diff sigma = 1483.1995849609375
# Cur diff theta = 5937.5233154296875
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-500, s/iter: 1.597e-01, ELBO: -4.695e+06
# Cur diff delta = 3611.5537109375
# Cur diff sigma = 1284.8486328125
# Cur diff theta = 4896.40234375
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-520, s/iter: 1.601e-01, ELBO: -4.542e+06
# Cur diff delta = 2891.073486328125
# Cur diff sigma = 1158.2696533203125
# Cur diff theta = 4049.3431396484375
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-540, s/iter: 1.593e-01, ELBO: -4.403e+06
# Cur diff delta = 2283.291748046875
# Cur diff sigma = 1043.0328369140625
# Cur diff theta = 3326.3245849609375
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-560, s/iter: 1.592e-01, ELBO: -4.297e+06
# Cur diff delta = 1780.8165283203125
# Cur diff sigma = 926.332763671875
# Cur diff theta = 2707.1492919921875
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-580, s/iter: 1.588e-01, ELBO: -4.200e+06
# Cur diff delta = 1373.6790771484375
# Cur diff sigma = 809.526123046875
# Cur diff theta = 2183.2052001953125
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-600, s/iter: 1.579e-01, ELBO: -4.087e+06
# Cur diff delta = 1050.408935546875
# Cur diff sigma = 692.8259887695312
# Cur diff theta = 1743.2349243164062
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-620, s/iter: 1.599e-01, ELBO: -4.000e+06
# Cur diff delta = 803.892578125
# Cur diff sigma = 583.0162353515625
# Cur diff theta = 1386.9088134765625
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-640, s/iter: 1.590e-01, ELBO: -3.917e+06
# Cur diff delta = 624.775634765625
# Cur diff sigma = 481.90606689453125
# Cur diff theta = 1106.6817016601562
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-660, s/iter: 1.584e-01, ELBO: -3.830e+06
# Cur diff delta = 500.0207214355469
# Cur diff sigma = 391.853515625
# Cur diff theta = 891.8742370605469
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-680, s/iter: 1.585e-01, ELBO: -3.767e+06
# Cur diff delta = 420.3033142089844
# Cur diff sigma = 312.00531005859375
# Cur diff theta = 732.3086242675781
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-700, s/iter: 1.589e-01, ELBO: -3.707e+06
# Cur diff delta = 376.2672119140625
# Cur diff sigma = 241.7800750732422
# Cur diff theta = 618.0472869873047
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-720, s/iter: 1.585e-01, ELBO: -3.667e+06
# Cur diff delta = 358.8614196777344
# Cur diff sigma = 186.5494842529297
# Cur diff theta = 545.4109039306641
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-740, s/iter: 1.578e-01, ELBO: -3.621e+06
# Cur diff delta = 355.2736511230469
# Cur diff sigma = 144.68016052246094
# Cur diff theta = 499.9538116455078
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-760, s/iter: 1.588e-01, ELBO: -3.582e+06
# Cur diff delta = 354.8438415527344
# Cur diff sigma = 111.6498031616211
# Cur diff theta = 466.49364471435547
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-780, s/iter: 1.584e-01, ELBO: -3.547e+06
# Cur diff delta = 356.3856506347656
# Cur diff sigma = 85.54625701904297
# Cur diff theta = 441.9319076538086
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-800, s/iter: 1.613e-01, ELBO: -3.516e+06
# Cur diff delta = 357.1454162597656
# Cur diff sigma = 68.4023208618164
# Cur diff theta = 425.54773712158203
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-820, s/iter: 1.600e-01, ELBO: -3.497e+06
# Cur diff delta = 356.9559326171875
# Cur diff sigma = 58.39773178100586
# Cur diff theta = 415.35366439819336
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-840, s/iter: 1.603e-01, ELBO: -3.498e+06
# Cur diff delta = 356.97979736328125
# Cur diff sigma = 52.842750549316406
# Cur diff theta = 409.82254791259766
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-860, s/iter: 1.565e-01, ELBO: -3.485e+06
# Cur diff delta = 356.0941467285156
# Cur diff sigma = 49.807456970214844
# Cur diff theta = 405.90160369873047
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-880, s/iter: 1.583e-01, ELBO: -3.493e+06
# Cur diff delta = 356.9280090332031
# Cur diff sigma = 48.85920333862305
# Cur diff theta = 405.7872123718262
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-900, s/iter: 1.564e-01, ELBO: -3.487e+06
# Cur diff delta = 357.87554931640625
# Cur diff sigma = 48.49260330200195
# Cur diff theta = 406.3681526184082
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-920, s/iter: 1.578e-01, ELBO: -3.490e+06
# Cur diff delta = 357.20452880859375
# Cur diff sigma = 48.55875778198242
# Cur diff theta = 405.7632865905762
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-940, s/iter: 1.572e-01, ELBO: -3.486e+06
# Cur diff delta = 357.2740478515625
# Cur diff sigma = 48.53108215332031
# Cur diff theta = 405.8051300048828
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-960, s/iter: 1.573e-01, ELBO: -3.489e+06
# Cur diff delta = 357.4287414550781
# Cur diff sigma = 48.573158264160156
# Cur diff theta = 406.0018997192383
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-980, s/iter: 1.574e-01, ELBO: -3.485e+06
# Cur diff delta = 357.26885986328125
# Cur diff sigma = 48.489540100097656
# Cur diff theta = 405.7583999633789
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1000, s/iter: 1.589e-01, ELBO: -3.502e+06
# Cur diff delta = 357.5329895019531
# Cur diff sigma = 48.75566482543945
# Cur diff theta = 406.2886543273926
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1020, s/iter: 1.579e-01, ELBO: -3.493e+06
# Cur diff delta = 357.0988464355469
# Cur diff sigma = 48.57844543457031
# Cur diff theta = 405.6772918701172
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1040, s/iter: 1.585e-01, ELBO: -3.490e+06
# Cur diff delta = 356.730712890625
# Cur diff sigma = 48.702423095703125
# Cur diff theta = 405.4331359863281
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1060, s/iter: 1.566e-01, ELBO: -3.497e+06
# Cur diff delta = 357.165283203125
# Cur diff sigma = 48.56068801879883
# Cur diff theta = 405.7259712219238
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1080, s/iter: 1.592e-01, ELBO: -3.493e+06
# Cur diff delta = 356.7768859863281
# Cur diff sigma = 48.6098518371582
# Cur diff theta = 405.3867378234863
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1100, s/iter: 1.589e-01, ELBO: -3.489e+06
# Cur diff delta = 356.13006591796875
# Cur diff sigma = 48.59498596191406
# Cur diff theta = 404.7250518798828
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1120, s/iter: 1.602e-01, ELBO: -3.481e+06
# Cur diff delta = 357.02764892578125
# Cur diff sigma = 48.40507125854492
# Cur diff theta = 405.4327201843262
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1140, s/iter: 1.582e-01, ELBO: -3.496e+06
# Cur diff delta = 356.9163818359375
# Cur diff sigma = 48.626468658447266
# Cur diff theta = 405.54285049438477
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1160, s/iter: 1.591e-01, ELBO: -3.491e+06
# Cur diff delta = 356.3048400878906
# Cur diff sigma = 48.601402282714844
# Cur diff theta = 404.90624237060547
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1180, s/iter: 1.598e-01, ELBO: -3.485e+06
# Cur diff delta = 357.5428466796875
# Cur diff sigma = 48.44077682495117
# Cur diff theta = 405.9836235046387
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1200, s/iter: 1.591e-01, ELBO: -3.490e+06
# Cur diff delta = 356.8654479980469
# Cur diff sigma = 48.678382873535156
# Cur diff theta = 405.54383087158203
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1220, s/iter: 1.604e-01, ELBO: -3.485e+06
# Cur diff delta = 357.0382995605469
# Cur diff sigma = 48.411720275878906
# Cur diff theta = 405.4500198364258
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1240, s/iter: 1.582e-01, ELBO: -3.492e+06
# Cur diff delta = 357.3822937011719
# Cur diff sigma = 48.5408821105957
# Cur diff theta = 405.9231758117676
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1260, s/iter: 1.583e-01, ELBO: -3.489e+06
# Cur diff delta = 357.3759765625
# Cur diff sigma = 48.58286666870117
# Cur diff theta = 405.9588432312012
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1280, s/iter: 1.590e-01, ELBO: -3.484e+06
# Cur diff delta = 357.5647888183594
# Cur diff sigma = 48.53212356567383
# Cur diff theta = 406.0969123840332
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1300, s/iter: 1.603e-01, ELBO: -3.486e+06
# Cur diff delta = 356.9603271484375
# Cur diff sigma = 48.4877815246582
# Cur diff theta = 405.4481086730957
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1320, s/iter: 1.593e-01, ELBO: -3.479e+06
# Cur diff delta = 357.3699035644531
# Cur diff sigma = 48.32157897949219
# Cur diff theta = 405.6914825439453
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1340, s/iter: 1.592e-01, ELBO: -3.482e+06
# Cur diff delta = 355.80047607421875
# Cur diff sigma = 48.53639602661133
# Cur diff theta = 404.3368721008301
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1360, s/iter: 1.579e-01, ELBO: -3.491e+06
# Cur diff delta = 357.78680419921875
# Cur diff sigma = 48.58964538574219
# Cur diff theta = 406.37644958496094
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1380, s/iter: 1.600e-01, ELBO: -3.494e+06
# Cur diff delta = 356.55810546875
# Cur diff sigma = 48.56302261352539
# Cur diff theta = 405.1211280822754
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1400, s/iter: 1.594e-01, ELBO: -3.483e+06
# Cur diff delta = 357.08587646484375
# Cur diff sigma = 48.50667953491211
# Cur diff theta = 405.59255599975586
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1420, s/iter: 1.582e-01, ELBO: -3.497e+06
# Cur diff delta = 356.510498046875
# Cur diff sigma = 48.61539840698242
# Cur diff theta = 405.1258964538574
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1440, s/iter: 1.594e-01, ELBO: -3.487e+06
# Cur diff delta = 356.5926818847656
# Cur diff sigma = 48.42378234863281
# Cur diff theta = 405.01646423339844
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1460, s/iter: 1.587e-01, ELBO: -3.493e+06
# Cur diff delta = 356.27178955078125
# Cur diff sigma = 48.6038818359375
# Cur diff theta = 404.87567138671875
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1480, s/iter: 1.594e-01, ELBO: -3.489e+06
# Cur diff delta = 356.73687744140625
# Cur diff sigma = 48.446388244628906
# Cur diff theta = 405.18326568603516
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1500, s/iter: 1.591e-01, ELBO: -3.487e+06
# Cur diff delta = 357.1799621582031
# Cur diff sigma = 48.531192779541016
# Cur diff theta = 405.71115493774414
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1520, s/iter: 1.592e-01, ELBO: -3.488e+06
# Cur diff delta = 356.95587158203125
# Cur diff sigma = 48.57699966430664
# Cur diff theta = 405.5328712463379
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1540, s/iter: 1.600e-01, ELBO: -3.498e+06
# Cur diff delta = 356.85302734375
# Cur diff sigma = 48.519920349121094
# Cur diff theta = 405.3729476928711
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1560, s/iter: 1.608e-01, ELBO: -3.496e+06
# Cur diff delta = 356.7617492675781
# Cur diff sigma = 48.60057830810547
# Cur diff theta = 405.3623275756836
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1580, s/iter: 1.582e-01, ELBO: -3.488e+06
# Cur diff delta = 357.2774963378906
# Cur diff sigma = 48.54877471923828
# Cur diff theta = 405.8262710571289
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1600, s/iter: 1.598e-01, ELBO: -3.488e+06
# Cur diff delta = 356.9859619140625
# Cur diff sigma = 48.57460403442383
# Cur diff theta = 405.5605659484863
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1620, s/iter: 1.600e-01, ELBO: -3.498e+06
# Cur diff delta = 357.59393310546875
# Cur diff sigma = 48.62203598022461
# Cur diff theta = 406.21596908569336
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1640, s/iter: 1.598e-01, ELBO: -3.490e+06
# Cur diff delta = 357.06878662109375
# Cur diff sigma = 48.52500915527344
# Cur diff theta = 405.5937957763672
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1660, s/iter: 1.583e-01, ELBO: -3.492e+06
# Cur diff delta = 356.9882507324219
# Cur diff sigma = 48.52839279174805
# Cur diff theta = 405.5166435241699
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1680, s/iter: 1.574e-01, ELBO: -3.486e+06
# Cur diff delta = 357.0197448730469
# Cur diff sigma = 48.44281005859375
# Cur diff theta = 405.4625549316406
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1700, s/iter: 1.585e-01, ELBO: -3.492e+06
# Cur diff delta = 357.98297119140625
# Cur diff sigma = 48.541236877441406
# Cur diff theta = 406.52420806884766
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1720, s/iter: 1.579e-01, ELBO: -3.497e+06
# Cur diff delta = 356.8831481933594
# Cur diff sigma = 48.59276580810547
# Cur diff theta = 405.47591400146484
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1740, s/iter: 1.574e-01, ELBO: -3.494e+06
# Cur diff delta = 357.0879211425781
# Cur diff sigma = 48.63885498046875
# Cur diff theta = 405.7267761230469
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1760, s/iter: 1.597e-01, ELBO: -3.492e+06
# Cur diff delta = 357.64794921875
# Cur diff sigma = 48.60715866088867
# Cur diff theta = 406.2551078796387
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1780, s/iter: 1.592e-01, ELBO: -3.482e+06
# Cur diff delta = 357.1126403808594
# Cur diff sigma = 48.61159133911133
# Cur diff theta = 405.7242317199707
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1800, s/iter: 1.609e-01, ELBO: -3.485e+06
# Cur diff delta = 357.54443359375
# Cur diff sigma = 48.4332389831543
# Cur diff theta = 405.9776725769043
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1820, s/iter: 1.612e-01, ELBO: -3.490e+06
# Cur diff delta = 356.7313232421875
# Cur diff sigma = 48.57753372192383
# Cur diff theta = 405.3088569641113
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1840, s/iter: 1.623e-01, ELBO: -3.495e+06
# Cur diff delta = 356.7705383300781
# Cur diff sigma = 48.62196731567383
# Cur diff theta = 405.39250564575195
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1860, s/iter: 1.577e-01, ELBO: -3.486e+06
# Cur diff delta = 357.2735290527344
# Cur diff sigma = 48.584468841552734
# Cur diff theta = 405.8579978942871
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1880, s/iter: 1.593e-01, ELBO: -3.490e+06
# Cur diff delta = 356.94647216796875
# Cur diff sigma = 48.526214599609375
# Cur diff theta = 405.4726867675781
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1900, s/iter: 1.590e-01, ELBO: -3.490e+06
# Cur diff delta = 357.36285400390625
# Cur diff sigma = 48.4873161315918
# Cur diff theta = 405.85017013549805
# ---------------------------------------
# HVAE_notemp_1, d: 300, Iter: 2-1920, s/iter: 1.584e-01, ELBO: -3.489e+06
# Cur diff delta = 356.99884033203125
# Cur diff sigma = 48.550132751464844
# Cur diff theta = 405.5489730834961
# ---------------------------------------
# ...
# Cur diff sigma = 276.38958740234375
# Cur diff theta = 736.7264099121094
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-680, s/iter: 4.368e-01, ELBO: -4.647e+06
# Cur diff delta = 385.71380615234375
# Cur diff sigma = 216.7334442138672
# Cur diff theta = 602.4472503662109
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-700, s/iter: 4.355e-01, ELBO: -4.596e+06
# Cur diff delta = 348.0068054199219
# Cur diff sigma = 183.89808654785156
# Cur diff theta = 531.9048919677734
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-720, s/iter: 4.300e-01, ELBO: -4.561e+06
# Cur diff delta = 332.51531982421875
# Cur diff sigma = 165.40451049804688
# Cur diff theta = 497.9198303222656
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-740, s/iter: 4.262e-01, ELBO: -4.556e+06
# Cur diff delta = 329.66119384765625
# Cur diff sigma = 157.575439453125
# Cur diff theta = 487.23663330078125
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-760, s/iter: 4.243e-01, ELBO: -4.529e+06
# Cur diff delta = 334.7400207519531
# Cur diff sigma = 154.43093872070312
# Cur diff theta = 489.17095947265625
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-780, s/iter: 4.293e-01, ELBO: -4.535e+06
# Cur diff delta = 339.2055358886719
# Cur diff sigma = 154.08297729492188
# Cur diff theta = 493.28851318359375
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-800, s/iter: 4.271e-01, ELBO: -4.535e+06
# Cur diff delta = 339.80596923828125
# Cur diff sigma = 154.16555786132812
# Cur diff theta = 493.9715270996094
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-820, s/iter: 4.292e-01, ELBO: -4.528e+06
# Cur diff delta = 340.66851806640625
# Cur diff sigma = 153.96368408203125
# Cur diff theta = 494.6322021484375
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-840, s/iter: 4.290e-01, ELBO: -4.525e+06
# Cur diff delta = 340.1281433105469
# Cur diff sigma = 153.8236846923828
# Cur diff theta = 493.9518280029297
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-860, s/iter: 4.303e-01, ELBO: -4.519e+06
# Cur diff delta = 339.6987609863281
# Cur diff sigma = 153.02935791015625
# Cur diff theta = 492.7281188964844
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-880, s/iter: 4.325e-01, ELBO: -4.530e+06
# Cur diff delta = 339.5876159667969
# Cur diff sigma = 154.03895568847656
# Cur diff theta = 493.62657165527344
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-900, s/iter: 4.241e-01, ELBO: -4.538e+06
# Cur diff delta = 340.73663330078125
# Cur diff sigma = 154.11427307128906
# Cur diff theta = 494.8509063720703
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-920, s/iter: 4.226e-01, ELBO: -4.536e+06
# Cur diff delta = 340.4083557128906
# Cur diff sigma = 154.1595458984375
# Cur diff theta = 494.5679016113281
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-940, s/iter: 4.299e-01, ELBO: -4.543e+06
# Cur diff delta = 339.88873291015625
# Cur diff sigma = 154.3286895751953
# Cur diff theta = 494.21742248535156
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-960, s/iter: 4.388e-01, ELBO: -4.530e+06
# Cur diff delta = 340.3541564941406
# Cur diff sigma = 154.1226806640625
# Cur diff theta = 494.4768371582031
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-980, s/iter: 4.282e-01, ELBO: -4.524e+06
# Cur diff delta = 340.16748046875
# Cur diff sigma = 153.5926971435547
# Cur diff theta = 493.7601776123047
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1000, s/iter: 4.278e-01, ELBO: -4.528e+06
# Cur diff delta = 340.6662292480469
# Cur diff sigma = 153.7415771484375
# Cur diff theta = 494.4078063964844
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1020, s/iter: 4.260e-01, ELBO: -4.539e+06
# Cur diff delta = 340.9379577636719
# Cur diff sigma = 154.4456787109375
# Cur diff theta = 495.3836364746094
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1040, s/iter: 4.189e-01, ELBO: -4.531e+06
# Cur diff delta = 340.3583068847656
# Cur diff sigma = 153.65489196777344
# Cur diff theta = 494.01319885253906
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1060, s/iter: 4.290e-01, ELBO: -4.523e+06
# Cur diff delta = 340.2015075683594
# Cur diff sigma = 153.94956970214844
# Cur diff theta = 494.1510772705078
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1080, s/iter: 4.296e-01, ELBO: -4.538e+06
# Cur diff delta = 340.6580505371094
# Cur diff sigma = 154.57191467285156
# Cur diff theta = 495.22996520996094
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1100, s/iter: 4.237e-01, ELBO: -4.534e+06
# Cur diff delta = 341.1655578613281
# Cur diff sigma = 154.14260864257812
# Cur diff theta = 495.30816650390625
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1120, s/iter: 4.244e-01, ELBO: -4.531e+06
# Cur diff delta = 340.55908203125
# Cur diff sigma = 154.2176513671875
# Cur diff theta = 494.7767333984375
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1140, s/iter: 4.258e-01, ELBO: -4.530e+06
# Cur diff delta = 340.0038757324219
# Cur diff sigma = 153.9353485107422
# Cur diff theta = 493.93922424316406
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1160, s/iter: 4.262e-01, ELBO: -4.534e+06
# Cur diff delta = 340.15057373046875
# Cur diff sigma = 154.67190551757812
# Cur diff theta = 494.8224792480469
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1180, s/iter: 4.238e-01, ELBO: -4.526e+06
# Cur diff delta = 340.0058288574219
# Cur diff sigma = 153.75440979003906
# Cur diff theta = 493.76023864746094
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1200, s/iter: 4.244e-01, ELBO: -4.534e+06
# Cur diff delta = 341.37823486328125
# Cur diff sigma = 154.18096923828125
# Cur diff theta = 495.5592041015625
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1220, s/iter: 4.247e-01, ELBO: -4.537e+06
# Cur diff delta = 340.09088134765625
# Cur diff sigma = 154.1240692138672
# Cur diff theta = 494.21495056152344
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1240, s/iter: 4.293e-01, ELBO: -4.529e+06
# Cur diff delta = 340.0861511230469
# Cur diff sigma = 153.82098388671875
# Cur diff theta = 493.9071350097656
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1260, s/iter: 4.310e-01, ELBO: -4.528e+06
# Cur diff delta = 340.405517578125
# Cur diff sigma = 153.5572509765625
# Cur diff theta = 493.9627685546875
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1280, s/iter: 4.266e-01, ELBO: -4.537e+06
# Cur diff delta = 340.4494323730469
# Cur diff sigma = 153.8526611328125
# Cur diff theta = 494.3020935058594
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1300, s/iter: 4.268e-01, ELBO: -4.538e+06
# Cur diff delta = 340.27294921875
# Cur diff sigma = 153.95655822753906
# Cur diff theta = 494.22950744628906
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1320, s/iter: 4.257e-01, ELBO: -4.532e+06
# Cur diff delta = 340.5299072265625
# Cur diff sigma = 154.11135864257812
# Cur diff theta = 494.6412658691406
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1340, s/iter: 4.276e-01, ELBO: -4.537e+06
# Cur diff delta = 340.22662353515625
# Cur diff sigma = 154.3525848388672
# Cur diff theta = 494.57920837402344
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1360, s/iter: 4.266e-01, ELBO: -4.532e+06
# Cur diff delta = 340.4366455078125
# Cur diff sigma = 154.05540466308594
# Cur diff theta = 494.49205017089844
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1380, s/iter: 4.289e-01, ELBO: -4.533e+06
# Cur diff delta = 340.29644775390625
# Cur diff sigma = 154.1254425048828
# Cur diff theta = 494.42189025878906
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1400, s/iter: 4.288e-01, ELBO: -4.536e+06
# Cur diff delta = 339.8770751953125
# Cur diff sigma = 153.86288452148438
# Cur diff theta = 493.7399597167969
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1420, s/iter: 4.279e-01, ELBO: -4.530e+06
# Cur diff delta = 340.7737121582031
# Cur diff sigma = 153.67311096191406
# Cur diff theta = 494.4468231201172
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1440, s/iter: 4.346e-01, ELBO: -4.543e+06
# Cur diff delta = 341.0691223144531
# Cur diff sigma = 154.3753204345703
# Cur diff theta = 495.44444274902344
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1460, s/iter: 4.255e-01, ELBO: -4.527e+06
# Cur diff delta = 341.09014892578125
# Cur diff sigma = 153.75967407226562
# Cur diff theta = 494.8498229980469
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1480, s/iter: 4.303e-01, ELBO: -4.531e+06
# Cur diff delta = 340.2451477050781
# Cur diff sigma = 153.68443298339844
# Cur diff theta = 493.92958068847656
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1500, s/iter: 4.295e-01, ELBO: -4.527e+06
# Cur diff delta = 340.022705078125
# Cur diff sigma = 153.89907836914062
# Cur diff theta = 493.9217834472656
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1520, s/iter: 4.332e-01, ELBO: -4.532e+06
# Cur diff delta = 340.5010986328125
# Cur diff sigma = 153.85279846191406
# Cur diff theta = 494.35389709472656
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1540, s/iter: 4.314e-01, ELBO: -4.531e+06
# Cur diff delta = 340.2427978515625
# Cur diff sigma = 154.01513671875
# Cur diff theta = 494.2579345703125
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1560, s/iter: 4.273e-01, ELBO: -4.539e+06
# Cur diff delta = 340.6085205078125
# Cur diff sigma = 154.29676818847656
# Cur diff theta = 494.90528869628906
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1580, s/iter: 4.249e-01, ELBO: -4.525e+06
# Cur diff delta = 339.7929382324219
# Cur diff sigma = 153.91058349609375
# Cur diff theta = 493.7035217285156
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1600, s/iter: 4.290e-01, ELBO: -4.529e+06
# Cur diff delta = 340.0716552734375
# Cur diff sigma = 153.28924560546875
# Cur diff theta = 493.36090087890625
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1620, s/iter: 4.310e-01, ELBO: -4.533e+06
# Cur diff delta = 340.4752502441406
# Cur diff sigma = 153.81478881835938
# Cur diff theta = 494.2900390625
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1640, s/iter: 4.322e-01, ELBO: -4.534e+06
# Cur diff delta = 341.2762145996094
# Cur diff sigma = 153.65554809570312
# Cur diff theta = 494.9317626953125
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1660, s/iter: 4.403e-01, ELBO: -4.528e+06
# Cur diff delta = 340.6771545410156
# Cur diff sigma = 153.96990966796875
# Cur diff theta = 494.6470642089844
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1680, s/iter: 4.459e-01, ELBO: -4.540e+06
# Cur diff delta = 340.6864318847656
# Cur diff sigma = 154.15748596191406
# Cur diff theta = 494.8439178466797
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1700, s/iter: 4.347e-01, ELBO: -4.534e+06
# Cur diff delta = 340.30145263671875
# Cur diff sigma = 154.1656036376953
# Cur diff theta = 494.46705627441406
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1720, s/iter: 4.270e-01, ELBO: -4.532e+06
# Cur diff delta = 340.14080810546875
# Cur diff sigma = 153.85977172851562
# Cur diff theta = 494.0005798339844
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1740, s/iter: 4.268e-01, ELBO: -4.533e+06
# Cur diff delta = 340.2353515625
# Cur diff sigma = 154.20416259765625
# Cur diff theta = 494.43951416015625
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1760, s/iter: 4.270e-01, ELBO: -4.526e+06
# Cur diff delta = 340.15289306640625
# Cur diff sigma = 153.7411346435547
# Cur diff theta = 493.89402770996094
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1780, s/iter: 4.280e-01, ELBO: -4.539e+06
# Cur diff delta = 340.2880859375
# Cur diff sigma = 154.3559112548828
# Cur diff theta = 494.6439971923828
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1800, s/iter: 4.307e-01, ELBO: -4.537e+06
# Cur diff delta = 341.3583068847656
# Cur diff sigma = 154.12322998046875
# Cur diff theta = 495.4815368652344
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1820, s/iter: 4.338e-01, ELBO: -4.530e+06
# Cur diff delta = 340.74407958984375
# Cur diff sigma = 153.82498168945312
# Cur diff theta = 494.5690612792969
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1840, s/iter: 4.228e-01, ELBO: -4.524e+06
# Cur diff delta = 340.3603515625
# Cur diff sigma = 154.04727172851562
# Cur diff theta = 494.4076232910156
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1860, s/iter: 4.231e-01, ELBO: -4.520e+06
# Cur diff delta = 341.3494873046875
# Cur diff sigma = 153.60302734375
# Cur diff theta = 494.9525146484375
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1880, s/iter: 4.326e-01, ELBO: -4.533e+06
# Cur diff delta = 340.0957946777344
# Cur diff sigma = 154.12628173828125
# Cur diff theta = 494.2220764160156
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1900, s/iter: 4.276e-01, ELBO: -4.521e+06
# Cur diff delta = 340.5336608886719
# Cur diff sigma = 153.5478973388672
# Cur diff theta = 494.08155822753906
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1920, s/iter: 4.256e-01, ELBO: -4.529e+06
# Cur diff delta = 339.533447265625
# Cur diff sigma = 154.05126953125
# Cur diff theta = 493.584716796875
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1940, s/iter: 4.221e-01, ELBO: -4.529e+06
# Cur diff delta = 339.77886962890625
# Cur diff sigma = 153.64186096191406
# Cur diff theta = 493.4207305908203
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1960, s/iter: 4.252e-01, ELBO: -4.535e+06
# Cur diff delta = 340.0077209472656
# Cur diff sigma = 154.18698120117188
# Cur diff theta = 494.1947021484375
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-1980, s/iter: 4.221e-01, ELBO: -4.523e+06
# Cur diff delta = 339.6293640136719
# Cur diff sigma = 153.71337890625
# Cur diff theta = 493.3427429199219
# ---------------------------------------
# HVAE_notemp_2, d: 300, Iter: 3-2000, s/iter: 4.313e-01, ELBO: -4.535e+06
# Cur diff delta = 340.3754577636719
# Cur diff sigma = 153.96112060546875
# Cur diff theta = 494.3365783691406
# ---------------------------------------
# Model HVAE_notemp_1, test = 0, result delta diff = 296.61309814453125
# Model HVAE_notemp_1, test = 0, result sigma diff = 48.62712097167969
# Model HVAE_notemp_1, test = 0, result theta diff = 345.240234375
# Model HVAE_notemp_1, test = 1, result delta diff = 356.5179748535156
# Model HVAE_notemp_1, test = 1, result sigma diff = 48.52021026611328
# Model HVAE_notemp_1, test = 1, result theta diff = 405.0381774902344
# Model HVAE_notemp_1, test = 2, result delta diff = 339.8089599609375
# Model HVAE_notemp_1, test = 2, result sigma diff = 48.529998779296875
# Model HVAE_notemp_1, test = 2, result theta diff = 388.3389587402344
# Model HVAE_notemp_2, test = 0, result delta diff = 297.276611328125
# Model HVAE_notemp_2, test = 0, result sigma diff = 153.96548461914062
# Model HVAE_notemp_2, test = 0, result theta diff = 451.2420959472656
# Model HVAE_notemp_2, test = 1, result delta diff = 356.7850036621094
# Model HVAE_notemp_2, test = 1, result sigma diff = 154.0728759765625
# Model HVAE_notemp_2, test = 1, result theta diff = 510.8578796386719
# Model HVAE_notemp_2, test = 2, result delta diff = 340.37548828125
# Model HVAE_notemp_2, test = 2, result sigma diff = 153.96112060546875
# Model HVAE_notemp_2, test = 2, result theta diff = 494.33660888671875

# %%
model_names = ['HVAE_notemp_1', 'HVAE_notemp_2']
diff_delta_results = {}
diff_sigma_results = {}
diff_results = {}
for name in model_names:
    diff_delta_tests = np.zeros(params['n_tests'])
    diff_sigma_tests = np.zeros(params['n_tests'])
    diff_tests = np.zeros(params['n_tests'])
    for i in range(params['n_tests']):
        file_name = name + '_train_' + str(i) + '.p'
        diff_path = os.path.join('save', str(params['dims'][0]), file_name)
        with open(diff_path, 'rb') as f:
            data = pickle.load(f)
            elbo = data['elbo']
            diff_delta = data['diff_delta']
            diff_sigma = data['diff_sigma']
            diff = diff_delta + diff_sigma
            diff_delta_is_not_nan = diff_delta[~np.isnan(diff_delta)]
            diff_sigma_is_not_nan = diff_sigma[~np.isnan(diff_sigma)]
            diff_is_not_nan = diff[~np.isnan(diff)]
            diff_delta_tests[i] = diff_delta_is_not_nan[-1]
            diff_sigma_tests[i] = diff_sigma_is_not_nan[-1]
            diff_tests[i] = diff_is_not_nan[-1]
    diff_delta_results[name] = diff_delta_tests
    diff_sigma_results[name] = diff_sigma_tests
    diff_results[name] = diff_tests
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, diff delta = {diff_delta_tests}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, diff sigma = {diff_sigma_tests}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, diff = {diff_tests}")
# Out:
# Model = HVAE_notemp_1, dimensionality = 300, diff delta = [296.61303711 356.51794434 339.80889893]
# Model = HVAE_notemp_1, dimensionality = 300, diff sigma = [48.62711716 48.52020645 48.52999878]
# Model = HVAE_notemp_1, dimensionality = 300, diff = [345.24014282 405.03814697 388.33889771]
# Model = HVAE_notemp_2, dimensionality = 300, diff delta = [297.27651978 356.78497314 340.37545776]
# Model = HVAE_notemp_2, dimensionality = 300, diff sigma = [153.96548462 154.07287598 153.96112061]
# Model = HVAE_notemp_2, dimensionality = 300, diff = [451.24200439 510.85784912 494.33657837]

# %%
for name in model_names:
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, mean diff delta = {diff_delta_results[name].mean()}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, mean diff sigma = {diff_sigma_results[name].mean()}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, mean diff = {diff_results[name].mean()}")
# Out:
# Model = HVAE_notemp_1, dimensionality = 300, mean diff delta = 330.97996012369794
# Model = HVAE_notemp_1, dimensionality = 300, mean diff sigma = 48.5591074625651
# Model = HVAE_notemp_1, dimensionality = 300, mean diff = 379.5390625
# Model = HVAE_notemp_2, dimensionality = 300, mean diff delta = 331.47898356119794
# Model = HVAE_notemp_2, dimensionality = 300, mean diff sigma = 153.99982706705728
# Model = HVAE_notemp_2, dimensionality = 300, mean diff = 485.4788106282552

# %%
dim_arr = [25, 50, 100, 200, 300]
hvae_1_theta_diff = [22.289, 51.340, 101.332, 196.822, 331.271]
hvae_2_theta_diff = [22.206, 51.189, 101.418, 196.681, 331.726]
nf_1_theta_diff = [37.226, 81.842, 163.513, 322.498, 558.192]
nf_2_theta_diff = [37.301, 81.922, 163.243, 322.274, 520.293]
vb_theta_diff = [17.340, 43.769, 112.271, 270.123, 679.850]

fig = plt.figure(figsize = (10, 5))
plt.xlabel("Dimensionality")
plt.ylabel(r"$\|\theta_{true} - \theta_{result}\|^{2}$")
plt.grid(True)
plt.title(r'Learning $\theta$, 2000-4000 iterations, batch size = 256')
plt.plot(dim_arr, hvae_1_theta_diff, 'b', label = f"HVAE, K = {params['HVAE_K_1']}")
plt.plot(dim_arr, hvae_2_theta_diff, 'g', label = f"HVAE, K = {params['HVAE_K_2']}")
plt.plot(dim_arr, nf_1_theta_diff, 'r', label = f"NF, K = {params['NF_K_1']}")
plt.plot(dim_arr, nf_2_theta_diff, 'black', label = f"NF, K = {params['NF_K_2']}")
plt.plot(dim_arr, vb_theta_diff, 'purple', label = f"VB")
plt.legend()
plt.yscale("log")
plt.show()

# %%
import matplotlib.pyplot as plt
dim_arr = [25, 50, 100, 200, 300, 400]

hvae_1_theta_diff = [22.289, 51.340, 101.332, 196.822, 331.271, 390.17012]
hvae_2_theta_diff = [22.206, 51.189, 101.418, 196.681, 331.726, 390.458]
nf_1_theta_diff = [37.226, 81.842, 163.513, 322.498, 558.192, 641.721]
nf_2_theta_diff = [37.301, 81.922, 163.243, 322.274, 520.293, 641.768]
vb_theta_diff = [17.340, 43.769, 112.271, 270.123, 679.850, 926.496]
iaf_theta_diff = [23.181, 52.036, 108.319, 218.984, 283.2829, 394.344]

hvae_notemp_1_theta_diff = [26.135, 59.126, 117.464, 228.607, 379.539]
hvae_notemp_2_theta_diff = [34.784, 76.350, 152.488, 298.795,  485.478]

fig, axs = plt.subplots(1, 2, figsize = (20, 5))
axs[0].set_xlabel("Dimensionality")
axs[0].set_ylabel(r"$\|\theta_{true} - \theta_{result}\|^{2}$")
axs[0].grid(True)
axs[0].set_title(r'Learning $\theta$, 2000-4000 iterations, batch size = 256')
axs[0].plot(dim_arr, hvae_1_theta_diff, 'b', label = f"HVAE, K = {1}")
axs[0].plot(dim_arr, hvae_2_theta_diff, 'g', label = f"HVAE, K = {10}")
axs[0].plot(dim_arr, nf_1_theta_diff, 'r', label = f"PNF, K = {1}")
axs[0].plot(dim_arr, nf_2_theta_diff, 'black', label = f"PNF, K = {30}")
axs[0].plot(dim_arr, vb_theta_diff, 'purple', label = f"VB")
axs[0].plot(dim_arr, iaf_theta_diff, 'violet', label = f"IAF, K = {1}")
axs[0].legend()
axs[0].set_yscale("log")

axs[1].set_xlabel("Dimensionality")
axs[1].set_ylabel(r"$\|\theta_{true} - \theta_{result}\|^{2}$")
axs[1].grid(True)
axs[1].set_title(r'Learning $\theta$, 2000-4000 iterations, batch size = 256')
axs[1].plot(dim_arr[:5], hvae_1_theta_diff[:5], 'b', label = r"HVAE, $K = 1$")
axs[1].plot(dim_arr[:5], hvae_2_theta_diff[:5], 'g', label = r"HVAE, $K = 10$")
axs[1].plot(dim_arr[:5], hvae_notemp_1_theta_diff, 'r', label = r"HVAE, $K = 1$, $\beta_{0} = 1$")
axs[1].plot(dim_arr[:5], hvae_notemp_2_theta_diff, 'purple', label = r"HVAE, $K = 10$, $\beta_{0} = 1$")
axs[1].legend()
axs[1].set_yscale("log")
plt.show()

# %%
for name in model_names:
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, mean diff delta = {diff_delta_results[name].mean()}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, mean diff sigma = {diff_sigma_results[name].mean()}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, mean diff = {diff_results[name].mean()}")
# Out:
# Model = HVAE_1, dimensionality = 300, mean diff delta = 330.77086385091144
# Model = HVAE_1, dimensionality = 300, mean diff sigma = 0.5004732410113016
# Model = HVAE_1, dimensionality = 300, mean diff = 331.27134195963544
# Model = HVAE_2, dimensionality = 300, mean diff delta = 331.27587890625
# Model = HVAE_2, dimensionality = 300, mean diff sigma = 0.45022286971410114
# Model = HVAE_2, dimensionality = 300, mean diff = 331.72609456380206
# Model = NF_1, dimensionality = 300, mean diff delta = 335.35467529296875
# Model = NF_1, dimensionality = 300, mean diff sigma = 222.8373819986979
# Model = NF_1, dimensionality = 300, mean diff = 558.1920572916666
# Model = NF_2, dimensionality = 300, mean diff delta = 331.4223937988281
# Model = NF_2, dimensionality = 300, mean diff sigma = 188.87073771158853
# Model = NF_2, dimensionality = 300, mean diff = 520.2931213378906
# Model = VB, dimensionality = 300, mean diff delta = 679.8463948567709
# Model = VB, dimensionality = 300, mean diff sigma = 0.003903571516275406
# Model = VB, dimensionality = 300, mean diff = 679.8503011067709

# %%
dim_arr = [25, 50, 100, 200, 300, 400]

hvae_1_delta_diff = [22.249, 51.257, 101.165, 196.487, 330.770, 389.562]
hvae_2_delta_diff = [22.168, 51.112, 101.264, 196.373, 331.275, 389.853]
nf_1_delta_diff = [22.255, 51.198, 101.134, 196.637, 335.354, 389.607]
nf_2_delta_diff = [22.329, 51.183, 101.175, 196.850, 331.422, 389.324]
vb_delta_diff = [17.340, 43.769, 112.270, 270.120, 679.84, 926.496]
iaf_delta_diff = [22.0402, 49.8763, 104.136, 210.8027, 271.0732, 378.017]

hvae_1_sigma_diff = [0.04025, 0.08303, 0.16670, 0.33494, 0.50047, 0.607]
hvae_2_sigma_diff = [0.03827, 0.07728, 0.15395, 0.30777,  0.45022, 0.605]
nf_1_sigma_diff = [14.971, 30.644, 62.379, 125.860, 222.837, 252.114]
nf_2_sigma_diff = [14.971, 30.739, 62.068, 125.42, 188.870, 252.44]
vb_sigma_diff = [0.00031, 0.00075, 0.00150, 0.00291, 0.00390, 0.00529]
iaf_sigma_diff = [1.14152, 2.15999, 4.1821, 8.1820, 12.20969, 16.327]

fig, axs = plt.subplots(1, 2, figsize = (20, 5))
axs[0].set_xlabel("Dimensionality")
axs[0].set_ylabel(r"$\|\Delta_{true} - \Delta_{result}\|^{2}$")
axs[0].grid(True)
axs[0].set_title(r'Learning $\Delta$, 2000-4000 iterations, batch size = 256')
axs[0].plot(dim_arr, hvae_1_delta_diff, 'b', label = f"HVAE, K = {1}")
axs[0].plot(dim_arr, hvae_2_delta_diff, 'g', label = f"HVAE, K = {10}")
axs[0].plot(dim_arr, nf_1_delta_diff, 'r', label = f"PNF, K = {1}")
axs[0].plot(dim_arr, nf_2_delta_diff, 'black', label = f"PNF, K = {30}")
axs[0].plot(dim_arr, vb_delta_diff, 'purple', label = f"VB")
axs[0].plot(dim_arr, iaf_delta_diff, 'violet', label = f"IAF, K = {1}")
axs[0].legend()
axs[0].set_yscale("log")

axs[1].set_xlabel("Dimensionality")
axs[1].set_ylabel(r"$\|\Sigma_{true} - \Sigma_{result}\|^{2}$")
axs[1].grid(True)
axs[1].set_title(r'Learning $\Sigma$, 2000-4000 iterations, batch size = 256')
axs[1].plot(dim_arr, hvae_1_sigma_diff, 'b', label = f"HVAE, K = {1}")
axs[1].plot(dim_arr, hvae_2_sigma_diff, 'g', label = f"HVAE, K = {10}")
axs[1].plot(dim_arr, nf_1_sigma_diff, 'r', label = f"PNF, K = {1}")
axs[1].plot(dim_arr, nf_2_sigma_diff, 'black', label = f"PNF, K = {30}")
axs[1].plot(dim_arr, vb_sigma_diff, 'purple', label = f"VB")
axs[1].plot(dim_arr, iaf_sigma_diff, 'violet', label = f"IAF, K = {1}")
axs[1].legend()
axs[1].set_yscale("log")
plt.show()

# %%
dim_arr = [25, 50, 100, 200, 300, 400]

hvae_1_delta_diff = [22.249, 51.257, 101.165, 196.487, 330.770, 389.562]
hvae_2_delta_diff = [22.168, 51.112, 101.264, 196.373, 331.275, 389.853]
nf_1_delta_diff = [22.255, 51.198, 101.134, 196.637, 335.354, 389.607]
nf_2_delta_diff = [22.329, 51.183, 101.175, 196.850, 331.422, 389.324]
vb_delta_diff = [17.340, 43.769, 112.270, 270.120, 679.84, 926.496]
iaf_delta_diff = [22.0402, 49.8763, 104.136, 210.8027, 271.0732, 378.017]

hvae_1_sigma_diff = [0.04025, 0.08303, 0.16670, 0.33494, 0.50047, 0.607]
hvae_2_sigma_diff = [0.03827, 0.07728, 0.15395, 0.30777,  0.45022, 0.605]
nf_1_sigma_diff = [14.971, 30.644, 62.379, 125.860, 222.837, 252.114]
nf_2_sigma_diff = [14.971, 30.739, 62.068, 125.42, 188.870, 252.44]
vb_sigma_diff = [0.00031, 0.00075, 0.00150, 0.00291, 0.00390, 0.00529]
iaf_sigma_diff = [1.14152, 2.15999, 4.1821, 8.1820, 12.20969, 16.327]

fig = plt.figure(figsize = (12, 6))

plt.xlabel("Dimensionality")
plt.ylabel(r"$\|\Delta_{true} - \Delta_{result}\|^{2}$")
plt.grid(True)
plt.title(r'Learning $\Delta$, 2000-4000 iterations, batch size = 256')
plt.plot(dim_arr, hvae_1_delta_diff, 'b', label = f"HVAE, K = {1}")
plt.plot(dim_arr, hvae_2_delta_diff, 'g', label = f"HVAE, K = {10}")
plt.plot(dim_arr, nf_1_delta_diff, 'r', label = f"PNF, K = {1}")
plt.plot(dim_arr, nf_2_delta_diff, 'black', label = f"PNF, K = {30}")
plt.plot(dim_arr, vb_delta_diff, 'purple', label = f"VB")
plt.plot(dim_arr, iaf_delta_diff, 'violet', label = f"IAF, K = {1}")
plt.legend()
plt.yscale("log")
plt.show()

# %%
dim_arr = [25, 50, 100, 200, 300, 400]

hvae_1_delta_diff = [22.249, 51.257, 101.165, 196.487, 330.770, 389.562]
hvae_2_delta_diff = [22.168, 51.112, 101.264, 196.373, 331.275, 389.853]
nf_1_delta_diff = [22.255, 51.198, 101.134, 196.637, 335.354, 389.607]
nf_2_delta_diff = [22.329, 51.183, 101.175, 196.850, 331.422, 389.324]
vb_delta_diff = [17.340, 43.769, 112.270, 270.120, 679.84, 926.496]
iaf_delta_diff = [22.0402, 49.8763, 104.136, 210.8027, 271.0732, 378.017]

hvae_1_sigma_diff = [0.04025, 0.08303, 0.16670, 0.33494, 0.50047, 0.607]
hvae_2_sigma_diff = [0.03827, 0.07728, 0.15395, 0.30777,  0.45022, 0.605]
nf_1_sigma_diff = [14.971, 30.644, 62.379, 125.860, 222.837, 252.114]
nf_2_sigma_diff = [14.971, 30.739, 62.068, 125.42, 188.870, 252.44]
vb_sigma_diff = [0.00031, 0.00075, 0.00150, 0.00291, 0.00390, 0.00529]
iaf_sigma_diff = [1.14152, 2.15999, 4.1821, 8.1820, 12.20969, 16.327]

fig = plt.figure(figsize = (12, 6))

plt.xlabel("Dimensionality")
plt.ylabel(r"$\|\Sigma_{true} - \Sigma_{result}\|^{2}$")
plt.grid(True)
plt.title(r'Learning $\Sigma$, 2000-4000 iterations, batch size = 256')
plt.plot(dim_arr, hvae_1_sigma_diff, 'b', label = f"HVAE, K = {1}")
plt.plot(dim_arr, hvae_2_sigma_diff, 'g', label = f"HVAE, K = {10}")
plt.plot(dim_arr, nf_1_sigma_diff, 'r', label = f"PNF, K = {1}")
plt.plot(dim_arr, nf_2_sigma_diff, 'black', label = f"PNF, K = {30}")
plt.plot(dim_arr, vb_sigma_diff, 'purple', label = f"VB")
plt.plot(dim_arr, iaf_sigma_diff, 'violet', label = f"IAF, K = {1}")
plt.legend()
plt.yscale("log")
plt.show()

# %%
diff_path = os.path.join('save', str(params['dims'][0]), 'HVAE_1_train_0.p')
with open(diff_path, 'rb') as f:
     data = pickle.load(f)
     elbo_1 = data['elbo']
     diff_delta_1 = data['diff_delta']
     diff_sigma_1 = data['diff_sigma']
     diff_1 = diff_delta_1 + diff_sigma_1

diff_path = os.path.join('save', str(params['dims'][0]), 'HVAE_2_train_0.p')
with open(diff_path, 'rb') as f:
     data = pickle.load(f)
     elbo_2 = data['elbo']
     diff_delta_2 = data['diff_delta']
     diff_sigma_2 = data['diff_sigma']
     diff_2 = diff_delta_2 + diff_sigma_2

fig, axs = plt.subplots(2, 2, figsize = (20, 10))
fig.suptitle(f"Learning HVAE,  saving epoch every = {params['save_every']}, dim = {2}")
axs[0, 0].set_xlabel("#epoch")
axs[0, 0].set_ylabel("ELBO")
axs[0, 1].set_xlabel("#epoch")
axs[0, 1].set_ylabel(r"$\|\theta_{true} - \theta_{epoch}\|^{2}$")
axs[1, 0].set_xlabel("#epoch")
axs[1, 0].set_ylabel("$\|\delta_{true} - \delta_{epoch}\|^{2}$")
axs[1, 1].set_xlabel("#epoch")
axs[1, 1].set_ylabel("$\|\Sigma_{true} - \Sigma_{epoch}\|^{2}$")
axs[0, 0].grid(True)
axs[0, 1].grid(True)
axs[1, 0].grid(True)
axs[1, 1].grid(True)
axs[0, 0].set_title('ELBO')
axs[0, 1].set_title(r'Learning $\theta$')
axs[1, 0].set_title(r'Learning $\Sigma$')
axs[1, 1].set_title(r'Learning $\delta$')
axs[0, 0].plot(elbo_1[1:], 'b', label = f"K = {params['HVAE_K_1']}")
axs[0, 0].plot(elbo_2[1:], 'r', label = f"K = {params['HVAE_K_2']}")
axs[0, 1].plot(diff_1[1:], 'b', label = f"K = {params['HVAE_K_1']}")
axs[0, 1].plot(diff_2[1:], 'r', label = f"K = {params['HVAE_K_2']}")
axs[1, 0].plot(diff_delta_1[1:], 'b', label = f"K = {params['HVAE_K_1']}")
axs[1, 0].plot(diff_delta_2[1:], 'r', label = f"K = {params['HVAE_K_2']}")
axs[1, 1].plot(diff_sigma_1[1:], 'b', label = f"K = {params['HVAE_K_1']}")
axs[1, 1].plot(diff_sigma_2[1:], 'r', label = f"K = {params['HVAE_K_2']}")
axs[0, 0].hlines(elbo_1[0], 0, len(elbo_1), 'g', label = r'$ELBO_{init}$')
axs[0, 1].hlines(diff_1[0], 0, len(diff_1), 'g', label = r'$\|\theta_{true} - \theta_{init}\|^{2}$')
axs[1, 0].hlines(diff_delta_1[0], 0, len(diff_delta_1), 'g', label = r'$\|\delta_{true} - \delta_{init}\|^{2}$')
axs[1, 1].hlines(diff_sigma_1[0], 0, len(diff_sigma_1), 'g', label = r'$\|\Sigma_{true} - \Sigma_{init}\|^{2}$')
axs[0, 0].legend()
axs[0, 1].legend()
axs[1, 0].legend()
axs[1, 1].legend()
axs[0, 1].set_yscale('log')
#axs[1, 0].set_yscale('log')
axs[1, 1].set_yscale('log')
plt.show()
print(f"Init ELBO = {elbo_1[0]}, HVAE-1: result ELBO = {elbo_1[-1]}, HVAE-2: result ELBO = {elbo_2[-1]}")
print(f"Init diff theta = {diff_1[0]}, HVAE-1: result diff theta = {diff_1[-1]}, HVAE-2: result diff theta = {diff_2[-1]}")
print(f"Init diff delta = {diff_delta_1[0]}, HVAE-1: result diff delta = {diff_delta_1[-1]}, HVAE-2: result diff theta = {diff_delta_2[-1]}")
print(f"Init diff sigma = {diff_sigma_1[0]}, HVAE-1: result diff sigma = {diff_sigma_1[-1]}, HVAE-2: result diff theta = {diff_sigma_2[-1]}")

# %%
diff_path = os.path.join('save', str(300), 'NF_1_train_0.p')
with open(diff_path, 'rb') as f:
     data = pickle.load(f)
     elbo_1 = data['elbo']
     diff_delta_1 = data['diff_delta']
     diff_sigma_1 = data['diff_sigma']
     diff_1 = diff_delta_1 + diff_sigma_1

diff_path = os.path.join('save', str(300), 'NF_2_train_0.p')
with open(diff_path, 'rb') as f:
     data = pickle.load(f)
     elbo_2 = data['elbo']
     diff_delta_2 = data['diff_delta']
     diff_sigma_2 = data['diff_sigma']
     diff_2 = diff_delta_2 + diff_sigma_2

fig, axs = plt.subplots(2, 2, figsize = (20, 10))
fig.suptitle(f"Learning NF,  saving epoch every = {params['save_every']}, dim = {300}")
axs[0, 0].set_xlabel("#epoch")
axs[0, 0].set_ylabel("ELBO")
axs[0, 1].set_xlabel("#epoch")
axs[0, 1].set_ylabel(r"$\|\theta_{true} - \theta_{epoch}\|^{2}$")
axs[1, 0].set_xlabel("#epoch")
axs[1, 0].set_ylabel("$\|\delta_{true} - \delta_{epoch}\|^{2}$")
axs[1, 1].set_xlabel("#epoch")
axs[1, 1].set_ylabel("$\|\Sigma_{true} - \Sigma_{epoch}\|^{2}$")
axs[0, 0].grid(True)
axs[0, 1].grid(True)
axs[1, 0].grid(True)
axs[1, 1].grid(True)
axs[0, 0].set_title('ELBO')
axs[0, 1].set_title(r'Learning $\theta$')
axs[1, 0].set_title(r'Learning $\Sigma$')
axs[1, 1].set_title(r'Learning $\delta$')
axs[0, 0].plot(elbo_1[1:], 'b', label = f"K = {params['NF_K_1']}")
axs[0, 0].plot(elbo_2[1:], 'r', label = f"K = {params['NF_K_2']}")
axs[0, 1].plot(diff_1[1:], 'b', label = f"K = {params['NF_K_1']}")
axs[0, 1].plot(diff_2[1:], 'r', label = f"K = {params['NF_K_2']}")
axs[1, 0].plot(diff_delta_1[1:], 'b', label = f"K = {params['NF_K_1']}")
axs[1, 0].plot(diff_delta_2[1:], 'r', label = f"K = {params['NF_K_2']}")
axs[1, 1].plot(diff_sigma_1[1:], 'b', label = f"K = {params['NF_K_1']}")
axs[1, 1].plot(diff_sigma_2[1:], 'r', label = f"K = {params['NF_K_2']}")
axs[0, 0].hlines(elbo_1[0], 0, len(elbo_1), 'g', label = r'$ELBO_{init}$')
axs[0, 1].hlines(diff_1[0], 0, len(diff_1), 'g', label = r'$\|\theta_{true} - \theta_{init}\|^{2}$')
axs[1, 0].hlines(diff_delta_1[0], 0, len(diff_delta_1), 'g', label = r'$\|\delta_{true} - \delta_{init}\|^{2}$')
axs[1, 1].hlines(diff_sigma_1[0], 0, len(diff_sigma_1), 'g', label = r'$\|\Sigma_{true} - \Sigma_{init}\|^{2}$')
axs[0, 0].legend()
axs[0, 1].legend()
axs[1, 0].legend()
axs[1, 1].legend()
axs[0, 1].set_yscale('log')
#axs[1, 0].set_yscale('log')
axs[1, 1].set_yscale('log')
plt.show()
print(f"Init ELBO = {elbo_1[0]}, NF-1: result ELBO = {elbo_1[-1]}, NF-2: result ELBO = {elbo_2[-1]}")
print(f"Init diff theta = {diff_1[0]}, NFE-1: result diff theta = {diff_1[-1]}, NF-2: result diff theta = {diff_2[-1]}")
print(f"Init diff delta = {diff_delta_1[0]}, NF-1: result diff delta = {diff_delta_1[-1]}, NF-2: result diff delta = {diff_delta_2[-1]}")
print(f"Init diff sigma = {diff_sigma_1[0]}, NF-1: result diff sigma = {diff_sigma_1[-1]}, NF-2: result diff sigma = {diff_sigma_2[-1]}")
# Out:
# Init ELBO = -14011409.0, NF-1: result ELBO = -4733919.0, NF-2: result ELBO = -4794300.0
# Init diff theta = 206253.296875, NFE-1: result diff theta = 492.0887756347656, NF-2: result diff theta = 477.0177001953125
# Init diff delta = 89999.0078125, NF-1: result diff delta = 282.27239990234375, NF-2: result diff theta = 282.5074157714844
# Init diff sigma = 116254.2890625, NF-1: result diff sigma = 209.81637573242188, NF-2: result diff theta = 194.51026916503906

# %%
# !pip install pyro-ppl
# Out:
# Collecting pyro-ppl
#   Downloading https://files.pythonhosted.org/packages/3d/1b/946ff38dd8675b8fa114444df0940db078eb42e5354df46645a9e9467085/pyro_ppl-1.5.0-py3-none-any.whl (604kB)
#      |████████████████████████████████| 614kB 4.8MB/s
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from pyro-ppl) (3.3.0)
# Collecting pyro-api>=0.1.1
#   Downloading https://files.pythonhosted.org/packages/fc/81/957ae78e6398460a7230b0eb9b8f1cb954c5e913e868e48d89324c68cec7/pyro_api-0.1.2-py3-none-any.whl
# Requirement already satisfied: tqdm>=4.36 in /usr/local/lib/python3.6/dist-packages (from pyro-ppl) (4.41.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from pyro-ppl) (1.6.0+cu101)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from pyro-ppl) (1.18.5)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch>=1.6.0->pyro-ppl) (0.16.0)
# Installing collected packages: pyro-api, pyro-ppl
# Successfully installed pyro-api-0.1.2 pyro-ppl-1.5.0

# %%
# !rm -r h-vae/
# !git clone https://github.com/Daniil-Selikhanovych/h-vae
# Out:
# Cloning into 'h-vae'...
# remote: Enumerating objects: 106, done.
# remote: Counting objects: 100% (106/106), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 106 (delta 32), reused 97 (delta 26), pack-reused 0
# Receiving objects: 100% (106/106), 400.62 KiB | 19.08 MiB/s, done.
# Resolving deltas: 100% (32/32), done.

# %%
path_to_gaussians = os.path.join(os.getcwd(), 'h-vae', 'gaussians')
path_to_gaussians_api = os.path.join(path_to_gaussians, 'api')

sys.path.append(path_to_gaussians)
sys.path.append(path_to_gaussians_api)

# %%
from models import HVAE, NF, VB, IAF

# %%
def run_test(d, params, 
             batch_size=256,
             clip_value=None,
             dtype=torch.float32, 
             device=torch.device("cpu")):
    """ 
    Run the gaussian test with dimension d 
    """

    ######### Problem Specification

    # Data generation parameters
    prior_mu_z = torch.zeros(d, dtype=dtype)    # Prior mean
    prior_sigma_z = torch.eye(d, dtype=dtype)   # Prior covariance matrix

    # True model parameters
    num_range = torch.arange(-(d-1)/2, (d+1)/2, dtype=dtype)

    t_delta =  num_range / 5 

    print(f"true delta = {t_delta.numpy()}")

    if d == 1:
        t_sigma = torch.ones(1, dtype=dtype)
    else: 
        # Allow sigma to range from 0.1 to 1
        t_sigma = 36/(10*(d-1)**2) * num_range**2 + 0.1 
    print(f"true sigma = {t_sigma.numpy()}")

    ######### Variable Initialization

    # Initial model parameters - same across all methods
    init_delta = prior_mu_z.clone().to(device)
    init_log_sigma = 3 * torch.ones(d).to(device)

    # Initial HVAE variational parameters
    init_T = torch.tensor(5., dtype=dtype, device=device)
    init_eps = 0.005 * torch.ones(d, dtype=dtype)
    max_eps = params['max_eps'] * torch.ones(d, dtype=dtype)
    init_logit_eps = torch.log(init_eps/(max_eps - init_eps)).to(device)
    init_log_T_0 = torch.log(init_T - 1)

    # Initial NF variational parameters
    init_u_pre_reparam = torch.tensor(scipy.stats.truncnorm.rvs(-2, 2, 
                                                                scale=0.1, 
                                                                size=d),
                                      dtype=dtype, device=device)
    init_w = torch.tensor(scipy.stats.truncnorm.rvs(-2, 2, scale=0.1, size=d),
                          dtype=dtype, device=device)
    init_b = torch.tensor(0.1, dtype=dtype, device=device)

    # Initial VAE parameters
    init_mu_z = prior_mu_z.clone()
    init_log_sigma_z = torch.ones(d, dtype=dtype)

    ######### Set up models
    init_params = [[init_delta, init_log_sigma],
                   [init_delta, init_log_sigma]]
    
    hid_dim = d + 100
    IAF_model = IAF(params,
        ['delta', 'log_sigma'],
        init_params[0], 
        'IAF', d, 1, hid_dim)

    #model_list = [HVAE_model_1, HVAE_model_2, NF_model_1]
    #model_list = [HVAE_model_1, NF_model_1]
    model_list = [IAF_model]

    print("Models were initialized!")
    
    ######### Generate Training Data & Save - One for each test

    train_data_list = []

    for i in range(params['n_tests']):
        z = MultivariateNormal(prior_mu_z, prior_sigma_z).sample()
        x = MultivariateNormal(z + t_delta, 
                               torch.diag(t_sigma**2)).sample([params['n_data']])
        x = x.to(device)
        train_data_list.append(x)

    # Folder should have already been created in the initializations
    data_path = os.path.join('save', str(d), 'train_data.p')
    pickle.dump(train_data_list, open(data_path, 'wb')) 

    # Store the final parameter values for all test runs in this dictionary
    final_params = {}

    for i in range(len(model_list)):
        final_values = []
        m = model_list[i]
        model_init_params = init_params[i]

        for j in range(params['n_tests']):
            print("------------------------------------------------------")
            print(f"Test = {j}")
            print("------------------------------------------------------")
            m._reinitialize(model_init_params)
            gaussian_data = gaussian_dataset(train_data_list[j])
            train_dataloader = DataLoader(gaussian_data, batch_size=batch_size,
                                          shuffle=False, num_workers=0)
            (delta, sigma) = m.train(train_dataloader, j, 
                                     t_delta, t_sigma,
                                     clip_value)
            final_values.append((delta, sigma))

        final_params[m.model_name] = final_values.copy()

    ######### Test models using difference between parameters

    param_diffs = {}

    for m in model_list:
        
        diffs = []

        for i in range(params['n_tests']):
            delta = final_params[m.model_name][i][0]
            sigma = final_params[m.model_name][i][1]

            delta_diff = np.sum((delta - t_delta.numpy())**2)
            sigma_diff = np.sum((sigma - t_sigma.numpy())**2)
            theta_diff = delta_diff + sigma_diff
            print(f"Model {m.model_name}, test = {i}, result delta diff = {delta_diff}")
            print(f"Model {m.model_name}, test = {i}, result sigma diff = {sigma_diff}")
            print(f"Model {m.model_name}, test = {i}, result theta diff = {theta_diff}")

            diffs.append((delta_diff, sigma_diff, theta_diff))

        param_diffs[m.model_name] = diffs.copy()

    # Save parameter differences in a pickle file
    diff_path = os.path.join('save', str(d), 'all_diffs.p')
    pickle.dump(param_diffs, open(diff_path, 'wb'))

# %%
device = torch.device("cpu")
dtype = torch.float32
clip_value = None
batch_size = 256

# %%
params = {

    # PROBLEM SPECIFICATION
    #'dims': [1, 2, 3, 5, 11, 25, 51, 101, 201, 301], # Dimensions to test
    'dims': [200],
    'n_data': 10000,                                 # Number of data points

    # TEST HYPERPARAMETERS
    'n_tests': 3,      # Number of experiments to run

    # GLOBAL OPTIMIZATION PARAMETERS
    'n_iter': 2000,    # Number of optimization iterations
    'n_batch': 10,      # Number of points for ELBO estimate
    'rms_eta': 0.001,   # Stepsize for RMSProp
    'save_every': 20,   # Save parameter information every so often
    'print_every': 20, # Print less often than save

    # HVAE HYPERPARAMETERS
    'HVAE_K_1': 1,    # Number of leapfrog/cooling steps for HVAE flow 1
    'HVAE_K_2': 10,   # Number of leapfrog/cooling steps for HVAE flow 2
    'max_eps': 0.5,   # Maximum leapfrog step size per dimension 

    # NF HYPERPARAMETERS
    'NF_K_1': 1,    # Number of flow steps for NF flow 1
    'NF_K_2': 30,   # Number of flow steps for NF flow 2
    
}

# %%
dims = params['dims']
seed = 12345
np.random.seed(seed)
torch.manual_seed(seed)
for d in dims:
    print('**** Running test for d={0:d} ****'.format(d))
    run_test(d, params, batch_size, clip_value, dtype, device)
# Out:
# **** Running test for d=200 ****
# true delta = [-19.9 -19.7 -19.5 -19.3 -19.1 -18.9 -18.7 -18.5 -18.3 -18.1 -17.9 -17.7
#  -17.5 -17.3 -17.1 -16.9 -16.7 -16.5 -16.3 -16.1 -15.9 -15.7 -15.5 -15.3
#  -15.1 -14.9 -14.7 -14.5 -14.3 -14.1 -13.9 -13.7 -13.5 -13.3 -13.1 -12.9
#  -12.7 -12.5 -12.3 -12.1 -11.9 -11.7 -11.5 -11.3 -11.1 -10.9 -10.7 -10.5
#  -10.3 -10.1  -9.9  -9.7  -9.5  -9.3  -9.1  -8.9  -8.7  -8.5  -8.3  -8.1
#   -7.9  -7.7  -7.5  -7.3  -7.1  -6.9  -6.7  -6.5  -6.3  -6.1  -5.9  -5.7
#   -5.5  -5.3  -5.1  -4.9  -4.7  -4.5  -4.3  -4.1  -3.9  -3.7  -3.5  -3.3
#   -3.1  -2.9  -2.7  -2.5  -2.3  -2.1  -1.9  -1.7  -1.5  -1.3  -1.1  -0.9
#   -0.7  -0.5  -0.3  -0.1   0.1   0.3   0.5   0.7   0.9   1.1   1.3   1.5
#    1.7   1.9   2.1   2.3   2.5   2.7   2.9   3.1   3.3   3.5   3.7   3.9
#    4.1   4.3   4.5   4.7   4.9   5.1   5.3   5.5   5.7   5.9   6.1   6.3
#    6.5   6.7   6.9   7.1   7.3   7.5   7.7   7.9   8.1   8.3   8.5   8.7
#    8.9   9.1   9.3   9.5   9.7   9.9  10.1  10.3  10.5  10.7  10.9  11.1
#   11.3  11.5  11.7  11.9  12.1  12.3  12.5  12.7  12.9  13.1  13.3  13.5
#   13.7  13.9  14.1  14.3  14.5  14.7  14.9  15.1  15.3  15.5  15.7  15.9
#   16.1  16.3  16.5  16.7  16.9  17.1  17.3  17.5  17.7  17.9  18.1  18.3
#   18.5  18.7  18.9  19.1  19.3  19.5  19.7  19.9]
# true sigma = [1.         0.98200047 0.96418273 0.94654685 0.92909276 0.9118205
#  0.89473    0.8778213  0.8610945  0.8445494  0.8281862  0.8120048
#  0.7960052  0.7801874  0.76455146 0.7490973  0.7338249  0.7187344
#  0.7038257  0.6890988  0.6745537  0.6601904  0.64600897 0.6320093
#  0.6181915  0.6045555  0.5911012  0.5778289  0.5647383  0.5518295
#  0.53910255 0.52655745 0.51419413 0.5020126  0.49001288 0.47819498
#  0.46655893 0.45510468 0.44383222 0.43274158 0.42183277 0.41110578
#  0.4005606  0.39019722 0.38001564 0.37001592 0.36019796 0.35056186
#  0.34110755 0.33183506 0.32274437 0.3138355  0.30510846 0.2965632
#  0.2881998  0.28001818 0.27201837 0.2642004  0.25656423 0.24910986
#  0.24183732 0.2347466  0.22783768 0.22111058 0.21456529 0.20820183
#  0.20202015 0.1960203  0.19020227 0.18456605 0.17911164 0.17383905
#  0.16874826 0.16383931 0.15911214 0.15456681 0.15020329 0.14602157
#  0.14202167 0.13820359 0.1345673  0.13111286 0.1278402  0.12474938
#  0.12184036 0.11911315 0.11656776 0.11420419 0.11202242 0.11002248
#  0.10820434 0.10656802 0.10511351 0.10384081 0.10274993 0.10184086
#  0.10111361 0.10056817 0.10020454 0.10002273 0.10002273 0.10020454
#  0.10056817 0.10111361 0.10184086 0.10274993 0.10384081 0.10511351
#  0.10656802 0.10820434 0.11002248 0.11202242 0.11420419 0.11656776
#  0.11911315 0.12184036 0.12474938 0.1278402  0.13111286 0.1345673
#  0.13820359 0.14202167 0.14602157 0.15020329 0.15456681 0.15911214
#  0.16383931 0.16874826 0.17383905 0.17911164 0.18456605 0.19020227
#  0.1960203  0.20202015 0.20820183 0.21456529 0.22111058 0.22783768
#  0.2347466  0.24183732 0.24910986 0.25656423 0.2642004  0.27201837
#  0.28001818 0.2881998  0.2965632  0.30510846 0.3138355  0.32274437
#  0.33183506 0.34110755 0.35056186 0.36019796 0.37001592 0.38001564
#  0.39019722 0.4005606  0.41110578 0.42183277 0.43274158 0.44383222
#  0.45510468 0.46655893 0.47819498 0.49001288 0.5020126  0.51419413
#  0.52655745 0.53910255 0.5518295  0.5647383  0.5778289  0.5911012
#  0.6045555  0.6181915  0.6320093  0.64600897 0.6601904  0.6745537
#  0.6890988  0.7038257  0.7187344  0.7338249  0.7490973  0.76455146
#  0.7801874  0.7960052  0.8120048  0.8281862  0.8445494  0.8610945
#  0.8778213  0.89473    0.9118205  0.92909276 0.94654685 0.96418273
#  0.98200047 1.        ]
# Models were initialized!
# ------------------------------------------------------
# Test = 0
# ------------------------------------------------------
# Init diff delta = 26666.0
# Init diff sigma = 77495.03125
# Init diff theta = 104161.03125
# IAF, d: 200, Iter: 1-20, s/iter: 1.755e-01, ELBO: -7.512e+06
# Cur diff delta = 23090.35546875
# Cur diff sigma = 32454.337890625
# Cur diff theta = 55544.693359375
# ---------------------------------------
# IAF, d: 200, Iter: 1-40, s/iter: 1.758e-01, ELBO: -6.936e+06
# Cur diff delta = 20287.501953125
# Cur diff sigma = 24566.541015625
# Cur diff theta = 44854.04296875
# ---------------------------------------
# IAF, d: 200, Iter: 1-60, s/iter: 1.763e-01, ELBO: -6.394e+06
# Cur diff delta = 17752.421875
# Cur diff sigma = 20486.26171875
# Cur diff theta = 38238.68359375
# ---------------------------------------
# IAF, d: 200, Iter: 1-80, s/iter: 1.741e-01, ELBO: -5.818e+06
# Cur diff delta = 15447.9482421875
# Cur diff sigma = 17287.69921875
# Cur diff theta = 32735.6474609375
# ---------------------------------------
# IAF, d: 200, Iter: 1-100, s/iter: 1.752e-01, ELBO: -5.212e+06
# Cur diff delta = 13349.962890625
# Cur diff sigma = 14549.64453125
# Cur diff theta = 27899.607421875
# ---------------------------------------
# IAF, d: 200, Iter: 1-120, s/iter: 1.748e-01, ELBO: -4.706e+06
# Cur diff delta = 11458.4482421875
# Cur diff sigma = 12152.115234375
# Cur diff theta = 23610.5634765625
# ---------------------------------------
# IAF, d: 200, Iter: 1-140, s/iter: 1.757e-01, ELBO: -4.340e+06
# Cur diff delta = 9757.9169921875
# Cur diff sigma = 10056.771484375
# Cur diff theta = 19814.6884765625
# ---------------------------------------
# IAF, d: 200, Iter: 1-160, s/iter: 1.773e-01, ELBO: -4.044e+06
# Cur diff delta = 8234.1025390625
# Cur diff sigma = 8235.7265625
# Cur diff theta = 16469.8291015625
# ---------------------------------------
# IAF, d: 200, Iter: 1-180, s/iter: 1.748e-01, ELBO: -3.730e+06
# Cur diff delta = 6879.12890625
# Cur diff sigma = 6680.7724609375
# Cur diff theta = 13559.9013671875
# ---------------------------------------
# IAF, d: 200, Iter: 1-200, s/iter: 1.759e-01, ELBO: -3.419e+06
# Cur diff delta = 5684.541015625
# Cur diff sigma = 5365.89794921875
# Cur diff theta = 11050.43896484375
# ---------------------------------------
# IAF, d: 200, Iter: 1-220, s/iter: 1.757e-01, ELBO: -3.150e+06
# Cur diff delta = 4644.7666015625
# Cur diff sigma = 4253.18798828125
# Cur diff theta = 8897.95458984375
# ---------------------------------------
# IAF, d: 200, Iter: 1-240, s/iter: 1.751e-01, ELBO: -2.931e+06
# Cur diff delta = 3740.16552734375
# Cur diff sigma = 3319.043701171875
# Cur diff theta = 7059.209228515625
# ---------------------------------------
# IAF, d: 200, Iter: 1-260, s/iter: 1.740e-01, ELBO: -2.697e+06
# Cur diff delta = 2960.923828125
# Cur diff sigma = 2546.740478515625
# Cur diff theta = 5507.664306640625
# ---------------------------------------
# IAF, d: 200, Iter: 1-280, s/iter: 1.767e-01, ELBO: -2.467e+06
# Cur diff delta = 2309.2216796875
# Cur diff sigma = 1914.078125
# Cur diff theta = 4223.2998046875
# ---------------------------------------
# IAF, d: 200, Iter: 1-300, s/iter: 1.741e-01, ELBO: -2.259e+06
# Cur diff delta = 1769.6031494140625
# Cur diff sigma = 1404.848388671875
# Cur diff theta = 3174.4515380859375
# ---------------------------------------
# IAF, d: 200, Iter: 1-320, s/iter: 1.735e-01, ELBO: -2.069e+06
# Cur diff delta = 1330.9459228515625
# Cur diff sigma = 1002.4150390625
# Cur diff theta = 2333.3609619140625
# ---------------------------------------
# IAF, d: 200, Iter: 1-340, s/iter: 1.747e-01, ELBO: -1.894e+06
# Cur diff delta = 984.8380126953125
# Cur diff sigma = 692.3699951171875
# Cur diff theta = 1677.2080078125
# ---------------------------------------
# IAF, d: 200, Iter: 1-360, s/iter: 1.741e-01, ELBO: -1.742e+06
# Cur diff delta = 712.22705078125
# Cur diff sigma = 458.29437255859375
# Cur diff theta = 1170.5214233398438
# ---------------------------------------
# IAF, d: 200, Iter: 1-380, s/iter: 1.770e-01, ELBO: -1.610e+06
# Cur diff delta = 509.9087829589844
# Cur diff sigma = 289.4811096191406
# Cur diff theta = 799.389892578125
# ---------------------------------------
# IAF, d: 200, Iter: 1-400, s/iter: 1.779e-01, ELBO: -1.498e+06
# Cur diff delta = 368.0386657714844
# Cur diff sigma = 172.6044158935547
# Cur diff theta = 540.6430816650391
# ---------------------------------------
# IAF, d: 200, Iter: 1-420, s/iter: 1.819e-01, ELBO: -1.407e+06
# Cur diff delta = 279.6529541015625
# Cur diff sigma = 96.78056335449219
# Cur diff theta = 376.4335174560547
# ---------------------------------------
# IAF, d: 200, Iter: 1-440, s/iter: 1.854e-01, ELBO: -1.340e+06
# Cur diff delta = 230.55398559570312
# Cur diff sigma = 51.10293960571289
# Cur diff theta = 281.656925201416
# ---------------------------------------
# IAF, d: 200, Iter: 1-460, s/iter: 1.908e-01, ELBO: -1.290e+06
# Cur diff delta = 208.54116821289062
# Cur diff sigma = 26.546194076538086
# Cur diff theta = 235.0873622894287
# ---------------------------------------
# IAF, d: 200, Iter: 1-480, s/iter: 1.935e-01, ELBO: -1.263e+06
# Cur diff delta = 204.34774780273438
# Cur diff sigma = 15.019458770751953
# Cur diff theta = 219.36720657348633
# ---------------------------------------
# IAF, d: 200, Iter: 1-500, s/iter: 1.979e-01, ELBO: -1.249e+06
# Cur diff delta = 205.990478515625
# Cur diff sigma = 10.157724380493164
# Cur diff theta = 216.14820289611816
# ---------------------------------------
# IAF, d: 200, Iter: 1-520, s/iter: 2.030e-01, ELBO: -1.243e+06
# Cur diff delta = 210.20594787597656
# Cur diff sigma = 8.540701866149902
# Cur diff theta = 218.74664974212646
# ---------------------------------------
# IAF, d: 200, Iter: 1-540, s/iter: 2.085e-01, ELBO: -1.241e+06
# Cur diff delta = 213.71786499023438
# Cur diff sigma = 8.214323997497559
# Cur diff theta = 221.93218898773193
# ---------------------------------------
# IAF, d: 200, Iter: 1-560, s/iter: 2.146e-01, ELBO: -1.241e+06
# Cur diff delta = 214.7489013671875
# Cur diff sigma = 8.197861671447754
# Cur diff theta = 222.94676303863525
# ---------------------------------------
# IAF, d: 200, Iter: 1-580, s/iter: 2.223e-01, ELBO: -1.241e+06
# Cur diff delta = 214.73927307128906
# Cur diff sigma = 8.19793701171875
# Cur diff theta = 222.9372100830078
# ---------------------------------------
# IAF, d: 200, Iter: 1-600, s/iter: 2.273e-01, ELBO: -1.241e+06
# Cur diff delta = 214.72486877441406
# Cur diff sigma = 8.198460578918457
# Cur diff theta = 222.92332935333252
# ---------------------------------------
# IAF, d: 200, Iter: 1-620, s/iter: 2.298e-01, ELBO: -1.241e+06
# Cur diff delta = 214.7328643798828
# Cur diff sigma = 8.197010040283203
# Cur diff theta = 222.92987442016602
# ---------------------------------------
# IAF, d: 200, Iter: 1-640, s/iter: 2.336e-01, ELBO: -1.241e+06
# Cur diff delta = 214.75582885742188
# Cur diff sigma = 8.198042869567871
# Cur diff theta = 222.95387172698975
# ---------------------------------------
# IAF, d: 200, Iter: 1-660, s/iter: 2.380e-01, ELBO: -1.241e+06
# Cur diff delta = 214.7366943359375
# Cur diff sigma = 8.196722984313965
# Cur diff theta = 222.93341732025146
# ---------------------------------------
# IAF, d: 200, Iter: 1-680, s/iter: 2.412e-01, ELBO: -1.241e+06
# Cur diff delta = 214.75770568847656
# Cur diff sigma = 8.196696281433105
# Cur diff theta = 222.95440196990967
# ---------------------------------------
# IAF, d: 200, Iter: 1-700, s/iter: 2.457e-01, ELBO: -1.241e+06
# Cur diff delta = 214.7190399169922
# Cur diff sigma = 8.196541786193848
# Cur diff theta = 222.91558170318604
# ---------------------------------------
# IAF, d: 200, Iter: 1-720, s/iter: 2.422e-01, ELBO: -1.241e+06
# Cur diff delta = 214.70069885253906
# Cur diff sigma = 8.196588516235352
# Cur diff theta = 222.8972873687744
# ---------------------------------------
# IAF, d: 200, Iter: 1-740, s/iter: 2.459e-01, ELBO: -1.241e+06
# Cur diff delta = 214.77105712890625
# Cur diff sigma = 8.196455955505371
# Cur diff theta = 222.96751308441162
# ---------------------------------------
# IAF, d: 200, Iter: 1-760, s/iter: 2.473e-01, ELBO: -1.241e+06
# Cur diff delta = 214.75326538085938
# Cur diff sigma = 8.196632385253906
# Cur diff theta = 222.94989776611328
# ---------------------------------------
# IAF, d: 200, Iter: 1-780, s/iter: 2.498e-01, ELBO: -1.241e+06
# Cur diff delta = 214.72535705566406
# Cur diff sigma = 8.196609497070312
# Cur diff theta = 222.92196655273438
# ---------------------------------------
# IAF, d: 200, Iter: 1-800, s/iter: 2.515e-01, ELBO: -1.241e+06
# Cur diff delta = 214.73269653320312
# Cur diff sigma = 8.196345329284668
# Cur diff theta = 222.9290418624878
# ---------------------------------------
# IAF, d: 200, Iter: 1-820, s/iter: 2.592e-01, ELBO: -1.241e+06
# Cur diff delta = 214.76734924316406
# Cur diff sigma = 8.197060585021973
# Cur diff theta = 222.96440982818604
# ---------------------------------------
# IAF, d: 200, Iter: 1-840, s/iter: 2.644e-01, ELBO: -1.241e+06
# Cur diff delta = 214.7371826171875
# Cur diff sigma = 8.196877479553223
# Cur diff theta = 222.93406009674072
# ---------------------------------------
# IAF, d: 200, Iter: 1-860, s/iter: 2.712e-01, ELBO: -1.241e+06
# Cur diff delta = 214.73199462890625
# Cur diff sigma = 8.195608139038086
# Cur diff theta = 222.92760276794434
# ---------------------------------------
# IAF, d: 200, Iter: 1-880, s/iter: 2.715e-01, ELBO: -1.241e+06
# Cur diff delta = 214.74388122558594
# Cur diff sigma = 8.195042610168457
# Cur diff theta = 222.9389238357544
# ---------------------------------------
# IAF, d: 200, Iter: 1-900, s/iter: 2.725e-01, ELBO: -1.241e+06
# Cur diff delta = 214.74415588378906
# Cur diff sigma = 8.194635391235352
# Cur diff theta = 222.9387912750244
# ---------------------------------------
# IAF, d: 200, Iter: 1-920, s/iter: 2.714e-01, ELBO: -1.241e+06
# Cur diff delta = 214.7467041015625
# Cur diff sigma = 8.19603443145752
# Cur diff theta = 222.94273853302002
# ---------------------------------------
# IAF, d: 200, Iter: 1-940, s/iter: 2.706e-01, ELBO: -1.241e+06
# Cur diff delta = 214.74180603027344
# Cur diff sigma = 8.196464538574219
# Cur diff theta = 222.93827056884766
# ---------------------------------------
# IAF, d: 200, Iter: 1-960, s/iter: 2.801e-01, ELBO: -1.241e+06
# Cur diff delta = 214.7524871826172
# Cur diff sigma = 8.195659637451172
# Cur diff theta = 222.94814682006836
# ---------------------------------------
# IAF, d: 200, Iter: 1-980, s/iter: 2.807e-01, ELBO: -1.241e+06
# Cur diff delta = 214.7561798095703
# Cur diff sigma = 8.19474983215332
# Cur diff theta = 222.95092964172363
# ---------------------------------------
# IAF, d: 200, Iter: 1-1000, s/iter: 2.804e-01, ELBO: -1.241e+06
# Cur diff delta = 214.75308227539062
# Cur diff sigma = 8.196551322937012
# Cur diff theta = 222.94963359832764
# ---------------------------------------
# IAF, d: 200, Iter: 1-1020, s/iter: 2.816e-01, ELBO: -1.241e+06
# Cur diff delta = 214.73602294921875
# Cur diff sigma = 8.19782543182373
# Cur diff theta = 222.93384838104248
# ---------------------------------------
# IAF, d: 200, Iter: 1-1040, s/iter: 2.894e-01, ELBO: -1.241e+06
# Cur diff delta = 214.7283935546875
# Cur diff sigma = 8.194764137268066
# Cur diff theta = 222.92315769195557
# ---------------------------------------
# IAF, d: 200, Iter: 1-1060, s/iter: 2.911e-01, ELBO: -1.241e+06
# Cur diff delta = 214.75436401367188
# Cur diff sigma = 8.195504188537598
# Cur diff theta = 222.94986820220947
# ---------------------------------------
# IAF, d: 200, Iter: 1-1080, s/iter: 2.926e-01, ELBO: -1.241e+06
# Cur diff delta = 214.76882934570312
# Cur diff sigma = 8.194048881530762
# Cur diff theta = 222.9628782272339
# ---------------------------------------
# IAF, d: 200, Iter: 1-1100, s/iter: 2.941e-01, ELBO: -1.241e+06
# Cur diff delta = 214.74267578125
# Cur diff sigma = 8.196797370910645
# Cur diff theta = 222.93947315216064
# ---------------------------------------
# IAF, d: 200, Iter: 1-1120, s/iter: 2.976e-01, ELBO: -1.241e+06
# Cur diff delta = 214.74305725097656
# Cur diff sigma = 8.196243286132812
# Cur diff theta = 222.93930053710938
# ---------------------------------------
# IAF, d: 200, Iter: 1-1140, s/iter: 3.013e-01, ELBO: -1.241e+06
# Cur diff delta = 214.7563018798828
# Cur diff sigma = 8.196340560913086
# Cur diff theta = 222.9526424407959
# ---------------------------------------
# IAF, d: 200, Iter: 1-1160, s/iter: 3.062e-01, ELBO: -1.241e+06
# Cur diff delta = 214.73049926757812
# Cur diff sigma = 8.194604873657227
# Cur diff theta = 222.92510414123535
# ---------------------------------------
# IAF, d: 200, Iter: 1-1180, s/iter: 2.966e-01, ELBO: -1.241e+06
# Cur diff delta = 214.7306365966797
# Cur diff sigma = 8.194637298583984
# Cur diff theta = 222.92527389526367
# ---------------------------------------
# IAF, d: 200, Iter: 1-1200, s/iter: 2.938e-01, ELBO: -1.241e+06
# Cur diff delta = 214.74176025390625
# Cur diff sigma = 8.19516372680664
# Cur diff theta = 222.9369239807129
# ---------------------------------------
# IAF, d: 200, Iter: 1-1220, s/iter: 2.915e-01, ELBO: -1.241e+06
# Cur diff delta = 214.7459716796875
# Cur diff sigma = 8.195452690124512
# Cur diff theta = 222.941424369812
# ---------------------------------------
# IAF, d: 200, Iter: 1-1240, s/iter: 2.898e-01, ELBO: -1.241e+06
# Cur diff delta = 214.75306701660156
# Cur diff sigma = 8.19434642791748
# Cur diff theta = 222.94741344451904
# ---------------------------------------
# IAF, d: 200, Iter: 1-1260, s/iter: 2.937e-01, ELBO: -1.241e+06
# Cur diff delta = 214.74600219726562
# Cur diff sigma = 8.194351196289062
# Cur diff theta = 222.9403533935547
# ---------------------------------------
# IAF, d: 200, Iter: 1-1280, s/iter: 2.952e-01, ELBO: -1.241e+06
# Cur diff delta = 214.74130249023438
# Cur diff sigma = 8.194877624511719
# Cur diff theta = 222.9361801147461
# ---------------------------------------
# IAF, d: 200, Iter: 1-1300, s/iter: 2.941e-01, ELBO: -1.241e+06
# Cur diff delta = 214.75856018066406
# Cur diff sigma = 8.195122718811035
# Cur diff theta = 222.9536828994751
# ---------------------------------------
# IAF, d: 200, Iter: 1-1320, s/iter: 2.964e-01, ELBO: -1.241e+06
# Cur diff delta = 214.74794006347656
# Cur diff sigma = 8.19466495513916
# Cur diff theta = 222.94260501861572
# ---------------------------------------
# IAF, d: 200, Iter: 1-1340, s/iter: 2.949e-01, ELBO: -1.241e+06
# Cur diff delta = 214.74435424804688
# Cur diff sigma = 8.193441390991211
# Cur diff theta = 222.9377956390381
# ---------------------------------------
# IAF, d: 200, Iter: 1-1360, s/iter: 2.938e-01, ELBO: -1.241e+06
# Cur diff delta = 214.74343872070312
# Cur diff sigma = 8.194046974182129
# Cur diff theta = 222.93748569488525
# ---------------------------------------
# IAF, d: 200, Iter: 1-1380, s/iter: 2.954e-01, ELBO: -1.241e+06
# Cur diff delta = 214.73898315429688
# Cur diff sigma = 8.195016860961914
# Cur diff theta = 222.9340000152588
# ---------------------------------------
# IAF, d: 200, Iter: 1-1400, s/iter: 2.957e-01, ELBO: -1.241e+06
# Cur diff delta = 214.7757568359375
# Cur diff sigma = 8.194036483764648
# Cur diff theta = 222.96979331970215
# ---------------------------------------
# IAF, d: 200, Iter: 1-1420, s/iter: 2.968e-01, ELBO: -1.241e+06
# Cur diff delta = 214.7746124267578
# Cur diff sigma = 8.193528175354004
# Cur diff theta = 222.96814060211182
# ---------------------------------------
# IAF, d: 200, Iter: 1-1440, s/iter: 2.969e-01, ELBO: -1.241e+06
# Cur diff delta = 214.78248596191406
# Cur diff sigma = 8.194023132324219
# Cur diff theta = 222.97650909423828
# ---------------------------------------
# IAF, d: 200, Iter: 1-1460, s/iter: 3.003e-01, ELBO: -1.241e+06
# Cur diff delta = 214.7388153076172
# Cur diff sigma = 8.1946382522583
# Cur diff theta = 222.9334535598755
# ---------------------------------------
# IAF, d: 200, Iter: 1-1480, s/iter: 3.008e-01, ELBO: -1.241e+06
# Cur diff delta = 214.74147033691406
# Cur diff sigma = 8.194842338562012
# Cur diff theta = 222.93631267547607
# ---------------------------------------
# IAF, d: 200, Iter: 1-1500, s/iter: 3.027e-01, ELBO: -1.241e+06
# Cur diff delta = 214.76171875
# Cur diff sigma = 8.194636344909668
# Cur diff theta = 222.95635509490967
# ---------------------------------------
# IAF, d: 200, Iter: 1-1520, s/iter: 3.080e-01, ELBO: -1.241e+06
# Cur diff delta = 214.76318359375
# Cur diff sigma = 8.194560050964355
# Cur diff theta = 222.95774364471436
# ---------------------------------------
# IAF, d: 200, Iter: 1-1540, s/iter: 3.109e-01, ELBO: -1.241e+06
# Cur diff delta = 214.76522827148438
# Cur diff sigma = 8.194491386413574
# Cur diff theta = 222.95971965789795
# ---------------------------------------
# IAF, d: 200, Iter: 1-1560, s/iter: 3.072e-01, ELBO: -1.241e+06
# Cur diff delta = 214.75906372070312
# Cur diff sigma = 8.193668365478516
# Cur diff theta = 222.95273208618164
# ---------------------------------------
# IAF, d: 200, Iter: 1-1580, s/iter: 3.100e-01, ELBO: -1.241e+06
# Cur diff delta = 214.733154296875
# Cur diff sigma = 8.194496154785156
# Cur diff theta = 222.92765045166016
# ---------------------------------------
# IAF, d: 200, Iter: 1-1600, s/iter: 3.067e-01, ELBO: -1.240e+06
# Cur diff delta = 214.7328643798828
# Cur diff sigma = 8.194453239440918
# Cur diff theta = 222.92731761932373
# ---------------------------------------
# IAF, d: 200, Iter: 1-1620, s/iter: 3.082e-01, ELBO: -1.241e+06
# Cur diff delta = 214.73687744140625
# Cur diff sigma = 8.193771362304688
# Cur diff theta = 222.93064880371094
# ---------------------------------------
# IAF, d: 200, Iter: 1-1640, s/iter: 3.058e-01, ELBO: -1.241e+06
# Cur diff delta = 214.7488250732422
# Cur diff sigma = 8.194149017333984
# Cur diff theta = 222.94297409057617
# ---------------------------------------
# IAF, d: 200, Iter: 1-1660, s/iter: 3.071e-01, ELBO: -1.240e+06
# Cur diff delta = 214.76129150390625
# Cur diff sigma = 8.19441032409668
# Cur diff theta = 222.95570182800293
# ---------------------------------------
# IAF, d: 200, Iter: 1-1680, s/iter: 3.144e-01, ELBO: -1.241e+06
# Cur diff delta = 214.7298126220703
# Cur diff sigma = 8.193357467651367
# Cur diff theta = 222.92317008972168
# ---------------------------------------
# IAF, d: 200, Iter: 1-1700, s/iter: 3.153e-01, ELBO: -1.241e+06
# Cur diff delta = 214.72457885742188
# Cur diff sigma = 8.194421768188477
# Cur diff theta = 222.91900062561035
# ---------------------------------------
# IAF, d: 200, Iter: 1-1720, s/iter: 3.122e-01, ELBO: -1.241e+06
# Cur diff delta = 214.73590087890625
# Cur diff sigma = 8.195555686950684
# Cur diff theta = 222.93145656585693
# ---------------------------------------
# IAF, d: 200, Iter: 1-1740, s/iter: 3.126e-01, ELBO: -1.241e+06
# Cur diff delta = 214.77928161621094
# Cur diff sigma = 8.194588661193848
# Cur diff theta = 222.97387027740479
# ---------------------------------------
# IAF, d: 200, Iter: 1-1760, s/iter: 3.098e-01, ELBO: -1.241e+06
# Cur diff delta = 214.7507781982422
# Cur diff sigma = 8.193188667297363
# Cur diff theta = 222.94396686553955
# ---------------------------------------
# IAF, d: 200, Iter: 1-1780, s/iter: 3.141e-01, ELBO: -1.241e+06
# Cur diff delta = 214.7514190673828
# Cur diff sigma = 8.194623947143555
# Cur diff theta = 222.94604301452637
# ---------------------------------------
# IAF, d: 200, Iter: 1-1800, s/iter: 3.131e-01, ELBO: -1.241e+06
# Cur diff delta = 214.7777099609375
# Cur diff sigma = 8.193672180175781
# Cur diff theta = 222.97138214111328
# ---------------------------------------
# IAF, d: 200, Iter: 1-1820, s/iter: 3.129e-01, ELBO: -1.241e+06
# Cur diff delta = 214.75335693359375
# Cur diff sigma = 8.19530963897705
# Cur diff theta = 222.9486665725708
# ---------------------------------------
# IAF, d: 200, Iter: 1-1840, s/iter: 3.173e-01, ELBO: -1.241e+06
# Cur diff delta = 214.74179077148438
# Cur diff sigma = 8.194375038146973
# Cur diff theta = 222.93616580963135
# ---------------------------------------
# IAF, d: 200, Iter: 1-1860, s/iter: 3.171e-01, ELBO: -1.240e+06
# Cur diff delta = 214.74606323242188
# Cur diff sigma = 8.193821907043457
# Cur diff theta = 222.93988513946533
# ---------------------------------------
# IAF, d: 200, Iter: 1-1880, s/iter: 3.215e-01, ELBO: -1.240e+06
# Cur diff delta = 214.76187133789062
# Cur diff sigma = 8.192972183227539
# Cur diff theta = 222.95484352111816
# ---------------------------------------
# IAF, d: 200, Iter: 1-1900, s/iter: 3.196e-01, ELBO: -1.241e+06
# Cur diff delta = 214.74325561523438
# Cur diff sigma = 8.194622039794922
# Cur diff theta = 222.9378776550293
# ---------------------------------------
# IAF, d: 200, Iter: 1-1920, s/iter: 3.231e-01, ELBO: -1.240e+06
# Cur diff delta = 214.7463836669922
# Cur diff sigma = 8.193706512451172
# Cur diff theta = 222.94009017944336
# ---------------------------------------
# IAF, d: 200, Iter: 1-1940, s/iter: 3.248e-01, ELBO: -1.240e+06
# Cur diff delta = 214.74752807617188
# Cur diff sigma = 8.194162368774414
# Cur diff theta = 222.9416904449463
# ---------------------------------------
# IAF, d: 200, Iter: 1-1960, s/iter: 3.242e-01, ELBO: -1.240e+06
# Cur diff delta = 214.72171020507812
# Cur diff sigma = 8.193643569946289
# Cur diff theta = 222.9153537750244
# ---------------------------------------
# IAF, d: 200, Iter: 1-1980, s/iter: 3.263e-01, ELBO: -1.240e+06
# Cur diff delta = 214.7412109375
# Cur diff sigma = 8.192917823791504
# Cur diff theta = 222.9341287612915
# ---------------------------------------
# IAF, d: 200, Iter: 1-2000, s/iter: 3.220e-01, ELBO: -1.241e+06
# Cur diff delta = 214.73306274414062
# Cur diff sigma = 8.195391654968262
# Cur diff theta = 222.9284543991089
# ---------------------------------------
# ------------------------------------------------------
# Test = 1
# ------------------------------------------------------
# Init diff delta = 26666.0
# Init diff sigma = 77495.03125
# Init diff theta = 104161.03125
# IAF, d: 200, Iter: 2-20, s/iter: 1.602e-01, ELBO: -7.532e+06
# Cur diff delta = 23089.279296875
# Cur diff sigma = 32502.265625
# Cur diff theta = 55591.544921875
# ---------------------------------------
# IAF, d: 200, Iter: 2-40, s/iter: 1.620e-01, ELBO: -6.960e+06
# Cur diff delta = 20296.45703125
# Cur diff sigma = 24683.029296875
# Cur diff theta = 44979.486328125
# ---------------------------------------
# IAF, d: 200, Iter: 2-60, s/iter: 1.608e-01, ELBO: -6.425e+06
# Cur diff delta = 17774.18359375
# Cur diff sigma = 20636.025390625
# Cur diff theta = 38410.208984375
# ---------------------------------------
# IAF, d: 200, Iter: 2-80, s/iter: 1.610e-01, ELBO: -5.853e+06
# Cur diff delta = 15470.4326171875
# Cur diff sigma = 17451.35546875
# Cur diff theta = 32921.7880859375
# ---------------------------------------
# IAF, d: 200, Iter: 2-100, s/iter: 1.586e-01, ELBO: -5.221e+06
# Cur diff delta = 13374.751953125
# Cur diff sigma = 14698.7314453125
# Cur diff theta = 28073.4833984375
# ---------------------------------------
# IAF, d: 200, Iter: 2-120, s/iter: 1.624e-01, ELBO: -4.730e+06
# Cur diff delta = 11482.8466796875
# Cur diff sigma = 12314.3505859375
# Cur diff theta = 23797.197265625
# ---------------------------------------
# IAF, d: 200, Iter: 2-140, s/iter: 1.613e-01, ELBO: -4.399e+06
# Cur diff delta = 9779.61328125
# Cur diff sigma = 10187.921875
# Cur diff theta = 19967.53515625
# ---------------------------------------
# IAF, d: 200, Iter: 2-160, s/iter: 1.633e-01, ELBO: -4.081e+06
# Cur diff delta = 8257.318359375
# Cur diff sigma = 8360.71875
# Cur diff theta = 16618.037109375
# ---------------------------------------
# IAF, d: 200, Iter: 2-180, s/iter: 1.609e-01, ELBO: -3.780e+06
# Cur diff delta = 6899.7080078125
# Cur diff sigma = 6790.46240234375
# Cur diff theta = 13690.17041015625
# ---------------------------------------
# IAF, d: 200, Iter: 2-200, s/iter: 1.610e-01, ELBO: -3.519e+06
# Cur diff delta = 5702.49072265625
# Cur diff sigma = 5445.13671875
# Cur diff theta = 11147.62744140625
# ---------------------------------------
# IAF, d: 200, Iter: 2-220, s/iter: 1.592e-01, ELBO: -3.255e+06
# Cur diff delta = 4656.21630859375
# Cur diff sigma = 4309.8505859375
# Cur diff theta = 8966.06689453125
# ---------------------------------------
# IAF, d: 200, Iter: 2-240, s/iter: 1.592e-01, ELBO: -2.994e+06
# Cur diff delta = 3748.599609375
# Cur diff sigma = 3355.083251953125
# Cur diff theta = 7103.682861328125
# ---------------------------------------
# IAF, d: 200, Iter: 2-260, s/iter: 1.596e-01, ELBO: -2.732e+06
# Cur diff delta = 2974.1552734375
# Cur diff sigma = 2568.589599609375
# Cur diff theta = 5542.744873046875
# ---------------------------------------
# IAF, d: 200, Iter: 2-280, s/iter: 1.590e-01, ELBO: -2.499e+06
# Cur diff delta = 2322.379150390625
# Cur diff sigma = 1925.1466064453125
# Cur diff theta = 4247.5257568359375
# ---------------------------------------
# IAF, d: 200, Iter: 2-300, s/iter: 1.600e-01, ELBO: -2.294e+06
# Cur diff delta = 1781.1201171875
# Cur diff sigma = 1405.6136474609375
# Cur diff theta = 3186.7337646484375
# ---------------------------------------
# IAF, d: 200, Iter: 2-320, s/iter: 1.608e-01, ELBO: -2.105e+06
# Cur diff delta = 1338.5458984375
# Cur diff sigma = 994.27880859375
# Cur diff theta = 2332.82470703125
# ---------------------------------------
# IAF, d: 200, Iter: 2-340, s/iter: 1.619e-01, ELBO: -1.932e+06
# Cur diff delta = 984.048828125
# Cur diff sigma = 676.2610473632812
# Cur diff theta = 1660.3098754882812
# ---------------------------------------
# IAF, d: 200, Iter: 2-360, s/iter: 1.625e-01, ELBO: -1.773e+06
# Cur diff delta = 710.7708740234375
# Cur diff sigma = 437.6374206542969
# Cur diff theta = 1148.4082946777344
# ---------------------------------------
# IAF, d: 200, Iter: 2-380, s/iter: 1.644e-01, ELBO: -1.628e+06
# Cur diff delta = 512.0927734375
# Cur diff sigma = 266.8733825683594
# Cur diff theta = 778.9661560058594
# ---------------------------------------
# IAF, d: 200, Iter: 2-400, s/iter: 1.638e-01, ELBO: -1.503e+06
# Cur diff delta = 375.9932556152344
# Cur diff sigma = 151.62750244140625
# Cur diff theta = 527.6207580566406
# ---------------------------------------
# IAF, d: 200, Iter: 2-420, s/iter: 1.676e-01, ELBO: -1.404e+06
# Cur diff delta = 287.9843444824219
# Cur diff sigma = 79.43267822265625
# Cur diff theta = 367.4170227050781
# ---------------------------------------
# IAF, d: 200, Iter: 2-440, s/iter: 1.712e-01, ELBO: -1.330e+06
# Cur diff delta = 239.50233459472656
# Cur diff sigma = 38.75563430786133
# Cur diff theta = 278.2579689025879
# ---------------------------------------
# IAF, d: 200, Iter: 2-460, s/iter: 1.719e-01, ELBO: -1.281e+06
# Cur diff delta = 219.81866455078125
# Cur diff sigma = 18.905445098876953
# Cur diff theta = 238.7241096496582
# ---------------------------------------
# IAF, d: 200, Iter: 2-480, s/iter: 1.757e-01, ELBO: -1.257e+06
# Cur diff delta = 219.56082153320312
# Cur diff sigma = 10.962066650390625
# Cur diff theta = 230.52288818359375
# ---------------------------------------
# IAF, d: 200, Iter: 2-500, s/iter: 1.803e-01, ELBO: -1.245e+06
# Cur diff delta = 224.10887145996094
# Cur diff sigma = 8.548388481140137
# Cur diff theta = 232.65725994110107
# ---------------------------------------
# IAF, d: 200, Iter: 2-520, s/iter: 1.887e-01, ELBO: -1.242e+06
# Cur diff delta = 227.96600341796875
# Cur diff sigma = 8.195451736450195
# Cur diff theta = 236.16145515441895
# ---------------------------------------
# IAF, d: 200, Iter: 2-540, s/iter: 1.967e-01, ELBO: -1.242e+06
# Cur diff delta = 228.41595458984375
# Cur diff sigma = 8.190851211547852
# Cur diff theta = 236.6068058013916
# ---------------------------------------
# IAF, d: 200, Iter: 2-560, s/iter: 1.986e-01, ELBO: -1.242e+06
# Cur diff delta = 228.42526245117188
# Cur diff sigma = 8.191136360168457
# Cur diff theta = 236.61639881134033
# ---------------------------------------
# IAF, d: 200, Iter: 2-580, s/iter: 2.027e-01, ELBO: -1.242e+06
# Cur diff delta = 228.3863525390625
# Cur diff sigma = 8.191377639770508
# Cur diff theta = 236.577730178833
# ---------------------------------------
# IAF, d: 200, Iter: 2-600, s/iter: 2.091e-01, ELBO: -1.242e+06
# Cur diff delta = 228.4029541015625
# Cur diff sigma = 8.191571235656738
# Cur diff theta = 236.59452533721924
# ---------------------------------------
# IAF, d: 200, Iter: 2-620, s/iter: 2.100e-01, ELBO: -1.242e+06
# Cur diff delta = 228.42820739746094
# Cur diff sigma = 8.191238403320312
# Cur diff theta = 236.61944580078125
# ---------------------------------------
# IAF, d: 200, Iter: 2-640, s/iter: 2.154e-01, ELBO: -1.242e+06
# Cur diff delta = 228.42572021484375
# Cur diff sigma = 8.190720558166504
# Cur diff theta = 236.61644077301025
# ---------------------------------------
# IAF, d: 200, Iter: 2-660, s/iter: 2.165e-01, ELBO: -1.242e+06
# Cur diff delta = 228.42803955078125
# Cur diff sigma = 8.191179275512695
# Cur diff theta = 236.61921882629395
# ---------------------------------------
# IAF, d: 200, Iter: 2-680, s/iter: 2.201e-01, ELBO: -1.242e+06
# Cur diff delta = 228.41795349121094
# Cur diff sigma = 8.190357208251953
# Cur diff theta = 236.6083106994629
# ---------------------------------------
# IAF, d: 200, Iter: 2-700, s/iter: 2.248e-01, ELBO: -1.242e+06
# Cur diff delta = 228.41241455078125
# Cur diff sigma = 8.190261840820312
# Cur diff theta = 236.60267639160156
# ---------------------------------------
# IAF, d: 200, Iter: 2-720, s/iter: 2.237e-01, ELBO: -1.242e+06
# Cur diff delta = 228.4166717529297
# Cur diff sigma = 8.18967056274414
# Cur diff theta = 236.60634231567383
# ---------------------------------------
# IAF, d: 200, Iter: 2-740, s/iter: 2.281e-01, ELBO: -1.242e+06
# Cur diff delta = 228.4444580078125
# Cur diff sigma = 8.189831733703613
# Cur diff theta = 236.6342897415161
# ---------------------------------------
# IAF, d: 200, Iter: 2-760, s/iter: 2.345e-01, ELBO: -1.242e+06
# Cur diff delta = 228.42543029785156
# Cur diff sigma = 8.189530372619629
# Cur diff theta = 236.6149606704712
# ---------------------------------------
# IAF, d: 200, Iter: 2-780, s/iter: 2.366e-01, ELBO: -1.242e+06
# Cur diff delta = 228.42544555664062
# Cur diff sigma = 8.189249992370605
# Cur diff theta = 236.61469554901123
# ---------------------------------------
# IAF, d: 200, Iter: 2-800, s/iter: 2.367e-01, ELBO: -1.242e+06
# Cur diff delta = 228.4375457763672
# Cur diff sigma = 8.189102172851562
# Cur diff theta = 236.62664794921875
# ---------------------------------------
# IAF, d: 200, Iter: 2-820, s/iter: 2.336e-01, ELBO: -1.242e+06
# Cur diff delta = 228.4159698486328
# Cur diff sigma = 8.188703536987305
# Cur diff theta = 236.60467338562012
# ---------------------------------------
# IAF, d: 200, Iter: 2-840, s/iter: 2.350e-01, ELBO: -1.242e+06
# Cur diff delta = 228.42344665527344
# Cur diff sigma = 8.190162658691406
# Cur diff theta = 236.61360931396484
# ---------------------------------------
# IAF, d: 200, Iter: 2-860, s/iter: 2.387e-01, ELBO: -1.242e+06
# Cur diff delta = 228.42469787597656
# Cur diff sigma = 8.190258979797363
# Cur diff theta = 236.61495685577393
# ---------------------------------------
# IAF, d: 200, Iter: 2-880, s/iter: 2.430e-01, ELBO: -1.242e+06
# Cur diff delta = 228.421630859375
# Cur diff sigma = 8.190370559692383
# Cur diff theta = 236.61200141906738
# ---------------------------------------
# IAF, d: 200, Iter: 2-900, s/iter: 2.448e-01, ELBO: -1.242e+06
# Cur diff delta = 228.41148376464844
# Cur diff sigma = 8.190021514892578
# Cur diff theta = 236.60150527954102
# ---------------------------------------
# IAF, d: 200, Iter: 2-920, s/iter: 2.484e-01, ELBO: -1.242e+06
# Cur diff delta = 228.43275451660156
# Cur diff sigma = 8.18887996673584
# Cur diff theta = 236.6216344833374
# ---------------------------------------
# IAF, d: 200, Iter: 2-940, s/iter: 2.510e-01, ELBO: -1.242e+06
# Cur diff delta = 228.41201782226562
# Cur diff sigma = 8.189090728759766
# Cur diff theta = 236.6011085510254
# ---------------------------------------
# IAF, d: 200, Iter: 2-960, s/iter: 2.550e-01, ELBO: -1.242e+06
# Cur diff delta = 228.44204711914062
# Cur diff sigma = 8.188725471496582
# Cur diff theta = 236.6307725906372
# ---------------------------------------
# IAF, d: 200, Iter: 2-980, s/iter: 2.571e-01, ELBO: -1.242e+06
# Cur diff delta = 228.448486328125
# Cur diff sigma = 8.189566612243652
# Cur diff theta = 236.63805294036865
# ---------------------------------------
# IAF, d: 200, Iter: 2-1000, s/iter: 2.597e-01, ELBO: -1.242e+06
# Cur diff delta = 228.42457580566406
# Cur diff sigma = 8.188149452209473
# Cur diff theta = 236.61272525787354
# ---------------------------------------
# IAF, d: 200, Iter: 2-1020, s/iter: 2.626e-01, ELBO: -1.242e+06
# Cur diff delta = 228.44241333007812
# Cur diff sigma = 8.188346862792969
# Cur diff theta = 236.6307601928711
# ---------------------------------------
# IAF, d: 200, Iter: 2-1040, s/iter: 2.641e-01, ELBO: -1.242e+06
# Cur diff delta = 228.4414825439453
# Cur diff sigma = 8.189169883728027
# Cur diff theta = 236.63065242767334
# ---------------------------------------
# IAF, d: 200, Iter: 2-1060, s/iter: 2.638e-01, ELBO: -1.242e+06
# Cur diff delta = 228.4289093017578
# Cur diff sigma = 8.189786911010742
# Cur diff theta = 236.61869621276855
# ---------------------------------------
# IAF, d: 200, Iter: 2-1080, s/iter: 2.654e-01, ELBO: -1.242e+06
# Cur diff delta = 228.42051696777344
# Cur diff sigma = 8.188353538513184
# Cur diff theta = 236.60887050628662
# ---------------------------------------
# IAF, d: 200, Iter: 2-1100, s/iter: 2.644e-01, ELBO: -1.242e+06
# Cur diff delta = 228.42222595214844
# Cur diff sigma = 8.189616203308105
# Cur diff theta = 236.61184215545654
# ---------------------------------------
# IAF, d: 200, Iter: 2-1120, s/iter: 2.632e-01, ELBO: -1.242e+06
# Cur diff delta = 228.42904663085938
# Cur diff sigma = 8.18851375579834
# Cur diff theta = 236.61756038665771
# ---------------------------------------
# IAF, d: 200, Iter: 2-1140, s/iter: 2.653e-01, ELBO: -1.242e+06
# Cur diff delta = 228.4344482421875
# Cur diff sigma = 8.189658164978027
# Cur diff theta = 236.62410640716553
# ---------------------------------------
# IAF, d: 200, Iter: 2-1160, s/iter: 2.708e-01, ELBO: -1.242e+06
# Cur diff delta = 228.44920349121094
# Cur diff sigma = 8.189650535583496
# Cur diff theta = 236.63885402679443
# ---------------------------------------
# IAF, d: 200, Iter: 2-1180, s/iter: 2.720e-01, ELBO: -1.242e+06
# Cur diff delta = 228.4293212890625
# Cur diff sigma = 8.188024520874023
# Cur diff theta = 236.61734580993652
# ---------------------------------------
# IAF, d: 200, Iter: 2-1200, s/iter: 2.774e-01, ELBO: -1.242e+06
# Cur diff delta = 228.43746948242188
# Cur diff sigma = 8.188008308410645
# Cur diff theta = 236.62547779083252
# ---------------------------------------
# IAF, d: 200, Iter: 2-1220, s/iter: 2.743e-01, ELBO: -1.242e+06
# Cur diff delta = 228.42283630371094
# Cur diff sigma = 8.187628746032715
# Cur diff theta = 236.61046504974365
# ---------------------------------------
# IAF, d: 200, Iter: 2-1240, s/iter: 2.759e-01, ELBO: -1.242e+06
# Cur diff delta = 228.4324188232422
# Cur diff sigma = 8.187946319580078
# Cur diff theta = 236.62036514282227
# ---------------------------------------
# IAF, d: 200, Iter: 2-1260, s/iter: 2.793e-01, ELBO: -1.242e+06
# Cur diff delta = 228.44091796875
# Cur diff sigma = 8.188933372497559
# Cur diff theta = 236.62985134124756
# ---------------------------------------
# IAF, d: 200, Iter: 2-1280, s/iter: 2.793e-01, ELBO: -1.242e+06
# Cur diff delta = 228.46060180664062
# Cur diff sigma = 8.187522888183594
# Cur diff theta = 236.64812469482422
# ---------------------------------------
# IAF, d: 200, Iter: 2-1300, s/iter: 2.847e-01, ELBO: -1.242e+06
# Cur diff delta = 228.43661499023438
# Cur diff sigma = 8.188701629638672
# Cur diff theta = 236.62531661987305
# ---------------------------------------
# IAF, d: 200, Iter: 2-1320, s/iter: 2.869e-01, ELBO: -1.242e+06
# Cur diff delta = 228.43324279785156
# Cur diff sigma = 8.188530921936035
# Cur diff theta = 236.6217737197876
# ---------------------------------------
# IAF, d: 200, Iter: 2-1340, s/iter: 2.861e-01, ELBO: -1.242e+06
# Cur diff delta = 228.4309539794922
# Cur diff sigma = 8.187901496887207
# Cur diff theta = 236.6188554763794
# ---------------------------------------
# IAF, d: 200, Iter: 2-1360, s/iter: 2.862e-01, ELBO: -1.242e+06
# Cur diff delta = 228.40664672851562
# Cur diff sigma = 8.18811321258545
# Cur diff theta = 236.59475994110107
# ---------------------------------------
# IAF, d: 200, Iter: 2-1380, s/iter: 2.908e-01, ELBO: -1.242e+06
# Cur diff delta = 228.4206085205078
# Cur diff sigma = 8.1881103515625
# Cur diff theta = 236.6087188720703
# ---------------------------------------
# IAF, d: 200, Iter: 2-1400, s/iter: 2.904e-01, ELBO: -1.242e+06
# Cur diff delta = 228.4244842529297
# Cur diff sigma = 8.187936782836914
# Cur diff theta = 236.6124210357666
# ---------------------------------------
# IAF, d: 200, Iter: 2-1420, s/iter: 2.854e-01, ELBO: -1.242e+06
# Cur diff delta = 228.44735717773438
# Cur diff sigma = 8.187263488769531
# Cur diff theta = 236.6346206665039
# ---------------------------------------
# IAF, d: 200, Iter: 2-1440, s/iter: 2.867e-01, ELBO: -1.242e+06
# Cur diff delta = 228.46029663085938
# Cur diff sigma = 8.186786651611328
# Cur diff theta = 236.6470832824707
# ---------------------------------------
# IAF, d: 200, Iter: 2-1460, s/iter: 2.857e-01, ELBO: -1.242e+06
# Cur diff delta = 228.4292755126953
# Cur diff sigma = 8.186180114746094
# Cur diff theta = 236.6154556274414
# ---------------------------------------
# IAF, d: 200, Iter: 2-1480, s/iter: 2.823e-01, ELBO: -1.242e+06
# Cur diff delta = 228.42164611816406
# Cur diff sigma = 8.189287185668945
# Cur diff theta = 236.610933303833
# ---------------------------------------
# IAF, d: 200, Iter: 2-1500, s/iter: 2.872e-01, ELBO: -1.242e+06
# Cur diff delta = 228.4376678466797
# Cur diff sigma = 8.18837833404541
# Cur diff theta = 236.6260461807251
# ---------------------------------------
# IAF, d: 200, Iter: 2-1520, s/iter: 2.897e-01, ELBO: -1.242e+06
# Cur diff delta = 228.4490203857422
# Cur diff sigma = 8.18802547454834
# Cur diff theta = 236.63704586029053
# ---------------------------------------
# IAF, d: 200, Iter: 2-1540, s/iter: 2.855e-01, ELBO: -1.242e+06
# Cur diff delta = 228.4205780029297
# Cur diff sigma = 8.187256813049316
# Cur diff theta = 236.607834815979
# ---------------------------------------
# IAF, d: 200, Iter: 2-1560, s/iter: 2.869e-01, ELBO: -1.242e+06
# Cur diff delta = 228.42947387695312
# Cur diff sigma = 8.18889045715332
# Cur diff theta = 236.61836433410645
# ---------------------------------------
# IAF, d: 200, Iter: 2-1580, s/iter: 2.863e-01, ELBO: -1.242e+06
# Cur diff delta = 228.42906188964844
# Cur diff sigma = 8.188228607177734
# Cur diff theta = 236.61729049682617
# ---------------------------------------
# IAF, d: 200, Iter: 2-1600, s/iter: 2.879e-01, ELBO: -1.242e+06
# Cur diff delta = 228.42640686035156
# Cur diff sigma = 8.18869400024414
# Cur diff theta = 236.6151008605957
# ---------------------------------------
# IAF, d: 200, Iter: 2-1620, s/iter: 2.947e-01, ELBO: -1.242e+06
# Cur diff delta = 228.41497802734375
# Cur diff sigma = 8.186385154724121
# Cur diff theta = 236.60136318206787
# ---------------------------------------
# IAF, d: 200, Iter: 2-1640, s/iter: 2.905e-01, ELBO: -1.242e+06
# Cur diff delta = 228.44503784179688
# Cur diff sigma = 8.186954498291016
# Cur diff theta = 236.6319923400879
# ---------------------------------------
# IAF, d: 200, Iter: 2-1660, s/iter: 2.915e-01, ELBO: -1.242e+06
# Cur diff delta = 228.4459228515625
# Cur diff sigma = 8.187758445739746
# Cur diff theta = 236.63368129730225
# ---------------------------------------
# IAF, d: 200, Iter: 2-1680, s/iter: 2.968e-01, ELBO: -1.242e+06
# Cur diff delta = 228.44000244140625
# Cur diff sigma = 8.187398910522461
# Cur diff theta = 236.6274013519287
# ---------------------------------------
# IAF, d: 200, Iter: 2-1700, s/iter: 3.006e-01, ELBO: -1.242e+06
# Cur diff delta = 228.44296264648438
# Cur diff sigma = 8.186445236206055
# Cur diff theta = 236.62940788269043
# ---------------------------------------
# IAF, d: 200, Iter: 2-1720, s/iter: 2.962e-01, ELBO: -1.242e+06
# Cur diff delta = 228.44439697265625
# Cur diff sigma = 8.187708854675293
# Cur diff theta = 236.63210582733154
# ---------------------------------------
# IAF, d: 200, Iter: 2-1740, s/iter: 2.951e-01, ELBO: -1.242e+06
# Cur diff delta = 228.4239959716797
# Cur diff sigma = 8.186836242675781
# Cur diff theta = 236.61083221435547
# ---------------------------------------
# IAF, d: 200, Iter: 2-1760, s/iter: 2.947e-01, ELBO: -1.242e+06
# Cur diff delta = 228.42237854003906
# Cur diff sigma = 8.188167572021484
# Cur diff theta = 236.61054611206055
# ---------------------------------------
# IAF, d: 200, Iter: 2-1780, s/iter: 2.943e-01, ELBO: -1.242e+06
# Cur diff delta = 228.44517517089844
# Cur diff sigma = 8.18753719329834
# Cur diff theta = 236.63271236419678
# ---------------------------------------
# IAF, d: 200, Iter: 2-1800, s/iter: 2.956e-01, ELBO: -1.242e+06
# Cur diff delta = 228.44398498535156
# Cur diff sigma = 8.187856674194336
# Cur diff theta = 236.6318416595459
# ---------------------------------------
# IAF, d: 200, Iter: 2-1820, s/iter: 2.955e-01, ELBO: -1.242e+06
# Cur diff delta = 228.439453125
# Cur diff sigma = 8.187171936035156
# Cur diff theta = 236.62662506103516
# ---------------------------------------
# IAF, d: 200, Iter: 2-1840, s/iter: 2.986e-01, ELBO: -1.242e+06
# Cur diff delta = 228.42333984375
# Cur diff sigma = 8.1866455078125
# Cur diff theta = 236.6099853515625
# ---------------------------------------
# IAF, d: 200, Iter: 2-1860, s/iter: 2.984e-01, ELBO: -1.242e+06
# Cur diff delta = 228.4330596923828
# Cur diff sigma = 8.187448501586914
# Cur diff theta = 236.62050819396973
# ---------------------------------------
# IAF, d: 200, Iter: 2-1880, s/iter: 2.957e-01, ELBO: -1.242e+06
# Cur diff delta = 228.43646240234375
# Cur diff sigma = 8.188237190246582
# Cur diff theta = 236.62469959259033
# ---------------------------------------
# IAF, d: 200, Iter: 2-1900, s/iter: 3.011e-01, ELBO: -1.242e+06
# Cur diff delta = 228.42584228515625
# Cur diff sigma = 8.186311721801758
# Cur diff theta = 236.612154006958
# ---------------------------------------
# IAF, d: 200, Iter: 2-1920, s/iter: 2.974e-01, ELBO: -1.242e+06
# Cur diff delta = 228.45455932617188
# Cur diff sigma = 8.18797779083252
# Cur diff theta = 236.6425371170044
# ---------------------------------------
# IAF, d: 200, Iter: 2-1940, s/iter: 3.026e-01, ELBO: -1.242e+06
# Cur diff delta = 228.44871520996094
# Cur diff sigma = 8.187365531921387
# Cur diff theta = 236.63608074188232
# ---------------------------------------
# IAF, d: 200, Iter: 2-1960, s/iter: 3.039e-01, ELBO: -1.242e+06
# Cur diff delta = 228.4169921875
# Cur diff sigma = 8.186784744262695
# Cur diff theta = 236.6037769317627
# ---------------------------------------
# IAF, d: 200, Iter: 2-1980, s/iter: 2.967e-01, ELBO: -1.242e+06
# Cur diff delta = 228.43873596191406
# Cur diff sigma = 8.187870979309082
# Cur diff theta = 236.62660694122314
# ---------------------------------------
# IAF, d: 200, Iter: 2-2000, s/iter: 2.972e-01, ELBO: -1.242e+06
# Cur diff delta = 228.41424560546875
# Cur diff sigma = 8.186877250671387
# Cur diff theta = 236.60112285614014
# ---------------------------------------
# ------------------------------------------------------
# Test = 2
# ------------------------------------------------------
# Init diff delta = 26666.0
# Init diff sigma = 77495.03125
# Init diff theta = 104161.03125
# IAF, d: 200, Iter: 3-20, s/iter: 1.531e-01, ELBO: -7.528e+06
# Cur diff delta = 23092.908203125
# Cur diff sigma = 32565.025390625
# Cur diff theta = 55657.93359375
# ---------------------------------------
# IAF, d: 200, Iter: 3-40, s/iter: 1.547e-01, ELBO: -6.960e+06
# Cur diff delta = 20293.953125
# Cur diff sigma = 24804.55859375
# Cur diff theta = 45098.51171875
# ---------------------------------------
# IAF, d: 200, Iter: 3-60, s/iter: 1.555e-01, ELBO: -6.432e+06
# Cur diff delta = 17760.693359375
# Cur diff sigma = 20752.578125
# Cur diff theta = 38513.271484375
# ---------------------------------------
# IAF, d: 200, Iter: 3-80, s/iter: 1.564e-01, ELBO: -5.865e+06
# Cur diff delta = 15455.310546875
# Cur diff sigma = 17540.30859375
# Cur diff theta = 32995.619140625
# ---------------------------------------
# IAF, d: 200, Iter: 3-100, s/iter: 1.572e-01, ELBO: -5.247e+06
# Cur diff delta = 13362.802734375
# Cur diff sigma = 14775.3447265625
# Cur diff theta = 28138.1474609375
# ---------------------------------------
# IAF, d: 200, Iter: 3-120, s/iter: 1.561e-01, ELBO: -4.747e+06
# Cur diff delta = 11474.0712890625
# Cur diff sigma = 12354.15625
# Cur diff theta = 23828.2275390625
# ---------------------------------------
# IAF, d: 200, Iter: 3-140, s/iter: 1.540e-01, ELBO: -4.390e+06
# Cur diff delta = 9776.7099609375
# Cur diff sigma = 10244.5263671875
# Cur diff theta = 20021.236328125
# ---------------------------------------
# IAF, d: 200, Iter: 3-160, s/iter: 1.543e-01, ELBO: -4.073e+06
# Cur diff delta = 8254.65234375
# Cur diff sigma = 8421.439453125
# Cur diff theta = 16676.091796875
# ---------------------------------------
# IAF, d: 200, Iter: 3-180, s/iter: 1.554e-01, ELBO: -3.762e+06
# Cur diff delta = 6901.4072265625
# Cur diff sigma = 6852.99560546875
# Cur diff theta = 13754.40283203125
# ---------------------------------------
# IAF, d: 200, Iter: 3-200, s/iter: 1.522e-01, ELBO: -3.465e+06
# Cur diff delta = 5702.50439453125
# Cur diff sigma = 5508.20263671875
# Cur diff theta = 11210.70703125
# ---------------------------------------
# IAF, d: 200, Iter: 3-220, s/iter: 1.572e-01, ELBO: -3.191e+06
# Cur diff delta = 4654.0126953125
# Cur diff sigma = 4375.08447265625
# Cur diff theta = 9029.09716796875
# ---------------------------------------
# IAF, d: 200, Iter: 3-240, s/iter: 1.569e-01, ELBO: -2.938e+06
# Cur diff delta = 3748.6513671875
# Cur diff sigma = 3427.636474609375
# Cur diff theta = 7176.287841796875
# ...
# IAF, d: 200, Iter: 3-540, s/iter: 1.932e-01, ELBO: -1.241e+06
# Cur diff delta = 189.11422729492188
# Cur diff sigma = 8.168395042419434
# Cur diff theta = 197.2826223373413
# ---------------------------------------
# IAF, d: 200, Iter: 3-560, s/iter: 1.993e-01, ELBO: -1.241e+06
# Cur diff delta = 189.26571655273438
# Cur diff sigma = 8.167436599731445
# Cur diff theta = 197.43315315246582
# ---------------------------------------
# IAF, d: 200, Iter: 3-580, s/iter: 2.060e-01, ELBO: -1.241e+06
# Cur diff delta = 189.23728942871094
# Cur diff sigma = 8.166959762573242
# Cur diff theta = 197.40424919128418
# ---------------------------------------
# IAF, d: 200, Iter: 3-600, s/iter: 2.135e-01, ELBO: -1.241e+06
# Cur diff delta = 189.24057006835938
# Cur diff sigma = 8.16687297821045
# Cur diff theta = 197.40744304656982
# ---------------------------------------
# IAF, d: 200, Iter: 3-620, s/iter: 2.159e-01, ELBO: -1.241e+06
# Cur diff delta = 189.25746154785156
# Cur diff sigma = 8.167101860046387
# Cur diff theta = 197.42456340789795
# ---------------------------------------
# IAF, d: 200, Iter: 3-640, s/iter: 2.219e-01, ELBO: -1.241e+06
# Cur diff delta = 189.2693328857422
# Cur diff sigma = 8.1655912399292
# Cur diff theta = 197.4349241256714
# ---------------------------------------
# IAF, d: 200, Iter: 3-660, s/iter: 2.241e-01, ELBO: -1.241e+06
# Cur diff delta = 189.26385498046875
# Cur diff sigma = 8.166753768920898
# Cur diff theta = 197.43060874938965
# ---------------------------------------
# IAF, d: 200, Iter: 3-680, s/iter: 2.295e-01, ELBO: -1.241e+06
# Cur diff delta = 189.2480010986328
# Cur diff sigma = 8.166097640991211
# Cur diff theta = 197.41409873962402
# ---------------------------------------
# IAF, d: 200, Iter: 3-700, s/iter: 2.290e-01, ELBO: -1.241e+06
# Cur diff delta = 189.24810791015625
# Cur diff sigma = 8.166227340698242
# Cur diff theta = 197.4143352508545
# ---------------------------------------
# IAF, d: 200, Iter: 3-720, s/iter: 2.337e-01, ELBO: -1.241e+06
# Cur diff delta = 189.26043701171875
# Cur diff sigma = 8.166146278381348
# Cur diff theta = 197.4265832901001
# ---------------------------------------
# IAF, d: 200, Iter: 3-740, s/iter: 2.377e-01, ELBO: -1.241e+06
# Cur diff delta = 189.2501983642578
# Cur diff sigma = 8.166229248046875
# Cur diff theta = 197.4164276123047
# ---------------------------------------
# IAF, d: 200, Iter: 3-760, s/iter: 2.366e-01, ELBO: -1.241e+06
# Cur diff delta = 189.2512664794922
# Cur diff sigma = 8.16423225402832
# Cur diff theta = 197.4154987335205
# ---------------------------------------
# IAF, d: 200, Iter: 3-780, s/iter: 2.406e-01, ELBO: -1.241e+06
# Cur diff delta = 189.2506866455078
# Cur diff sigma = 8.166569709777832
# Cur diff theta = 197.41725635528564
# ---------------------------------------
# IAF, d: 200, Iter: 3-800, s/iter: 2.420e-01, ELBO: -1.241e+06
# Cur diff delta = 189.25909423828125
# Cur diff sigma = 8.165833473205566
# Cur diff theta = 197.42492771148682
# ---------------------------------------
# IAF, d: 200, Iter: 3-820, s/iter: 2.402e-01, ELBO: -1.241e+06
# Cur diff delta = 189.24154663085938
# Cur diff sigma = 8.167038917541504
# Cur diff theta = 197.40858554840088
# ---------------------------------------
# IAF, d: 200, Iter: 3-840, s/iter: 2.407e-01, ELBO: -1.241e+06
# Cur diff delta = 189.24978637695312
# Cur diff sigma = 8.165886878967285
# Cur diff theta = 197.4156732559204
# ---------------------------------------
# IAF, d: 200, Iter: 3-860, s/iter: 2.372e-01, ELBO: -1.241e+06
# Cur diff delta = 189.25306701660156
# Cur diff sigma = 8.165718078613281
# Cur diff theta = 197.41878509521484
# ---------------------------------------
# IAF, d: 200, Iter: 3-880, s/iter: 2.383e-01, ELBO: -1.241e+06
# Cur diff delta = 189.229736328125
# Cur diff sigma = 8.16502857208252
# Cur diff theta = 197.39476490020752
# ---------------------------------------
# IAF, d: 200, Iter: 3-900, s/iter: 2.454e-01, ELBO: -1.241e+06
# Cur diff delta = 189.25827026367188
# Cur diff sigma = 8.16661548614502
# Cur diff theta = 197.4248857498169
# ---------------------------------------
# IAF, d: 200, Iter: 3-920, s/iter: 2.497e-01, ELBO: -1.241e+06
# Cur diff delta = 189.26300048828125
# Cur diff sigma = 8.164952278137207
# Cur diff theta = 197.42795276641846
# ---------------------------------------
# IAF, d: 200, Iter: 3-940, s/iter: 2.519e-01, ELBO: -1.241e+06
# Cur diff delta = 189.23817443847656
# Cur diff sigma = 8.16546630859375
# Cur diff theta = 197.4036407470703
# ---------------------------------------
# IAF, d: 200, Iter: 3-960, s/iter: 2.531e-01, ELBO: -1.241e+06
# Cur diff delta = 189.23890686035156
# Cur diff sigma = 8.165966987609863
# Cur diff theta = 197.40487384796143
# ---------------------------------------
# IAF, d: 200, Iter: 3-980, s/iter: 2.597e-01, ELBO: -1.241e+06
# Cur diff delta = 189.2565155029297
# Cur diff sigma = 8.163995742797852
# Cur diff theta = 197.42051124572754
# ---------------------------------------
# IAF, d: 200, Iter: 3-1000, s/iter: 2.568e-01, ELBO: -1.241e+06
# Cur diff delta = 189.2376708984375
# Cur diff sigma = 8.165873527526855
# Cur diff theta = 197.40354442596436
# ---------------------------------------
# IAF, d: 200, Iter: 3-1020, s/iter: 2.604e-01, ELBO: -1.241e+06
# Cur diff delta = 189.22943115234375
# Cur diff sigma = 8.165252685546875
# Cur diff theta = 197.39468383789062
# ---------------------------------------
# IAF, d: 200, Iter: 3-1040, s/iter: 2.633e-01, ELBO: -1.241e+06
# Cur diff delta = 189.2815704345703
# Cur diff sigma = 8.164454460144043
# Cur diff theta = 197.44602489471436
# ---------------------------------------
# IAF, d: 200, Iter: 3-1060, s/iter: 2.623e-01, ELBO: -1.241e+06
# Cur diff delta = 189.2501678466797
# Cur diff sigma = 8.164840698242188
# Cur diff theta = 197.41500854492188
# ---------------------------------------
# IAF, d: 200, Iter: 3-1080, s/iter: 2.582e-01, ELBO: -1.241e+06
# Cur diff delta = 189.22723388671875
# Cur diff sigma = 8.164307594299316
# Cur diff theta = 197.39154148101807
# ---------------------------------------
# IAF, d: 200, Iter: 3-1100, s/iter: 2.659e-01, ELBO: -1.241e+06
# Cur diff delta = 189.24574279785156
# Cur diff sigma = 8.164209365844727
# Cur diff theta = 197.4099521636963
# ---------------------------------------
# IAF, d: 200, Iter: 3-1120, s/iter: 2.583e-01, ELBO: -1.241e+06
# Cur diff delta = 189.2540283203125
# Cur diff sigma = 8.164397239685059
# Cur diff theta = 197.41842555999756
# ---------------------------------------
# IAF, d: 200, Iter: 3-1140, s/iter: 2.619e-01, ELBO: -1.241e+06
# Cur diff delta = 189.2422332763672
# Cur diff sigma = 8.1648588180542
# Cur diff theta = 197.4070920944214
# ---------------------------------------
# IAF, d: 200, Iter: 3-1160, s/iter: 2.632e-01, ELBO: -1.241e+06
# Cur diff delta = 189.2439727783203
# Cur diff sigma = 8.165353775024414
# Cur diff theta = 197.40932655334473
# ---------------------------------------
# IAF, d: 200, Iter: 3-1180, s/iter: 2.563e-01, ELBO: -1.241e+06
# Cur diff delta = 189.26119995117188
# Cur diff sigma = 8.16444206237793
# Cur diff theta = 197.4256420135498
# ---------------------------------------
# IAF, d: 200, Iter: 3-1200, s/iter: 2.579e-01, ELBO: -1.241e+06
# Cur diff delta = 189.25125122070312
# Cur diff sigma = 8.165116310119629
# Cur diff theta = 197.41636753082275
# ---------------------------------------
# IAF, d: 200, Iter: 3-1220, s/iter: 2.620e-01, ELBO: -1.241e+06
# Cur diff delta = 189.2407989501953
# Cur diff sigma = 8.16503620147705
# Cur diff theta = 197.40583515167236
# ---------------------------------------
# IAF, d: 200, Iter: 3-1240, s/iter: 2.696e-01, ELBO: -1.241e+06
# Cur diff delta = 189.2749786376953
# Cur diff sigma = 8.164260864257812
# Cur diff theta = 197.43923950195312
# ---------------------------------------
# IAF, d: 200, Iter: 3-1260, s/iter: 2.714e-01, ELBO: -1.241e+06
# Cur diff delta = 189.24168395996094
# Cur diff sigma = 8.164887428283691
# Cur diff theta = 197.40657138824463
# ---------------------------------------
# IAF, d: 200, Iter: 3-1280, s/iter: 2.738e-01, ELBO: -1.241e+06
# Cur diff delta = 189.26133728027344
# Cur diff sigma = 8.164040565490723
# Cur diff theta = 197.42537784576416
# ---------------------------------------
# IAF, d: 200, Iter: 3-1300, s/iter: 2.739e-01, ELBO: -1.241e+06
# Cur diff delta = 189.2600555419922
# Cur diff sigma = 8.164403915405273
# Cur diff theta = 197.42445945739746
# ---------------------------------------
# IAF, d: 200, Iter: 3-1320, s/iter: 2.717e-01, ELBO: -1.241e+06
# Cur diff delta = 189.23114013671875
# Cur diff sigma = 8.164693832397461
# Cur diff theta = 197.3958339691162
# ---------------------------------------
# IAF, d: 200, Iter: 3-1340, s/iter: 2.725e-01, ELBO: -1.241e+06
# Cur diff delta = 189.26356506347656
# Cur diff sigma = 8.163485527038574
# Cur diff theta = 197.42705059051514
# ---------------------------------------
# IAF, d: 200, Iter: 3-1360, s/iter: 2.771e-01, ELBO: -1.241e+06
# Cur diff delta = 189.24427795410156
# Cur diff sigma = 8.16512680053711
# Cur diff theta = 197.40940475463867
# ---------------------------------------
# IAF, d: 200, Iter: 3-1380, s/iter: 2.780e-01, ELBO: -1.241e+06
# Cur diff delta = 189.25167846679688
# Cur diff sigma = 8.16425895690918
# Cur diff theta = 197.41593742370605
# ---------------------------------------
# IAF, d: 200, Iter: 3-1400, s/iter: 2.811e-01, ELBO: -1.241e+06
# Cur diff delta = 189.2523956298828
# Cur diff sigma = 8.164958953857422
# Cur diff theta = 197.41735458374023
# ---------------------------------------
# IAF, d: 200, Iter: 3-1420, s/iter: 2.796e-01, ELBO: -1.241e+06
# Cur diff delta = 189.2367401123047
# Cur diff sigma = 8.164124488830566
# Cur diff theta = 197.40086460113525
# ---------------------------------------
# IAF, d: 200, Iter: 3-1440, s/iter: 2.799e-01, ELBO: -1.241e+06
# Cur diff delta = 189.24742126464844
# Cur diff sigma = 8.1636381149292
# Cur diff theta = 197.41105937957764
# ---------------------------------------
# IAF, d: 200, Iter: 3-1460, s/iter: 2.819e-01, ELBO: -1.241e+06
# Cur diff delta = 189.2430419921875
# Cur diff sigma = 8.163850784301758
# Cur diff theta = 197.40689277648926
# ---------------------------------------
# IAF, d: 200, Iter: 3-1480, s/iter: 2.849e-01, ELBO: -1.241e+06
# Cur diff delta = 189.25929260253906
# Cur diff sigma = 8.163055419921875
# Cur diff theta = 197.42234802246094
# ---------------------------------------
# IAF, d: 200, Iter: 3-1500, s/iter: 2.912e-01, ELBO: -1.241e+06
# Cur diff delta = 189.25401306152344
# Cur diff sigma = 8.16315746307373
# Cur diff theta = 197.41717052459717
# ---------------------------------------
# IAF, d: 200, Iter: 3-1520, s/iter: 2.909e-01, ELBO: -1.241e+06
# Cur diff delta = 189.2325439453125
# Cur diff sigma = 8.163640975952148
# Cur diff theta = 197.39618492126465
# ---------------------------------------
# IAF, d: 200, Iter: 3-1540, s/iter: 2.895e-01, ELBO: -1.241e+06
# Cur diff delta = 189.25186157226562
# Cur diff sigma = 8.16401481628418
# Cur diff theta = 197.4158763885498
# ---------------------------------------
# IAF, d: 200, Iter: 3-1560, s/iter: 2.975e-01, ELBO: -1.241e+06
# Cur diff delta = 189.2682647705078
# Cur diff sigma = 8.16403579711914
# Cur diff theta = 197.43230056762695
# ---------------------------------------
# IAF, d: 200, Iter: 3-1580, s/iter: 3.014e-01, ELBO: -1.241e+06
# Cur diff delta = 189.26397705078125
# Cur diff sigma = 8.164779663085938
# Cur diff theta = 197.4287567138672
# ---------------------------------------
# IAF, d: 200, Iter: 3-1600, s/iter: 2.997e-01, ELBO: -1.241e+06
# Cur diff delta = 189.2539520263672
# Cur diff sigma = 8.164523124694824
# Cur diff theta = 197.418475151062
# ---------------------------------------
# IAF, d: 200, Iter: 3-1620, s/iter: 3.000e-01, ELBO: -1.241e+06
# Cur diff delta = 189.23245239257812
# Cur diff sigma = 8.163460731506348
# Cur diff theta = 197.39591312408447
# ---------------------------------------
# IAF, d: 200, Iter: 3-1640, s/iter: 3.020e-01, ELBO: -1.241e+06
# Cur diff delta = 189.2262420654297
# Cur diff sigma = 8.162890434265137
# Cur diff theta = 197.38913249969482
# ---------------------------------------
# IAF, d: 200, Iter: 3-1660, s/iter: 3.036e-01, ELBO: -1.241e+06
# Cur diff delta = 189.2827606201172
# Cur diff sigma = 8.164968490600586
# Cur diff theta = 197.44772911071777
# ---------------------------------------
# IAF, d: 200, Iter: 3-1680, s/iter: 3.055e-01, ELBO: -1.241e+06
# Cur diff delta = 189.24009704589844
# Cur diff sigma = 8.164185523986816
# Cur diff theta = 197.40428256988525
# ---------------------------------------
# IAF, d: 200, Iter: 3-1700, s/iter: 3.026e-01, ELBO: -1.241e+06
# Cur diff delta = 189.28167724609375
# Cur diff sigma = 8.16427230834961
# Cur diff theta = 197.44594955444336
# ---------------------------------------
# IAF, d: 200, Iter: 3-1720, s/iter: 2.948e-01, ELBO: -1.241e+06
# Cur diff delta = 189.26576232910156
# Cur diff sigma = 8.164679527282715
# Cur diff theta = 197.43044185638428
# ---------------------------------------
# IAF, d: 200, Iter: 3-1740, s/iter: 2.925e-01, ELBO: -1.241e+06
# Cur diff delta = 189.2583465576172
# Cur diff sigma = 8.16359806060791
# Cur diff theta = 197.4219446182251
# ---------------------------------------
# IAF, d: 200, Iter: 3-1760, s/iter: 3.010e-01, ELBO: -1.241e+06
# Cur diff delta = 189.24668884277344
# Cur diff sigma = 8.163759231567383
# Cur diff theta = 197.41044807434082
# ---------------------------------------
# IAF, d: 200, Iter: 3-1780, s/iter: 3.000e-01, ELBO: -1.241e+06
# Cur diff delta = 189.23870849609375
# Cur diff sigma = 8.164228439331055
# Cur diff theta = 197.4029369354248
# ---------------------------------------
# IAF, d: 200, Iter: 3-1800, s/iter: 2.943e-01, ELBO: -1.241e+06
# Cur diff delta = 189.2716064453125
# Cur diff sigma = 8.163814544677734
# Cur diff theta = 197.43542098999023
# ---------------------------------------
# IAF, d: 200, Iter: 3-1820, s/iter: 2.996e-01, ELBO: -1.241e+06
# Cur diff delta = 189.27682495117188
# Cur diff sigma = 8.164527893066406
# Cur diff theta = 197.44135284423828
# ---------------------------------------
# IAF, d: 200, Iter: 3-1840, s/iter: 2.949e-01, ELBO: -1.241e+06
# Cur diff delta = 189.25350952148438
# Cur diff sigma = 8.163751602172852
# Cur diff theta = 197.41726112365723
# ---------------------------------------
# IAF, d: 200, Iter: 3-1860, s/iter: 2.965e-01, ELBO: -1.241e+06
# Cur diff delta = 189.26922607421875
# Cur diff sigma = 8.164527893066406
# Cur diff theta = 197.43375396728516
# ---------------------------------------
# IAF, d: 200, Iter: 3-1880, s/iter: 2.952e-01, ELBO: -1.241e+06
# Cur diff delta = 189.26055908203125
# Cur diff sigma = 8.163476943969727
# Cur diff theta = 197.42403602600098
# ---------------------------------------
# IAF, d: 200, Iter: 3-1900, s/iter: 2.974e-01, ELBO: -1.241e+06
# Cur diff delta = 189.26812744140625
# Cur diff sigma = 8.163028717041016
# Cur diff theta = 197.43115615844727
# ---------------------------------------
# IAF, d: 200, Iter: 3-1920, s/iter: 3.004e-01, ELBO: -1.241e+06
# Cur diff delta = 189.26608276367188
# Cur diff sigma = 8.164043426513672
# Cur diff theta = 197.43012619018555
# ---------------------------------------
# IAF, d: 200, Iter: 3-1940, s/iter: 3.031e-01, ELBO: -1.241e+06
# Cur diff delta = 189.27264404296875
# Cur diff sigma = 8.164891242980957
# Cur diff theta = 197.4375352859497
# ---------------------------------------
# IAF, d: 200, Iter: 3-1960, s/iter: 3.012e-01, ELBO: -1.241e+06
# Cur diff delta = 189.24642944335938
# Cur diff sigma = 8.162782669067383
# Cur diff theta = 197.40921211242676
# ---------------------------------------
# IAF, d: 200, Iter: 3-1980, s/iter: 2.953e-01, ELBO: -1.241e+06
# Cur diff delta = 189.253173828125
# Cur diff sigma = 8.163704872131348
# Cur diff theta = 197.41687870025635
# ---------------------------------------
# IAF, d: 200, Iter: 3-2000, s/iter: 2.944e-01, ELBO: -1.241e+06
# Cur diff delta = 189.26095581054688
# Cur diff sigma = 8.163840293884277
# Cur diff theta = 197.42479610443115
# ---------------------------------------
# Model IAF, test = 0, result delta diff = 214.7330780029297
# Model IAF, test = 0, result sigma diff = 8.195390701293945
# Model IAF, test = 0, result theta diff = 222.928466796875
# Model IAF, test = 1, result delta diff = 228.4142608642578
# Model IAF, test = 1, result sigma diff = 8.18687629699707
# Model IAF, test = 1, result theta diff = 236.60113525390625
# Model IAF, test = 2, result delta diff = 189.2609405517578
# Model IAF, test = 2, result sigma diff = 8.163841247558594
# Model IAF, test = 2, result theta diff = 197.42477416992188

# %%
model_names = ['IAF']
diff_delta_results = {}
diff_sigma_results = {}
diff_results = {}
for name in model_names:
    diff_delta_tests = np.zeros(params['n_tests'])
    diff_sigma_tests = np.zeros(params['n_tests'])
    diff_tests = np.zeros(params['n_tests'])
    for i in range(params['n_tests']):
        file_name = name + '_train_' + str(i) + '.p'
        diff_path = os.path.join('save', str(params['dims'][0]), file_name)
        with open(diff_path, 'rb') as f:
            data = pickle.load(f)
            elbo = data['elbo']
            diff_delta = data['diff_delta']
            diff_sigma = data['diff_sigma']
            diff = diff_delta + diff_sigma
            diff_delta_is_not_nan = diff_delta[~np.isnan(diff_delta)]
            diff_sigma_is_not_nan = diff_sigma[~np.isnan(diff_sigma)]
            diff_is_not_nan = diff[~np.isnan(diff)]
            diff_delta_tests[i] = diff_delta_is_not_nan[-1]
            diff_sigma_tests[i] = diff_sigma_is_not_nan[-1]
            diff_tests[i] = diff_is_not_nan[-1]
    diff_delta_results[name] = diff_delta_tests
    diff_sigma_results[name] = diff_sigma_tests
    diff_results[name] = diff_tests
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, diff delta = {diff_delta_tests}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, diff sigma = {diff_sigma_tests}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, diff = {diff_tests}")
# Out:
# Model = IAF, dimensionality = 200, diff delta = [214.73306274 228.41424561 189.26095581]
# Model = IAF, dimensionality = 200, diff sigma = [8.19539165 8.18687725 8.16384029]
# Model = IAF, dimensionality = 200, diff = [222.92845154 236.60112    197.42478943]

# %%
for name in model_names:
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, mean diff delta = {diff_delta_results[name].mean()}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, mean diff sigma = {diff_sigma_results[name].mean()}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, mean diff = {diff_results[name].mean()}")
# Out:
# Model = IAF, dimensionality = 200, mean diff delta = 210.8027547200521
# Model = IAF, dimensionality = 200, mean diff sigma = 8.182036399841309
# Model = IAF, dimensionality = 200, mean diff = 218.9847869873047
