# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
from torch.distributions.normal import Normal
import torch.optim as optim
from torch.distributions.multivariate_normal import MultivariateNormal
from torch.nn import Parameter
from torch import nn
from torch.utils.data import Dataset, DataLoader

import scipy.stats
import time
import pickle
import os
import sys

# %%
# !rm -r h-vae/

# %%
# !git clone https://github.com/Daniil-Selikhanovych/h-vae
# Out:
# Cloning into 'h-vae'...
# remote: Enumerating objects: 106, done.
# remote: Counting objects: 100% (106/106), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 106 (delta 32), reused 97 (delta 26), pack-reused 0
# Receiving objects: 100% (106/106), 400.62 KiB | 26.71 MiB/s, done.
# Resolving deltas: 100% (32/32), done.

# %%
# !pip install pyro-ppl

from pyro.nn import AutoRegressiveNN
# Out:
# Collecting pyro-ppl
#   Downloading https://files.pythonhosted.org/packages/3d/1b/946ff38dd8675b8fa114444df0940db078eb42e5354df46645a9e9467085/pyro_ppl-1.5.0-py3-none-any.whl (604kB)
#      |████████████████████████████████| 614kB 11.6MB/s
# Collecting pyro-api>=0.1.1
#   Downloading https://files.pythonhosted.org/packages/fc/81/957ae78e6398460a7230b0eb9b8f1cb954c5e913e868e48d89324c68cec7/pyro_api-0.1.2-py3-none-any.whl
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from pyro-ppl) (3.3.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from pyro-ppl) (1.18.5)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from pyro-ppl) (1.6.0+cu101)
# Requirement already satisfied: tqdm>=4.36 in /usr/local/lib/python3.6/dist-packages (from pyro-ppl) (4.41.1)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch>=1.6.0->pyro-ppl) (0.16.0)
# Installing collected packages: pyro-api, pyro-ppl
# Successfully installed pyro-api-0.1.2 pyro-ppl-1.5.0

# %%
path_to_gaussians = os.path.join(os.getcwd(), 'h-vae', 'gaussians')
path_to_gaussians_api = os.path.join(path_to_gaussians, 'api')

sys.path.append(path_to_gaussians)
sys.path.append(path_to_gaussians_api)

# %%
from models import HVAE, NF, VB, IAF

# %%
class gaussian_dataset(Dataset):
    def __init__(self, x):
          'Initialization'
          self.x = x

    def __len__(self):
          'Denotes the total number of samples'
          return self.x.shape[0]

    def __getitem__(self, index):
          'Generates one sample of data'
          x_index = self.x[index]

          return x_index

# %%
def run_test(d, params, 
             batch_size=256,
             clip_value=None,
             dtype=torch.float32, 
             device=torch.device("cpu")):
    """ 
    Run the gaussian test with dimension d 
    """

    ######### Problem Specification

    # Data generation parameters
    prior_mu_z = torch.zeros(d, dtype=dtype)    # Prior mean
    prior_sigma_z = torch.eye(d, dtype=dtype)   # Prior covariance matrix

    # True model parameters
    num_range = torch.arange(-(d-1)/2, (d+1)/2, dtype=dtype)

    t_delta =  num_range / 5 

    print(f"true delta = {t_delta.numpy()}")

    if d == 1:
        t_sigma = torch.ones(1, dtype=dtype)
    else: 
        # Allow sigma to range from 0.1 to 1
        t_sigma = 36/(10*(d-1)**2) * num_range**2 + 0.1 
    print(f"true sigma = {t_sigma.numpy()}")

    ######### Variable Initialization

    # Initial model parameters - same across all methods
    init_delta = prior_mu_z.clone().to(device)
    init_log_sigma = 3 * torch.ones(d).to(device)

    # Initial HVAE variational parameters
    init_T = torch.tensor(5., dtype=dtype, device=device)
    init_eps = 0.005 * torch.ones(d, dtype=dtype)
    max_eps = params['max_eps'] * torch.ones(d, dtype=dtype)
    init_logit_eps = torch.log(init_eps/(max_eps - init_eps)).to(device)
    init_log_T_0 = torch.log(init_T - 1)

    # Initial NF variational parameters
    init_u_pre_reparam = torch.tensor(scipy.stats.truncnorm.rvs(-2, 2, 
                                                                scale=0.1, 
                                                                size=d),
                                      dtype=dtype, device=device)
    init_w = torch.tensor(scipy.stats.truncnorm.rvs(-2, 2, scale=0.1, size=d),
                          dtype=dtype, device=device)
    init_b = torch.tensor(0.1, dtype=dtype, device=device)

    # Initial VAE parameters
    init_mu_z = prior_mu_z.clone()
    init_log_sigma_z = torch.ones(d, dtype=dtype)

    ######### Set up models
    init_params = [[init_delta, init_log_sigma, init_logit_eps, init_log_T_0],
                   [init_delta, init_log_sigma, init_logit_eps, init_log_T_0],
                   [init_delta, init_log_sigma, init_u_pre_reparam, init_w, init_b],
                   [init_delta, init_log_sigma, init_u_pre_reparam, init_w, init_b],
                   [init_delta, init_log_sigma, init_mu_z, init_log_sigma_z]]

    HVAE_model_1 = HVAE(params,
        ['delta', 'log_sigma', 'logit_eps', 'log_T_0'],
        init_params[0], 
        'HVAE_1', d, params['HVAE_K_1'])
    HVAE_model_2 = HVAE(params,
        ['delta', 'log_sigma', 'logit_eps', 'log_T_0'],
        init_params[1], 
        'HVAE_2', d, params['HVAE_K_2'])
    
    
    NF_model_1 = NF(params,
        ['delta', 'log_sigma', 'u_pre_reparam', 'w', 'b'],
        init_params[2],
        'NF_1', d, params['NF_K_1'])
    
    NF_model_2 = NF(params,
        ['delta', 'log_sigma', 'u_pre_reparam', 'w', 'b'],
        init_params[3],
        'NF_2', d, params['NF_K_2'])
    
    VB_model = VB(params,
        ['delta', 'log_sigma', 'mu_z', 'log_sigma_z'], 
        init_params[4], 'VB', d)

    #model_list = [HVAE_model_1, HVAE_model_2, NF_model_1]
    #model_list = [HVAE_model_1, NF_model_1]
    model_list = [HVAE_model_1, HVAE_model_2, NF_model_1, NF_model_2, VB_model]

    print("Models were initialized!")
    
    ######### Generate Training Data & Save - One for each test

    train_data_list = []

    for i in range(params['n_tests']):
        z = MultivariateNormal(prior_mu_z, prior_sigma_z).sample()
        x = MultivariateNormal(z + t_delta, 
                               torch.diag(t_sigma**2)).sample([params['n_data']])
        x = x.to(device)
        train_data_list.append(x)

    # Folder should have already been created in the initializations
    data_path = os.path.join('save', str(d), 'train_data.p')
    pickle.dump(train_data_list, open(data_path, 'wb')) 

    # Store the final parameter values for all test runs in this dictionary
    final_params = {}

    for i in range(len(model_list)):
        final_values = []
        m = model_list[i]
        model_init_params = init_params[i]

        for j in range(params['n_tests']):
            print("------------------------------------------------------")
            print(f"Test = {j}")
            print("------------------------------------------------------")
            m._reinitialize(model_init_params)
            gaussian_data = gaussian_dataset(train_data_list[j])
            train_dataloader = DataLoader(gaussian_data, batch_size=batch_size,
                                          shuffle=False, num_workers=0)
            (delta, sigma) = m.train(train_dataloader, j, 
                                     t_delta, t_sigma,
                                     clip_value)
            final_values.append((delta, sigma))

        final_params[m.model_name] = final_values.copy()

    ######### Test models using difference between parameters

    param_diffs = {}

    for m in model_list:
        
        diffs = []

        for i in range(params['n_tests']):
            delta = final_params[m.model_name][i][0]
            sigma = final_params[m.model_name][i][1]

            delta_diff = np.sum((delta - t_delta.numpy())**2)
            sigma_diff = np.sum((sigma - t_sigma.numpy())**2)
            theta_diff = delta_diff + sigma_diff
            print(f"Model {m.model_name}, test = {i}, result delta diff = {delta_diff}")
            print(f"Model {m.model_name}, test = {i}, result sigma diff = {sigma_diff}")
            print(f"Model {m.model_name}, test = {i}, result theta diff = {theta_diff}")

            diffs.append((delta_diff, sigma_diff, theta_diff))

        param_diffs[m.model_name] = diffs.copy()

    # Save parameter differences in a pickle file
    diff_path = os.path.join('save', str(d), 'all_diffs.p')
    pickle.dump(param_diffs, open(diff_path, 'wb'))

# %%
params = {

    # PROBLEM SPECIFICATION
    #'dims': [1, 2, 3, 5, 11, 25, 51, 101, 201, 301], # Dimensions to test
    'dims': [100],
    'n_data': 10000,                                 # Number of data points

    # TEST HYPERPARAMETERS
    'n_tests': 3,      # Number of experiments to run

    # GLOBAL OPTIMIZATION PARAMETERS
    'n_iter': 2000,    # Number of optimization iterations
    'n_batch': 10,      # Number of points for ELBO estimate
    'rms_eta': 0.001,   # Stepsize for RMSProp
    'save_every': 20,   # Save parameter information every so often
    'print_every': 20, # Print less often than save

    # HVAE HYPERPARAMETERS
    'HVAE_K_1': 1,    # Number of leapfrog/cooling steps for HVAE flow 1
    'HVAE_K_2': 10,   # Number of leapfrog/cooling steps for HVAE flow 2
    'max_eps': 0.5,   # Maximum leapfrog step size per dimension 

    # NF HYPERPARAMETERS
    'NF_K_1': 1,    # Number of flow steps for NF flow 1
    'NF_K_2': 30,   # Number of flow steps for NF flow 2
    
}

# %%
device = torch.device("cpu")
dtype = torch.float32
clip_value = 1e-4
batch_size = 256

# %%
dims = params['dims']
seed = 12345
np.random.seed(seed)
torch.manual_seed(seed)
for d in dims:
    print('**** Running test for d={0:d} ****'.format(d))
    run_test(d, params, batch_size, clip_value, dtype, device)
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# HVAE_2, d: 100, Iter: 3-420, s/iter: 2.283e-01, ELBO: -5.345e+05
# Cur diff delta = 109.19351196289062
# Cur diff sigma = 0.15246424078941345
# Cur diff theta = 109.34597620368004
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-440, s/iter: 2.074e-01, ELBO: -5.318e+05
# Cur diff delta = 108.63592529296875
# Cur diff sigma = 0.15398748219013214
# Cur diff theta = 108.78991277515888
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-460, s/iter: 2.090e-01, ELBO: -5.349e+05
# Cur diff delta = 109.04488372802734
# Cur diff sigma = 0.1533268541097641
# Cur diff theta = 109.19821058213711
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-480, s/iter: 2.148e-01, ELBO: -5.328e+05
# Cur diff delta = 109.04862213134766
# Cur diff sigma = 0.15377859771251678
# Cur diff theta = 109.20240072906017
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-500, s/iter: 2.256e-01, ELBO: -5.353e+05
# Cur diff delta = 109.0512466430664
# Cur diff sigma = 0.1555805653333664
# Cur diff theta = 109.20682720839977
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-520, s/iter: 2.490e-01, ELBO: -5.324e+05
# Cur diff delta = 109.44401550292969
# Cur diff sigma = 0.15329323709011078
# Cur diff theta = 109.5973087400198
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-540, s/iter: 2.098e-01, ELBO: -5.353e+05
# Cur diff delta = 109.37793731689453
# Cur diff sigma = 0.15334752202033997
# Cur diff theta = 109.53128483891487
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-560, s/iter: 2.274e-01, ELBO: -5.345e+05
# Cur diff delta = 108.70242309570312
# Cur diff sigma = 0.15272124111652374
# Cur diff theta = 108.85514433681965
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-580, s/iter: 2.292e-01, ELBO: -5.369e+05
# Cur diff delta = 109.10273742675781
# Cur diff sigma = 0.15388181805610657
# Cur diff theta = 109.25661924481392
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-600, s/iter: 2.183e-01, ELBO: -5.325e+05
# Cur diff delta = 109.67578125
# Cur diff sigma = 0.1530192792415619
# Cur diff theta = 109.82880052924156
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-620, s/iter: 2.063e-01, ELBO: -5.326e+05
# Cur diff delta = 109.22592163085938
# Cur diff sigma = 0.1536003053188324
# Cur diff theta = 109.37952193617821
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-640, s/iter: 2.427e-01, ELBO: -5.337e+05
# Cur diff delta = 109.03534698486328
# Cur diff sigma = 0.15272454917430878
# Cur diff theta = 109.18807153403759
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-660, s/iter: 2.217e-01, ELBO: -5.321e+05
# Cur diff delta = 109.39751434326172
# Cur diff sigma = 0.1528383493423462
# Cur diff theta = 109.55035269260406
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-680, s/iter: 2.232e-01, ELBO: -5.333e+05
# Cur diff delta = 108.92202758789062
# Cur diff sigma = 0.15408430993556976
# Cur diff theta = 109.0761118978262
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-700, s/iter: 2.359e-01, ELBO: -5.350e+05
# Cur diff delta = 109.42716979980469
# Cur diff sigma = 0.15287812054157257
# Cur diff theta = 109.58004792034626
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-720, s/iter: 2.144e-01, ELBO: -5.351e+05
# Cur diff delta = 108.98307800292969
# Cur diff sigma = 0.15347778797149658
# Cur diff theta = 109.13655579090118
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-740, s/iter: 2.180e-01, ELBO: -5.325e+05
# Cur diff delta = 109.06620025634766
# Cur diff sigma = 0.15459725260734558
# Cur diff theta = 109.220797508955
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-760, s/iter: 2.109e-01, ELBO: -5.338e+05
# Cur diff delta = 109.62407684326172
# Cur diff sigma = 0.15356315672397614
# Cur diff theta = 109.7776399999857
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-780, s/iter: 2.156e-01, ELBO: -5.321e+05
# Cur diff delta = 109.2174072265625
# Cur diff sigma = 0.15344703197479248
# Cur diff theta = 109.37085425853729
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-800, s/iter: 2.051e-01, ELBO: -5.326e+05
# Cur diff delta = 109.24215698242188
# Cur diff sigma = 0.15321609377861023
# Cur diff theta = 109.39537307620049
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-820, s/iter: 2.228e-01, ELBO: -5.325e+05
# Cur diff delta = 109.29679107666016
# Cur diff sigma = 0.15177276730537415
# Cur diff theta = 109.44856384396553
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-840, s/iter: 2.193e-01, ELBO: -5.330e+05
# Cur diff delta = 108.79540252685547
# Cur diff sigma = 0.151432067155838
# Cur diff theta = 108.9468345940113
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-860, s/iter: 2.227e-01, ELBO: -5.332e+05
# Cur diff delta = 108.9406967163086
# Cur diff sigma = 0.15236873924732208
# Cur diff theta = 109.09306545555592
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-880, s/iter: 2.182e-01, ELBO: -5.335e+05
# Cur diff delta = 109.3028335571289
# Cur diff sigma = 0.15218999981880188
# Cur diff theta = 109.45502355694771
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-900, s/iter: 2.164e-01, ELBO: -5.311e+05
# Cur diff delta = 109.09074401855469
# Cur diff sigma = 0.1527967005968094
# Cur diff theta = 109.2435407191515
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-920, s/iter: 2.105e-01, ELBO: -5.341e+05
# Cur diff delta = 109.25904846191406
# Cur diff sigma = 0.15353743731975555
# Cur diff theta = 109.41258589923382
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-940, s/iter: 2.053e-01, ELBO: -5.339e+05
# Cur diff delta = 109.39610290527344
# Cur diff sigma = 0.15189628303050995
# Cur diff theta = 109.54799918830395
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-960, s/iter: 2.119e-01, ELBO: -5.341e+05
# Cur diff delta = 109.01799011230469
# Cur diff sigma = 0.1533840000629425
# Cur diff theta = 109.17137411236763
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-980, s/iter: 2.156e-01, ELBO: -5.347e+05
# Cur diff delta = 109.24014282226562
# Cur diff sigma = 0.15313966572284698
# Cur diff theta = 109.39328248798847
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1000, s/iter: 2.505e-01, ELBO: -5.329e+05
# Cur diff delta = 108.85743713378906
# Cur diff sigma = 0.15582291781902313
# Cur diff theta = 109.01326005160809
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1020, s/iter: 2.447e-01, ELBO: -5.335e+05
# Cur diff delta = 109.2220458984375
# Cur diff sigma = 0.15422920882701874
# Cur diff theta = 109.37627510726452
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1040, s/iter: 2.174e-01, ELBO: -5.350e+05
# Cur diff delta = 108.86376953125
# Cur diff sigma = 0.15341489017009735
# Cur diff theta = 109.0171844214201
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1060, s/iter: 2.228e-01, ELBO: -5.337e+05
# Cur diff delta = 108.6578140258789
# Cur diff sigma = 0.15386097133159637
# Cur diff theta = 108.8116749972105
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1080, s/iter: 2.267e-01, ELBO: -5.323e+05
# Cur diff delta = 109.19239807128906
# Cur diff sigma = 0.15290263295173645
# Cur diff theta = 109.3453007042408
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1100, s/iter: 2.278e-01, ELBO: -5.341e+05
# Cur diff delta = 108.86497497558594
# Cur diff sigma = 0.1528344750404358
# Cur diff theta = 109.01780945062637
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1120, s/iter: 2.101e-01, ELBO: -5.374e+05
# Cur diff delta = 109.51731872558594
# Cur diff sigma = 0.1531255841255188
# Cur diff theta = 109.67044430971146
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1140, s/iter: 2.312e-01, ELBO: -5.367e+05
# Cur diff delta = 109.20686340332031
# Cur diff sigma = 0.15374109148979187
# Cur diff theta = 109.3606044948101
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1160, s/iter: 2.130e-01, ELBO: -5.330e+05
# Cur diff delta = 109.52259826660156
# Cur diff sigma = 0.15307989716529846
# Cur diff theta = 109.67567816376686
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1180, s/iter: 2.178e-01, ELBO: -5.337e+05
# Cur diff delta = 108.81595611572266
# Cur diff sigma = 0.15278972685337067
# Cur diff theta = 108.96874584257603
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1200, s/iter: 2.240e-01, ELBO: -5.315e+05
# Cur diff delta = 109.22509765625
# Cur diff sigma = 0.15283581614494324
# Cur diff theta = 109.37793347239494
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1220, s/iter: 2.143e-01, ELBO: -5.328e+05
# Cur diff delta = 109.45941162109375
# Cur diff sigma = 0.15310244262218475
# Cur diff theta = 109.61251406371593
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1240, s/iter: 2.317e-01, ELBO: -5.352e+05
# Cur diff delta = 108.8182373046875
# Cur diff sigma = 0.15273882448673248
# Cur diff theta = 108.97097612917423
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1260, s/iter: 2.185e-01, ELBO: -5.359e+05
# Cur diff delta = 109.01710510253906
# Cur diff sigma = 0.15280453860759735
# Cur diff theta = 109.16990964114666
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1280, s/iter: 2.131e-01, ELBO: -5.334e+05
# Cur diff delta = 108.90482330322266
# Cur diff sigma = 0.1543874740600586
# Cur diff theta = 109.05921077728271
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1300, s/iter: 2.312e-01, ELBO: -5.348e+05
# Cur diff delta = 109.6549301147461
# Cur diff sigma = 0.15385255217552185
# Cur diff theta = 109.80878266692162
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1320, s/iter: 2.134e-01, ELBO: -5.311e+05
# Cur diff delta = 109.17854309082031
# Cur diff sigma = 0.15408317744731903
# Cur diff theta = 109.33262626826763
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1340, s/iter: 2.313e-01, ELBO: -5.341e+05
# Cur diff delta = 109.34548950195312
# Cur diff sigma = 0.15447792410850525
# Cur diff theta = 109.49996742606163
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1360, s/iter: 2.399e-01, ELBO: -5.355e+05
# Cur diff delta = 109.15034484863281
# Cur diff sigma = 0.15292935073375702
# Cur diff theta = 109.30327419936657
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1380, s/iter: 2.093e-01, ELBO: -5.346e+05
# Cur diff delta = 108.9236068725586
# Cur diff sigma = 0.15253902971744537
# Cur diff theta = 109.07614590227604
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1400, s/iter: 2.143e-01, ELBO: -5.343e+05
# Cur diff delta = 108.5666275024414
# Cur diff sigma = 0.15333977341651917
# Cur diff theta = 108.71996727585793
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1420, s/iter: 2.249e-01, ELBO: -5.337e+05
# Cur diff delta = 109.02862548828125
# Cur diff sigma = 0.15242116153240204
# Cur diff theta = 109.18104664981365
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1440, s/iter: 2.276e-01, ELBO: -5.349e+05
# Cur diff delta = 109.17269134521484
# Cur diff sigma = 0.15389353036880493
# Cur diff theta = 109.32658487558365
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1460, s/iter: 2.144e-01, ELBO: -5.316e+05
# Cur diff delta = 109.27999114990234
# Cur diff sigma = 0.1550353765487671
# Cur diff theta = 109.43502652645111
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1480, s/iter: 2.183e-01, ELBO: -5.325e+05
# Cur diff delta = 109.39930725097656
# Cur diff sigma = 0.15323694050312042
# Cur diff theta = 109.55254419147968
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1500, s/iter: 2.295e-01, ELBO: -5.341e+05
# Cur diff delta = 109.15347290039062
# Cur diff sigma = 0.15454524755477905
# Cur diff theta = 109.3080181479454
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1520, s/iter: 2.224e-01, ELBO: -5.345e+05
# Cur diff delta = 109.04399108886719
# Cur diff sigma = 0.15331925451755524
# Cur diff theta = 109.19731034338474
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1540, s/iter: 2.262e-01, ELBO: -5.348e+05
# Cur diff delta = 108.8086166381836
# Cur diff sigma = 0.1534983068704605
# Cur diff theta = 108.96211494505405
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1560, s/iter: 2.397e-01, ELBO: -5.343e+05
# Cur diff delta = 109.64203643798828
# Cur diff sigma = 0.15327298641204834
# Cur diff theta = 109.79530942440033
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1580, s/iter: 2.324e-01, ELBO: -5.338e+05
# Cur diff delta = 108.98824310302734
# Cur diff sigma = 0.15344774723052979
# Cur diff theta = 109.14169085025787
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1600, s/iter: 2.367e-01, ELBO: -5.317e+05
# Cur diff delta = 109.1568374633789
# Cur diff sigma = 0.1536969542503357
# Cur diff theta = 109.31053441762924
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1620, s/iter: 2.446e-01, ELBO: -5.335e+05
# Cur diff delta = 109.38706970214844
# Cur diff sigma = 0.1522052139043808
# Cur diff theta = 109.53927491605282
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1640, s/iter: 2.265e-01, ELBO: -5.328e+05
# Cur diff delta = 109.1025161743164
# Cur diff sigma = 0.15352194011211395
# Cur diff theta = 109.25603811442852
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1660, s/iter: 2.346e-01, ELBO: -5.333e+05
# Cur diff delta = 108.81532287597656
# Cur diff sigma = 0.1512051522731781
# Cur diff theta = 108.96652802824974
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1680, s/iter: 2.217e-01, ELBO: -5.337e+05
# Cur diff delta = 108.49246978759766
# Cur diff sigma = 0.15239767730236053
# Cur diff theta = 108.64486746490002
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1700, s/iter: 2.188e-01, ELBO: -5.351e+05
# Cur diff delta = 109.27030944824219
# Cur diff sigma = 0.15369462966918945
# Cur diff theta = 109.42400407791138
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1720, s/iter: 2.201e-01, ELBO: -5.336e+05
# Cur diff delta = 109.15312957763672
# Cur diff sigma = 0.1528184711933136
# Cur diff theta = 109.30594804883003
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1740, s/iter: 2.279e-01, ELBO: -5.361e+05
# Cur diff delta = 109.233154296875
# Cur diff sigma = 0.15401099622249603
# Cur diff theta = 109.3871652930975
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1760, s/iter: 2.487e-01, ELBO: -5.367e+05
# Cur diff delta = 109.07593536376953
# Cur diff sigma = 0.15445731580257416
# Cur diff theta = 109.2303926795721
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1780, s/iter: 2.169e-01, ELBO: -5.320e+05
# Cur diff delta = 109.06342315673828
# Cur diff sigma = 0.15433861315250397
# Cur diff theta = 109.21776176989079
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1800, s/iter: 2.327e-01, ELBO: -5.370e+05
# Cur diff delta = 109.16337585449219
# Cur diff sigma = 0.1529223471879959
# Cur diff theta = 109.31629820168018
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1820, s/iter: 2.192e-01, ELBO: -5.330e+05
# Cur diff delta = 108.57179260253906
# Cur diff sigma = 0.15375015139579773
# Cur diff theta = 108.72554275393486
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1840, s/iter: 2.146e-01, ELBO: -5.363e+05
# Cur diff delta = 109.60186004638672
# Cur diff sigma = 0.15386615693569183
# Cur diff theta = 109.75572620332241
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1860, s/iter: 2.198e-01, ELBO: -5.333e+05
# Cur diff delta = 108.73731231689453
# Cur diff sigma = 0.152822345495224
# Cur diff theta = 108.89013466238976
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1880, s/iter: 2.109e-01, ELBO: -5.365e+05
# Cur diff delta = 108.97016906738281
# Cur diff sigma = 0.1523808240890503
# Cur diff theta = 109.12254989147186
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1900, s/iter: 2.139e-01, ELBO: -5.335e+05
# Cur diff delta = 109.15084838867188
# Cur diff sigma = 0.15382036566734314
# Cur diff theta = 109.30466875433922
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1920, s/iter: 2.181e-01, ELBO: -5.336e+05
# Cur diff delta = 109.00187683105469
# Cur diff sigma = 0.1534392237663269
# Cur diff theta = 109.15531605482101
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1940, s/iter: 2.353e-01, ELBO: -5.354e+05
# Cur diff delta = 108.92593383789062
# Cur diff sigma = 0.15385682880878448
# Cur diff theta = 109.07979066669941
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1960, s/iter: 2.207e-01, ELBO: -5.347e+05
# Cur diff delta = 109.09796142578125
# Cur diff sigma = 0.15284191071987152
# Cur diff theta = 109.25080333650112
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-1980, s/iter: 2.241e-01, ELBO: -5.311e+05
# Cur diff delta = 109.2848892211914
# Cur diff sigma = 0.15215802192687988
# Cur diff theta = 109.43704724311829
# ---------------------------------------
# HVAE_2, d: 100, Iter: 3-2000, s/iter: 2.176e-01, ELBO: -5.340e+05
# Cur diff delta = 109.26582336425781
# Cur diff sigma = 0.15267325937747955
# Cur diff theta = 109.41849662363529
# ---------------------------------------
# ------------------------------------------------------
# Test = 0
# ------------------------------------------------------
# Init diff delta = 3333.0
# Init diff sigma = 38735.67578125
# Init diff theta = 42068.67578125
# NF_1, d: 100, Iter: 1-20, s/iter: 1.034e-01, ELBO: -3.518e+06
# Cur diff delta = 2747.603515625
# Cur diff sigma = 12240.470703125
# Cur diff theta = 14988.07421875
# ---------------------------------------
# NF_1, d: 100, Iter: 1-40, s/iter: 9.391e-02, ELBO: -3.263e+06
# Cur diff delta = 2476.1318359375
# Cur diff sigma = 6199.1884765625
# Cur diff theta = 8675.3203125
# ---------------------------------------
# NF_1, d: 100, Iter: 1-60, s/iter: 9.549e-02, ELBO: -2.949e+06
# Cur diff delta = 2118.177001953125
# Cur diff sigma = 3300.05859375
# Cur diff theta = 5418.235595703125
# ---------------------------------------
# NF_1, d: 100, Iter: 1-80, s/iter: 9.585e-02, ELBO: -2.678e+06
# Cur diff delta = 1766.2906494140625
# Cur diff sigma = 2388.37939453125
# Cur diff theta = 4154.6700439453125
# ---------------------------------------
# NF_1, d: 100, Iter: 1-100, s/iter: 9.332e-02, ELBO: -2.455e+06
# Cur diff delta = 1432.7059326171875
# Cur diff sigma = 1883.273193359375
# Cur diff theta = 3315.9791259765625
# ---------------------------------------
# NF_1, d: 100, Iter: 1-120, s/iter: 9.919e-02, ELBO: -2.289e+06
# Cur diff delta = 1113.375732421875
# Cur diff sigma = 1430.9654541015625
# Cur diff theta = 2544.3411865234375
# ---------------------------------------
# NF_1, d: 100, Iter: 1-140, s/iter: 9.237e-02, ELBO: -2.131e+06
# Cur diff delta = 794.8785400390625
# Cur diff sigma = 960.7859497070312
# Cur diff theta = 1755.6644897460938
# ---------------------------------------
# NF_1, d: 100, Iter: 1-160, s/iter: 9.373e-02, ELBO: -1.987e+06
# Cur diff delta = 551.8268432617188
# Cur diff sigma = 613.9260864257812
# Cur diff theta = 1165.7529296875
# ---------------------------------------
# NF_1, d: 100, Iter: 1-180, s/iter: 9.147e-02, ELBO: -1.888e+06
# Cur diff delta = 383.855712890625
# Cur diff sigma = 409.1761779785156
# Cur diff theta = 793.0318908691406
# ---------------------------------------
# NF_1, d: 100, Iter: 1-200, s/iter: 9.094e-02, ELBO: -1.802e+06
# Cur diff delta = 268.748779296875
# Cur diff sigma = 282.5909118652344
# Cur diff theta = 551.3396911621094
# ---------------------------------------
# NF_1, d: 100, Iter: 1-220, s/iter: 9.346e-02, ELBO: -1.741e+06
# Cur diff delta = 193.29571533203125
# Cur diff sigma = 200.59906005859375
# Cur diff theta = 393.894775390625
# ---------------------------------------
# NF_1, d: 100, Iter: 1-240, s/iter: 9.290e-02, ELBO: -1.694e+06
# Cur diff delta = 143.8512420654297
# Cur diff sigma = 146.09396362304688
# Cur diff theta = 289.94520568847656
# ---------------------------------------
# NF_1, d: 100, Iter: 1-260, s/iter: 9.573e-02, ELBO: -1.659e+06
# Cur diff delta = 113.9156265258789
# Cur diff sigma = 112.70893859863281
# Cur diff theta = 226.62456512451172
# ---------------------------------------
# NF_1, d: 100, Iter: 1-280, s/iter: 9.596e-02, ELBO: -1.639e+06
# Cur diff delta = 98.392578125
# Cur diff sigma = 92.6059341430664
# Cur diff theta = 190.9985122680664
# ---------------------------------------
# NF_1, d: 100, Iter: 1-300, s/iter: 9.312e-02, ELBO: -1.621e+06
# Cur diff delta = 92.54365539550781
# Cur diff sigma = 79.95584869384766
# Cur diff theta = 172.49950408935547
# ---------------------------------------
# NF_1, d: 100, Iter: 1-320, s/iter: 1.037e-01, ELBO: -1.610e+06
# Cur diff delta = 91.91283416748047
# Cur diff sigma = 72.20809936523438
# Cur diff theta = 164.12093353271484
# ---------------------------------------
# NF_1, d: 100, Iter: 1-340, s/iter: 9.354e-02, ELBO: -1.594e+06
# Cur diff delta = 95.46710968017578
# Cur diff sigma = 66.29013061523438
# Cur diff theta = 161.75724029541016
# ---------------------------------------
# NF_1, d: 100, Iter: 1-360, s/iter: 9.211e-02, ELBO: -1.592e+06
# Cur diff delta = 100.44538116455078
# Cur diff sigma = 63.98651885986328
# Cur diff theta = 164.43190002441406
# ---------------------------------------
# NF_1, d: 100, Iter: 1-380, s/iter: 9.149e-02, ELBO: -1.587e+06
# Cur diff delta = 104.25088500976562
# Cur diff sigma = 62.79536437988281
# Cur diff theta = 167.04624938964844
# ---------------------------------------
# NF_1, d: 100, Iter: 1-400, s/iter: 9.158e-02, ELBO: -1.584e+06
# Cur diff delta = 106.1807632446289
# Cur diff sigma = 62.76587677001953
# Cur diff theta = 168.94664001464844
# ---------------------------------------
# NF_1, d: 100, Iter: 1-420, s/iter: 9.681e-02, ELBO: -1.591e+06
# Cur diff delta = 106.4041519165039
# Cur diff sigma = 63.02238845825195
# Cur diff theta = 169.42654037475586
# ---------------------------------------
# NF_1, d: 100, Iter: 1-440, s/iter: 9.962e-02, ELBO: -1.583e+06
# Cur diff delta = 106.66116333007812
# Cur diff sigma = 62.66205596923828
# Cur diff theta = 169.3232192993164
# ---------------------------------------
# NF_1, d: 100, Iter: 1-460, s/iter: 9.668e-02, ELBO: -1.582e+06
# Cur diff delta = 106.51929473876953
# Cur diff sigma = 62.48222351074219
# Cur diff theta = 169.00151824951172
# ---------------------------------------
# NF_1, d: 100, Iter: 1-480, s/iter: 9.314e-02, ELBO: -1.584e+06
# Cur diff delta = 106.32072448730469
# Cur diff sigma = 62.312705993652344
# Cur diff theta = 168.63343048095703
# ---------------------------------------
# NF_1, d: 100, Iter: 1-500, s/iter: 9.692e-02, ELBO: -1.582e+06
# Cur diff delta = 106.57574462890625
# Cur diff sigma = 62.364418029785156
# Cur diff theta = 168.9401626586914
# ---------------------------------------
# NF_1, d: 100, Iter: 1-520, s/iter: 9.389e-02, ELBO: -1.585e+06
# Cur diff delta = 106.44449615478516
# Cur diff sigma = 62.19173812866211
# Cur diff theta = 168.63623428344727
# ---------------------------------------
# NF_1, d: 100, Iter: 1-540, s/iter: 9.147e-02, ELBO: -1.588e+06
# Cur diff delta = 106.71421813964844
# Cur diff sigma = 62.471771240234375
# Cur diff theta = 169.1859893798828
# ---------------------------------------
# NF_1, d: 100, Iter: 1-560, s/iter: 9.436e-02, ELBO: -1.586e+06
# Cur diff delta = 106.64535522460938
# Cur diff sigma = 62.23228073120117
# Cur diff theta = 168.87763595581055
# ---------------------------------------
# NF_1, d: 100, Iter: 1-580, s/iter: 9.312e-02, ELBO: -1.584e+06
# Cur diff delta = 106.48646545410156
# Cur diff sigma = 62.345550537109375
# Cur diff theta = 168.83201599121094
# ---------------------------------------
# NF_1, d: 100, Iter: 1-600, s/iter: 8.979e-02, ELBO: -1.584e+06
# Cur diff delta = 106.5806884765625
# Cur diff sigma = 62.35149002075195
# Cur diff theta = 168.93217849731445
# ---------------------------------------
# NF_1, d: 100, Iter: 1-620, s/iter: 9.209e-02, ELBO: -1.578e+06
# Cur diff delta = 106.49092864990234
# Cur diff sigma = 62.3932991027832
# Cur diff theta = 168.88422775268555
# ---------------------------------------
# NF_1, d: 100, Iter: 1-640, s/iter: 1.018e-01, ELBO: -1.585e+06
# Cur diff delta = 106.59834289550781
# Cur diff sigma = 62.319122314453125
# Cur diff theta = 168.91746520996094
# ---------------------------------------
# NF_1, d: 100, Iter: 1-660, s/iter: 1.032e-01, ELBO: -1.582e+06
# Cur diff delta = 106.29733276367188
# Cur diff sigma = 62.17856979370117
# Cur diff theta = 168.47590255737305
# ---------------------------------------
# NF_1, d: 100, Iter: 1-680, s/iter: 1.022e-01, ELBO: -1.582e+06
# Cur diff delta = 106.81696319580078
# Cur diff sigma = 62.510711669921875
# Cur diff theta = 169.32767486572266
# ---------------------------------------
# NF_1, d: 100, Iter: 1-700, s/iter: 1.045e-01, ELBO: -1.575e+06
# Cur diff delta = 106.41374969482422
# Cur diff sigma = 62.42936706542969
# Cur diff theta = 168.8431167602539
# ---------------------------------------
# NF_1, d: 100, Iter: 1-720, s/iter: 9.558e-02, ELBO: -1.577e+06
# Cur diff delta = 106.4637680053711
# Cur diff sigma = 62.35204315185547
# Cur diff theta = 168.81581115722656
# ---------------------------------------
# NF_1, d: 100, Iter: 1-740, s/iter: 9.109e-02, ELBO: -1.572e+06
# Cur diff delta = 106.42298889160156
# Cur diff sigma = 62.25172424316406
# Cur diff theta = 168.67471313476562
# ---------------------------------------
# NF_1, d: 100, Iter: 1-760, s/iter: 9.476e-02, ELBO: -1.576e+06
# Cur diff delta = 106.34871673583984
# Cur diff sigma = 62.294742584228516
# Cur diff theta = 168.64345932006836
# ---------------------------------------
# NF_1, d: 100, Iter: 1-780, s/iter: 9.902e-02, ELBO: -1.573e+06
# Cur diff delta = 106.20895385742188
# Cur diff sigma = 62.18857192993164
# Cur diff theta = 168.39752578735352
# ---------------------------------------
# NF_1, d: 100, Iter: 1-800, s/iter: 9.280e-02, ELBO: -1.573e+06
# Cur diff delta = 106.34273529052734
# Cur diff sigma = 62.45637893676758
# Cur diff theta = 168.79911422729492
# ---------------------------------------
# NF_1, d: 100, Iter: 1-820, s/iter: 1.042e-01, ELBO: -1.574e+06
# Cur diff delta = 105.99656677246094
# Cur diff sigma = 62.326698303222656
# Cur diff theta = 168.3232650756836
# ---------------------------------------
# NF_1, d: 100, Iter: 1-840, s/iter: 9.305e-02, ELBO: -1.574e+06
# Cur diff delta = 106.54094696044922
# Cur diff sigma = 62.42448806762695
# Cur diff theta = 168.96543502807617
# ---------------------------------------
# NF_1, d: 100, Iter: 1-860, s/iter: 9.511e-02, ELBO: -1.565e+06
# Cur diff delta = 106.80330657958984
# Cur diff sigma = 61.85176086425781
# Cur diff theta = 168.65506744384766
# ---------------------------------------
# NF_1, d: 100, Iter: 1-880, s/iter: 9.437e-02, ELBO: -1.574e+06
# Cur diff delta = 106.6065673828125
# Cur diff sigma = 62.499446868896484
# Cur diff theta = 169.10601425170898
# ---------------------------------------
# NF_1, d: 100, Iter: 1-900, s/iter: 1.005e-01, ELBO: -1.575e+06
# Cur diff delta = 106.90644073486328
# Cur diff sigma = 62.47971725463867
# Cur diff theta = 169.38615798950195
# ---------------------------------------
# NF_1, d: 100, Iter: 1-920, s/iter: 9.882e-02, ELBO: -1.574e+06
# Cur diff delta = 106.4293212890625
# Cur diff sigma = 62.27029037475586
# Cur diff theta = 168.69961166381836
# ---------------------------------------
# NF_1, d: 100, Iter: 1-940, s/iter: 9.669e-02, ELBO: -1.573e+06
# Cur diff delta = 106.47954559326172
# Cur diff sigma = 62.12467575073242
# Cur diff theta = 168.60422134399414
# ---------------------------------------
# NF_1, d: 100, Iter: 1-960, s/iter: 9.827e-02, ELBO: -1.572e+06
# Cur diff delta = 106.4793930053711
# Cur diff sigma = 62.24878692626953
# Cur diff theta = 168.72817993164062
# ---------------------------------------
# NF_1, d: 100, Iter: 1-980, s/iter: 1.013e-01, ELBO: -1.574e+06
# Cur diff delta = 106.28622436523438
# Cur diff sigma = 62.46867370605469
# Cur diff theta = 168.75489807128906
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1000, s/iter: 1.042e-01, ELBO: -1.572e+06
# Cur diff delta = 106.3848648071289
# Cur diff sigma = 62.29270935058594
# Cur diff theta = 168.67757415771484
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1020, s/iter: 9.415e-02, ELBO: -1.569e+06
# Cur diff delta = 106.5981216430664
# Cur diff sigma = 62.13870620727539
# Cur diff theta = 168.7368278503418
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1040, s/iter: 1.120e-01, ELBO: -1.574e+06
# Cur diff delta = 106.6480941772461
# Cur diff sigma = 62.20148849487305
# Cur diff theta = 168.84958267211914
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1060, s/iter: 9.743e-02, ELBO: -1.571e+06
# Cur diff delta = 106.4367904663086
# Cur diff sigma = 62.03814697265625
# Cur diff theta = 168.47493743896484
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1080, s/iter: 1.049e-01, ELBO: -1.573e+06
# Cur diff delta = 106.41887664794922
# Cur diff sigma = 62.21641159057617
# Cur diff theta = 168.6352882385254
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1100, s/iter: 1.062e-01, ELBO: -1.567e+06
# Cur diff delta = 106.29725646972656
# Cur diff sigma = 62.113399505615234
# Cur diff theta = 168.4106559753418
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1120, s/iter: 9.709e-02, ELBO: -1.570e+06
# Cur diff delta = 106.45836639404297
# Cur diff sigma = 62.21916961669922
# Cur diff theta = 168.6775360107422
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1140, s/iter: 9.698e-02, ELBO: -1.566e+06
# Cur diff delta = 106.67693328857422
# Cur diff sigma = 62.037086486816406
# Cur diff theta = 168.71401977539062
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1160, s/iter: 9.565e-02, ELBO: -1.568e+06
# Cur diff delta = 106.44891357421875
# Cur diff sigma = 62.19816970825195
# Cur diff theta = 168.6470832824707
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1180, s/iter: 1.040e-01, ELBO: -1.572e+06
# Cur diff delta = 106.3481674194336
# Cur diff sigma = 62.35787582397461
# Cur diff theta = 168.7060432434082
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1200, s/iter: 1.086e-01, ELBO: -1.573e+06
# Cur diff delta = 106.04344177246094
# Cur diff sigma = 62.316768646240234
# Cur diff theta = 168.36021041870117
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1220, s/iter: 9.779e-02, ELBO: -1.569e+06
# Cur diff delta = 106.5385513305664
# Cur diff sigma = 62.17397689819336
# Cur diff theta = 168.71252822875977
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1240, s/iter: 9.947e-02, ELBO: -1.571e+06
# Cur diff delta = 106.65232849121094
# Cur diff sigma = 62.25749588012695
# Cur diff theta = 168.9098243713379
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1260, s/iter: 1.004e-01, ELBO: -1.566e+06
# Cur diff delta = 106.14305114746094
# Cur diff sigma = 62.13233184814453
# Cur diff theta = 168.27538299560547
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1280, s/iter: 1.053e-01, ELBO: -1.567e+06
# Cur diff delta = 106.46768951416016
# Cur diff sigma = 62.02886199951172
# Cur diff theta = 168.49655151367188
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1300, s/iter: 1.028e-01, ELBO: -1.571e+06
# Cur diff delta = 106.58484649658203
# Cur diff sigma = 62.28487777709961
# Cur diff theta = 168.86972427368164
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1320, s/iter: 9.643e-02, ELBO: -1.574e+06
# Cur diff delta = 106.68626403808594
# Cur diff sigma = 62.539432525634766
# Cur diff theta = 169.2256965637207
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1340, s/iter: 9.921e-02, ELBO: -1.571e+06
# Cur diff delta = 106.54412078857422
# Cur diff sigma = 62.08372497558594
# Cur diff theta = 168.62784576416016
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1360, s/iter: 9.615e-02, ELBO: -1.566e+06
# Cur diff delta = 106.44962310791016
# Cur diff sigma = 62.08430480957031
# Cur diff theta = 168.53392791748047
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1380, s/iter: 1.003e-01, ELBO: -1.570e+06
# Cur diff delta = 106.93314361572266
# Cur diff sigma = 62.21898651123047
# Cur diff theta = 169.15213012695312
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1400, s/iter: 1.056e-01, ELBO: -1.573e+06
# Cur diff delta = 106.44212341308594
# Cur diff sigma = 62.48945236206055
# Cur diff theta = 168.93157577514648
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1420, s/iter: 1.099e-01, ELBO: -1.570e+06
# Cur diff delta = 106.64678955078125
# Cur diff sigma = 62.08053970336914
# Cur diff theta = 168.7273292541504
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1440, s/iter: 1.080e-01, ELBO: -1.570e+06
# Cur diff delta = 106.44904327392578
# Cur diff sigma = 62.516475677490234
# Cur diff theta = 168.96551895141602
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1460, s/iter: 9.918e-02, ELBO: -1.572e+06
# Cur diff delta = 106.34616088867188
# Cur diff sigma = 62.3027458190918
# Cur diff theta = 168.64890670776367
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1480, s/iter: 9.797e-02, ELBO: -1.568e+06
# Cur diff delta = 106.27220153808594
# Cur diff sigma = 62.02772521972656
# Cur diff theta = 168.2999267578125
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1500, s/iter: 1.037e-01, ELBO: -1.570e+06
# Cur diff delta = 106.46852111816406
# Cur diff sigma = 62.28417205810547
# Cur diff theta = 168.75269317626953
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1520, s/iter: 9.643e-02, ELBO: -1.571e+06
# Cur diff delta = 106.26213836669922
# Cur diff sigma = 62.2030029296875
# Cur diff theta = 168.46514129638672
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1540, s/iter: 1.012e-01, ELBO: -1.573e+06
# Cur diff delta = 106.28237915039062
# Cur diff sigma = 62.35222244262695
# Cur diff theta = 168.63460159301758
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1560, s/iter: 1.109e-01, ELBO: -1.574e+06
# Cur diff delta = 106.48890686035156
# Cur diff sigma = 62.25175857543945
# Cur diff theta = 168.74066543579102
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1580, s/iter: 1.122e-01, ELBO: -1.573e+06
# Cur diff delta = 106.32460021972656
# Cur diff sigma = 62.12432861328125
# Cur diff theta = 168.4489288330078
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1600, s/iter: 9.624e-02, ELBO: -1.573e+06
# Cur diff delta = 106.5460433959961
# Cur diff sigma = 62.51882553100586
# Cur diff theta = 169.06486892700195
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1620, s/iter: 1.002e-01, ELBO: -1.571e+06
# Cur diff delta = 106.53267669677734
# Cur diff sigma = 62.563926696777344
# Cur diff theta = 169.0966033935547
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1640, s/iter: 9.696e-02, ELBO: -1.572e+06
# Cur diff delta = 106.66522216796875
# Cur diff sigma = 62.289146423339844
# Cur diff theta = 168.9543685913086
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1660, s/iter: 9.669e-02, ELBO: -1.575e+06
# Cur diff delta = 106.72907257080078
# Cur diff sigma = 62.394630432128906
# Cur diff theta = 169.1237030029297
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1680, s/iter: 9.620e-02, ELBO: -1.571e+06
# Cur diff delta = 106.25948333740234
# Cur diff sigma = 62.40997314453125
# Cur diff theta = 168.6694564819336
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1700, s/iter: 1.060e-01, ELBO: -1.570e+06
# Cur diff delta = 106.26853942871094
# Cur diff sigma = 61.9332275390625
# Cur diff theta = 168.20176696777344
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1720, s/iter: 1.004e-01, ELBO: -1.571e+06
# Cur diff delta = 106.31440734863281
# Cur diff sigma = 62.11109924316406
# Cur diff theta = 168.42550659179688
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1740, s/iter: 9.667e-02, ELBO: -1.571e+06
# Cur diff delta = 106.44415283203125
# Cur diff sigma = 62.25104522705078
# Cur diff theta = 168.69519805908203
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1760, s/iter: 9.713e-02, ELBO: -1.571e+06
# Cur diff delta = 106.84886932373047
# Cur diff sigma = 62.27000045776367
# Cur diff theta = 169.11886978149414
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1780, s/iter: 9.841e-02, ELBO: -1.573e+06
# Cur diff delta = 106.37993621826172
# Cur diff sigma = 62.213783264160156
# Cur diff theta = 168.59371948242188
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1800, s/iter: 9.884e-02, ELBO: -1.568e+06
# Cur diff delta = 106.86164093017578
# Cur diff sigma = 62.12952423095703
# Cur diff theta = 168.9911651611328
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1820, s/iter: 1.037e-01, ELBO: -1.568e+06
# Cur diff delta = 106.4425277709961
# Cur diff sigma = 62.1459846496582
# Cur diff theta = 168.5885124206543
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1840, s/iter: 1.047e-01, ELBO: -1.576e+06
# Cur diff delta = 106.5277328491211
# Cur diff sigma = 62.35417556762695
# Cur diff theta = 168.88190841674805
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1860, s/iter: 9.841e-02, ELBO: -1.571e+06
# Cur diff delta = 106.2894515991211
# Cur diff sigma = 62.40230178833008
# Cur diff theta = 168.69175338745117
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1880, s/iter: 1.123e-01, ELBO: -1.568e+06
# Cur diff delta = 106.3528823852539
# Cur diff sigma = 62.44283676147461
# Cur diff theta = 168.79571914672852
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1900, s/iter: 1.050e-01, ELBO: -1.571e+06
# Cur diff delta = 106.63961029052734
# Cur diff sigma = 62.32160186767578
# Cur diff theta = 168.96121215820312
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1920, s/iter: 9.890e-02, ELBO: -1.570e+06
# Cur diff delta = 106.47016906738281
# Cur diff sigma = 62.31815719604492
# Cur diff theta = 168.78832626342773
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1940, s/iter: 1.045e-01, ELBO: -1.576e+06
# Cur diff delta = 106.66019439697266
# Cur diff sigma = 62.45954895019531
# Cur diff theta = 169.11974334716797
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1960, s/iter: 1.040e-01, ELBO: -1.569e+06
# Cur diff delta = 106.5378646850586
# Cur diff sigma = 62.33583068847656
# Cur diff theta = 168.87369537353516
# ---------------------------------------
# NF_1, d: 100, Iter: 1-1980, s/iter: 1.059e-01, ELBO: -1.570e+06
# Cur diff delta = 106.4914321899414
# Cur diff sigma = 62.192481994628906
# Cur diff theta = 168.6839141845703
# ---------------------------------------
# NF_1, d: 100, Iter: 1-2000, s/iter: 1.015e-01, ELBO: -1.572e+06
# Cur diff delta = 106.20252990722656
# Cur diff sigma = 62.425437927246094
# Cur diff theta = 168.62796783447266
# ---------------------------------------
# ------------------------------------------------------
# Test = 1
# ------------------------------------------------------
# Init diff delta = 3333.0
# Init diff sigma = 38735.67578125
# Init diff theta = 42068.67578125
# NF_1, d: 100, Iter: 2-20, s/iter: 9.938e-02, ELBO: -3.519e+06
# Cur diff delta = 2746.961181640625
# Cur diff sigma = 12209.166015625
# Cur diff theta = 14956.127197265625
# ---------------------------------------
# NF_1, d: 100, Iter: 2-40, s/iter: 9.703e-02, ELBO: -3.268e+06
# Cur diff delta = 2477.927490234375
# Cur diff sigma = 6173.3525390625
# Cur diff theta = 8651.280029296875
# ---------------------------------------
# NF_1, d: 100, Iter: 2-60, s/iter: 9.792e-02, ELBO: -2.950e+06
# Cur diff delta = 2119.030029296875
# Cur diff sigma = 3259.9921875
# Cur diff theta = 5379.022216796875
# ---------------------------------------
# NF_1, d: 100, Iter: 2-80, s/iter: 1.137e-01, ELBO: -2.680e+06
# Cur diff delta = 1766.5897216796875
# Cur diff sigma = 2333.330810546875
# Cur diff theta = 4099.9205322265625
# ---------------------------------------
# NF_1, d: 100, Iter: 2-100, s/iter: 9.800e-02, ELBO: -2.452e+06
# Cur diff delta = 1433.1470947265625
# Cur diff sigma = 1824.7982177734375
# Cur diff theta = 3257.9453125
# ---------------------------------------
# NF_1, d: 100, Iter: 2-120, s/iter: 1.008e-01, ELBO: -2.290e+06
# Cur diff delta = 1113.0994873046875
# Cur diff sigma = 1373.5635986328125
# Cur diff theta = 2486.6630859375
# ---------------------------------------
# NF_1, d: 100, Iter: 2-140, s/iter: 9.890e-02, ELBO: -2.128e+06
# Cur diff delta = 795.9573364257812
# Cur diff sigma = 906.7389526367188
# Cur diff theta = 1702.6962890625
# ---------------------------------------
# NF_1, d: 100, Iter: 2-160, s/iter: 1.095e-01, ELBO: -1.994e+06
# Cur diff delta = 554.3878784179688
# Cur diff sigma = 566.5460205078125
# Cur diff theta = 1120.9338989257812
# ---------------------------------------
# NF_1, d: 100, Iter: 2-180, s/iter: 1.038e-01, ELBO: -1.895e+06
# Cur diff delta = 383.3726806640625
# Cur diff sigma = 365.85504150390625
# Cur diff theta = 749.2277221679688
# ---------------------------------------
# NF_1, d: 100, Iter: 2-200, s/iter: 1.015e-01, ELBO: -1.810e+06
# Cur diff delta = 263.7076416015625
# Cur diff sigma = 243.36404418945312
# Cur diff theta = 507.0716857910156
# ---------------------------------------
# NF_1, d: 100, Iter: 2-220, s/iter: 1.211e-01, ELBO: -1.740e+06
# Cur diff delta = 183.1071319580078
# Cur diff sigma = 167.4920196533203
# Cur diff theta = 350.5991516113281
# ---------------------------------------
# NF_1, d: 100, Iter: 2-240, s/iter: 1.033e-01, ELBO: -1.691e+06
# Cur diff delta = 131.6385955810547
# Cur diff sigma = 120.61786651611328
# Cur diff theta = 252.25646209716797
# ---------------------------------------
# NF_1, d: 100, Iter: 2-260, s/iter: 9.884e-02, ELBO: -1.651e+06
# Cur diff delta = 102.20764923095703
# Cur diff sigma = 92.65504455566406
# Cur diff theta = 194.8626937866211
# ---------------------------------------
# NF_1, d: 100, Iter: 2-280, s/iter: 1.014e-01, ELBO: -1.628e+06
# Cur diff delta = 88.39252471923828
# Cur diff sigma = 77.43954467773438
# Cur diff theta = 165.83206939697266
# ---------------------------------------
# NF_1, d: 100, Iter: 2-300, s/iter: 9.748e-02, ELBO: -1.608e+06
# Cur diff delta = 84.12034606933594
# Cur diff sigma = 69.5069351196289
# Cur diff theta = 153.62728118896484
# ---------------------------------------
# NF_1, d: 100, Iter: 2-320, s/iter: 1.075e-01, ELBO: -1.593e+06
# Cur diff delta = 84.24052429199219
# Cur diff sigma = 65.75772094726562
# Cur diff theta = 149.9982452392578
# ---------------------------------------
# NF_1, d: 100, Iter: 2-340, s/iter: 1.126e-01, ELBO: -1.593e+06
# Cur diff delta = 86.48712921142578
# Cur diff sigma = 64.08889770507812
# Cur diff theta = 150.5760269165039
# ---------------------------------------
# NF_1, d: 100, Iter: 2-360, s/iter: 1.005e-01, ELBO: -1.583e+06
# Cur diff delta = 87.9382553100586
# Cur diff sigma = 62.74296569824219
# Cur diff theta = 150.68122100830078
# ---------------------------------------
# NF_1, d: 100, Iter: 2-380, s/iter: 9.885e-02, ELBO: -1.586e+06
# Cur diff delta = 87.95527648925781
# Cur diff sigma = 62.88648986816406
# Cur diff theta = 150.84176635742188
# ---------------------------------------
# NF_1, d: 100, Iter: 2-400, s/iter: 9.987e-02, ELBO: -1.589e+06
# Cur diff delta = 88.2855453491211
# Cur diff sigma = 63.15095520019531
# Cur diff theta = 151.4365005493164
# ---------------------------------------
# NF_1, d: 100, Iter: 2-420, s/iter: 1.001e-01, ELBO: -1.586e+06
# Cur diff delta = 88.1141128540039
# Cur diff sigma = 62.960838317871094
# Cur diff theta = 151.074951171875
# ---------------------------------------
# NF_1, d: 100, Iter: 2-440, s/iter: 1.108e-01, ELBO: -1.582e+06
# Cur diff delta = 88.19908142089844
# Cur diff sigma = 62.75315475463867
# Cur diff theta = 150.9522361755371
# ---------------------------------------
# NF_1, d: 100, Iter: 2-460, s/iter: 1.008e-01, ELBO: -1.588e+06
# Cur diff delta = 88.4088134765625
# Cur diff sigma = 62.75786590576172
# Cur diff theta = 151.16667938232422
# ---------------------------------------
# NF_1, d: 100, Iter: 2-480, s/iter: 1.049e-01, ELBO: -1.579e+06
# Cur diff delta = 88.1825942993164
# Cur diff sigma = 63.02036666870117
# Cur diff theta = 151.20296096801758
# ---------------------------------------
# NF_1, d: 100, Iter: 2-500, s/iter: 9.976e-02, ELBO: -1.581e+06
# Cur diff delta = 88.29727935791016
# Cur diff sigma = 62.89640808105469
# Cur diff theta = 151.19368743896484
# ---------------------------------------
# NF_1, d: 100, Iter: 2-520, s/iter: 9.903e-02, ELBO: -1.579e+06
# Cur diff delta = 88.25050354003906
# Cur diff sigma = 62.52622604370117
# Cur diff theta = 150.77672958374023
# ---------------------------------------
# NF_1, d: 100, Iter: 2-540, s/iter: 1.031e-01, ELBO: -1.579e+06
# Cur diff delta = 88.08715057373047
# Cur diff sigma = 62.48968505859375
# Cur diff theta = 150.57683563232422
# ---------------------------------------
# NF_1, d: 100, Iter: 2-560, s/iter: 1.108e-01, ELBO: -1.576e+06
# Cur diff delta = 88.13789367675781
# Cur diff sigma = 62.6801872253418
# Cur diff theta = 150.8180809020996
# ---------------------------------------
# NF_1, d: 100, Iter: 2-580, s/iter: 1.184e-01, ELBO: -1.577e+06
# Cur diff delta = 88.1390151977539
# Cur diff sigma = 62.40508270263672
# Cur diff theta = 150.54409790039062
# ---------------------------------------
# NF_1, d: 100, Iter: 2-600, s/iter: 9.791e-02, ELBO: -1.577e+06
# Cur diff delta = 88.20403289794922
# Cur diff sigma = 62.63932418823242
# Cur diff theta = 150.84335708618164
# ---------------------------------------
# NF_1, d: 100, Iter: 2-620, s/iter: 1.072e-01, ELBO: -1.578e+06
# Cur diff delta = 88.59000396728516
# Cur diff sigma = 62.61128616333008
# Cur diff theta = 151.20129013061523
# ---------------------------------------
# NF_1, d: 100, Iter: 2-640, s/iter: 9.942e-02, ELBO: -1.575e+06
# Cur diff delta = 87.95803833007812
# Cur diff sigma = 62.494998931884766
# Cur diff theta = 150.4530372619629
# ---------------------------------------
# NF_1, d: 100, Iter: 2-660, s/iter: 9.726e-02, ELBO: -1.574e+06
# Cur diff delta = 88.26575469970703
# Cur diff sigma = 62.29535675048828
# Cur diff theta = 150.5611114501953
# ---------------------------------------
# NF_1, d: 100, Iter: 2-680, s/iter: 1.062e-01, ELBO: -1.579e+06
# Cur diff delta = 88.09374237060547
# Cur diff sigma = 62.423072814941406
# Cur diff theta = 150.51681518554688
# ---------------------------------------
# NF_1, d: 100, Iter: 2-700, s/iter: 9.567e-02, ELBO: -1.580e+06
# Cur diff delta = 88.14958190917969
# Cur diff sigma = 62.52196502685547
# Cur diff theta = 150.67154693603516
# ---------------------------------------
# NF_1, d: 100, Iter: 2-720, s/iter: 9.829e-02, ELBO: -1.567e+06
# Cur diff delta = 88.02815246582031
# Cur diff sigma = 62.282955169677734
# Cur diff theta = 150.31110763549805
# ---------------------------------------
# NF_1, d: 100, Iter: 2-740, s/iter: 9.829e-02, ELBO: -1.582e+06
# Cur diff delta = 88.24176025390625
# Cur diff sigma = 62.617164611816406
# Cur diff theta = 150.85892486572266
# ---------------------------------------
# NF_1, d: 100, Iter: 2-760, s/iter: 9.879e-02, ELBO: -1.575e+06
# Cur diff delta = 88.05980682373047
# Cur diff sigma = 62.583106994628906
# Cur diff theta = 150.64291381835938
# ---------------------------------------
# NF_1, d: 100, Iter: 2-780, s/iter: 9.765e-02, ELBO: -1.578e+06
# Cur diff delta = 88.3272705078125
# Cur diff sigma = 62.399898529052734
# Cur diff theta = 150.72716903686523
# ---------------------------------------
# NF_1, d: 100, Iter: 2-800, s/iter: 9.735e-02, ELBO: -1.571e+06
# Cur diff delta = 87.95286560058594
# Cur diff sigma = 62.36548614501953
# Cur diff theta = 150.31835174560547
# ---------------------------------------
# NF_1, d: 100, Iter: 2-820, s/iter: 9.944e-02, ELBO: -1.573e+06
# Cur diff delta = 88.48839569091797
# Cur diff sigma = 62.544864654541016
# Cur diff theta = 151.03326034545898
# ---------------------------------------
# NF_1, d: 100, Iter: 2-840, s/iter: 9.508e-02, ELBO: -1.577e+06
# Cur diff delta = 88.15864562988281
# Cur diff sigma = 62.71137619018555
# Cur diff theta = 150.87002182006836
# ---------------------------------------
# NF_1, d: 100, Iter: 2-860, s/iter: 9.897e-02, ELBO: -1.578e+06
# Cur diff delta = 88.054931640625
# Cur diff sigma = 62.45984649658203
# Cur diff theta = 150.51477813720703
# ---------------------------------------
# NF_1, d: 100, Iter: 2-880, s/iter: 9.749e-02, ELBO: -1.576e+06
# Cur diff delta = 88.3431625366211
# Cur diff sigma = 62.43440246582031
# Cur diff theta = 150.7775650024414
# ---------------------------------------
# NF_1, d: 100, Iter: 2-900, s/iter: 1.044e-01, ELBO: -1.578e+06
# Cur diff delta = 88.22379302978516
# Cur diff sigma = 62.444000244140625
# Cur diff theta = 150.66779327392578
# ---------------------------------------
# NF_1, d: 100, Iter: 2-920, s/iter: 9.807e-02, ELBO: -1.578e+06
# ...
# Cur diff theta = 308.4259669705061
# ---------------------------------------
# VB, d: 100, Iter: 3-780, s/iter: 6.589e-02, ELBO: -2.881e+05
# Cur diff delta = 300.9422302246094
# Cur diff sigma = 0.0014369114069268107
# Cur diff theta = 300.9436671360163
# ---------------------------------------
# VB, d: 100, Iter: 3-800, s/iter: 6.601e-02, ELBO: -2.880e+05
# Cur diff delta = 293.7308044433594
# Cur diff sigma = 0.001436885679140687
# Cur diff theta = 293.7322413290385
# ---------------------------------------
# VB, d: 100, Iter: 3-820, s/iter: 6.790e-02, ELBO: -2.878e+05
# Cur diff delta = 286.77972412109375
# Cur diff sigma = 0.0014368556439876556
# Cur diff theta = 286.78116097673774
# ---------------------------------------
# VB, d: 100, Iter: 3-840, s/iter: 6.625e-02, ELBO: -2.877e+05
# Cur diff delta = 280.0790710449219
# Cur diff sigma = 0.001436786842532456
# Cur diff theta = 280.0805078317644
# ---------------------------------------
# VB, d: 100, Iter: 3-860, s/iter: 7.174e-02, ELBO: -2.876e+05
# Cur diff delta = 273.619384765625
# Cur diff sigma = 0.001436718157492578
# Cur diff theta = 273.6208214837825
# ---------------------------------------
# VB, d: 100, Iter: 3-880, s/iter: 7.046e-02, ELBO: -2.874e+05
# Cur diff delta = 267.3913879394531
# Cur diff sigma = 0.0014366944087669253
# Cur diff theta = 267.3928246338619
# ---------------------------------------
# VB, d: 100, Iter: 3-900, s/iter: 7.273e-02, ELBO: -2.873e+05
# Cur diff delta = 261.3866271972656
# Cur diff sigma = 0.0014366607647389174
# Cur diff theta = 261.38806385803036
# ---------------------------------------
# VB, d: 100, Iter: 3-920, s/iter: 6.581e-02, ELBO: -2.872e+05
# Cur diff delta = 255.59645080566406
# Cur diff sigma = 0.001436635386198759
# Cur diff theta = 255.59788744105026
# ---------------------------------------
# VB, d: 100, Iter: 3-940, s/iter: 6.731e-02, ELBO: -2.871e+05
# Cur diff delta = 250.01263427734375
# Cur diff sigma = 0.001436596387065947
# Cur diff theta = 250.01407087373082
# ---------------------------------------
# VB, d: 100, Iter: 3-960, s/iter: 6.570e-02, ELBO: -2.870e+05
# Cur diff delta = 244.62753295898438
# Cur diff sigma = 0.0014365356182679534
# Cur diff theta = 244.62896949460264
# ---------------------------------------
# VB, d: 100, Iter: 3-980, s/iter: 6.556e-02, ELBO: -2.868e+05
# Cur diff delta = 239.4339141845703
# Cur diff sigma = 0.001436530495993793
# Cur diff theta = 239.4353507150663
# ---------------------------------------
# VB, d: 100, Iter: 3-1000, s/iter: 6.758e-02, ELBO: -2.867e+05
# Cur diff delta = 234.4243621826172
# Cur diff sigma = 0.0014364946400746703
# Cur diff theta = 234.42579867725726
# ---------------------------------------
# VB, d: 100, Iter: 3-1020, s/iter: 6.590e-02, ELBO: -2.866e+05
# Cur diff delta = 229.59202575683594
# Cur diff sigma = 0.0014364736853167415
# Cur diff theta = 229.59346223052125
# ---------------------------------------
# VB, d: 100, Iter: 3-1040, s/iter: 6.557e-02, ELBO: -2.865e+05
# Cur diff delta = 224.93031311035156
# Cur diff sigma = 0.0014364469097927213
# Cur diff theta = 224.93174955726136
# ---------------------------------------
# VB, d: 100, Iter: 3-1060, s/iter: 6.677e-02, ELBO: -2.864e+05
# Cur diff delta = 220.43301391601562
# Cur diff sigma = 0.0014364159433171153
# Cur diff theta = 220.43445033195894
# ---------------------------------------
# VB, d: 100, Iter: 3-1080, s/iter: 6.546e-02, ELBO: -2.863e+05
# Cur diff delta = 216.0938720703125
# Cur diff sigma = 0.001436381135135889
# Cur diff theta = 216.09530845144764
# ---------------------------------------
# VB, d: 100, Iter: 3-1100, s/iter: 6.542e-02, ELBO: -2.862e+05
# Cur diff delta = 211.9072723388672
# Cur diff sigma = 0.0014363573864102364
# Cur diff theta = 211.9087086962536
# ---------------------------------------
# VB, d: 100, Iter: 3-1120, s/iter: 6.534e-02, ELBO: -2.862e+05
# Cur diff delta = 207.86732482910156
# Cur diff sigma = 0.0014363541267812252
# Cur diff theta = 207.86876118322834
# ---------------------------------------
# VB, d: 100, Iter: 3-1140, s/iter: 6.818e-02, ELBO: -2.861e+05
# Cur diff delta = 203.9686737060547
# Cur diff sigma = 0.0014362941728904843
# Cur diff theta = 203.97011000022758
# ---------------------------------------
# VB, d: 100, Iter: 3-1160, s/iter: 7.046e-02, ELBO: -2.860e+05
# Cur diff delta = 200.20632934570312
# Cur diff sigma = 0.001436297781765461
# Cur diff theta = 200.2077656434849
# ---------------------------------------
# VB, d: 100, Iter: 3-1180, s/iter: 6.580e-02, ELBO: -2.859e+05
# Cur diff delta = 196.57498168945312
# Cur diff sigma = 0.0014362848596647382
# Cur diff theta = 196.5764179743128
# ---------------------------------------
# VB, d: 100, Iter: 3-1200, s/iter: 7.903e-02, ELBO: -2.858e+05
# Cur diff delta = 193.070068359375
# Cur diff sigma = 0.001436256687156856
# Cur diff theta = 193.07150461606216
# ---------------------------------------
# VB, d: 100, Iter: 3-1220, s/iter: 6.452e-02, ELBO: -2.858e+05
# Cur diff delta = 189.6870574951172
# Cur diff sigma = 0.0014362415531650186
# Cur diff theta = 189.68849373667035
# ---------------------------------------
# VB, d: 100, Iter: 3-1240, s/iter: 6.501e-02, ELBO: -2.857e+05
# Cur diff delta = 186.42140197753906
# Cur diff sigma = 0.0014362017391249537
# Cur diff theta = 186.4228381792782
# ---------------------------------------
# VB, d: 100, Iter: 3-1260, s/iter: 8.118e-02, ELBO: -2.856e+05
# Cur diff delta = 183.26876831054688
# Cur diff sigma = 0.0014361884677782655
# Cur diff theta = 183.27020449901465
# ---------------------------------------
# VB, d: 100, Iter: 3-1280, s/iter: 6.656e-02, ELBO: -2.855e+05
# Cur diff delta = 180.22503662109375
# Cur diff sigma = 0.0014361654175445437
# Cur diff theta = 180.2264727865113
# ---------------------------------------
# VB, d: 100, Iter: 3-1300, s/iter: 6.916e-02, ELBO: -2.855e+05
# Cur diff delta = 177.28651428222656
# Cur diff sigma = 0.0014361386420205235
# Cur diff theta = 177.28795042086858
# ---------------------------------------
# VB, d: 100, Iter: 3-1320, s/iter: 7.371e-02, ELBO: -2.854e+05
# Cur diff delta = 174.4493408203125
# Cur diff sigma = 0.0014361136127263308
# Cur diff theta = 174.45077693392523
# ---------------------------------------
# VB, d: 100, Iter: 3-1340, s/iter: 6.890e-02, ELBO: -2.854e+05
# Cur diff delta = 171.7095947265625
# Cur diff sigma = 0.0014361207140609622
# Cur diff theta = 171.71103084727656
# ---------------------------------------
# VB, d: 100, Iter: 3-1360, s/iter: 6.846e-02, ELBO: -2.853e+05
# Cur diff delta = 169.0641632080078
# Cur diff sigma = 0.0014361104695126414
# Cur diff theta = 169.06559931847733
# ---------------------------------------
# VB, d: 100, Iter: 3-1380, s/iter: 6.994e-02, ELBO: -2.852e+05
# Cur diff delta = 166.50946044921875
# Cur diff sigma = 0.0014360736822709441
# Cur diff theta = 166.51089652290102
# ---------------------------------------
# VB, d: 100, Iter: 3-1400, s/iter: 7.429e-02, ELBO: -2.852e+05
# Cur diff delta = 164.04232788085938
# Cur diff sigma = 0.0014360734494403005
# Cur diff theta = 164.04376395430882
# ---------------------------------------
# VB, d: 100, Iter: 3-1420, s/iter: 6.525e-02, ELBO: -2.851e+05
# Cur diff delta = 161.65960693359375
# Cur diff sigma = 0.0014360536588355899
# Cur diff theta = 161.66104298725259
# ---------------------------------------
# VB, d: 100, Iter: 3-1440, s/iter: 7.570e-02, ELBO: -2.851e+05
# Cur diff delta = 159.35833740234375
# Cur diff sigma = 0.0014360393397510052
# Cur diff theta = 159.3597734416835
# ---------------------------------------
# VB, d: 100, Iter: 3-1460, s/iter: 6.651e-02, ELBO: -2.850e+05
# Cur diff delta = 157.13543701171875
# Cur diff sigma = 0.0014360185014083982
# Cur diff theta = 157.13687303022016
# ---------------------------------------
# VB, d: 100, Iter: 3-1480, s/iter: 7.202e-02, ELBO: -2.850e+05
# Cur diff delta = 154.98838806152344
# Cur diff sigma = 0.0014360088389366865
# Cur diff theta = 154.98982407036237
# ---------------------------------------
# VB, d: 100, Iter: 3-1500, s/iter: 6.622e-02, ELBO: -2.849e+05
# Cur diff delta = 152.91445922851562
# Cur diff sigma = 0.0014359855558723211
# Cur diff theta = 152.9158952140715
# ---------------------------------------
# VB, d: 100, Iter: 3-1520, s/iter: 6.505e-02, ELBO: -2.849e+05
# Cur diff delta = 150.9109344482422
# Cur diff sigma = 0.001435991027392447
# Cur diff theta = 150.91237043926958
# ---------------------------------------
# VB, d: 100, Iter: 3-1540, s/iter: 6.825e-02, ELBO: -2.848e+05
# Cur diff delta = 148.97557067871094
# Cur diff sigma = 0.0014359838096424937
# Cur diff theta = 148.97700666252058
# ---------------------------------------
# VB, d: 100, Iter: 3-1560, s/iter: 6.624e-02, ELBO: -2.848e+05
# Cur diff delta = 147.10589599609375
# Cur diff sigma = 0.0014359698398038745
# Cur diff theta = 147.10733196593355
# ---------------------------------------
# VB, d: 100, Iter: 3-1580, s/iter: 6.522e-02, ELBO: -2.847e+05
# Cur diff delta = 145.299560546875
# Cur diff sigma = 0.0014359462074935436
# Cur diff theta = 145.3009964930825
# ---------------------------------------
# VB, d: 100, Iter: 3-1600, s/iter: 7.204e-02, ELBO: -2.847e+05
# Cur diff delta = 143.5542755126953
# Cur diff sigma = 0.0014359388733282685
# Cur diff theta = 143.55571145156864
# ---------------------------------------
# VB, d: 100, Iter: 3-1620, s/iter: 6.889e-02, ELBO: -2.847e+05
# Cur diff delta = 141.8682098388672
# Cur diff sigma = 0.0014359274646267295
# Cur diff theta = 141.86964576633181
# ---------------------------------------
# VB, d: 100, Iter: 3-1640, s/iter: 7.583e-02, ELBO: -2.846e+05
# Cur diff delta = 140.2389678955078
# Cur diff sigma = 0.0014359211781993508
# Cur diff theta = 140.240403816686
# ---------------------------------------
# VB, d: 100, Iter: 3-1660, s/iter: 6.700e-02, ELBO: -2.846e+05
# Cur diff delta = 138.66476440429688
# Cur diff sigma = 0.0014359084889292717
# Cur diff theta = 138.6662003127858
# ---------------------------------------
# VB, d: 100, Iter: 3-1680, s/iter: 7.140e-02, ELBO: -2.845e+05
# Cur diff delta = 137.14370727539062
# Cur diff sigma = 0.0014358962653204799
# Cur diff theta = 137.14514317165595
# ---------------------------------------
# VB, d: 100, Iter: 3-1700, s/iter: 6.885e-02, ELBO: -2.845e+05
# Cur diff delta = 135.6740264892578
# Cur diff sigma = 0.0014358926564455032
# Cur diff theta = 135.67546238191426
# ---------------------------------------
# VB, d: 100, Iter: 3-1720, s/iter: 7.538e-02, ELBO: -2.845e+05
# Cur diff delta = 134.2537078857422
# Cur diff sigma = 0.0014358909102156758
# Cur diff theta = 134.2551437766524
# ---------------------------------------
# VB, d: 100, Iter: 3-1740, s/iter: 7.558e-02, ELBO: -2.844e+05
# Cur diff delta = 132.8816375732422
# Cur diff sigma = 0.0014358831103891134
# Cur diff theta = 132.88307345635258
# ---------------------------------------
# VB, d: 100, Iter: 3-1760, s/iter: 7.019e-02, ELBO: -2.844e+05
# Cur diff delta = 131.55523681640625
# Cur diff sigma = 0.001435869256965816
# Cur diff theta = 131.55667268566322
# ---------------------------------------
# VB, d: 100, Iter: 3-1780, s/iter: 6.534e-02, ELBO: -2.844e+05
# Cur diff delta = 130.27366638183594
# Cur diff sigma = 0.0014358506305143237
# Cur diff theta = 130.27510223246645
# ---------------------------------------
# VB, d: 100, Iter: 3-1800, s/iter: 6.691e-02, ELBO: -2.843e+05
# Cur diff delta = 129.0351104736328
# Cur diff sigma = 0.001435851794667542
# Cur diff theta = 129.03654632542748
# ---------------------------------------
# VB, d: 100, Iter: 3-1820, s/iter: 6.779e-02, ELBO: -2.843e+05
# Cur diff delta = 127.8384017944336
# Cur diff sigma = 0.0014358372427523136
# Cur diff theta = 127.83983763167635
# ---------------------------------------
# VB, d: 100, Iter: 3-1840, s/iter: 6.507e-02, ELBO: -2.843e+05
# Cur diff delta = 126.68153381347656
# Cur diff sigma = 0.0014358374755829573
# Cur diff theta = 126.68296965095215
# ---------------------------------------
# VB, d: 100, Iter: 3-1860, s/iter: 7.865e-02, ELBO: -2.843e+05
# Cur diff delta = 125.56363677978516
# Cur diff sigma = 0.0014358339831233025
# Cur diff theta = 125.56507261376828
# ---------------------------------------
# VB, d: 100, Iter: 3-1880, s/iter: 6.550e-02, ELBO: -2.842e+05
# Cur diff delta = 124.48355102539062
# Cur diff sigma = 0.0014358138432726264
# Cur diff theta = 124.4849868392339
# ---------------------------------------
# VB, d: 100, Iter: 3-1900, s/iter: 6.519e-02, ELBO: -2.842e+05
# Cur diff delta = 123.43940734863281
# Cur diff sigma = 0.0014358110493049026
# Cur diff theta = 123.44084315968212
# ---------------------------------------
# VB, d: 100, Iter: 3-1920, s/iter: 7.128e-02, ELBO: -2.842e+05
# Cur diff delta = 122.43043518066406
# Cur diff sigma = 0.0014358086045831442
# Cur diff theta = 122.43187098926865
# ---------------------------------------
# VB, d: 100, Iter: 3-1940, s/iter: 6.620e-02, ELBO: -2.842e+05
# Cur diff delta = 121.45552062988281
# Cur diff sigma = 0.0014358102343976498
# Cur diff theta = 121.45695644011721
# ---------------------------------------
# VB, d: 100, Iter: 3-1960, s/iter: 7.707e-02, ELBO: -2.841e+05
# Cur diff delta = 120.5130844116211
# Cur diff sigma = 0.0014357876498252153
# Cur diff theta = 120.51452019927092
# ---------------------------------------
# VB, d: 100, Iter: 3-1980, s/iter: 7.219e-02, ELBO: -2.841e+05
# Cur diff delta = 119.6024169921875
# Cur diff sigma = 0.001435785205103457
# Cur diff theta = 119.6038527773926
# ---------------------------------------
# VB, d: 100, Iter: 3-2000, s/iter: 6.895e-02, ELBO: -2.841e+05
# Cur diff delta = 118.72222900390625
# Cur diff sigma = 0.0014357821783050895
# Cur diff theta = 118.72366478608456
# ---------------------------------------
# Model HVAE_1, test = 0, result delta diff = 106.708251953125
# Model HVAE_1, test = 0, result sigma diff = 0.16567815840244293
# Model HVAE_1, test = 0, result theta diff = 106.87393188476562
# Model HVAE_1, test = 1, result delta diff = 87.75175476074219
# Model HVAE_1, test = 1, result sigma diff = 0.16832561790943146
# Model HVAE_1, test = 1, result theta diff = 87.92008209228516
# Model HVAE_1, test = 2, result delta diff = 109.03657531738281
# Model HVAE_1, test = 2, result sigma diff = 0.16612447798252106
# Model HVAE_1, test = 2, result theta diff = 109.20269775390625
# Model HVAE_2, test = 0, result delta diff = 106.50257110595703
# Model HVAE_2, test = 0, result sigma diff = 0.15408127009868622
# Model HVAE_2, test = 0, result theta diff = 106.65665435791016
# Model HVAE_2, test = 1, result delta diff = 88.02531433105469
# Model HVAE_2, test = 1, result sigma diff = 0.15510234236717224
# Model HVAE_2, test = 1, result theta diff = 88.180419921875
# Model HVAE_2, test = 2, result delta diff = 109.26580810546875
# Model HVAE_2, test = 2, result sigma diff = 0.15267324447631836
# Model HVAE_2, test = 2, result theta diff = 109.4184799194336
# Model NF_1, test = 0, result delta diff = 106.20252990722656
# Model NF_1, test = 0, result sigma diff = 62.42543411254883
# Model NF_1, test = 0, result theta diff = 168.62796020507812
# Model NF_1, test = 1, result delta diff = 88.09043884277344
# Model NF_1, test = 1, result sigma diff = 62.33919143676758
# Model NF_1, test = 1, result theta diff = 150.42962646484375
# Model NF_1, test = 2, result delta diff = 109.10942840576172
# Model NF_1, test = 2, result sigma diff = 62.374481201171875
# Model NF_1, test = 2, result theta diff = 171.48391723632812
# Model NF_2, test = 0, result delta diff = 106.1917724609375
# Model NF_2, test = 0, result sigma diff = 61.95193099975586
# Model NF_2, test = 0, result theta diff = 168.14370727539062
# Model NF_2, test = 1, result delta diff = 88.07634735107422
# Model NF_2, test = 1, result sigma diff = 62.342105865478516
# Model NF_2, test = 1, result theta diff = 150.41845703125
# Model NF_2, test = 2, result delta diff = 109.25711059570312
# Model NF_2, test = 2, result sigma diff = 61.911781311035156
# Model NF_2, test = 2, result theta diff = 171.16888427734375
# Model VB, test = 0, result delta diff = 116.38240051269531
# Model VB, test = 0, result sigma diff = 0.0015591643750667572
# Model VB, test = 0, result theta diff = 116.38395690917969
# Model VB, test = 1, result delta diff = 101.70657348632812
# Model VB, test = 1, result sigma diff = 0.001508941175416112
# Model VB, test = 1, result theta diff = 101.70808410644531
# Model VB, test = 2, result delta diff = 118.72222137451172
# Model VB, test = 2, result sigma diff = 0.0014357821783050895
# Model VB, test = 2, result theta diff = 118.7236557006836

# %%
model_names = ['HVAE_1', 'HVAE_2', 'NF_1', 'NF_2', 'VB']
diff_delta_results = {}
diff_sigma_results = {}
diff_results = {}
for name in model_names:
    diff_delta_tests = np.zeros(params['n_tests'])
    diff_sigma_tests = np.zeros(params['n_tests'])
    diff_tests = np.zeros(params['n_tests'])
    for i in range(params['n_tests']):
        file_name = name + '_train_' + str(i) + '.p'
        diff_path = os.path.join('save', str(params['dims'][0]), file_name)
        with open(diff_path, 'rb') as f:
            data = pickle.load(f)
            elbo = data['elbo']
            diff_delta = data['diff_delta']
            diff_sigma = data['diff_sigma']
            diff = diff_delta + diff_sigma
            diff_delta_is_not_nan = diff_delta[~np.isnan(diff_delta)]
            diff_sigma_is_not_nan = diff_sigma[~np.isnan(diff_sigma)]
            diff_is_not_nan = diff[~np.isnan(diff)]
            diff_delta_tests[i] = diff_delta_is_not_nan[-1]
            diff_sigma_tests[i] = diff_sigma_is_not_nan[-1]
            diff_tests[i] = diff_is_not_nan[-1]
    diff_delta_results[name] = diff_delta_tests
    diff_sigma_results[name] = diff_sigma_tests
    diff_results[name] = diff_tests
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, diff delta = {diff_delta_tests}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, diff sigma = {diff_sigma_tests}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, diff = {diff_tests}")
# Out:
# Model = HVAE_1, dimensionality = 100, diff delta = [106.70824432  87.75175476 109.03658295]
# Model = HVAE_1, dimensionality = 100, diff sigma = [0.16567816 0.16832563 0.16612449]
# Model = HVAE_1, dimensionality = 100, diff = [106.87392426  87.92008209 109.20270538]
# Model = HVAE_2, dimensionality = 100, diff delta = [106.50257111  88.02532196 109.26582336]
# Model = HVAE_2, dimensionality = 100, diff sigma = [0.15408127 0.15510234 0.15267326]
# Model = HVAE_2, dimensionality = 100, diff = [106.65665436  88.18042755 109.41849518]
# Model = NF_1, dimensionality = 100, diff delta = [106.20252991  88.09043121 109.10942078]
# Model = NF_1, dimensionality = 100, diff sigma = [62.42543793 62.33919144 62.3744812 ]
# Model = NF_1, dimensionality = 100, diff = [168.62796021 150.42962646 171.48390198]
# Model = NF_2, dimensionality = 100, diff delta = [106.19176483  88.07633972 109.2571106 ]
# Model = NF_2, dimensionality = 100, diff sigma = [61.95193481 62.34210587 61.9117775 ]
# Model = NF_2, dimensionality = 100, diff = [168.14370728 150.41844177 171.16888428]
# Model = VB, dimensionality = 100, diff delta = [116.38240814 101.70657349 118.722229  ]
# Model = VB, dimensionality = 100, diff sigma = [0.00155916 0.00150894 0.00143578]
# Model = VB, dimensionality = 100, diff = [116.38396454 101.70808411 118.72366333]

# %%
for name in model_names:
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, mean diff delta = {diff_delta_results[name].mean()}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, mean diff sigma = {diff_sigma_results[name].mean()}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, mean diff = {diff_results[name].mean()}")
# Out:
# Model = HVAE_1, dimensionality = 100, mean diff delta = 101.16552734375
# Model = HVAE_1, dimensionality = 100, mean diff sigma = 0.1667094280322393
# Model = HVAE_1, dimensionality = 100, mean diff = 101.33223724365234
# Model = HVAE_2, dimensionality = 100, mean diff delta = 101.26457214355469
# Model = HVAE_2, dimensionality = 100, mean diff sigma = 0.153952290614446
# Model = HVAE_2, dimensionality = 100, mean diff = 101.41852569580078
# Model = NF_1, dimensionality = 100, mean diff delta = 101.13412729899089
# Model = NF_1, dimensionality = 100, mean diff sigma = 62.379703521728516
# Model = NF_1, dimensionality = 100, mean diff = 163.51382954915366
# Model = NF_2, dimensionality = 100, mean diff delta = 101.1750717163086
# Model = NF_2, dimensionality = 100, mean diff sigma = 62.06860605875651
# Model = NF_2, dimensionality = 100, mean diff = 163.2436777750651
# Model = VB, dimensionality = 100, mean diff delta = 112.27040354410808
# Model = VB, dimensionality = 100, mean diff sigma = 0.0015012959095959861
# Model = VB, dimensionality = 100, mean diff = 112.27190399169922

# %%
def run_test(d, params, 
             batch_size=256,
             clip_value=None,
             dtype=torch.float32, 
             device=torch.device("cpu")):
    """ 
    Run the gaussian test with dimension d 
    """

    ######### Problem Specification

    # Data generation parameters
    prior_mu_z = torch.zeros(d, dtype=dtype)    # Prior mean
    prior_sigma_z = torch.eye(d, dtype=dtype)   # Prior covariance matrix

    # True model parameters
    num_range = torch.arange(-(d-1)/2, (d+1)/2, dtype=dtype)

    t_delta =  num_range / 5 

    print(f"true delta = {t_delta.numpy()}")

    if d == 1:
        t_sigma = torch.ones(1, dtype=dtype)
    else: 
        # Allow sigma to range from 0.1 to 1
        t_sigma = 36/(10*(d-1)**2) * num_range**2 + 0.1 
    print(f"true sigma = {t_sigma.numpy()}")

    ######### Variable Initialization

    # Initial model parameters - same across all methods
    init_delta = prior_mu_z.clone().to(device)
    init_log_sigma = 3 * torch.ones(d).to(device)

    # Initial HVAE variational parameters
    init_T = torch.tensor(5., dtype=dtype, device=device)
    init_eps = 0.005 * torch.ones(d, dtype=dtype)
    max_eps = params['max_eps'] * torch.ones(d, dtype=dtype)
    init_logit_eps = torch.log(init_eps/(max_eps - init_eps)).to(device)
    init_log_T_0 = torch.log(init_T - 1)

    # Initial NF variational parameters
    init_u_pre_reparam = torch.tensor(scipy.stats.truncnorm.rvs(-2, 2, 
                                                                scale=0.1, 
                                                                size=d),
                                      dtype=dtype, device=device)
    init_w = torch.tensor(scipy.stats.truncnorm.rvs(-2, 2, scale=0.1, size=d),
                          dtype=dtype, device=device)
    init_b = torch.tensor(0.1, dtype=dtype, device=device)

    # Initial VAE parameters
    init_mu_z = prior_mu_z.clone()
    init_log_sigma_z = torch.ones(d, dtype=dtype)

    ######### Set up models
    init_params = [[init_delta, init_log_sigma, init_logit_eps, init_log_T_0],
                   [init_delta, init_log_sigma, init_logit_eps, init_log_T_0],
                   [init_delta, init_log_sigma, init_u_pre_reparam, init_w, init_b],
                   [init_delta, init_log_sigma, init_u_pre_reparam, init_w, init_b],
                   [init_delta, init_log_sigma, init_mu_z, init_log_sigma_z]]
    
    VB_model = VB(params,
        ['delta', 'log_sigma', 'mu_z', 'log_sigma_z'], 
        init_params[4], 'VB', d)

    #model_list = [HVAE_model_1, HVAE_model_2, NF_model_1]
    #model_list = [HVAE_model_1, NF_model_1]
    model_list = [VB_model]

    print("Models were initialized!")
    
    ######### Generate Training Data & Save - One for each test

    train_data_list = []

    for i in range(params['n_tests']):
        z = MultivariateNormal(prior_mu_z, prior_sigma_z).sample()
        x = MultivariateNormal(z + t_delta, 
                               torch.diag(t_sigma**2)).sample([params['n_data']])
        x = x.to(device)
        train_data_list.append(x)

    # Folder should have already been created in the initializations
    data_path = os.path.join('save', str(d), 'train_data.p')
    pickle.dump(train_data_list, open(data_path, 'wb')) 

    # Store the final parameter values for all test runs in this dictionary
    final_params = {}

    for i in range(len(model_list)):
        final_values = []
        m = model_list[i]
        model_init_params = init_params[i]

        for j in range(params['n_tests']):
            print("------------------------------------------------------")
            print(f"Test = {j}")
            print("------------------------------------------------------")
            m._reinitialize(model_init_params)
            gaussian_data = gaussian_dataset(train_data_list[j])
            train_dataloader = DataLoader(gaussian_data, batch_size=batch_size,
                                          shuffle=False, num_workers=0)
            (delta, sigma) = m.train(train_dataloader, j, 
                                     t_delta, t_sigma,
                                     clip_value)
            final_values.append((delta, sigma))

        final_params[m.model_name] = final_values.copy()

    ######### Test models using difference between parameters

    param_diffs = {}

    for m in model_list:
        
        diffs = []

        for i in range(params['n_tests']):
            delta = final_params[m.model_name][i][0]
            sigma = final_params[m.model_name][i][1]

            delta_diff = np.sum((delta - t_delta.numpy())**2)
            sigma_diff = np.sum((sigma - t_sigma.numpy())**2)
            theta_diff = delta_diff + sigma_diff
            print(f"Model {m.model_name}, test = {i}, result delta diff = {delta_diff}")
            print(f"Model {m.model_name}, test = {i}, result sigma diff = {sigma_diff}")
            print(f"Model {m.model_name}, test = {i}, result theta diff = {theta_diff}")

            diffs.append((delta_diff, sigma_diff, theta_diff))

        param_diffs[m.model_name] = diffs.copy()

    # Save parameter differences in a pickle file
    diff_path = os.path.join('save', str(d), 'all_diffs.p')
    pickle.dump(param_diffs, open(diff_path, 'wb'))

# %%
params = {

    # PROBLEM SPECIFICATION
    #'dims': [1, 2, 3, 5, 11, 25, 51, 101, 201, 301], # Dimensions to test
    'dims': [100],
    'n_data': 10000,                                 # Number of data points

    # TEST HYPERPARAMETERS
    'n_tests': 3,      # Number of experiments to run

    # GLOBAL OPTIMIZATION PARAMETERS
    'n_iter': 4000,    # Number of optimization iterations
    'n_batch': 10,      # Number of points for ELBO estimate
    'rms_eta': 0.001,   # Stepsize for RMSProp
    'save_every': 20,   # Save parameter information every so often
    'print_every': 20, # Print less often than save

    # HVAE HYPERPARAMETERS
    'HVAE_K_1': 1,    # Number of leapfrog/cooling steps for HVAE flow 1
    'HVAE_K_2': 10,   # Number of leapfrog/cooling steps for HVAE flow 2
    'max_eps': 0.5,   # Maximum leapfrog step size per dimension 

    # NF HYPERPARAMETERS
    'NF_K_1': 1,    # Number of flow steps for NF flow 1
    'NF_K_2': 30,   # Number of flow steps for NF flow 2
    
}

# %%
device = torch.device("cuda")
dtype = torch.float32
clip_value = None
batch_size = 256

# %%
dims = params['dims']
seed = 12345
np.random.seed(seed)
torch.manual_seed(seed)
for d in dims:
    print('**** Running test for d={0:d} ****'.format(d))
    run_test(d, params, batch_size, clip_value, dtype, device)
# Out:
# **** Running test for d=100 ****
# true delta = [-9.9 -9.7 -9.5 -9.3 -9.1 -8.9 -8.7 -8.5 -8.3 -8.1 -7.9 -7.7 -7.5 -7.3
#  -7.1 -6.9 -6.7 -6.5 -6.3 -6.1 -5.9 -5.7 -5.5 -5.3 -5.1 -4.9 -4.7 -4.5
#  -4.3 -4.1 -3.9 -3.7 -3.5 -3.3 -3.1 -2.9 -2.7 -2.5 -2.3 -2.1 -1.9 -1.7
#  -1.5 -1.3 -1.1 -0.9 -0.7 -0.5 -0.3 -0.1  0.1  0.3  0.5  0.7  0.9  1.1
#   1.3  1.5  1.7  1.9  2.1  2.3  2.5  2.7  2.9  3.1  3.3  3.5  3.7  3.9
#   4.1  4.3  4.5  4.7  4.9  5.1  5.3  5.5  5.7  5.9  6.1  6.3  6.5  6.7
#   6.9  7.1  7.3  7.5  7.7  7.9  8.1  8.3  8.5  8.7  8.9  9.1  9.3  9.5
#   9.7  9.9]
# true sigma = [1.         0.9640037  0.928742   0.8942149  0.86042243 0.82736456
#  0.7950414  0.76345277 0.7325987  0.70247936 0.67309463 0.64444447
#  0.6165289  0.589348   0.56290174 0.5371901  0.51221305 0.48797062
#  0.46446282 0.4416896  0.41965106 0.3983471  0.37777779 0.35794306
#  0.338843   0.32047752 0.30284664 0.28595042 0.2697888  0.2543618
#  0.23966941 0.22571167 0.21248853 0.2        0.1882461  0.17722681
#  0.16694215 0.1573921  0.14857668 0.14049587 0.13314968 0.12653811
#  0.12066115 0.11551882 0.11111111 0.10743802 0.10449954 0.10229568
#  0.10082645 0.10009183 0.10009183 0.10082645 0.10229568 0.10449954
#  0.10743802 0.11111111 0.11551882 0.12066115 0.12653811 0.13314968
#  0.14049587 0.14857668 0.1573921  0.16694215 0.17722681 0.1882461
#  0.2        0.21248853 0.22571167 0.23966941 0.2543618  0.2697888
#  0.28595042 0.30284664 0.32047752 0.338843   0.35794306 0.37777779
#  0.3983471  0.41965106 0.4416896  0.46446282 0.48797062 0.51221305
#  0.5371901  0.56290174 0.589348   0.6165289  0.64444447 0.67309463
#  0.70247936 0.7325987  0.76345277 0.7950414  0.82736456 0.86042243
#  0.8942149  0.928742   0.9640037  1.        ]
# Models were initialized!
# ------------------------------------------------------
# Test = 0
# ------------------------------------------------------
# Init diff delta = 3333.0
# Init diff sigma = 38735.67578125
# Init diff theta = 42068.67578125
# VB, d: 100, Iter: 1-20, s/iter: 1.141e-01, ELBO: -3.324e+06
# Cur diff delta = 2556.399169921875
# Cur diff sigma = 7166.11962890625
# Cur diff theta = 9722.518798828125
# ---------------------------------------
# VB, d: 100, Iter: 1-40, s/iter: 1.101e-01, ELBO: -2.732e+06
# Cur diff delta = 1969.828125
# Cur diff sigma = 2651.823974609375
# Cur diff theta = 4621.652099609375
# ---------------------------------------
# VB, d: 100, Iter: 1-60, s/iter: 1.090e-01, ELBO: -2.113e+06
# Cur diff delta = 1502.4947509765625
# Cur diff sigma = 1303.6412353515625
# Cur diff theta = 2806.135986328125
# ---------------------------------------
# VB, d: 100, Iter: 1-80, s/iter: 1.088e-01, ELBO: -1.493e+06
# Cur diff delta = 1192.107666015625
# Cur diff sigma = 676.4468383789062
# Cur diff theta = 1868.5545043945312
# ---------------------------------------
# VB, d: 100, Iter: 1-100, s/iter: 1.159e-01, ELBO: -9.756e+05
# Cur diff delta = 1001.1378784179688
# Cur diff sigma = 318.64007568359375
# Cur diff theta = 1319.7779541015625
# ---------------------------------------
# VB, d: 100, Iter: 1-120, s/iter: 1.101e-01, ELBO: -5.949e+05
# Cur diff delta = 866.1585693359375
# Cur diff sigma = 121.01400756835938
# Cur diff theta = 987.1725769042969
# ---------------------------------------
# VB, d: 100, Iter: 1-140, s/iter: 1.089e-01, ELBO: -4.016e+05
# Cur diff delta = 770.3858642578125
# Cur diff sigma = 32.28058624267578
# Cur diff theta = 802.6664505004883
# ---------------------------------------
# VB, d: 100, Iter: 1-160, s/iter: 1.117e-01, ELBO: -3.085e+05
# Cur diff delta = 707.6218872070312
# Cur diff sigma = 4.980926513671875
# Cur diff theta = 712.6028137207031
# ---------------------------------------
# VB, d: 100, Iter: 1-180, s/iter: 1.154e-01, ELBO: -2.838e+05
# Cur diff delta = 673.7106323242188
# Cur diff sigma = 0.12934787571430206
# Cur diff theta = 673.839980199933
# ---------------------------------------
# VB, d: 100, Iter: 1-200, s/iter: 1.102e-01, ELBO: -2.796e+05
# Cur diff delta = 650.9303588867188
# Cur diff sigma = 0.0014283573254942894
# Cur diff theta = 650.9317872440442
# ---------------------------------------
# VB, d: 100, Iter: 1-220, s/iter: 1.096e-01, ELBO: -2.791e+05
# Cur diff delta = 630.9855346679688
# Cur diff sigma = 0.0014281844487413764
# Cur diff theta = 630.9869628524175
# ---------------------------------------
# VB, d: 100, Iter: 1-240, s/iter: 1.144e-01, ELBO: -2.787e+05
# Cur diff delta = 611.8325805664062
# Cur diff sigma = 0.0014281338080763817
# Cur diff theta = 611.8340087002143
# ---------------------------------------
# VB, d: 100, Iter: 1-260, s/iter: 1.162e-01, ELBO: -2.783e+05
# Cur diff delta = 593.4434814453125
# Cur diff sigma = 0.0014281561598181725
# Cur diff theta = 593.4449096014723
# ---------------------------------------
# VB, d: 100, Iter: 1-280, s/iter: 1.197e-01, ELBO: -2.779e+05
# Cur diff delta = 575.7870483398438
# Cur diff sigma = 0.0014281772309914231
# Cur diff theta = 575.7884765170747
# ---------------------------------------
# VB, d: 100, Iter: 1-300, s/iter: 1.101e-01, ELBO: -2.775e+05
# Cur diff delta = 558.8329467773438
# Cur diff sigma = 0.0014281822368502617
# Cur diff theta = 558.8343749595806
# ---------------------------------------
# VB, d: 100, Iter: 1-320, s/iter: 1.154e-01, ELBO: -2.772e+05
# Cur diff delta = 542.55224609375
# Cur diff sigma = 0.0014281838666647673
# Cur diff theta = 542.5536742776167
# ---------------------------------------
# VB, d: 100, Iter: 1-340, s/iter: 1.115e-01, ELBO: -2.768e+05
# Cur diff delta = 526.9171752929688
# Cur diff sigma = 0.0014282061019912362
# Cur diff theta = 526.9186034990707
# ---------------------------------------
# VB, d: 100, Iter: 1-360, s/iter: 1.098e-01, ELBO: -2.765e+05
# Cur diff delta = 511.901123046875
# Cur diff sigma = 0.0014282560441643
# Cur diff theta = 511.90255130291916
# ---------------------------------------
# VB, d: 100, Iter: 1-380, s/iter: 1.246e-01, ELBO: -2.762e+05
# Cur diff delta = 497.4785461425781
# Cur diff sigma = 0.0014282588381320238
# Cur diff theta = 497.47997440141626
# ---------------------------------------
# VB, d: 100, Iter: 1-400, s/iter: 1.115e-01, ELBO: -2.759e+05
# Cur diff delta = 483.62493896484375
# Cur diff sigma = 0.001428272225894034
# Cur diff theta = 483.62636723706964
# ---------------------------------------
# VB, d: 100, Iter: 1-420, s/iter: 1.090e-01, ELBO: -2.756e+05
# Cur diff delta = 470.316650390625
# Cur diff sigma = 0.001428292947821319
# Cur diff theta = 470.3180786835728
# ---------------------------------------
# VB, d: 100, Iter: 1-440, s/iter: 1.079e-01, ELBO: -2.753e+05
# Cur diff delta = 457.5312805175781
# Cur diff sigma = 0.0014282986521720886
# Cur diff theta = 457.5327088162303
# ---------------------------------------
# VB, d: 100, Iter: 1-460, s/iter: 1.252e-01, ELBO: -2.750e+05
# Cur diff delta = 445.2473449707031
# Cur diff sigma = 0.0014283225173130631
# Cur diff theta = 445.24877329322044
# ---------------------------------------
# VB, d: 100, Iter: 1-480, s/iter: 1.197e-01, ELBO: -2.748e+05
# Cur diff delta = 433.4440612792969
# Cur diff sigma = 0.0014283283380791545
# Cur diff theta = 433.44548960763495
# ---------------------------------------
# VB, d: 100, Iter: 1-500, s/iter: 1.126e-01, ELBO: -2.745e+05
# Cur diff delta = 422.1015625
# Cur diff sigma = 0.001428349525667727
# Cur diff theta = 422.10299084952567
# ---------------------------------------
# VB, d: 100, Iter: 1-520, s/iter: 1.230e-01, ELBO: -2.743e+05
# Cur diff delta = 411.2011413574219
# Cur diff sigma = 0.0014283581404015422
# Cur diff theta = 411.2025697155623
# ---------------------------------------
# VB, d: 100, Iter: 1-540, s/iter: 1.103e-01, ELBO: -2.740e+05
# Cur diff delta = 400.72412109375
# Cur diff sigma = 0.0014283786294981837
# Cur diff theta = 400.7255494723795
# ---------------------------------------
# VB, d: 100, Iter: 1-560, s/iter: 1.104e-01, ELBO: -2.738e+05
# Cur diff delta = 390.65338134765625
# Cur diff sigma = 0.0014283985365182161
# Cur diff theta = 390.65480974619277
# ---------------------------------------
# VB, d: 100, Iter: 1-580, s/iter: 1.088e-01, ELBO: -2.736e+05
# Cur diff delta = 380.9721984863281
# Cur diff sigma = 0.0014283985365182161
# Cur diff theta = 380.97362688486464
# ---------------------------------------
# VB, d: 100, Iter: 1-600, s/iter: 1.140e-01, ELBO: -2.734e+05
# Cur diff delta = 371.66455078125
# Cur diff sigma = 0.001428417395800352
# Cur diff theta = 371.6659791986458
# ---------------------------------------
# VB, d: 100, Iter: 1-620, s/iter: 1.245e-01, ELBO: -2.732e+05
# Cur diff delta = 362.7151794433594
# Cur diff sigma = 0.0014284375356510282
# Cur diff theta = 362.716607880895
# ---------------------------------------
# VB, d: 100, Iter: 1-640, s/iter: 1.345e-01, ELBO: -2.730e+05
# Cur diff delta = 354.1092529296875
# Cur diff sigma = 0.001428449060767889
# Cur diff theta = 354.11068137874827
# ---------------------------------------
# VB, d: 100, Iter: 1-660, s/iter: 1.129e-01, ELBO: -2.728e+05
# Cur diff delta = 345.8326721191406
# Cur diff sigma = 0.0014284664066508412
# Cur diff theta = 345.8341005855473
# ---------------------------------------
# VB, d: 100, Iter: 1-680, s/iter: 1.104e-01, ELBO: -2.726e+05
# Cur diff delta = 337.8719482421875
# Cur diff sigma = 0.0014284738572314382
# Cur diff theta = 337.87337671604473
# ---------------------------------------
# VB, d: 100, Iter: 1-700, s/iter: 1.244e-01, ELBO: -2.724e+05
# Cur diff delta = 330.21441650390625
# Cur diff sigma = 0.0014284858480095863
# Cur diff theta = 330.21584498975426
# ---------------------------------------
# VB, d: 100, Iter: 1-720, s/iter: 1.176e-01, ELBO: -2.723e+05
# Cur diff delta = 322.8472900390625
# Cur diff sigma = 0.001428505522198975
# Cur diff theta = 322.8487185445847
# ---------------------------------------
# VB, d: 100, Iter: 1-740, s/iter: 1.101e-01, ELBO: -2.721e+05
# Cur diff delta = 315.7591247558594
# Cur diff sigma = 0.0014285157667472959
# Cur diff theta = 315.7605532716261
# ---------------------------------------
# VB, d: 100, Iter: 1-760, s/iter: 1.098e-01, ELBO: -2.719e+05
# Cur diff delta = 308.938232421875
# Cur diff sigma = 0.0014285399811342359
# Cur diff theta = 308.93966096185613
# ---------------------------------------
# VB, d: 100, Iter: 1-780, s/iter: 1.091e-01, ELBO: -2.718e+05
# Cur diff delta = 302.3740539550781
# Cur diff sigma = 0.0014285602374002337
# Cur diff theta = 302.3754825153155
# ---------------------------------------
# VB, d: 100, Iter: 1-800, s/iter: 1.223e-01, ELBO: -2.716e+05
# Cur diff delta = 296.0558776855469
# Cur diff sigma = 0.0014285770012065768
# Cur diff theta = 296.0573062625481
# ---------------------------------------
# VB, d: 100, Iter: 1-820, s/iter: 1.125e-01, ELBO: -2.715e+05
# Cur diff delta = 289.9739074707031
# Cur diff sigma = 0.0014285942306742072
# Cur diff theta = 289.9753360649338
# ---------------------------------------
# VB, d: 100, Iter: 1-840, s/iter: 1.145e-01, ELBO: -2.714e+05
# Cur diff delta = 284.1186218261719
# Cur diff sigma = 0.0014286076184362173
# Cur diff theta = 284.1200504337903
# ---------------------------------------
# VB, d: 100, Iter: 1-860, s/iter: 1.109e-01, ELBO: -2.712e+05
# Cur diff delta = 278.480712890625
# Cur diff sigma = 0.0014286218211054802
# Cur diff theta = 278.4821415124461
# ---------------------------------------
# VB, d: 100, Iter: 1-880, s/iter: 1.127e-01, ELBO: -2.711e+05
# Cur diff delta = 273.0513610839844
# Cur diff sigma = 0.00142862054053694
# Cur diff theta = 273.0527897045249
# ---------------------------------------
# VB, d: 100, Iter: 1-900, s/iter: 1.112e-01, ELBO: -2.710e+05
# Cur diff delta = 267.8223571777344
# Cur diff sigma = 0.0014286336954683065
# Cur diff theta = 267.82378581142984
# ---------------------------------------
# VB, d: 100, Iter: 1-920, s/iter: 1.097e-01, ELBO: -2.709e+05
# Cur diff delta = 262.7855224609375
# Cur diff sigma = 0.0014286485966295004
# Cur diff theta = 262.78695110953413
# ---------------------------------------
# VB, d: 100, Iter: 1-940, s/iter: 1.132e-01, ELBO: -2.708e+05
# Cur diff delta = 257.9330749511719
# Cur diff sigma = 0.001428654184564948
# Cur diff theta = 257.93450360535644
# ---------------------------------------
# VB, d: 100, Iter: 1-960, s/iter: 1.086e-01, ELBO: -2.706e+05
# Cur diff delta = 253.2579345703125
# Cur diff sigma = 0.0014286660589277744
# Cur diff theta = 253.25936323637143
# ---------------------------------------
# VB, d: 100, Iter: 1-980, s/iter: 1.127e-01, ELBO: -2.705e+05
# Cur diff delta = 248.75274658203125
# Cur diff sigma = 0.001428682473488152
# Cur diff theta = 248.75417526450474
# ---------------------------------------
# VB, d: 100, Iter: 1-1000, s/iter: 1.092e-01, ELBO: -2.704e+05
# Cur diff delta = 244.41062927246094
# Cur diff sigma = 0.0014286991208791733
# Cur diff theta = 244.41205797158182
# ---------------------------------------
# VB, d: 100, Iter: 1-1020, s/iter: 1.084e-01, ELBO: -2.703e+05
# Cur diff delta = 240.22509765625
# Cur diff sigma = 0.0014287097146734595
# Cur diff theta = 240.22652636596467
# ---------------------------------------
# VB, d: 100, Iter: 1-1040, s/iter: 1.093e-01, ELBO: -2.702e+05
# Cur diff delta = 236.19015502929688
# Cur diff sigma = 0.001428722171112895
# Cur diff theta = 236.191583751468
# ---------------------------------------
# VB, d: 100, Iter: 1-1060, s/iter: 1.089e-01, ELBO: -2.701e+05
# Cur diff delta = 232.29969787597656
# Cur diff sigma = 0.0014287279918789864
# Cur diff theta = 232.30112660396844
# ---------------------------------------
# VB, d: 100, Iter: 1-1080, s/iter: 1.103e-01, ELBO: -2.700e+05
# Cur diff delta = 228.54818725585938
# Cur diff sigma = 0.0014287384692579508
# Cur diff theta = 228.54961599432863
# ---------------------------------------
# VB, d: 100, Iter: 1-1100, s/iter: 1.113e-01, ELBO: -2.700e+05
# Cur diff delta = 224.9298858642578
# Cur diff sigma = 0.001428754534572363
# Cur diff theta = 224.93131461879238
# ---------------------------------------
# VB, d: 100, Iter: 1-1120, s/iter: 1.129e-01, ELBO: -2.699e+05
# Cur diff delta = 221.43983459472656
# Cur diff sigma = 0.0014287660596892238
# Cur diff theta = 221.44126336078625
# ---------------------------------------
# VB, d: 100, Iter: 1-1140, s/iter: 1.109e-01, ELBO: -2.698e+05
# Cur diff delta = 218.0726776123047
# Cur diff sigma = 0.0014287736266851425
# Cur diff theta = 218.07410638593137
# ---------------------------------------
# VB, d: 100, Iter: 1-1160, s/iter: 1.203e-01, ELBO: -2.697e+05
# Cur diff delta = 214.82374572753906
# Cur diff sigma = 0.0014287877129390836
# Cur diff theta = 214.825174515252
# ---------------------------------------
# VB, d: 100, Iter: 1-1180, s/iter: 1.095e-01, ELBO: -2.696e+05
# Cur diff delta = 211.68844604492188
# Cur diff sigma = 0.0014288021484389901
# Cur diff theta = 211.6898748470703
# ---------------------------------------
# VB, d: 100, Iter: 1-1200, s/iter: 1.110e-01, ELBO: -2.696e+05
# Cur diff delta = 208.6622314453125
# Cur diff sigma = 0.0014288151869550347
# Cur diff theta = 208.66366026049946
# ---------------------------------------
# VB, d: 100, Iter: 1-1220, s/iter: 1.101e-01, ELBO: -2.695e+05
# Cur diff delta = 205.74085998535156
# Cur diff sigma = 0.0014288157690316439
# Cur diff theta = 205.7422888011206
# ---------------------------------------
# VB, d: 100, Iter: 1-1240, s/iter: 1.234e-01, ELBO: -2.694e+05
# Cur diff delta = 202.9203643798828
# Cur diff sigma = 0.0014288246165961027
# Cur diff theta = 202.9217932044994
# ---------------------------------------
# VB, d: 100, Iter: 1-1260, s/iter: 1.131e-01, ELBO: -2.694e+05
# Cur diff delta = 200.19677734375
# Cur diff sigma = 0.0014288437087088823
# Cur diff theta = 200.1982061874587
# ---------------------------------------
# VB, d: 100, Iter: 1-1280, s/iter: 1.130e-01, ELBO: -2.693e+05
# Cur diff delta = 197.56629943847656
# Cur diff sigma = 0.0014288448728621006
# Cur diff theta = 197.56772828334942
# ---------------------------------------
# VB, d: 100, Iter: 1-1300, s/iter: 1.134e-01, ELBO: -2.692e+05
# Cur diff delta = 195.02542114257812
# Cur diff sigma = 0.001428851974196732
# Cur diff theta = 195.02684999455232
# ---------------------------------------
# VB, d: 100, Iter: 1-1320, s/iter: 1.123e-01, ELBO: -2.692e+05
# Cur diff delta = 192.57083129882812
# Cur diff sigma = 0.0014288650127127767
# Cur diff theta = 192.57226016384084
# ---------------------------------------
# VB, d: 100, Iter: 1-1340, s/iter: 1.205e-01, ELBO: -2.691e+05
# Cur diff delta = 190.19900512695312
# Cur diff sigma = 0.0014288690872490406
# Cur diff theta = 190.20043399604037
# ---------------------------------------
# VB, d: 100, Iter: 1-1360, s/iter: 1.154e-01, ELBO: -2.690e+05
# Cur diff delta = 187.9068145751953
# Cur diff sigma = 0.0014288845704868436
# Cur diff theta = 187.9082434597658
# ---------------------------------------
# VB, d: 100, Iter: 1-1380, s/iter: 1.152e-01, ELBO: -2.690e+05
# Cur diff delta = 185.69137573242188
# Cur diff sigma = 0.0014288942329585552
# Cur diff theta = 185.69280462665483
# ---------------------------------------
# VB, d: 100, Iter: 1-1400, s/iter: 1.110e-01, ELBO: -2.689e+05
# Cur diff delta = 183.549560546875
# Cur diff sigma = 0.0014288985403254628
# Cur diff theta = 183.55098944541533
# ---------------------------------------
# VB, d: 100, Iter: 1-1420, s/iter: 1.104e-01, ELBO: -2.689e+05
# Cur diff delta = 181.4787139892578
# Cur diff sigma = 0.001428903080523014
# Cur diff theta = 181.48014289233834
# ---------------------------------------
# VB, d: 100, Iter: 1-1440, s/iter: 1.102e-01, ELBO: -2.688e+05
# Cur diff delta = 179.47613525390625
# Cur diff sigma = 0.0014289100654423237
# Cur diff theta = 179.4775641639717
# ---------------------------------------
# VB, d: 100, Iter: 1-1460, s/iter: 1.083e-01, ELBO: -2.688e+05
# Cur diff delta = 177.53916931152344
# Cur diff sigma = 0.001428917865268886
# Cur diff theta = 177.5405982293887
# ---------------------------------------
# VB, d: 100, Iter: 1-1480, s/iter: 1.140e-01, ELBO: -2.687e+05
# Cur diff delta = 175.66546630859375
# Cur diff sigma = 0.0014289289247244596
# Cur diff theta = 175.66689523751847
# ---------------------------------------
# VB, d: 100, Iter: 1-1500, s/iter: 1.080e-01, ELBO: -2.687e+05
# Cur diff delta = 173.85250854492188
# Cur diff sigma = 0.0014289353275671601
# Cur diff theta = 173.85393748024944
# ---------------------------------------
# VB, d: 100, Iter: 1-1520, s/iter: 1.146e-01, ELBO: -2.686e+05
# Cur diff delta = 172.09812927246094
# Cur diff sigma = 0.001428943476639688
# Cur diff theta = 172.09955821593758
# ---------------------------------------
# VB, d: 100, Iter: 1-1540, s/iter: 1.080e-01, ELBO: -2.686e+05
# Cur diff delta = 170.400146484375
# Cur diff sigma = 0.0014289505779743195
# Cur diff theta = 170.40157543495297
# ---------------------------------------
# VB, d: 100, Iter: 1-1560, s/iter: 1.222e-01, ELBO: -2.685e+05
# Cur diff delta = 168.75650024414062
# Cur diff sigma = 0.0014289587270468473
# Cur diff theta = 168.75792920286767
# ---------------------------------------
# VB, d: 100, Iter: 1-1580, s/iter: 1.100e-01, ELBO: -2.685e+05
# Cur diff delta = 167.16510009765625
# Cur diff sigma = 0.0014289604732766747
# Cur diff theta = 167.16652905812953
# ---------------------------------------
# VB, d: 100, Iter: 1-1600, s/iter: 1.181e-01, ELBO: -2.685e+05
# Cur diff delta = 165.62405395507812
# Cur diff sigma = 0.0014289756072685122
# Cur diff theta = 165.6254829306854
# ---------------------------------------
# VB, d: 100, Iter: 1-1620, s/iter: 1.244e-01, ELBO: -2.684e+05
# Cur diff delta = 164.13162231445312
# Cur diff sigma = 0.001428990508429706
# Cur diff theta = 164.13305130496155
# ---------------------------------------
# VB, d: 100, Iter: 1-1640, s/iter: 1.081e-01, ELBO: -2.684e+05
# Cur diff delta = 162.68588256835938
# Cur diff sigma = 0.0014289920218288898
# Cur diff theta = 162.6873115603812
# ---------------------------------------
# VB, d: 100, Iter: 1-1660, s/iter: 1.095e-01, ELBO: -2.683e+05
# Cur diff delta = 161.28524780273438
# Cur diff sigma = 0.0014289977261796594
# Cur diff theta = 161.28667680046055
# ---------------------------------------
# VB, d: 100, Iter: 1-1680, s/iter: 1.199e-01, ELBO: -2.683e+05
# Cur diff delta = 159.92800903320312
# Cur diff sigma = 0.0014290096005424857
# Cur diff theta = 159.92943804280367
# ---------------------------------------
# VB, d: 100, Iter: 1-1700, s/iter: 1.101e-01, ELBO: -2.683e+05
# Cur diff delta = 158.61245727539062
# Cur diff sigma = 0.0014290113467723131
# Cur diff theta = 158.6138862867374
# ---------------------------------------
# VB, d: 100, Iter: 1-1720, s/iter: 1.082e-01, ELBO: -2.682e+05
# Cur diff delta = 157.33734130859375
# Cur diff sigma = 0.0014290157705545425
# Cur diff theta = 157.3387703243643
# ---------------------------------------
# VB, d: 100, Iter: 1-1740, s/iter: 1.079e-01, ELBO: -2.682e+05
# Cur diff delta = 156.10107421875
# Cur diff sigma = 0.0014290219405665994
# Cur diff theta = 156.10250324069057
# ---------------------------------------
# VB, d: 100, Iter: 1-1760, s/iter: 1.081e-01, ELBO: -2.682e+05
# Cur diff delta = 154.90240478515625
# Cur diff sigma = 0.001429030322469771
# Cur diff theta = 154.90383381547872
# ---------------------------------------
# VB, d: 100, Iter: 1-1780, s/iter: 1.085e-01, ELBO: -2.681e+05
# Cur diff delta = 153.73995971679688
# Cur diff sigma = 0.0014290300896391273
# Cur diff theta = 153.7413887468865
# ---------------------------------------
# VB, d: 100, Iter: 1-1800, s/iter: 1.218e-01, ELBO: -2.681e+05
# Cur diff delta = 152.6121826171875
# Cur diff sigma = 0.0014290345134213567
# Cur diff theta = 152.61361165170092
# ---------------------------------------
# VB, d: 100, Iter: 1-1820, s/iter: 1.217e-01, ELBO: -2.681e+05
# Cur diff delta = 151.51806640625
# Cur diff sigma = 0.0014290374238044024
# Cur diff theta = 151.5194954436738
# ---------------------------------------
# VB, d: 100, Iter: 1-1840, s/iter: 1.093e-01, ELBO: -2.680e+05
# Cur diff delta = 150.4565887451172
# Cur diff sigma = 0.0014290447579696774
# Cur diff theta = 150.45801778987516
# ---------------------------------------
# VB, d: 100, Iter: 1-1860, s/iter: 1.120e-01, ELBO: -2.680e+05
# Cur diff delta = 149.42626953125
# Cur diff sigma = 0.0014290552353486419
# Cur diff theta = 149.42769858648535
# ---------------------------------------
# VB, d: 100, Iter: 1-1880, s/iter: 1.080e-01, ELBO: -2.680e+05
# Cur diff delta = 148.42587280273438
# Cur diff sigma = 0.0014290594263002276
# Cur diff theta = 148.42730186216068
# ---------------------------------------
# VB, d: 100, Iter: 1-1900, s/iter: 1.241e-01, ELBO: -2.679e+05
# Cur diff delta = 147.45465087890625
# Cur diff sigma = 0.0014290617546066642
# Cur diff theta = 147.45607994066086
# ---------------------------------------
# VB, d: 100, Iter: 1-1920, s/iter: 1.172e-01, ELBO: -2.679e+05
# Cur diff delta = 146.5116424560547
# Cur diff sigma = 0.001429060474038124
# Cur diff theta = 146.51307151652873
# ---------------------------------------
# VB, d: 100, Iter: 1-1940, s/iter: 1.078e-01, ELBO: -2.679e+05
# Cur diff delta = 145.5957794189453
# Cur diff sigma = 0.0014290716499090195
# Cur diff theta = 145.59720849059522
# ---------------------------------------
# VB, d: 100, Iter: 1-1960, s/iter: 1.113e-01, ELBO: -2.679e+05
# Cur diff delta = 144.7061004638672
# Cur diff sigma = 0.001429074676707387
# Cur diff theta = 144.7075295385439
# ---------------------------------------
# VB, d: 100, Iter: 1-1980, s/iter: 1.087e-01, ELBO: -2.678e+05
# Cur diff delta = 143.8415985107422
# Cur diff sigma = 0.0014290761901065707
# Cur diff theta = 143.8430275869323
# ---------------------------------------
# VB, d: 100, Iter: 1-2000, s/iter: 1.107e-01, ELBO: -2.678e+05
# Cur diff delta = 143.0016326904297
# Cur diff sigma = 0.001429084688425064
# Cur diff theta = 143.0030617751181
# ---------------------------------------
# VB, d: 100, Iter: 1-2020, s/iter: 1.094e-01, ELBO: -2.678e+05
# Cur diff delta = 142.18519592285156
# Cur diff sigma = 0.0014290809631347656
# Cur diff theta = 142.1866250038147
# ---------------------------------------
# VB, d: 100, Iter: 1-2040, s/iter: 1.154e-01, ELBO: -2.678e+05
# Cur diff delta = 141.39175415039062
# Cur diff sigma = 0.0014290933031588793
# Cur diff theta = 141.39318324369378
# ---------------------------------------
# VB, d: 100, Iter: 1-2060, s/iter: 1.099e-01, ELBO: -2.677e+05
# Cur diff delta = 140.6202850341797
# Cur diff sigma = 0.0014290960971266031
# Cur diff theta = 140.6217141302768
# ---------------------------------------
# VB, d: 100, Iter: 1-2080, s/iter: 1.109e-01, ELBO: -2.677e+05
# Cur diff delta = 139.8702392578125
# Cur diff sigma = 0.001429100288078189
# Cur diff theta = 139.87166835810058
# ---------------------------------------
# VB, d: 100, Iter: 1-2100, s/iter: 1.211e-01, ELBO: -2.677e+05
# Cur diff delta = 139.1405029296875
# Cur diff sigma = 0.0014290984254330397
# Cur diff theta = 139.14193202811293
# ---------------------------------------
# VB, d: 100, Iter: 1-2120, s/iter: 1.222e-01, ELBO: -2.677e+05
# Cur diff delta = 138.43101501464844
# Cur diff sigma = 0.0014291119296103716
# Cur diff theta = 138.43244412657805
# ---------------------------------------
# VB, d: 100, Iter: 1-2140, s/iter: 1.160e-01, ELBO: -2.677e+05
# Cur diff delta = 137.74073791503906
# Cur diff sigma = 0.0014291133265942335
# Cur diff theta = 137.74216702836566
# ---------------------------------------
# VB, d: 100, Iter: 1-2160, s/iter: 1.084e-01, ELBO: -2.676e+05
# Cur diff delta = 137.06893920898438
# Cur diff sigma = 0.0014291125116869807
# Cur diff theta = 137.07036832149606
# ---------------------------------------
# VB, d: 100, Iter: 1-2180, s/iter: 1.080e-01, ELBO: -2.676e+05
# Cur diff delta = 136.41519165039062
# Cur diff sigma = 0.0014291147235780954
# Cur diff theta = 136.4166207651142
# ---------------------------------------
# VB, d: 100, Iter: 1-2200, s/iter: 1.085e-01, ELBO: -2.676e+05
# Cur diff delta = 135.77894592285156
# Cur diff sigma = 0.0014291220577433705
# Cur diff theta = 135.7803750449093
# ---------------------------------------
# VB, d: 100, Iter: 1-2220, s/iter: 1.191e-01, ELBO: -2.676e+05
# Cur diff delta = 135.15939331054688
# Cur diff sigma = 0.0014291261322796345
# Cur diff theta = 135.16082243667915
# ---------------------------------------
# VB, d: 100, Iter: 1-2240, s/iter: 1.090e-01, ELBO: -2.676e+05
# Cur diff delta = 134.556396484375
# Cur diff sigma = 0.0014291293919086456
# Cur diff theta = 134.5578256137669
# ---------------------------------------
# VB, d: 100, Iter: 1-2260, s/iter: 1.080e-01, ELBO: -2.675e+05
# Cur diff delta = 133.9688262939453
# Cur diff sigma = 0.0014291349798440933
# Cur diff theta = 133.97025542892516
# ---------------------------------------
# VB, d: 100, Iter: 1-2280, s/iter: 1.134e-01, ELBO: -2.675e+05
# Cur diff delta = 133.39649963378906
# Cur diff sigma = 0.0014291339321061969
# Cur diff theta = 133.39792876772117
# ---------------------------------------
# VB, d: 100, Iter: 1-2300, s/iter: 1.125e-01, ELBO: -2.675e+05
# Cur diff delta = 132.8391876220703
# Cur diff sigma = 0.001429135911166668
# Cur diff theta = 132.84061675798148
# ---------------------------------------
# VB, d: 100, Iter: 1-2320, s/iter: 1.188e-01, ELBO: -2.675e+05
# Cur diff delta = 132.2958526611328
# Cur diff sigma = 0.0014291395200416446
# Cur diff theta = 132.29728180065285
# ---------------------------------------
# VB, d: 100, Iter: 1-2340, s/iter: 1.111e-01, ELBO: -2.675e+05
# Cur diff delta = 131.7666778564453
# Cur diff sigma = 0.0014291433617472649
# Cur diff theta = 131.76810699980706
# ---------------------------------------
# VB, d: 100, Iter: 1-2360, s/iter: 1.126e-01, ELBO: -2.675e+05
# Cur diff delta = 131.25070190429688
# Cur diff sigma = 0.0014291449915617704
# Cur diff theta = 131.25213104928844
# ---------------------------------------
# VB, d: 100, Iter: 1-2380, s/iter: 1.086e-01, ELBO: -2.674e+05
# Cur diff delta = 130.74754333496094
# Cur diff sigma = 0.0014291456900537014
# Cur diff theta = 130.748972480651
# ---------------------------------------
# VB, d: 100, Iter: 1-2400, s/iter: 1.200e-01, ELBO: -2.674e+05
# Cur diff delta = 130.2572479248047
# Cur diff sigma = 0.001429149298928678
# Cur diff theta = 130.25867707410362
# ---------------------------------------
# VB, d: 100, Iter: 1-2420, s/iter: 1.243e-01, ELBO: -2.674e+05
# Cur diff delta = 129.77890014648438
# Cur diff sigma = 0.0014291551196947694
# Cur diff theta = 129.78032930160407
# ---------------------------------------
# VB, d: 100, Iter: 1-2440, s/iter: 1.170e-01, ELBO: -2.674e+05
# Cur diff delta = 129.31243896484375
# Cur diff sigma = 0.0014291566330939531
# Cur diff theta = 129.31386812147684
# ---------------------------------------
# VB, d: 100, Iter: 1-2460, s/iter: 1.092e-01, ELBO: -2.674e+05
# Cur diff delta = 128.85743713378906
# Cur diff sigma = 0.001429156051017344
# Cur diff theta = 128.85886628984008
# ---------------------------------------
# VB, d: 100, Iter: 1-2480, s/iter: 1.088e-01, ELBO: -2.674e+05
# Cur diff delta = 128.413330078125
# Cur diff sigma = 0.001429160125553608
# Cur diff theta = 128.41475923825055
# ---------------------------------------
# VB, d: 100, Iter: 1-2500, s/iter: 1.179e-01, ELBO: -2.673e+05
# Cur diff delta = 127.97982025146484
# Cur diff sigma = 0.001429160824045539
# Cur diff theta = 127.98124941228889
# ---------------------------------------
# VB, d: 100, Iter: 1-2520, s/iter: 1.090e-01, ELBO: -2.673e+05
# Cur diff delta = 127.55706787109375
# Cur diff sigma = 0.001429161406122148
# Cur diff theta = 127.55849703249987
# ---------------------------------------
# VB, d: 100, Iter: 1-2540, s/iter: 1.087e-01, ELBO: -2.673e+05
# Cur diff delta = 127.14412689208984
# Cur diff sigma = 0.0014291687402874231
# Cur diff theta = 127.14555606083013
# ---------------------------------------
# VB, d: 100, Iter: 1-2560, s/iter: 1.225e-01, ELBO: -2.673e+05
# Cur diff delta = 126.74107360839844
# Cur diff sigma = 0.001429169555194676
# Cur diff theta = 126.74250277795363
# ---------------------------------------
# VB, d: 100, Iter: 1-2580, s/iter: 1.266e-01, ELBO: -2.673e+05
# Cur diff delta = 126.3478012084961
# Cur diff sigma = 0.0014291693223640323
# Cur diff theta = 126.34923037781846
# ---------------------------------------
# VB, d: 100, Iter: 1-2600, s/iter: 1.108e-01, ELBO: -2.673e+05
# Cur diff delta = 125.9634017944336
# Cur diff sigma = 0.0014291689731180668
# Cur diff theta = 125.96483096340671
# ---------------------------------------
# VB, d: 100, Iter: 1-2620, s/iter: 1.162e-01, ELBO: -2.673e+05
# Cur diff delta = 125.58814239501953
# Cur diff sigma = 0.0014291733969002962
# Cur diff theta = 125.58957156841643
# ---------------------------------------
# VB, d: 100, Iter: 1-2640, s/iter: 1.130e-01, ELBO: -2.672e+05
# Cur diff delta = 125.22171783447266
# Cur diff sigma = 0.001429172814823687
# Cur diff theta = 125.22314700728748
# ---------------------------------------
# VB, d: 100, Iter: 1-2660, s/iter: 1.086e-01, ELBO: -2.672e+05
# Cur diff delta = 124.86355590820312
# Cur diff sigma = 0.001429178984835744
# Cur diff theta = 124.86498508718796
# ---------------------------------------
# VB, d: 100, Iter: 1-2680, s/iter: 1.085e-01, ELBO: -2.672e+05
# Cur diff delta = 124.51353454589844
# Cur diff sigma = 0.0014291774714365602
# Cur diff theta = 124.51496372336987
# ---------------------------------------
# VB, d: 100, Iter: 1-2700, s/iter: 1.169e-01, ELBO: -2.672e+05
# Cur diff delta = 124.17166900634766
# Cur diff sigma = 0.0014291832922026515
# Cur diff theta = 124.17309818963986
# ---------------------------------------
# VB, d: 100, Iter: 1-2720, s/iter: 1.167e-01, ELBO: -2.672e+05
# Cur diff delta = 123.8376693725586
# Cur diff sigma = 0.001429184922017157
# Cur diff theta = 123.83909855748061
# ---------------------------------------
# VB, d: 100, Iter: 1-2740, s/iter: 1.175e-01, ELBO: -2.672e+05
# Cur diff delta = 123.51118469238281
# Cur diff sigma = 0.0014291838742792606
# Cur diff theta = 123.51261387625709
# ---------------------------------------
# VB, d: 100, Iter: 1-2760, s/iter: 1.102e-01, ELBO: -2.672e+05
# Cur diff delta = 123.19166564941406
# Cur diff sigma = 0.0014291855040937662
# Cur diff theta = 123.19309483491816
# ---------------------------------------
# VB, d: 100, Iter: 1-2780, s/iter: 1.244e-01, ELBO: -2.672e+05
# Cur diff delta = 122.87943267822266
# Cur diff sigma = 0.00142918701749295
# Cur diff theta = 122.88086186524015
# ---------------------------------------
# VB, d: 100, Iter: 1-2800, s/iter: 1.103e-01, ELBO: -2.672e+05
# Cur diff delta = 122.57421875
# Cur diff sigma = 0.0014291935367509723
# Cur diff theta = 122.57564794353675
# ---------------------------------------
# VB, d: 100, Iter: 1-2820, s/iter: 1.141e-01, ELBO: -2.671e+05
# Cur diff delta = 122.27547454833984
# Cur diff sigma = 0.0014291907427832484
# Cur diff theta = 122.27690373908263
# ---------------------------------------
# VB, d: 100, Iter: 1-2840, s/iter: 1.218e-01, ELBO: -2.671e+05
# Cur diff delta = 121.98311614990234
# Cur diff sigma = 0.0014291914412751794
# Cur diff theta = 121.98454534134362
# ---------------------------------------
# VB, d: 100, Iter: 1-2860, s/iter: 1.213e-01, ELBO: -2.671e+05
# Cur diff delta = 121.69710540771484
# Cur diff sigma = 0.0014291900442913175
# Cur diff theta = 121.69853459775914
# ---------------------------------------
# VB, d: 100, Iter: 1-2880, s/iter: 1.193e-01, ELBO: -2.671e+05
# Cur diff delta = 121.41719055175781
# Cur diff sigma = 0.0014291929546743631
# Cur diff theta = 121.41861974471249
# ---------------------------------------
# VB, d: 100, Iter: 1-2900, s/iter: 1.086e-01, ELBO: -2.671e+05
# Cur diff delta = 121.14305877685547
# Cur diff sigma = 0.00142919912468642
# Cur diff theta = 121.14448797598016
# ---------------------------------------
# VB, d: 100, Iter: 1-2920, s/iter: 1.229e-01, ELBO: -2.671e+05
# Cur diff delta = 120.87483978271484
# Cur diff sigma = 0.0014292038977146149
# Cur diff theta = 120.87626898661256
# ---------------------------------------
# VB, d: 100, Iter: 1-2940, s/iter: 1.110e-01, ELBO: -2.671e+05
# Cur diff delta = 120.61255645751953
# Cur diff sigma = 0.0014292026171460748
# Cur diff theta = 120.61398566013668
# ---------------------------------------
# VB, d: 100, Iter: 1-2960, s/iter: 1.198e-01, ELBO: -2.671e+05
# Cur diff delta = 120.35564422607422
# Cur diff sigma = 0.0014292008709162474
# Cur diff theta = 120.35707342694513
# ---------------------------------------
# VB, d: 100, Iter: 1-2980, s/iter: 1.081e-01, ELBO: -2.671e+05
# Cur diff delta = 120.1041488647461
# Cur diff sigma = 0.00142920040525496
# Cur diff theta = 120.10557806515135
# ---------------------------------------
# VB, d: 100, Iter: 1-3000, s/iter: 1.086e-01, ELBO: -2.671e+05
# Cur diff delta = 119.85770416259766
# Cur diff sigma = 0.001429207157343626
# Cur diff theta = 119.859133369755
# ---------------------------------------
# VB, d: 100, Iter: 1-3020, s/iter: 1.108e-01, ELBO: -2.670e+05
# Cur diff delta = 119.61640930175781
# Cur diff sigma = 0.0014292061096057296
# Cur diff theta = 119.61783850786742
# ---------------------------------------
# VB, d: 100, Iter: 1-3040, s/iter: 1.111e-01, ELBO: -2.670e+05
# Cur diff delta = 119.37999725341797
# Cur diff sigma = 0.0014292094856500626
# Cur diff theta = 119.38142646290362
# ---------------------------------------
# VB, d: 100, Iter: 1-3060, s/iter: 1.204e-01, ELBO: -2.670e+05
# Cur diff delta = 119.14830017089844
# Cur diff sigma = 0.0014292111154645681
# Cur diff theta = 119.1497293820139
# ---------------------------------------
# VB, d: 100, Iter: 1-3080, s/iter: 1.216e-01, ELBO: -2.670e+05
# Cur diff delta = 118.92130279541016
# Cur diff sigma = 0.001429209834896028
# Cur diff theta = 118.92273200524505
# ---------------------------------------
# VB, d: 100, Iter: 1-3100, s/iter: 1.189e-01, ELBO: -2.670e+05
# Cur diff delta = 118.69879150390625
# Cur diff sigma = 0.0014292135601863265
# Cur diff theta = 118.70022071746644
# ---------------------------------------
# VB, d: 100, Iter: 1-3120, s/iter: 1.105e-01, ELBO: -2.670e+05
# Cur diff delta = 118.48074340820312
# Cur diff sigma = 0.001429205876775086
# Cur diff theta = 118.4821726140799
# ---------------------------------------
# VB, d: 100, Iter: 1-3140, s/iter: 1.174e-01, ELBO: -2.670e+05
# Cur diff delta = 118.26712799072266
# Cur diff sigma = 0.001429209834896028
# Cur diff theta = 118.26855720055755
# ---------------------------------------
# VB, d: 100, Iter: 1-3160, s/iter: 1.172e-01, ELBO: -2.670e+05
# Cur diff delta = 118.05793762207031
# Cur diff sigma = 0.0014292157720774412
# Cur diff theta = 118.05936683784239
# ---------------------------------------
# VB, d: 100, Iter: 1-3180, s/iter: 1.280e-01, ELBO: -2.670e+05
# Cur diff delta = 117.85292053222656
# Cur diff sigma = 0.0014292113482952118
# Cur diff theta = 117.85434974357486
# ---------------------------------------
# VB, d: 100, Iter: 1-3200, s/iter: 1.102e-01, ELBO: -2.670e+05
# Cur diff delta = 117.65167999267578
# Cur diff sigma = 0.0014292106498032808
# Cur diff theta = 117.65310920332558
# ---------------------------------------
# VB, d: 100, Iter: 1-3220, s/iter: 1.119e-01, ELBO: -2.670e+05
# Cur diff delta = 117.4541015625
# Cur diff sigma = 0.001429209834896028
# Cur diff theta = 117.4555307723349
# ---------------------------------------
# VB, d: 100, Iter: 1-3240, s/iter: 1.179e-01, ELBO: -2.669e+05
# Cur diff delta = 117.26034545898438
# Cur diff sigma = 0.0014292121632024646
# Cur diff theta = 117.26177467114758
# ---------------------------------------
# VB, d: 100, Iter: 1-3260, s/iter: 1.164e-01, ELBO: -2.669e+05
# Cur diff delta = 117.07038879394531
# Cur diff sigma = 0.001429215306416154
# Cur diff theta = 117.07181800925173
# ---------------------------------------
# VB, d: 100, Iter: 1-3280, s/iter: 1.173e-01, ELBO: -2.669e+05
# Cur diff delta = 116.88440704345703
# Cur diff sigma = 0.0014292204286903143
# Cur diff theta = 116.88583626388572
# ---------------------------------------
# VB, d: 100, Iter: 1-3300, s/iter: 1.108e-01, ELBO: -2.669e+05
# Cur diff delta = 116.70195007324219
# Cur diff sigma = 0.001429216586984694
# Cur diff theta = 116.70337928982917
# ---------------------------------------
# VB, d: 100, Iter: 1-3320, s/iter: 1.170e-01, ELBO: -2.669e+05
# Cur diff delta = 116.52289581298828
# Cur diff sigma = 0.0014292189152911305
# Cur diff theta = 116.52432503190357
# ---------------------------------------
# VB, d: 100, Iter: 1-3340, s/iter: 1.096e-01, ELBO: -2.669e+05
# Cur diff delta = 116.34673309326172
# Cur diff sigma = 0.0014292265987023711
# Cur diff theta = 116.34816231986042
# ---------------------------------------
# VB, d: 100, Iter: 1-3360, s/iter: 1.101e-01, ELBO: -2.669e+05
# Cur diff delta = 116.17367553710938
# Cur diff sigma = 0.001429220661520958
# Cur diff theta = 116.1751047577709
# ---------------------------------------
# VB, d: 100, Iter: 1-3380, s/iter: 1.231e-01, ELBO: -2.669e+05
# Cur diff delta = 116.00389862060547
# Cur diff sigma = 0.0014292234554886818
# Cur diff theta = 116.00532784406096
# ---------------------------------------
# VB, d: 100, Iter: 1-3400, s/iter: 1.141e-01, ELBO: -2.669e+05
# Cur diff delta = 115.83766174316406
# Cur diff sigma = 0.0014292217092588544
# Cur diff theta = 115.83909096487332
# ---------------------------------------
# VB, d: 100, Iter: 1-3420, s/iter: 1.117e-01, ELBO: -2.669e+05
# Cur diff delta = 115.67453002929688
# Cur diff sigma = 0.001429227297194302
# Cur diff theta = 115.67595925659407
# ---------------------------------------
# VB, d: 100, Iter: 1-3440, s/iter: 1.163e-01, ELBO: -2.669e+05
# Cur diff delta = 115.51433563232422
# Cur diff sigma = 0.001429227413609624
# Cur diff theta = 115.51576485973783
# ---------------------------------------
# VB, d: 100, Iter: 1-3460, s/iter: 1.166e-01, ELBO: -2.669e+05
# Cur diff delta = 115.35665130615234
# Cur diff sigma = 0.001429225318133831
# Cur diff theta = 115.35808053147048
# ---------------------------------------
# VB, d: 100, Iter: 1-3480, s/iter: 1.105e-01, ELBO: -2.669e+05
# Cur diff delta = 115.20165252685547
# Cur diff sigma = 0.0014292311388999224
# Cur diff theta = 115.20308175799437
# ---------------------------------------
# VB, d: 100, Iter: 1-3500, s/iter: 1.104e-01, ELBO: -2.669e+05
# Cur diff delta = 115.04956817626953
# Cur diff sigma = 0.0014292288105934858
# Cur diff theta = 115.05099740508012
# ---------------------------------------
# VB, d: 100, Iter: 1-3520, s/iter: 1.158e-01, ELBO: -2.668e+05
# Cur diff delta = 114.9005355834961
# Cur diff sigma = 0.0014292249688878655
# Cur diff theta = 114.90196480846498
# ---------------------------------------
# VB, d: 100, Iter: 1-3540, s/iter: 1.180e-01, ELBO: -2.668e+05
# Cur diff delta = 114.7540054321289
# Cur diff sigma = 0.001429226715117693
# Cur diff theta = 114.75543465884402
# ---------------------------------------
# VB, d: 100, Iter: 1-3560, s/iter: 1.115e-01, ELBO: -2.668e+05
# Cur diff delta = 114.61026000976562
# Cur diff sigma = 0.0014292269479483366
# Cur diff theta = 114.61168923671357
# ---------------------------------------
# VB, d: 100, Iter: 1-3580, s/iter: 1.135e-01, ELBO: -2.668e+05
# Cur diff delta = 114.46893310546875
# Cur diff sigma = 0.001429228694178164
# Cur diff theta = 114.47036233416293
# ---------------------------------------
# VB, d: 100, Iter: 1-3600, s/iter: 1.111e-01, ELBO: -2.668e+05
# Cur diff delta = 114.32999420166016
# Cur diff sigma = 0.001429228694178164
# Cur diff theta = 114.33142343035433
# ---------------------------------------
# VB, d: 100, Iter: 1-3620, s/iter: 1.141e-01, ELBO: -2.668e+05
# Cur diff delta = 114.19338989257812
# Cur diff sigma = 0.0014292309060692787
# Cur diff theta = 114.1948191234842
# ---------------------------------------
# VB, d: 100, Iter: 1-3640, s/iter: 1.086e-01, ELBO: -2.668e+05
# Cur diff delta = 114.05908966064453
# Cur diff sigma = 0.0014292264822870493
# Cur diff theta = 114.06051888712682
# ---------------------------------------
# VB, d: 100, Iter: 1-3660, s/iter: 1.222e-01, ELBO: -2.668e+05
# Cur diff delta = 113.92726135253906
# Cur diff sigma = 0.0014292288105934858
# Cur diff theta = 113.92869058134966
# ---------------------------------------
# VB, d: 100, Iter: 1-3680, s/iter: 1.089e-01, ELBO: -2.668e+05
# Cur diff delta = 113.797607421875
# Cur diff sigma = 0.0014292304404079914
# Cur diff theta = 113.79903665231541
# ---------------------------------------
# VB, d: 100, Iter: 1-3700, s/iter: 1.085e-01, ELBO: -2.668e+05
# Cur diff delta = 113.67036437988281
# Cur diff sigma = 0.001429227297194302
# Cur diff theta = 113.67179360718
# ---------------------------------------
# VB, d: 100, Iter: 1-3720, s/iter: 1.118e-01, ELBO: -2.668e+05
# Cur diff delta = 113.54547882080078
# Cur diff sigma = 0.0014292256673797965
# Cur diff theta = 113.54690804646816
# ---------------------------------------
# VB, d: 100, Iter: 1-3740, s/iter: 1.090e-01, ELBO: -2.668e+05
# Cur diff delta = 113.42255401611328
# Cur diff sigma = 0.0014292250853031874
# Cur diff theta = 113.42398324119858
# ---------------------------------------
# VB, d: 100, Iter: 1-3760, s/iter: 1.137e-01, ELBO: -2.668e+05
# Cur diff delta = 113.30165100097656
# Cur diff sigma = 0.0014292236883193254
# Cur diff theta = 113.30308022466488
# ---------------------------------------
# VB, d: 100, Iter: 1-3780, s/iter: 1.085e-01, ELBO: -2.668e+05
# Cur diff delta = 113.18270874023438
# Cur diff sigma = 0.0014292278792709112
# Cur diff theta = 113.18413796811365
# ---------------------------------------
# VB, d: 100, Iter: 1-3800, s/iter: 1.157e-01, ELBO: -2.668e+05
# Cur diff delta = 113.06566619873047
# Cur diff sigma = 0.001429226715117693
# Cur diff theta = 113.06709542544559
# ---------------------------------------
# VB, d: 100, Iter: 1-3820, s/iter: 1.138e-01, ELBO: -2.668e+05
# Cur diff delta = 112.95074462890625
# Cur diff sigma = 0.0014292319538071752
# Cur diff theta = 112.95217386086006
# ---------------------------------------
# VB, d: 100, Iter: 1-3840, s/iter: 1.099e-01, ELBO: -2.668e+05
# Cur diff delta = 112.83773803710938
# Cur diff sigma = 0.001429234747774899
# Cur diff theta = 112.83916727185715
# ---------------------------------------
# VB, d: 100, Iter: 1-3860, s/iter: 1.100e-01, ELBO: -2.667e+05
# Cur diff delta = 112.72657012939453
# Cur diff sigma = 0.0014292359119281173
# Cur diff theta = 112.72799936530646
# ---------------------------------------
# VB, d: 100, Iter: 1-3880, s/iter: 1.106e-01, ELBO: -2.667e+05
# Cur diff delta = 112.61727142333984
# Cur diff sigma = 0.001429232768714428
# Cur diff theta = 112.61870065610856
# ---------------------------------------
# VB, d: 100, Iter: 1-3900, s/iter: 1.087e-01, ELBO: -2.667e+05
# Cur diff delta = 112.50956726074219
# Cur diff sigma = 0.0014292364940047264
# Cur diff theta = 112.51099649723619
# ---------------------------------------
# VB, d: 100, Iter: 1-3920, s/iter: 1.084e-01, ELBO: -2.667e+05
# Cur diff delta = 112.40337371826172
# Cur diff sigma = 0.0014292355626821518
# Cur diff theta = 112.4048029538244
# ---------------------------------------
# VB, d: 100, Iter: 1-3940, s/iter: 1.113e-01, ELBO: -2.667e+05
# Cur diff delta = 112.29883575439453
# Cur diff sigma = 0.0014292350970208645
# Cur diff theta = 112.30026498949155
# ---------------------------------------
# VB, d: 100, Iter: 1-3960, s/iter: 1.163e-01, ELBO: -2.667e+05
# Cur diff delta = 112.1960678100586
# Cur diff sigma = 0.0014292350970208645
# Cur diff theta = 112.19749704515561
# ---------------------------------------
# VB, d: 100, Iter: 1-3980, s/iter: 1.192e-01, ELBO: -2.667e+05
# Cur diff delta = 112.0948257446289
# Cur diff sigma = 0.0014292335836216807
# Cur diff theta = 112.09625497821253
# ---------------------------------------
# VB, d: 100, Iter: 1-4000, s/iter: 1.136e-01, ELBO: -2.667e+05
# Cur diff delta = 111.99510192871094
# Cur diff sigma = 0.0014292350970208645
# Cur diff theta = 111.99653116380796
# ---------------------------------------
# ------------------------------------------------------
# Test = 1
# ------------------------------------------------------
# Init diff delta = 3333.0
# Init diff sigma = 38735.67578125
# Init diff theta = 42068.67578125
# VB, d: 100, Iter: 2-20, s/iter: 1.128e-01, ELBO: -3.322e+06
# Cur diff delta = 2572.05859375
# Cur diff sigma = 7183.5625
# Cur diff theta = 9755.62109375
# ---------------------------------------
# VB, d: 100, Iter: 2-40, s/iter: 1.149e-01, ELBO: -2.730e+06
# Cur diff delta = 1978.6474609375
# Cur diff sigma = 2659.65771484375
# Cur diff theta = 4638.30517578125
# ---------------------------------------
# VB, d: 100, Iter: 2-60, s/iter: 1.113e-01, ELBO: -2.115e+06
# Cur diff delta = 1498.5972900390625
# Cur diff sigma = 1314.15185546875
# Cur diff theta = 2812.7491455078125
# ---------------------------------------
# VB, d: 100, Iter: 2-80, s/iter: 1.088e-01, ELBO: -1.509e+06
# Cur diff delta = 1196.021240234375
# Cur diff sigma = 681.9569702148438
# Cur diff theta = 1877.9782104492188
# ---------------------------------------
# VB, d: 100, Iter: 2-100, s/iter: 1.116e-01, ELBO: -9.597e+05
# Cur diff delta = 1011.87841796875
# Cur diff sigma = 326.6097717285156
# Cur diff theta = 1338.4881896972656
# ---------------------------------------
# VB, d: 100, Iter: 2-120, s/iter: 1.113e-01, ELBO: -5.906e+05
# Cur diff delta = 875.6432495117188
# Cur diff sigma = 127.90396881103516
# Cur diff theta = 1003.5472183227539
# ---------------------------------------
# VB, d: 100, Iter: 2-140, s/iter: 1.103e-01, ELBO: -4.030e+05
# Cur diff delta = 776.3717041015625
# Cur diff sigma = 34.55992889404297
# Cur diff theta = 810.9316329956055
# ---------------------------------------
# VB, d: 100, Iter: 2-160, s/iter: 1.279e-01, ELBO: -3.158e+05
# Cur diff delta = 712.2974853515625
# Cur diff sigma = 3.8522961139678955
# Cur diff theta = 716.1497814655304
# ---------------------------------------
# VB, d: 100, Iter: 2-180, s/iter: 1.119e-01, ELBO: -2.808e+05
# Cur diff delta = 676.17333984375
# Cur diff sigma = 0.00754708843305707
# Cur diff theta = 676.1808869321831
# ---------------------------------------
# VB, d: 100, Iter: 2-200, s/iter: 1.112e-01, ELBO: -2.795e+05
# Cur diff delta = 654.7551879882812
# Cur diff sigma = 0.0013374745612964034
# Cur diff theta = 654.7565254628425
# ---------------------------------------
# VB, d: 100, Iter: 2-220, s/iter: 1.113e-01, ELBO: -2.791e+05
# Cur diff delta = 634.8832397460938
# Cur diff sigma = 0.0013372489484027028
# Cur diff theta = 634.8845769950422
# ---------------------------------------
# VB, d: 100, Iter: 2-240, s/iter: 1.140e-01, ELBO: -2.787e+05
# Cur diff delta = 615.7689208984375
# Cur diff sigma = 0.0013372569810599089
# Cur diff theta = 615.7702581554186
# ---------------------------------------
# VB, d: 100, Iter: 2-260, s/iter: 1.182e-01, ELBO: -2.783e+05
# Cur diff delta = 597.3819580078125
# Cur diff sigma = 0.0013372278772294521
# Cur diff theta = 597.3832952356897
# ---------------------------------------
# VB, d: 100, Iter: 2-280, s/iter: 1.161e-01, ELBO: -2.779e+05
# Cur diff delta = 579.6934814453125
# Cur diff sigma = 0.00133722263853997
# Cur diff theta = 579.694818667951
# ---------------------------------------
# VB, d: 100, Iter: 2-300, s/iter: 1.130e-01, ELBO: -2.776e+05
# Cur diff delta = 562.6756591796875
# Cur diff sigma = 0.0013372284593060613
# Cur diff theta = 562.6769964081468
# ---------------------------------------
# VB, d: 100, Iter: 2-320, s/iter: 1.146e-01, ELBO: -2.772e+05
# Cur diff delta = 546.3020629882812
# Cur diff sigma = 0.0013372001703828573
# Cur diff theta = 546.3034001884516
# ---------------------------------------
# VB, d: 100, Iter: 2-340, s/iter: 1.106e-01, ELBO: -2.769e+05
# Cur diff delta = 530.5467529296875
# Cur diff sigma = 0.0013371981913223863
# Cur diff theta = 530.5480901278788
# ---------------------------------------
# VB, d: 100, Iter: 2-360, s/iter: 1.104e-01, ELBO: -2.766e+05
# Cur diff delta = 515.3853759765625
# ...
# Cur diff delta = 115.05908203125
# Cur diff sigma = 0.001239090459421277
# Cur diff theta = 115.06032112170942
# ---------------------------------------
# VB, d: 100, Iter: 3-2580, s/iter: 1.147e-01, ELBO: -2.668e+05
# Cur diff delta = 114.76089477539062
# Cur diff sigma = 0.0012390875490382314
# Cur diff theta = 114.76213386293966
# ---------------------------------------
# VB, d: 100, Iter: 3-2600, s/iter: 1.125e-01, ELBO: -2.668e+05
# Cur diff delta = 114.4719467163086
# Cur diff sigma = 0.0012390869669616222
# Cur diff theta = 114.47318580327556
# ---------------------------------------
# VB, d: 100, Iter: 3-2620, s/iter: 1.085e-01, ELBO: -2.668e+05
# Cur diff delta = 114.19207763671875
# Cur diff sigma = 0.0012390849879011512
# Cur diff theta = 114.19331672170665
# ---------------------------------------
# VB, d: 100, Iter: 3-2640, s/iter: 1.086e-01, ELBO: -2.667e+05
# Cur diff delta = 113.92071533203125
# Cur diff sigma = 0.0012390818446874619
# Cur diff theta = 113.92195441387594
# ---------------------------------------
# VB, d: 100, Iter: 3-2660, s/iter: 1.098e-01, ELBO: -2.667e+05
# Cur diff delta = 113.65788269042969
# Cur diff sigma = 0.0012390806805342436
# Cur diff theta = 113.65912177111022
# ---------------------------------------
# VB, d: 100, Iter: 3-2680, s/iter: 1.106e-01, ELBO: -2.667e+05
# Cur diff delta = 113.40303802490234
# Cur diff sigma = 0.0012390759075060487
# Cur diff theta = 113.40427710080985
# ---------------------------------------
# VB, d: 100, Iter: 3-2700, s/iter: 1.138e-01, ELBO: -2.667e+05
# Cur diff delta = 113.1558609008789
# Cur diff sigma = 0.0012390771880745888
# Cur diff theta = 113.15709997806698
# ---------------------------------------
# VB, d: 100, Iter: 3-2720, s/iter: 1.088e-01, ELBO: -2.667e+05
# Cur diff delta = 112.91632080078125
# Cur diff sigma = 0.0012390746269375086
# Cur diff theta = 112.91755987540819
# ---------------------------------------
# VB, d: 100, Iter: 3-2740, s/iter: 1.106e-01, ELBO: -2.667e+05
# Cur diff delta = 112.68402099609375
# Cur diff sigma = 0.0012390697374939919
# Cur diff theta = 112.68526006583124
# ---------------------------------------
# VB, d: 100, Iter: 3-2760, s/iter: 1.083e-01, ELBO: -2.667e+05
# Cur diff delta = 112.45889282226562
# Cur diff sigma = 0.0012390697374939919
# Cur diff theta = 112.46013189200312
# ---------------------------------------
# VB, d: 100, Iter: 3-2780, s/iter: 1.084e-01, ELBO: -2.667e+05
# Cur diff delta = 112.2405776977539
# Cur diff sigma = 0.0012390646152198315
# Cur diff theta = 112.24181676236913
# ---------------------------------------
# VB, d: 100, Iter: 3-2800, s/iter: 1.091e-01, ELBO: -2.667e+05
# Cur diff delta = 112.02872467041016
# Cur diff sigma = 0.0012390629854053259
# Cur diff theta = 112.02996373339556
# ---------------------------------------
# VB, d: 100, Iter: 3-2820, s/iter: 1.102e-01, ELBO: -2.666e+05
# Cur diff delta = 111.82296752929688
# Cur diff sigma = 0.0012390612391754985
# Cur diff theta = 111.82420659053605
# ---------------------------------------
# VB, d: 100, Iter: 3-2840, s/iter: 1.127e-01, ELBO: -2.666e+05
# Cur diff delta = 111.62358093261719
# Cur diff sigma = 0.0012390631018206477
# Cur diff theta = 111.62481999571901
# ---------------------------------------
# VB, d: 100, Iter: 3-2860, s/iter: 1.130e-01, ELBO: -2.666e+05
# Cur diff delta = 111.42989349365234
# Cur diff sigma = 0.001239059492945671
# Cur diff theta = 111.43113255314529
# ---------------------------------------
# VB, d: 100, Iter: 3-2880, s/iter: 1.085e-01, ELBO: -2.666e+05
# Cur diff delta = 111.24190521240234
# Cur diff sigma = 0.0012390566989779472
# Cur diff theta = 111.24314426910132
# ---------------------------------------
# VB, d: 100, Iter: 3-2900, s/iter: 1.104e-01, ELBO: -2.666e+05
# Cur diff delta = 111.05956268310547
# Cur diff sigma = 0.001239058212377131
# Cur diff theta = 111.06080174131785
# ---------------------------------------
# VB, d: 100, Iter: 3-2920, s/iter: 1.094e-01, ELBO: -2.666e+05
# Cur diff delta = 110.88256072998047
# Cur diff sigma = 0.0012390549527481198
# Cur diff theta = 110.88379978493322
# ---------------------------------------
# VB, d: 100, Iter: 3-2940, s/iter: 1.167e-01, ELBO: -2.666e+05
# Cur diff delta = 110.71075439453125
# Cur diff sigma = 0.0012390502961352468
# Cur diff theta = 110.71199344482739
# ---------------------------------------
# VB, d: 100, Iter: 3-2960, s/iter: 1.110e-01, ELBO: -2.666e+05
# Cur diff delta = 110.54412841796875
# Cur diff sigma = 0.0012390522751957178
# Cur diff theta = 110.54536747024395
# ---------------------------------------
# VB, d: 100, Iter: 3-2980, s/iter: 1.087e-01, ELBO: -2.666e+05
# Cur diff delta = 110.38236999511719
# Cur diff sigma = 0.0012390546035021544
# Cur diff theta = 110.38360904972069
# ---------------------------------------
# VB, d: 100, Iter: 3-3000, s/iter: 1.147e-01, ELBO: -2.666e+05
# Cur diff delta = 110.22525024414062
# Cur diff sigma = 0.0012390516931191087
# Cur diff theta = 110.22648929583374
# ---------------------------------------
# VB, d: 100, Iter: 3-3020, s/iter: 1.085e-01, ELBO: -2.665e+05
# Cur diff delta = 110.07274627685547
# Cur diff sigma = 0.001239050761796534
# Cur diff theta = 110.07398532761727
# ---------------------------------------
# VB, d: 100, Iter: 3-3040, s/iter: 1.079e-01, ELBO: -2.665e+05
# Cur diff delta = 109.92460632324219
# Cur diff sigma = 0.0012390456395223737
# Cur diff theta = 109.92584536888171
# ---------------------------------------
# VB, d: 100, Iter: 3-3060, s/iter: 1.105e-01, ELBO: -2.665e+05
# Cur diff delta = 109.7808837890625
# Cur diff sigma = 0.0012390471529215574
# Cur diff theta = 109.78212283621542
# ---------------------------------------
# VB, d: 100, Iter: 3-3080, s/iter: 1.083e-01, ELBO: -2.665e+05
# Cur diff delta = 109.64149475097656
# Cur diff sigma = 0.0012390465708449483
# Cur diff theta = 109.64273379754741
# ---------------------------------------
# VB, d: 100, Iter: 3-3100, s/iter: 1.235e-01, ELBO: -2.665e+05
# Cur diff delta = 109.50601196289062
# Cur diff sigma = 0.001239044009707868
# Cur diff theta = 109.50725100690033
# ---------------------------------------
# VB, d: 100, Iter: 3-3120, s/iter: 1.126e-01, ELBO: -2.665e+05
# Cur diff delta = 109.37435913085938
# Cur diff sigma = 0.001239046105183661
# Cur diff theta = 109.37559817696456
# ---------------------------------------
# VB, d: 100, Iter: 3-3140, s/iter: 1.152e-01, ELBO: -2.665e+05
# Cur diff delta = 109.24642944335938
# Cur diff sigma = 0.0012390406336635351
# Cur diff theta = 109.24766848399304
# ---------------------------------------
# VB, d: 100, Iter: 3-3160, s/iter: 1.097e-01, ELBO: -2.665e+05
# Cur diff delta = 109.12229919433594
# Cur diff sigma = 0.0012390408664941788
# Cur diff theta = 109.12353823520243
# ---------------------------------------
# VB, d: 100, Iter: 3-3180, s/iter: 1.086e-01, ELBO: -2.665e+05
# Cur diff delta = 109.00182342529297
# Cur diff sigma = 0.0012390351621434093
# Cur diff theta = 109.00306246045511
# ---------------------------------------
# VB, d: 100, Iter: 3-3200, s/iter: 1.088e-01, ELBO: -2.665e+05
# Cur diff delta = 108.88484954833984
# Cur diff sigma = 0.001239039353094995
# Cur diff theta = 108.88608858769294
# ---------------------------------------
# VB, d: 100, Iter: 3-3220, s/iter: 1.086e-01, ELBO: -2.665e+05
# Cur diff delta = 108.7711181640625
# Cur diff sigma = 0.0012390395859256387
# Cur diff theta = 108.77235720364843
# ---------------------------------------
# VB, d: 100, Iter: 3-3240, s/iter: 1.099e-01, ELBO: -2.665e+05
# Cur diff delta = 108.66053771972656
# Cur diff sigma = 0.0012390402844175696
# Cur diff theta = 108.66177676001098
# ---------------------------------------
# VB, d: 100, Iter: 3-3260, s/iter: 1.128e-01, ELBO: -2.664e+05
# Cur diff delta = 108.55294036865234
# Cur diff sigma = 0.0012390384217724204
# Cur diff theta = 108.55417940707412
# ---------------------------------------
# VB, d: 100, Iter: 3-3280, s/iter: 1.116e-01, ELBO: -2.664e+05
# Cur diff delta = 108.44833374023438
# Cur diff sigma = 0.0012390370247885585
# Cur diff theta = 108.44957277725916
# ---------------------------------------
# VB, d: 100, Iter: 3-3300, s/iter: 1.085e-01, ELBO: -2.664e+05
# Cur diff delta = 108.34662628173828
# Cur diff sigma = 0.0012390374904498458
# Cur diff theta = 108.34786531922873
# ---------------------------------------
# VB, d: 100, Iter: 3-3320, s/iter: 1.088e-01, ELBO: -2.664e+05
# Cur diff delta = 108.24763488769531
# Cur diff sigma = 0.001239035977050662
# Cur diff theta = 108.24887392367236
# ---------------------------------------
# VB, d: 100, Iter: 3-3340, s/iter: 1.080e-01, ELBO: -2.664e+05
# Cur diff delta = 108.15149688720703
# Cur diff sigma = 0.0012390328338369727
# Cur diff theta = 108.15273592004087
# ---------------------------------------
# VB, d: 100, Iter: 3-3360, s/iter: 1.128e-01, ELBO: -2.664e+05
# Cur diff delta = 108.05805206298828
# Cur diff sigma = 0.0012390315532684326
# Cur diff theta = 108.05929109454155
# ---------------------------------------
# VB, d: 100, Iter: 3-3380, s/iter: 1.114e-01, ELBO: -2.664e+05
# Cur diff delta = 107.96710968017578
# Cur diff sigma = 0.0012390336487442255
# Cur diff theta = 107.96834871382453
# ---------------------------------------
# VB, d: 100, Iter: 3-3400, s/iter: 1.094e-01, ELBO: -2.664e+05
# Cur diff delta = 107.87838745117188
# Cur diff sigma = 0.0012390350457280874
# Cur diff theta = 107.8796264862176
# ---------------------------------------
# VB, d: 100, Iter: 3-3420, s/iter: 1.174e-01, ELBO: -2.664e+05
# Cur diff delta = 107.79199981689453
# Cur diff sigma = 0.0012390330666676164
# Cur diff theta = 107.7932388499612
# ---------------------------------------
# VB, d: 100, Iter: 3-3440, s/iter: 1.211e-01, ELBO: -2.664e+05
# Cur diff delta = 107.7080307006836
# Cur diff sigma = 0.0012390310876071453
# Cur diff theta = 107.7092697317712
# ---------------------------------------
# VB, d: 100, Iter: 3-3460, s/iter: 1.120e-01, ELBO: -2.664e+05
# Cur diff delta = 107.6263427734375
# Cur diff sigma = 0.0012390317860990763
# Cur diff theta = 107.6275818052236
# ---------------------------------------
# VB, d: 100, Iter: 3-3480, s/iter: 1.118e-01, ELBO: -2.664e+05
# Cur diff delta = 107.54698181152344
# Cur diff sigma = 0.0012390289921313524
# Cur diff theta = 107.54822084051557
# ---------------------------------------
# VB, d: 100, Iter: 3-3500, s/iter: 1.134e-01, ELBO: -2.664e+05
# Cur diff delta = 107.46988677978516
# Cur diff sigma = 0.0012390263145789504
# Cur diff theta = 107.47112580609974
# ---------------------------------------
# VB, d: 100, Iter: 3-3520, s/iter: 1.102e-01, ELBO: -2.664e+05
# Cur diff delta = 107.3947982788086
# Cur diff sigma = 0.0012390309711918235
# Cur diff theta = 107.39603730977979
# ---------------------------------------
# VB, d: 100, Iter: 3-3540, s/iter: 1.105e-01, ELBO: -2.663e+05
# Cur diff delta = 107.32188415527344
# Cur diff sigma = 0.0012390249175950885
# Cur diff theta = 107.32312318019103
# ---------------------------------------
# VB, d: 100, Iter: 3-3560, s/iter: 1.114e-01, ELBO: -2.663e+05
# Cur diff delta = 107.25088500976562
# Cur diff sigma = 0.001239025266841054
# Cur diff theta = 107.25212403503247
# ---------------------------------------
# VB, d: 100, Iter: 3-3580, s/iter: 1.078e-01, ELBO: -2.663e+05
# Cur diff delta = 107.18167877197266
# Cur diff sigma = 0.0012390229385346174
# Cur diff theta = 107.18291779491119
# ---------------------------------------
# VB, d: 100, Iter: 3-3600, s/iter: 1.234e-01, ELBO: -2.663e+05
# Cur diff delta = 107.11416625976562
# Cur diff sigma = 0.0012390190968289971
# Cur diff theta = 107.11540527886245
# ---------------------------------------
# VB, d: 100, Iter: 3-3620, s/iter: 1.104e-01, ELBO: -2.663e+05
# Cur diff delta = 107.04840087890625
# Cur diff sigma = 0.0012390210758894682
# Cur diff theta = 107.04963989998214
# ---------------------------------------
# VB, d: 100, Iter: 3-3640, s/iter: 1.087e-01, ELBO: -2.663e+05
# Cur diff delta = 106.98443603515625
# Cur diff sigma = 0.0012390209594741464
# Cur diff theta = 106.98567505611572
# ---------------------------------------
# VB, d: 100, Iter: 3-3660, s/iter: 1.091e-01, ELBO: -2.663e+05
# Cur diff delta = 106.92237091064453
# Cur diff sigma = 0.0012390195624902844
# Cur diff theta = 106.92360993020702
# ---------------------------------------
# VB, d: 100, Iter: 3-3680, s/iter: 1.086e-01, ELBO: -2.663e+05
# Cur diff delta = 106.8617172241211
# Cur diff sigma = 0.0012390164192765951
# Cur diff theta = 106.86295624054037
# ---------------------------------------
# VB, d: 100, Iter: 3-3700, s/iter: 1.119e-01, ELBO: -2.663e+05
# Cur diff delta = 106.80235290527344
# Cur diff sigma = 0.0012390217743813992
# Cur diff theta = 106.80359192704782
# ---------------------------------------
# VB, d: 100, Iter: 3-3720, s/iter: 1.115e-01, ELBO: -2.663e+05
# Cur diff delta = 106.7445297241211
# Cur diff sigma = 0.0012390195624902844
# Cur diff theta = 106.74576874368358
# ---------------------------------------
# VB, d: 100, Iter: 3-3740, s/iter: 1.158e-01, ELBO: -2.663e+05
# Cur diff delta = 106.68814849853516
# Cur diff sigma = 0.0012390202609822154
# Cur diff theta = 106.68938751879614
# ---------------------------------------
# VB, d: 100, Iter: 3-3760, s/iter: 1.129e-01, ELBO: -2.663e+05
# Cur diff delta = 106.63321685791016
# Cur diff sigma = 0.001239020493812859
# Cur diff theta = 106.63445587840397
# ---------------------------------------
# VB, d: 100, Iter: 3-3780, s/iter: 1.099e-01, ELBO: -2.663e+05
# Cur diff delta = 106.57978057861328
# Cur diff sigma = 0.0012390214251354337
# Cur diff theta = 106.58101960003842
# ---------------------------------------
# VB, d: 100, Iter: 3-3800, s/iter: 1.082e-01, ELBO: -2.663e+05
# Cur diff delta = 106.52789306640625
# Cur diff sigma = 0.0012390164192765951
# Cur diff theta = 106.52913208282553
# ---------------------------------------
# VB, d: 100, Iter: 3-3820, s/iter: 1.325e-01, ELBO: -2.663e+05
# Cur diff delta = 106.4771957397461
# Cur diff sigma = 0.001239013858139515
# Cur diff theta = 106.47843475360423
# ---------------------------------------
# VB, d: 100, Iter: 3-3840, s/iter: 1.114e-01, ELBO: -2.663e+05
# Cur diff delta = 106.42768096923828
# Cur diff sigma = 0.0012390157207846642
# Cur diff theta = 106.42891998495907
# ---------------------------------------
# VB, d: 100, Iter: 3-3860, s/iter: 1.150e-01, ELBO: -2.663e+05
# Cur diff delta = 106.3793716430664
# Cur diff sigma = 0.001239015138708055
# Cur diff theta = 106.38061065820511
# ---------------------------------------
# VB, d: 100, Iter: 3-3880, s/iter: 1.134e-01, ELBO: -2.663e+05
# Cur diff delta = 106.33222961425781
# Cur diff sigma = 0.0012390129268169403
# Cur diff theta = 106.33346862718463
# ---------------------------------------
# VB, d: 100, Iter: 3-3900, s/iter: 1.088e-01, ELBO: -2.663e+05
# Cur diff delta = 106.28629302978516
# Cur diff sigma = 0.001239017816260457
# Cur diff theta = 106.28753204760142
# ---------------------------------------
# VB, d: 100, Iter: 3-3920, s/iter: 1.087e-01, ELBO: -2.662e+05
# Cur diff delta = 106.24154663085938
# Cur diff sigma = 0.0012390152551233768
# Cur diff theta = 106.2427856461145
# ---------------------------------------
# VB, d: 100, Iter: 3-3940, s/iter: 1.217e-01, ELBO: -2.662e+05
# Cur diff delta = 106.1980209350586
# Cur diff sigma = 0.0012390133924782276
# Cur diff theta = 106.19925994845107
# ---------------------------------------
# VB, d: 100, Iter: 3-3960, s/iter: 1.199e-01, ELBO: -2.662e+05
# Cur diff delta = 106.15577697753906
# Cur diff sigma = 0.0012390130432322621
# Cur diff theta = 106.1570159905823
# ---------------------------------------
# VB, d: 100, Iter: 3-3980, s/iter: 1.209e-01, ELBO: -2.662e+05
# Cur diff delta = 106.11456298828125
# Cur diff sigma = 0.0012390116462484002
# Cur diff theta = 106.1158019999275
# ---------------------------------------
# VB, d: 100, Iter: 3-4000, s/iter: 1.114e-01, ELBO: -2.662e+05
# Cur diff delta = 106.07459259033203
# Cur diff sigma = 0.001239007688127458
# Cur diff theta = 106.07583159802016
# ---------------------------------------
# Model VB, test = 0, result delta diff = 111.99510192871094
# Model VB, test = 0, result sigma diff = 0.0014292346313595772
# Model VB, test = 0, result theta diff = 111.99652862548828
# Model VB, test = 1, result delta diff = 88.63661193847656
# Model VB, test = 1, result sigma diff = 0.001336310408078134
# Model VB, test = 1, result theta diff = 88.63794708251953
# Model VB, test = 2, result delta diff = 106.07460021972656
# Model VB, test = 2, result sigma diff = 0.0012390075717121363
# Model VB, test = 2, result theta diff = 106.07583618164062

# %%
diff_path = os.path.join('save', str(params['dims'][0]), 'HVAE_1_train_0.p')
with open(diff_path, 'rb') as f:
     data = pickle.load(f)
     elbo_1 = data['elbo']
     diff_delta_1 = data['diff_delta']
     diff_sigma_1 = data['diff_sigma']
     diff_1 = diff_delta_1 + diff_sigma_1

diff_path = os.path.join('save', str(params['dims'][0]), 'HVAE_2_train_0.p')
with open(diff_path, 'rb') as f:
     data = pickle.load(f)
     elbo_2 = data['elbo']
     diff_delta_2 = data['diff_delta']
     diff_sigma_2 = data['diff_sigma']
     diff_2 = diff_delta_2 + diff_sigma_2

fig, axs = plt.subplots(2, 2, figsize = (20, 10))
fig.suptitle(f"Learning HVAE,  saving epoch every = {params['save_every']}, dim = {2}")
axs[0, 0].set_xlabel("#epoch")
axs[0, 0].set_ylabel("ELBO")
axs[0, 1].set_xlabel("#epoch")
axs[0, 1].set_ylabel(r"$\|\theta_{true} - \theta_{epoch}\|^{2}$")
axs[1, 0].set_xlabel("#epoch")
axs[1, 0].set_ylabel("$\|\delta_{true} - \delta_{epoch}\|^{2}$")
axs[1, 1].set_xlabel("#epoch")
axs[1, 1].set_ylabel("$\|\Sigma_{true} - \Sigma_{epoch}\|^{2}$")
axs[0, 0].grid(True)
axs[0, 1].grid(True)
axs[1, 0].grid(True)
axs[1, 1].grid(True)
axs[0, 0].set_title('ELBO')
axs[0, 1].set_title(r'Learning $\theta$')
axs[1, 0].set_title(r'Learning $\Sigma$')
axs[1, 1].set_title(r'Learning $\delta$')
axs[0, 0].plot(elbo_1[1:], 'b', label = f"K = {params['HVAE_K_1']}")
axs[0, 0].plot(elbo_2[1:], 'r', label = f"K = {params['HVAE_K_2']}")
axs[0, 1].plot(diff_1[1:], 'b', label = f"K = {params['HVAE_K_1']}")
axs[0, 1].plot(diff_2[1:], 'r', label = f"K = {params['HVAE_K_2']}")
axs[1, 0].plot(diff_delta_1[1:], 'b', label = f"K = {params['HVAE_K_1']}")
axs[1, 0].plot(diff_delta_2[1:], 'r', label = f"K = {params['HVAE_K_2']}")
axs[1, 1].plot(diff_sigma_1[1:], 'b', label = f"K = {params['HVAE_K_1']}")
axs[1, 1].plot(diff_sigma_2[1:], 'r', label = f"K = {params['HVAE_K_2']}")
axs[0, 0].hlines(elbo_1[0], 0, len(elbo_1), 'g', label = r'$ELBO_{init}$')
axs[0, 1].hlines(diff_1[0], 0, len(diff_1), 'g', label = r'$\|\theta_{true} - \theta_{init}\|^{2}$')
axs[1, 0].hlines(diff_delta_1[0], 0, len(diff_delta_1), 'g', label = r'$\|\delta_{true} - \delta_{init}\|^{2}$')
axs[1, 1].hlines(diff_sigma_1[0], 0, len(diff_sigma_1), 'g', label = r'$\|\Sigma_{true} - \Sigma_{init}\|^{2}$')
axs[0, 0].legend()
axs[0, 1].legend()
axs[1, 0].legend()
axs[1, 1].legend()
axs[0, 1].set_yscale('log')
#axs[1, 0].set_yscale('log')
axs[1, 1].set_yscale('log')
plt.show()
print(f"Init ELBO = {elbo_1[0]}, HVAE-1: result ELBO = {elbo_1[-1]}, HVAE-2: result ELBO = {elbo_2[-1]}")
print(f"Init diff theta = {diff_1[0]}, HVAE-1: result diff theta = {diff_1[-1]}, HVAE-2: result diff theta = {diff_2[-1]}")
print(f"Init diff delta = {diff_delta_1[0]}, HVAE-1: result diff delta = {diff_delta_1[-1]}, HVAE-2: result diff theta = {diff_delta_2[-1]}")
print(f"Init diff sigma = {diff_sigma_1[0]}, HVAE-1: result diff sigma = {diff_sigma_1[-1]}, HVAE-2: result diff theta = {diff_sigma_2[-1]}")
# Out:
# Init ELBO = 3451927.25, HVAE-1: result ELBO = 1.5897790247501562e+19, HVAE-2: result ELBO = 1.414364039166401e+19
# Init diff theta = 728.5354614257812, HVAE-1: result diff theta = 4.0963239669799805, HVAE-2: result diff theta = 2.3503165245056152
# Init diff delta = 0.020000001415610313, HVAE-1: result diff delta = 2.0978832244873047, HVAE-2: result diff theta = 0.35197341442108154
# Init diff sigma = 728.5154418945312, HVAE-1: result diff sigma = 1.9984408617019653, HVAE-2: result diff theta = 1.9983429908752441

# %%
diff_path = os.path.join('save', str(params['dims'][0]), 'NF_1_train_0.p')
with open(diff_path, 'rb') as f:
     data = pickle.load(f)
     elbo_1 = data['elbo']
     diff_delta_1 = data['diff_delta']
     diff_sigma_1 = data['diff_sigma']
     diff_1 = diff_delta_1 + diff_sigma_1

diff_path = os.path.join('save', str(params['dims'][0]), 'NF_2_train_0.p')
with open(diff_path, 'rb') as f:
     data = pickle.load(f)
     elbo_2 = data['elbo']
     diff_delta_2 = data['diff_delta']
     diff_sigma_2 = data['diff_sigma']
     diff_2 = diff_delta_2 + diff_sigma_2

fig, axs = plt.subplots(2, 2, figsize = (20, 10))
fig.suptitle(f"Learning NF,  saving epoch every = {params['save_every']}, dim = {2}")
axs[0, 0].set_xlabel("#epoch")
axs[0, 0].set_ylabel("ELBO")
axs[0, 1].set_xlabel("#epoch")
axs[0, 1].set_ylabel(r"$\|\theta_{true} - \theta_{epoch}\|^{2}$")
axs[1, 0].set_xlabel("#epoch")
axs[1, 0].set_ylabel("$\|\delta_{true} - \delta_{epoch}\|^{2}$")
axs[1, 1].set_xlabel("#epoch")
axs[1, 1].set_ylabel("$\|\Sigma_{true} - \Sigma_{epoch}\|^{2}$")
axs[0, 0].grid(True)
axs[0, 1].grid(True)
axs[1, 0].grid(True)
axs[1, 1].grid(True)
axs[0, 0].set_title('ELBO')
axs[0, 1].set_title(r'Learning $\theta$')
axs[1, 0].set_title(r'Learning $\Sigma$')
axs[1, 1].set_title(r'Learning $\delta$')
axs[0, 0].plot(elbo_1[1:], 'b', label = f"K = {params['NF_K_1']}")
axs[0, 0].plot(elbo_2[1:], 'r', label = f"K = {params['NF_K_2']}")
axs[0, 1].plot(diff_1[1:], 'b', label = f"K = {params['NF_K_1']}")
axs[0, 1].plot(diff_2[1:], 'r', label = f"K = {params['NF_K_2']}")
axs[1, 0].plot(diff_delta_1[1:], 'b', label = f"K = {params['NF_K_1']}")
axs[1, 0].plot(diff_delta_2[1:], 'r', label = f"K = {params['NF_K_2']}")
axs[1, 1].plot(diff_sigma_1[1:], 'b', label = f"K = {params['NF_K_1']}")
axs[1, 1].plot(diff_sigma_2[1:], 'r', label = f"K = {params['NF_K_2']}")
axs[0, 0].hlines(elbo_1[0], 0, len(elbo_1), 'g', label = r'$ELBO_{init}$')
axs[0, 1].hlines(diff_1[0], 0, len(diff_1), 'g', label = r'$\|\theta_{true} - \theta_{init}\|^{2}$')
axs[1, 0].hlines(diff_delta_1[0], 0, len(diff_delta_1), 'g', label = r'$\|\delta_{true} - \delta_{init}\|^{2}$')
axs[1, 1].hlines(diff_sigma_1[0], 0, len(diff_sigma_1), 'g', label = r'$\|\Sigma_{true} - \Sigma_{init}\|^{2}$')
axs[0, 0].legend()
axs[0, 1].legend()
axs[1, 0].legend()
axs[1, 1].legend()
axs[0, 1].set_yscale('log')
#axs[1, 0].set_yscale('log')
axs[1, 1].set_yscale('log')
plt.show()
print(f"Init ELBO = {elbo_1[0]}, NF-1: result ELBO = {elbo_1[-1]}, NF-2: result ELBO = {elbo_2[-1]}")
print(f"Init diff theta = {diff_1[0]}, NFE-1: result diff theta = {diff_1[-1]}, NF-2: result diff theta = {diff_2[-1]}")
print(f"Init diff delta = {diff_delta_1[0]}, NF-1: result diff delta = {diff_delta_1[-1]}, NF-2: result diff theta = {diff_delta_2[-1]}")
print(f"Init diff sigma = {diff_sigma_1[0]}, NF-1: result diff sigma = {diff_sigma_1[-1]}, NF-2: result diff theta = {diff_sigma_2[-1]}")
# Out:
# Init ELBO = -78584.90625, NF-1: result ELBO = -38951.34765625, NF-2: result ELBO = -37631.43359375
# Init diff theta = 728.5354614257812, NFE-1: result diff theta = 6.155850410461426, NF-2: result diff theta = 6.186968803405762
# Init diff delta = 0.020000001415610313, NF-1: result diff delta = 5.5262322425842285, NF-2: result diff theta = 5.53543758392334
# Init diff sigma = 728.5154418945312, NF-1: result diff sigma = 0.6296179294586182, NF-2: result diff theta = 0.6515311598777771

# %%
def run_test(d, params, 
             batch_size=256,
             clip_value=None,
             dtype=torch.float32, 
             device=torch.device("cpu")):
    """ 
    Run the gaussian test with dimension d 
    """

    ######### Problem Specification

    # Data generation parameters
    prior_mu_z = torch.zeros(d, dtype=dtype)    # Prior mean
    prior_sigma_z = torch.eye(d, dtype=dtype)   # Prior covariance matrix

    # True model parameters
    num_range = torch.arange(-(d-1)/2, (d+1)/2, dtype=dtype)

    t_delta =  num_range / 5 

    print(f"true delta = {t_delta.numpy()}")

    if d == 1:
        t_sigma = torch.ones(1, dtype=dtype)
    else: 
        # Allow sigma to range from 0.1 to 1
        t_sigma = 36/(10*(d-1)**2) * num_range**2 + 0.1 
    print(f"true sigma = {t_sigma.numpy()}")

    ######### Variable Initialization

    # Initial model parameters - same across all methods
    init_delta = prior_mu_z.clone().to(device)
    init_log_sigma = 3 * torch.ones(d).to(device)

    # Initial HVAE variational parameters
    init_T = torch.tensor(5., dtype=dtype, device=device)
    init_eps = 0.005 * torch.ones(d, dtype=dtype)
    max_eps = params['max_eps'] * torch.ones(d, dtype=dtype)
    init_logit_eps = torch.log(init_eps/(max_eps - init_eps)).to(device)
    init_log_T_0 = torch.log(init_T - 1)

    # Initial NF variational parameters
    init_u_pre_reparam = torch.tensor(scipy.stats.truncnorm.rvs(-2, 2, 
                                                                scale=0.1, 
                                                                size=d),
                                      dtype=dtype, device=device)
    init_w = torch.tensor(scipy.stats.truncnorm.rvs(-2, 2, scale=0.1, size=d),
                          dtype=dtype, device=device)
    init_b = torch.tensor(0.1, dtype=dtype, device=device)

    # Initial VAE parameters
    init_mu_z = prior_mu_z.clone()
    init_log_sigma_z = torch.ones(d, dtype=dtype)

    ######### Set up models
    init_params = [[init_delta, init_log_sigma, init_logit_eps],
                   [init_delta, init_log_sigma, init_logit_eps]]
    
    HVAE_model_notemp_1 = HVAE(params,
        ['delta', 'log_sigma', 'logit_eps'],
        init_params[0], 
        'HVAE_notemp_1', d, params['HVAE_K_1'])
    HVAE_model_notemp_2 = HVAE(params,
        ['delta', 'log_sigma', 'logit_eps'], 
        init_params[1],
        'HVAE_notemp_2', d, params['HVAE_K_2'])

    #model_list = [HVAE_model_1, HVAE_model_2, NF_model_1]
    #model_list = [HVAE_model_1, NF_model_1]
    model_list = [HVAE_model_notemp_1, HVAE_model_notemp_2]

    print("Models were initialized!")
    
    ######### Generate Training Data & Save - One for each test

    train_data_list = []

    for i in range(params['n_tests']):
        z = MultivariateNormal(prior_mu_z, prior_sigma_z).sample()
        x = MultivariateNormal(z + t_delta, 
                               torch.diag(t_sigma**2)).sample([params['n_data']])
        x = x.to(device)
        train_data_list.append(x)

    # Folder should have already been created in the initializations
    data_path = os.path.join('save', str(d), 'train_data.p')
    pickle.dump(train_data_list, open(data_path, 'wb')) 

    # Store the final parameter values for all test runs in this dictionary
    final_params = {}

    for i in range(len(model_list)):
        final_values = []
        m = model_list[i]
        model_init_params = init_params[i]

        for j in range(params['n_tests']):
            print("------------------------------------------------------")
            print(f"Test = {j}")
            print("------------------------------------------------------")
            m._reinitialize(model_init_params)
            gaussian_data = gaussian_dataset(train_data_list[j])
            train_dataloader = DataLoader(gaussian_data, batch_size=batch_size,
                                          shuffle=False, num_workers=0)
            (delta, sigma) = m.train(train_dataloader, j, 
                                     t_delta, t_sigma,
                                     clip_value)
            final_values.append((delta, sigma))

        final_params[m.model_name] = final_values.copy()

    ######### Test models using difference between parameters

    param_diffs = {}

    for m in model_list:
        
        diffs = []

        for i in range(params['n_tests']):
            delta = final_params[m.model_name][i][0]
            sigma = final_params[m.model_name][i][1]

            delta_diff = np.sum((delta - t_delta.numpy())**2)
            sigma_diff = np.sum((sigma - t_sigma.numpy())**2)
            theta_diff = delta_diff + sigma_diff
            print(f"Model {m.model_name}, test = {i}, result delta diff = {delta_diff}")
            print(f"Model {m.model_name}, test = {i}, result sigma diff = {sigma_diff}")
            print(f"Model {m.model_name}, test = {i}, result theta diff = {theta_diff}")

            diffs.append((delta_diff, sigma_diff, theta_diff))

        param_diffs[m.model_name] = diffs.copy()

    # Save parameter differences in a pickle file
    diff_path = os.path.join('save', str(d), 'all_diffs.p')
    pickle.dump(param_diffs, open(diff_path, 'wb'))

# %%
device = torch.device("cuda")
dtype = torch.float32
clip_value = None
batch_size = 256

# %%
params = {

    # PROBLEM SPECIFICATION
    #'dims': [1, 2, 3, 5, 11, 25, 51, 101, 201, 301], # Dimensions to test
    'dims': [100],
    'n_data': 10000,                                 # Number of data points

    # TEST HYPERPARAMETERS
    'n_tests': 3,      # Number of experiments to run

    # GLOBAL OPTIMIZATION PARAMETERS
    'n_iter': 2000,    # Number of optimization iterations
    'n_batch': 10,      # Number of points for ELBO estimate
    'rms_eta': 0.001,   # Stepsize for RMSProp
    'save_every': 20,   # Save parameter information every so often
    'print_every': 20, # Print less often than save

    # HVAE HYPERPARAMETERS
    'HVAE_K_1': 1,    # Number of leapfrog/cooling steps for HVAE flow 1
    'HVAE_K_2': 10,   # Number of leapfrog/cooling steps for HVAE flow 2
    'max_eps': 0.5,   # Maximum leapfrog step size per dimension 

    # NF HYPERPARAMETERS
    'NF_K_1': 1,    # Number of flow steps for NF flow 1
    'NF_K_2': 30,   # Number of flow steps for NF flow 2
    
}

# %%
dims = params['dims']
seed = 12345
np.random.seed(seed)
torch.manual_seed(seed)
for d in dims:
    print('**** Running test for d={0:d} ****'.format(d))
    run_test(d, params, batch_size, clip_value, dtype, device)
# Out:
# **** Running test for d=100 ****
# true delta = [-9.9 -9.7 -9.5 -9.3 -9.1 -8.9 -8.7 -8.5 -8.3 -8.1 -7.9 -7.7 -7.5 -7.3
#  -7.1 -6.9 -6.7 -6.5 -6.3 -6.1 -5.9 -5.7 -5.5 -5.3 -5.1 -4.9 -4.7 -4.5
#  -4.3 -4.1 -3.9 -3.7 -3.5 -3.3 -3.1 -2.9 -2.7 -2.5 -2.3 -2.1 -1.9 -1.7
#  -1.5 -1.3 -1.1 -0.9 -0.7 -0.5 -0.3 -0.1  0.1  0.3  0.5  0.7  0.9  1.1
#   1.3  1.5  1.7  1.9  2.1  2.3  2.5  2.7  2.9  3.1  3.3  3.5  3.7  3.9
#   4.1  4.3  4.5  4.7  4.9  5.1  5.3  5.5  5.7  5.9  6.1  6.3  6.5  6.7
#   6.9  7.1  7.3  7.5  7.7  7.9  8.1  8.3  8.5  8.7  8.9  9.1  9.3  9.5
#   9.7  9.9]
# true sigma = [1.         0.9640037  0.928742   0.8942149  0.86042243 0.82736456
#  0.7950414  0.76345277 0.7325987  0.70247936 0.67309463 0.64444447
#  0.6165289  0.589348   0.56290174 0.5371901  0.51221305 0.48797062
#  0.46446282 0.4416896  0.41965106 0.3983471  0.37777779 0.35794306
#  0.338843   0.32047752 0.30284664 0.28595042 0.2697888  0.2543618
#  0.23966941 0.22571167 0.21248853 0.2        0.1882461  0.17722681
#  0.16694215 0.1573921  0.14857668 0.14049587 0.13314968 0.12653811
#  0.12066115 0.11551882 0.11111111 0.10743802 0.10449954 0.10229568
#  0.10082645 0.10009183 0.10009183 0.10082645 0.10229568 0.10449954
#  0.10743802 0.11111111 0.11551882 0.12066115 0.12653811 0.13314968
#  0.14049587 0.14857668 0.1573921  0.16694215 0.17722681 0.1882461
#  0.2        0.21248853 0.22571167 0.23966941 0.2543618  0.2697888
#  0.28595042 0.30284664 0.32047752 0.338843   0.35794306 0.37777779
#  0.3983471  0.41965106 0.4416896  0.46446282 0.48797062 0.51221305
#  0.5371901  0.56290174 0.589348   0.6165289  0.64444447 0.67309463
#  0.70247936 0.7325987  0.76345277 0.7950414  0.82736456 0.86042243
#  0.8942149  0.928742   0.9640037  1.        ]
# Models were initialized!
# ------------------------------------------------------
# Test = 0
# ------------------------------------------------------
# Init diff delta = 3333.0
# Init diff sigma = 38735.67578125
# Init diff theta = 42068.67578125
# HVAE_notemp_1, d: 100, Iter: 1-20, s/iter: 1.459e-01, ELBO: -3.230e+06
# Cur diff delta = 2421.517333984375
# Cur diff sigma = 6427.921875
# Cur diff theta = 8849.439208984375
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-40, s/iter: 1.457e-01, ELBO: -2.755e+06
# Cur diff delta = 1801.947021484375
# Cur diff sigma = 2190.22119140625
# Cur diff theta = 3992.168212890625
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-60, s/iter: 1.499e-01, ELBO: -2.382e+06
# Cur diff delta = 1325.7742919921875
# Cur diff sigma = 1275.8236083984375
# Cur diff theta = 2601.597900390625
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-80, s/iter: 1.534e-01, ELBO: -2.146e+06
# Cur diff delta = 951.0816650390625
# Cur diff sigma = 867.3684692382812
# Cur diff theta = 1818.4501342773438
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-100, s/iter: 1.445e-01, ELBO: -1.752e+06
# Cur diff delta = 661.8220825195312
# Cur diff sigma = 537.7841796875
# Cur diff theta = 1199.6062622070312
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-120, s/iter: 1.423e-01, ELBO: -1.542e+06
# Cur diff delta = 443.9256591796875
# Cur diff sigma = 263.544677734375
# Cur diff theta = 707.4703369140625
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-140, s/iter: 1.434e-01, ELBO: -1.400e+06
# Cur diff delta = 291.5368957519531
# Cur diff sigma = 120.6916732788086
# Cur diff theta = 412.2285690307617
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-160, s/iter: 1.419e-01, ELBO: -1.309e+06
# Cur diff delta = 193.31150817871094
# Cur diff sigma = 62.159637451171875
# Cur diff theta = 255.4711456298828
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-180, s/iter: 1.425e-01, ELBO: -1.253e+06
# Cur diff delta = 136.2911376953125
# Cur diff sigma = 39.59980010986328
# Cur diff theta = 175.89093780517578
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-200, s/iter: 1.647e-01, ELBO: -1.213e+06
# Cur diff delta = 105.26002502441406
# Cur diff sigma = 27.951416015625
# Cur diff theta = 133.21144104003906
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-220, s/iter: 1.531e-01, ELBO: -1.190e+06
# Cur diff delta = 92.4337158203125
# Cur diff sigma = 21.6019287109375
# Cur diff theta = 114.03564453125
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-240, s/iter: 1.427e-01, ELBO: -1.175e+06
# Cur diff delta = 91.43131256103516
# Cur diff sigma = 18.33990478515625
# Cur diff theta = 109.7712173461914
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-260, s/iter: 1.453e-01, ELBO: -1.171e+06
# Cur diff delta = 94.72931671142578
# Cur diff sigma = 16.871286392211914
# Cur diff theta = 111.6006031036377
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-280, s/iter: 1.452e-01, ELBO: -1.170e+06
# Cur diff delta = 99.91545104980469
# Cur diff sigma = 16.264312744140625
# Cur diff theta = 116.17976379394531
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-300, s/iter: 1.463e-01, ELBO: -1.170e+06
# Cur diff delta = 103.524169921875
# Cur diff sigma = 16.09371566772461
# Cur diff theta = 119.61788558959961
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-320, s/iter: 1.457e-01, ELBO: -1.164e+06
# Cur diff delta = 106.35197448730469
# Cur diff sigma = 16.09278678894043
# Cur diff theta = 122.44476127624512
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-340, s/iter: 1.542e-01, ELBO: -1.168e+06
# Cur diff delta = 106.26494598388672
# Cur diff sigma = 16.078994750976562
# Cur diff theta = 122.34394073486328
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-360, s/iter: 1.427e-01, ELBO: -1.165e+06
# Cur diff delta = 106.4926986694336
# Cur diff sigma = 16.114900588989258
# Cur diff theta = 122.60759925842285
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-380, s/iter: 1.425e-01, ELBO: -1.169e+06
# Cur diff delta = 106.34422302246094
# Cur diff sigma = 16.14631462097168
# Cur diff theta = 122.49053764343262
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-400, s/iter: 1.459e-01, ELBO: -1.167e+06
# Cur diff delta = 106.60147857666016
# Cur diff sigma = 16.108083724975586
# Cur diff theta = 122.70956230163574
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-420, s/iter: 1.502e-01, ELBO: -1.170e+06
# Cur diff delta = 106.31837463378906
# Cur diff sigma = 16.13484001159668
# Cur diff theta = 122.45321464538574
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-440, s/iter: 1.491e-01, ELBO: -1.168e+06
# Cur diff delta = 106.1615219116211
# Cur diff sigma = 16.095008850097656
# Cur diff theta = 122.25653076171875
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-460, s/iter: 1.572e-01, ELBO: -1.163e+06
# Cur diff delta = 106.7634048461914
# Cur diff sigma = 16.06337547302246
# Cur diff theta = 122.82678031921387
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-480, s/iter: 1.491e-01, ELBO: -1.161e+06
# Cur diff delta = 106.73663330078125
# Cur diff sigma = 16.117673873901367
# Cur diff theta = 122.85430717468262
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-500, s/iter: 1.598e-01, ELBO: -1.162e+06
# Cur diff delta = 106.44844818115234
# Cur diff sigma = 16.014497756958008
# Cur diff theta = 122.46294593811035
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-520, s/iter: 1.425e-01, ELBO: -1.171e+06
# Cur diff delta = 106.37052154541016
# Cur diff sigma = 16.172046661376953
# Cur diff theta = 122.54256820678711
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-540, s/iter: 1.462e-01, ELBO: -1.168e+06
# Cur diff delta = 106.45830535888672
# Cur diff sigma = 16.09196662902832
# Cur diff theta = 122.55027198791504
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-560, s/iter: 1.536e-01, ELBO: -1.163e+06
# Cur diff delta = 106.72689056396484
# Cur diff sigma = 16.120220184326172
# Cur diff theta = 122.84711074829102
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-580, s/iter: 1.450e-01, ELBO: -1.167e+06
# Cur diff delta = 106.44583892822266
# Cur diff sigma = 16.0839786529541
# Cur diff theta = 122.52981758117676
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-600, s/iter: 1.528e-01, ELBO: -1.169e+06
# Cur diff delta = 106.46668243408203
# Cur diff sigma = 16.18185806274414
# Cur diff theta = 122.64854049682617
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-620, s/iter: 1.488e-01, ELBO: -1.170e+06
# Cur diff delta = 106.35977172851562
# Cur diff sigma = 16.10616111755371
# Cur diff theta = 122.46593284606934
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-640, s/iter: 1.441e-01, ELBO: -1.161e+06
# Cur diff delta = 106.35128784179688
# Cur diff sigma = 16.033695220947266
# Cur diff theta = 122.38498306274414
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-660, s/iter: 1.429e-01, ELBO: -1.163e+06
# Cur diff delta = 106.50277709960938
# Cur diff sigma = 16.05702781677246
# Cur diff theta = 122.55980491638184
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-680, s/iter: 1.423e-01, ELBO: -1.169e+06
# Cur diff delta = 106.06417846679688
# Cur diff sigma = 16.087629318237305
# Cur diff theta = 122.15180778503418
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-700, s/iter: 1.449e-01, ELBO: -1.167e+06
# Cur diff delta = 106.48517608642578
# Cur diff sigma = 16.0899658203125
# Cur diff theta = 122.57514190673828
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-720, s/iter: 1.435e-01, ELBO: -1.169e+06
# Cur diff delta = 106.72749328613281
# Cur diff sigma = 16.128684997558594
# Cur diff theta = 122.8561782836914
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-740, s/iter: 1.527e-01, ELBO: -1.166e+06
# Cur diff delta = 106.6369857788086
# Cur diff sigma = 16.086214065551758
# Cur diff theta = 122.72319984436035
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-760, s/iter: 1.544e-01, ELBO: -1.164e+06
# Cur diff delta = 106.53321075439453
# Cur diff sigma = 16.10919189453125
# Cur diff theta = 122.64240264892578
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-780, s/iter: 1.460e-01, ELBO: -1.173e+06
# Cur diff delta = 106.97712707519531
# Cur diff sigma = 16.1678466796875
# Cur diff theta = 123.14497375488281
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-800, s/iter: 1.465e-01, ELBO: -1.170e+06
# Cur diff delta = 106.39189147949219
# Cur diff sigma = 16.177553176879883
# Cur diff theta = 122.56944465637207
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-820, s/iter: 1.428e-01, ELBO: -1.166e+06
# Cur diff delta = 106.99275970458984
# Cur diff sigma = 16.083980560302734
# Cur diff theta = 123.07674026489258
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-840, s/iter: 1.437e-01, ELBO: -1.171e+06
# Cur diff delta = 106.27273559570312
# Cur diff sigma = 16.10795783996582
# Cur diff theta = 122.38069343566895
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-860, s/iter: 1.493e-01, ELBO: -1.164e+06
# Cur diff delta = 106.26030731201172
# Cur diff sigma = 16.023542404174805
# Cur diff theta = 122.28384971618652
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-880, s/iter: 1.554e-01, ELBO: -1.166e+06
# Cur diff delta = 106.04570770263672
# Cur diff sigma = 16.051822662353516
# Cur diff theta = 122.09753036499023
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-900, s/iter: 1.429e-01, ELBO: -1.166e+06
# Cur diff delta = 106.1297836303711
# Cur diff sigma = 16.05380630493164
# Cur diff theta = 122.18358993530273
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-920, s/iter: 1.570e-01, ELBO: -1.166e+06
# Cur diff delta = 106.51968383789062
# Cur diff sigma = 16.057262420654297
# Cur diff theta = 122.57694625854492
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-940, s/iter: 1.427e-01, ELBO: -1.167e+06
# Cur diff delta = 106.40634155273438
# Cur diff sigma = 16.125518798828125
# Cur diff theta = 122.5318603515625
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-960, s/iter: 1.570e-01, ELBO: -1.171e+06
# Cur diff delta = 106.60423278808594
# Cur diff sigma = 16.072872161865234
# Cur diff theta = 122.67710494995117
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-980, s/iter: 1.483e-01, ELBO: -1.166e+06
# Cur diff delta = 106.2522201538086
# Cur diff sigma = 16.10077667236328
# Cur diff theta = 122.35299682617188
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1000, s/iter: 1.483e-01, ELBO: -1.162e+06
# Cur diff delta = 106.16929626464844
# Cur diff sigma = 16.131038665771484
# Cur diff theta = 122.30033493041992
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1020, s/iter: 1.485e-01, ELBO: -1.167e+06
# Cur diff delta = 106.28915405273438
# Cur diff sigma = 16.10881996154785
# Cur diff theta = 122.39797401428223
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1040, s/iter: 1.428e-01, ELBO: -1.166e+06
# Cur diff delta = 106.6524658203125
# Cur diff sigma = 16.04450035095215
# Cur diff theta = 122.69696617126465
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1060, s/iter: 1.446e-01, ELBO: -1.160e+06
# Cur diff delta = 106.4171371459961
# Cur diff sigma = 15.983657836914062
# Cur diff theta = 122.40079498291016
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1080, s/iter: 1.428e-01, ELBO: -1.166e+06
# Cur diff delta = 106.44811248779297
# Cur diff sigma = 16.013246536254883
# Cur diff theta = 122.46135902404785
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1100, s/iter: 1.459e-01, ELBO: -1.160e+06
# Cur diff delta = 106.38724517822266
# Cur diff sigma = 16.094768524169922
# Cur diff theta = 122.48201370239258
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1120, s/iter: 1.502e-01, ELBO: -1.166e+06
# Cur diff delta = 106.3803939819336
# Cur diff sigma = 16.063720703125
# Cur diff theta = 122.4441146850586
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1140, s/iter: 1.448e-01, ELBO: -1.170e+06
# Cur diff delta = 105.93103790283203
# Cur diff sigma = 16.08551788330078
# Cur diff theta = 122.01655578613281
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1160, s/iter: 1.515e-01, ELBO: -1.163e+06
# Cur diff delta = 106.62088012695312
# Cur diff sigma = 16.01418113708496
# Cur diff theta = 122.63506126403809
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1180, s/iter: 1.474e-01, ELBO: -1.163e+06
# Cur diff delta = 106.8276138305664
# Cur diff sigma = 16.05027198791504
# Cur diff theta = 122.87788581848145
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1200, s/iter: 1.435e-01, ELBO: -1.166e+06
# Cur diff delta = 106.60366821289062
# Cur diff sigma = 16.126482009887695
# Cur diff theta = 122.73015022277832
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1220, s/iter: 1.442e-01, ELBO: -1.167e+06
# Cur diff delta = 106.67670440673828
# Cur diff sigma = 16.12703514099121
# Cur diff theta = 122.80373954772949
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1240, s/iter: 1.502e-01, ELBO: -1.165e+06
# Cur diff delta = 106.43643951416016
# Cur diff sigma = 16.039321899414062
# Cur diff theta = 122.47576141357422
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1260, s/iter: 1.512e-01, ELBO: -1.165e+06
# Cur diff delta = 106.31415557861328
# Cur diff sigma = 16.132949829101562
# Cur diff theta = 122.44710540771484
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1280, s/iter: 1.503e-01, ELBO: -1.167e+06
# Cur diff delta = 106.58621978759766
# Cur diff sigma = 16.11366844177246
# Cur diff theta = 122.69988822937012
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1300, s/iter: 1.513e-01, ELBO: -1.168e+06
# Cur diff delta = 106.14244842529297
# Cur diff sigma = 16.126251220703125
# Cur diff theta = 122.2686996459961
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1320, s/iter: 1.453e-01, ELBO: -1.164e+06
# Cur diff delta = 106.89035034179688
# Cur diff sigma = 16.02910804748535
# Cur diff theta = 122.91945838928223
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1340, s/iter: 1.500e-01, ELBO: -1.163e+06
# Cur diff delta = 106.72314453125
# Cur diff sigma = 16.040815353393555
# Cur diff theta = 122.76395988464355
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1360, s/iter: 1.426e-01, ELBO: -1.168e+06
# Cur diff delta = 106.52005004882812
# Cur diff sigma = 16.099510192871094
# Cur diff theta = 122.61956024169922
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1380, s/iter: 1.481e-01, ELBO: -1.170e+06
# Cur diff delta = 106.78761291503906
# Cur diff sigma = 16.13087272644043
# Cur diff theta = 122.91848564147949
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1400, s/iter: 1.422e-01, ELBO: -1.165e+06
# Cur diff delta = 106.90267944335938
# Cur diff sigma = 16.00925636291504
# Cur diff theta = 122.91193580627441
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1420, s/iter: 1.566e-01, ELBO: -1.165e+06
# Cur diff delta = 106.48107147216797
# Cur diff sigma = 16.072307586669922
# Cur diff theta = 122.55337905883789
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1440, s/iter: 1.633e-01, ELBO: -1.166e+06
# Cur diff delta = 106.55728149414062
# Cur diff sigma = 16.0755672454834
# Cur diff theta = 122.63284873962402
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1460, s/iter: 1.617e-01, ELBO: -1.166e+06
# Cur diff delta = 106.77958679199219
# Cur diff sigma = 16.04155158996582
# Cur diff theta = 122.82113838195801
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1480, s/iter: 1.438e-01, ELBO: -1.170e+06
# Cur diff delta = 106.43042755126953
# Cur diff sigma = 16.124353408813477
# Cur diff theta = 122.55478096008301
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1500, s/iter: 1.424e-01, ELBO: -1.165e+06
# Cur diff delta = 106.29072570800781
# Cur diff sigma = 16.091875076293945
# Cur diff theta = 122.38260078430176
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1520, s/iter: 1.528e-01, ELBO: -1.168e+06
# Cur diff delta = 106.73941040039062
# Cur diff sigma = 16.068038940429688
# Cur diff theta = 122.80744934082031
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1540, s/iter: 1.431e-01, ELBO: -1.167e+06
# Cur diff delta = 107.05121612548828
# Cur diff sigma = 16.085718154907227
# Cur diff theta = 123.13693428039551
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1560, s/iter: 1.491e-01, ELBO: -1.164e+06
# Cur diff delta = 106.38410186767578
# Cur diff sigma = 16.096446990966797
# Cur diff theta = 122.48054885864258
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1580, s/iter: 1.426e-01, ELBO: -1.164e+06
# Cur diff delta = 106.01729583740234
# Cur diff sigma = 16.155170440673828
# Cur diff theta = 122.17246627807617
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1600, s/iter: 1.422e-01, ELBO: -1.167e+06
# Cur diff delta = 106.49351501464844
# Cur diff sigma = 16.13116455078125
# Cur diff theta = 122.62467956542969
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1620, s/iter: 1.474e-01, ELBO: -1.166e+06
# Cur diff delta = 106.57683563232422
# Cur diff sigma = 16.074628829956055
# Cur diff theta = 122.65146446228027
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1640, s/iter: 1.426e-01, ELBO: -1.165e+06
# Cur diff delta = 105.51609802246094
# Cur diff sigma = 16.047250747680664
# Cur diff theta = 121.5633487701416
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1660, s/iter: 1.430e-01, ELBO: -1.168e+06
# Cur diff delta = 106.14037322998047
# Cur diff sigma = 16.001224517822266
# Cur diff theta = 122.14159774780273
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1680, s/iter: 1.446e-01, ELBO: -1.165e+06
# Cur diff delta = 106.0386734008789
# Cur diff sigma = 16.06007194519043
# Cur diff theta = 122.09874534606934
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1700, s/iter: 1.599e-01, ELBO: -1.168e+06
# Cur diff delta = 106.41668701171875
# Cur diff sigma = 16.069982528686523
# Cur diff theta = 122.48666954040527
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1720, s/iter: 1.516e-01, ELBO: -1.165e+06
# Cur diff delta = 106.29143524169922
# Cur diff sigma = 16.11153793334961
# Cur diff theta = 122.40297317504883
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1740, s/iter: 1.423e-01, ELBO: -1.170e+06
# Cur diff delta = 106.76544189453125
# Cur diff sigma = 16.151912689208984
# Cur diff theta = 122.91735458374023
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1760, s/iter: 1.443e-01, ELBO: -1.167e+06
# Cur diff delta = 106.06107330322266
# Cur diff sigma = 16.1273193359375
# Cur diff theta = 122.18839263916016
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1780, s/iter: 1.426e-01, ELBO: -1.167e+06
# Cur diff delta = 106.21886444091797
# Cur diff sigma = 16.122446060180664
# Cur diff theta = 122.34131050109863
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1800, s/iter: 1.553e-01, ELBO: -1.164e+06
# Cur diff delta = 106.15167999267578
# Cur diff sigma = 16.070722579956055
# Cur diff theta = 122.22240257263184
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1820, s/iter: 1.533e-01, ELBO: -1.165e+06
# Cur diff delta = 106.41567993164062
# Cur diff sigma = 16.04018211364746
# Cur diff theta = 122.45586204528809
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1840, s/iter: 1.470e-01, ELBO: -1.165e+06
# Cur diff delta = 106.3012466430664
# Cur diff sigma = 16.050878524780273
# Cur diff theta = 122.35212516784668
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1860, s/iter: 1.424e-01, ELBO: -1.168e+06
# Cur diff delta = 106.36573791503906
# Cur diff sigma = 16.101037979125977
# Cur diff theta = 122.46677589416504
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1880, s/iter: 1.473e-01, ELBO: -1.164e+06
# Cur diff delta = 106.71186828613281
# Cur diff sigma = 16.053939819335938
# Cur diff theta = 122.76580810546875
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1900, s/iter: 1.424e-01, ELBO: -1.169e+06
# Cur diff delta = 106.48319244384766
# Cur diff sigma = 16.11063003540039
# Cur diff theta = 122.59382247924805
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1920, s/iter: 1.480e-01, ELBO: -1.166e+06
# Cur diff delta = 106.19212341308594
# Cur diff sigma = 16.113689422607422
# Cur diff theta = 122.30581283569336
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1940, s/iter: 1.568e-01, ELBO: -1.167e+06
# Cur diff delta = 106.8631362915039
# Cur diff sigma = 16.030725479125977
# Cur diff theta = 122.89386177062988
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1960, s/iter: 1.489e-01, ELBO: -1.166e+06
# Cur diff delta = 106.56295013427734
# Cur diff sigma = 16.05999755859375
# Cur diff theta = 122.6229476928711
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-1980, s/iter: 1.624e-01, ELBO: -1.167e+06
# Cur diff delta = 106.09249877929688
# Cur diff sigma = 16.079669952392578
# Cur diff theta = 122.17216873168945
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 1-2000, s/iter: 1.471e-01, ELBO: -1.166e+06
# Cur diff delta = 106.56404113769531
# Cur diff sigma = 16.03827667236328
# Cur diff theta = 122.6023178100586
# ---------------------------------------
# ------------------------------------------------------
# Test = 1
# ------------------------------------------------------
# Init diff delta = 3333.0
# Init diff sigma = 38735.67578125
# Init diff theta = 42068.67578125
# HVAE_notemp_1, d: 100, Iter: 2-20, s/iter: 1.444e-01, ELBO: -3.230e+06
# Cur diff delta = 2419.32470703125
# Cur diff sigma = 6387.71728515625
# Cur diff theta = 8807.0419921875
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-40, s/iter: 1.440e-01, ELBO: -2.753e+06
# Cur diff delta = 1801.85107421875
# Cur diff sigma = 2163.8505859375
# Cur diff theta = 3965.70166015625
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-60, s/iter: 1.466e-01, ELBO: -2.379e+06
# Cur diff delta = 1326.8214111328125
# Cur diff sigma = 1250.19091796875
# Cur diff theta = 2577.0123291015625
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-80, s/iter: 1.458e-01, ELBO: -2.145e+06
# Cur diff delta = 952.5419921875
# Cur diff sigma = 849.2860107421875
# Cur diff theta = 1801.8280029296875
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-100, s/iter: 1.507e-01, ELBO: -1.753e+06
# Cur diff delta = 663.3956909179688
# Cur diff sigma = 528.1511840820312
# Cur diff theta = 1191.546875
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-120, s/iter: 1.456e-01, ELBO: -1.542e+06
# Cur diff delta = 445.45416259765625
# Cur diff sigma = 241.9081573486328
# Cur diff theta = 687.3623199462891
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-140, s/iter: 1.482e-01, ELBO: -1.406e+06
# Cur diff delta = 292.037109375
# Cur diff sigma = 83.04566955566406
# Cur diff theta = 375.08277893066406
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-160, s/iter: 1.423e-01, ELBO: -1.317e+06
# Cur diff delta = 189.99649047851562
# Cur diff sigma = 53.98991394042969
# Cur diff theta = 243.9864044189453
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-180, s/iter: 1.483e-01, ELBO: -1.256e+06
# Cur diff delta = 128.07415771484375
# Cur diff sigma = 33.45738983154297
# Cur diff theta = 161.53154754638672
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-200, s/iter: 1.431e-01, ELBO: -1.206e+06
# Cur diff delta = 95.58075714111328
# Cur diff sigma = 22.63727569580078
# Cur diff theta = 118.21803283691406
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-220, s/iter: 1.510e-01, ELBO: -1.177e+06
# Cur diff delta = 84.30493927001953
# Cur diff sigma = 17.873624801635742
# Cur diff theta = 102.17856407165527
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-240, s/iter: 1.586e-01, ELBO: -1.167e+06
# Cur diff delta = 84.53103637695312
# Cur diff sigma = 16.443836212158203
# Cur diff theta = 100.97487258911133
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-260, s/iter: 1.467e-01, ELBO: -1.164e+06
# Cur diff delta = 87.16031646728516
# Cur diff sigma = 16.10780143737793
# Cur diff theta = 103.26811790466309
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-280, s/iter: 1.439e-01, ELBO: -1.167e+06
# Cur diff delta = 88.28936004638672
# Cur diff sigma = 16.12571144104004
# Cur diff theta = 104.41507148742676
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-300, s/iter: 1.428e-01, ELBO: -1.165e+06
# Cur diff delta = 88.34613037109375
# Cur diff sigma = 16.070232391357422
# Cur diff theta = 104.41636276245117
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-320, s/iter: 1.432e-01, ELBO: -1.163e+06
# Cur diff delta = 87.8603744506836
# Cur diff sigma = 15.974392890930176
# Cur diff theta = 103.83476734161377
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-340, s/iter: 1.428e-01, ELBO: -1.163e+06
# Cur diff delta = 88.44234466552734
# Cur diff sigma = 16.022241592407227
# Cur diff theta = 104.46458625793457
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-360, s/iter: 1.466e-01, ELBO: -1.167e+06
# Cur diff delta = 88.52313995361328
# Cur diff sigma = 16.09811782836914
# Cur diff theta = 104.62125778198242
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-380, s/iter: 1.459e-01, ELBO: -1.163e+06
# Cur diff delta = 88.2228012084961
# Cur diff sigma = 16.050989151000977
# Cur diff theta = 104.27379035949707
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-400, s/iter: 1.512e-01, ELBO: -1.169e+06
# Cur diff delta = 88.2935562133789
# Cur diff sigma = 16.09010124206543
# Cur diff theta = 104.38365745544434
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-420, s/iter: 1.472e-01, ELBO: -1.163e+06
# Cur diff delta = 88.18963623046875
# Cur diff sigma = 16.07440948486328
# Cur diff theta = 104.26404571533203
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-440, s/iter: 1.474e-01, ELBO: -1.169e+06
# Cur diff delta = 88.49153900146484
# Cur diff sigma = 16.13193130493164
# Cur diff theta = 104.62347030639648
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-460, s/iter: 1.426e-01, ELBO: -1.166e+06
# Cur diff delta = 88.42375946044922
# Cur diff sigma = 16.088781356811523
# Cur diff theta = 104.51254081726074
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-480, s/iter: 1.434e-01, ELBO: -1.166e+06
# Cur diff delta = 88.5542221069336
# Cur diff sigma = 16.090593338012695
# Cur diff theta = 104.64481544494629
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-500, s/iter: 1.550e-01, ELBO: -1.166e+06
# Cur diff delta = 88.70213317871094
# Cur diff sigma = 16.053998947143555
# Cur diff theta = 104.75613212585449
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-520, s/iter: 1.539e-01, ELBO: -1.168e+06
# Cur diff delta = 88.45539855957031
# Cur diff sigma = 16.022768020629883
# Cur diff theta = 104.4781665802002
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-540, s/iter: 1.504e-01, ELBO: -1.171e+06
# Cur diff delta = 88.95960998535156
# Cur diff sigma = 16.097068786621094
# Cur diff theta = 105.05667877197266
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-560, s/iter: 1.469e-01, ELBO: -1.170e+06
# Cur diff delta = 88.47198486328125
# Cur diff sigma = 16.129953384399414
# Cur diff theta = 104.60193824768066
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-580, s/iter: 1.644e-01, ELBO: -1.168e+06
# Cur diff delta = 88.11641693115234
# Cur diff sigma = 16.100893020629883
# Cur diff theta = 104.21730995178223
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-600, s/iter: 1.464e-01, ELBO: -1.166e+06
# Cur diff delta = 88.3313980102539
# Cur diff sigma = 16.15485191345215
# Cur diff theta = 104.48624992370605
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-620, s/iter: 1.572e-01, ELBO: -1.159e+06
# Cur diff delta = 87.94910430908203
# Cur diff sigma = 16.028194427490234
# Cur diff theta = 103.97729873657227
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-640, s/iter: 1.535e-01, ELBO: -1.165e+06
# Cur diff delta = 88.52471160888672
# Cur diff sigma = 16.059959411621094
# Cur diff theta = 104.58467102050781
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-660, s/iter: 1.435e-01, ELBO: -1.161e+06
# Cur diff delta = 88.34970092773438
# Cur diff sigma = 16.077625274658203
# Cur diff theta = 104.42732620239258
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-680, s/iter: 1.500e-01, ELBO: -1.161e+06
# Cur diff delta = 88.14907836914062
# Cur diff sigma = 16.046552658081055
# Cur diff theta = 104.19563102722168
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-700, s/iter: 1.436e-01, ELBO: -1.170e+06
# Cur diff delta = 88.45612335205078
# Cur diff sigma = 16.08102035522461
# Cur diff theta = 104.53714370727539
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-720, s/iter: 1.593e-01, ELBO: -1.168e+06
# Cur diff delta = 88.41094970703125
# Cur diff sigma = 16.077701568603516
# Cur diff theta = 104.48865127563477
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-740, s/iter: 1.604e-01, ELBO: -1.165e+06
# Cur diff delta = 88.53387451171875
# Cur diff sigma = 16.087331771850586
# Cur diff theta = 104.62120628356934
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-760, s/iter: 1.490e-01, ELBO: -1.171e+06
# Cur diff delta = 87.99386596679688
# Cur diff sigma = 16.13029670715332
# Cur diff theta = 104.1241626739502
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-780, s/iter: 1.438e-01, ELBO: -1.168e+06
# Cur diff delta = 88.47726440429688
# Cur diff sigma = 16.190330505371094
# Cur diff theta = 104.66759490966797
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-800, s/iter: 1.471e-01, ELBO: -1.166e+06
# Cur diff delta = 88.103271484375
# Cur diff sigma = 16.036535263061523
# Cur diff theta = 104.13980674743652
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-820, s/iter: 1.488e-01, ELBO: -1.165e+06
# Cur diff delta = 88.1889877319336
# Cur diff sigma = 16.042316436767578
# Cur diff theta = 104.23130416870117
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-840, s/iter: 1.511e-01, ELBO: -1.163e+06
# Cur diff delta = 87.80941009521484
# Cur diff sigma = 16.057716369628906
# Cur diff theta = 103.86712646484375
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-860, s/iter: 1.484e-01, ELBO: -1.163e+06
# Cur diff delta = 88.26126861572266
# Cur diff sigma = 16.032976150512695
# Cur diff theta = 104.29424476623535
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-880, s/iter: 1.444e-01, ELBO: -1.164e+06
# Cur diff delta = 87.62565612792969
# Cur diff sigma = 16.003511428833008
# Cur diff theta = 103.6291675567627
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-900, s/iter: 1.503e-01, ELBO: -1.164e+06
# Cur diff delta = 88.26798248291016
# Cur diff sigma = 16.09249496459961
# Cur diff theta = 104.36047744750977
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-920, s/iter: 1.455e-01, ELBO: -1.168e+06
# Cur diff delta = 88.02289581298828
# Cur diff sigma = 16.184066772460938
# Cur diff theta = 104.20696258544922
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-940, s/iter: 1.544e-01, ELBO: -1.168e+06
# Cur diff delta = 88.033935546875
# Cur diff sigma = 16.081483840942383
# Cur diff theta = 104.11541938781738
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-960, s/iter: 1.480e-01, ELBO: -1.164e+06
# Cur diff delta = 88.59480285644531
# Cur diff sigma = 16.144668579101562
# Cur diff theta = 104.73947143554688
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-980, s/iter: 1.574e-01, ELBO: -1.164e+06
# Cur diff delta = 88.3872299194336
# Cur diff sigma = 15.964874267578125
# Cur diff theta = 104.35210418701172
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1000, s/iter: 1.503e-01, ELBO: -1.165e+06
# Cur diff delta = 88.49614715576172
# Cur diff sigma = 16.125394821166992
# Cur diff theta = 104.62154197692871
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1020, s/iter: 1.431e-01, ELBO: -1.169e+06
# Cur diff delta = 88.5868911743164
# Cur diff sigma = 16.128263473510742
# Cur diff theta = 104.71515464782715
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1040, s/iter: 1.639e-01, ELBO: -1.170e+06
# Cur diff delta = 88.24666595458984
# Cur diff sigma = 16.207260131835938
# Cur diff theta = 104.45392608642578
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1060, s/iter: 1.421e-01, ELBO: -1.164e+06
# Cur diff delta = 88.46636199951172
# Cur diff sigma = 16.119680404663086
# Cur diff theta = 104.5860424041748
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1080, s/iter: 1.423e-01, ELBO: -1.164e+06
# Cur diff delta = 88.30598449707031
# Cur diff sigma = 16.02503776550293
# Cur diff theta = 104.33102226257324
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1100, s/iter: 1.535e-01, ELBO: -1.166e+06
# Cur diff delta = 88.07110595703125
# Cur diff sigma = 16.096702575683594
# Cur diff theta = 104.16780853271484
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1120, s/iter: 1.477e-01, ELBO: -1.172e+06
# Cur diff delta = 87.9864501953125
# Cur diff sigma = 16.131635665893555
# Cur diff theta = 104.11808586120605
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1140, s/iter: 1.495e-01, ELBO: -1.170e+06
# Cur diff delta = 88.21680450439453
# Cur diff sigma = 16.109079360961914
# Cur diff theta = 104.32588386535645
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1160, s/iter: 1.511e-01, ELBO: -1.170e+06
# Cur diff delta = 88.302978515625
# Cur diff sigma = 16.083526611328125
# Cur diff theta = 104.38650512695312
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1180, s/iter: 1.589e-01, ELBO: -1.170e+06
# Cur diff delta = 88.3156967163086
# Cur diff sigma = 16.112497329711914
# Cur diff theta = 104.42819404602051
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1200, s/iter: 1.467e-01, ELBO: -1.165e+06
# Cur diff delta = 88.8139419555664
# Cur diff sigma = 16.101533889770508
# Cur diff theta = 104.91547584533691
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1220, s/iter: 1.521e-01, ELBO: -1.164e+06
# Cur diff delta = 88.28382873535156
# Cur diff sigma = 16.109373092651367
# Cur diff theta = 104.39320182800293
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1240, s/iter: 1.599e-01, ELBO: -1.169e+06
# Cur diff delta = 88.15158081054688
# Cur diff sigma = 16.121356964111328
# Cur diff theta = 104.2729377746582
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1260, s/iter: 1.532e-01, ELBO: -1.171e+06
# Cur diff delta = 88.80079650878906
# Cur diff sigma = 16.09953498840332
# Cur diff theta = 104.90033149719238
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1280, s/iter: 1.559e-01, ELBO: -1.168e+06
# Cur diff delta = 88.02041625976562
# Cur diff sigma = 16.077213287353516
# Cur diff theta = 104.09762954711914
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1300, s/iter: 1.567e-01, ELBO: -1.168e+06
# Cur diff delta = 88.22747039794922
# Cur diff sigma = 16.065410614013672
# Cur diff theta = 104.29288101196289
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1320, s/iter: 1.498e-01, ELBO: -1.162e+06
# Cur diff delta = 88.12908935546875
# Cur diff sigma = 15.94636058807373
# Cur diff theta = 104.07544994354248
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1340, s/iter: 1.495e-01, ELBO: -1.165e+06
# Cur diff delta = 88.19546508789062
# Cur diff sigma = 16.10662078857422
# Cur diff theta = 104.30208587646484
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1360, s/iter: 1.583e-01, ELBO: -1.170e+06
# Cur diff delta = 88.02213287353516
# Cur diff sigma = 16.15396499633789
# Cur diff theta = 104.17609786987305
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1380, s/iter: 1.498e-01, ELBO: -1.166e+06
# Cur diff delta = 87.95040893554688
# Cur diff sigma = 16.085491180419922
# Cur diff theta = 104.0359001159668
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1400, s/iter: 1.427e-01, ELBO: -1.166e+06
# Cur diff delta = 87.93860626220703
# Cur diff sigma = 16.109634399414062
# Cur diff theta = 104.0482406616211
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1420, s/iter: 1.473e-01, ELBO: -1.170e+06
# Cur diff delta = 88.07652282714844
# Cur diff sigma = 16.10729217529297
# Cur diff theta = 104.1838150024414
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1440, s/iter: 1.617e-01, ELBO: -1.163e+06
# Cur diff delta = 88.42243194580078
# Cur diff sigma = 16.056644439697266
# Cur diff theta = 104.47907638549805
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1460, s/iter: 1.432e-01, ELBO: -1.164e+06
# Cur diff delta = 88.149169921875
# Cur diff sigma = 16.089340209960938
# Cur diff theta = 104.23851013183594
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1480, s/iter: 1.571e-01, ELBO: -1.169e+06
# Cur diff delta = 87.95182800292969
# Cur diff sigma = 16.138538360595703
# Cur diff theta = 104.09036636352539
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1500, s/iter: 1.463e-01, ELBO: -1.165e+06
# Cur diff delta = 88.0462417602539
# Cur diff sigma = 16.132551193237305
# Cur diff theta = 104.17879295349121
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1520, s/iter: 1.438e-01, ELBO: -1.165e+06
# Cur diff delta = 88.24515533447266
# Cur diff sigma = 16.119104385375977
# Cur diff theta = 104.36425971984863
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1540, s/iter: 1.503e-01, ELBO: -1.165e+06
# Cur diff delta = 88.57733917236328
# Cur diff sigma = 16.1624698638916
# Cur diff theta = 104.73980903625488
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1560, s/iter: 1.454e-01, ELBO: -1.169e+06
# Cur diff delta = 88.3212890625
# Cur diff sigma = 16.126934051513672
# Cur diff theta = 104.44822311401367
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1580, s/iter: 1.459e-01, ELBO: -1.167e+06
# Cur diff delta = 88.38639068603516
# Cur diff sigma = 16.11176109313965
# Cur diff theta = 104.4981517791748
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1600, s/iter: 1.453e-01, ELBO: -1.163e+06
# Cur diff delta = 88.15029907226562
# Cur diff sigma = 16.17522621154785
# Cur diff theta = 104.32552528381348
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1620, s/iter: 1.495e-01, ELBO: -1.166e+06
# Cur diff delta = 88.48028564453125
# Cur diff sigma = 16.004117965698242
# Cur diff theta = 104.48440361022949
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1640, s/iter: 1.454e-01, ELBO: -1.171e+06
# Cur diff delta = 88.3129653930664
# Cur diff sigma = 16.06058692932129
# Cur diff theta = 104.3735523223877
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1660, s/iter: 1.589e-01, ELBO: -1.162e+06
# Cur diff delta = 88.55390167236328
# Cur diff sigma = 16.106409072875977
# Cur diff theta = 104.66031074523926
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1680, s/iter: 1.561e-01, ELBO: -1.165e+06
# Cur diff delta = 88.29629516601562
# Cur diff sigma = 16.06968116760254
# Cur diff theta = 104.36597633361816
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1700, s/iter: 1.503e-01, ELBO: -1.163e+06
# Cur diff delta = 88.45476531982422
# Cur diff sigma = 16.053730010986328
# Cur diff theta = 104.50849533081055
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1720, s/iter: 1.426e-01, ELBO: -1.169e+06
# Cur diff delta = 87.9894027709961
# Cur diff sigma = 16.145204544067383
# Cur diff theta = 104.13460731506348
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1740, s/iter: 1.516e-01, ELBO: -1.166e+06
# Cur diff delta = 88.3303451538086
# Cur diff sigma = 16.12778091430664
# Cur diff theta = 104.45812606811523
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1760, s/iter: 1.502e-01, ELBO: -1.169e+06
# Cur diff delta = 88.19489288330078
# Cur diff sigma = 16.15913200378418
# Cur diff theta = 104.35402488708496
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1780, s/iter: 1.694e-01, ELBO: -1.167e+06
# Cur diff delta = 88.25093078613281
# Cur diff sigma = 16.051982879638672
# Cur diff theta = 104.30291366577148
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1800, s/iter: 1.435e-01, ELBO: -1.161e+06
# Cur diff delta = 88.48477935791016
# Cur diff sigma = 16.015867233276367
# Cur diff theta = 104.50064659118652
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1820, s/iter: 1.532e-01, ELBO: -1.167e+06
# Cur diff delta = 88.46906280517578
# Cur diff sigma = 16.15680694580078
# Cur diff theta = 104.62586975097656
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1840, s/iter: 1.535e-01, ELBO: -1.166e+06
# Cur diff delta = 88.392822265625
# Cur diff sigma = 16.02471351623535
# Cur diff theta = 104.41753578186035
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1860, s/iter: 1.450e-01, ELBO: -1.168e+06
# Cur diff delta = 88.39633178710938
# Cur diff sigma = 16.064922332763672
# Cur diff theta = 104.46125411987305
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1880, s/iter: 1.492e-01, ELBO: -1.167e+06
# Cur diff delta = 88.2972412109375
# Cur diff sigma = 16.124143600463867
# Cur diff theta = 104.42138481140137
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1900, s/iter: 1.494e-01, ELBO: -1.167e+06
# Cur diff delta = 88.21891784667969
# Cur diff sigma = 16.10127067565918
# Cur diff theta = 104.32018852233887
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1920, s/iter: 1.450e-01, ELBO: -1.164e+06
# Cur diff delta = 88.20980072021484
# Cur diff sigma = 16.080886840820312
# Cur diff theta = 104.29068756103516
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1940, s/iter: 1.459e-01, ELBO: -1.159e+06
# Cur diff delta = 88.61160278320312
# Cur diff sigma = 16.039108276367188
# Cur diff theta = 104.65071105957031
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1960, s/iter: 1.493e-01, ELBO: -1.164e+06
# Cur diff delta = 87.91129302978516
# Cur diff sigma = 16.117868423461914
# Cur diff theta = 104.02916145324707
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-1980, s/iter: 1.488e-01, ELBO: -1.166e+06
# Cur diff delta = 88.78241729736328
# Cur diff sigma = 16.107742309570312
# Cur diff theta = 104.8901596069336
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 2-2000, s/iter: 1.496e-01, ELBO: -1.170e+06
# Cur diff delta = 88.52863311767578
# Cur diff sigma = 16.158483505249023
# Cur diff theta = 104.6871166229248
# ---------------------------------------
# ------------------------------------------------------
# Test = 2
# ------------------------------------------------------
# Init diff delta = 3333.0
# Init diff sigma = 38735.67578125
# Init diff theta = 42068.67578125
# HVAE_notemp_1, d: 100, Iter: 3-20, s/iter: 1.475e-01, ELBO: -3.226e+06
# Cur diff delta = 2415.64111328125
# Cur diff sigma = 6342.37451171875
# Cur diff theta = 8758.015625
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 3-40, s/iter: 1.544e-01, ELBO: -2.756e+06
# Cur diff delta = 1796.263916015625
# Cur diff sigma = 2106.522705078125
# Cur diff theta = 3902.78662109375
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 3-60, s/iter: 1.461e-01, ELBO: -2.384e+06
# Cur diff delta = 1330.0885009765625
# Cur diff sigma = 1208.435302734375
# Cur diff theta = 2538.5238037109375
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 3-80, s/iter: 1.580e-01, ELBO: -2.164e+06
# Cur diff delta = 961.7703247070312
# Cur diff sigma = 807.1695556640625
# Cur diff theta = 1768.9398803710938
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 3-100, s/iter: 1.478e-01, ELBO: -1.760e+06
# Cur diff delta = 671.6040649414062
# Cur diff sigma = 476.4197082519531
# Cur diff theta = 1148.0237731933594
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 3-120, s/iter: 1.420e-01, ELBO: -1.538e+06
# Cur diff delta = 453.7399597167969
# Cur diff sigma = 196.89114379882812
# Cur diff theta = 650.631103515625
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 3-140, s/iter: 1.494e-01, ELBO: -1.390e+06
# Cur diff delta = 301.2915954589844
# Cur diff sigma = 74.87373352050781
# Cur diff theta = 376.1653289794922
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 3-160, s/iter: 1.579e-01, ELBO: -1.298e+06
# Cur diff delta = 201.0709686279297
# Cur diff sigma = 45.90498352050781
# Cur diff theta = 246.9759521484375
# ---------------------------------------
# HVAE_notemp_1, d: 100, Iter: 3-180, s/iter: 1.523e-01, ELBO: -1.237e+06
# Cur diff delta = 141.2835693359375
# Cur diff sigma = 28.266067504882812
# ...
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-680, s/iter: 4.232e-01, ELBO: -1.513e+06
# Cur diff delta = 108.78900146484375
# Cur diff sigma = 51.22905731201172
# Cur diff theta = 160.01805877685547
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-700, s/iter: 4.259e-01, ELBO: -1.509e+06
# Cur diff delta = 109.33744812011719
# Cur diff sigma = 50.878509521484375
# Cur diff theta = 160.21595764160156
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-720, s/iter: 4.138e-01, ELBO: -1.511e+06
# Cur diff delta = 108.6013412475586
# Cur diff sigma = 51.17398452758789
# Cur diff theta = 159.77532577514648
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-740, s/iter: 4.234e-01, ELBO: -1.510e+06
# Cur diff delta = 108.92815399169922
# Cur diff sigma = 51.13850784301758
# Cur diff theta = 160.0666618347168
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-760, s/iter: 4.081e-01, ELBO: -1.513e+06
# Cur diff delta = 109.45853424072266
# Cur diff sigma = 51.12971115112305
# Cur diff theta = 160.5882453918457
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-780, s/iter: 4.196e-01, ELBO: -1.512e+06
# Cur diff delta = 108.85231018066406
# Cur diff sigma = 51.14879608154297
# Cur diff theta = 160.00110626220703
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-800, s/iter: 4.210e-01, ELBO: -1.514e+06
# Cur diff delta = 109.10746765136719
# Cur diff sigma = 50.95457077026367
# Cur diff theta = 160.06203842163086
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-820, s/iter: 4.115e-01, ELBO: -1.509e+06
# Cur diff delta = 109.17906951904297
# Cur diff sigma = 51.10776901245117
# Cur diff theta = 160.28683853149414
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-840, s/iter: 4.384e-01, ELBO: -1.512e+06
# Cur diff delta = 108.64109802246094
# Cur diff sigma = 51.014591217041016
# Cur diff theta = 159.65568923950195
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-860, s/iter: 4.293e-01, ELBO: -1.506e+06
# Cur diff delta = 108.57088470458984
# Cur diff sigma = 50.853111267089844
# Cur diff theta = 159.4239959716797
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-880, s/iter: 4.314e-01, ELBO: -1.509e+06
# Cur diff delta = 108.98380279541016
# Cur diff sigma = 50.855342864990234
# Cur diff theta = 159.8391456604004
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-900, s/iter: 4.017e-01, ELBO: -1.508e+06
# Cur diff delta = 109.04143524169922
# Cur diff sigma = 50.747886657714844
# Cur diff theta = 159.78932189941406
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-920, s/iter: 4.300e-01, ELBO: -1.513e+06
# Cur diff delta = 108.94227600097656
# Cur diff sigma = 51.0877799987793
# Cur diff theta = 160.03005599975586
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-940, s/iter: 4.337e-01, ELBO: -1.511e+06
# Cur diff delta = 109.2738265991211
# Cur diff sigma = 50.98721694946289
# Cur diff theta = 160.26104354858398
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-960, s/iter: 4.319e-01, ELBO: -1.513e+06
# Cur diff delta = 108.89034271240234
# Cur diff sigma = 50.96678161621094
# Cur diff theta = 159.85712432861328
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-980, s/iter: 4.252e-01, ELBO: -1.512e+06
# Cur diff delta = 109.23482513427734
# Cur diff sigma = 51.23454284667969
# Cur diff theta = 160.46936798095703
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1000, s/iter: 4.080e-01, ELBO: -1.508e+06
# Cur diff delta = 108.64954376220703
# Cur diff sigma = 50.92894744873047
# Cur diff theta = 159.5784912109375
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1020, s/iter: 4.320e-01, ELBO: -1.507e+06
# Cur diff delta = 109.05950164794922
# Cur diff sigma = 50.92249298095703
# Cur diff theta = 159.98199462890625
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1040, s/iter: 4.076e-01, ELBO: -1.515e+06
# Cur diff delta = 108.65084838867188
# Cur diff sigma = 51.357505798339844
# Cur diff theta = 160.00835418701172
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1060, s/iter: 4.178e-01, ELBO: -1.510e+06
# Cur diff delta = 108.30831909179688
# Cur diff sigma = 51.14805221557617
# Cur diff theta = 159.45637130737305
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1080, s/iter: 4.255e-01, ELBO: -1.510e+06
# Cur diff delta = 109.0078353881836
# Cur diff sigma = 50.90232467651367
# Cur diff theta = 159.91016006469727
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1100, s/iter: 4.274e-01, ELBO: -1.514e+06
# Cur diff delta = 108.98375701904297
# Cur diff sigma = 50.953758239746094
# Cur diff theta = 159.93751525878906
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1120, s/iter: 4.248e-01, ELBO: -1.519e+06
# Cur diff delta = 109.33157348632812
# Cur diff sigma = 51.352420806884766
# Cur diff theta = 160.6839942932129
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1140, s/iter: 4.046e-01, ELBO: -1.515e+06
# Cur diff delta = 109.07111358642578
# Cur diff sigma = 51.29054260253906
# Cur diff theta = 160.36165618896484
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1160, s/iter: 4.256e-01, ELBO: -1.511e+06
# Cur diff delta = 109.06051635742188
# Cur diff sigma = 50.95209503173828
# Cur diff theta = 160.01261138916016
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1180, s/iter: 4.194e-01, ELBO: -1.513e+06
# Cur diff delta = 108.64302062988281
# Cur diff sigma = 51.1752815246582
# Cur diff theta = 159.81830215454102
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1200, s/iter: 4.182e-01, ELBO: -1.511e+06
# Cur diff delta = 109.02725982666016
# Cur diff sigma = 51.09920883178711
# Cur diff theta = 160.12646865844727
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1220, s/iter: 4.295e-01, ELBO: -1.509e+06
# Cur diff delta = 109.2799301147461
# Cur diff sigma = 50.98142623901367
# Cur diff theta = 160.26135635375977
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1240, s/iter: 4.207e-01, ELBO: -1.517e+06
# Cur diff delta = 108.84551239013672
# Cur diff sigma = 51.17072677612305
# Cur diff theta = 160.01623916625977
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1260, s/iter: 4.442e-01, ELBO: -1.515e+06
# Cur diff delta = 108.95118713378906
# Cur diff sigma = 51.05550003051758
# Cur diff theta = 160.00668716430664
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1280, s/iter: 4.141e-01, ELBO: -1.510e+06
# Cur diff delta = 109.0201187133789
# Cur diff sigma = 51.082664489746094
# Cur diff theta = 160.102783203125
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1300, s/iter: 4.196e-01, ELBO: -1.512e+06
# Cur diff delta = 109.44769287109375
# Cur diff sigma = 51.2039680480957
# Cur diff theta = 160.65166091918945
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1320, s/iter: 4.283e-01, ELBO: -1.510e+06
# Cur diff delta = 109.12617492675781
# Cur diff sigma = 50.9738655090332
# Cur diff theta = 160.10004043579102
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1340, s/iter: 4.180e-01, ELBO: -1.515e+06
# Cur diff delta = 109.07566833496094
# Cur diff sigma = 51.21538543701172
# Cur diff theta = 160.29105377197266
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1360, s/iter: 4.375e-01, ELBO: -1.512e+06
# Cur diff delta = 108.767578125
# Cur diff sigma = 50.90473556518555
# Cur diff theta = 159.67231369018555
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1380, s/iter: 4.355e-01, ELBO: -1.513e+06
# Cur diff delta = 108.93206787109375
# Cur diff sigma = 51.11481857299805
# Cur diff theta = 160.0468864440918
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1400, s/iter: 4.511e-01, ELBO: -1.512e+06
# Cur diff delta = 108.69438171386719
# Cur diff sigma = 50.91846466064453
# Cur diff theta = 159.61284637451172
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1420, s/iter: 4.338e-01, ELBO: -1.511e+06
# Cur diff delta = 108.97120666503906
# Cur diff sigma = 50.99557876586914
# Cur diff theta = 159.9667854309082
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1440, s/iter: 4.167e-01, ELBO: -1.513e+06
# Cur diff delta = 108.90689849853516
# Cur diff sigma = 51.273006439208984
# Cur diff theta = 160.17990493774414
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1460, s/iter: 4.218e-01, ELBO: -1.507e+06
# Cur diff delta = 109.16974639892578
# Cur diff sigma = 51.06608200073242
# Cur diff theta = 160.2358283996582
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1480, s/iter: 4.012e-01, ELBO: -1.514e+06
# Cur diff delta = 109.0538101196289
# Cur diff sigma = 51.2692985534668
# Cur diff theta = 160.3231086730957
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1500, s/iter: 4.397e-01, ELBO: -1.516e+06
# Cur diff delta = 108.92632293701172
# Cur diff sigma = 51.33009338378906
# Cur diff theta = 160.25641632080078
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1520, s/iter: 4.063e-01, ELBO: -1.511e+06
# Cur diff delta = 109.16963195800781
# Cur diff sigma = 51.1039924621582
# Cur diff theta = 160.27362442016602
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1540, s/iter: 4.253e-01, ELBO: -1.511e+06
# Cur diff delta = 108.69447326660156
# Cur diff sigma = 51.12016296386719
# Cur diff theta = 159.81463623046875
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1560, s/iter: 4.094e-01, ELBO: -1.513e+06
# Cur diff delta = 109.29768371582031
# Cur diff sigma = 51.322547912597656
# Cur diff theta = 160.62023162841797
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1580, s/iter: 4.224e-01, ELBO: -1.514e+06
# Cur diff delta = 108.98408508300781
# Cur diff sigma = 51.433616638183594
# Cur diff theta = 160.4177017211914
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1600, s/iter: 4.146e-01, ELBO: -1.509e+06
# Cur diff delta = 108.97123718261719
# Cur diff sigma = 51.07149887084961
# Cur diff theta = 160.0427360534668
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1620, s/iter: 4.230e-01, ELBO: -1.511e+06
# Cur diff delta = 109.29840850830078
# Cur diff sigma = 51.04638671875
# Cur diff theta = 160.34479522705078
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1640, s/iter: 4.256e-01, ELBO: -1.512e+06
# Cur diff delta = 108.84510803222656
# Cur diff sigma = 51.10818862915039
# Cur diff theta = 159.95329666137695
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1660, s/iter: 4.235e-01, ELBO: -1.513e+06
# Cur diff delta = 108.60285186767578
# Cur diff sigma = 50.99220657348633
# Cur diff theta = 159.5950584411621
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1680, s/iter: 4.059e-01, ELBO: -1.512e+06
# Cur diff delta = 108.7014389038086
# Cur diff sigma = 51.24311828613281
# Cur diff theta = 159.9445571899414
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1700, s/iter: 4.469e-01, ELBO: -1.511e+06
# Cur diff delta = 109.02918243408203
# Cur diff sigma = 50.97270202636719
# Cur diff theta = 160.00188446044922
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1720, s/iter: 4.163e-01, ELBO: -1.511e+06
# Cur diff delta = 109.04389953613281
# Cur diff sigma = 51.21441650390625
# Cur diff theta = 160.25831604003906
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1740, s/iter: 4.259e-01, ELBO: -1.514e+06
# Cur diff delta = 109.10758972167969
# Cur diff sigma = 51.04282760620117
# Cur diff theta = 160.15041732788086
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1760, s/iter: 4.107e-01, ELBO: -1.515e+06
# Cur diff delta = 109.01026916503906
# Cur diff sigma = 51.15085220336914
# Cur diff theta = 160.1611213684082
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1780, s/iter: 4.486e-01, ELBO: -1.507e+06
# Cur diff delta = 109.03948974609375
# Cur diff sigma = 50.985740661621094
# Cur diff theta = 160.02523040771484
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1800, s/iter: 4.068e-01, ELBO: -1.513e+06
# Cur diff delta = 109.171142578125
# Cur diff sigma = 51.007598876953125
# Cur diff theta = 160.17874145507812
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1820, s/iter: 4.164e-01, ELBO: -1.512e+06
# Cur diff delta = 108.57886505126953
# Cur diff sigma = 51.25435256958008
# Cur diff theta = 159.8332176208496
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1840, s/iter: 4.306e-01, ELBO: -1.515e+06
# Cur diff delta = 109.3468246459961
# Cur diff sigma = 51.032501220703125
# Cur diff theta = 160.37932586669922
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1860, s/iter: 4.181e-01, ELBO: -1.513e+06
# Cur diff delta = 108.6535415649414
# Cur diff sigma = 51.04677963256836
# Cur diff theta = 159.70032119750977
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1880, s/iter: 4.292e-01, ELBO: -1.519e+06
# Cur diff delta = 108.81356811523438
# Cur diff sigma = 51.286441802978516
# Cur diff theta = 160.1000099182129
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1900, s/iter: 4.115e-01, ELBO: -1.511e+06
# Cur diff delta = 109.14138793945312
# Cur diff sigma = 50.96368408203125
# Cur diff theta = 160.10507202148438
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1920, s/iter: 4.143e-01, ELBO: -1.515e+06
# Cur diff delta = 108.76815032958984
# Cur diff sigma = 50.933837890625
# Cur diff theta = 159.70198822021484
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1940, s/iter: 4.090e-01, ELBO: -1.514e+06
# Cur diff delta = 108.85470581054688
# Cur diff sigma = 51.35811996459961
# Cur diff theta = 160.21282577514648
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1960, s/iter: 4.255e-01, ELBO: -1.512e+06
# Cur diff delta = 108.9525375366211
# Cur diff sigma = 51.09599685668945
# Cur diff theta = 160.04853439331055
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-1980, s/iter: 4.054e-01, ELBO: -1.511e+06
# Cur diff delta = 109.23912811279297
# Cur diff sigma = 51.1949462890625
# Cur diff theta = 160.43407440185547
# ---------------------------------------
# HVAE_notemp_2, d: 100, Iter: 3-2000, s/iter: 4.234e-01, ELBO: -1.510e+06
# Cur diff delta = 108.98001861572266
# Cur diff sigma = 51.11366271972656
# Cur diff theta = 160.09368133544922
# ---------------------------------------
# Model HVAE_notemp_1, test = 0, result delta diff = 106.56404113769531
# Model HVAE_notemp_1, test = 0, result sigma diff = 16.038278579711914
# Model HVAE_notemp_1, test = 0, result theta diff = 122.6023178100586
# Model HVAE_notemp_1, test = 1, result delta diff = 88.52863311767578
# Model HVAE_notemp_1, test = 1, result sigma diff = 16.158483505249023
# Model HVAE_notemp_1, test = 1, result theta diff = 104.68711853027344
# Model HVAE_notemp_1, test = 2, result delta diff = 108.9835205078125
# Model HVAE_notemp_1, test = 2, result sigma diff = 16.11968421936035
# Model HVAE_notemp_1, test = 2, result theta diff = 125.10320281982422
# Model HVAE_notemp_2, test = 0, result delta diff = 106.611328125
# Model HVAE_notemp_2, test = 0, result sigma diff = 51.08967590332031
# Model HVAE_notemp_2, test = 0, result theta diff = 157.7010040283203
# Model HVAE_notemp_2, test = 1, result delta diff = 88.41127014160156
# Model HVAE_notemp_2, test = 1, result sigma diff = 51.26065444946289
# Model HVAE_notemp_2, test = 1, result theta diff = 139.6719207763672
# Model HVAE_notemp_2, test = 2, result delta diff = 108.98001861572266
# Model HVAE_notemp_2, test = 2, result sigma diff = 51.11366271972656
# Model HVAE_notemp_2, test = 2, result theta diff = 160.09368896484375

# %%
model_names = ['HVAE_notemp_1', 'HVAE_notemp_2']
diff_delta_results = {}
diff_sigma_results = {}
diff_results = {}
for name in model_names:
    diff_delta_tests = np.zeros(params['n_tests'])
    diff_sigma_tests = np.zeros(params['n_tests'])
    diff_tests = np.zeros(params['n_tests'])
    for i in range(params['n_tests']):
        file_name = name + '_train_' + str(i) + '.p'
        diff_path = os.path.join('save', str(params['dims'][0]), file_name)
        with open(diff_path, 'rb') as f:
            data = pickle.load(f)
            elbo = data['elbo']
            diff_delta = data['diff_delta']
            diff_sigma = data['diff_sigma']
            diff = diff_delta + diff_sigma
            diff_delta_is_not_nan = diff_delta[~np.isnan(diff_delta)]
            diff_sigma_is_not_nan = diff_sigma[~np.isnan(diff_sigma)]
            diff_is_not_nan = diff[~np.isnan(diff)]
            diff_delta_tests[i] = diff_delta_is_not_nan[-1]
            diff_sigma_tests[i] = diff_sigma_is_not_nan[-1]
            diff_tests[i] = diff_is_not_nan[-1]
    diff_delta_results[name] = diff_delta_tests
    diff_sigma_results[name] = diff_sigma_tests
    diff_results[name] = diff_tests
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, diff delta = {diff_delta_tests}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, diff sigma = {diff_sigma_tests}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, diff = {diff_tests}")
# Out:
# Model = HVAE_notemp_1, dimensionality = 100, diff delta = [106.56404114  88.52863312 108.98352051]
# Model = HVAE_notemp_1, dimensionality = 100, diff sigma = [16.03827667 16.15848351 16.11968422]
# Model = HVAE_notemp_1, dimensionality = 100, diff = [122.60231781 104.68711853 125.10320282]
# Model = HVAE_notemp_2, dimensionality = 100, diff delta = [106.61132812  88.41127014 108.98001862]
# Model = HVAE_notemp_2, dimensionality = 100, diff sigma = [51.08967209 51.26065826 51.11366272]
# Model = HVAE_notemp_2, dimensionality = 100, diff = [157.70100403 139.67193604 160.09368896]

# %%
for name in model_names:
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, mean diff delta = {diff_delta_results[name].mean()}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, mean diff sigma = {diff_sigma_results[name].mean()}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, mean diff = {diff_results[name].mean()}")
# Out:
# Model = HVAE_notemp_1, dimensionality = 100, mean diff delta = 101.35873158772786
# Model = HVAE_notemp_1, dimensionality = 100, mean diff sigma = 16.10548146565755
# Model = HVAE_notemp_1, dimensionality = 100, mean diff = 117.46421305338542
# Model = HVAE_notemp_2, dimensionality = 100, mean diff delta = 101.3342056274414
# Model = HVAE_notemp_2, dimensionality = 100, mean diff sigma = 51.15466435750326
# Model = HVAE_notemp_2, dimensionality = 100, mean diff = 152.48887634277344

# %%
def run_test(d, params, 
             batch_size=256,
             clip_value=None,
             dtype=torch.float32, 
             device=torch.device("cpu")):
    """ 
    Run the gaussian test with dimension d 
    """

    ######### Problem Specification

    # Data generation parameters
    prior_mu_z = torch.zeros(d, dtype=dtype)    # Prior mean
    prior_sigma_z = torch.eye(d, dtype=dtype)   # Prior covariance matrix

    # True model parameters
    num_range = torch.arange(-(d-1)/2, (d+1)/2, dtype=dtype)

    t_delta =  num_range / 5 

    print(f"true delta = {t_delta.numpy()}")

    if d == 1:
        t_sigma = torch.ones(1, dtype=dtype)
    else: 
        # Allow sigma to range from 0.1 to 1
        t_sigma = 36/(10*(d-1)**2) * num_range**2 + 0.1 
    print(f"true sigma = {t_sigma.numpy()}")

    ######### Variable Initialization

    # Initial model parameters - same across all methods
    init_delta = prior_mu_z.clone().to(device)
    init_log_sigma = 3 * torch.ones(d).to(device)

    # Initial HVAE variational parameters
    init_T = torch.tensor(5., dtype=dtype, device=device)
    init_eps = 0.005 * torch.ones(d, dtype=dtype)
    max_eps = params['max_eps'] * torch.ones(d, dtype=dtype)
    init_logit_eps = torch.log(init_eps/(max_eps - init_eps)).to(device)
    init_log_T_0 = torch.log(init_T - 1)

    # Initial NF variational parameters
    init_u_pre_reparam = torch.tensor(scipy.stats.truncnorm.rvs(-2, 2, 
                                                                scale=0.1, 
                                                                size=d),
                                      dtype=dtype, device=device)
    init_w = torch.tensor(scipy.stats.truncnorm.rvs(-2, 2, scale=0.1, size=d),
                          dtype=dtype, device=device)
    init_b = torch.tensor(0.1, dtype=dtype, device=device)

    # Initial VAE parameters
    init_mu_z = prior_mu_z.clone()
    init_log_sigma_z = torch.ones(d, dtype=dtype)

    ######### Set up models
    init_params = [[init_delta, init_log_sigma],
                   [init_delta, init_log_sigma]]
    
    hid_dim = d + 100
    IAF_model = IAF(params,
        ['delta', 'log_sigma'],
        init_params[0], 
        'IAF', d, 1, hid_dim)

    #model_list = [HVAE_model_1, HVAE_model_2, NF_model_1]
    #model_list = [HVAE_model_1, NF_model_1]
    model_list = [IAF_model]

    print("Models were initialized!")
    
    ######### Generate Training Data & Save - One for each test

    train_data_list = []

    for i in range(params['n_tests']):
        z = MultivariateNormal(prior_mu_z, prior_sigma_z).sample()
        x = MultivariateNormal(z + t_delta, 
                               torch.diag(t_sigma**2)).sample([params['n_data']])
        x = x.to(device)
        train_data_list.append(x)

    # Folder should have already been created in the initializations
    data_path = os.path.join('save', str(d), 'train_data.p')
    pickle.dump(train_data_list, open(data_path, 'wb')) 

    # Store the final parameter values for all test runs in this dictionary
    final_params = {}

    for i in range(len(model_list)):
        final_values = []
        m = model_list[i]
        model_init_params = init_params[i]

        for j in range(params['n_tests']):
            print("------------------------------------------------------")
            print(f"Test = {j}")
            print("------------------------------------------------------")
            m._reinitialize(model_init_params)
            gaussian_data = gaussian_dataset(train_data_list[j])
            train_dataloader = DataLoader(gaussian_data, batch_size=batch_size,
                                          shuffle=False, num_workers=0)
            (delta, sigma) = m.train(train_dataloader, j, 
                                     t_delta, t_sigma,
                                     clip_value)
            final_values.append((delta, sigma))

        final_params[m.model_name] = final_values.copy()

    ######### Test models using difference between parameters

    param_diffs = {}

    for m in model_list:
        
        diffs = []

        for i in range(params['n_tests']):
            delta = final_params[m.model_name][i][0]
            sigma = final_params[m.model_name][i][1]

            delta_diff = np.sum((delta - t_delta.numpy())**2)
            sigma_diff = np.sum((sigma - t_sigma.numpy())**2)
            theta_diff = delta_diff + sigma_diff
            print(f"Model {m.model_name}, test = {i}, result delta diff = {delta_diff}")
            print(f"Model {m.model_name}, test = {i}, result sigma diff = {sigma_diff}")
            print(f"Model {m.model_name}, test = {i}, result theta diff = {theta_diff}")

            diffs.append((delta_diff, sigma_diff, theta_diff))

        param_diffs[m.model_name] = diffs.copy()

    # Save parameter differences in a pickle file
    diff_path = os.path.join('save', str(d), 'all_diffs.p')
    pickle.dump(param_diffs, open(diff_path, 'wb'))

# %%
device = torch.device("cpu")
dtype = torch.float32
clip_value = None
batch_size = 256

# %%
params = {

    # PROBLEM SPECIFICATION
    #'dims': [1, 2, 3, 5, 11, 25, 51, 101, 201, 301], # Dimensions to test
    'dims': [50],
    'n_data': 10000,                                 # Number of data points

    # TEST HYPERPARAMETERS
    'n_tests': 3,      # Number of experiments to run

    # GLOBAL OPTIMIZATION PARAMETERS
    'n_iter': 2000,    # Number of optimization iterations
    'n_batch': 10,      # Number of points for ELBO estimate
    'rms_eta': 0.001,   # Stepsize for RMSProp
    'save_every': 20,   # Save parameter information every so often
    'print_every': 20, # Print less often than save

    # HVAE HYPERPARAMETERS
    'HVAE_K_1': 1,    # Number of leapfrog/cooling steps for HVAE flow 1
    'HVAE_K_2': 10,   # Number of leapfrog/cooling steps for HVAE flow 2
    'max_eps': 0.5,   # Maximum leapfrog step size per dimension 

    # NF HYPERPARAMETERS
    'NF_K_1': 1,    # Number of flow steps for NF flow 1
    'NF_K_2': 30,   # Number of flow steps for NF flow 2
    
}

# %%
dims = params['dims']
seed = 12345
np.random.seed(seed)
torch.manual_seed(seed)
for d in dims:
    print('**** Running test for d={0:d} ****'.format(d))
    run_test(d, params, batch_size, clip_value, dtype, device)
# Out:
# **** Running test for d=50 ****
# true delta = [-4.9 -4.7 -4.5 -4.3 -4.1 -3.9 -3.7 -3.5 -3.3 -3.1 -2.9 -2.7 -2.5 -2.3
#  -2.1 -1.9 -1.7 -1.5 -1.3 -1.1 -0.9 -0.7 -0.5 -0.3 -0.1  0.1  0.3  0.5
#   0.7  0.9  1.1  1.3  1.5  1.7  1.9  2.1  2.3  2.5  2.7  2.9  3.1  3.3
#   3.5  3.7  3.9  4.1  4.3  4.5  4.7  4.9]
# true sigma = [1.         0.92803    0.85905874 0.79308623 0.73011243 0.67013747
#  0.6131612  0.55918366 0.50820494 0.4602249  0.41524363 0.37326112
#  0.3342774  0.29829237 0.26530612 0.2353186  0.20832986 0.18433985
#  0.16334862 0.1453561  0.13036235 0.11836734 0.1093711  0.10337359
#  0.10037485 0.10037485 0.10337359 0.1093711  0.11836734 0.13036235
#  0.1453561  0.16334862 0.18433985 0.20832986 0.2353186  0.26530612
#  0.29829237 0.3342774  0.37326112 0.41524363 0.4602249  0.50820494
#  0.55918366 0.6131612  0.67013747 0.73011243 0.79308623 0.85905874
#  0.92803    1.        ]
# Models were initialized!
# ------------------------------------------------------
# Test = 0
# ------------------------------------------------------
# Init diff delta = 416.5
# Init diff sigma = 19355.818359375
# Init diff theta = 19772.318359375
# IAF, d: 50, Iter: 1-20, s/iter: 9.367e-02, ELBO: -1.542e+06
# Cur diff delta = 226.47021484375
# Cur diff sigma = 2953.106689453125
# Cur diff theta = 3179.576904296875
# ---------------------------------------
# IAF, d: 50, Iter: 1-40, s/iter: 8.666e-02, ELBO: -1.184e+06
# Cur diff delta = 117.59487915039062
# Cur diff sigma = 559.9413452148438
# Cur diff theta = 677.5362243652344
# ---------------------------------------
# IAF, d: 50, Iter: 1-60, s/iter: 9.782e-02, ELBO: -8.521e+05
# Cur diff delta = 63.74296951293945
# Cur diff sigma = 111.20697784423828
# Cur diff theta = 174.94994735717773
# ---------------------------------------
# IAF, d: 50, Iter: 1-80, s/iter: 8.841e-02, ELBO: -5.642e+05
# Cur diff delta = 44.82843780517578
# Cur diff sigma = 25.388139724731445
# Cur diff theta = 70.21657752990723
# ---------------------------------------
# IAF, d: 50, Iter: 1-100, s/iter: 9.096e-02, ELBO: -3.885e+05
# Cur diff delta = 38.795082092285156
# Cur diff sigma = 7.476279258728027
# Cur diff theta = 46.271361351013184
# ---------------------------------------
# IAF, d: 50, Iter: 1-120, s/iter: 9.219e-02, ELBO: -3.264e+05
# Cur diff delta = 40.801490783691406
# Cur diff sigma = 3.4442391395568848
# Cur diff theta = 44.24572992324829
# ---------------------------------------
# IAF, d: 50, Iter: 1-140, s/iter: 8.900e-02, ELBO: -3.209e+05
# Cur diff delta = 43.14860153198242
# Cur diff sigma = 2.400120973587036
# Cur diff theta = 45.54872250556946
# ---------------------------------------
# IAF, d: 50, Iter: 1-160, s/iter: 8.842e-02, ELBO: -3.190e+05
# Cur diff delta = 45.399436950683594
# Cur diff sigma = 2.159759998321533
# Cur diff theta = 47.55919694900513
# ---------------------------------------
# IAF, d: 50, Iter: 1-180, s/iter: 9.298e-02, ELBO: -3.189e+05
# Cur diff delta = 45.97212600708008
# Cur diff sigma = 2.1517224311828613
# Cur diff theta = 48.12384843826294
# ---------------------------------------
# IAF, d: 50, Iter: 1-200, s/iter: 8.907e-02, ELBO: -3.189e+05
# Cur diff delta = 45.967811584472656
# Cur diff sigma = 2.150956630706787
# Cur diff theta = 48.11876821517944
# ---------------------------------------
# IAF, d: 50, Iter: 1-220, s/iter: 8.889e-02, ELBO: -3.189e+05
# Cur diff delta = 45.980384826660156
# Cur diff sigma = 2.1512598991394043
# Cur diff theta = 48.13164472579956
# ---------------------------------------
# IAF, d: 50, Iter: 1-240, s/iter: 8.745e-02, ELBO: -3.189e+05
# Cur diff delta = 45.97258377075195
# Cur diff sigma = 2.150118112564087
# Cur diff theta = 48.12270188331604
# ---------------------------------------
# IAF, d: 50, Iter: 1-260, s/iter: 8.673e-02, ELBO: -3.189e+05
# Cur diff delta = 45.97492980957031
# Cur diff sigma = 2.150491952896118
# Cur diff theta = 48.12542176246643
# ---------------------------------------
# IAF, d: 50, Iter: 1-280, s/iter: 8.819e-02, ELBO: -3.189e+05
# Cur diff delta = 45.969818115234375
# Cur diff sigma = 2.150317668914795
# Cur diff theta = 48.12013578414917
# ---------------------------------------
# IAF, d: 50, Iter: 1-300, s/iter: 9.317e-02, ELBO: -3.189e+05
# Cur diff delta = 45.983821868896484
# Cur diff sigma = 2.1503875255584717
# Cur diff theta = 48.134209394454956
# ---------------------------------------
# IAF, d: 50, Iter: 1-320, s/iter: 9.582e-02, ELBO: -3.188e+05
# Cur diff delta = 45.970985412597656
# Cur diff sigma = 2.149550437927246
# Cur diff theta = 48.1205358505249
# ---------------------------------------
# IAF, d: 50, Iter: 1-340, s/iter: 9.759e-02, ELBO: -3.188e+05
# Cur diff delta = 45.97639465332031
# Cur diff sigma = 2.1495492458343506
# Cur diff theta = 48.12594389915466
# ---------------------------------------
# IAF, d: 50, Iter: 1-360, s/iter: 1.029e-01, ELBO: -3.188e+05
# Cur diff delta = 45.98533630371094
# Cur diff sigma = 2.1500749588012695
# Cur diff theta = 48.13541126251221
# ---------------------------------------
# IAF, d: 50, Iter: 1-380, s/iter: 9.767e-02, ELBO: -3.189e+05
# Cur diff delta = 45.97413635253906
# Cur diff sigma = 2.1509790420532227
# Cur diff theta = 48.125115394592285
# ---------------------------------------
# IAF, d: 50, Iter: 1-400, s/iter: 1.169e-01, ELBO: -3.188e+05
# Cur diff delta = 45.97507858276367
# Cur diff sigma = 2.149686098098755
# Cur diff theta = 48.12476468086243
# ---------------------------------------
# IAF, d: 50, Iter: 1-420, s/iter: 9.699e-02, ELBO: -3.188e+05
# Cur diff delta = 45.963626861572266
# Cur diff sigma = 2.1495697498321533
# Cur diff theta = 48.11319661140442
# ---------------------------------------
# IAF, d: 50, Iter: 1-440, s/iter: 1.062e-01, ELBO: -3.188e+05
# Cur diff delta = 45.96916961669922
# Cur diff sigma = 2.1492037773132324
# Cur diff theta = 48.11837339401245
# ---------------------------------------
# IAF, d: 50, Iter: 1-460, s/iter: 1.053e-01, ELBO: -3.188e+05
# Cur diff delta = 45.97315979003906
# Cur diff sigma = 2.1496331691741943
# Cur diff theta = 48.12279295921326
# ---------------------------------------
# IAF, d: 50, Iter: 1-480, s/iter: 9.665e-02, ELBO: -3.188e+05
# Cur diff delta = 45.973628997802734
# Cur diff sigma = 2.1492302417755127
# Cur diff theta = 48.12285923957825
# ---------------------------------------
# IAF, d: 50, Iter: 1-500, s/iter: 1.027e-01, ELBO: -3.188e+05
# Cur diff delta = 45.97003173828125
# Cur diff sigma = 2.1501455307006836
# Cur diff theta = 48.120177268981934
# ---------------------------------------
# IAF, d: 50, Iter: 1-520, s/iter: 1.081e-01, ELBO: -3.188e+05
# Cur diff delta = 45.98147964477539
# Cur diff sigma = 2.149125814437866
# Cur diff theta = 48.13060545921326
# ---------------------------------------
# IAF, d: 50, Iter: 1-540, s/iter: 1.019e-01, ELBO: -3.188e+05
# Cur diff delta = 45.97376251220703
# Cur diff sigma = 2.1495115756988525
# Cur diff theta = 48.123274087905884
# ---------------------------------------
# IAF, d: 50, Iter: 1-560, s/iter: 1.032e-01, ELBO: -3.188e+05
# Cur diff delta = 45.98128890991211
# Cur diff sigma = 2.1495449542999268
# Cur diff theta = 48.130833864212036
# ---------------------------------------
# IAF, d: 50, Iter: 1-580, s/iter: 1.025e-01, ELBO: -3.188e+05
# Cur diff delta = 45.978721618652344
# Cur diff sigma = 2.1497461795806885
# Cur diff theta = 48.12846779823303
# ---------------------------------------
# IAF, d: 50, Iter: 1-600, s/iter: 1.143e-01, ELBO: -3.188e+05
# Cur diff delta = 45.96933364868164
# Cur diff sigma = 2.149168014526367
# Cur diff theta = 48.11850166320801
# ---------------------------------------
# IAF, d: 50, Iter: 1-620, s/iter: 1.071e-01, ELBO: -3.188e+05
# Cur diff delta = 45.97846984863281
# Cur diff sigma = 2.149315357208252
# Cur diff theta = 48.127785205841064
# ---------------------------------------
# IAF, d: 50, Iter: 1-640, s/iter: 1.079e-01, ELBO: -3.188e+05
# Cur diff delta = 45.9734992980957
# Cur diff sigma = 2.149024248123169
# Cur diff theta = 48.12252354621887
# ---------------------------------------
# IAF, d: 50, Iter: 1-660, s/iter: 1.305e-01, ELBO: -3.188e+05
# Cur diff delta = 45.97060012817383
# Cur diff sigma = 2.1495110988616943
# Cur diff theta = 48.12011122703552
# ---------------------------------------
# IAF, d: 50, Iter: 1-680, s/iter: 1.222e-01, ELBO: -3.188e+05
# Cur diff delta = 45.97164535522461
# Cur diff sigma = 2.149862289428711
# Cur diff theta = 48.12150764465332
# ---------------------------------------
# IAF, d: 50, Iter: 1-700, s/iter: 1.128e-01, ELBO: -3.188e+05
# Cur diff delta = 45.97655487060547
# Cur diff sigma = 2.150207281112671
# Cur diff theta = 48.12676215171814
# ---------------------------------------
# IAF, d: 50, Iter: 1-720, s/iter: 1.086e-01, ELBO: -3.188e+05
# Cur diff delta = 45.96963119506836
# Cur diff sigma = 2.1494314670562744
# Cur diff theta = 48.119062662124634
# ---------------------------------------
# IAF, d: 50, Iter: 1-740, s/iter: 1.130e-01, ELBO: -3.188e+05
# Cur diff delta = 45.96854019165039
# Cur diff sigma = 2.149934768676758
# Cur diff theta = 48.11847496032715
# ---------------------------------------
# IAF, d: 50, Iter: 1-760, s/iter: 1.218e-01, ELBO: -3.188e+05
# Cur diff delta = 45.97705078125
# Cur diff sigma = 2.1494202613830566
# Cur diff theta = 48.12647104263306
# ---------------------------------------
# IAF, d: 50, Iter: 1-780, s/iter: 1.076e-01, ELBO: -3.188e+05
# Cur diff delta = 45.97307205200195
# Cur diff sigma = 2.149819850921631
# Cur diff theta = 48.122891902923584
# ---------------------------------------
# IAF, d: 50, Iter: 1-800, s/iter: 1.094e-01, ELBO: -3.188e+05
# Cur diff delta = 45.96348190307617
# Cur diff sigma = 2.14898943901062
# Cur diff theta = 48.11247134208679
# ---------------------------------------
# IAF, d: 50, Iter: 1-820, s/iter: 1.254e-01, ELBO: -3.188e+05
# Cur diff delta = 45.9724006652832
# Cur diff sigma = 2.1497373580932617
# Cur diff theta = 48.122138023376465
# ---------------------------------------
# IAF, d: 50, Iter: 1-840, s/iter: 1.190e-01, ELBO: -3.188e+05
# Cur diff delta = 45.975372314453125
# Cur diff sigma = 2.1493539810180664
# Cur diff theta = 48.12472629547119
# ---------------------------------------
# IAF, d: 50, Iter: 1-860, s/iter: 1.169e-01, ELBO: -3.188e+05
# Cur diff delta = 45.97737503051758
# Cur diff sigma = 2.1497879028320312
# Cur diff theta = 48.12716293334961
# ---------------------------------------
# IAF, d: 50, Iter: 1-880, s/iter: 1.233e-01, ELBO: -3.188e+05
# Cur diff delta = 45.974639892578125
# Cur diff sigma = 2.1492366790771484
# Cur diff theta = 48.12387657165527
# ---------------------------------------
# IAF, d: 50, Iter: 1-900, s/iter: 1.146e-01, ELBO: -3.188e+05
# Cur diff delta = 45.97969055175781
# Cur diff sigma = 2.1484618186950684
# Cur diff theta = 48.12815237045288
# ---------------------------------------
# IAF, d: 50, Iter: 1-920, s/iter: 1.147e-01, ELBO: -3.188e+05
# Cur diff delta = 45.971858978271484
# Cur diff sigma = 2.1494688987731934
# Cur diff theta = 48.12132787704468
# ---------------------------------------
# IAF, d: 50, Iter: 1-940, s/iter: 1.202e-01, ELBO: -3.188e+05
# Cur diff delta = 45.97328567504883
# Cur diff sigma = 2.1489574909210205
# Cur diff theta = 48.12224316596985
# ---------------------------------------
# IAF, d: 50, Iter: 1-960, s/iter: 1.175e-01, ELBO: -3.188e+05
# Cur diff delta = 45.98712158203125
# Cur diff sigma = 2.1485588550567627
# Cur diff theta = 48.13568043708801
# ---------------------------------------
# IAF, d: 50, Iter: 1-980, s/iter: 1.093e-01, ELBO: -3.188e+05
# Cur diff delta = 45.97531509399414
# Cur diff sigma = 2.148952007293701
# Cur diff theta = 48.12426710128784
# ---------------------------------------
# IAF, d: 50, Iter: 1-1000, s/iter: 1.097e-01, ELBO: -3.188e+05
# Cur diff delta = 45.97368621826172
# Cur diff sigma = 2.1493775844573975
# Cur diff theta = 48.123063802719116
# ---------------------------------------
# IAF, d: 50, Iter: 1-1020, s/iter: 1.103e-01, ELBO: -3.188e+05
# Cur diff delta = 45.9753532409668
# Cur diff sigma = 2.1488988399505615
# Cur diff theta = 48.12425208091736
# ---------------------------------------
# IAF, d: 50, Iter: 1-1040, s/iter: 1.234e-01, ELBO: -3.188e+05
# Cur diff delta = 45.97072982788086
# Cur diff sigma = 2.149531364440918
# Cur diff theta = 48.12026119232178
# ---------------------------------------
# IAF, d: 50, Iter: 1-1060, s/iter: 1.114e-01, ELBO: -3.188e+05
# Cur diff delta = 45.97529602050781
# Cur diff sigma = 2.149752616882324
# Cur diff theta = 48.12504863739014
# ---------------------------------------
# IAF, d: 50, Iter: 1-1080, s/iter: 1.123e-01, ELBO: -3.188e+05
# Cur diff delta = 45.983253479003906
# Cur diff sigma = 2.148876905441284
# Cur diff theta = 48.13213038444519
# ---------------------------------------
# IAF, d: 50, Iter: 1-1100, s/iter: 1.222e-01, ELBO: -3.188e+05
# Cur diff delta = 45.98481750488281
# Cur diff sigma = 2.148913860321045
# Cur diff theta = 48.13373136520386
# ---------------------------------------
# IAF, d: 50, Iter: 1-1120, s/iter: 1.121e-01, ELBO: -3.188e+05
# Cur diff delta = 45.98820114135742
# Cur diff sigma = 2.1484646797180176
# Cur diff theta = 48.13666582107544
# ---------------------------------------
# IAF, d: 50, Iter: 1-1140, s/iter: 1.168e-01, ELBO: -3.188e+05
# Cur diff delta = 45.97509002685547
# Cur diff sigma = 2.149204969406128
# Cur diff theta = 48.1242949962616
# ---------------------------------------
# IAF, d: 50, Iter: 1-1160, s/iter: 1.137e-01, ELBO: -3.188e+05
# Cur diff delta = 45.98091506958008
# Cur diff sigma = 2.1497843265533447
# Cur diff theta = 48.13069939613342
# ---------------------------------------
# IAF, d: 50, Iter: 1-1180, s/iter: 1.140e-01, ELBO: -3.188e+05
# Cur diff delta = 45.97349548339844
# Cur diff sigma = 2.14927077293396
# Cur diff theta = 48.1227662563324
# ---------------------------------------
# IAF, d: 50, Iter: 1-1200, s/iter: 1.158e-01, ELBO: -3.188e+05
# Cur diff delta = 45.977195739746094
# Cur diff sigma = 2.148979902267456
# Cur diff theta = 48.12617564201355
# ---------------------------------------
# IAF, d: 50, Iter: 1-1220, s/iter: 1.180e-01, ELBO: -3.188e+05
# Cur diff delta = 45.98207473754883
# Cur diff sigma = 2.1493661403656006
# Cur diff theta = 48.13144087791443
# ---------------------------------------
# IAF, d: 50, Iter: 1-1240, s/iter: 1.120e-01, ELBO: -3.188e+05
# Cur diff delta = 45.97493362426758
# Cur diff sigma = 2.14894437789917
# Cur diff theta = 48.12387800216675
# ---------------------------------------
# IAF, d: 50, Iter: 1-1260, s/iter: 1.118e-01, ELBO: -3.188e+05
# Cur diff delta = 45.979698181152344
# Cur diff sigma = 2.1492931842803955
# Cur diff theta = 48.12899136543274
# ---------------------------------------
# IAF, d: 50, Iter: 1-1280, s/iter: 1.213e-01, ELBO: -3.188e+05
# Cur diff delta = 45.980777740478516
# Cur diff sigma = 2.149509906768799
# Cur diff theta = 48.130287647247314
# ---------------------------------------
# IAF, d: 50, Iter: 1-1300, s/iter: 1.115e-01, ELBO: -3.188e+05
# Cur diff delta = 45.979122161865234
# Cur diff sigma = 2.14896821975708
# Cur diff theta = 48.128090381622314
# ---------------------------------------
# IAF, d: 50, Iter: 1-1320, s/iter: 1.125e-01, ELBO: -3.188e+05
# Cur diff delta = 45.960201263427734
# Cur diff sigma = 2.1488661766052246
# Cur diff theta = 48.10906744003296
# ---------------------------------------
# IAF, d: 50, Iter: 1-1340, s/iter: 1.134e-01, ELBO: -3.188e+05
# Cur diff delta = 45.971771240234375
# Cur diff sigma = 2.149793863296509
# Cur diff theta = 48.121565103530884
# ---------------------------------------
# IAF, d: 50, Iter: 1-1360, s/iter: 1.177e-01, ELBO: -3.188e+05
# Cur diff delta = 45.97517776489258
# Cur diff sigma = 2.1493468284606934
# Cur diff theta = 48.12452459335327
# ---------------------------------------
# IAF, d: 50, Iter: 1-1380, s/iter: 1.150e-01, ELBO: -3.188e+05
# Cur diff delta = 45.971458435058594
# Cur diff sigma = 2.149613857269287
# Cur diff theta = 48.12107229232788
# ---------------------------------------
# IAF, d: 50, Iter: 1-1400, s/iter: 1.230e-01, ELBO: -3.188e+05
# Cur diff delta = 45.972198486328125
# Cur diff sigma = 2.149334669113159
# Cur diff theta = 48.121533155441284
# ---------------------------------------
# IAF, d: 50, Iter: 1-1420, s/iter: 1.259e-01, ELBO: -3.187e+05
# Cur diff delta = 45.977203369140625
# Cur diff sigma = 2.149394989013672
# Cur diff theta = 48.1265983581543
# ---------------------------------------
# IAF, d: 50, Iter: 1-1440, s/iter: 1.106e-01, ELBO: -3.188e+05
# Cur diff delta = 45.97816848754883
# Cur diff sigma = 2.1490402221679688
# Cur diff theta = 48.1272087097168
# ---------------------------------------
# IAF, d: 50, Iter: 1-1460, s/iter: 1.130e-01, ELBO: -3.188e+05
# Cur diff delta = 45.9730110168457
# Cur diff sigma = 2.1489410400390625
# Cur diff theta = 48.121952056884766
# ---------------------------------------
# IAF, d: 50, Iter: 1-1480, s/iter: 1.169e-01, ELBO: -3.188e+05
# Cur diff delta = 45.97666549682617
# Cur diff sigma = 2.149202823638916
# Cur diff theta = 48.12586832046509
# ---------------------------------------
# IAF, d: 50, Iter: 1-1500, s/iter: 1.130e-01, ELBO: -3.188e+05
# Cur diff delta = 45.983577728271484
# Cur diff sigma = 2.149447441101074
# Cur diff theta = 48.13302516937256
# ---------------------------------------
# IAF, d: 50, Iter: 1-1520, s/iter: 1.170e-01, ELBO: -3.188e+05
# Cur diff delta = 45.97044372558594
# Cur diff sigma = 2.148763418197632
# Cur diff theta = 48.11920714378357
# ---------------------------------------
# IAF, d: 50, Iter: 1-1540, s/iter: 1.258e-01, ELBO: -3.188e+05
# Cur diff delta = 45.977725982666016
# Cur diff sigma = 2.149413585662842
# Cur diff theta = 48.12713956832886
# ---------------------------------------
# IAF, d: 50, Iter: 1-1560, s/iter: 1.192e-01, ELBO: -3.188e+05
# Cur diff delta = 45.98768615722656
# Cur diff sigma = 2.1492249965667725
# Cur diff theta = 48.136911153793335
# ---------------------------------------
# IAF, d: 50, Iter: 1-1580, s/iter: 1.199e-01, ELBO: -3.188e+05
# Cur diff delta = 45.97336959838867
# Cur diff sigma = 2.1490609645843506
# Cur diff theta = 48.12243056297302
# ---------------------------------------
# IAF, d: 50, Iter: 1-1600, s/iter: 1.244e-01, ELBO: -3.188e+05
# Cur diff delta = 45.97551345825195
# Cur diff sigma = 2.149590492248535
# Cur diff theta = 48.12510395050049
# ---------------------------------------
# IAF, d: 50, Iter: 1-1620, s/iter: 1.161e-01, ELBO: -3.188e+05
# Cur diff delta = 45.9757080078125
# Cur diff sigma = 2.1487271785736084
# Cur diff theta = 48.12443518638611
# ---------------------------------------
# IAF, d: 50, Iter: 1-1640, s/iter: 1.166e-01, ELBO: -3.188e+05
# Cur diff delta = 45.97104263305664
# Cur diff sigma = 2.149596929550171
# Cur diff theta = 48.12063956260681
# ---------------------------------------
# IAF, d: 50, Iter: 1-1660, s/iter: 1.171e-01, ELBO: -3.188e+05
# Cur diff delta = 45.978790283203125
# Cur diff sigma = 2.1490886211395264
# Cur diff theta = 48.12787890434265
# ---------------------------------------
# IAF, d: 50, Iter: 1-1680, s/iter: 1.197e-01, ELBO: -3.188e+05
# Cur diff delta = 45.98301696777344
# Cur diff sigma = 2.1491470336914062
# Cur diff theta = 48.132164001464844
# ---------------------------------------
# IAF, d: 50, Iter: 1-1700, s/iter: 1.176e-01, ELBO: -3.187e+05
# Cur diff delta = 45.979026794433594
# Cur diff sigma = 2.1490230560302734
# Cur diff theta = 48.12804985046387
# ---------------------------------------
# IAF, d: 50, Iter: 1-1720, s/iter: 1.185e-01, ELBO: -3.188e+05
# Cur diff delta = 45.97737503051758
# Cur diff sigma = 2.148752450942993
# Cur diff theta = 48.12612748146057
# ---------------------------------------
# IAF, d: 50, Iter: 1-1740, s/iter: 1.260e-01, ELBO: -3.188e+05
# Cur diff delta = 45.97677230834961
# Cur diff sigma = 2.1490180492401123
# Cur diff theta = 48.12579035758972
# ---------------------------------------
# IAF, d: 50, Iter: 1-1760, s/iter: 1.323e-01, ELBO: -3.188e+05
# Cur diff delta = 45.971580505371094
# Cur diff sigma = 2.149261951446533
# Cur diff theta = 48.12084245681763
# ---------------------------------------
# IAF, d: 50, Iter: 1-1780, s/iter: 1.262e-01, ELBO: -3.188e+05
# Cur diff delta = 45.976844787597656
# Cur diff sigma = 2.1488239765167236
# Cur diff theta = 48.12566876411438
# ---------------------------------------
# IAF, d: 50, Iter: 1-1800, s/iter: 1.153e-01, ELBO: -3.188e+05
# Cur diff delta = 45.97867965698242
# Cur diff sigma = 2.148676633834839
# Cur diff theta = 48.12735629081726
# ---------------------------------------
# IAF, d: 50, Iter: 1-1820, s/iter: 1.209e-01, ELBO: -3.188e+05
# Cur diff delta = 45.974281311035156
# Cur diff sigma = 2.1486337184906006
# Cur diff theta = 48.12291502952576
# ---------------------------------------
# IAF, d: 50, Iter: 1-1840, s/iter: 1.232e-01, ELBO: -3.188e+05
# Cur diff delta = 45.96630096435547
# Cur diff sigma = 2.148895740509033
# Cur diff theta = 48.1151967048645
# ---------------------------------------
# IAF, d: 50, Iter: 1-1860, s/iter: 1.143e-01, ELBO: -3.188e+05
# Cur diff delta = 45.974334716796875
# Cur diff sigma = 2.14927077293396
# Cur diff theta = 48.123605489730835
# ---------------------------------------
# IAF, d: 50, Iter: 1-1880, s/iter: 1.140e-01, ELBO: -3.188e+05
# Cur diff delta = 45.965518951416016
# Cur diff sigma = 2.1491427421569824
# Cur diff theta = 48.114661693573
# ---------------------------------------
# IAF, d: 50, Iter: 1-1900, s/iter: 1.230e-01, ELBO: -3.188e+05
# Cur diff delta = 45.97256088256836
# Cur diff sigma = 2.1492233276367188
# Cur diff theta = 48.12178421020508
# ---------------------------------------
# IAF, d: 50, Iter: 1-1920, s/iter: 1.204e-01, ELBO: -3.188e+05
# Cur diff delta = 45.97685623168945
# Cur diff sigma = 2.1488659381866455
# Cur diff theta = 48.1257221698761
# ---------------------------------------
# IAF, d: 50, Iter: 1-1940, s/iter: 1.208e-01, ELBO: -3.188e+05
# Cur diff delta = 45.97313690185547
# Cur diff sigma = 2.148988723754883
# Cur diff theta = 48.12212562561035
# ---------------------------------------
# IAF, d: 50, Iter: 1-1960, s/iter: 1.260e-01, ELBO: -3.188e+05
# Cur diff delta = 45.980186462402344
# Cur diff sigma = 2.148972749710083
# Cur diff theta = 48.12915921211243
# ---------------------------------------
# IAF, d: 50, Iter: 1-1980, s/iter: 1.190e-01, ELBO: -3.188e+05
# Cur diff delta = 45.94950866699219
# Cur diff sigma = 2.1490378379821777
# Cur diff theta = 48.098546504974365
# ---------------------------------------
# IAF, d: 50, Iter: 1-2000, s/iter: 1.198e-01, ELBO: -3.188e+05
# Cur diff delta = 45.97723388671875
# Cur diff sigma = 2.1491830348968506
# Cur diff theta = 48.1264169216156
# ---------------------------------------
# ------------------------------------------------------
# Test = 1
# ------------------------------------------------------
# Init diff delta = 416.5
# Init diff sigma = 19355.818359375
# Init diff theta = 19772.318359375
# IAF, d: 50, Iter: 2-20, s/iter: 9.517e-02, ELBO: -1.546e+06
# Cur diff delta = 223.3498077392578
# Cur diff sigma = 2956.652099609375
# Cur diff theta = 3180.001907348633
# ---------------------------------------
# IAF, d: 50, Iter: 2-40, s/iter: 9.346e-02, ELBO: -1.193e+06
# Cur diff delta = 118.97163391113281
# Cur diff sigma = 566.8321533203125
# Cur diff theta = 685.8037872314453
# ---------------------------------------
# IAF, d: 50, Iter: 2-60, s/iter: 9.761e-02, ELBO: -8.653e+05
# Cur diff delta = 66.27911376953125
# Cur diff sigma = 119.34447479248047
# Cur diff theta = 185.62358856201172
# ---------------------------------------
# IAF, d: 50, Iter: 2-80, s/iter: 9.857e-02, ELBO: -5.775e+05
# Cur diff delta = 44.337249755859375
# Cur diff sigma = 30.115947723388672
# Cur diff theta = 74.45319747924805
# ---------------------------------------
# IAF, d: 50, Iter: 2-100, s/iter: 9.371e-02, ELBO: -3.972e+05
# Cur diff delta = 40.01188278198242
# Cur diff sigma = 9.333976745605469
# Cur diff theta = 49.34585952758789
# ---------------------------------------
# IAF, d: 50, Iter: 2-120, s/iter: 1.074e-01, ELBO: -3.295e+05
# Cur diff delta = 43.576080322265625
# Cur diff sigma = 3.789829969406128
# Cur diff theta = 47.36591029167175
# ---------------------------------------
# IAF, d: 50, Iter: 2-140, s/iter: 1.105e-01, ELBO: -3.212e+05
# Cur diff delta = 47.74742126464844
# Cur diff sigma = 2.4103810787200928
# Cur diff theta = 50.15780234336853
# ---------------------------------------
# IAF, d: 50, Iter: 2-160, s/iter: 1.080e-01, ELBO: -3.197e+05
# Cur diff delta = 50.17890548706055
# Cur diff sigma = 2.1946475505828857
# Cur diff theta = 52.37355303764343
# ---------------------------------------
# IAF, d: 50, Iter: 2-180, s/iter: 9.655e-02, ELBO: -3.196e+05
# Cur diff delta = 50.530433654785156
# Cur diff sigma = 2.1892857551574707
# Cur diff theta = 52.71971940994263
# ---------------------------------------
# IAF, d: 50, Iter: 2-200, s/iter: 9.992e-02, ELBO: -3.196e+05
# Cur diff delta = 50.52080535888672
# Cur diff sigma = 2.1894211769104004
# Cur diff theta = 52.71022653579712
# ---------------------------------------
# IAF, d: 50, Iter: 2-220, s/iter: 1.075e-01, ELBO: -3.196e+05
# Cur diff delta = 50.5216178894043
# Cur diff sigma = 2.1891512870788574
# Cur diff theta = 52.710769176483154
# ---------------------------------------
# IAF, d: 50, Iter: 2-240, s/iter: 1.104e-01, ELBO: -3.195e+05
# Cur diff delta = 50.52359390258789
# Cur diff sigma = 2.1886701583862305
# Cur diff theta = 52.71226406097412
# ---------------------------------------
# IAF, d: 50, Iter: 2-260, s/iter: 1.065e-01, ELBO: -3.196e+05
# Cur diff delta = 50.51877212524414
# Cur diff sigma = 2.189051628112793
# Cur diff theta = 52.707823753356934
# ---------------------------------------
# IAF, d: 50, Iter: 2-280, s/iter: 1.025e-01, ELBO: -3.195e+05
# Cur diff delta = 50.52574157714844
# Cur diff sigma = 2.1888725757598877
# Cur diff theta = 52.714614152908325
# ---------------------------------------
# IAF, d: 50, Iter: 2-300, s/iter: 1.151e-01, ELBO: -3.195e+05
# Cur diff delta = 50.517513275146484
# Cur diff sigma = 2.189084768295288
# Cur diff theta = 52.70659804344177
# ---------------------------------------
# IAF, d: 50, Iter: 2-320, s/iter: 9.956e-02, ELBO: -3.195e+05
# Cur diff delta = 50.51890563964844
# Cur diff sigma = 2.188323974609375
# Cur diff theta = 52.70722961425781
# ---------------------------------------
# IAF, d: 50, Iter: 2-340, s/iter: 1.004e-01, ELBO: -3.195e+05
# Cur diff delta = 50.51927185058594
# Cur diff sigma = 2.1886050701141357
# Cur diff theta = 52.70787692070007
# ---------------------------------------
# IAF, d: 50, Iter: 2-360, s/iter: 9.802e-02, ELBO: -3.195e+05
# Cur diff delta = 50.52705383300781
# Cur diff sigma = 2.188471555709839
# Cur diff theta = 52.71552538871765
# ---------------------------------------
# IAF, d: 50, Iter: 2-380, s/iter: 1.002e-01, ELBO: -3.195e+05
# Cur diff delta = 50.52699279785156
# Cur diff sigma = 2.1879923343658447
# Cur diff theta = 52.71498513221741
# ---------------------------------------
# IAF, d: 50, Iter: 2-400, s/iter: 1.022e-01, ELBO: -3.195e+05
# Cur diff delta = 50.52777862548828
# Cur diff sigma = 2.1884191036224365
# Cur diff theta = 52.71619772911072
# ---------------------------------------
# IAF, d: 50, Iter: 2-420, s/iter: 1.204e-01, ELBO: -3.195e+05
# Cur diff delta = 50.5250358581543
# Cur diff sigma = 2.1882693767547607
# Cur diff theta = 52.71330523490906
# ---------------------------------------
# IAF, d: 50, Iter: 2-440, s/iter: 1.028e-01, ELBO: -3.195e+05
# Cur diff delta = 50.51713943481445
# Cur diff sigma = 2.1882872581481934
# Cur diff theta = 52.70542669296265
# ---------------------------------------
# IAF, d: 50, Iter: 2-460, s/iter: 1.116e-01, ELBO: -3.195e+05
# Cur diff delta = 50.517494201660156
# Cur diff sigma = 2.188018798828125
# Cur diff theta = 52.70551300048828
# ---------------------------------------
# IAF, d: 50, Iter: 2-480, s/iter: 1.076e-01, ELBO: -3.195e+05
# Cur diff delta = 50.525787353515625
# Cur diff sigma = 2.1880557537078857
# Cur diff theta = 52.71384310722351
# ---------------------------------------
# IAF, d: 50, Iter: 2-500, s/iter: 1.058e-01, ELBO: -3.195e+05
# Cur diff delta = 50.52106857299805
# Cur diff sigma = 2.1883974075317383
# Cur diff theta = 52.709465980529785
# ---------------------------------------
# IAF, d: 50, Iter: 2-520, s/iter: 1.110e-01, ELBO: -3.195e+05
# Cur diff delta = 50.523719787597656
# Cur diff sigma = 2.187835216522217
# Cur diff theta = 52.71155500411987
# ---------------------------------------
# IAF, d: 50, Iter: 2-540, s/iter: 1.298e-01, ELBO: -3.195e+05
# Cur diff delta = 50.521541595458984
# Cur diff sigma = 2.1885313987731934
# Cur diff theta = 52.71007299423218
# ---------------------------------------
# IAF, d: 50, Iter: 2-560, s/iter: 1.123e-01, ELBO: -3.195e+05
# Cur diff delta = 50.51393508911133
# Cur diff sigma = 2.187680959701538
# Cur diff theta = 52.701616048812866
# ---------------------------------------
# IAF, d: 50, Iter: 2-580, s/iter: 1.166e-01, ELBO: -3.195e+05
# Cur diff delta = 50.533851623535156
# Cur diff sigma = 2.188538074493408
# Cur diff theta = 52.722389698028564
# ---------------------------------------
# IAF, d: 50, Iter: 2-600, s/iter: 1.115e-01, ELBO: -3.195e+05
# Cur diff delta = 50.52906799316406
# Cur diff sigma = 2.1878714561462402
# Cur diff theta = 52.7169394493103
# ---------------------------------------
# IAF, d: 50, Iter: 2-620, s/iter: 1.153e-01, ELBO: -3.195e+05
# Cur diff delta = 50.525291442871094
# Cur diff sigma = 2.1884360313415527
# Cur diff theta = 52.71372747421265
# ---------------------------------------
# IAF, d: 50, Iter: 2-640, s/iter: 1.160e-01, ELBO: -3.195e+05
# Cur diff delta = 50.52428436279297
# Cur diff sigma = 2.1879589557647705
# Cur diff theta = 52.71224331855774
# ---------------------------------------
# IAF, d: 50, Iter: 2-660, s/iter: 1.199e-01, ELBO: -3.195e+05
# Cur diff delta = 50.532371520996094
# Cur diff sigma = 2.187810182571411
# Cur diff theta = 52.720181703567505
# ---------------------------------------
# IAF, d: 50, Iter: 2-680, s/iter: 1.202e-01, ELBO: -3.195e+05
# Cur diff delta = 50.52619552612305
# Cur diff sigma = 2.187324047088623
# Cur diff theta = 52.71351957321167
# ---------------------------------------
# IAF, d: 50, Iter: 2-700, s/iter: 1.329e-01, ELBO: -3.195e+05
# Cur diff delta = 50.53229522705078
# Cur diff sigma = 2.188443183898926
# Cur diff theta = 52.72073841094971
# ---------------------------------------
# IAF, d: 50, Iter: 2-720, s/iter: 1.167e-01, ELBO: -3.195e+05
# Cur diff delta = 50.52865219116211
# Cur diff sigma = 2.1883270740509033
# Cur diff theta = 52.71697926521301
# ---------------------------------------
# IAF, d: 50, Iter: 2-740, s/iter: 1.241e-01, ELBO: -3.195e+05
# Cur diff delta = 50.51763916015625
# Cur diff sigma = 2.1882078647613525
# Cur diff theta = 52.7058470249176
# ---------------------------------------
# IAF, d: 50, Iter: 2-760, s/iter: 1.174e-01, ELBO: -3.194e+05
# Cur diff delta = 50.517276763916016
# Cur diff sigma = 2.1872174739837646
# Cur diff theta = 52.70449423789978
# ---------------------------------------
# IAF, d: 50, Iter: 2-780, s/iter: 1.167e-01, ELBO: -3.194e+05
# Cur diff delta = 50.53224563598633
# Cur diff sigma = 2.1873302459716797
# Cur diff theta = 52.71957588195801
# ---------------------------------------
# IAF, d: 50, Iter: 2-800, s/iter: 1.164e-01, ELBO: -3.195e+05
# Cur diff delta = 50.53026580810547
# Cur diff sigma = 2.1880524158477783
# Cur diff theta = 52.71831822395325
# ---------------------------------------
# IAF, d: 50, Iter: 2-820, s/iter: 1.145e-01, ELBO: -3.195e+05
# Cur diff delta = 50.52802276611328
# Cur diff sigma = 2.188617706298828
# Cur diff theta = 52.71664047241211
# ---------------------------------------
# IAF, d: 50, Iter: 2-840, s/iter: 1.138e-01, ELBO: -3.195e+05
# Cur diff delta = 50.53873062133789
# Cur diff sigma = 2.1885931491851807
# Cur diff theta = 52.72732377052307
# ---------------------------------------
# IAF, d: 50, Iter: 2-860, s/iter: 1.163e-01, ELBO: -3.195e+05
# Cur diff delta = 50.533382415771484
# Cur diff sigma = 2.1880855560302734
# Cur diff theta = 52.72146797180176
# ---------------------------------------
# IAF, d: 50, Iter: 2-880, s/iter: 1.173e-01, ELBO: -3.195e+05
# Cur diff delta = 50.533424377441406
# Cur diff sigma = 2.187873363494873
# Cur diff theta = 52.72129774093628
# ---------------------------------------
# IAF, d: 50, Iter: 2-900, s/iter: 1.180e-01, ELBO: -3.194e+05
# Cur diff delta = 50.546573638916016
# Cur diff sigma = 2.1876397132873535
# Cur diff theta = 52.73421335220337
# ---------------------------------------
# IAF, d: 50, Iter: 2-920, s/iter: 1.186e-01, ELBO: -3.195e+05
# Cur diff delta = 50.52681350708008
# Cur diff sigma = 2.187626361846924
# Cur diff theta = 52.714439868927
# ---------------------------------------
# IAF, d: 50, Iter: 2-940, s/iter: 1.194e-01, ELBO: -3.195e+05
# Cur diff delta = 50.521949768066406
# Cur diff sigma = 2.1880784034729004
# Cur diff theta = 52.71002817153931
# ---------------------------------------
# IAF, d: 50, Iter: 2-960, s/iter: 1.226e-01, ELBO: -3.194e+05
# Cur diff delta = 50.524635314941406
# Cur diff sigma = 2.187743663787842
# Cur diff theta = 52.71237897872925
# ---------------------------------------
# IAF, d: 50, Iter: 2-980, s/iter: 1.205e-01, ELBO: -3.195e+05
# Cur diff delta = 50.53374481201172
# Cur diff sigma = 2.1880767345428467
# Cur diff theta = 52.721821546554565
# ---------------------------------------
# IAF, d: 50, Iter: 2-1000, s/iter: 1.160e-01, ELBO: -3.195e+05
# Cur diff delta = 50.51985549926758
# Cur diff sigma = 2.18796443939209
# Cur diff theta = 52.70781993865967
# ---------------------------------------
# IAF, d: 50, Iter: 2-1020, s/iter: 1.177e-01, ELBO: -3.195e+05
# Cur diff delta = 50.52965545654297
# Cur diff sigma = 2.187122344970703
# Cur diff theta = 52.71677780151367
# ---------------------------------------
# IAF, d: 50, Iter: 2-1040, s/iter: 1.188e-01, ELBO: -3.195e+05
# Cur diff delta = 50.524906158447266
# Cur diff sigma = 2.187473773956299
# Cur diff theta = 52.712379932403564
# ---------------------------------------
# IAF, d: 50, Iter: 2-1060, s/iter: 1.198e-01, ELBO: -3.195e+05
# Cur diff delta = 50.53273010253906
# Cur diff sigma = 2.187856674194336
# Cur diff theta = 52.7205867767334
# ---------------------------------------
# IAF, d: 50, Iter: 2-1080, s/iter: 1.248e-01, ELBO: -3.195e+05
# Cur diff delta = 50.53489685058594
# Cur diff sigma = 2.1877408027648926
# Cur diff theta = 52.72263765335083
# ---------------------------------------
# IAF, d: 50, Iter: 2-1100, s/iter: 1.145e-01, ELBO: -3.195e+05
# Cur diff delta = 50.52836227416992
# Cur diff sigma = 2.187962770462036
# Cur diff theta = 52.71632504463196
# ---------------------------------------
# IAF, d: 50, Iter: 2-1120, s/iter: 1.224e-01, ELBO: -3.195e+05
# Cur diff delta = 50.53514099121094
# Cur diff sigma = 2.1879935264587402
# Cur diff theta = 52.72313451766968
# ---------------------------------------
# IAF, d: 50, Iter: 2-1140, s/iter: 1.281e-01, ELBO: -3.195e+05
# Cur diff delta = 50.52812576293945
# Cur diff sigma = 2.187652587890625
# Cur diff theta = 52.71577835083008
# ---------------------------------------
# IAF, d: 50, Iter: 2-1160, s/iter: 1.241e-01, ELBO: -3.194e+05
# Cur diff delta = 50.530460357666016
# Cur diff sigma = 2.1878700256347656
# Cur diff theta = 52.71833038330078
# ---------------------------------------
# IAF, d: 50, Iter: 2-1180, s/iter: 1.226e-01, ELBO: -3.195e+05
# Cur diff delta = 50.53029251098633
# Cur diff sigma = 2.187875747680664
# Cur diff theta = 52.71816825866699
# ---------------------------------------
# IAF, d: 50, Iter: 2-1200, s/iter: 1.207e-01, ELBO: -3.195e+05
# Cur diff delta = 50.529537200927734
# Cur diff sigma = 2.187882423400879
# Cur diff theta = 52.71741962432861
# ---------------------------------------
# IAF, d: 50, Iter: 2-1220, s/iter: 1.158e-01, ELBO: -3.195e+05
# Cur diff delta = 50.51797103881836
# Cur diff sigma = 2.187771797180176
# Cur diff theta = 52.705742835998535
# ---------------------------------------
# IAF, d: 50, Iter: 2-1240, s/iter: 1.155e-01, ELBO: -3.195e+05
# Cur diff delta = 50.52730941772461
# Cur diff sigma = 2.1883327960968018
# Cur diff theta = 52.71564221382141
# ---------------------------------------
# IAF, d: 50, Iter: 2-1260, s/iter: 1.159e-01, ELBO: -3.194e+05
# Cur diff delta = 50.52526092529297
# Cur diff sigma = 2.1874213218688965
# Cur diff theta = 52.712682247161865
# ---------------------------------------
# IAF, d: 50, Iter: 2-1280, s/iter: 1.251e-01, ELBO: -3.194e+05
# Cur diff delta = 50.52592086791992
# Cur diff sigma = 2.187978744506836
# Cur diff theta = 52.71389961242676
# ---------------------------------------
# IAF, d: 50, Iter: 2-1300, s/iter: 1.221e-01, ELBO: -3.194e+05
# Cur diff delta = 50.541664123535156
# Cur diff sigma = 2.186976432800293
# Cur diff theta = 52.72864055633545
# ---------------------------------------
# IAF, d: 50, Iter: 2-1320, s/iter: 1.172e-01, ELBO: -3.194e+05
# Cur diff delta = 50.534210205078125
# Cur diff sigma = 2.1877827644348145
# Cur diff theta = 52.72199296951294
# ---------------------------------------
# IAF, d: 50, Iter: 2-1340, s/iter: 1.197e-01, ELBO: -3.195e+05
# Cur diff delta = 50.53388977050781
# Cur diff sigma = 2.187268018722534
# Cur diff theta = 52.72115778923035
# ---------------------------------------
# IAF, d: 50, Iter: 2-1360, s/iter: 1.197e-01, ELBO: -3.194e+05
# Cur diff delta = 50.520423889160156
# Cur diff sigma = 2.18681001663208
# Cur diff theta = 52.707233905792236
# ---------------------------------------
# IAF, d: 50, Iter: 2-1380, s/iter: 1.202e-01, ELBO: -3.194e+05
# Cur diff delta = 50.51961135864258
# Cur diff sigma = 2.187352180480957
# Cur diff theta = 52.706963539123535
# ---------------------------------------
# IAF, d: 50, Iter: 2-1400, s/iter: 1.190e-01, ELBO: -3.195e+05
# Cur diff delta = 50.52497100830078
# Cur diff sigma = 2.1881744861602783
# Cur diff theta = 52.71314549446106
# ---------------------------------------
# IAF, d: 50, Iter: 2-1420, s/iter: 1.217e-01, ELBO: -3.195e+05
# Cur diff delta = 50.532325744628906
# Cur diff sigma = 2.187412977218628
# Cur diff theta = 52.719738721847534
# ---------------------------------------
# IAF, d: 50, Iter: 2-1440, s/iter: 1.239e-01, ELBO: -3.195e+05
# Cur diff delta = 50.53754806518555
# Cur diff sigma = 2.1878914833068848
# Cur diff theta = 52.72543954849243
# ---------------------------------------
# IAF, d: 50, Iter: 2-1460, s/iter: 1.226e-01, ELBO: -3.194e+05
# Cur diff delta = 50.53165054321289
# Cur diff sigma = 2.187699317932129
# Cur diff theta = 52.71934986114502
# ---------------------------------------
# IAF, d: 50, Iter: 2-1480, s/iter: 1.173e-01, ELBO: -3.195e+05
# Cur diff delta = 50.52716827392578
# Cur diff sigma = 2.187697410583496
# Cur diff theta = 52.71486568450928
# ---------------------------------------
# IAF, d: 50, Iter: 2-1500, s/iter: 1.272e-01, ELBO: -3.194e+05
# Cur diff delta = 50.5168342590332
# Cur diff sigma = 2.187609910964966
# Cur diff theta = 52.70444416999817
# ---------------------------------------
# IAF, d: 50, Iter: 2-1520, s/iter: 1.238e-01, ELBO: -3.194e+05
# Cur diff delta = 50.523250579833984
# Cur diff sigma = 2.187079668045044
# Cur diff theta = 52.71033024787903
# ---------------------------------------
# IAF, d: 50, Iter: 2-1540, s/iter: 1.295e-01, ELBO: -3.194e+05
# Cur diff delta = 50.531620025634766
# Cur diff sigma = 2.1875433921813965
# Cur diff theta = 52.71916341781616
# ---------------------------------------
# IAF, d: 50, Iter: 2-1560, s/iter: 1.186e-01, ELBO: -3.195e+05
# Cur diff delta = 50.5318603515625
# Cur diff sigma = 2.1877572536468506
# Cur diff theta = 52.71961760520935
# ---------------------------------------
# IAF, d: 50, Iter: 2-1580, s/iter: 1.177e-01, ELBO: -3.194e+05
# Cur diff delta = 50.52610778808594
# Cur diff sigma = 2.1872732639312744
# Cur diff theta = 52.71338105201721
# ---------------------------------------
# IAF, d: 50, Iter: 2-1600, s/iter: 1.260e-01, ELBO: -3.195e+05
# Cur diff delta = 50.520751953125
# Cur diff sigma = 2.187208890914917
# Cur diff theta = 52.70796084403992
# ---------------------------------------
# IAF, d: 50, Iter: 2-1620, s/iter: 1.290e-01, ELBO: -3.195e+05
# Cur diff delta = 50.511878967285156
# Cur diff sigma = 2.1879019737243652
# Cur diff theta = 52.69978094100952
# ---------------------------------------
# IAF, d: 50, Iter: 2-1640, s/iter: 1.331e-01, ELBO: -3.195e+05
# Cur diff delta = 50.54043960571289
# Cur diff sigma = 2.1874866485595703
# Cur diff theta = 52.72792625427246
# ---------------------------------------
# IAF, d: 50, Iter: 2-1660, s/iter: 1.232e-01, ELBO: -3.194e+05
# Cur diff delta = 50.523704528808594
# Cur diff sigma = 2.1869077682495117
# Cur diff theta = 52.710612297058105
# ---------------------------------------
# IAF, d: 50, Iter: 2-1680, s/iter: 1.211e-01, ELBO: -3.194e+05
# Cur diff delta = 50.53703308105469
# Cur diff sigma = 2.188035249710083
# Cur diff theta = 52.72506833076477
# ---------------------------------------
# IAF, d: 50, Iter: 2-1700, s/iter: 1.213e-01, ELBO: -3.194e+05
# Cur diff delta = 50.53813552856445
# Cur diff sigma = 2.1878550052642822
# Cur diff theta = 52.725990533828735
# ---------------------------------------
# IAF, d: 50, Iter: 2-1720, s/iter: 1.199e-01, ELBO: -3.195e+05
# Cur diff delta = 50.53015899658203
# Cur diff sigma = 2.187177896499634
# Cur diff theta = 52.717336893081665
# ---------------------------------------
# IAF, d: 50, Iter: 2-1740, s/iter: 1.253e-01, ELBO: -3.195e+05
# Cur diff delta = 50.53887939453125
# Cur diff sigma = 2.187248945236206
# Cur diff theta = 52.726128339767456
# ---------------------------------------
# IAF, d: 50, Iter: 2-1760, s/iter: 1.332e-01, ELBO: -3.194e+05
# Cur diff delta = 50.531009674072266
# Cur diff sigma = 2.1871492862701416
# Cur diff theta = 52.71815896034241
# ---------------------------------------
# IAF, d: 50, Iter: 2-1780, s/iter: 1.355e-01, ELBO: -3.194e+05
# Cur diff delta = 50.52510452270508
# Cur diff sigma = 2.186885118484497
# Cur diff theta = 52.711989641189575
# ---------------------------------------
# IAF, d: 50, Iter: 2-1800, s/iter: 1.228e-01, ELBO: -3.195e+05
# Cur diff delta = 50.53981399536133
# Cur diff sigma = 2.187617063522339
# Cur diff theta = 52.72743105888367
# ---------------------------------------
# IAF, d: 50, Iter: 2-1820, s/iter: 1.296e-01, ELBO: -3.194e+05
# Cur diff delta = 50.54450225830078
# Cur diff sigma = 2.187788248062134
# Cur diff theta = 52.732290506362915
# ---------------------------------------
# IAF, d: 50, Iter: 2-1840, s/iter: 1.239e-01, ELBO: -3.194e+05
# Cur diff delta = 50.52838897705078
# Cur diff sigma = 2.1873972415924072
# Cur diff theta = 52.71578621864319
# ---------------------------------------
# IAF, d: 50, Iter: 2-1860, s/iter: 1.201e-01, ELBO: -3.194e+05
# Cur diff delta = 50.5256233215332
# Cur diff sigma = 2.1875808238983154
# Cur diff theta = 52.71320414543152
# ---------------------------------------
# IAF, d: 50, Iter: 2-1880, s/iter: 1.291e-01, ELBO: -3.194e+05
# Cur diff delta = 50.53732681274414
# Cur diff sigma = 2.1873984336853027
# Cur diff theta = 52.72472524642944
# ---------------------------------------
# IAF, d: 50, Iter: 2-1900, s/iter: 1.224e-01, ELBO: -3.194e+05
# Cur diff delta = 50.533424377441406
# Cur diff sigma = 2.1877079010009766
# Cur diff theta = 52.72113227844238
# ---------------------------------------
# IAF, d: 50, Iter: 2-1920, s/iter: 1.257e-01, ELBO: -3.194e+05
# Cur diff delta = 50.5305061340332
# Cur diff sigma = 2.187413454055786
# Cur diff theta = 52.71791958808899
# ---------------------------------------
# IAF, d: 50, Iter: 2-1940, s/iter: 1.262e-01, ELBO: -3.194e+05
# Cur diff delta = 50.52265167236328
# Cur diff sigma = 2.187553882598877
# Cur diff theta = 52.71020555496216
# ---------------------------------------
# IAF, d: 50, Iter: 2-1960, s/iter: 1.167e-01, ELBO: -3.195e+05
# Cur diff delta = 50.52333068847656
# Cur diff sigma = 2.187950611114502
# Cur diff theta = 52.711281299591064
# ---------------------------------------
# IAF, d: 50, Iter: 2-1980, s/iter: 1.208e-01, ELBO: -3.194e+05
# Cur diff delta = 50.525142669677734
# Cur diff sigma = 2.187934398651123
# Cur diff theta = 52.71307706832886
# ---------------------------------------
# IAF, d: 50, Iter: 2-2000, s/iter: 1.275e-01, ELBO: -3.194e+05
# Cur diff delta = 50.5294303894043
# Cur diff sigma = 2.1874217987060547
# Cur diff theta = 52.71685218811035
# ---------------------------------------
# ------------------------------------------------------
# Test = 2
# ------------------------------------------------------
# Init diff delta = 416.5
# Init diff sigma = 19355.818359375
# Init diff theta = 19772.318359375
# IAF, d: 50, Iter: 3-20, s/iter: 1.006e-01, ELBO: -1.540e+06
# Cur diff delta = 227.84056091308594
# Cur diff sigma = 2951.441162109375
# Cur diff theta = 3179.281723022461
# ---------------------------------------
# IAF, d: 50, Iter: 3-40, s/iter: 9.600e-02, ELBO: -1.180e+06
# Cur diff delta = 124.51837921142578
# Cur diff sigma = 558.0646362304688
# Cur diff theta = 682.5830154418945
# ---------------------------------------
# IAF, d: 50, Iter: 3-60, s/iter: 9.420e-02, ELBO: -8.415e+05
# Cur diff delta = 71.68164825439453
# Cur diff sigma = 110.31272888183594
# Cur diff theta = 181.99437713623047
# ---------------------------------------
# IAF, d: 50, Iter: 3-80, s/iter: 1.068e-01, ELBO: -5.576e+05
# Cur diff delta = 51.80436325073242
# Cur diff sigma = 25.089078903198242
# Cur diff theta = 76.89344215393066
# ---------------------------------------
# IAF, d: 50, Iter: 3-100, s/iter: 1.039e-01, ELBO: -3.915e+05
# Cur diff delta = 46.4378662109375
# Cur diff sigma = 7.497995853424072
# Cur diff theta = 53.93586206436157
# ---------------------------------------
# IAF, d: 50, Iter: 3-120, s/iter: 1.084e-01, ELBO: -3.275e+05
# Cur diff delta = 48.29863739013672
# Cur diff sigma = 3.1624326705932617
# Cur diff theta = 51.46107006072998
# ---------------------------------------
# IAF, d: 50, Iter: 3-140, s/iter: 9.569e-02, ELBO: -3.206e+05
# Cur diff delta = 51.41313171386719
# Cur diff sigma = 2.241421699523926
# Cur diff theta = 53.65455341339111
# ---------------------------------------
# IAF, d: 50, Iter: 3-160, s/iter: 1.085e-01, ELBO: -3.198e+05
# Cur diff delta = 53.024532318115234
# Cur diff sigma = 2.1463778018951416
# Cur diff theta = 55.170910120010376
# ---------------------------------------
# IAF, d: 50, Iter: 3-180, s/iter: 9.491e-02, ELBO: -3.198e+05
# Cur diff delta = 53.120452880859375
# Cur diff sigma = 2.1459267139434814
# Cur diff theta = 55.266379594802856
# ---------------------------------------
# IAF, d: 50, Iter: 3-200, s/iter: 9.421e-02, ELBO: -3.197e+05
# Cur diff delta = 53.11172866821289
# Cur diff sigma = 2.1451797485351562
# Cur diff theta = 55.25690841674805
# ---------------------------------------
# IAF, d: 50, Iter: 3-220, s/iter: 9.785e-02, ELBO: -3.197e+05
# Cur diff delta = 53.11424255371094
# Cur diff sigma = 2.1450915336608887
# Cur diff theta = 55.259334087371826
# ---------------------------------------
# IAF, d: 50, Iter: 3-240, s/iter: 9.596e-02, ELBO: -3.197e+05
# Cur diff delta = 53.11500930786133
# Cur diff sigma = 2.1451473236083984
# Cur diff theta = 55.26015663146973
# ---------------------------------------
# IAF, d: 50, Iter: 3-260, s/iter: 9.479e-02, ELBO: -3.197e+05
# Cur diff delta = 53.12076187133789
# Cur diff sigma = 2.144496440887451
# Cur diff theta = 55.26525831222534
# ---------------------------------------
# IAF, d: 50, Iter: 3-280, s/iter: 9.483e-02, ELBO: -3.197e+05
# Cur diff delta = 53.11024475097656
# Cur diff sigma = 2.144157648086548
# Cur diff theta = 55.25440239906311
# ---------------------------------------
# IAF, d: 50, Iter: 3-300, s/iter: 9.881e-02, ELBO: -3.197e+05
# Cur diff delta = 53.11506271362305
# Cur diff sigma = 2.144578218460083
# Cur diff theta = 55.25964093208313
# ---------------------------------------
# IAF, d: 50, Iter: 3-320, s/iter: 1.084e-01, ELBO: -3.197e+05
# Cur diff delta = 53.10885238647461
# Cur diff sigma = 2.144402503967285
# Cur diff theta = 55.253254890441895
# ---------------------------------------
# IAF, d: 50, Iter: 3-340, s/iter: 1.034e-01, ELBO: -3.197e+05
# Cur diff delta = 53.114501953125
# Cur diff sigma = 2.1439907550811768
# Cur diff theta = 55.25849270820618
# ---------------------------------------
# IAF, d: 50, Iter: 3-360, s/iter: 1.016e-01, ELBO: -3.196e+05
# Cur diff delta = 53.11433792114258
# Cur diff sigma = 2.144213914871216
# Cur diff theta = 55.258551836013794
# ---------------------------------------
# IAF, d: 50, Iter: 3-380, s/iter: 1.093e-01, ELBO: -3.197e+05
# Cur diff delta = 53.1220703125
# Cur diff sigma = 2.1440184116363525
# Cur diff theta = 55.26608872413635
# ---------------------------------------
# IAF, d: 50, Iter: 3-400, s/iter: 1.153e-01, ELBO: -3.196e+05
# Cur diff delta = 53.11222839355469
# Cur diff sigma = 2.144026279449463
# Cur diff theta = 55.25625467300415
# ---------------------------------------
# IAF, d: 50, Iter: 3-420, s/iter: 1.053e-01, ELBO: -3.197e+05
# Cur diff delta = 53.121490478515625
# Cur diff sigma = 2.1439621448516846
# Cur diff theta = 55.26545262336731
# ---------------------------------------
# IAF, d: 50, Iter: 3-440, s/iter: 1.066e-01, ELBO: -3.196e+05
# Cur diff delta = 53.10402297973633
# Cur diff sigma = 2.14454984664917
# Cur diff theta = 55.2485728263855
# ---------------------------------------
# IAF, d: 50, Iter: 3-460, s/iter: 1.111e-01, ELBO: -3.196e+05
# Cur diff delta = 53.13045120239258
# Cur diff sigma = 2.1440298557281494
# Cur diff theta = 55.27448105812073
# ---------------------------------------
# IAF, d: 50, Iter: 3-480, s/iter: 1.130e-01, ELBO: -3.197e+05
# Cur diff delta = 53.1124153137207
# Cur diff sigma = 2.1437957286834717
# Cur diff theta = 55.256211042404175
# ---------------------------------------
# ...
# Cur diff sigma = 2.143939971923828
# Cur diff theta = 55.2613639831543
# ---------------------------------------
# IAF, d: 50, Iter: 3-540, s/iter: 1.164e-01, ELBO: -3.196e+05
# Cur diff delta = 53.12069320678711
# Cur diff sigma = 2.143587589263916
# Cur diff theta = 55.264280796051025
# ---------------------------------------
# IAF, d: 50, Iter: 3-560, s/iter: 1.227e-01, ELBO: -3.197e+05
# Cur diff delta = 53.1280517578125
# Cur diff sigma = 2.1439855098724365
# Cur diff theta = 55.27203726768494
# ---------------------------------------
# IAF, d: 50, Iter: 3-580, s/iter: 1.183e-01, ELBO: -3.196e+05
# Cur diff delta = 53.12194061279297
# Cur diff sigma = 2.143819808959961
# Cur diff theta = 55.26576042175293
# ---------------------------------------
# IAF, d: 50, Iter: 3-600, s/iter: 1.208e-01, ELBO: -3.196e+05
# Cur diff delta = 53.12372970581055
# Cur diff sigma = 2.1440916061401367
# Cur diff theta = 55.267821311950684
# ---------------------------------------
# IAF, d: 50, Iter: 3-620, s/iter: 1.139e-01, ELBO: -3.196e+05
# Cur diff delta = 53.10964584350586
# Cur diff sigma = 2.1447033882141113
# Cur diff theta = 55.25434923171997
# ---------------------------------------
# IAF, d: 50, Iter: 3-640, s/iter: 1.171e-01, ELBO: -3.197e+05
# Cur diff delta = 53.121158599853516
# Cur diff sigma = 2.1444129943847656
# Cur diff theta = 55.26557159423828
# ---------------------------------------
# IAF, d: 50, Iter: 3-660, s/iter: 1.127e-01, ELBO: -3.196e+05
# Cur diff delta = 53.0994758605957
# Cur diff sigma = 2.143500328063965
# Cur diff theta = 55.24297618865967
# ---------------------------------------
# IAF, d: 50, Iter: 3-680, s/iter: 1.116e-01, ELBO: -3.196e+05
# Cur diff delta = 53.112571716308594
# Cur diff sigma = 2.1433160305023193
# Cur diff theta = 55.25588774681091
# ---------------------------------------
# IAF, d: 50, Iter: 3-700, s/iter: 1.154e-01, ELBO: -3.196e+05
# Cur diff delta = 53.11532211303711
# Cur diff sigma = 2.1435954570770264
# Cur diff theta = 55.258917570114136
# ---------------------------------------
# IAF, d: 50, Iter: 3-720, s/iter: 1.145e-01, ELBO: -3.196e+05
# Cur diff delta = 53.118247985839844
# Cur diff sigma = 2.143867254257202
# Cur diff theta = 55.262115240097046
# ---------------------------------------
# IAF, d: 50, Iter: 3-740, s/iter: 1.129e-01, ELBO: -3.196e+05
# Cur diff delta = 53.1115608215332
# Cur diff sigma = 2.1429991722106934
# Cur diff theta = 55.2545599937439
# ---------------------------------------
# IAF, d: 50, Iter: 3-760, s/iter: 1.180e-01, ELBO: -3.196e+05
# Cur diff delta = 53.113746643066406
# Cur diff sigma = 2.143145799636841
# Cur diff theta = 55.25689244270325
# ---------------------------------------
# IAF, d: 50, Iter: 3-780, s/iter: 1.129e-01, ELBO: -3.196e+05
# Cur diff delta = 53.10979080200195
# Cur diff sigma = 2.1437408924102783
# Cur diff theta = 55.25353169441223
# ---------------------------------------
# IAF, d: 50, Iter: 3-800, s/iter: 1.139e-01, ELBO: -3.196e+05
# Cur diff delta = 53.1182861328125
# Cur diff sigma = 2.1427295207977295
# Cur diff theta = 55.26101565361023
# ---------------------------------------
# IAF, d: 50, Iter: 3-820, s/iter: 1.236e-01, ELBO: -3.196e+05
# Cur diff delta = 53.12784194946289
# Cur diff sigma = 2.143570899963379
# Cur diff theta = 55.27141284942627
# ---------------------------------------
# IAF, d: 50, Iter: 3-840, s/iter: 1.188e-01, ELBO: -3.196e+05
# Cur diff delta = 53.1208610534668
# Cur diff sigma = 2.143200397491455
# Cur diff theta = 55.26406145095825
# ---------------------------------------
# IAF, d: 50, Iter: 3-860, s/iter: 1.224e-01, ELBO: -3.196e+05
# Cur diff delta = 53.11770248413086
# Cur diff sigma = 2.143425226211548
# Cur diff theta = 55.26112771034241
# ---------------------------------------
# IAF, d: 50, Iter: 3-880, s/iter: 1.288e-01, ELBO: -3.197e+05
# Cur diff delta = 53.11981201171875
# Cur diff sigma = 2.143620014190674
# Cur diff theta = 55.263432025909424
# ---------------------------------------
# IAF, d: 50, Iter: 3-900, s/iter: 1.193e-01, ELBO: -3.196e+05
# Cur diff delta = 53.11053466796875
# Cur diff sigma = 2.1435697078704834
# Cur diff theta = 55.25410437583923
# ---------------------------------------
# IAF, d: 50, Iter: 3-920, s/iter: 1.193e-01, ELBO: -3.196e+05
# Cur diff delta = 53.114444732666016
# Cur diff sigma = 2.1437222957611084
# Cur diff theta = 55.258167028427124
# ---------------------------------------
# IAF, d: 50, Iter: 3-940, s/iter: 1.170e-01, ELBO: -3.196e+05
# Cur diff delta = 53.111228942871094
# Cur diff sigma = 2.143306016921997
# Cur diff theta = 55.25453495979309
# ---------------------------------------
# IAF, d: 50, Iter: 3-960, s/iter: 1.251e-01, ELBO: -3.196e+05
# Cur diff delta = 53.114322662353516
# Cur diff sigma = 2.1435546875
# Cur diff theta = 55.257877349853516
# ---------------------------------------
# IAF, d: 50, Iter: 3-980, s/iter: 1.169e-01, ELBO: -3.196e+05
# Cur diff delta = 53.11326217651367
# Cur diff sigma = 2.143670082092285
# Cur diff theta = 55.25693225860596
# ---------------------------------------
# IAF, d: 50, Iter: 3-1000, s/iter: 1.179e-01, ELBO: -3.196e+05
# Cur diff delta = 53.104618072509766
# Cur diff sigma = 2.143432378768921
# Cur diff theta = 55.24805045127869
# ---------------------------------------
# IAF, d: 50, Iter: 3-1020, s/iter: 1.264e-01, ELBO: -3.196e+05
# Cur diff delta = 53.115665435791016
# Cur diff sigma = 2.144336462020874
# Cur diff theta = 55.26000189781189
# ---------------------------------------
# IAF, d: 50, Iter: 3-1040, s/iter: 1.188e-01, ELBO: -3.196e+05
# Cur diff delta = 53.10465621948242
# Cur diff sigma = 2.1433041095733643
# Cur diff theta = 55.247960329055786
# ---------------------------------------
# IAF, d: 50, Iter: 3-1060, s/iter: 1.198e-01, ELBO: -3.196e+05
# Cur diff delta = 53.11540222167969
# Cur diff sigma = 2.1432487964630127
# Cur diff theta = 55.2586510181427
# ---------------------------------------
# IAF, d: 50, Iter: 3-1080, s/iter: 1.206e-01, ELBO: -3.196e+05
# Cur diff delta = 53.10879898071289
# Cur diff sigma = 2.143340587615967
# Cur diff theta = 55.25213956832886
# ---------------------------------------
# IAF, d: 50, Iter: 3-1100, s/iter: 1.228e-01, ELBO: -3.196e+05
# Cur diff delta = 53.1172981262207
# Cur diff sigma = 2.1436939239501953
# Cur diff theta = 55.2609920501709
# ---------------------------------------
# IAF, d: 50, Iter: 3-1120, s/iter: 1.297e-01, ELBO: -3.196e+05
# Cur diff delta = 53.12638854980469
# Cur diff sigma = 2.143542766571045
# Cur diff theta = 55.26993131637573
# ---------------------------------------
# IAF, d: 50, Iter: 3-1140, s/iter: 1.239e-01, ELBO: -3.196e+05
# Cur diff delta = 53.12056350708008
# Cur diff sigma = 2.1432440280914307
# Cur diff theta = 55.26380753517151
# ---------------------------------------
# IAF, d: 50, Iter: 3-1160, s/iter: 1.196e-01, ELBO: -3.196e+05
# Cur diff delta = 53.11075973510742
# Cur diff sigma = 2.1434175968170166
# Cur diff theta = 55.25417733192444
# ---------------------------------------
# IAF, d: 50, Iter: 3-1180, s/iter: 1.237e-01, ELBO: -3.196e+05
# Cur diff delta = 53.11609649658203
# Cur diff sigma = 2.1429378986358643
# Cur diff theta = 55.259034395217896
# ---------------------------------------
# IAF, d: 50, Iter: 3-1200, s/iter: 1.368e-01, ELBO: -3.196e+05
# Cur diff delta = 53.112796783447266
# Cur diff sigma = 2.143552780151367
# Cur diff theta = 55.25634956359863
# ---------------------------------------
# IAF, d: 50, Iter: 3-1220, s/iter: 1.202e-01, ELBO: -3.196e+05
# Cur diff delta = 53.118743896484375
# Cur diff sigma = 2.1431052684783936
# Cur diff theta = 55.26184916496277
# ---------------------------------------
# IAF, d: 50, Iter: 3-1240, s/iter: 1.215e-01, ELBO: -3.196e+05
# Cur diff delta = 53.11503219604492
# Cur diff sigma = 2.1438753604888916
# Cur diff theta = 55.25890755653381
# ---------------------------------------
# IAF, d: 50, Iter: 3-1260, s/iter: 1.224e-01, ELBO: -3.196e+05
# Cur diff delta = 53.121543884277344
# Cur diff sigma = 2.1434545516967773
# Cur diff theta = 55.26499843597412
# ---------------------------------------
# IAF, d: 50, Iter: 3-1280, s/iter: 1.211e-01, ELBO: -3.196e+05
# Cur diff delta = 53.103538513183594
# Cur diff sigma = 2.1431539058685303
# Cur diff theta = 55.246692419052124
# ---------------------------------------
# IAF, d: 50, Iter: 3-1300, s/iter: 1.192e-01, ELBO: -3.196e+05
# Cur diff delta = 53.119384765625
# Cur diff sigma = 2.1429085731506348
# Cur diff theta = 55.262293338775635
# ---------------------------------------
# IAF, d: 50, Iter: 3-1320, s/iter: 1.187e-01, ELBO: -3.196e+05
# Cur diff delta = 53.118988037109375
# Cur diff sigma = 2.143745183944702
# Cur diff theta = 55.26273322105408
# ---------------------------------------
# IAF, d: 50, Iter: 3-1340, s/iter: 1.211e-01, ELBO: -3.196e+05
# Cur diff delta = 53.126502990722656
# Cur diff sigma = 2.143246650695801
# Cur diff theta = 55.26974964141846
# ---------------------------------------
# IAF, d: 50, Iter: 3-1360, s/iter: 1.231e-01, ELBO: -3.196e+05
# Cur diff delta = 53.11259460449219
# Cur diff sigma = 2.143399477005005
# Cur diff theta = 55.25599408149719
# ---------------------------------------
# IAF, d: 50, Iter: 3-1380, s/iter: 1.214e-01, ELBO: -3.196e+05
# Cur diff delta = 53.121036529541016
# Cur diff sigma = 2.1431050300598145
# Cur diff theta = 55.26414155960083
# ---------------------------------------
# IAF, d: 50, Iter: 3-1400, s/iter: 1.207e-01, ELBO: -3.196e+05
# Cur diff delta = 53.11307144165039
# Cur diff sigma = 2.1441428661346436
# Cur diff theta = 55.257214307785034
# ---------------------------------------
# IAF, d: 50, Iter: 3-1420, s/iter: 1.204e-01, ELBO: -3.196e+05
# Cur diff delta = 53.11293411254883
# Cur diff sigma = 2.14379620552063
# Cur diff theta = 55.25673031806946
# ---------------------------------------
# IAF, d: 50, Iter: 3-1440, s/iter: 1.371e-01, ELBO: -3.196e+05
# Cur diff delta = 53.10806655883789
# Cur diff sigma = 2.142629623413086
# Cur diff theta = 55.25069618225098
# ---------------------------------------
# IAF, d: 50, Iter: 3-1460, s/iter: 1.218e-01, ELBO: -3.196e+05
# Cur diff delta = 53.1170768737793
# Cur diff sigma = 2.1429831981658936
# Cur diff theta = 55.26006007194519
# ---------------------------------------
# IAF, d: 50, Iter: 3-1480, s/iter: 1.344e-01, ELBO: -3.196e+05
# Cur diff delta = 53.11189651489258
# Cur diff sigma = 2.143156051635742
# Cur diff theta = 55.25505256652832
# ---------------------------------------
# IAF, d: 50, Iter: 3-1500, s/iter: 1.228e-01, ELBO: -3.196e+05
# Cur diff delta = 53.116455078125
# Cur diff sigma = 2.1431548595428467
# Cur diff theta = 55.25960993766785
# ---------------------------------------
# IAF, d: 50, Iter: 3-1520, s/iter: 1.271e-01, ELBO: -3.196e+05
# Cur diff delta = 53.11578369140625
# Cur diff sigma = 2.1428608894348145
# Cur diff theta = 55.258644580841064
# ---------------------------------------
# IAF, d: 50, Iter: 3-1540, s/iter: 1.288e-01, ELBO: -3.196e+05
# Cur diff delta = 53.112972259521484
# Cur diff sigma = 2.143296957015991
# Cur diff theta = 55.256269216537476
# ---------------------------------------
# IAF, d: 50, Iter: 3-1560, s/iter: 1.192e-01, ELBO: -3.196e+05
# Cur diff delta = 53.114925384521484
# Cur diff sigma = 2.143380880355835
# Cur diff theta = 55.25830626487732
# ---------------------------------------
# IAF, d: 50, Iter: 3-1580, s/iter: 1.188e-01, ELBO: -3.196e+05
# Cur diff delta = 53.11861038208008
# Cur diff sigma = 2.143380641937256
# Cur diff theta = 55.261991024017334
# ---------------------------------------
# IAF, d: 50, Iter: 3-1600, s/iter: 1.255e-01, ELBO: -3.196e+05
# Cur diff delta = 53.10587692260742
# Cur diff sigma = 2.1428749561309814
# Cur diff theta = 55.2487518787384
# ---------------------------------------
# IAF, d: 50, Iter: 3-1620, s/iter: 1.203e-01, ELBO: -3.196e+05
# Cur diff delta = 53.1239128112793
# Cur diff sigma = 2.1428732872009277
# Cur diff theta = 55.266786098480225
# ---------------------------------------
# IAF, d: 50, Iter: 3-1640, s/iter: 1.320e-01, ELBO: -3.196e+05
# Cur diff delta = 53.12177276611328
# Cur diff sigma = 2.1434738636016846
# Cur diff theta = 55.265246629714966
# ---------------------------------------
# IAF, d: 50, Iter: 3-1660, s/iter: 1.198e-01, ELBO: -3.196e+05
# Cur diff delta = 53.109371185302734
# Cur diff sigma = 2.143329381942749
# Cur diff theta = 55.25270056724548
# ---------------------------------------
# IAF, d: 50, Iter: 3-1680, s/iter: 1.337e-01, ELBO: -3.196e+05
# Cur diff delta = 53.13011932373047
# Cur diff sigma = 2.143594264984131
# Cur diff theta = 55.2737135887146
# ---------------------------------------
# IAF, d: 50, Iter: 3-1700, s/iter: 1.209e-01, ELBO: -3.196e+05
# Cur diff delta = 53.100006103515625
# Cur diff sigma = 2.142982006072998
# Cur diff theta = 55.24298810958862
# ---------------------------------------
# IAF, d: 50, Iter: 3-1720, s/iter: 1.229e-01, ELBO: -3.196e+05
# Cur diff delta = 53.095298767089844
# Cur diff sigma = 2.143677234649658
# Cur diff theta = 55.2389760017395
# ---------------------------------------
# IAF, d: 50, Iter: 3-1740, s/iter: 1.207e-01, ELBO: -3.196e+05
# Cur diff delta = 53.119956970214844
# Cur diff sigma = 2.1426000595092773
# Cur diff theta = 55.26255702972412
# ---------------------------------------
# IAF, d: 50, Iter: 3-1760, s/iter: 1.288e-01, ELBO: -3.196e+05
# Cur diff delta = 53.1060905456543
# Cur diff sigma = 2.143784284591675
# Cur diff theta = 55.24987483024597
# ---------------------------------------
# IAF, d: 50, Iter: 3-1780, s/iter: 1.356e-01, ELBO: -3.196e+05
# Cur diff delta = 53.12135314941406
# Cur diff sigma = 2.1438980102539062
# Cur diff theta = 55.26525115966797
# ---------------------------------------
# IAF, d: 50, Iter: 3-1800, s/iter: 1.290e-01, ELBO: -3.196e+05
# Cur diff delta = 53.11896896362305
# Cur diff sigma = 2.1428310871124268
# Cur diff theta = 55.261800050735474
# ---------------------------------------
# IAF, d: 50, Iter: 3-1820, s/iter: 1.183e-01, ELBO: -3.196e+05
# Cur diff delta = 53.118431091308594
# Cur diff sigma = 2.1430819034576416
# Cur diff theta = 55.261512994766235
# ---------------------------------------
# IAF, d: 50, Iter: 3-1840, s/iter: 1.180e-01, ELBO: -3.196e+05
# Cur diff delta = 53.11798095703125
# Cur diff sigma = 2.1434152126312256
# Cur diff theta = 55.261396169662476
# ---------------------------------------
# IAF, d: 50, Iter: 3-1860, s/iter: 1.186e-01, ELBO: -3.196e+05
# Cur diff delta = 53.11991500854492
# Cur diff sigma = 2.14328670501709
# Cur diff theta = 55.26320171356201
# ---------------------------------------
# IAF, d: 50, Iter: 3-1880, s/iter: 1.280e-01, ELBO: -3.196e+05
# Cur diff delta = 53.0950813293457
# Cur diff sigma = 2.1436071395874023
# Cur diff theta = 55.238688468933105
# ---------------------------------------
# IAF, d: 50, Iter: 3-1900, s/iter: 1.194e-01, ELBO: -3.196e+05
# Cur diff delta = 53.10929489135742
# Cur diff sigma = 2.1430280208587646
# Cur diff theta = 55.25232291221619
# ---------------------------------------
# IAF, d: 50, Iter: 3-1920, s/iter: 1.189e-01, ELBO: -3.196e+05
# Cur diff delta = 53.10187911987305
# Cur diff sigma = 2.143174409866333
# Cur diff theta = 55.24505352973938
# ---------------------------------------
# IAF, d: 50, Iter: 3-1940, s/iter: 1.191e-01, ELBO: -3.196e+05
# Cur diff delta = 53.112648010253906
# Cur diff sigma = 2.1431784629821777
# Cur diff theta = 55.255826473236084
# ---------------------------------------
# IAF, d: 50, Iter: 3-1960, s/iter: 1.194e-01, ELBO: -3.196e+05
# Cur diff delta = 53.11195373535156
# Cur diff sigma = 2.1438560485839844
# Cur diff theta = 55.25580978393555
# ---------------------------------------
# IAF, d: 50, Iter: 3-1980, s/iter: 1.177e-01, ELBO: -3.196e+05
# Cur diff delta = 53.112098693847656
# Cur diff sigma = 2.1429848670959473
# Cur diff theta = 55.2550835609436
# ---------------------------------------
# IAF, d: 50, Iter: 3-2000, s/iter: 1.218e-01, ELBO: -3.196e+05
# Cur diff delta = 53.12238311767578
# Cur diff sigma = 2.143369674682617
# Cur diff theta = 55.2657527923584
# ---------------------------------------
# Model IAF, test = 0, result delta diff = 45.97723388671875
# Model IAF, test = 0, result sigma diff = 2.1491830348968506
# Model IAF, test = 0, result theta diff = 48.12641525268555
# Model IAF, test = 1, result delta diff = 50.5294303894043
# Model IAF, test = 1, result sigma diff = 2.1874215602874756
# Model IAF, test = 1, result theta diff = 52.71685028076172
# Model IAF, test = 2, result delta diff = 53.122379302978516
# Model IAF, test = 2, result sigma diff = 2.143369436264038
# Model IAF, test = 2, result theta diff = 55.2657470703125

# %%
model_names = ['IAF']
diff_delta_results = {}
diff_sigma_results = {}
diff_results = {}
for name in model_names:
    diff_delta_tests = np.zeros(params['n_tests'])
    diff_sigma_tests = np.zeros(params['n_tests'])
    diff_tests = np.zeros(params['n_tests'])
    for i in range(params['n_tests']):
        file_name = name + '_train_' + str(i) + '.p'
        diff_path = os.path.join('save', str(params['dims'][0]), file_name)
        with open(diff_path, 'rb') as f:
            data = pickle.load(f)
            elbo = data['elbo']
            diff_delta = data['diff_delta']
            diff_sigma = data['diff_sigma']
            diff = diff_delta + diff_sigma
            diff_delta_is_not_nan = diff_delta[~np.isnan(diff_delta)]
            diff_sigma_is_not_nan = diff_sigma[~np.isnan(diff_sigma)]
            diff_is_not_nan = diff[~np.isnan(diff)]
            diff_delta_tests[i] = diff_delta_is_not_nan[-1]
            diff_sigma_tests[i] = diff_sigma_is_not_nan[-1]
            diff_tests[i] = diff_is_not_nan[-1]
    diff_delta_results[name] = diff_delta_tests
    diff_sigma_results[name] = diff_sigma_tests
    diff_results[name] = diff_tests
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, diff delta = {diff_delta_tests}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, diff sigma = {diff_sigma_tests}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, diff = {diff_tests}")
# Out:
# Model = IAF, dimensionality = 50, diff delta = [45.97723389 50.52943039 53.12238312]
# Model = IAF, dimensionality = 50, diff sigma = [2.14918303 2.1874218  2.14336967]
# Model = IAF, dimensionality = 50, diff = [48.12641525 52.71685028 55.2657547 ]

# %%
for name in model_names:
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, mean diff delta = {diff_delta_results[name].mean()}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, mean diff sigma = {diff_sigma_results[name].mean()}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, mean diff = {diff_results[name].mean()}")
# Out:
# Model = IAF, dimensionality = 50, mean diff delta = 49.876349131266274
# Model = IAF, dimensionality = 50, mean diff sigma = 2.159991502761841
# Model = IAF, dimensionality = 50, mean diff = 52.0363400777181
