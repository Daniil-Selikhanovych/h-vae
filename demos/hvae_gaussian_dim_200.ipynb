# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
from torch.distributions.normal import Normal
import torch.optim as optim
from torch.distributions.multivariate_normal import MultivariateNormal
from torch.nn import Parameter
from torch import nn
from torch.utils.data import Dataset, DataLoader

import scipy.stats
import time
import pickle
import os
import sys

# %%
# !rm -r h-vae/

# %%
# !git clone https://github.com/Daniil-Selikhanovych/h-vae
# Out:
# Cloning into 'h-vae'...
# remote: Enumerating objects: 106, done.
# remote: Counting objects: 100% (106/106), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 106 (delta 32), reused 97 (delta 26), pack-reused 0
# Receiving objects: 100% (106/106), 400.62 KiB | 23.57 MiB/s, done.
# Resolving deltas: 100% (32/32), done.

# %%
# !pip install pyro-ppl

from pyro.nn import AutoRegressiveNN
# Out:
# Collecting pyro-ppl
#   Downloading https://files.pythonhosted.org/packages/3d/1b/946ff38dd8675b8fa114444df0940db078eb42e5354df46645a9e9467085/pyro_ppl-1.5.0-py3-none-any.whl (604kB)
#      |████████████████████████████████| 614kB 12.6MB/s
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from pyro-ppl) (3.3.0)
# Collecting pyro-api>=0.1.1
#   Downloading https://files.pythonhosted.org/packages/fc/81/957ae78e6398460a7230b0eb9b8f1cb954c5e913e868e48d89324c68cec7/pyro_api-0.1.2-py3-none-any.whl
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from pyro-ppl) (1.18.5)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from pyro-ppl) (1.6.0+cu101)
# Requirement already satisfied: tqdm>=4.36 in /usr/local/lib/python3.6/dist-packages (from pyro-ppl) (4.41.1)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch>=1.6.0->pyro-ppl) (0.16.0)
# Installing collected packages: pyro-api, pyro-ppl
# Successfully installed pyro-api-0.1.2 pyro-ppl-1.5.0

# %%
path_to_gaussians = os.path.join(os.getcwd(), 'h-vae', 'gaussians')
path_to_gaussians_api = os.path.join(path_to_gaussians, 'api')

sys.path.append(path_to_gaussians)
sys.path.append(path_to_gaussians_api)

# %%
from models import HVAE, NF, VB, IAF

# %%
class gaussian_dataset(Dataset):
    def __init__(self, x):
          'Initialization'
          self.x = x

    def __len__(self):
          'Denotes the total number of samples'
          return self.x.shape[0]

    def __getitem__(self, index):
          'Generates one sample of data'
          x_index = self.x[index]

          return x_index

# %%
def run_test(d, params, 
             batch_size=256,
             clip_value=None,
             dtype=torch.float32, 
             device=torch.device("cpu")):
    """ 
    Run the gaussian test with dimension d 
    """

    ######### Problem Specification

    # Data generation parameters
    prior_mu_z = torch.zeros(d, dtype=dtype)    # Prior mean
    prior_sigma_z = torch.eye(d, dtype=dtype)   # Prior covariance matrix

    # True model parameters
    num_range = torch.arange(-(d-1)/2, (d+1)/2, dtype=dtype)

    t_delta =  num_range / 5 

    print(f"true delta = {t_delta.numpy()}")

    if d == 1:
        t_sigma = torch.ones(1, dtype=dtype)
    else: 
        # Allow sigma to range from 0.1 to 1
        t_sigma = 36/(10*(d-1)**2) * num_range**2 + 0.1 
    print(f"true sigma = {t_sigma.numpy()}")

    ######### Variable Initialization

    # Initial model parameters - same across all methods
    init_delta = prior_mu_z.clone().to(device)
    init_log_sigma = 3 * torch.ones(d).to(device)

    # Initial HVAE variational parameters
    init_T = torch.tensor(5., dtype=dtype, device=device)
    init_eps = 0.005 * torch.ones(d, dtype=dtype)
    max_eps = params['max_eps'] * torch.ones(d, dtype=dtype)
    init_logit_eps = torch.log(init_eps/(max_eps - init_eps)).to(device)
    init_log_T_0 = torch.log(init_T - 1)

    # Initial NF variational parameters
    init_u_pre_reparam = torch.tensor(scipy.stats.truncnorm.rvs(-2, 2, 
                                                                scale=0.1, 
                                                                size=d),
                                      dtype=dtype, device=device)
    init_w = torch.tensor(scipy.stats.truncnorm.rvs(-2, 2, scale=0.1, size=d),
                          dtype=dtype, device=device)
    init_b = torch.tensor(0.1, dtype=dtype, device=device)

    # Initial VAE parameters
    init_mu_z = prior_mu_z.clone()
    init_log_sigma_z = torch.ones(d, dtype=dtype)

    ######### Set up models
    init_params = [[init_delta, init_log_sigma, init_logit_eps, init_log_T_0],
                   [init_delta, init_log_sigma, init_logit_eps, init_log_T_0],
                   [init_delta, init_log_sigma, init_u_pre_reparam, init_w, init_b],
                   [init_delta, init_log_sigma, init_u_pre_reparam, init_w, init_b],
                   [init_delta, init_log_sigma, init_mu_z, init_log_sigma_z]]

    HVAE_model_1 = HVAE(params,
        ['delta', 'log_sigma', 'logit_eps', 'log_T_0'],
        init_params[0], 
        'HVAE_1', d, params['HVAE_K_1'])
    HVAE_model_2 = HVAE(params,
        ['delta', 'log_sigma', 'logit_eps', 'log_T_0'],
        init_params[1], 
        'HVAE_2', d, params['HVAE_K_2'])
    
    
    NF_model_1 = NF(params,
        ['delta', 'log_sigma', 'u_pre_reparam', 'w', 'b'],
        init_params[2],
        'NF_1', d, params['NF_K_1'])
    
    NF_model_2 = NF(params,
        ['delta', 'log_sigma', 'u_pre_reparam', 'w', 'b'],
        init_params[3],
        'NF_2', d, params['NF_K_2'])
    
    VB_model = VB(params,
        ['delta', 'log_sigma', 'mu_z', 'log_sigma_z'], 
        init_params[4], 'VB', d)

    #model_list = [HVAE_model_1, HVAE_model_2, NF_model_1]
    #model_list = [HVAE_model_1, NF_model_1]
    model_list = [HVAE_model_1, HVAE_model_2, NF_model_1, NF_model_2, VB_model]

    print("Models were initialized!")
    
    ######### Generate Training Data & Save - One for each test

    train_data_list = []

    for i in range(params['n_tests']):
        z = MultivariateNormal(prior_mu_z, prior_sigma_z).sample()
        x = MultivariateNormal(z + t_delta, 
                               torch.diag(t_sigma**2)).sample([params['n_data']])
        x = x.to(device)
        train_data_list.append(x)

    # Folder should have already been created in the initializations
    data_path = os.path.join('save', str(d), 'train_data.p')
    pickle.dump(train_data_list, open(data_path, 'wb')) 

    # Store the final parameter values for all test runs in this dictionary
    final_params = {}

    for i in range(len(model_list)):
        final_values = []
        m = model_list[i]
        model_init_params = init_params[i]

        for j in range(params['n_tests']):
            print("------------------------------------------------------")
            print(f"Test = {j}")
            print("------------------------------------------------------")
            m._reinitialize(model_init_params)
            gaussian_data = gaussian_dataset(train_data_list[j])
            train_dataloader = DataLoader(gaussian_data, batch_size=batch_size,
                                          shuffle=False, num_workers=0)
            (delta, sigma) = m.train(train_dataloader, j, 
                                     t_delta, t_sigma,
                                     clip_value)
            final_values.append((delta, sigma))

        final_params[m.model_name] = final_values.copy()

    ######### Test models using difference between parameters

    param_diffs = {}

    for m in model_list:
        
        diffs = []

        for i in range(params['n_tests']):
            delta = final_params[m.model_name][i][0]
            sigma = final_params[m.model_name][i][1]

            delta_diff = np.sum((delta - t_delta.numpy())**2)
            sigma_diff = np.sum((sigma - t_sigma.numpy())**2)
            theta_diff = delta_diff + sigma_diff
            print(f"Model {m.model_name}, test = {i}, result delta diff = {delta_diff}")
            print(f"Model {m.model_name}, test = {i}, result sigma diff = {sigma_diff}")
            print(f"Model {m.model_name}, test = {i}, result theta diff = {theta_diff}")

            diffs.append((delta_diff, sigma_diff, theta_diff))

        param_diffs[m.model_name] = diffs.copy()

    # Save parameter differences in a pickle file
    diff_path = os.path.join('save', str(d), 'all_diffs.p')
    pickle.dump(param_diffs, open(diff_path, 'wb'))

# %%
params = {

    # PROBLEM SPECIFICATION
    #'dims': [1, 2, 3, 5, 11, 25, 51, 101, 201, 301], # Dimensions to test
    'dims': [200],
    'n_data': 10000,                                 # Number of data points

    # TEST HYPERPARAMETERS
    'n_tests': 3,      # Number of experiments to run

    # GLOBAL OPTIMIZATION PARAMETERS
    'n_iter': 2000,    # Number of optimization iterations
    'n_batch': 10,      # Number of points for ELBO estimate
    'rms_eta': 0.001,   # Stepsize for RMSProp
    'save_every': 20,   # Save parameter information every so often
    'print_every': 20, # Print less often than save

    # HVAE HYPERPARAMETERS
    'HVAE_K_1': 1,    # Number of leapfrog/cooling steps for HVAE flow 1
    'HVAE_K_2': 10,   # Number of leapfrog/cooling steps for HVAE flow 2
    'max_eps': 0.5,   # Maximum leapfrog step size per dimension 

    # NF HYPERPARAMETERS
    'NF_K_1': 1,    # Number of flow steps for NF flow 1
    'NF_K_2': 30,   # Number of flow steps for NF flow 2
    
}

# %%
device = torch.device("cpu")
dtype = torch.float32
clip_value = 1e-4
batch_size = 256

# %%
dims = params['dims']
seed = 12345
np.random.seed(seed)
torch.manual_seed(seed)
for d in dims:
    print('**** Running test for d={0:d} ****'.format(d))
    run_test(d, params, batch_size, clip_value, dtype, device)
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# HVAE_2, d: 200, Iter: 3-420, s/iter: 2.636e-01, ELBO: -1.087e+06
# Cur diff delta = 368.30657958984375
# Cur diff sigma = 0.7167985439300537
# Cur diff theta = 369.0233781337738
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-440, s/iter: 2.505e-01, ELBO: -1.077e+06
# Cur diff delta = 283.0844421386719
# Cur diff sigma = 0.4775009751319885
# Cur diff theta = 283.56194311380386
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-460, s/iter: 2.545e-01, ELBO: -1.067e+06
# Cur diff delta = 232.56497192382812
# Cur diff sigma = 0.3695141673088074
# Cur diff theta = 232.93448609113693
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-480, s/iter: 2.537e-01, ELBO: -1.062e+06
# Cur diff delta = 207.742431640625
# Cur diff sigma = 0.31886768341064453
# Cur diff theta = 208.06129932403564
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-500, s/iter: 2.807e-01, ELBO: -1.059e+06
# Cur diff delta = 198.8241424560547
# Cur diff sigma = 0.309373140335083
# Cur diff theta = 199.13351559638977
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-520, s/iter: 2.679e-01, ELBO: -1.058e+06
# Cur diff delta = 197.42103576660156
# Cur diff sigma = 0.3042587339878082
# Cur diff theta = 197.72529450058937
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-540, s/iter: 2.811e-01, ELBO: -1.061e+06
# Cur diff delta = 198.86801147460938
# Cur diff sigma = 0.30615663528442383
# Cur diff theta = 199.1741681098938
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-560, s/iter: 2.722e-01, ELBO: -1.062e+06
# Cur diff delta = 199.66510009765625
# Cur diff sigma = 0.3058560788631439
# Cur diff theta = 199.9709561765194
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-580, s/iter: 2.805e-01, ELBO: -1.061e+06
# Cur diff delta = 201.0127410888672
# Cur diff sigma = 0.30715492367744446
# Cur diff theta = 201.31989601254463
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-600, s/iter: 2.680e-01, ELBO: -1.062e+06
# Cur diff delta = 200.49795532226562
# Cur diff sigma = 0.3091217577457428
# Cur diff theta = 200.80707708001137
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-620, s/iter: 2.629e-01, ELBO: -1.059e+06
# Cur diff delta = 200.84837341308594
# Cur diff sigma = 0.3068203032016754
# Cur diff theta = 201.1551937162876
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-640, s/iter: 2.589e-01, ELBO: -1.060e+06
# Cur diff delta = 200.64395141601562
# Cur diff sigma = 0.3076629042625427
# Cur diff theta = 200.95161432027817
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-660, s/iter: 2.640e-01, ELBO: -1.058e+06
# Cur diff delta = 200.28944396972656
# Cur diff sigma = 0.30989277362823486
# Cur diff theta = 200.5993367433548
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-680, s/iter: 2.576e-01, ELBO: -1.061e+06
# Cur diff delta = 200.03436279296875
# Cur diff sigma = 0.30836549401283264
# Cur diff theta = 200.34272828698158
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-700, s/iter: 2.614e-01, ELBO: -1.059e+06
# Cur diff delta = 200.18997192382812
# Cur diff sigma = 0.31028419733047485
# Cur diff theta = 200.5002561211586
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-720, s/iter: 2.493e-01, ELBO: -1.059e+06
# Cur diff delta = 200.41464233398438
# Cur diff sigma = 0.30930936336517334
# Cur diff theta = 200.72395169734955
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-740, s/iter: 2.405e-01, ELBO: -1.060e+06
# Cur diff delta = 200.62176513671875
# Cur diff sigma = 0.3070773780345917
# Cur diff theta = 200.92884251475334
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-760, s/iter: 2.411e-01, ELBO: -1.059e+06
# Cur diff delta = 200.9008026123047
# Cur diff sigma = 0.31012973189353943
# Cur diff theta = 201.21093234419823
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-780, s/iter: 2.382e-01, ELBO: -1.061e+06
# Cur diff delta = 201.33425903320312
# Cur diff sigma = 0.30898770689964294
# Cur diff theta = 201.64324674010277
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-800, s/iter: 2.580e-01, ELBO: -1.063e+06
# Cur diff delta = 201.52500915527344
# Cur diff sigma = 0.3079458475112915
# Cur diff theta = 201.83295500278473
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-820, s/iter: 2.685e-01, ELBO: -1.059e+06
# Cur diff delta = 200.8739776611328
# Cur diff sigma = 0.3079911470413208
# Cur diff theta = 201.18196880817413
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-840, s/iter: 2.511e-01, ELBO: -1.057e+06
# Cur diff delta = 201.26255798339844
# Cur diff sigma = 0.3084789514541626
# Cur diff theta = 201.5710369348526
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-860, s/iter: 2.518e-01, ELBO: -1.062e+06
# Cur diff delta = 201.08340454101562
# Cur diff sigma = 0.3092386722564697
# Cur diff theta = 201.3926432132721
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-880, s/iter: 2.467e-01, ELBO: -1.060e+06
# Cur diff delta = 200.56967163085938
# Cur diff sigma = 0.30828163027763367
# Cur diff theta = 200.877953261137
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-900, s/iter: 2.452e-01, ELBO: -1.059e+06
# Cur diff delta = 200.72012329101562
# Cur diff sigma = 0.30680108070373535
# Cur diff theta = 201.02692437171936
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-920, s/iter: 2.469e-01, ELBO: -1.059e+06
# Cur diff delta = 200.8717498779297
# Cur diff sigma = 0.30810895562171936
# Cur diff theta = 201.1798588335514
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-940, s/iter: 2.616e-01, ELBO: -1.059e+06
# Cur diff delta = 200.3616180419922
# Cur diff sigma = 0.30662426352500916
# Cur diff theta = 200.6682423055172
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-960, s/iter: 2.362e-01, ELBO: -1.060e+06
# Cur diff delta = 201.1749725341797
# Cur diff sigma = 0.3072667121887207
# Cur diff theta = 201.4822392463684
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-980, s/iter: 2.527e-01, ELBO: -1.059e+06
# Cur diff delta = 201.08119201660156
# Cur diff sigma = 0.3094482421875
# Cur diff theta = 201.39064025878906
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1000, s/iter: 2.523e-01, ELBO: -1.058e+06
# Cur diff delta = 200.23143005371094
# Cur diff sigma = 0.30923599004745483
# Cur diff theta = 200.5406660437584
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1020, s/iter: 2.601e-01, ELBO: -1.060e+06
# Cur diff delta = 200.5983123779297
# Cur diff sigma = 0.30682456493377686
# Cur diff theta = 200.90513694286346
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1040, s/iter: 2.365e-01, ELBO: -1.062e+06
# Cur diff delta = 200.98780822753906
# Cur diff sigma = 0.30868569016456604
# Cur diff theta = 201.29649391770363
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1060, s/iter: 2.680e-01, ELBO: -1.059e+06
# Cur diff delta = 200.2874755859375
# Cur diff sigma = 0.30818185210227966
# Cur diff theta = 200.59565743803978
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1080, s/iter: 2.343e-01, ELBO: -1.060e+06
# Cur diff delta = 201.4246826171875
# Cur diff sigma = 0.3086512088775635
# Cur diff theta = 201.73333382606506
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1100, s/iter: 2.402e-01, ELBO: -1.060e+06
# Cur diff delta = 200.7449951171875
# Cur diff sigma = 0.30983731150627136
# Cur diff theta = 201.05483242869377
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1120, s/iter: 2.479e-01, ELBO: -1.057e+06
# Cur diff delta = 201.1090850830078
# Cur diff sigma = 0.30866116285324097
# Cur diff theta = 201.41774624586105
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1140, s/iter: 2.416e-01, ELBO: -1.057e+06
# Cur diff delta = 200.3428497314453
# Cur diff sigma = 0.30982357263565063
# Cur diff theta = 200.65267330408096
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1160, s/iter: 2.380e-01, ELBO: -1.060e+06
# Cur diff delta = 200.47348022460938
# Cur diff sigma = 0.3069641590118408
# Cur diff theta = 200.78044438362122
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1180, s/iter: 2.521e-01, ELBO: -1.060e+06
# Cur diff delta = 200.78623962402344
# Cur diff sigma = 0.30737441778182983
# Cur diff theta = 201.09361404180527
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1200, s/iter: 2.370e-01, ELBO: -1.058e+06
# Cur diff delta = 200.73114013671875
# Cur diff sigma = 0.3077889382839203
# Cur diff theta = 201.03892907500267
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1220, s/iter: 2.309e-01, ELBO: -1.060e+06
# Cur diff delta = 200.7960205078125
# Cur diff sigma = 0.3084601163864136
# Cur diff theta = 201.1044806241989
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1240, s/iter: 2.605e-01, ELBO: -1.057e+06
# Cur diff delta = 200.90582275390625
# Cur diff sigma = 0.30745580792427063
# Cur diff theta = 201.21327856183052
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1260, s/iter: 2.304e-01, ELBO: -1.058e+06
# Cur diff delta = 200.42320251464844
# Cur diff sigma = 0.30841800570487976
# Cur diff theta = 200.73162052035332
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1280, s/iter: 2.331e-01, ELBO: -1.062e+06
# Cur diff delta = 200.4293670654297
# Cur diff sigma = 0.3079541027545929
# Cur diff theta = 200.73732116818428
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1300, s/iter: 2.391e-01, ELBO: -1.056e+06
# Cur diff delta = 200.41062927246094
# Cur diff sigma = 0.30633440613746643
# Cur diff theta = 200.7169636785984
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1320, s/iter: 2.291e-01, ELBO: -1.060e+06
# Cur diff delta = 201.58631896972656
# Cur diff sigma = 0.30836865305900574
# Cur diff theta = 201.89468762278557
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1340, s/iter: 2.318e-01, ELBO: -1.058e+06
# Cur diff delta = 200.3779296875
# Cur diff sigma = 0.3077482581138611
# Cur diff theta = 200.68567794561386
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1360, s/iter: 2.351e-01, ELBO: -1.055e+06
# Cur diff delta = 201.0101776123047
# Cur diff sigma = 0.3084665834903717
# Cur diff theta = 201.31864419579506
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1380, s/iter: 2.344e-01, ELBO: -1.058e+06
# Cur diff delta = 200.14910888671875
# Cur diff sigma = 0.30731281638145447
# Cur diff theta = 200.4564217031002
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1400, s/iter: 2.516e-01, ELBO: -1.057e+06
# Cur diff delta = 200.9189453125
# Cur diff sigma = 0.3072769045829773
# Cur diff theta = 201.22622221708298
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1420, s/iter: 2.298e-01, ELBO: -1.059e+06
# Cur diff delta = 200.4539794921875
# Cur diff sigma = 0.3086397349834442
# Cur diff theta = 200.76261922717094
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1440, s/iter: 2.317e-01, ELBO: -1.059e+06
# Cur diff delta = 201.0872039794922
# Cur diff sigma = 0.30606237053871155
# Cur diff theta = 201.3932663500309
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1460, s/iter: 2.278e-01, ELBO: -1.060e+06
# Cur diff delta = 200.9702911376953
# Cur diff sigma = 0.3091796934604645
# Cur diff theta = 201.27947083115578
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1480, s/iter: 2.541e-01, ELBO: -1.059e+06
# Cur diff delta = 200.68759155273438
# Cur diff sigma = 0.30738765001296997
# Cur diff theta = 200.99497920274734
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1500, s/iter: 2.447e-01, ELBO: -1.059e+06
# Cur diff delta = 200.7436981201172
# Cur diff sigma = 0.30762967467308044
# Cur diff theta = 201.05132779479027
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1520, s/iter: 2.512e-01, ELBO: -1.059e+06
# Cur diff delta = 200.62579345703125
# Cur diff sigma = 0.3081028461456299
# Cur diff theta = 200.93389630317688
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1540, s/iter: 2.650e-01, ELBO: -1.057e+06
# Cur diff delta = 200.7736053466797
# Cur diff sigma = 0.308856725692749
# Cur diff theta = 201.08246207237244
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1560, s/iter: 2.409e-01, ELBO: -1.060e+06
# Cur diff delta = 200.6813507080078
# Cur diff sigma = 0.3072475790977478
# Cur diff theta = 200.98859828710556
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1580, s/iter: 2.267e-01, ELBO: -1.056e+06
# Cur diff delta = 201.50473022460938
# Cur diff sigma = 0.30615946650505066
# Cur diff theta = 201.81088969111443
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1600, s/iter: 2.264e-01, ELBO: -1.058e+06
# Cur diff delta = 200.5152587890625
# Cur diff sigma = 0.30700817704200745
# Cur diff theta = 200.8222669661045
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1620, s/iter: 2.308e-01, ELBO: -1.061e+06
# Cur diff delta = 201.12619018554688
# Cur diff sigma = 0.30846932530403137
# Cur diff theta = 201.4346595108509
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1640, s/iter: 2.371e-01, ELBO: -1.055e+06
# Cur diff delta = 200.77740478515625
# Cur diff sigma = 0.3072957396507263
# Cur diff theta = 201.08470052480698
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1660, s/iter: 2.614e-01, ELBO: -1.060e+06
# Cur diff delta = 200.5869140625
# Cur diff sigma = 0.306860089302063
# Cur diff theta = 200.89377415180206
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1680, s/iter: 2.344e-01, ELBO: -1.057e+06
# Cur diff delta = 201.5617218017578
# Cur diff sigma = 0.3082561194896698
# Cur diff theta = 201.86997792124748
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1700, s/iter: 2.415e-01, ELBO: -1.057e+06
# Cur diff delta = 201.28842163085938
# Cur diff sigma = 0.30659857392311096
# Cur diff theta = 201.5950202047825
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1720, s/iter: 2.332e-01, ELBO: -1.061e+06
# Cur diff delta = 200.85488891601562
# Cur diff sigma = 0.30934247374534607
# Cur diff theta = 201.16423138976097
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1740, s/iter: 2.477e-01, ELBO: -1.059e+06
# Cur diff delta = 200.3310546875
# Cur diff sigma = 0.3093310594558716
# Cur diff theta = 200.64038574695587
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1760, s/iter: 2.449e-01, ELBO: -1.058e+06
# Cur diff delta = 201.19166564941406
# Cur diff sigma = 0.30864906311035156
# Cur diff theta = 201.5003147125244
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1780, s/iter: 2.261e-01, ELBO: -1.057e+06
# Cur diff delta = 200.59454345703125
# Cur diff sigma = 0.309186726808548
# Cur diff theta = 200.9037301838398
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1800, s/iter: 2.313e-01, ELBO: -1.060e+06
# Cur diff delta = 200.19773864746094
# Cur diff sigma = 0.30883580446243286
# Cur diff theta = 200.50657445192337
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1820, s/iter: 2.332e-01, ELBO: -1.060e+06
# Cur diff delta = 200.6053924560547
# Cur diff sigma = 0.30988809466362
# Cur diff theta = 200.9152805507183
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1840, s/iter: 2.513e-01, ELBO: -1.062e+06
# Cur diff delta = 200.6384735107422
# Cur diff sigma = 0.30614903569221497
# Cur diff theta = 200.9446225464344
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1860, s/iter: 2.423e-01, ELBO: -1.058e+06
# Cur diff delta = 201.02757263183594
# Cur diff sigma = 0.3086901605129242
# Cur diff theta = 201.33626279234886
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1880, s/iter: 2.383e-01, ELBO: -1.060e+06
# Cur diff delta = 200.8153533935547
# Cur diff sigma = 0.30886873602867126
# Cur diff theta = 201.12422212958336
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1900, s/iter: 2.480e-01, ELBO: -1.058e+06
# Cur diff delta = 200.55567932128906
# Cur diff sigma = 0.3085973858833313
# Cur diff theta = 200.8642767071724
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1920, s/iter: 2.293e-01, ELBO: -1.059e+06
# Cur diff delta = 201.24400329589844
# Cur diff sigma = 0.30783018469810486
# Cur diff theta = 201.55183348059654
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1940, s/iter: 2.267e-01, ELBO: -1.057e+06
# Cur diff delta = 200.0866241455078
# Cur diff sigma = 0.307902991771698
# Cur diff theta = 200.3945271372795
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1960, s/iter: 2.368e-01, ELBO: -1.058e+06
# Cur diff delta = 200.55470275878906
# Cur diff sigma = 0.30690813064575195
# Cur diff theta = 200.86161088943481
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-1980, s/iter: 2.274e-01, ELBO: -1.059e+06
# Cur diff delta = 200.58843994140625
# Cur diff sigma = 0.3084866404533386
# Cur diff theta = 200.8969265818596
# ---------------------------------------
# HVAE_2, d: 200, Iter: 3-2000, s/iter: 2.345e-01, ELBO: -1.060e+06
# Cur diff delta = 200.20713806152344
# Cur diff sigma = 0.31064045429229736
# Cur diff theta = 200.51777851581573
# ---------------------------------------
# ------------------------------------------------------
# Test = 2
# ------------------------------------------------------
# Init diff delta = 26666.0
# Init diff sigma = 77495.03125
# Init diff theta = 104161.03125
# NF_1, d: 200, Iter: 1-20, s/iter: 9.013e-02, ELBO: -7.743e+06
# Cur diff delta = 23235.7734375
# Cur diff sigma = 46442.32421875
# Cur diff theta = 69678.09765625
# ---------------------------------------
# NF_1, d: 200, Iter: 1-40, s/iter: 9.122e-02, ELBO: -7.532e+06
# Cur diff delta = 22594.498046875
# Cur diff sigma = 41287.59375
# Cur diff theta = 63882.091796875
# ---------------------------------------
# NF_1, d: 200, Iter: 1-60, s/iter: 1.019e-01, ELBO: -7.214e+06
# Cur diff delta = 21371.8984375
# Cur diff sigma = 37319.2109375
# Cur diff theta = 58691.109375
# ---------------------------------------
# NF_1, d: 200, Iter: 1-80, s/iter: 1.020e-01, ELBO: -6.904e+06
# Cur diff delta = 20060.0
# Cur diff sigma = 34758.21484375
# Cur diff theta = 54818.21484375
# ---------------------------------------
# NF_1, d: 200, Iter: 1-100, s/iter: 1.135e-01, ELBO: -6.617e+06
# Cur diff delta = 18576.83984375
# Cur diff sigma = 31983.46484375
# Cur diff theta = 50560.3046875
# ---------------------------------------
# NF_1, d: 200, Iter: 1-120, s/iter: 8.955e-02, ELBO: -6.337e+06
# Cur diff delta = 16446.904296875
# Cur diff sigma = 27096.650390625
# Cur diff theta = 43543.5546875
# ---------------------------------------
# NF_1, d: 200, Iter: 1-140, s/iter: 8.916e-02, ELBO: -6.097e+06
# Cur diff delta = 14517.1669921875
# Cur diff sigma = 22656.888671875
# Cur diff theta = 37174.0556640625
# ---------------------------------------
# NF_1, d: 200, Iter: 1-160, s/iter: 8.944e-02, ELBO: -5.888e+06
# Cur diff delta = 12842.1611328125
# Cur diff sigma = 19123.689453125
# Cur diff theta = 31965.8505859375
# ---------------------------------------
# NF_1, d: 200, Iter: 1-180, s/iter: 8.948e-02, ELBO: -5.686e+06
# Cur diff delta = 11364.419921875
# Cur diff sigma = 16230.9326171875
# Cur diff theta = 27595.3525390625
# ---------------------------------------
# NF_1, d: 200, Iter: 1-200, s/iter: 8.958e-02, ELBO: -5.502e+06
# Cur diff delta = 10059.7490234375
# Cur diff sigma = 13890.8857421875
# Cur diff theta = 23950.634765625
# ---------------------------------------
# NF_1, d: 200, Iter: 1-220, s/iter: 9.099e-02, ELBO: -5.325e+06
# Cur diff delta = 8919.359375
# Cur diff sigma = 11934.00390625
# Cur diff theta = 20853.36328125
# ---------------------------------------
# NF_1, d: 200, Iter: 1-240, s/iter: 9.195e-02, ELBO: -5.162e+06
# Cur diff delta = 7926.10986328125
# Cur diff sigma = 10319.052734375
# Cur diff theta = 18245.16259765625
# ---------------------------------------
# NF_1, d: 200, Iter: 1-260, s/iter: 9.282e-02, ELBO: -5.015e+06
# Cur diff delta = 7045.99072265625
# Cur diff sigma = 8941.7470703125
# Cur diff theta = 15987.73779296875
# ---------------------------------------
# NF_1, d: 200, Iter: 1-280, s/iter: 8.990e-02, ELBO: -4.881e+06
# Cur diff delta = 6257.8427734375
# Cur diff sigma = 7747.40771484375
# Cur diff theta = 14005.25048828125
# ---------------------------------------
# NF_1, d: 200, Iter: 1-300, s/iter: 9.000e-02, ELBO: -4.750e+06
# Cur diff delta = 5546.36083984375
# Cur diff sigma = 6716.2587890625
# Cur diff theta = 12262.61962890625
# ---------------------------------------
# NF_1, d: 200, Iter: 1-320, s/iter: 8.965e-02, ELBO: -4.625e+06
# Cur diff delta = 4904.0234375
# Cur diff sigma = 5801.18115234375
# Cur diff theta = 10705.20458984375
# ---------------------------------------
# NF_1, d: 200, Iter: 1-340, s/iter: 8.877e-02, ELBO: -4.517e+06
# Cur diff delta = 4314.01416015625
# Cur diff sigma = 4992.67236328125
# Cur diff theta = 9306.6865234375
# ---------------------------------------
# NF_1, d: 200, Iter: 1-360, s/iter: 9.431e-02, ELBO: -4.407e+06
# Cur diff delta = 3772.246337890625
# Cur diff sigma = 4257.06298828125
# Cur diff theta = 8029.309326171875
# ---------------------------------------
# NF_1, d: 200, Iter: 1-380, s/iter: 9.229e-02, ELBO: -4.297e+06
# Cur diff delta = 3274.88232421875
# Cur diff sigma = 3613.5556640625
# Cur diff theta = 6888.43798828125
# ---------------------------------------
# NF_1, d: 200, Iter: 1-400, s/iter: 9.084e-02, ELBO: -4.190e+06
# Cur diff delta = 2824.819580078125
# Cur diff sigma = 3047.330078125
# Cur diff theta = 5872.149658203125
# ---------------------------------------
# NF_1, d: 200, Iter: 1-420, s/iter: 9.080e-02, ELBO: -4.098e+06
# Cur diff delta = 2420.02685546875
# Cur diff sigma = 2555.643798828125
# Cur diff theta = 4975.670654296875
# ---------------------------------------
# NF_1, d: 200, Iter: 1-440, s/iter: 9.202e-02, ELBO: -3.990e+06
# Cur diff delta = 2060.858154296875
# Cur diff sigma = 2134.80712890625
# Cur diff theta = 4195.665283203125
# ---------------------------------------
# NF_1, d: 200, Iter: 1-460, s/iter: 9.120e-02, ELBO: -3.896e+06
# Cur diff delta = 1744.37451171875
# Cur diff sigma = 1776.8162841796875
# Cur diff theta = 3521.1907958984375
# ---------------------------------------
# NF_1, d: 200, Iter: 1-480, s/iter: 9.178e-02, ELBO: -3.812e+06
# Cur diff delta = 1463.7972412109375
# Cur diff sigma = 1468.19921875
# Cur diff theta = 2931.9964599609375
# ---------------------------------------
# NF_1, d: 200, Iter: 1-500, s/iter: 9.174e-02, ELBO: -3.727e+06
# Cur diff delta = 1215.271484375
# Cur diff sigma = 1202.5150146484375
# Cur diff theta = 2417.7864990234375
# ---------------------------------------
# NF_1, d: 200, Iter: 1-520, s/iter: 9.199e-02, ELBO: -3.664e+06
# Cur diff delta = 996.4072265625
# Cur diff sigma = 977.83935546875
# Cur diff theta = 1974.24658203125
# ---------------------------------------
# NF_1, d: 200, Iter: 1-540, s/iter: 9.262e-02, ELBO: -3.582e+06
# Cur diff delta = 807.391357421875
# Cur diff sigma = 787.9191284179688
# Cur diff theta = 1595.3104858398438
# ---------------------------------------
# NF_1, d: 200, Iter: 1-560, s/iter: 9.035e-02, ELBO: -3.519e+06
# Cur diff delta = 649.1710205078125
# Cur diff sigma = 632.9000854492188
# Cur diff theta = 1282.0711059570312
# ---------------------------------------
# NF_1, d: 200, Iter: 1-580, s/iter: 1.013e-01, ELBO: -3.458e+06
# Cur diff delta = 515.795654296875
# Cur diff sigma = 505.5727844238281
# Cur diff theta = 1021.3684387207031
# ---------------------------------------
# NF_1, d: 200, Iter: 1-600, s/iter: 1.032e-01, ELBO: -3.385e+06
# Cur diff delta = 394.8736572265625
# Cur diff sigma = 407.2989196777344
# Cur diff theta = 802.1725769042969
# ---------------------------------------
# NF_1, d: 200, Iter: 1-620, s/iter: 9.532e-02, ELBO: -3.319e+06
# Cur diff delta = 304.0655822753906
# Cur diff sigma = 327.75140380859375
# Cur diff theta = 631.8169860839844
# ---------------------------------------
# NF_1, d: 200, Iter: 1-640, s/iter: 9.042e-02, ELBO: -3.289e+06
# Cur diff delta = 243.84046936035156
# Cur diff sigma = 261.85528564453125
# Cur diff theta = 505.6957550048828
# ---------------------------------------
# NF_1, d: 200, Iter: 1-660, s/iter: 9.459e-02, ELBO: -3.244e+06
# Cur diff delta = 205.1904296875
# Cur diff sigma = 219.13038635253906
# Cur diff theta = 424.32081604003906
# ---------------------------------------
# NF_1, d: 200, Iter: 1-680, s/iter: 9.372e-02, ELBO: -3.210e+06
# Cur diff delta = 184.57908630371094
# Cur diff sigma = 182.9288787841797
# Cur diff theta = 367.5079650878906
# ---------------------------------------
# NF_1, d: 200, Iter: 1-700, s/iter: 9.128e-02, ELBO: -3.198e+06
# Cur diff delta = 175.57785034179688
# Cur diff sigma = 163.68936157226562
# Cur diff theta = 339.2672119140625
# ---------------------------------------
# NF_1, d: 200, Iter: 1-720, s/iter: 8.993e-02, ELBO: -3.198e+06
# Cur diff delta = 172.57325744628906
# Cur diff sigma = 151.8297576904297
# Cur diff theta = 324.40301513671875
# ---------------------------------------
# NF_1, d: 200, Iter: 1-740, s/iter: 9.025e-02, ELBO: -3.189e+06
# Cur diff delta = 172.24583435058594
# Cur diff sigma = 141.6509552001953
# Cur diff theta = 313.89678955078125
# ---------------------------------------
# NF_1, d: 200, Iter: 1-760, s/iter: 9.161e-02, ELBO: -3.179e+06
# Cur diff delta = 173.66278076171875
# Cur diff sigma = 133.7835235595703
# Cur diff theta = 307.44630432128906
# ---------------------------------------
# NF_1, d: 200, Iter: 1-780, s/iter: 9.140e-02, ELBO: -3.183e+06
# Cur diff delta = 176.95315551757812
# Cur diff sigma = 129.5923309326172
# Cur diff theta = 306.5454864501953
# ---------------------------------------
# NF_1, d: 200, Iter: 1-800, s/iter: 9.023e-02, ELBO: -3.172e+06
# Cur diff delta = 179.69607543945312
# Cur diff sigma = 126.89210510253906
# Cur diff theta = 306.5881805419922
# ---------------------------------------
# NF_1, d: 200, Iter: 1-820, s/iter: 9.101e-02, ELBO: -3.170e+06
# Cur diff delta = 183.35562133789062
# Cur diff sigma = 126.47109985351562
# Cur diff theta = 309.82672119140625
# ---------------------------------------
# NF_1, d: 200, Iter: 1-840, s/iter: 8.988e-02, ELBO: -3.173e+06
# Cur diff delta = 184.29486083984375
# Cur diff sigma = 126.3276138305664
# Cur diff theta = 310.62247467041016
# ---------------------------------------
# NF_1, d: 200, Iter: 1-860, s/iter: 1.041e-01, ELBO: -3.171e+06
# Cur diff delta = 184.16973876953125
# Cur diff sigma = 126.62134552001953
# Cur diff theta = 310.7910842895508
# ---------------------------------------
# NF_1, d: 200, Iter: 1-880, s/iter: 1.049e-01, ELBO: -3.160e+06
# Cur diff delta = 183.91448974609375
# Cur diff sigma = 125.91999816894531
# Cur diff theta = 309.83448791503906
# ---------------------------------------
# NF_1, d: 200, Iter: 1-900, s/iter: 9.247e-02, ELBO: -3.177e+06
# Cur diff delta = 183.42739868164062
# Cur diff sigma = 126.46237182617188
# Cur diff theta = 309.8897705078125
# ---------------------------------------
# NF_1, d: 200, Iter: 1-920, s/iter: 9.085e-02, ELBO: -3.174e+06
# Cur diff delta = 184.1795654296875
# Cur diff sigma = 126.63613891601562
# Cur diff theta = 310.8157043457031
# ---------------------------------------
# NF_1, d: 200, Iter: 1-940, s/iter: 9.575e-02, ELBO: -3.172e+06
# Cur diff delta = 184.28518676757812
# Cur diff sigma = 126.7582778930664
# Cur diff theta = 311.04346466064453
# ---------------------------------------
# NF_1, d: 200, Iter: 1-960, s/iter: 9.251e-02, ELBO: -3.170e+06
# Cur diff delta = 184.18682861328125
# Cur diff sigma = 126.69432067871094
# Cur diff theta = 310.8811492919922
# ---------------------------------------
# NF_1, d: 200, Iter: 1-980, s/iter: 9.636e-02, ELBO: -3.170e+06
# Cur diff delta = 184.38211059570312
# Cur diff sigma = 126.1837158203125
# Cur diff theta = 310.5658264160156
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1000, s/iter: 1.079e-01, ELBO: -3.166e+06
# Cur diff delta = 184.00819396972656
# Cur diff sigma = 126.27925109863281
# Cur diff theta = 310.2874450683594
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1020, s/iter: 9.148e-02, ELBO: -3.166e+06
# Cur diff delta = 184.20037841796875
# Cur diff sigma = 125.95179748535156
# Cur diff theta = 310.1521759033203
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1040, s/iter: 9.329e-02, ELBO: -3.166e+06
# Cur diff delta = 183.70497131347656
# Cur diff sigma = 126.34520721435547
# Cur diff theta = 310.05017852783203
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1060, s/iter: 9.032e-02, ELBO: -3.172e+06
# Cur diff delta = 184.293212890625
# Cur diff sigma = 126.28512573242188
# Cur diff theta = 310.5783386230469
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1080, s/iter: 1.016e-01, ELBO: -3.165e+06
# Cur diff delta = 184.03443908691406
# Cur diff sigma = 125.78465270996094
# Cur diff theta = 309.819091796875
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1100, s/iter: 9.302e-02, ELBO: -3.171e+06
# Cur diff delta = 184.2095489501953
# Cur diff sigma = 125.68616485595703
# Cur diff theta = 309.89571380615234
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1120, s/iter: 9.079e-02, ELBO: -3.169e+06
# Cur diff delta = 183.94097900390625
# Cur diff sigma = 126.25669860839844
# Cur diff theta = 310.1976776123047
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1140, s/iter: 9.277e-02, ELBO: -3.170e+06
# Cur diff delta = 183.77210998535156
# Cur diff sigma = 126.31946563720703
# Cur diff theta = 310.0915756225586
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1160, s/iter: 1.045e-01, ELBO: -3.168e+06
# Cur diff delta = 184.07127380371094
# Cur diff sigma = 126.38078308105469
# Cur diff theta = 310.4520568847656
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1180, s/iter: 9.293e-02, ELBO: -3.164e+06
# Cur diff delta = 184.3049774169922
# Cur diff sigma = 125.8953857421875
# Cur diff theta = 310.2003631591797
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1200, s/iter: 9.809e-02, ELBO: -3.147e+06
# Cur diff delta = 184.25257873535156
# Cur diff sigma = 125.87792205810547
# Cur diff theta = 310.13050079345703
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1220, s/iter: 9.465e-02, ELBO: -3.159e+06
# Cur diff delta = 184.16943359375
# Cur diff sigma = 125.8790512084961
# Cur diff theta = 310.0484848022461
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1240, s/iter: 9.392e-02, ELBO: -3.157e+06
# Cur diff delta = 184.17550659179688
# Cur diff sigma = 125.73657989501953
# Cur diff theta = 309.9120864868164
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1260, s/iter: 9.870e-02, ELBO: -3.159e+06
# Cur diff delta = 183.7272186279297
# Cur diff sigma = 125.937255859375
# Cur diff theta = 309.6644744873047
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1280, s/iter: 9.413e-02, ELBO: -3.153e+06
# Cur diff delta = 184.28883361816406
# Cur diff sigma = 125.60826110839844
# Cur diff theta = 309.8970947265625
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1300, s/iter: 9.703e-02, ELBO: -3.151e+06
# Cur diff delta = 184.21923828125
# Cur diff sigma = 125.68702697753906
# Cur diff theta = 309.90626525878906
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1320, s/iter: 9.354e-02, ELBO: -3.156e+06
# Cur diff delta = 184.36856079101562
# Cur diff sigma = 125.61212921142578
# Cur diff theta = 309.9806900024414
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1340, s/iter: 1.127e-01, ELBO: -3.163e+06
# Cur diff delta = 183.92227172851562
# Cur diff sigma = 126.15238952636719
# Cur diff theta = 310.0746612548828
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1360, s/iter: 9.585e-02, ELBO: -3.160e+06
# Cur diff delta = 183.9720458984375
# Cur diff sigma = 125.70293426513672
# Cur diff theta = 309.6749801635742
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1380, s/iter: 9.541e-02, ELBO: -3.158e+06
# Cur diff delta = 184.25689697265625
# Cur diff sigma = 125.7697525024414
# Cur diff theta = 310.02664947509766
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1400, s/iter: 1.033e-01, ELBO: -3.166e+06
# Cur diff delta = 184.0581817626953
# Cur diff sigma = 125.91124725341797
# Cur diff theta = 309.9694290161133
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1420, s/iter: 9.675e-02, ELBO: -3.155e+06
# Cur diff delta = 184.17564392089844
# Cur diff sigma = 125.45882415771484
# Cur diff theta = 309.6344680786133
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1440, s/iter: 1.050e-01, ELBO: -3.152e+06
# Cur diff delta = 183.62564086914062
# Cur diff sigma = 125.68582916259766
# Cur diff theta = 309.3114700317383
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1460, s/iter: 1.008e-01, ELBO: -3.158e+06
# Cur diff delta = 184.1669158935547
# Cur diff sigma = 125.76293182373047
# Cur diff theta = 309.92984771728516
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1480, s/iter: 9.389e-02, ELBO: -3.153e+06
# Cur diff delta = 184.02392578125
# Cur diff sigma = 125.30694580078125
# Cur diff theta = 309.33087158203125
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1500, s/iter: 9.303e-02, ELBO: -3.158e+06
# Cur diff delta = 184.2038116455078
# Cur diff sigma = 125.81615447998047
# Cur diff theta = 310.0199661254883
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1520, s/iter: 1.038e-01, ELBO: -3.154e+06
# Cur diff delta = 184.3115234375
# Cur diff sigma = 125.79570770263672
# Cur diff theta = 310.1072311401367
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1540, s/iter: 1.054e-01, ELBO: -3.165e+06
# Cur diff delta = 184.49424743652344
# Cur diff sigma = 126.02777862548828
# Cur diff theta = 310.5220260620117
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1560, s/iter: 9.452e-02, ELBO: -3.152e+06
# Cur diff delta = 184.00306701660156
# Cur diff sigma = 125.8199462890625
# Cur diff theta = 309.82301330566406
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1580, s/iter: 9.387e-02, ELBO: -3.159e+06
# Cur diff delta = 184.37721252441406
# Cur diff sigma = 126.02425384521484
# Cur diff theta = 310.4014663696289
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1600, s/iter: 9.222e-02, ELBO: -3.150e+06
# Cur diff delta = 184.5537872314453
# Cur diff sigma = 125.69544219970703
# Cur diff theta = 310.24922943115234
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1620, s/iter: 9.660e-02, ELBO: -3.155e+06
# Cur diff delta = 184.45249938964844
# Cur diff sigma = 125.51815795898438
# Cur diff theta = 309.9706573486328
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1640, s/iter: 9.367e-02, ELBO: -3.153e+06
# Cur diff delta = 184.6097412109375
# Cur diff sigma = 125.76144409179688
# Cur diff theta = 310.3711853027344
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1660, s/iter: 9.630e-02, ELBO: -3.159e+06
# Cur diff delta = 184.22267150878906
# Cur diff sigma = 125.81550598144531
# Cur diff theta = 310.0381774902344
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1680, s/iter: 9.693e-02, ELBO: -3.166e+06
# Cur diff delta = 184.3913116455078
# Cur diff sigma = 126.55704498291016
# Cur diff theta = 310.94835662841797
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1700, s/iter: 1.130e-01, ELBO: -3.158e+06
# Cur diff delta = 183.92379760742188
# Cur diff sigma = 125.91120910644531
# Cur diff theta = 309.8350067138672
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1720, s/iter: 9.278e-02, ELBO: -3.158e+06
# Cur diff delta = 184.65020751953125
# Cur diff sigma = 125.64019012451172
# Cur diff theta = 310.29039764404297
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1740, s/iter: 9.342e-02, ELBO: -3.155e+06
# Cur diff delta = 183.9427947998047
# Cur diff sigma = 125.39458465576172
# Cur diff theta = 309.3373794555664
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1760, s/iter: 9.521e-02, ELBO: -3.154e+06
# Cur diff delta = 183.99659729003906
# Cur diff sigma = 125.51927185058594
# Cur diff theta = 309.515869140625
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1780, s/iter: 9.630e-02, ELBO: -3.164e+06
# Cur diff delta = 183.63780212402344
# Cur diff sigma = 125.8753433227539
# Cur diff theta = 309.51314544677734
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1800, s/iter: 1.078e-01, ELBO: -3.162e+06
# Cur diff delta = 184.39186096191406
# Cur diff sigma = 126.09551239013672
# Cur diff theta = 310.4873733520508
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1820, s/iter: 9.702e-02, ELBO: -3.160e+06
# Cur diff delta = 183.80978393554688
# Cur diff sigma = 126.10948181152344
# Cur diff theta = 309.9192657470703
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1840, s/iter: 9.538e-02, ELBO: -3.153e+06
# Cur diff delta = 184.86888122558594
# Cur diff sigma = 125.73120880126953
# Cur diff theta = 310.60009002685547
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1860, s/iter: 9.584e-02, ELBO: -3.148e+06
# Cur diff delta = 184.35311889648438
# Cur diff sigma = 125.43215942382812
# Cur diff theta = 309.7852783203125
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1880, s/iter: 9.765e-02, ELBO: -3.150e+06
# Cur diff delta = 183.75521850585938
# Cur diff sigma = 125.75645446777344
# Cur diff theta = 309.5116729736328
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1900, s/iter: 9.835e-02, ELBO: -3.159e+06
# Cur diff delta = 184.01368713378906
# Cur diff sigma = 125.87914276123047
# Cur diff theta = 309.89282989501953
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1920, s/iter: 9.469e-02, ELBO: -3.154e+06
# Cur diff delta = 183.96607971191406
# Cur diff sigma = 125.67616271972656
# Cur diff theta = 309.6422424316406
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1940, s/iter: 9.841e-02, ELBO: -3.154e+06
# Cur diff delta = 184.3767547607422
# Cur diff sigma = 125.89237976074219
# Cur diff theta = 310.2691345214844
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1960, s/iter: 9.628e-02, ELBO: -3.161e+06
# Cur diff delta = 184.1143798828125
# Cur diff sigma = 126.14220428466797
# Cur diff theta = 310.25658416748047
# ---------------------------------------
# NF_1, d: 200, Iter: 1-1980, s/iter: 9.622e-02, ELBO: -3.157e+06
# Cur diff delta = 183.91006469726562
# Cur diff sigma = 125.67752075195312
# Cur diff theta = 309.58758544921875
# ---------------------------------------
# NF_1, d: 200, Iter: 1-2000, s/iter: 1.063e-01, ELBO: -3.159e+06
# Cur diff delta = 183.93060302734375
# Cur diff sigma = 125.7940444946289
# Cur diff theta = 309.72464752197266
# ---------------------------------------
# ------------------------------------------------------
# Test = 2
# ------------------------------------------------------
# Init diff delta = 26666.0
# Init diff sigma = 77495.03125
# Init diff theta = 104161.03125
# NF_1, d: 200, Iter: 2-20, s/iter: 9.534e-02, ELBO: -7.747e+06
# Cur diff delta = 23232.185546875
# Cur diff sigma = 46639.4765625
# Cur diff theta = 69871.662109375
# ---------------------------------------
# NF_1, d: 200, Iter: 2-40, s/iter: 9.547e-02, ELBO: -7.555e+06
# Cur diff delta = 22695.177734375
# Cur diff sigma = 41860.01171875
# Cur diff theta = 64555.189453125
# ---------------------------------------
# NF_1, d: 200, Iter: 2-60, s/iter: 1.036e-01, ELBO: -7.231e+06
# Cur diff delta = 21448.22265625
# Cur diff sigma = 37760.04296875
# Cur diff theta = 59208.265625
# ---------------------------------------
# NF_1, d: 200, Iter: 2-80, s/iter: 9.734e-02, ELBO: -6.921e+06
# Cur diff delta = 20117.6796875
# Cur diff sigma = 35154.25390625
# Cur diff theta = 55271.93359375
# ---------------------------------------
# NF_1, d: 200, Iter: 2-100, s/iter: 9.837e-02, ELBO: -6.628e+06
# Cur diff delta = 18606.529296875
# Cur diff sigma = 32335.208984375
# Cur diff theta = 50941.73828125
# ---------------------------------------
# NF_1, d: 200, Iter: 2-120, s/iter: 1.009e-01, ELBO: -6.342e+06
# Cur diff delta = 16435.849609375
# Cur diff sigma = 27208.005859375
# Cur diff theta = 43643.85546875
# ---------------------------------------
# NF_1, d: 200, Iter: 2-140, s/iter: 1.026e-01, ELBO: -6.106e+06
# Cur diff delta = 14544.58203125
# Cur diff sigma = 22897.896484375
# Cur diff theta = 37442.478515625
# ---------------------------------------
# NF_1, d: 200, Iter: 2-160, s/iter: 1.058e-01, ELBO: -5.903e+06
# Cur diff delta = 12882.1806640625
# Cur diff sigma = 19370.5
# Cur diff theta = 32252.6806640625
# ---------------------------------------
# NF_1, d: 200, Iter: 2-180, s/iter: 9.985e-02, ELBO: -5.711e+06
# Cur diff delta = 11387.7626953125
# Cur diff sigma = 16403.353515625
# Cur diff theta = 27791.1162109375
# ---------------------------------------
# NF_1, d: 200, Iter: 2-200, s/iter: 9.685e-02, ELBO: -5.529e+06
# Cur diff delta = 10060.525390625
# Cur diff sigma = 13965.26953125
# Cur diff theta = 24025.794921875
# ---------------------------------------
# NF_1, d: 200, Iter: 2-220, s/iter: 9.753e-02, ELBO: -5.360e+06
# Cur diff delta = 8896.5146484375
# Cur diff sigma = 11947.3720703125
# Cur diff theta = 20843.88671875
# ---------------------------------------
# NF_1, d: 200, Iter: 2-240, s/iter: 9.706e-02, ELBO: -5.193e+06
# Cur diff delta = 7876.28857421875
# Cur diff sigma = 10275.5537109375
# Cur diff theta = 18151.84228515625
# ---------------------------------------
# NF_1, d: 200, Iter: 2-260, s/iter: 1.082e-01, ELBO: -5.033e+06
# Cur diff delta = 6986.5302734375
# Cur diff sigma = 8875.234375
# Cur diff theta = 15861.7646484375
# ---------------------------------------
# NF_1, d: 200, Iter: 2-280, s/iter: 1.008e-01, ELBO: -4.895e+06
# Cur diff delta = 6208.03955078125
# Cur diff sigma = 7675.2119140625
# Cur diff theta = 13883.25146484375
# ---------------------------------------
# NF_1, d: 200, Iter: 2-300, s/iter: 1.007e-01, ELBO: -4.759e+06
# Cur diff delta = 5509.513671875
# Cur diff sigma = 6647.24609375
# Cur diff theta = 12156.759765625
# ---------------------------------------
# NF_1, d: 200, Iter: 2-320, s/iter: 9.853e-02, ELBO: -4.651e+06
# Cur diff delta = 4869.92724609375
# Cur diff sigma = 5726.447265625
# Cur diff theta = 10596.37451171875
# ---------------------------------------
# NF_1, d: 200, Iter: 2-340, s/iter: 1.123e-01, ELBO: -4.531e+06
# Cur diff delta = 4278.01708984375
# Cur diff sigma = 4896.603515625
# Cur diff theta = 9174.62060546875
# ---------------------------------------
# NF_1, d: 200, Iter: 2-360, s/iter: 1.074e-01, ELBO: -4.428e+06
# Cur diff delta = 3736.590087890625
# Cur diff sigma = 4166.322265625
# Cur diff theta = 7902.912353515625
# ---------------------------------------
# NF_1, d: 200, Iter: 2-380, s/iter: 9.820e-02, ELBO: -4.320e+06
# Cur diff delta = 3245.599365234375
# Cur diff sigma = 3529.34814453125
# Cur diff theta = 6774.947509765625
# ---------------------------------------
# NF_1, d: 200, Iter: 2-400, s/iter: 9.761e-02, ELBO: -4.213e+06
# Cur diff delta = 2800.36669921875
# Cur diff sigma = 2966.3037109375
# Cur diff theta = 5766.67041015625
# ---------------------------------------
# NF_1, d: 200, Iter: 2-420, s/iter: 9.826e-02, ELBO: -4.120e+06
# Cur diff delta = 2398.593017578125
# Cur diff sigma = 2472.26416015625
# Cur diff theta = 4870.857177734375
# ---------------------------------------
# NF_1, d: 200, Iter: 2-440, s/iter: 1.035e-01, ELBO: -4.011e+06
# Cur diff delta = 2035.531005859375
# Cur diff sigma = 2042.6953125
# Cur diff theta = 4078.226318359375
# ---------------------------------------
# NF_1, d: 200, Iter: 2-460, s/iter: 1.114e-01, ELBO: -3.922e+06
# Cur diff delta = 1710.578369140625
# Cur diff sigma = 1678.0093994140625
# Cur diff theta = 3388.5877685546875
# ---------------------------------------
# NF_1, d: 200, Iter: 2-480, s/iter: 1.012e-01, ELBO: -3.827e+06
# Cur diff delta = 1424.778564453125
# Cur diff sigma = 1368.90087890625
# Cur diff theta = 2793.679443359375
# ---------------------------------------
# NF_1, d: 200, Iter: 2-500, s/iter: 9.936e-02, ELBO: -3.738e+06
# Cur diff delta = 1177.025390625
# Cur diff sigma = 1110.9990234375
# Cur diff theta = 2288.0244140625
# ---------------------------------------
# NF_1, d: 200, Iter: 2-520, s/iter: 9.792e-02, ELBO: -3.664e+06
# Cur diff delta = 964.4981689453125
# Cur diff sigma = 896.7716674804688
# Cur diff theta = 1861.2698364257812
# ---------------------------------------
# NF_1, d: 200, Iter: 2-540, s/iter: 9.755e-02, ELBO: -3.594e+06
# Cur diff delta = 783.8502197265625
# Cur diff sigma = 720.0064086914062
# Cur diff theta = 1503.8566284179688
# ---------------------------------------
# NF_1, d: 200, Iter: 2-560, s/iter: 1.014e-01, ELBO: -3.519e+06
# Cur diff delta = 633.4271850585938
# Cur diff sigma = 575.6172485351562
# Cur diff theta = 1209.04443359375
# ---------------------------------------
# NF_1, d: 200, Iter: 2-580, s/iter: 1.006e-01, ELBO: -3.453e+06
# Cur diff delta = 507.4384460449219
# Cur diff sigma = 458.2655029296875
# Cur diff theta = 965.7039489746094
# ---------------------------------------
# NF_1, d: 200, Iter: 2-600, s/iter: 1.025e-01, ELBO: -3.370e+06
# Cur diff delta = 394.39337158203125
# Cur diff sigma = 361.2974853515625
# Cur diff theta = 755.6908569335938
# ---------------------------------------
# NF_1, d: 200, Iter: 2-620, s/iter: 1.075e-01, ELBO: -3.316e+06
# Cur diff delta = 299.7764587402344
# Cur diff sigma = 293.2826232910156
# Cur diff theta = 593.05908203125
# ---------------------------------------
# NF_1, d: 200, Iter: 2-640, s/iter: 9.914e-02, ELBO: -3.263e+06
# Cur diff delta = 241.85191345214844
# Cur diff sigma = 234.206298828125
# Cur diff theta = 476.05821228027344
# ---------------------------------------
# NF_1, d: 200, Iter: 2-660, s/iter: 9.942e-02, ELBO: -3.238e+06
# Cur diff delta = 209.81983947753906
# Cur diff sigma = 196.18162536621094
# Cur diff theta = 406.00146484375
# ---------------------------------------
# NF_1, d: 200, Iter: 2-680, s/iter: 9.952e-02, ELBO: -3.218e+06
# Cur diff delta = 194.53807067871094
# Cur diff sigma = 166.3397216796875
# Cur diff theta = 360.87779235839844
# ---------------------------------------
# NF_1, d: 200, Iter: 2-700, s/iter: 9.860e-02, ELBO: -3.190e+06
# Cur diff delta = 189.1670684814453
# Cur diff sigma = 149.29481506347656
# Cur diff theta = 338.4618835449219
# ---------------------------------------
# NF_1, d: 200, Iter: 2-720, s/iter: 1.031e-01, ELBO: -3.182e+06
# Cur diff delta = 190.2490234375
# Cur diff sigma = 141.06234741210938
# Cur diff theta = 331.3113708496094
# ---------------------------------------
# NF_1, d: 200, Iter: 2-740, s/iter: 9.736e-02, ELBO: -3.180e+06
# Cur diff delta = 192.98233032226562
# Cur diff sigma = 134.2351837158203
# Cur diff theta = 327.21751403808594
# ---------------------------------------
# NF_1, d: 200, Iter: 2-760, s/iter: 1.017e-01, ELBO: -3.180e+06
# Cur diff delta = 195.34292602539062
# Cur diff sigma = 129.70802307128906
# Cur diff theta = 325.0509490966797
# ---------------------------------------
# NF_1, d: 200, Iter: 2-780, s/iter: 9.984e-02, ELBO: -3.180e+06
# Cur diff delta = 199.33961486816406
# Cur diff sigma = 127.62106323242188
# Cur diff theta = 326.96067810058594
# ---------------------------------------
# NF_1, d: 200, Iter: 2-800, s/iter: 1.111e-01, ELBO: -3.173e+06
# Cur diff delta = 203.34007263183594
# Cur diff sigma = 126.41227722167969
# Cur diff theta = 329.7523498535156
# ---------------------------------------
# NF_1, d: 200, Iter: 2-820, s/iter: 9.897e-02, ELBO: -3.173e+06
# Cur diff delta = 204.93887329101562
# Cur diff sigma = 126.47126770019531
# Cur diff theta = 331.41014099121094
# ---------------------------------------
# NF_1, d: 200, Iter: 2-840, s/iter: 1.007e-01, ELBO: -3.174e+06
# Cur diff delta = 205.68492126464844
# Cur diff sigma = 126.4580078125
# Cur diff theta = 332.14292907714844
# ---------------------------------------
# NF_1, d: 200, Iter: 2-860, s/iter: 1.048e-01, ELBO: -3.174e+06
# Cur diff delta = 204.9791259765625
# Cur diff sigma = 126.23237609863281
# Cur diff theta = 331.2115020751953
# ---------------------------------------
# NF_1, d: 200, Iter: 2-880, s/iter: 1.018e-01, ELBO: -3.170e+06
# Cur diff delta = 205.30299377441406
# Cur diff sigma = 126.67877197265625
# Cur diff theta = 331.9817657470703
# ---------------------------------------
# NF_1, d: 200, Iter: 2-900, s/iter: 1.085e-01, ELBO: -3.175e+06
# Cur diff delta = 204.85533142089844
# Cur diff sigma = 126.38509368896484
# Cur diff theta = 331.2404251098633
# ---------------------------------------
# NF_1, d: 200, Iter: 2-920, s/iter: 1.080e-01, ELBO: -3.178e+06
# Cur diff delta = 205.724365234375
# Cur diff sigma = 126.3836441040039
# Cur diff theta = 332.1080093383789
# ---------------------------------------
# NF_1, d: 200, Iter: 2-940, s/iter: 1.170e-01, ELBO: -3.171e+06
# Cur diff delta = 205.30128479003906
# Cur diff sigma = 126.38988494873047
# Cur diff theta = 331.69116973876953
# ...
# Cur diff delta = 2749.492919921875
# Cur diff sigma = 0.0036450864281505346
# Cur diff theta = 2749.496565008303
# ---------------------------------------
# VB, d: 200, Iter: 3-780, s/iter: 7.745e-02, ELBO: -6.064e+05
# Cur diff delta = 2671.027099609375
# Cur diff sigma = 0.003644848009571433
# Cur diff theta = 2671.0307444573846
# ---------------------------------------
# VB, d: 200, Iter: 3-800, s/iter: 7.316e-02, ELBO: -6.049e+05
# Cur diff delta = 2595.310302734375
# Cur diff sigma = 0.0036446000449359417
# Cur diff theta = 2595.31394733442
# ---------------------------------------
# VB, d: 200, Iter: 3-820, s/iter: 7.294e-02, ELBO: -6.034e+05
# Cur diff delta = 2522.239501953125
# Cur diff sigma = 0.003644408890977502
# Cur diff theta = 2522.243146362016
# ---------------------------------------
# VB, d: 200, Iter: 3-840, s/iter: 7.241e-02, ELBO: -6.021e+05
# Cur diff delta = 2451.714599609375
# Cur diff sigma = 0.0036442691925913095
# Cur diff theta = 2451.7182438785676
# ---------------------------------------
# VB, d: 200, Iter: 3-860, s/iter: 8.381e-02, ELBO: -6.007e+05
# Cur diff delta = 2383.637939453125
# Cur diff sigma = 0.0036438656970858574
# Cur diff theta = 2383.641583318822
# ---------------------------------------
# VB, d: 200, Iter: 3-880, s/iter: 7.174e-02, ELBO: -5.994e+05
# Cur diff delta = 2317.919921875
# Cur diff sigma = 0.0036438710521906614
# Cur diff theta = 2317.923565746052
# ---------------------------------------
# VB, d: 200, Iter: 3-900, s/iter: 7.815e-02, ELBO: -5.982e+05
# Cur diff delta = 2254.470703125
# Cur diff sigma = 0.003643841715529561
# Cur diff theta = 2254.4743469667155
# ---------------------------------------
# VB, d: 200, Iter: 3-920, s/iter: 7.811e-02, ELBO: -5.970e+05
# Cur diff delta = 2193.203857421875
# Cur diff sigma = 0.0036436000373214483
# Cur diff theta = 2193.2075010219123
# ---------------------------------------
# VB, d: 200, Iter: 3-940, s/iter: 7.442e-02, ELBO: -5.958e+05
# Cur diff delta = 2134.037841796875
# Cur diff sigma = 0.0036434305366128683
# Cur diff theta = 2134.0414852274116
# ---------------------------------------
# VB, d: 200, Iter: 3-960, s/iter: 7.383e-02, ELBO: -5.947e+05
# Cur diff delta = 2076.894287109375
# Cur diff sigma = 0.0036433138884603977
# Cur diff theta = 2076.8979304232635
# ---------------------------------------
# VB, d: 200, Iter: 3-980, s/iter: 7.323e-02, ELBO: -5.936e+05
# Cur diff delta = 2021.6981201171875
# Cur diff sigma = 0.0036431218031793833
# Cur diff theta = 2021.7017632389907
# ---------------------------------------
# VB, d: 200, Iter: 3-1000, s/iter: 7.375e-02, ELBO: -5.925e+05
# Cur diff delta = 1968.375244140625
# Cur diff sigma = 0.003643026575446129
# Cur diff theta = 1968.3788871672004
# ---------------------------------------
# VB, d: 200, Iter: 3-1020, s/iter: 7.304e-02, ELBO: -5.915e+05
# Cur diff delta = 1916.855712890625
# Cur diff sigma = 0.0036429509054869413
# Cur diff theta = 1916.8593558415305
# ---------------------------------------
# VB, d: 200, Iter: 3-1040, s/iter: 7.517e-02, ELBO: -5.906e+05
# Cur diff delta = 1867.0731201171875
# Cur diff sigma = 0.003642755327746272
# Cur diff theta = 1867.0767628725152
# ---------------------------------------
# VB, d: 200, Iter: 3-1060, s/iter: 8.120e-02, ELBO: -5.896e+05
# Cur diff delta = 1818.961669921875
# Cur diff sigma = 0.0036427038721740246
# Cur diff theta = 1818.9653126257472
# ---------------------------------------
# VB, d: 200, Iter: 3-1080, s/iter: 8.000e-02, ELBO: -5.887e+05
# Cur diff delta = 1772.459716796875
# Cur diff sigma = 0.003642657306045294
# Cur diff theta = 1772.463359454181
# ---------------------------------------
# VB, d: 200, Iter: 3-1100, s/iter: 7.414e-02, ELBO: -5.878e+05
# Cur diff delta = 1727.5086669921875
# Cur diff sigma = 0.003642476163804531
# Cur diff theta = 1727.5123094683513
# ---------------------------------------
# VB, d: 200, Iter: 3-1120, s/iter: 7.496e-02, ELBO: -5.870e+05
# Cur diff delta = 1684.04931640625
# Cur diff sigma = 0.0036422512494027615
# Cur diff theta = 1684.0529586574994
# ---------------------------------------
# VB, d: 200, Iter: 3-1140, s/iter: 7.451e-02, ELBO: -5.861e+05
# Cur diff delta = 1642.02783203125
# Cur diff sigma = 0.0036422063130885363
# Cur diff theta = 1642.031474237563
# ---------------------------------------
# VB, d: 200, Iter: 3-1160, s/iter: 7.594e-02, ELBO: -5.853e+05
# Cur diff delta = 1601.39111328125
# Cur diff sigma = 0.003642248921096325
# Cur diff theta = 1601.394755530171
# ---------------------------------------
# VB, d: 200, Iter: 3-1180, s/iter: 7.734e-02, ELBO: -5.846e+05
# Cur diff delta = 1562.08740234375
# Cur diff sigma = 0.00364207592792809
# Cur diff theta = 1562.091044419678
# ---------------------------------------
# VB, d: 200, Iter: 3-1200, s/iter: 7.958e-02, ELBO: -5.838e+05
# Cur diff delta = 1524.0689697265625
# Cur diff sigma = 0.0036419937387108803
# Cur diff theta = 1524.0726117203012
# ---------------------------------------
# VB, d: 200, Iter: 3-1220, s/iter: 7.353e-02, ELBO: -5.831e+05
# Cur diff delta = 1487.2877197265625
# Cur diff sigma = 0.003642030293121934
# Cur diff theta = 1487.2913617568556
# ---------------------------------------
# VB, d: 200, Iter: 3-1240, s/iter: 7.328e-02, ELBO: -5.824e+05
# Cur diff delta = 1451.69873046875
# Cur diff sigma = 0.003641927381977439
# Cur diff theta = 1451.702372396132
# ---------------------------------------
# VB, d: 200, Iter: 3-1260, s/iter: 7.266e-02, ELBO: -5.817e+05
# Cur diff delta = 1417.2591552734375
# Cur diff sigma = 0.003641783958300948
# Cur diff theta = 1417.2627970573958
# ---------------------------------------
# VB, d: 200, Iter: 3-1280, s/iter: 7.801e-02, ELBO: -5.811e+05
# Cur diff delta = 1383.92626953125
# Cur diff sigma = 0.003641671733930707
# Cur diff theta = 1383.929911202984
# ---------------------------------------
# VB, d: 200, Iter: 3-1300, s/iter: 8.337e-02, ELBO: -5.804e+05
# Cur diff delta = 1351.66064453125
# Cur diff sigma = 0.003641616553068161
# Cur diff theta = 1351.664286147803
# ---------------------------------------
# VB, d: 200, Iter: 3-1320, s/iter: 7.239e-02, ELBO: -5.798e+05
# Cur diff delta = 1320.423828125
# Cur diff sigma = 0.0036416875664144754
# Cur diff theta = 1320.4274698125664
# ---------------------------------------
# VB, d: 200, Iter: 3-1340, s/iter: 7.251e-02, ELBO: -5.792e+05
# Cur diff delta = 1290.1790771484375
# Cur diff sigma = 0.0036415159702301025
# Cur diff theta = 1290.1827186644077
# ---------------------------------------
# VB, d: 200, Iter: 3-1360, s/iter: 7.345e-02, ELBO: -5.786e+05
# Cur diff delta = 1260.890380859375
# Cur diff sigma = 0.003641488030552864
# Cur diff theta = 1260.8940223474056
# ---------------------------------------
# VB, d: 200, Iter: 3-1380, s/iter: 7.295e-02, ELBO: -5.781e+05
# Cur diff delta = 1232.5234375
# Cur diff sigma = 0.0036413269117474556
# Cur diff theta = 1232.5270788269117
# ---------------------------------------
# VB, d: 200, Iter: 3-1400, s/iter: 7.551e-02, ELBO: -5.775e+05
# Cur diff delta = 1205.0450439453125
# Cur diff sigma = 0.003641359508037567
# Cur diff theta = 1205.0486853048205
# ---------------------------------------
# VB, d: 200, Iter: 3-1420, s/iter: 7.362e-02, ELBO: -5.770e+05
# Cur diff delta = 1178.4241943359375
# Cur diff sigma = 0.003641303861513734
# Cur diff theta = 1178.427835639799
# ---------------------------------------
# VB, d: 200, Iter: 3-1440, s/iter: 7.770e-02, ELBO: -5.765e+05
# Cur diff delta = 1152.629638671875
# Cur diff sigma = 0.0036412645131349564
# Cur diff theta = 1152.6332799363881
# ---------------------------------------
# VB, d: 200, Iter: 3-1460, s/iter: 7.259e-02, ELBO: -5.760e+05
# Cur diff delta = 1127.6317138671875
# Cur diff sigma = 0.0036412859335541725
# Cur diff theta = 1127.635355153121
# ---------------------------------------
# VB, d: 200, Iter: 3-1480, s/iter: 8.538e-02, ELBO: -5.755e+05
# Cur diff delta = 1103.4039306640625
# Cur diff sigma = 0.003641235874965787
# Cur diff theta = 1103.4075718999375
# ---------------------------------------
# VB, d: 200, Iter: 3-1500, s/iter: 7.405e-02, ELBO: -5.751e+05
# Cur diff delta = 1079.91845703125
# Cur diff sigma = 0.003641229122877121
# Cur diff theta = 1079.9220982603729
# ---------------------------------------
# VB, d: 200, Iter: 3-1520, s/iter: 8.382e-02, ELBO: -5.746e+05
# Cur diff delta = 1057.149169921875
# Cur diff sigma = 0.0036411182954907417
# Cur diff theta = 1057.1528110401705
# ---------------------------------------
# VB, d: 200, Iter: 3-1540, s/iter: 7.321e-02, ELBO: -5.742e+05
# Cur diff delta = 1035.0716552734375
# Cur diff sigma = 0.0036411720793694258
# Cur diff theta = 1035.0752964455169
# ---------------------------------------
# VB, d: 200, Iter: 3-1560, s/iter: 8.033e-02, ELBO: -5.738e+05
# Cur diff delta = 1013.6605834960938
# Cur diff sigma = 0.003640989074483514
# Cur diff theta = 1013.6642244851682
# ---------------------------------------
# VB, d: 200, Iter: 3-1580, s/iter: 7.799e-02, ELBO: -5.734e+05
# Cur diff delta = 992.8942260742188
# Cur diff sigma = 0.0036409839522093534
# Cur diff theta = 992.897867058171
# ---------------------------------------
# VB, d: 200, Iter: 3-1600, s/iter: 7.323e-02, ELBO: -5.730e+05
# Cur diff delta = 972.7490844726562
# Cur diff sigma = 0.003640960669144988
# Cur diff theta = 972.7527254333254
# ---------------------------------------
# VB, d: 200, Iter: 3-1620, s/iter: 7.922e-02, ELBO: -5.726e+05
# Cur diff delta = 953.2047729492188
# Cur diff sigma = 0.003640928538516164
# Cur diff theta = 953.2084138777573
# ---------------------------------------
# VB, d: 200, Iter: 3-1640, s/iter: 7.562e-02, ELBO: -5.722e+05
# Cur diff delta = 934.2398681640625
# Cur diff sigma = 0.0036409192252904177
# Cur diff theta = 934.2435090832878
# ---------------------------------------
# VB, d: 200, Iter: 3-1660, s/iter: 7.560e-02, ELBO: -5.719e+05
# Cur diff delta = 915.8353271484375
# Cur diff sigma = 0.0036408633459359407
# Cur diff theta = 915.8389680117834
# ---------------------------------------
# VB, d: 200, Iter: 3-1680, s/iter: 8.539e-02, ELBO: -5.715e+05
# Cur diff delta = 897.9714965820312
# Cur diff sigma = 0.003640884766355157
# Cur diff theta = 897.9751374667976
# ---------------------------------------
# VB, d: 200, Iter: 3-1700, s/iter: 7.679e-02, ELBO: -5.712e+05
# Cur diff delta = 880.631591796875
# Cur diff sigma = 0.0036407902371138334
# Cur diff theta = 880.6352325871121
# ---------------------------------------
# VB, d: 200, Iter: 3-1720, s/iter: 8.646e-02, ELBO: -5.708e+05
# Cur diff delta = 863.7952270507812
# Cur diff sigma = 0.0036408817395567894
# Cur diff theta = 863.7988679325208
# ---------------------------------------
# VB, d: 200, Iter: 3-1740, s/iter: 8.617e-02, ELBO: -5.705e+05
# Cur diff delta = 847.4478759765625
# Cur diff sigma = 0.003640795825049281
# Cur diff theta = 847.4515167723875
# ---------------------------------------
# VB, d: 200, Iter: 3-1760, s/iter: 7.450e-02, ELBO: -5.702e+05
# Cur diff delta = 831.5704345703125
# Cur diff sigma = 0.003640740877017379
# Cur diff theta = 831.5740753111895
# ---------------------------------------
# VB, d: 200, Iter: 3-1780, s/iter: 7.779e-02, ELBO: -5.699e+05
# Cur diff delta = 816.1500854492188
# Cur diff sigma = 0.003640784416347742
# Cur diff theta = 816.1537262336351
# ---------------------------------------
# VB, d: 200, Iter: 3-1800, s/iter: 8.432e-02, ELBO: -5.696e+05
# Cur diff delta = 801.169189453125
# Cur diff sigma = 0.0036407059524208307
# Cur diff theta = 801.1728301590774
# ---------------------------------------
# VB, d: 200, Iter: 3-1820, s/iter: 7.338e-02, ELBO: -5.693e+05
# Cur diff delta = 786.614501953125
# Cur diff sigma = 0.0036406780127435923
# Cur diff theta = 786.6181426311377
# ---------------------------------------
# VB, d: 200, Iter: 3-1840, s/iter: 7.386e-02, ELBO: -5.690e+05
# Cur diff delta = 772.4720458984375
# Cur diff sigma = 0.0036407134030014277
# Cur diff theta = 772.4756866118405
# ---------------------------------------
# VB, d: 200, Iter: 3-1860, s/iter: 8.440e-02, ELBO: -5.687e+05
# Cur diff delta = 758.7280883789062
# Cur diff sigma = 0.003640670096501708
# Cur diff theta = 758.7317290490028
# ---------------------------------------
# VB, d: 200, Iter: 3-1880, s/iter: 8.294e-02, ELBO: -5.685e+05
# Cur diff delta = 745.3684692382812
# Cur diff sigma = 0.0036406409926712513
# Cur diff theta = 745.3721098792739
# ---------------------------------------
# VB, d: 200, Iter: 3-1900, s/iter: 8.591e-02, ELBO: -5.682e+05
# Cur diff delta = 732.3817138671875
# Cur diff sigma = 0.0036406046710908413
# Cur diff theta = 732.3853544718586
# ---------------------------------------
# VB, d: 200, Iter: 3-1920, s/iter: 7.308e-02, ELBO: -5.680e+05
# Cur diff delta = 719.7561645507812
# Cur diff sigma = 0.0036405676510185003
# Cur diff theta = 719.7598051184323
# ---------------------------------------
# VB, d: 200, Iter: 3-1940, s/iter: 7.352e-02, ELBO: -5.677e+05
# Cur diff delta = 707.478271484375
# Cur diff sigma = 0.0036405976861715317
# Cur diff theta = 707.4819120820612
# ---------------------------------------
# VB, d: 200, Iter: 3-1960, s/iter: 7.516e-02, ELBO: -5.675e+05
# Cur diff delta = 695.5390625
# Cur diff sigma = 0.0036405909340828657
# Cur diff theta = 695.5427030909341
# ---------------------------------------
# VB, d: 200, Iter: 3-1980, s/iter: 8.361e-02, ELBO: -5.673e+05
# Cur diff delta = 683.9254760742188
# Cur diff sigma = 0.003640541108325124
# Cur diff theta = 683.9291166153271
# ---------------------------------------
# VB, d: 200, Iter: 3-2000, s/iter: 8.574e-02, ELBO: -5.670e+05
# Cur diff delta = 672.6297607421875
# Cur diff sigma = 0.003640545532107353
# Cur diff theta = 672.6334012877196
# ---------------------------------------
# Model HVAE_1, test = 0, result delta diff = 183.45849609375
# Model HVAE_1, test = 0, result sigma diff = 0.332958459854126
# Model HVAE_1, test = 0, result theta diff = 183.7914581298828
# Model HVAE_1, test = 1, result delta diff = 205.34616088867188
# Model HVAE_1, test = 1, result sigma diff = 0.33400043845176697
# Model HVAE_1, test = 1, result theta diff = 205.68016052246094
# Model HVAE_1, test = 2, result delta diff = 200.6571502685547
# Model HVAE_1, test = 2, result sigma diff = 0.3378676772117615
# Model HVAE_1, test = 2, result theta diff = 200.99501037597656
# Model HVAE_2, test = 0, result delta diff = 183.7972412109375
# Model HVAE_2, test = 0, result sigma diff = 0.30696815252304077
# Model HVAE_2, test = 0, result theta diff = 184.1042022705078
# Model HVAE_2, test = 1, result delta diff = 205.11700439453125
# Model HVAE_2, test = 1, result sigma diff = 0.30571064352989197
# Model HVAE_2, test = 1, result theta diff = 205.42271423339844
# Model HVAE_2, test = 2, result delta diff = 200.2071533203125
# Model HVAE_2, test = 2, result sigma diff = 0.31064045429229736
# Model HVAE_2, test = 2, result theta diff = 200.51779174804688
# Model NF_1, test = 0, result delta diff = 183.9305877685547
# Model NF_1, test = 0, result sigma diff = 125.79403686523438
# Model NF_1, test = 0, result theta diff = 309.724609375
# Model NF_1, test = 1, result delta diff = 205.45211791992188
# Model NF_1, test = 1, result sigma diff = 125.87238311767578
# Model NF_1, test = 1, result theta diff = 331.3244934082031
# Model NF_1, test = 2, result delta diff = 200.53009033203125
# Model NF_1, test = 2, result sigma diff = 125.91531372070312
# Model NF_1, test = 2, result theta diff = 326.4454040527344
# Model NF_2, test = 0, result delta diff = 184.42034912109375
# Model NF_2, test = 0, result sigma diff = 125.5378646850586
# Model NF_2, test = 0, result theta diff = 309.9582214355469
# Model NF_2, test = 1, result delta diff = 205.4742431640625
# Model NF_2, test = 1, result sigma diff = 125.6274185180664
# Model NF_2, test = 1, result theta diff = 331.1016540527344
# Model NF_2, test = 2, result delta diff = 200.65817260742188
# Model NF_2, test = 2, result sigma diff = 125.10679626464844
# Model NF_2, test = 2, result theta diff = 325.76495361328125
# Model VB, test = 0, result delta diff = 617.085693359375
# Model VB, test = 0, result sigma diff = 0.0034447945654392242
# Model VB, test = 0, result theta diff = 617.089111328125
# Model VB, test = 1, result delta diff = 615.775634765625
# Model VB, test = 1, result sigma diff = 0.0031295367516577244
# Model VB, test = 1, result theta diff = 615.7787475585938
# Model VB, test = 2, result delta diff = 672.6297607421875
# Model VB, test = 2, result sigma diff = 0.003640544367954135
# Model VB, test = 2, result theta diff = 672.6334228515625

# %%
model_names = ['HVAE_1', 'HVAE_2', 'NF_1', 'NF_2', 'VB']
diff_delta_results = {}
diff_sigma_results = {}
diff_results = {}
for name in model_names:
    diff_delta_tests = np.zeros(params['n_tests'])
    diff_sigma_tests = np.zeros(params['n_tests'])
    diff_tests = np.zeros(params['n_tests'])
    for i in range(params['n_tests']):
        file_name = name + '_train_' + str(i) + '.p'
        diff_path = os.path.join('save', str(params['dims'][0]), file_name)
        with open(diff_path, 'rb') as f:
            data = pickle.load(f)
            elbo = data['elbo']
            diff_delta = data['diff_delta']
            diff_sigma = data['diff_sigma']
            diff = diff_delta + diff_sigma
            diff_delta_is_not_nan = diff_delta[~np.isnan(diff_delta)]
            diff_sigma_is_not_nan = diff_sigma[~np.isnan(diff_sigma)]
            diff_is_not_nan = diff[~np.isnan(diff)]
            diff_delta_tests[i] = diff_delta_is_not_nan[-1]
            diff_sigma_tests[i] = diff_sigma_is_not_nan[-1]
            diff_tests[i] = diff_is_not_nan[-1]
    diff_delta_results[name] = diff_delta_tests
    diff_sigma_results[name] = diff_sigma_tests
    diff_results[name] = diff_tests
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, diff delta = {diff_delta_tests}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, diff sigma = {diff_sigma_tests}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, diff = {diff_tests}")
# Out:
# Model = HVAE_1, dimensionality = 200, diff delta = [183.45848083 205.34617615 200.65716553]
# Model = HVAE_1, dimensionality = 200, diff sigma = [0.33295846 0.33400047 0.33786768]
# Model = HVAE_1, dimensionality = 200, diff = [183.79144287 205.68017578 200.99502563]
# Model = HVAE_2, dimensionality = 200, diff delta = [183.79724121 205.11697388 200.20713806]
# Model = HVAE_2, dimensionality = 200, diff sigma = [0.30696803 0.30571064 0.31064045]
# Model = HVAE_2, dimensionality = 200, diff = [184.10420227 205.42268372 200.51777649]
# Model = NF_1, dimensionality = 200, diff delta = [183.93060303 205.45214844 200.53007507]
# Model = NF_1, dimensionality = 200, diff sigma = [125.79404449 125.87238312 125.91531372]
# Model = NF_1, dimensionality = 200, diff = [309.72463989 331.32452393 326.44537354]
# Model = NF_2, dimensionality = 200, diff delta = [184.4203186  205.47422791 200.65820312]
# Model = NF_2, dimensionality = 200, diff sigma = [125.53786469 125.62741852 125.10678101]
# Model = NF_2, dimensionality = 200, diff = [309.95819092 331.10165405 325.76498413]
# Model = VB, dimensionality = 200, diff delta = [617.08563232 615.77563477 672.62976074]
# Model = VB, dimensionality = 200, diff sigma = [0.00344479 0.00312954 0.00364055]
# Model = VB, dimensionality = 200, diff = [617.08905029 615.77874756 672.63342285]

# %%
for name in model_names:
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, mean diff delta = {diff_delta_results[name].mean()}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, mean diff sigma = {diff_sigma_results[name].mean()}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, mean diff = {diff_results[name].mean()}")
# Out:
# Model = HVAE_1, dimensionality = 200, mean diff delta = 196.48727416992188
# Model = HVAE_1, dimensionality = 200, mean diff sigma = 0.3349422017733256
# Model = HVAE_1, dimensionality = 200, mean diff = 196.82221476236978
# Model = HVAE_2, dimensionality = 200, mean diff delta = 196.37378438313803
# Model = HVAE_2, dimensionality = 200, mean diff sigma = 0.30777304371198017
# Model = HVAE_2, dimensionality = 200, mean diff = 196.68155415852866
# Model = NF_1, dimensionality = 200, mean diff delta = 196.63760884602866
# Model = NF_1, dimensionality = 200, mean diff sigma = 125.86058044433594
# Model = NF_1, dimensionality = 200, mean diff = 322.49817911783856
# Model = NF_2, dimensionality = 200, mean diff delta = 196.85091654459634
# Model = NF_2, dimensionality = 200, mean diff sigma = 125.4240214029948
# Model = NF_2, dimensionality = 200, mean diff = 322.2749430338542
# Model = VB, dimensionality = 200, mean diff delta = 635.1636759440104
# Model = VB, dimensionality = 200, mean diff sigma = 0.003404958018412193
# Model = VB, dimensionality = 200, mean diff = 635.1670735677084

# %%
params = {

    # PROBLEM SPECIFICATION
    #'dims': [1, 2, 3, 5, 11, 25, 51, 101, 201, 301], # Dimensions to test
    'dims': [200],
    'n_data': 10000,                                 # Number of data points

    # TEST HYPERPARAMETERS
    'n_tests': 3,      # Number of experiments to run

    # GLOBAL OPTIMIZATION PARAMETERS
    'n_iter': 4000,    # Number of optimization iterations
    'n_batch': 10,      # Number of points for ELBO estimate
    'rms_eta': 0.001,   # Stepsize for RMSProp
    'save_every': 20,   # Save parameter information every so often
    'print_every': 20, # Print less often than save

    # HVAE HYPERPARAMETERS
    'HVAE_K_1': 1,    # Number of leapfrog/cooling steps for HVAE flow 1
    'HVAE_K_2': 10,   # Number of leapfrog/cooling steps for HVAE flow 2
    'max_eps': 0.5,   # Maximum leapfrog step size per dimension 

    # NF HYPERPARAMETERS
    'NF_K_1': 1,    # Number of flow steps for NF flow 1
    'NF_K_2': 30,   # Number of flow steps for NF flow 2
    
}

# %%
def run_test(d, params, 
             batch_size=256,
             clip_value=None,
             dtype=torch.float32, 
             device=torch.device("cpu")):
    """ 
    Run the gaussian test with dimension d 
    """

    ######### Problem Specification

    # Data generation parameters
    prior_mu_z = torch.zeros(d, dtype=dtype)    # Prior mean
    prior_sigma_z = torch.eye(d, dtype=dtype)   # Prior covariance matrix

    # True model parameters
    num_range = torch.arange(-(d-1)/2, (d+1)/2, dtype=dtype)

    t_delta =  num_range / 5 

    print(f"true delta = {t_delta.numpy()}")

    if d == 1:
        t_sigma = torch.ones(1, dtype=dtype)
    else: 
        # Allow sigma to range from 0.1 to 1
        t_sigma = 36/(10*(d-1)**2) * num_range**2 + 0.1 
    print(f"true sigma = {t_sigma.numpy()}")

    ######### Variable Initialization

    # Initial model parameters - same across all methods
    init_delta = prior_mu_z.clone().to(device)
    init_log_sigma = 3 * torch.ones(d).to(device)

    # Initial HVAE variational parameters
    init_T = torch.tensor(5., dtype=dtype, device=device)
    init_eps = 0.005 * torch.ones(d, dtype=dtype)
    max_eps = params['max_eps'] * torch.ones(d, dtype=dtype)
    init_logit_eps = torch.log(init_eps/(max_eps - init_eps)).to(device)
    init_log_T_0 = torch.log(init_T - 1)

    # Initial NF variational parameters
    init_u_pre_reparam = torch.tensor(scipy.stats.truncnorm.rvs(-2, 2, 
                                                                scale=0.1, 
                                                                size=d),
                                      dtype=dtype, device=device)
    init_w = torch.tensor(scipy.stats.truncnorm.rvs(-2, 2, scale=0.1, size=d),
                          dtype=dtype, device=device)
    init_b = torch.tensor(0.1, dtype=dtype, device=device)

    # Initial VAE parameters
    init_mu_z = prior_mu_z.clone()
    init_log_sigma_z = torch.ones(d, dtype=dtype)

    ######### Set up models
    init_params = [[init_delta, init_log_sigma, init_logit_eps, init_log_T_0],
                   [init_delta, init_log_sigma, init_logit_eps, init_log_T_0],
                   [init_delta, init_log_sigma, init_u_pre_reparam, init_w, init_b],
                   [init_delta, init_log_sigma, init_u_pre_reparam, init_w, init_b],
                   [init_delta, init_log_sigma, init_mu_z, init_log_sigma_z]]
    
    VB_model = VB(params,
        ['delta', 'log_sigma', 'mu_z', 'log_sigma_z'], 
        init_params[4], 'VB', d)

    #model_list = [HVAE_model_1, HVAE_model_2, NF_model_1]
    #model_list = [HVAE_model_1, NF_model_1]
    model_list = [VB_model]

    print("Models were initialized!")
    
    ######### Generate Training Data & Save - One for each test

    train_data_list = []

    for i in range(params['n_tests']):
        z = MultivariateNormal(prior_mu_z, prior_sigma_z).sample()
        x = MultivariateNormal(z + t_delta, 
                               torch.diag(t_sigma**2)).sample([params['n_data']])
        x = x.to(device)
        train_data_list.append(x)

    # Folder should have already been created in the initializations
    data_path = os.path.join('save', str(d), 'train_data.p')
    pickle.dump(train_data_list, open(data_path, 'wb')) 

    # Store the final parameter values for all test runs in this dictionary
    final_params = {}

    for i in range(len(model_list)):
        final_values = []
        m = model_list[i]
        model_init_params = init_params[i]

        for j in range(params['n_tests']):
            print("------------------------------------------------------")
            print(f"Test = {j}")
            print("------------------------------------------------------")
            m._reinitialize(model_init_params)
            gaussian_data = gaussian_dataset(train_data_list[j])
            train_dataloader = DataLoader(gaussian_data, batch_size=batch_size,
                                          shuffle=False, num_workers=0)
            (delta, sigma) = m.train(train_dataloader, j, 
                                     t_delta, t_sigma,
                                     clip_value)
            final_values.append((delta, sigma))

        final_params[m.model_name] = final_values.copy()

    ######### Test models using difference between parameters

    param_diffs = {}

    for m in model_list:
        
        diffs = []

        for i in range(params['n_tests']):
            delta = final_params[m.model_name][i][0]
            sigma = final_params[m.model_name][i][1]

            delta_diff = np.sum((delta - t_delta.numpy())**2)
            sigma_diff = np.sum((sigma - t_sigma.numpy())**2)
            theta_diff = delta_diff + sigma_diff
            print(f"Model {m.model_name}, test = {i}, result delta diff = {delta_diff}")
            print(f"Model {m.model_name}, test = {i}, result sigma diff = {sigma_diff}")
            print(f"Model {m.model_name}, test = {i}, result theta diff = {theta_diff}")

            diffs.append((delta_diff, sigma_diff, theta_diff))

        param_diffs[m.model_name] = diffs.copy()

    # Save parameter differences in a pickle file
    diff_path = os.path.join('save', str(d), 'all_diffs.p')
    pickle.dump(param_diffs, open(diff_path, 'wb'))

# %%
device = torch.device("cuda")
dtype = torch.float32
clip_value = None
batch_size = 256

# %%
dims = params['dims']
seed = 12345
np.random.seed(seed)
torch.manual_seed(seed)
for d in dims:
    print('**** Running test for d={0:d} ****'.format(d))
    run_test(d, params, batch_size, clip_value, dtype, device)
# Out:
# **** Running test for d=200 ****
# true delta = [-19.9 -19.7 -19.5 -19.3 -19.1 -18.9 -18.7 -18.5 -18.3 -18.1 -17.9 -17.7
#  -17.5 -17.3 -17.1 -16.9 -16.7 -16.5 -16.3 -16.1 -15.9 -15.7 -15.5 -15.3
#  -15.1 -14.9 -14.7 -14.5 -14.3 -14.1 -13.9 -13.7 -13.5 -13.3 -13.1 -12.9
#  -12.7 -12.5 -12.3 -12.1 -11.9 -11.7 -11.5 -11.3 -11.1 -10.9 -10.7 -10.5
#  -10.3 -10.1  -9.9  -9.7  -9.5  -9.3  -9.1  -8.9  -8.7  -8.5  -8.3  -8.1
#   -7.9  -7.7  -7.5  -7.3  -7.1  -6.9  -6.7  -6.5  -6.3  -6.1  -5.9  -5.7
#   -5.5  -5.3  -5.1  -4.9  -4.7  -4.5  -4.3  -4.1  -3.9  -3.7  -3.5  -3.3
#   -3.1  -2.9  -2.7  -2.5  -2.3  -2.1  -1.9  -1.7  -1.5  -1.3  -1.1  -0.9
#   -0.7  -0.5  -0.3  -0.1   0.1   0.3   0.5   0.7   0.9   1.1   1.3   1.5
#    1.7   1.9   2.1   2.3   2.5   2.7   2.9   3.1   3.3   3.5   3.7   3.9
#    4.1   4.3   4.5   4.7   4.9   5.1   5.3   5.5   5.7   5.9   6.1   6.3
#    6.5   6.7   6.9   7.1   7.3   7.5   7.7   7.9   8.1   8.3   8.5   8.7
#    8.9   9.1   9.3   9.5   9.7   9.9  10.1  10.3  10.5  10.7  10.9  11.1
#   11.3  11.5  11.7  11.9  12.1  12.3  12.5  12.7  12.9  13.1  13.3  13.5
#   13.7  13.9  14.1  14.3  14.5  14.7  14.9  15.1  15.3  15.5  15.7  15.9
#   16.1  16.3  16.5  16.7  16.9  17.1  17.3  17.5  17.7  17.9  18.1  18.3
#   18.5  18.7  18.9  19.1  19.3  19.5  19.7  19.9]
# true sigma = [1.         0.98200047 0.96418273 0.94654685 0.92909276 0.9118205
#  0.89473    0.8778213  0.8610945  0.8445494  0.8281862  0.8120048
#  0.7960052  0.7801874  0.76455146 0.7490973  0.7338249  0.7187344
#  0.7038257  0.6890988  0.6745537  0.6601904  0.64600897 0.6320093
#  0.6181915  0.6045555  0.5911012  0.5778289  0.5647383  0.5518295
#  0.53910255 0.52655745 0.51419413 0.5020126  0.49001288 0.47819498
#  0.46655893 0.45510468 0.44383222 0.43274158 0.42183277 0.41110578
#  0.4005606  0.39019722 0.38001564 0.37001592 0.36019796 0.35056186
#  0.34110755 0.33183506 0.32274437 0.3138355  0.30510846 0.2965632
#  0.2881998  0.28001818 0.27201837 0.2642004  0.25656423 0.24910986
#  0.24183732 0.2347466  0.22783768 0.22111058 0.21456529 0.20820183
#  0.20202015 0.1960203  0.19020227 0.18456605 0.17911164 0.17383905
#  0.16874826 0.16383931 0.15911214 0.15456681 0.15020329 0.14602157
#  0.14202167 0.13820359 0.1345673  0.13111286 0.1278402  0.12474938
#  0.12184036 0.11911315 0.11656776 0.11420419 0.11202242 0.11002248
#  0.10820434 0.10656802 0.10511351 0.10384081 0.10274993 0.10184086
#  0.10111361 0.10056817 0.10020454 0.10002273 0.10002273 0.10020454
#  0.10056817 0.10111361 0.10184086 0.10274993 0.10384081 0.10511351
#  0.10656802 0.10820434 0.11002248 0.11202242 0.11420419 0.11656776
#  0.11911315 0.12184036 0.12474938 0.1278402  0.13111286 0.1345673
#  0.13820359 0.14202167 0.14602157 0.15020329 0.15456681 0.15911214
#  0.16383931 0.16874826 0.17383905 0.17911164 0.18456605 0.19020227
#  0.1960203  0.20202015 0.20820183 0.21456529 0.22111058 0.22783768
#  0.2347466  0.24183732 0.24910986 0.25656423 0.2642004  0.27201837
#  0.28001818 0.2881998  0.2965632  0.30510846 0.3138355  0.32274437
#  0.33183506 0.34110755 0.35056186 0.36019796 0.37001592 0.38001564
#  0.39019722 0.4005606  0.41110578 0.42183277 0.43274158 0.44383222
#  0.45510468 0.46655893 0.47819498 0.49001288 0.5020126  0.51419413
#  0.52655745 0.53910255 0.5518295  0.5647383  0.5778289  0.5911012
#  0.6045555  0.6181915  0.6320093  0.64600897 0.6601904  0.6745537
#  0.6890988  0.7038257  0.7187344  0.7338249  0.7490973  0.76455146
#  0.7801874  0.7960052  0.8120048  0.8281862  0.8445494  0.8610945
#  0.8778213  0.89473    0.9118205  0.92909276 0.94654685 0.96418273
#  0.98200047 1.        ]
# Models were initialized!
# ------------------------------------------------------
# Test = 0
# ------------------------------------------------------
# Init diff delta = 26666.0
# Init diff sigma = 77495.03125
# Init diff theta = 104161.03125
# VB, d: 200, Iter: 1-20, s/iter: 1.113e-01, ELBO: -7.303e+06
# Cur diff delta = 23139.541015625
# Cur diff sigma = 27214.599609375
# Cur diff theta = 50354.140625
# ---------------------------------------
# VB, d: 200, Iter: 1-40, s/iter: 1.089e-01, ELBO: -6.507e+06
# Cur diff delta = 20328.912109375
# Cur diff sigma = 17835.171875
# Cur diff theta = 38164.083984375
# ---------------------------------------
# VB, d: 200, Iter: 1-60, s/iter: 1.085e-01, ELBO: -5.641e+06
# Cur diff delta = 17754.787109375
# Cur diff sigma = 13089.763671875
# Cur diff theta = 30844.55078125
# ---------------------------------------
# VB, d: 200, Iter: 1-80, s/iter: 1.103e-01, ELBO: -4.649e+06
# Cur diff delta = 15491.2607421875
# Cur diff sigma = 9674.3271484375
# Cur diff theta = 25165.587890625
# ---------------------------------------
# VB, d: 200, Iter: 1-100, s/iter: 1.198e-01, ELBO: -3.618e+06
# Cur diff delta = 13583.65234375
# Cur diff sigma = 7036.15234375
# Cur diff theta = 20619.8046875
# ---------------------------------------
# VB, d: 200, Iter: 1-120, s/iter: 1.114e-01, ELBO: -2.806e+06
# Cur diff delta = 11994.4443359375
# Cur diff sigma = 4992.04638671875
# Cur diff theta = 16986.49072265625
# ---------------------------------------
# VB, d: 200, Iter: 1-140, s/iter: 1.090e-01, ELBO: -2.272e+06
# Cur diff delta = 10654.962890625
# Cur diff sigma = 3427.79296875
# Cur diff theta = 14082.755859375
# ---------------------------------------
# VB, d: 200, Iter: 1-160, s/iter: 1.103e-01, ELBO: -1.881e+06
# Cur diff delta = 9565.6767578125
# Cur diff sigma = 2257.230712890625
# Cur diff theta = 11822.907470703125
# ---------------------------------------
# VB, d: 200, Iter: 1-180, s/iter: 1.162e-01, ELBO: -1.562e+06
# Cur diff delta = 8669.7734375
# Cur diff sigma = 1403.3905029296875
# Cur diff theta = 10073.163940429688
# ---------------------------------------
# VB, d: 200, Iter: 1-200, s/iter: 1.089e-01, ELBO: -1.321e+06
# Cur diff delta = 7929.99755859375
# Cur diff sigma = 799.1231689453125
# Cur diff theta = 8729.120727539062
# ---------------------------------------
# VB, d: 200, Iter: 1-220, s/iter: 1.143e-01, ELBO: -1.109e+06
# Cur diff delta = 7299.87890625
# Cur diff sigma = 400.2618713378906
# Cur diff theta = 7700.140777587891
# ---------------------------------------
# VB, d: 200, Iter: 1-240, s/iter: 1.199e-01, ELBO: -9.254e+05
# Cur diff delta = 6778.27392578125
# Cur diff sigma = 165.11727905273438
# Cur diff theta = 6943.391204833984
# ---------------------------------------
# VB, d: 200, Iter: 1-260, s/iter: 1.089e-01, ELBO: -7.854e+05
# Cur diff delta = 6354.47265625
# Cur diff sigma = 47.65682601928711
# Cur diff theta = 6402.129482269287
# ---------------------------------------
# VB, d: 200, Iter: 1-280, s/iter: 1.161e-01, ELBO: -6.853e+05
# Cur diff delta = 6025.19580078125
# Cur diff sigma = 6.509644031524658
# Cur diff theta = 6031.705444812775
# ---------------------------------------
# VB, d: 200, Iter: 1-300, s/iter: 1.111e-01, ELBO: -6.398e+05
# Cur diff delta = 5782.2109375
# Cur diff sigma = 0.056818339973688126
# Cur diff theta = 5782.267755839974
# ---------------------------------------
# VB, d: 200, Iter: 1-320, s/iter: 1.211e-01, ELBO: -6.339e+05
# Cur diff delta = 5596.70947265625
# Cur diff sigma = 0.002735423156991601
# Cur diff theta = 5596.712208079407
# ---------------------------------------
# VB, d: 200, Iter: 1-340, s/iter: 1.123e-01, ELBO: -6.304e+05
# Cur diff delta = 5421.43408203125
# Cur diff sigma = 0.0027345491107553244
# Cur diff theta = 5421.436816580361
# ---------------------------------------
# VB, d: 200, Iter: 1-360, s/iter: 1.198e-01, ELBO: -6.269e+05
# Cur diff delta = 5252.32275390625
# Cur diff sigma = 0.002733768429607153
# Cur diff theta = 5252.32548767468
# ---------------------------------------
# VB, d: 200, Iter: 1-380, s/iter: 1.118e-01, ELBO: -6.236e+05
# Cur diff delta = 5089.166015625
# Cur diff sigma = 0.0027329465374350548
# Cur diff theta = 5089.168748571537
# ---------------------------------------
# VB, d: 200, Iter: 1-400, s/iter: 1.198e-01, ELBO: -6.204e+05
# Cur diff delta = 4931.7470703125
# Cur diff sigma = 0.002732203807681799
# Cur diff theta = 4931.749802516308
# ---------------------------------------
# VB, d: 200, Iter: 1-420, s/iter: 1.097e-01, ELBO: -6.173e+05
# Cur diff delta = 4779.86279296875
# Cur diff sigma = 0.002731551183387637
# Cur diff theta = 4779.865524519933
# ---------------------------------------
# VB, d: 200, Iter: 1-440, s/iter: 1.217e-01, ELBO: -6.143e+05
# Cur diff delta = 4633.30908203125
# Cur diff sigma = 0.002730801235884428
# Cur diff theta = 4633.311812832486
# ---------------------------------------
# VB, d: 200, Iter: 1-460, s/iter: 1.136e-01, ELBO: -6.114e+05
# Cur diff delta = 4491.8935546875
# Cur diff sigma = 0.002730158157646656
# Cur diff theta = 4491.896284845658
# ---------------------------------------
# VB, d: 200, Iter: 1-480, s/iter: 1.200e-01, ELBO: -6.086e+05
# Cur diff delta = 4355.431640625
# Cur diff sigma = 0.0027295087929815054
# Cur diff theta = 4355.434370133793
# ---------------------------------------
# VB, d: 200, Iter: 1-500, s/iter: 1.244e-01, ELBO: -6.059e+05
# Cur diff delta = 4223.74365234375
# Cur diff sigma = 0.002728990511968732
# Cur diff theta = 4223.746381334262
# ---------------------------------------
# VB, d: 200, Iter: 1-520, s/iter: 1.108e-01, ELBO: -6.033e+05
# Cur diff delta = 4096.6533203125
# Cur diff sigma = 0.0027284121606498957
# Cur diff theta = 4096.656048724661
# ---------------------------------------
# VB, d: 200, Iter: 1-540, s/iter: 1.083e-01, ELBO: -6.008e+05
# Cur diff delta = 3973.994873046875
# Cur diff sigma = 0.002727897372096777
# Cur diff theta = 3973.997600944247
# ---------------------------------------
# VB, d: 200, Iter: 1-560, s/iter: 1.090e-01, ELBO: -5.984e+05
# Cur diff delta = 3855.60595703125
# Cur diff sigma = 0.0027273737359791994
# Cur diff theta = 3855.608684404986
# ---------------------------------------
# VB, d: 200, Iter: 1-580, s/iter: 1.087e-01, ELBO: -5.960e+05
# Cur diff delta = 3741.330322265625
# Cur diff sigma = 0.0027268221601843834
# Cur diff theta = 3741.333049087785
# ---------------------------------------
# VB, d: 200, Iter: 1-600, s/iter: 1.080e-01, ELBO: -5.938e+05
# Cur diff delta = 3631.019775390625
# Cur diff sigma = 0.0027263115625828505
# Cur diff theta = 3631.0225017021876
# ---------------------------------------
# VB, d: 200, Iter: 1-620, s/iter: 1.096e-01, ELBO: -5.916e+05
# Cur diff delta = 3524.5263671875
# Cur diff sigma = 0.0027258822228759527
# Cur diff theta = 3524.529093069723
# ---------------------------------------
# VB, d: 200, Iter: 1-640, s/iter: 1.120e-01, ELBO: -5.895e+05
# Cur diff delta = 3421.712646484375
# Cur diff sigma = 0.0027254996821284294
# Cur diff theta = 3421.715371984057
# ---------------------------------------
# VB, d: 200, Iter: 1-660, s/iter: 1.103e-01, ELBO: -5.874e+05
# Cur diff delta = 3322.44091796875
# Cur diff sigma = 0.0027250763960182667
# Cur diff theta = 3322.443643045146
# ---------------------------------------
# VB, d: 200, Iter: 1-680, s/iter: 1.122e-01, ELBO: -5.854e+05
# Cur diff delta = 3226.5849609375
# Cur diff sigma = 0.002724654972553253
# Cur diff theta = 3226.5876855924726
# ---------------------------------------
# VB, d: 200, Iter: 1-700, s/iter: 1.097e-01, ELBO: -5.836e+05
# Cur diff delta = 3134.01904296875
# Cur diff sigma = 0.002724265679717064
# Cur diff theta = 3134.0217672344297
# ---------------------------------------
# VB, d: 200, Iter: 1-720, s/iter: 1.095e-01, ELBO: -5.817e+05
# Cur diff delta = 3044.62060546875
# Cur diff sigma = 0.0027238824404776096
# Cur diff theta = 3044.6233293511905
# ---------------------------------------
# VB, d: 200, Iter: 1-740, s/iter: 1.087e-01, ELBO: -5.799e+05
# Cur diff delta = 2958.27587890625
# Cur diff sigma = 0.00272357021458447
# Cur diff theta = 2958.2786024764646
# ---------------------------------------
# VB, d: 200, Iter: 1-760, s/iter: 1.083e-01, ELBO: -5.782e+05
# Cur diff delta = 2874.872314453125
# Cur diff sigma = 0.0027231895364820957
# Cur diff theta = 2874.8750376426615
# ---------------------------------------
# VB, d: 200, Iter: 1-780, s/iter: 1.084e-01, ELBO: -5.766e+05
# Cur diff delta = 2794.30322265625
# Cur diff sigma = 0.0027228863909840584
# Cur diff theta = 2794.305945542641
# ---------------------------------------
# VB, d: 200, Iter: 1-800, s/iter: 1.146e-01, ELBO: -5.749e+05
# Cur diff delta = 2716.464111328125
# Cur diff sigma = 0.0027225962840020657
# Cur diff theta = 2716.466833924409
# ---------------------------------------
# VB, d: 200, Iter: 1-820, s/iter: 1.074e-01, ELBO: -5.734e+05
# Cur diff delta = 2641.254638671875
# Cur diff sigma = 0.0027222370263189077
# Cur diff theta = 2641.2573609089013
# ---------------------------------------
# VB, d: 200, Iter: 1-840, s/iter: 1.192e-01, ELBO: -5.719e+05
# Cur diff delta = 2568.580322265625
# Cur diff sigma = 0.0027220011688768864
# Cur diff theta = 2568.583044266794
# ---------------------------------------
# VB, d: 200, Iter: 1-860, s/iter: 1.077e-01, ELBO: -5.704e+05
# Cur diff delta = 2498.3486328125
# Cur diff sigma = 0.00272171082906425
# Cur diff theta = 2498.351354523329
# ---------------------------------------
# VB, d: 200, Iter: 1-880, s/iter: 1.099e-01, ELBO: -5.690e+05
# Cur diff delta = 2430.471435546875
# Cur diff sigma = 0.002721459837630391
# Cur diff theta = 2430.4741570067126
# ---------------------------------------
# VB, d: 200, Iter: 1-900, s/iter: 1.072e-01, ELBO: -5.677e+05
# Cur diff delta = 2364.861328125
# Cur diff sigma = 0.0027211790438741446
# Cur diff theta = 2364.864049304044
# ---------------------------------------
# VB, d: 200, Iter: 1-920, s/iter: 1.090e-01, ELBO: -5.664e+05
# Cur diff delta = 2301.4375
# Cur diff sigma = 0.0027209424879401922
# Cur diff theta = 2301.440220942488
# ---------------------------------------
# VB, d: 200, Iter: 1-940, s/iter: 1.122e-01, ELBO: -5.651e+05
# Cur diff delta = 2240.11962890625
# Cur diff sigma = 0.002720730844885111
# Cur diff theta = 2240.122349637095
# ---------------------------------------
# VB, d: 200, Iter: 1-960, s/iter: 1.117e-01, ELBO: -5.639e+05
# Cur diff delta = 2180.832763671875
# Cur diff sigma = 0.002720465185120702
# Cur diff theta = 2180.83548413706
# ---------------------------------------
# VB, d: 200, Iter: 1-980, s/iter: 1.161e-01, ELBO: -5.627e+05
# Cur diff delta = 2123.501953125
# Cur diff sigma = 0.0027202770579606295
# Cur diff theta = 2123.504673402058
# ---------------------------------------
# VB, d: 200, Iter: 1-1000, s/iter: 1.092e-01, ELBO: -5.615e+05
# Cur diff delta = 2068.05810546875
# Cur diff sigma = 0.002720071002840996
# Cur diff theta = 2068.060825539753
# ---------------------------------------
# VB, d: 200, Iter: 1-1020, s/iter: 1.076e-01, ELBO: -5.604e+05
# Cur diff delta = 2014.43115234375
# Cur diff sigma = 0.00271988264285028
# Cur diff theta = 2014.4338722263929
# ---------------------------------------
# VB, d: 200, Iter: 1-1040, s/iter: 1.097e-01, ELBO: -5.593e+05
# Cur diff delta = 1962.55859375
# Cur diff sigma = 0.002719657029956579
# Cur diff theta = 1962.56131340703
# ---------------------------------------
# VB, d: 200, Iter: 1-1060, s/iter: 1.133e-01, ELBO: -5.583e+05
# Cur diff delta = 1912.3756103515625
# Cur diff sigma = 0.0027194712311029434
# Cur diff theta = 1912.3783298227936
# ---------------------------------------
# VB, d: 200, Iter: 1-1080, s/iter: 1.221e-01, ELBO: -5.573e+05
# Cur diff delta = 1863.821533203125
# Cur diff sigma = 0.0027193566784262657
# Cur diff theta = 1863.8242525598034
# ---------------------------------------
# VB, d: 200, Iter: 1-1100, s/iter: 1.098e-01, ELBO: -5.563e+05
# Cur diff delta = 1816.8387451171875
# Cur diff sigma = 0.002719154581427574
# Cur diff theta = 1816.841464271769
# ---------------------------------------
# VB, d: 200, Iter: 1-1120, s/iter: 1.075e-01, ELBO: -5.554e+05
# Cur diff delta = 1771.3714599609375
# Cur diff sigma = 0.0027190051041543484
# Cur diff theta = 1771.3741789660417
# ---------------------------------------
# VB, d: 200, Iter: 1-1140, s/iter: 1.100e-01, ELBO: -5.544e+05
# Cur diff delta = 1727.364990234375
# Cur diff sigma = 0.0027188602834939957
# Cur diff theta = 1727.3677090946585
# ---------------------------------------
# VB, d: 200, Iter: 1-1160, s/iter: 1.078e-01, ELBO: -5.535e+05
# Cur diff delta = 1684.767822265625
# Cur diff sigma = 0.002718705218285322
# Cur diff theta = 1684.7705409708433
# ---------------------------------------
# VB, d: 200, Iter: 1-1180, s/iter: 1.072e-01, ELBO: -5.527e+05
# Cur diff delta = 1643.5302734375
# Cur diff sigma = 0.002718566218391061
# Cur diff theta = 1643.5329920037184
# ---------------------------------------
# VB, d: 200, Iter: 1-1200, s/iter: 1.077e-01, ELBO: -5.519e+05
# Cur diff delta = 1603.6043701171875
# Cur diff sigma = 0.002718421397730708
# Cur diff theta = 1603.6070885385852
# ---------------------------------------
# VB, d: 200, Iter: 1-1220, s/iter: 1.072e-01, ELBO: -5.510e+05
# Cur diff delta = 1564.942626953125
# Cur diff sigma = 0.0027183033525943756
# Cur diff theta = 1564.9453452564776
# ---------------------------------------
# VB, d: 200, Iter: 1-1240, s/iter: 1.119e-01, ELBO: -5.503e+05
# Cur diff delta = 1527.5018310546875
# Cur diff sigma = 0.002718132920563221
# Cur diff theta = 1527.504549187608
# ---------------------------------------
# VB, d: 200, Iter: 1-1260, s/iter: 1.077e-01, ELBO: -5.495e+05
# Cur diff delta = 1491.2384033203125
# Cur diff sigma = 0.0027180190663784742
# Cur diff theta = 1491.2411213393789
# ---------------------------------------
# VB, d: 200, Iter: 1-1280, s/iter: 1.101e-01, ELBO: -5.488e+05
# Cur diff delta = 1456.1112060546875
# Cur diff sigma = 0.0027179087046533823
# Cur diff theta = 1456.1139239633922
# ---------------------------------------
# VB, d: 200, Iter: 1-1300, s/iter: 1.099e-01, ELBO: -5.480e+05
# Cur diff delta = 1422.08056640625
# Cur diff sigma = 0.0027177988085895777
# Cur diff theta = 1422.0832842050586
# ---------------------------------------
# VB, d: 200, Iter: 1-1320, s/iter: 1.079e-01, ELBO: -5.474e+05
# Cur diff delta = 1389.1082763671875
# Cur diff sigma = 0.00271772057749331
# Cur diff theta = 1389.110994087765
# ---------------------------------------
# VB, d: 200, Iter: 1-1340, s/iter: 1.085e-01, ELBO: -5.467e+05
# Cur diff delta = 1357.15771484375
# Cur diff sigma = 0.002717593451961875
# Cur diff theta = 1357.160432437202
# ---------------------------------------
# VB, d: 200, Iter: 1-1360, s/iter: 1.082e-01, ELBO: -5.460e+05
# Cur diff delta = 1326.1934814453125
# Cur diff sigma = 0.002717491937801242
# Cur diff theta = 1326.1961989372503
# ---------------------------------------
# VB, d: 200, Iter: 1-1380, s/iter: 1.091e-01, ELBO: -5.454e+05
# Cur diff delta = 1296.1815185546875
# Cur diff sigma = 0.002717394847422838
# Cur diff theta = 1296.184235949535
# ---------------------------------------
# VB, d: 200, Iter: 1-1400, s/iter: 1.125e-01, ELBO: -5.448e+05
# Cur diff delta = 1267.0897216796875
# Cur diff sigma = 0.0027172891423106194
# Cur diff theta = 1267.0924389688298
# ---------------------------------------
# VB, d: 200, Iter: 1-1420, s/iter: 1.091e-01, ELBO: -5.442e+05
# Cur diff delta = 1238.8857421875
# Cur diff sigma = 0.0027172439731657505
# Cur diff theta = 1238.8884594314732
# ---------------------------------------
# VB, d: 200, Iter: 1-1440, s/iter: 1.119e-01, ELBO: -5.436e+05
# Cur diff delta = 1211.538330078125
# Cur diff sigma = 0.002717142691835761
# Cur diff theta = 1211.5410472208168
# ---------------------------------------
# VB, d: 200, Iter: 1-1460, s/iter: 1.107e-01, ELBO: -5.430e+05
# Cur diff delta = 1185.01953125
# Cur diff sigma = 0.0027170840185135603
# Cur diff theta = 1185.0222483340185
# ---------------------------------------
# VB, d: 200, Iter: 1-1480, s/iter: 1.073e-01, ELBO: -5.425e+05
# Cur diff delta = 1159.3013916015625
# Cur diff sigma = 0.002716975985094905
# Cur diff theta = 1159.3041085775476
# ---------------------------------------
# VB, d: 200, Iter: 1-1500, s/iter: 1.103e-01, ELBO: -5.420e+05
# Cur diff delta = 1134.355712890625
# Cur diff sigma = 0.00271689728833735
# Cur diff theta = 1134.3584297879133
# ---------------------------------------
# VB, d: 200, Iter: 1-1520, s/iter: 1.126e-01, ELBO: -5.415e+05
# Cur diff delta = 1110.15625
# Cur diff sigma = 0.002716825110837817
# Cur diff theta = 1110.1589668251108
# ---------------------------------------
# VB, d: 200, Iter: 1-1540, s/iter: 1.127e-01, ELBO: -5.410e+05
# Cur diff delta = 1086.677001953125
# Cur diff sigma = 0.0027167233638465405
# Cur diff theta = 1086.6797186764888
# ---------------------------------------
# VB, d: 200, Iter: 1-1560, s/iter: 1.202e-01, ELBO: -5.405e+05
# Cur diff delta = 1063.8951416015625
# Cur diff sigma = 0.0027166963554918766
# Cur diff theta = 1063.897858297918
# ---------------------------------------
# VB, d: 200, Iter: 1-1580, s/iter: 1.111e-01, ELBO: -5.400e+05
# Cur diff delta = 1041.787109375
# Cur diff sigma = 0.002716596471145749
# Cur diff theta = 1041.7898259714711
# ---------------------------------------
# VB, d: 200, Iter: 1-1600, s/iter: 1.073e-01, ELBO: -5.396e+05
# Cur diff delta = 1020.3311767578125
# Cur diff sigma = 0.002716540591791272
# Cur diff theta = 1020.3338932984043
# ---------------------------------------
# VB, d: 200, Iter: 1-1620, s/iter: 1.107e-01, ELBO: -5.391e+05
# Cur diff delta = 999.5030517578125
# Cur diff sigma = 0.002716498216614127
# Cur diff theta = 999.5057682560291
# ---------------------------------------
# VB, d: 200, Iter: 1-1640, s/iter: 1.117e-01, ELBO: -5.387e+05
# Cur diff delta = 979.2839965820312
# Cur diff sigma = 0.002716446528211236
# Cur diff theta = 979.2867130285595
# ---------------------------------------
# VB, d: 200, Iter: 1-1660, s/iter: 1.080e-01, ELBO: -5.383e+05
# Cur diff delta = 959.653564453125
# Cur diff sigma = 0.0027163843624293804
# Cur diff theta = 959.6562808374874
# ---------------------------------------
# VB, d: 200, Iter: 1-1680, s/iter: 1.075e-01, ELBO: -5.379e+05
# Cur diff delta = 940.591552734375
# Cur diff sigma = 0.002716304501518607
# Cur diff theta = 940.5942690388765
# ---------------------------------------
# VB, d: 200, Iter: 1-1700, s/iter: 1.217e-01, ELBO: -5.375e+05
# Cur diff delta = 922.079833984375
# Cur diff sigma = 0.0027162402402609587
# Cur diff theta = 922.0825502246153
# ---------------------------------------
# VB, d: 200, Iter: 1-1720, s/iter: 1.159e-01, ELBO: -5.371e+05
# Cur diff delta = 904.1002807617188
# Cur diff sigma = 0.002716189483180642
# Cur diff theta = 904.1029969512019
# ---------------------------------------
# VB, d: 200, Iter: 1-1740, s/iter: 1.277e-01, ELBO: -5.367e+05
# Cur diff delta = 886.63623046875
# Cur diff sigma = 0.002716152695938945
# Cur diff theta = 886.6389466214459
# ---------------------------------------
# VB, d: 200, Iter: 1-1760, s/iter: 1.141e-01, ELBO: -5.363e+05
# Cur diff delta = 869.6702270507812
# Cur diff sigma = 0.0027160991448909044
# Cur diff theta = 869.6729431499261
# ---------------------------------------
# VB, d: 200, Iter: 1-1780, s/iter: 1.137e-01, ELBO: -5.360e+05
# Cur diff delta = 853.1852416992188
# Cur diff sigma = 0.002716072602197528
# Cur diff theta = 853.187957771821
# ---------------------------------------
# VB, d: 200, Iter: 1-1800, s/iter: 1.119e-01, ELBO: -5.356e+05
# Cur diff delta = 837.1666259765625
# Cur diff sigma = 0.002716047689318657
# Cur diff theta = 837.1693420242518
# ---------------------------------------
# VB, d: 200, Iter: 1-1820, s/iter: 1.132e-01, ELBO: -5.353e+05
# Cur diff delta = 821.5990600585938
# Cur diff sigma = 0.002716000424697995
# Cur diff theta = 821.6017760590184
# ---------------------------------------
# VB, d: 200, Iter: 1-1840, s/iter: 1.080e-01, ELBO: -5.350e+05
# Cur diff delta = 806.468505859375
# Cur diff sigma = 0.0027159592136740685
# Cur diff theta = 806.4712218185887
# ---------------------------------------
# VB, d: 200, Iter: 1-1860, s/iter: 1.084e-01, ELBO: -5.347e+05
# Cur diff delta = 791.759521484375
# Cur diff sigma = 0.002715922659263015
# Cur diff theta = 791.7622374070343
# ---------------------------------------
# VB, d: 200, Iter: 1-1880, s/iter: 1.150e-01, ELBO: -5.343e+05
# Cur diff delta = 777.4595947265625
# Cur diff sigma = 0.0027158656157553196
# Cur diff theta = 777.4623105921783
# ---------------------------------------
# VB, d: 200, Iter: 1-1900, s/iter: 1.079e-01, ELBO: -5.340e+05
# Cur diff delta = 763.5560302734375
# Cur diff sigma = 0.002715847222134471
# Cur diff theta = 763.5587461206596
# ---------------------------------------
# VB, d: 200, Iter: 1-1920, s/iter: 1.079e-01, ELBO: -5.338e+05
# Cur diff delta = 750.0359497070312
# Cur diff sigma = 0.002715819515287876
# Cur diff theta = 750.0386655265465
# ---------------------------------------
# VB, d: 200, Iter: 1-1940, s/iter: 1.076e-01, ELBO: -5.335e+05
# Cur diff delta = 736.88720703125
# Cur diff sigma = 0.0027157848235219717
# Cur diff theta = 736.8899228160735
# ---------------------------------------
# VB, d: 200, Iter: 1-1960, s/iter: 1.085e-01, ELBO: -5.332e+05
# Cur diff delta = 724.0985107421875
# Cur diff sigma = 0.0027157370932400227
# Cur diff theta = 724.1012264792807
# ---------------------------------------
# VB, d: 200, Iter: 1-1980, s/iter: 1.150e-01, ELBO: -5.329e+05
# Cur diff delta = 711.657470703125
# Cur diff sigma = 0.0027157196309417486
# Cur diff theta = 711.6601864227559
# ---------------------------------------
# VB, d: 200, Iter: 1-2000, s/iter: 1.112e-01, ELBO: -5.327e+05
# Cur diff delta = 699.5546264648438
# Cur diff sigma = 0.0027156982105225325
# Cur diff theta = 699.5573421630543
# ---------------------------------------
# VB, d: 200, Iter: 1-2020, s/iter: 1.076e-01, ELBO: -5.324e+05
# Cur diff delta = 687.7777709960938
# Cur diff sigma = 0.002715659560635686
# Cur diff theta = 687.7804866556544
# ---------------------------------------
# VB, d: 200, Iter: 1-2040, s/iter: 1.087e-01, ELBO: -5.321e+05
# Cur diff delta = 676.3185424804688
# Cur diff sigma = 0.0027156316209584475
# Cur diff theta = 676.3212581120897
# ---------------------------------------
# VB, d: 200, Iter: 1-2060, s/iter: 1.111e-01, ELBO: -5.319e+05
# Cur diff delta = 665.165771484375
# Cur diff sigma = 0.0027156039141118526
# Cur diff theta = 665.1684870882891
# ---------------------------------------
# VB, d: 200, Iter: 1-2080, s/iter: 1.092e-01, ELBO: -5.317e+05
# Cur diff delta = 654.3107299804688
# Cur diff sigma = 0.002715570852160454
# Cur diff theta = 654.3134455513209
# ---------------------------------------
# VB, d: 200, Iter: 1-2100, s/iter: 1.231e-01, ELBO: -5.314e+05
# Cur diff delta = 643.7429809570312
# Cur diff sigma = 0.00271555595099926
# Cur diff theta = 643.7456965129822
# ---------------------------------------
# VB, d: 200, Iter: 1-2120, s/iter: 1.103e-01, ELBO: -5.312e+05
# Cur diff delta = 633.4557495117188
# Cur diff sigma = 0.0027155254501849413
# Cur diff theta = 633.4584650371689
# ---------------------------------------
# VB, d: 200, Iter: 1-2140, s/iter: 1.091e-01, ELBO: -5.310e+05
# Cur diff delta = 623.439697265625
# Cur diff sigma = 0.002715502865612507
# Cur diff theta = 623.4424127684906
# ---------------------------------------
# VB, d: 200, Iter: 1-2160, s/iter: 1.100e-01, ELBO: -5.308e+05
# Cur diff delta = 613.68603515625
# Cur diff sigma = 0.0027154837734997272
# Cur diff theta = 613.6887506400235
# ---------------------------------------
# VB, d: 200, Iter: 1-2180, s/iter: 1.083e-01, ELBO: -5.306e+05
# Cur diff delta = 604.1876220703125
# Cur diff sigma = 0.002715463750064373
# Cur diff theta = 604.1903375340626
# ---------------------------------------
# VB, d: 200, Iter: 1-2200, s/iter: 1.093e-01, ELBO: -5.304e+05
# Cur diff delta = 594.9359130859375
# Cur diff sigma = 0.002715444890782237
# Cur diff theta = 594.9386285308283
# ---------------------------------------
# VB, d: 200, Iter: 1-2220, s/iter: 1.268e-01, ELBO: -5.302e+05
# Cur diff delta = 585.92431640625
# Cur diff sigma = 0.0027154230047017336
# Cur diff theta = 585.9270318292547
# ---------------------------------------
# VB, d: 200, Iter: 1-2240, s/iter: 1.169e-01, ELBO: -5.300e+05
# Cur diff delta = 577.14453125
# Cur diff sigma = 0.002715390408411622
# Cur diff theta = 577.1472466404084
# ---------------------------------------
# VB, d: 200, Iter: 1-2260, s/iter: 1.096e-01, ELBO: -5.298e+05
# Cur diff delta = 568.5909423828125
# Cur diff sigma = 0.002715365495532751
# Cur diff theta = 568.593657748308
# ---------------------------------------
# VB, d: 200, Iter: 1-2280, s/iter: 1.086e-01, ELBO: -5.296e+05
# Cur diff delta = 560.2559204101562
# Cur diff sigma = 0.0027153491973876953
# Cur diff theta = 560.2586357593536
# ---------------------------------------
# VB, d: 200, Iter: 1-2300, s/iter: 1.078e-01, ELBO: -5.294e+05
# Cur diff delta = 552.1331176757812
# Cur diff sigma = 0.0027153380215168
# Cur diff theta = 552.1358330138028
# ---------------------------------------
# VB, d: 200, Iter: 1-2320, s/iter: 1.200e-01, ELBO: -5.292e+05
# Cur diff delta = 544.2163696289062
# Cur diff sigma = 0.002715319860726595
# Cur diff theta = 544.219084948767
# ---------------------------------------
# VB, d: 200, Iter: 1-2340, s/iter: 1.085e-01, ELBO: -5.291e+05
# Cur diff delta = 536.499755859375
# Cur diff sigma = 0.00271530426107347
# Cur diff theta = 536.5024711636361
# ---------------------------------------
# VB, d: 200, Iter: 1-2360, s/iter: 1.080e-01, ELBO: -5.289e+05
# Cur diff delta = 528.9776000976562
# Cur diff sigma = 0.00271527748554945
# Cur diff theta = 528.9803153751418
# ---------------------------------------
# VB, d: 200, Iter: 1-2380, s/iter: 1.148e-01, ELBO: -5.287e+05
# Cur diff delta = 521.6444702148438
# Cur diff sigma = 0.0027152602560818195
# Cur diff theta = 521.6471854750998
# ---------------------------------------
# VB, d: 200, Iter: 1-2400, s/iter: 1.089e-01, ELBO: -5.286e+05
# Cur diff delta = 514.4926147460938
# Cur diff sigma = 0.0027152516413480043
# Cur diff theta = 514.4953299977351
# ---------------------------------------
# VB, d: 200, Iter: 1-2420, s/iter: 1.164e-01, ELBO: -5.284e+05
# Cur diff delta = 507.5190124511719
# Cur diff sigma = 0.002715235110372305
# Cur diff theta = 507.52172768628225
# ---------------------------------------
# VB, d: 200, Iter: 1-2440, s/iter: 1.109e-01, ELBO: -5.283e+05
# Cur diff delta = 500.71820068359375
# Cur diff sigma = 0.002715231152251363
# Cur diff theta = 500.720915914746
# ---------------------------------------
# VB, d: 200, Iter: 1-2460, s/iter: 1.092e-01, ELBO: -5.281e+05
# Cur diff delta = 494.08447265625
# Cur diff sigma = 0.0027152118273079395
# Cur diff theta = 494.0871878680773
# ---------------------------------------
# VB, d: 200, Iter: 1-2480, s/iter: 1.079e-01, ELBO: -5.280e+05
# Cur diff delta = 487.61456298828125
# Cur diff sigma = 0.002715193433687091
# Cur diff theta = 487.61727818171494
# ---------------------------------------
# VB, d: 200, Iter: 1-2500, s/iter: 1.120e-01, ELBO: -5.278e+05
# Cur diff delta = 481.3009948730469
# Cur diff sigma = 0.0027151841204613447
# Cur diff theta = 481.30371005716734
# ---------------------------------------
# VB, d: 200, Iter: 1-2520, s/iter: 1.084e-01, ELBO: -5.277e+05
# Cur diff delta = 475.1422424316406
# Cur diff sigma = 0.0027151743415743113
# Cur diff theta = 475.1449576059822
# ---------------------------------------
# VB, d: 200, Iter: 1-2540, s/iter: 1.124e-01, ELBO: -5.276e+05
# Cur diff delta = 469.1332702636719
# Cur diff sigma = 0.002715158509090543
# Cur diff theta = 469.13598542218097
# ---------------------------------------
# VB, d: 200, Iter: 1-2560, s/iter: 1.106e-01, ELBO: -5.274e+05
# Cur diff delta = 463.26837158203125
# Cur diff sigma = 0.0027151410467922688
# Cur diff theta = 463.27108672307804
# ---------------------------------------
# VB, d: 200, Iter: 1-2580, s/iter: 1.098e-01, ELBO: -5.273e+05
# Cur diff delta = 457.544189453125
# Cur diff sigma = 0.0027151380199939013
# Cur diff theta = 457.546904591145
# ---------------------------------------
# VB, d: 200, Iter: 1-2600, s/iter: 1.112e-01, ELBO: -5.272e+05
# Cur diff delta = 451.9576416015625
# Cur diff sigma = 0.002715128008276224
# Cur diff theta = 451.9603567295708
# ---------------------------------------
# VB, d: 200, Iter: 1-2620, s/iter: 1.095e-01, ELBO: -5.270e+05
# Cur diff delta = 446.50469970703125
# Cur diff sigma = 0.0027151124086230993
# Cur diff theta = 446.5074148194399
# ---------------------------------------
# VB, d: 200, Iter: 1-2640, s/iter: 1.108e-01, ELBO: -5.269e+05
# Cur diff delta = 441.1802978515625
# Cur diff sigma = 0.002715107286348939
# Cur diff theta = 441.18301295884885
# ---------------------------------------
# VB, d: 200, Iter: 1-2660, s/iter: 1.105e-01, ELBO: -5.268e+05
# Cur diff delta = 435.9813232421875
# Cur diff sigma = 0.002715103095397353
# Cur diff theta = 435.9840383452829
# ---------------------------------------
# VB, d: 200, Iter: 1-2680, s/iter: 1.122e-01, ELBO: -5.267e+05
# Cur diff delta = 430.906982421875
# Cur diff sigma = 0.002715084468945861
# Cur diff theta = 430.90969750634395
# ---------------------------------------
# VB, d: 200, Iter: 1-2700, s/iter: 1.119e-01, ELBO: -5.266e+05
# Cur diff delta = 425.9505615234375
# Cur diff sigma = 0.0027150691021233797
# Cur diff theta = 425.9532765925396
# ---------------------------------------
# VB, d: 200, Iter: 1-2720, s/iter: 1.230e-01, ELBO: -5.265e+05
# Cur diff delta = 421.1098327636719
# Cur diff sigma = 0.002715061418712139
# Cur diff theta = 421.1125478250906
# ---------------------------------------
# VB, d: 200, Iter: 1-2740, s/iter: 1.129e-01, ELBO: -5.264e+05
# Cur diff delta = 416.38226318359375
# Cur diff sigma = 0.0027150523383170366
# Cur diff theta = 416.38497823593207
# ---------------------------------------
# VB, d: 200, Iter: 1-2760, s/iter: 1.097e-01, ELBO: -5.263e+05
# Cur diff delta = 411.7644958496094
# Cur diff sigma = 0.0027150497771799564
# Cur diff theta = 411.76721089938655
# ---------------------------------------
# VB, d: 200, Iter: 1-2780, s/iter: 1.100e-01, ELBO: -5.261e+05
# Cur diff delta = 407.2528076171875
# Cur diff sigma = 0.002715047914534807
# Cur diff theta = 407.25552266510203
# ---------------------------------------
# VB, d: 200, Iter: 1-2800, s/iter: 1.087e-01, ELBO: -5.260e+05
# Cur diff delta = 402.8442077636719
# Cur diff sigma = 0.0027150260284543037
# Cur diff theta = 402.84692278970033
# ---------------------------------------
# VB, d: 200, Iter: 1-2820, s/iter: 1.109e-01, ELBO: -5.259e+05
# Cur diff delta = 398.5367431640625
# Cur diff sigma = 0.002715019043534994
# Cur diff theta = 398.53945818310603
# ---------------------------------------
# VB, d: 200, Iter: 1-2840, s/iter: 1.093e-01, ELBO: -5.259e+05
# Cur diff delta = 394.32794189453125
# Cur diff sigma = 0.0027150202076882124
# Cur diff theta = 394.33065691473894
# ---------------------------------------
# VB, d: 200, Iter: 1-2860, s/iter: 1.092e-01, ELBO: -5.258e+05
# Cur diff delta = 390.2145690917969
# Cur diff sigma = 0.002715017646551132
# Cur diff theta = 390.2172841094434
# ---------------------------------------
# VB, d: 200, Iter: 1-2880, s/iter: 1.254e-01, ELBO: -5.257e+05
# Cur diff delta = 386.1943664550781
# Cur diff sigma = 0.002715005539357662
# Cur diff theta = 386.1970814606175
# ---------------------------------------
# VB, d: 200, Iter: 1-2900, s/iter: 1.079e-01, ELBO: -5.256e+05
# Cur diff delta = 382.2659606933594
# Cur diff sigma = 0.002715002978220582
# Cur diff theta = 382.2686756963376
# ---------------------------------------
# VB, d: 200, Iter: 1-2920, s/iter: 1.123e-01, ELBO: -5.255e+05
# Cur diff delta = 378.42529296875
# Cur diff sigma = 0.002714993664994836
# Cur diff theta = 378.428007962415
# ---------------------------------------
# VB, d: 200, Iter: 1-2940, s/iter: 1.080e-01, ELBO: -5.254e+05
# Cur diff delta = 374.66998291015625
# Cur diff sigma = 0.0027149864472448826
# Cur diff theta = 374.6726978966035
# ---------------------------------------
# VB, d: 200, Iter: 1-2960, s/iter: 1.085e-01, ELBO: -5.253e+05
# Cur diff delta = 370.99859619140625
# Cur diff sigma = 0.0027149789966642857
# Cur diff theta = 371.0013111704029
# ---------------------------------------
# VB, d: 200, Iter: 1-2980, s/iter: 1.075e-01, ELBO: -5.252e+05
# Cur diff delta = 367.4086608886719
# Cur diff sigma = 0.0027149657253175974
# Cur diff theta = 367.4113758543972
# ---------------------------------------
# VB, d: 200, Iter: 1-3000, s/iter: 1.097e-01, ELBO: -5.251e+05
# Cur diff delta = 363.89739990234375
# Cur diff sigma = 0.0027149636298418045
# Cur diff theta = 363.9001148659736
# ---------------------------------------
# VB, d: 200, Iter: 1-3020, s/iter: 1.076e-01, ELBO: -5.251e+05
# Cur diff delta = 360.46392822265625
# Cur diff sigma = 0.00271496525965631
# Cur diff theta = 360.4666431879159
# ---------------------------------------
# VB, d: 200, Iter: 1-3040, s/iter: 1.106e-01, ELBO: -5.250e+05
# Cur diff delta = 357.1053771972656
# Cur diff sigma = 0.002714959904551506
# Cur diff theta = 357.1080921571702
# ---------------------------------------
# VB, d: 200, Iter: 1-3060, s/iter: 1.083e-01, ELBO: -5.249e+05
# Cur diff delta = 353.8203125
# Cur diff sigma = 0.0027149454690515995
# Cur diff theta = 353.82302744546905
# ---------------------------------------
# VB, d: 200, Iter: 1-3080, s/iter: 1.093e-01, ELBO: -5.248e+05
# Cur diff delta = 350.60687255859375
# Cur diff sigma = 0.0027149415109306574
# Cur diff theta = 350.6095875001047
# ---------------------------------------
# VB, d: 200, Iter: 1-3100, s/iter: 1.099e-01, ELBO: -5.248e+05
# Cur diff delta = 347.46417236328125
# Cur diff sigma = 0.002714937087148428
# Cur diff theta = 347.4668873003684
# ---------------------------------------
# VB, d: 200, Iter: 1-3120, s/iter: 1.127e-01, ELBO: -5.247e+05
# Cur diff delta = 344.3890075683594
# Cur diff sigma = 0.0027149352245032787
# Cur diff theta = 344.3917225035839
# ---------------------------------------
# VB, d: 200, Iter: 1-3140, s/iter: 1.138e-01, ELBO: -5.246e+05
# Cur diff delta = 341.3793029785156
# Cur diff sigma = 0.0027149284724146128
# Cur diff theta = 341.38201790698804
# ---------------------------------------
# VB, d: 200, Iter: 1-3160, s/iter: 1.082e-01, ELBO: -5.245e+05
# Cur diff delta = 338.43377685546875
# Cur diff sigma = 0.0027149219531565905
# Cur diff theta = 338.4364917774219
# ---------------------------------------
# VB, d: 200, Iter: 1-3180, s/iter: 1.183e-01, ELBO: -5.245e+05
# Cur diff delta = 335.5515441894531
# Cur diff sigma = 0.0027149140369147062
# Cur diff theta = 335.55425910349004
# ---------------------------------------
# VB, d: 200, Iter: 1-3200, s/iter: 1.088e-01, ELBO: -5.244e+05
# Cur diff delta = 332.7312927246094
# Cur diff sigma = 0.002714920323342085
# Cur diff theta = 332.7340076449327
# ---------------------------------------
# VB, d: 200, Iter: 1-3220, s/iter: 1.092e-01, ELBO: -5.243e+05
# Cur diff delta = 329.9698486328125
# Cur diff sigma = 0.00271491426974535
# Cur diff theta = 329.97256354708225
# ---------------------------------------
# VB, d: 200, Iter: 1-3240, s/iter: 1.087e-01, ELBO: -5.243e+05
# Cur diff delta = 327.2673034667969
# Cur diff sigma = 0.0027149030938744545
# Cur diff theta = 327.27001836989075
# ---------------------------------------
# VB, d: 200, Iter: 1-3260, s/iter: 1.081e-01, ELBO: -5.242e+05
# Cur diff delta = 324.6217956542969
# Cur diff sigma = 0.002714894711971283
# Cur diff theta = 324.62451054900885
# ---------------------------------------
# VB, d: 200, Iter: 1-3280, s/iter: 1.082e-01, ELBO: -5.242e+05
# Cur diff delta = 322.0318603515625
# Cur diff sigma = 0.002714894013479352
# Cur diff theta = 322.034575245576
# ---------------------------------------
# VB, d: 200, Iter: 1-3300, s/iter: 1.135e-01, ELBO: -5.241e+05
# Cur diff delta = 319.4962463378906
# Cur diff sigma = 0.0027148881927132607
# Cur diff theta = 319.49896122608334
# ---------------------------------------
# VB, d: 200, Iter: 1-3320, s/iter: 1.127e-01, ELBO: -5.240e+05
# Cur diff delta = 317.0129699707031
# Cur diff sigma = 0.002714882604777813
# Cur diff theta = 317.0156848533079
# ---------------------------------------
# VB, d: 200, Iter: 1-3340, s/iter: 1.077e-01, ELBO: -5.240e+05
# Cur diff delta = 314.5809631347656
# Cur diff sigma = 0.00271487794816494
# Cur diff theta = 314.5836780127138
# ---------------------------------------
# VB, d: 200, Iter: 1-3360, s/iter: 1.157e-01, ELBO: -5.239e+05
# Cur diff delta = 312.1990661621094
# Cur diff sigma = 0.002714872593060136
# Cur diff theta = 312.20178103470244
# ---------------------------------------
# VB, d: 200, Iter: 1-3380, s/iter: 1.083e-01, ELBO: -5.239e+05
# Cur diff delta = 309.8663635253906
# Cur diff sigma = 0.002714873291552067
# Cur diff theta = 309.8690783986822
# ---------------------------------------
# VB, d: 200, Iter: 1-3400, s/iter: 1.163e-01, ELBO: -5.238e+05
# Cur diff delta = 307.58203125
# Cur diff sigma = 0.002714866539463401
# Cur diff theta = 307.58474611653946
# ---------------------------------------
# VB, d: 200, Iter: 1-3420, s/iter: 1.133e-01, ELBO: -5.237e+05
# Cur diff delta = 305.3442687988281
# Cur diff sigma = 0.0027148621156811714
# Cur diff theta = 305.3469836609438
# ---------------------------------------
# VB, d: 200, Iter: 1-3440, s/iter: 1.096e-01, ELBO: -5.237e+05
# Cur diff delta = 303.1518249511719
# Cur diff sigma = 0.0027148681692779064
# Cur diff theta = 303.15453981934115
# ---------------------------------------
# VB, d: 200, Iter: 1-3460, s/iter: 1.108e-01, ELBO: -5.236e+05
# Cur diff delta = 301.00396728515625
# Cur diff sigma = 0.0027148588560521603
# Cur diff theta = 301.0066821440123
# ---------------------------------------
# VB, d: 200, Iter: 1-3480, s/iter: 1.334e-01, ELBO: -5.236e+05
# Cur diff delta = 298.90020751953125
# Cur diff sigma = 0.0027148514054715633
# Cur diff theta = 298.9029223709367
# ---------------------------------------
# VB, d: 200, Iter: 1-3500, s/iter: 1.170e-01, ELBO: -5.235e+05
# Cur diff delta = 296.83795166015625
# Cur diff sigma = 0.0027148588560521603
# Cur diff theta = 296.8406665190123
# ---------------------------------------
# VB, d: 200, Iter: 1-3520, s/iter: 1.077e-01, ELBO: -5.235e+05
# Cur diff delta = 294.816650390625
# Cur diff sigma = 0.002714843489229679
# Cur diff theta = 294.81936523411423
# ---------------------------------------
# VB, d: 200, Iter: 1-3540, s/iter: 1.120e-01, ELBO: -5.234e+05
# Cur diff delta = 292.8360290527344
# Cur diff sigma = 0.0027148413937538862
# Cur diff theta = 292.83874389412813
# ---------------------------------------
# VB, d: 200, Iter: 1-3560, s/iter: 1.097e-01, ELBO: -5.234e+05
# Cur diff delta = 290.8949279785156
# Cur diff sigma = 0.002714849077165127
# Cur diff theta = 290.8976428275928
# ---------------------------------------
# VB, d: 200, Iter: 1-3580, s/iter: 1.091e-01, ELBO: -5.233e+05
# Cur diff delta = 288.9930725097656
# Cur diff sigma = 0.0027148493099957705
# Cur diff theta = 288.9957873590756
# ---------------------------------------
# VB, d: 200, Iter: 1-3600, s/iter: 1.092e-01, ELBO: -5.233e+05
# Cur diff delta = 287.12823486328125
# Cur diff sigma = 0.002714842790737748
# Cur diff theta = 287.130949706072
# ---------------------------------------
# VB, d: 200, Iter: 1-3620, s/iter: 1.090e-01, ELBO: -5.233e+05
# Cur diff delta = 285.3000183105469
# Cur diff sigma = 0.0027148376684635878
# Cur diff theta = 285.30273314821534
# ---------------------------------------
# VB, d: 200, Iter: 1-3640, s/iter: 1.255e-01, ELBO: -5.232e+05
# Cur diff delta = 283.50811767578125
# Cur diff sigma = 0.0027148353401571512
# Cur diff theta = 283.5108325111214
# ---------------------------------------
# VB, d: 200, Iter: 1-3660, s/iter: 1.126e-01, ELBO: -5.232e+05
# Cur diff delta = 281.751220703125
# Cur diff sigma = 0.0027148318476974964
# Cur diff theta = 281.7539355349727
# ---------------------------------------
# VB, d: 200, Iter: 1-3680, s/iter: 1.181e-01, ELBO: -5.231e+05
# Cur diff delta = 280.02862548828125
# Cur diff sigma = 0.0027148292865604162
# Cur diff theta = 280.0313403175678
# ---------------------------------------
# VB, d: 200, Iter: 1-3700, s/iter: 1.085e-01, ELBO: -5.231e+05
# Cur diff delta = 278.34039306640625
# Cur diff sigma = 0.0027148225344717503
# Cur diff theta = 278.3431078889407
# ---------------------------------------
# VB, d: 200, Iter: 1-3720, s/iter: 1.089e-01, ELBO: -5.230e+05
# Cur diff delta = 276.68487548828125
# Cur diff sigma = 0.00271482951939106
# Cur diff theta = 276.68759031780064
# ---------------------------------------
# VB, d: 200, Iter: 1-3740, s/iter: 1.085e-01, ELBO: -5.230e+05
# Cur diff delta = 275.06109619140625
# Cur diff sigma = 0.0027148202061653137
# Cur diff theta = 275.0638110116124
# ---------------------------------------
# VB, d: 200, Iter: 1-3760, s/iter: 1.078e-01, ELBO: -5.230e+05
# Cur diff delta = 273.468994140625
# Cur diff sigma = 0.0027148202061653137
# Cur diff theta = 273.47170896083117
# ---------------------------------------
# VB, d: 200, Iter: 1-3780, s/iter: 1.079e-01, ELBO: -5.229e+05
# Cur diff delta = 271.90777587890625
# Cur diff sigma = 0.002714822068810463
# Cur diff theta = 271.91049070097506
# ---------------------------------------
# VB, d: 200, Iter: 1-3800, s/iter: 1.098e-01, ELBO: -5.229e+05
# Cur diff delta = 270.375732421875
# Cur diff sigma = 0.002714821370318532
# Cur diff theta = 270.3784472432453
# ---------------------------------------
# VB, d: 200, Iter: 1-3820, s/iter: 1.082e-01, ELBO: -5.228e+05
# Cur diff delta = 268.8724060058594
# Cur diff sigma = 0.002714816015213728
# Cur diff theta = 268.8751208218746
# ---------------------------------------
# VB, d: 200, Iter: 1-3840, s/iter: 1.103e-01, ELBO: -5.228e+05
# Cur diff delta = 267.3977966308594
# Cur diff sigma = 0.0027148162480443716
# Cur diff theta = 267.4005114471074
# ---------------------------------------
# VB, d: 200, Iter: 1-3860, s/iter: 1.082e-01, ELBO: -5.228e+05
# Cur diff delta = 265.95111083984375
# Cur diff sigma = 0.002714818809181452
# Cur diff theta = 265.95382565865293
# ---------------------------------------
# VB, d: 200, Iter: 1-3880, s/iter: 1.077e-01, ELBO: -5.227e+05
# Cur diff delta = 264.5317687988281
# Cur diff sigma = 0.002714813919737935
# Cur diff theta = 264.53448361274786
# ---------------------------------------
# VB, d: 200, Iter: 1-3900, s/iter: 1.161e-01, ELBO: -5.227e+05
# Cur diff delta = 263.1396484375
# Cur diff sigma = 0.0027148157823830843
# Cur diff theta = 263.1423632532824
# ---------------------------------------
# VB, d: 200, Iter: 1-3920, s/iter: 1.110e-01, ELBO: -5.227e+05
# Cur diff delta = 261.7735290527344
# Cur diff sigma = 0.002714812755584717
# Cur diff theta = 261.77624386548996
# ---------------------------------------
# VB, d: 200, Iter: 1-3940, s/iter: 1.094e-01, ELBO: -5.226e+05
# Cur diff delta = 260.43359375
# Cur diff sigma = 0.002714812522754073
# Cur diff theta = 260.43630856252275
# ---------------------------------------
# VB, d: 200, Iter: 1-3960, s/iter: 1.090e-01, ELBO: -5.226e+05
# Cur diff delta = 259.1179504394531
# Cur diff sigma = 0.0027148062363266945
# Cur diff theta = 259.12066524568945
# ---------------------------------------
# VB, d: 200, Iter: 1-3980, s/iter: 1.076e-01, ELBO: -5.226e+05
# Cur diff delta = 257.8264465332031
# Cur diff sigma = 0.0027148087974637747
# Cur diff theta = 257.8291613420006
# ---------------------------------------
# VB, d: 200, Iter: 1-4000, s/iter: 1.156e-01, ELBO: -5.225e+05
# Cur diff delta = 256.5592956542969
# Cur diff sigma = 0.002714801114052534
# Cur diff theta = 256.5620104554109
# ---------------------------------------
# ------------------------------------------------------
# Test = 1
# ------------------------------------------------------
# Init diff delta = 26666.0
# Init diff sigma = 77495.03125
# Init diff theta = 104161.03125
# VB, d: 200, Iter: 2-20, s/iter: 1.087e-01, ELBO: -7.307e+06
# Cur diff delta = 23101.52734375
# Cur diff sigma = 27260.919921875
# Cur diff theta = 50362.447265625
# ---------------------------------------
# VB, d: 200, Iter: 2-40, s/iter: 1.121e-01, ELBO: -6.504e+06
# Cur diff delta = 20294.34765625
# Cur diff sigma = 17861.248046875
# Cur diff theta = 38155.595703125
# ---------------------------------------
# VB, d: 200, Iter: 2-60, s/iter: 1.085e-01, ELBO: -5.625e+06
# Cur diff delta = 17745.982421875
# Cur diff sigma = 13100.435546875
# Cur diff theta = 30846.41796875
# ---------------------------------------
# VB, d: 200, Iter: 2-80, s/iter: 1.078e-01, ELBO: -4.629e+06
# Cur diff delta = 15487.2509765625
# Cur diff sigma = 9678.8447265625
# Cur diff theta = 25166.095703125
# ---------------------------------------
# VB, d: 200, Iter: 2-100, s/iter: 1.111e-01, ELBO: -3.622e+06
# Cur diff delta = 13589.353515625
# Cur diff sigma = 7023.9140625
# Cur diff theta = 20613.267578125
# ---------------------------------------
# VB, d: 200, Iter: 2-120, s/iter: 1.100e-01, ELBO: -2.821e+06
# Cur diff delta = 11963.2978515625
# Cur diff sigma = 4957.572265625
# Cur diff theta = 16920.8701171875
# ---------------------------------------
# VB, d: 200, Iter: 2-140, s/iter: 1.180e-01, ELBO: -2.309e+06
# Cur diff delta = 10600.63671875
# Cur diff sigma = 3377.208984375
# Cur diff theta = 13977.845703125
# ---------------------------------------
# VB, d: 200, Iter: 2-160, s/iter: 1.087e-01, ELBO: -1.903e+06
# Cur diff delta = 9484.8046875
# Cur diff sigma = 2202.8115234375
# Cur diff theta = 11687.6162109375
# ---------------------------------------
# VB, d: 200, Iter: 2-180, s/iter: 1.080e-01, ELBO: -1.577e+06
# Cur diff delta = 8585.998046875
# Cur diff sigma = 1352.92529296875
# Cur diff theta = 9938.92333984375
# ---------------------------------------
# VB, d: 200, Iter: 2-200, s/iter: 1.079e-01, ELBO: -1.324e+06
# Cur diff delta = 7841.11279296875
# Cur diff sigma = 757.0505981445312
# Cur diff theta = 8598.163391113281
# ---------------------------------------
# VB, d: 200, Iter: 2-220, s/iter: 1.158e-01, ELBO: -1.112e+06
# Cur diff delta = 7211.4580078125
# Cur diff sigma = 367.55853271484375
# Cur diff theta = 7579.016540527344
# ...
# ---------------------------------------
# VB, d: 200, Iter: 3-2560, s/iter: 1.086e-01, ELBO: -5.284e+05
# Cur diff delta = 521.0933227539062
# Cur diff sigma = 0.0033897929824888706
# Cur diff theta = 521.0967125468887
# ---------------------------------------
# VB, d: 200, Iter: 3-2580, s/iter: 1.081e-01, ELBO: -5.283e+05
# Cur diff delta = 514.9859619140625
# Cur diff sigma = 0.0033897939138114452
# Cur diff theta = 514.9893517079763
# ---------------------------------------
# VB, d: 200, Iter: 3-2600, s/iter: 1.076e-01, ELBO: -5.282e+05
# Cur diff delta = 509.02069091796875
# Cur diff sigma = 0.003389798803254962
# Cur diff theta = 509.024080716772
# ---------------------------------------
# VB, d: 200, Iter: 3-2620, s/iter: 1.109e-01, ELBO: -5.281e+05
# Cur diff delta = 503.1933898925781
# Cur diff sigma = 0.003389795310795307
# Cur diff theta = 503.1967796878889
# ---------------------------------------
# VB, d: 200, Iter: 3-2640, s/iter: 1.098e-01, ELBO: -5.280e+05
# Cur diff delta = 497.49969482421875
# Cur diff sigma = 0.0033897932153195143
# Cur diff theta = 497.50308461743407
# ---------------------------------------
# VB, d: 200, Iter: 3-2660, s/iter: 1.080e-01, ELBO: -5.278e+05
# Cur diff delta = 491.9370422363281
# Cur diff sigma = 0.003389775985851884
# Cur diff theta = 491.940432012314
# ---------------------------------------
# VB, d: 200, Iter: 3-2680, s/iter: 1.080e-01, ELBO: -5.277e+05
# Cur diff delta = 486.50164794921875
# Cur diff sigma = 0.003389777848497033
# Cur diff theta = 486.50503772706725
# ---------------------------------------
# VB, d: 200, Iter: 3-2700, s/iter: 1.087e-01, ELBO: -5.276e+05
# Cur diff delta = 481.1897888183594
# Cur diff sigma = 0.0033897862304002047
# Cur diff theta = 481.1931786045898
# ---------------------------------------
# VB, d: 200, Iter: 3-2720, s/iter: 1.123e-01, ELBO: -5.275e+05
# Cur diff delta = 475.9981994628906
# Cur diff sigma = 0.0033897750545293093
# Cur diff theta = 476.00158923794515
# ---------------------------------------
# VB, d: 200, Iter: 3-2740, s/iter: 1.086e-01, ELBO: -5.274e+05
# Cur diff delta = 470.9232177734375
# Cur diff sigma = 0.003389774588868022
# Cur diff theta = 470.92660754802637
# ---------------------------------------
# VB, d: 200, Iter: 3-2760, s/iter: 1.104e-01, ELBO: -5.273e+05
# Cur diff delta = 465.9614562988281
# Cur diff sigma = 0.0033897720277309418
# Cur diff theta = 465.96484607085586
# ---------------------------------------
# VB, d: 200, Iter: 3-2780, s/iter: 1.110e-01, ELBO: -5.272e+05
# Cur diff delta = 461.1113586425781
# Cur diff sigma = 0.003389781340956688
# Cur diff theta = 461.1147484239191
# ---------------------------------------
# VB, d: 200, Iter: 3-2800, s/iter: 1.105e-01, ELBO: -5.271e+05
# Cur diff delta = 456.368896484375
# Cur diff sigma = 0.0033897641114890575
# Cur diff theta = 456.3722862484865
# ---------------------------------------
# VB, d: 200, Iter: 3-2820, s/iter: 1.145e-01, ELBO: -5.270e+05
# Cur diff delta = 451.73211669921875
# Cur diff sigma = 0.003389767138287425
# Cur diff theta = 451.73550646635704
# ---------------------------------------
# VB, d: 200, Iter: 3-2840, s/iter: 1.135e-01, ELBO: -5.269e+05
# Cur diff delta = 447.1981201171875
# Cur diff sigma = 0.0033897608518600464
# Cur diff theta = 447.20150987803936
# ---------------------------------------
# VB, d: 200, Iter: 3-2860, s/iter: 1.244e-01, ELBO: -5.269e+05
# Cur diff delta = 442.7638854980469
# Cur diff sigma = 0.0033897573594003916
# Cur diff theta = 442.7672752554063
# ---------------------------------------
# VB, d: 200, Iter: 3-2880, s/iter: 1.075e-01, ELBO: -5.268e+05
# Cur diff delta = 438.42608642578125
# Cur diff sigma = 0.003389767138287425
# Cur diff theta = 438.42947619291954
# ---------------------------------------
# VB, d: 200, Iter: 3-2900, s/iter: 1.118e-01, ELBO: -5.267e+05
# Cur diff delta = 434.1830139160156
# Cur diff sigma = 0.0033897545654326677
# Cur diff theta = 434.18640367058106
# ---------------------------------------
# VB, d: 200, Iter: 3-2920, s/iter: 1.182e-01, ELBO: -5.266e+05
# Cur diff delta = 430.03204345703125
# Cur diff sigma = 0.0033897501416504383
# Cur diff theta = 430.0354332071729
# ---------------------------------------
# VB, d: 200, Iter: 3-2940, s/iter: 1.094e-01, ELBO: -5.265e+05
# Cur diff delta = 425.9710388183594
# Cur diff sigma = 0.003389740129932761
# Cur diff theta = 425.9744285584893
# ---------------------------------------
# VB, d: 200, Iter: 3-2960, s/iter: 1.085e-01, ELBO: -5.264e+05
# Cur diff delta = 421.9974060058594
# Cur diff sigma = 0.0033897454850375652
# Cur diff theta = 422.0007957513444
# ---------------------------------------
# VB, d: 200, Iter: 3-2980, s/iter: 1.095e-01, ELBO: -5.264e+05
# Cur diff delta = 418.1087951660156
# Cur diff sigma = 0.003389732912182808
# Cur diff theta = 418.1121848989278
# ---------------------------------------
# VB, d: 200, Iter: 3-3000, s/iter: 1.097e-01, ELBO: -5.263e+05
# Cur diff delta = 414.30389404296875
# Cur diff sigma = 0.003389742923900485
# Cur diff theta = 414.30728378589265
# ---------------------------------------
# VB, d: 200, Iter: 3-3020, s/iter: 1.090e-01, ELBO: -5.262e+05
# Cur diff delta = 410.5798034667969
# Cur diff sigma = 0.003389735473319888
# Cur diff theta = 410.5831932022702
# ---------------------------------------
# VB, d: 200, Iter: 3-3040, s/iter: 1.120e-01, ELBO: -5.261e+05
# Cur diff delta = 406.9333801269531
# Cur diff sigma = 0.003389720804989338
# Cur diff theta = 406.9367698477581
# ---------------------------------------
# VB, d: 200, Iter: 3-3060, s/iter: 1.085e-01, ELBO: -5.261e+05
# Cur diff delta = 403.3641052246094
# Cur diff sigma = 0.0033897212706506252
# Cur diff theta = 403.36749494588
# ---------------------------------------
# VB, d: 200, Iter: 3-3080, s/iter: 1.080e-01, ELBO: -5.260e+05
# Cur diff delta = 399.87042236328125
# Cur diff sigma = 0.0033897191751748323
# Cur diff theta = 399.8738120824564
# ---------------------------------------
# VB, d: 200, Iter: 3-3100, s/iter: 1.103e-01, ELBO: -5.259e+05
# Cur diff delta = 396.4507141113281
# Cur diff sigma = 0.0033897196408361197
# Cur diff theta = 396.45410383096896
# ---------------------------------------
# VB, d: 200, Iter: 3-3120, s/iter: 1.099e-01, ELBO: -5.258e+05
# Cur diff delta = 393.1021423339844
# Cur diff sigma = 0.0033897203393280506
# Cur diff theta = 393.1055320543237
# ---------------------------------------
# VB, d: 200, Iter: 3-3140, s/iter: 1.077e-01, ELBO: -5.258e+05
# Cur diff delta = 389.82330322265625
# Cur diff sigma = 0.0033897189423441887
# Cur diff theta = 389.8266929415986
# ---------------------------------------
# VB, d: 200, Iter: 3-3160, s/iter: 1.086e-01, ELBO: -5.257e+05
# Cur diff delta = 386.6111755371094
# Cur diff sigma = 0.0033897031098604202
# Cur diff theta = 386.61456524021924
# ---------------------------------------
# VB, d: 200, Iter: 3-3180, s/iter: 1.077e-01, ELBO: -5.257e+05
# Cur diff delta = 383.46527099609375
# Cur diff sigma = 0.003389710793271661
# Cur diff theta = 383.468660706887
# ---------------------------------------
# VB, d: 200, Iter: 3-3200, s/iter: 1.082e-01, ELBO: -5.256e+05
# Cur diff delta = 380.3832092285156
# Cur diff sigma = 0.0033897054381668568
# Cur diff theta = 380.3865989339538
# ---------------------------------------
# VB, d: 200, Iter: 3-3220, s/iter: 1.168e-01, ELBO: -5.255e+05
# Cur diff delta = 377.3645935058594
# Cur diff sigma = 0.003389699151739478
# Cur diff theta = 377.3679832050111
# ---------------------------------------
# VB, d: 200, Iter: 3-3240, s/iter: 1.115e-01, ELBO: -5.255e+05
# Cur diff delta = 374.4073486328125
# Cur diff sigma = 0.003389698686078191
# Cur diff theta = 374.4107383314986
# ---------------------------------------
# VB, d: 200, Iter: 3-3260, s/iter: 1.074e-01, ELBO: -5.254e+05
# Cur diff delta = 371.5107116699219
# Cur diff sigma = 0.0033897021785378456
# Cur diff theta = 371.5141013721004
# ---------------------------------------
# VB, d: 200, Iter: 3-3280, s/iter: 1.100e-01, ELBO: -5.253e+05
# Cur diff delta = 368.6723327636719
# Cur diff sigma = 0.0033896949607878923
# Cur diff theta = 368.67572245863266
# ---------------------------------------
# VB, d: 200, Iter: 3-3300, s/iter: 1.090e-01, ELBO: -5.253e+05
# Cur diff delta = 365.8918151855469
# Cur diff sigma = 0.0033896910026669502
# Cur diff theta = 365.89520487654954
# ---------------------------------------
# VB, d: 200, Iter: 3-3320, s/iter: 1.095e-01, ELBO: -5.252e+05
# Cur diff delta = 363.1676330566406
# Cur diff sigma = 0.003389689838513732
# Cur diff theta = 363.17102274647914
# ---------------------------------------
# VB, d: 200, Iter: 3-3340, s/iter: 1.108e-01, ELBO: -5.252e+05
# Cur diff delta = 360.4970397949219
# Cur diff sigma = 0.0033896849490702152
# Cur diff theta = 360.50042947987095
# ---------------------------------------
# VB, d: 200, Iter: 3-3360, s/iter: 1.121e-01, ELBO: -5.251e+05
# Cur diff delta = 357.879150390625
# Cur diff sigma = 0.0033896819222718477
# Cur diff theta = 357.8825400725473
# ---------------------------------------
# VB, d: 200, Iter: 3-3380, s/iter: 1.086e-01, ELBO: -5.251e+05
# Cur diff delta = 355.31353759765625
# Cur diff sigma = 0.003389679593965411
# Cur diff theta = 355.3169272772502
# ---------------------------------------
# VB, d: 200, Iter: 3-3400, s/iter: 1.192e-01, ELBO: -5.250e+05
# Cur diff delta = 352.79901123046875
# Cur diff sigma = 0.0033896819222718477
# Cur diff theta = 352.802400912391
# ---------------------------------------
# VB, d: 200, Iter: 3-3420, s/iter: 1.089e-01, ELBO: -5.250e+05
# Cur diff delta = 350.333740234375
# Cur diff sigma = 0.0033896763343364
# Cur diff theta = 350.33712991070934
# ---------------------------------------
# VB, d: 200, Iter: 3-3440, s/iter: 1.076e-01, ELBO: -5.249e+05
# Cur diff delta = 347.91607666015625
# Cur diff sigma = 0.0033896740060299635
# Cur diff theta = 347.9194663341623
# ---------------------------------------
# VB, d: 200, Iter: 3-3460, s/iter: 1.238e-01, ELBO: -5.249e+05
# Cur diff delta = 345.54559326171875
# Cur diff sigma = 0.0033896751701831818
# Cur diff theta = 345.54898293688893
# ---------------------------------------
# VB, d: 200, Iter: 3-3480, s/iter: 1.077e-01, ELBO: -5.248e+05
# Cur diff delta = 343.22186279296875
# Cur diff sigma = 0.0033896726090461016
# Cur diff theta = 343.2252524655778
# ---------------------------------------
# VB, d: 200, Iter: 3-3500, s/iter: 1.087e-01, ELBO: -5.248e+05
# Cur diff delta = 340.9430847167969
# Cur diff sigma = 0.003389670979231596
# Cur diff theta = 340.9464743877761
# ---------------------------------------
# VB, d: 200, Iter: 3-3520, s/iter: 1.116e-01, ELBO: -5.247e+05
# Cur diff delta = 338.70794677734375
# Cur diff sigma = 0.0033896658569574356
# Cur diff theta = 338.7113364432007
# ---------------------------------------
# VB, d: 200, Iter: 3-3540, s/iter: 1.115e-01, ELBO: -5.247e+05
# Cur diff delta = 336.515625
# Cur diff sigma = 0.003389670979231596
# Cur diff theta = 336.51901467097923
# ---------------------------------------
# VB, d: 200, Iter: 3-3560, s/iter: 1.103e-01, ELBO: -5.246e+05
# Cur diff delta = 334.3651123046875
# Cur diff sigma = 0.003389659570530057
# Cur diff theta = 334.36850196425803
# ---------------------------------------
# VB, d: 200, Iter: 3-3580, s/iter: 1.128e-01, ELBO: -5.246e+05
# Cur diff delta = 332.2557373046875
# Cur diff sigma = 0.0033896679524332285
# Cur diff theta = 332.25912697263993
# ---------------------------------------
# VB, d: 200, Iter: 3-3600, s/iter: 1.138e-01, ELBO: -5.245e+05
# Cur diff delta = 330.18682861328125
# Cur diff sigma = 0.0033896537497639656
# Cur diff theta = 330.190218267031
# ---------------------------------------
# VB, d: 200, Iter: 3-3620, s/iter: 1.088e-01, ELBO: -5.245e+05
# Cur diff delta = 328.1580505371094
# Cur diff sigma = 0.0033896630629897118
# Cur diff theta = 328.16144020017236
# ---------------------------------------
# VB, d: 200, Iter: 3-3640, s/iter: 1.120e-01, ELBO: -5.245e+05
# Cur diff delta = 326.16741943359375
# Cur diff sigma = 0.0033896612003445625
# Cur diff theta = 326.1708090947941
# ---------------------------------------
# VB, d: 200, Iter: 3-3660, s/iter: 1.105e-01, ELBO: -5.244e+05
# Cur diff delta = 324.2138977050781
# Cur diff sigma = 0.0033896600361913443
# Cur diff theta = 324.2172873651143
# ---------------------------------------
# VB, d: 200, Iter: 3-3680, s/iter: 1.088e-01, ELBO: -5.244e+05
# Cur diff delta = 322.2969970703125
# Cur diff sigma = 0.003389649325981736
# Cur diff theta = 322.3003867196385
# ---------------------------------------
# VB, d: 200, Iter: 3-3700, s/iter: 1.078e-01, ELBO: -5.243e+05
# Cur diff delta = 320.4158020019531
# Cur diff sigma = 0.003389650722965598
# Cur diff theta = 320.4191916526761
# ---------------------------------------
# VB, d: 200, Iter: 3-3720, s/iter: 1.096e-01, ELBO: -5.243e+05
# Cur diff delta = 318.5697937011719
# Cur diff sigma = 0.00338964955881238
# Cur diff theta = 318.5731833507307
# ---------------------------------------
# VB, d: 200, Iter: 3-3740, s/iter: 1.097e-01, ELBO: -5.243e+05
# Cur diff delta = 316.758056640625
# Cur diff sigma = 0.0033896444365382195
# Cur diff theta = 316.76144628506154
# ---------------------------------------
# VB, d: 200, Iter: 3-3760, s/iter: 1.072e-01, ELBO: -5.242e+05
# Cur diff delta = 314.97998046875
# Cur diff sigma = 0.0033896404784172773
# Cur diff theta = 314.9833701092284
# ---------------------------------------
# VB, d: 200, Iter: 3-3780, s/iter: 1.080e-01, ELBO: -5.242e+05
# Cur diff delta = 313.2344665527344
# Cur diff sigma = 0.0033896388486027718
# Cur diff theta = 313.237856191583
# ---------------------------------------
# VB, d: 200, Iter: 3-3800, s/iter: 1.075e-01, ELBO: -5.242e+05
# Cur diff delta = 311.5204772949219
# Cur diff sigma = 0.003389643970876932
# Cur diff theta = 311.52386693889275
# ---------------------------------------
# VB, d: 200, Iter: 3-3820, s/iter: 1.095e-01, ELBO: -5.241e+05
# Cur diff delta = 309.8382873535156
# Cur diff sigma = 0.0033896411769092083
# Cur diff theta = 309.84167699469253
# ---------------------------------------
# VB, d: 200, Iter: 3-3840, s/iter: 1.085e-01, ELBO: -5.241e+05
# Cur diff delta = 308.18609619140625
# Cur diff sigma = 0.00338964001275599
# Cur diff theta = 308.189485831419
# ---------------------------------------
# VB, d: 200, Iter: 3-3860, s/iter: 1.083e-01, ELBO: -5.241e+05
# Cur diff delta = 306.5640563964844
# Cur diff sigma = 0.003389632562175393
# Cur diff theta = 306.56744602904655
# ---------------------------------------
# VB, d: 200, Iter: 3-3880, s/iter: 1.078e-01, ELBO: -5.240e+05
# Cur diff delta = 304.97210693359375
# Cur diff sigma = 0.0033896351233124733
# Cur diff theta = 304.97549656871706
# ---------------------------------------
# VB, d: 200, Iter: 3-3900, s/iter: 1.093e-01, ELBO: -5.240e+05
# Cur diff delta = 303.40875244140625
# Cur diff sigma = 0.0033896344248205423
# Cur diff theta = 303.41214207583107
# ---------------------------------------
# VB, d: 200, Iter: 3-3920, s/iter: 1.180e-01, ELBO: -5.240e+05
# Cur diff delta = 301.8736267089844
# Cur diff sigma = 0.0033896288368850946
# Cur diff theta = 301.87701633782126
# ---------------------------------------
# VB, d: 200, Iter: 3-3940, s/iter: 1.080e-01, ELBO: -5.239e+05
# Cur diff delta = 300.3662414550781
# Cur diff sigma = 0.0033896369859576225
# Cur diff theta = 300.3696310920641
# ---------------------------------------
# VB, d: 200, Iter: 3-3960, s/iter: 1.149e-01, ELBO: -5.239e+05
# Cur diff delta = 298.8851318359375
# Cur diff sigma = 0.003389621153473854
# Cur diff theta = 298.888521457091
# ---------------------------------------
# VB, d: 200, Iter: 3-3980, s/iter: 1.083e-01, ELBO: -5.239e+05
# Cur diff delta = 297.4304504394531
# Cur diff sigma = 0.003389623947441578
# Cur diff theta = 297.43384006340057
# ---------------------------------------
# VB, d: 200, Iter: 3-4000, s/iter: 1.122e-01, ELBO: -5.238e+05
# Cur diff delta = 296.0016174316406
# Cur diff sigma = 0.003389619290828705
# Cur diff theta = 296.00500705093145
# ---------------------------------------
# Model VB, test = 0, result delta diff = 256.5592041015625
# Model VB, test = 0, result sigma diff = 0.0027148015797138214
# Model VB, test = 0, result theta diff = 256.5619201660156
# Model VB, test = 1, result delta diff = 257.800048828125
# Model VB, test = 1, result sigma diff = 0.0026283804327249527
# Model VB, test = 1, result theta diff = 257.80267333984375
# Model VB, test = 2, result delta diff = 296.0016784667969
# Model VB, test = 2, result sigma diff = 0.0033896206878125668
# Model VB, test = 2, result theta diff = 296.00506591796875

# %%
model_names = ['HVAE_1', 'HVAE_2', 'NF_1', 'NF_2', 'VB']
diff_delta_results = {}
diff_sigma_results = {}
diff_results = {}
for name in model_names:
    diff_delta_tests = np.zeros(params['n_tests'])
    diff_sigma_tests = np.zeros(params['n_tests'])
    diff_tests = np.zeros(params['n_tests'])
    for i in range(params['n_tests']):
        file_name = name + '_train_' + str(i) + '.p'
        diff_path = os.path.join('save', str(params['dims'][0]), file_name)
        with open(diff_path, 'rb') as f:
            data = pickle.load(f)
            elbo = data['elbo']
            diff_delta = data['diff_delta']
            diff_sigma = data['diff_sigma']
            diff = diff_delta + diff_sigma
            diff_delta_is_not_nan = diff_delta[~np.isnan(diff_delta)]
            diff_sigma_is_not_nan = diff_sigma[~np.isnan(diff_sigma)]
            diff_is_not_nan = diff[~np.isnan(diff)]
            diff_delta_tests[i] = diff_delta_is_not_nan[-1]
            diff_sigma_tests[i] = diff_sigma_is_not_nan[-1]
            diff_tests[i] = diff_is_not_nan[-1]
    diff_delta_results[name] = diff_delta_tests
    diff_sigma_results[name] = diff_sigma_tests
    diff_results[name] = diff_tests
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, diff delta = {diff_delta_tests}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, diff sigma = {diff_sigma_tests}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, diff = {diff_tests}")
# Out:
# Model = HVAE_1, dimensionality = 200, diff delta = [183.45848083 205.34617615 200.65716553]
# Model = HVAE_1, dimensionality = 200, diff sigma = [0.33295846 0.33400047 0.33786768]
# Model = HVAE_1, dimensionality = 200, diff = [183.79144287 205.68017578 200.99502563]
# Model = HVAE_2, dimensionality = 200, diff delta = [183.79724121 205.11697388 200.20713806]
# Model = HVAE_2, dimensionality = 200, diff sigma = [0.30696803 0.30571064 0.31064045]
# Model = HVAE_2, dimensionality = 200, diff = [184.10420227 205.42268372 200.51777649]
# Model = NF_1, dimensionality = 200, diff delta = [183.93060303 205.45214844 200.53007507]
# Model = NF_1, dimensionality = 200, diff sigma = [125.79404449 125.87238312 125.91531372]
# Model = NF_1, dimensionality = 200, diff = [309.72463989 331.32452393 326.44537354]
# Model = NF_2, dimensionality = 200, diff delta = [184.4203186  205.47422791 200.65820312]
# Model = NF_2, dimensionality = 200, diff sigma = [125.53786469 125.62741852 125.10678101]
# Model = NF_2, dimensionality = 200, diff = [309.95819092 331.10165405 325.76498413]
# Model = VB, dimensionality = 200, diff delta = [256.55929565 257.80007935 296.00161743]
# Model = VB, dimensionality = 200, diff sigma = [0.0027148  0.00262838 0.00338962]
# Model = VB, dimensionality = 200, diff = [256.56201172 257.80270386 296.00500488]

# %%
for name in model_names:
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, mean diff delta = {diff_delta_results[name].mean()}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, mean diff sigma = {diff_sigma_results[name].mean()}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, mean diff = {diff_results[name].mean()}")
# Out:
# Model = HVAE_1, dimensionality = 200, mean diff delta = 196.48727416992188
# Model = HVAE_1, dimensionality = 200, mean diff sigma = 0.3349422017733256
# Model = HVAE_1, dimensionality = 200, mean diff = 196.82221476236978
# Model = HVAE_2, dimensionality = 200, mean diff delta = 196.37378438313803
# Model = HVAE_2, dimensionality = 200, mean diff sigma = 0.30777304371198017
# Model = HVAE_2, dimensionality = 200, mean diff = 196.68155415852866
# Model = NF_1, dimensionality = 200, mean diff delta = 196.63760884602866
# Model = NF_1, dimensionality = 200, mean diff sigma = 125.86058044433594
# Model = NF_1, dimensionality = 200, mean diff = 322.49817911783856
# Model = NF_2, dimensionality = 200, mean diff delta = 196.85091654459634
# Model = NF_2, dimensionality = 200, mean diff sigma = 125.4240214029948
# Model = NF_2, dimensionality = 200, mean diff = 322.2749430338542
# Model = VB, dimensionality = 200, mean diff delta = 270.1203308105469
# Model = VB, dimensionality = 200, mean diff sigma = 0.002910933612535397
# Model = VB, dimensionality = 200, mean diff = 270.1232401529948

# %%
def run_test(d, params, 
             batch_size=256,
             clip_value=None,
             dtype=torch.float32, 
             device=torch.device("cpu")):
    """ 
    Run the gaussian test with dimension d 
    """

    ######### Problem Specification

    # Data generation parameters
    prior_mu_z = torch.zeros(d, dtype=dtype)    # Prior mean
    prior_sigma_z = torch.eye(d, dtype=dtype)   # Prior covariance matrix

    # True model parameters
    num_range = torch.arange(-(d-1)/2, (d+1)/2, dtype=dtype)

    t_delta =  num_range / 5 

    print(f"true delta = {t_delta.numpy()}")

    if d == 1:
        t_sigma = torch.ones(1, dtype=dtype)
    else: 
        # Allow sigma to range from 0.1 to 1
        t_sigma = 36/(10*(d-1)**2) * num_range**2 + 0.1 
    print(f"true sigma = {t_sigma.numpy()}")

    ######### Variable Initialization

    # Initial model parameters - same across all methods
    init_delta = prior_mu_z.clone().to(device)
    init_log_sigma = 3 * torch.ones(d).to(device)

    # Initial HVAE variational parameters
    init_T = torch.tensor(5., dtype=dtype, device=device)
    init_eps = 0.005 * torch.ones(d, dtype=dtype)
    max_eps = params['max_eps'] * torch.ones(d, dtype=dtype)
    init_logit_eps = torch.log(init_eps/(max_eps - init_eps)).to(device)
    init_log_T_0 = torch.log(init_T - 1)

    # Initial NF variational parameters
    init_u_pre_reparam = torch.tensor(scipy.stats.truncnorm.rvs(-2, 2, 
                                                                scale=0.1, 
                                                                size=d),
                                      dtype=dtype, device=device)
    init_w = torch.tensor(scipy.stats.truncnorm.rvs(-2, 2, scale=0.1, size=d),
                          dtype=dtype, device=device)
    init_b = torch.tensor(0.1, dtype=dtype, device=device)

    # Initial VAE parameters
    init_mu_z = prior_mu_z.clone()
    init_log_sigma_z = torch.ones(d, dtype=dtype)

    ######### Set up models
    init_params = [[init_delta, init_log_sigma, init_logit_eps],
                   [init_delta, init_log_sigma, init_logit_eps]]
    
    HVAE_model_notemp_1 = HVAE(params,
        ['delta', 'log_sigma', 'logit_eps'],
        init_params[0], 
        'HVAE_notemp_1', d, params['HVAE_K_1'])
    HVAE_model_notemp_2 = HVAE(params,
        ['delta', 'log_sigma', 'logit_eps'], 
        init_params[1],
        'HVAE_notemp_2', d, params['HVAE_K_2'])

    #model_list = [HVAE_model_1, HVAE_model_2, NF_model_1]
    #model_list = [HVAE_model_1, NF_model_1]
    model_list = [HVAE_model_notemp_1, HVAE_model_notemp_2]

    print("Models were initialized!")
    
    ######### Generate Training Data & Save - One for each test

    train_data_list = []

    for i in range(params['n_tests']):
        z = MultivariateNormal(prior_mu_z, prior_sigma_z).sample()
        x = MultivariateNormal(z + t_delta, 
                               torch.diag(t_sigma**2)).sample([params['n_data']])
        x = x.to(device)
        train_data_list.append(x)

    # Folder should have already been created in the initializations
    data_path = os.path.join('save', str(d), 'train_data.p')
    pickle.dump(train_data_list, open(data_path, 'wb')) 

    # Store the final parameter values for all test runs in this dictionary
    final_params = {}

    for i in range(len(model_list)):
        final_values = []
        m = model_list[i]
        model_init_params = init_params[i]

        for j in range(params['n_tests']):
            print("------------------------------------------------------")
            print(f"Test = {j}")
            print("------------------------------------------------------")
            m._reinitialize(model_init_params)
            gaussian_data = gaussian_dataset(train_data_list[j])
            train_dataloader = DataLoader(gaussian_data, batch_size=batch_size,
                                          shuffle=False, num_workers=0)
            (delta, sigma) = m.train(train_dataloader, j, 
                                     t_delta, t_sigma,
                                     clip_value)
            final_values.append((delta, sigma))

        final_params[m.model_name] = final_values.copy()

    ######### Test models using difference between parameters

    param_diffs = {}

    for m in model_list:
        
        diffs = []

        for i in range(params['n_tests']):
            delta = final_params[m.model_name][i][0]
            sigma = final_params[m.model_name][i][1]

            delta_diff = np.sum((delta - t_delta.numpy())**2)
            sigma_diff = np.sum((sigma - t_sigma.numpy())**2)
            theta_diff = delta_diff + sigma_diff
            print(f"Model {m.model_name}, test = {i}, result delta diff = {delta_diff}")
            print(f"Model {m.model_name}, test = {i}, result sigma diff = {sigma_diff}")
            print(f"Model {m.model_name}, test = {i}, result theta diff = {theta_diff}")

            diffs.append((delta_diff, sigma_diff, theta_diff))

        param_diffs[m.model_name] = diffs.copy()

    # Save parameter differences in a pickle file
    diff_path = os.path.join('save', str(d), 'all_diffs.p')
    pickle.dump(param_diffs, open(diff_path, 'wb'))

# %%
device = torch.device("cuda")
dtype = torch.float32
clip_value = None
batch_size = 256

# %%
params = {

    # PROBLEM SPECIFICATION
    #'dims': [1, 2, 3, 5, 11, 25, 51, 101, 201, 301], # Dimensions to test
    'dims': [200],
    'n_data': 10000,                                 # Number of data points

    # TEST HYPERPARAMETERS
    'n_tests': 3,      # Number of experiments to run

    # GLOBAL OPTIMIZATION PARAMETERS
    'n_iter': 2000,    # Number of optimization iterations
    'n_batch': 10,      # Number of points for ELBO estimate
    'rms_eta': 0.001,   # Stepsize for RMSProp
    'save_every': 20,   # Save parameter information every so often
    'print_every': 20, # Print less often than save

    # HVAE HYPERPARAMETERS
    'HVAE_K_1': 1,    # Number of leapfrog/cooling steps for HVAE flow 1
    'HVAE_K_2': 10,   # Number of leapfrog/cooling steps for HVAE flow 2
    'max_eps': 0.5,   # Maximum leapfrog step size per dimension 

    # NF HYPERPARAMETERS
    'NF_K_1': 1,    # Number of flow steps for NF flow 1
    'NF_K_2': 30,   # Number of flow steps for NF flow 2
    
}

# %%
dims = params['dims']
seed = 12345
np.random.seed(seed)
torch.manual_seed(seed)
for d in dims:
    print('**** Running test for d={0:d} ****'.format(d))
    run_test(d, params, batch_size, clip_value, dtype, device)
# Out:
# **** Running test for d=200 ****
# true delta = [-19.9 -19.7 -19.5 -19.3 -19.1 -18.9 -18.7 -18.5 -18.3 -18.1 -17.9 -17.7
#  -17.5 -17.3 -17.1 -16.9 -16.7 -16.5 -16.3 -16.1 -15.9 -15.7 -15.5 -15.3
#  -15.1 -14.9 -14.7 -14.5 -14.3 -14.1 -13.9 -13.7 -13.5 -13.3 -13.1 -12.9
#  -12.7 -12.5 -12.3 -12.1 -11.9 -11.7 -11.5 -11.3 -11.1 -10.9 -10.7 -10.5
#  -10.3 -10.1  -9.9  -9.7  -9.5  -9.3  -9.1  -8.9  -8.7  -8.5  -8.3  -8.1
#   -7.9  -7.7  -7.5  -7.3  -7.1  -6.9  -6.7  -6.5  -6.3  -6.1  -5.9  -5.7
#   -5.5  -5.3  -5.1  -4.9  -4.7  -4.5  -4.3  -4.1  -3.9  -3.7  -3.5  -3.3
#   -3.1  -2.9  -2.7  -2.5  -2.3  -2.1  -1.9  -1.7  -1.5  -1.3  -1.1  -0.9
#   -0.7  -0.5  -0.3  -0.1   0.1   0.3   0.5   0.7   0.9   1.1   1.3   1.5
#    1.7   1.9   2.1   2.3   2.5   2.7   2.9   3.1   3.3   3.5   3.7   3.9
#    4.1   4.3   4.5   4.7   4.9   5.1   5.3   5.5   5.7   5.9   6.1   6.3
#    6.5   6.7   6.9   7.1   7.3   7.5   7.7   7.9   8.1   8.3   8.5   8.7
#    8.9   9.1   9.3   9.5   9.7   9.9  10.1  10.3  10.5  10.7  10.9  11.1
#   11.3  11.5  11.7  11.9  12.1  12.3  12.5  12.7  12.9  13.1  13.3  13.5
#   13.7  13.9  14.1  14.3  14.5  14.7  14.9  15.1  15.3  15.5  15.7  15.9
#   16.1  16.3  16.5  16.7  16.9  17.1  17.3  17.5  17.7  17.9  18.1  18.3
#   18.5  18.7  18.9  19.1  19.3  19.5  19.7  19.9]
# true sigma = [1.         0.98200047 0.96418273 0.94654685 0.92909276 0.9118205
#  0.89473    0.8778213  0.8610945  0.8445494  0.8281862  0.8120048
#  0.7960052  0.7801874  0.76455146 0.7490973  0.7338249  0.7187344
#  0.7038257  0.6890988  0.6745537  0.6601904  0.64600897 0.6320093
#  0.6181915  0.6045555  0.5911012  0.5778289  0.5647383  0.5518295
#  0.53910255 0.52655745 0.51419413 0.5020126  0.49001288 0.47819498
#  0.46655893 0.45510468 0.44383222 0.43274158 0.42183277 0.41110578
#  0.4005606  0.39019722 0.38001564 0.37001592 0.36019796 0.35056186
#  0.34110755 0.33183506 0.32274437 0.3138355  0.30510846 0.2965632
#  0.2881998  0.28001818 0.27201837 0.2642004  0.25656423 0.24910986
#  0.24183732 0.2347466  0.22783768 0.22111058 0.21456529 0.20820183
#  0.20202015 0.1960203  0.19020227 0.18456605 0.17911164 0.17383905
#  0.16874826 0.16383931 0.15911214 0.15456681 0.15020329 0.14602157
#  0.14202167 0.13820359 0.1345673  0.13111286 0.1278402  0.12474938
#  0.12184036 0.11911315 0.11656776 0.11420419 0.11202242 0.11002248
#  0.10820434 0.10656802 0.10511351 0.10384081 0.10274993 0.10184086
#  0.10111361 0.10056817 0.10020454 0.10002273 0.10002273 0.10020454
#  0.10056817 0.10111361 0.10184086 0.10274993 0.10384081 0.10511351
#  0.10656802 0.10820434 0.11002248 0.11202242 0.11420419 0.11656776
#  0.11911315 0.12184036 0.12474938 0.1278402  0.13111286 0.1345673
#  0.13820359 0.14202167 0.14602157 0.15020329 0.15456681 0.15911214
#  0.16383931 0.16874826 0.17383905 0.17911164 0.18456605 0.19020227
#  0.1960203  0.20202015 0.20820183 0.21456529 0.22111058 0.22783768
#  0.2347466  0.24183732 0.24910986 0.25656423 0.2642004  0.27201837
#  0.28001818 0.2881998  0.2965632  0.30510846 0.3138355  0.32274437
#  0.33183506 0.34110755 0.35056186 0.36019796 0.37001592 0.38001564
#  0.39019722 0.4005606  0.41110578 0.42183277 0.43274158 0.44383222
#  0.45510468 0.46655893 0.47819498 0.49001288 0.5020126  0.51419413
#  0.52655745 0.53910255 0.5518295  0.5647383  0.5778289  0.5911012
#  0.6045555  0.6181915  0.6320093  0.64600897 0.6601904  0.6745537
#  0.6890988  0.7038257  0.7187344  0.7338249  0.7490973  0.76455146
#  0.7801874  0.7960052  0.8120048  0.8281862  0.8445494  0.8610945
#  0.8778213  0.89473    0.9118205  0.92909276 0.94654685 0.96418273
#  0.98200047 1.        ]
# Models were initialized!
# ------------------------------------------------------
# Test = 0
# ------------------------------------------------------
# Init diff delta = 26666.0
# Init diff sigma = 77495.03125
# Init diff theta = 104161.03125
# HVAE_notemp_1, d: 200, Iter: 1-20, s/iter: 1.509e-01, ELBO: -7.273e+06
# Cur diff delta = 22980.841796875
# Cur diff sigma = 26015.697265625
# Cur diff theta = 48996.5390625
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-40, s/iter: 1.471e-01, ELBO: -6.730e+06
# Cur diff delta = 20186.369140625
# Cur diff sigma = 19487.046875
# Cur diff theta = 39673.416015625
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-60, s/iter: 1.465e-01, ELBO: -6.283e+06
# Cur diff delta = 17664.513671875
# Cur diff sigma = 16580.34375
# Cur diff theta = 34244.857421875
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-80, s/iter: 1.575e-01, ELBO: -5.975e+06
# Cur diff delta = 15371.607421875
# Cur diff sigma = 14332.96484375
# Cur diff theta = 29704.572265625
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-100, s/iter: 1.517e-01, ELBO: -5.494e+06
# Cur diff delta = 13288.072265625
# Cur diff sigma = 12244.4267578125
# Cur diff theta = 25532.4990234375
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-120, s/iter: 1.521e-01, ELBO: -5.174e+06
# Cur diff delta = 11400.4912109375
# Cur diff sigma = 10268.216796875
# Cur diff theta = 21668.7080078125
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-140, s/iter: 1.641e-01, ELBO: -4.880e+06
# Cur diff delta = 9702.0166015625
# Cur diff sigma = 8423.6708984375
# Cur diff theta = 18125.6875
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-160, s/iter: 1.512e-01, ELBO: -4.617e+06
# Cur diff delta = 8182.2353515625
# Cur diff sigma = 6726.931640625
# Cur diff theta = 14909.1669921875
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-180, s/iter: 1.544e-01, ELBO: -4.329e+06
# Cur diff delta = 6828.81494140625
# Cur diff sigma = 4988.2548828125
# Cur diff theta = 11817.06982421875
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-200, s/iter: 1.601e-01, ELBO: -4.069e+06
# Cur diff delta = 5638.3115234375
# Cur diff sigma = 3520.034912109375
# Cur diff theta = 9158.346435546875
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-220, s/iter: 1.531e-01, ELBO: -3.839e+06
# Cur diff delta = 4597.68505859375
# Cur diff sigma = 2314.23486328125
# Cur diff theta = 6911.919921875
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-240, s/iter: 1.490e-01, ELBO: -3.624e+06
# Cur diff delta = 3697.220458984375
# Cur diff sigma = 1442.1661376953125
# Cur diff theta = 5139.3865966796875
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-260, s/iter: 1.658e-01, ELBO: -3.426e+06
# Cur diff delta = 2930.529052734375
# Cur diff sigma = 977.159912109375
# Cur diff theta = 3907.68896484375
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-280, s/iter: 1.489e-01, ELBO: -3.262e+06
# Cur diff delta = 2286.083251953125
# Cur diff sigma = 765.1143188476562
# Cur diff theta = 3051.1975708007812
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-300, s/iter: 1.495e-01, ELBO: -3.103e+06
# Cur diff delta = 1748.942626953125
# Cur diff sigma = 578.0062255859375
# Cur diff theta = 2326.9488525390625
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-320, s/iter: 1.736e-01, ELBO: -2.956e+06
# Cur diff delta = 1310.2994384765625
# Cur diff sigma = 442.3309020996094
# Cur diff theta = 1752.6303405761719
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-340, s/iter: 1.557e-01, ELBO: -2.821e+06
# Cur diff delta = 961.3087768554688
# Cur diff sigma = 332.90643310546875
# Cur diff theta = 1294.2152099609375
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-360, s/iter: 1.604e-01, ELBO: -2.702e+06
# Cur diff delta = 691.0413818359375
# Cur diff sigma = 240.02859497070312
# Cur diff theta = 931.0699768066406
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-380, s/iter: 1.622e-01, ELBO: -2.605e+06
# Cur diff delta = 488.2900695800781
# Cur diff sigma = 167.4955291748047
# Cur diff theta = 655.7855987548828
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-400, s/iter: 1.522e-01, ELBO: -2.518e+06
# Cur diff delta = 345.60968017578125
# Cur diff sigma = 114.96097564697266
# Cur diff theta = 460.5706558227539
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-420, s/iter: 1.518e-01, ELBO: -2.446e+06
# Cur diff delta = 256.3042907714844
# Cur diff sigma = 81.01936340332031
# Cur diff theta = 337.3236541748047
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-440, s/iter: 1.601e-01, ELBO: -2.403e+06
# Cur diff delta = 206.0388641357422
# Cur diff sigma = 61.551143646240234
# Cur diff theta = 267.5900077819824
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-460, s/iter: 1.686e-01, ELBO: -2.368e+06
# Cur diff delta = 181.0743865966797
# Cur diff sigma = 49.7066650390625
# Cur diff theta = 230.7810516357422
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-480, s/iter: 1.598e-01, ELBO: -2.353e+06
# Cur diff delta = 172.3696746826172
# Cur diff sigma = 41.36399841308594
# Cur diff theta = 213.73367309570312
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-500, s/iter: 1.522e-01, ELBO: -2.336e+06
# Cur diff delta = 171.94920349121094
# Cur diff sigma = 36.03156280517578
# Cur diff theta = 207.98076629638672
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-520, s/iter: 1.575e-01, ELBO: -2.334e+06
# Cur diff delta = 174.73866271972656
# Cur diff sigma = 33.326602935791016
# Cur diff theta = 208.06526565551758
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-540, s/iter: 1.542e-01, ELBO: -2.327e+06
# Cur diff delta = 179.03042602539062
# Cur diff sigma = 32.398193359375
# Cur diff theta = 211.42861938476562
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-560, s/iter: 1.510e-01, ELBO: -2.329e+06
# Cur diff delta = 182.9435272216797
# Cur diff sigma = 32.214412689208984
# Cur diff theta = 215.15793991088867
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-580, s/iter: 1.579e-01, ELBO: -2.330e+06
# Cur diff delta = 184.0362091064453
# Cur diff sigma = 32.355384826660156
# Cur diff theta = 216.39159393310547
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-600, s/iter: 1.564e-01, ELBO: -2.329e+06
# Cur diff delta = 183.8209228515625
# Cur diff sigma = 32.267208099365234
# Cur diff theta = 216.08813095092773
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-620, s/iter: 1.532e-01, ELBO: -2.329e+06
# Cur diff delta = 184.5525360107422
# Cur diff sigma = 32.42040252685547
# Cur diff theta = 216.97293853759766
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-640, s/iter: 1.544e-01, ELBO: -2.325e+06
# Cur diff delta = 184.0989532470703
# Cur diff sigma = 32.306636810302734
# Cur diff theta = 216.40559005737305
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-660, s/iter: 1.686e-01, ELBO: -2.330e+06
# Cur diff delta = 184.86419677734375
# Cur diff sigma = 32.33718490600586
# Cur diff theta = 217.2013816833496
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-680, s/iter: 1.603e-01, ELBO: -2.325e+06
# Cur diff delta = 183.61241149902344
# Cur diff sigma = 32.24748229980469
# Cur diff theta = 215.85989379882812
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-700, s/iter: 1.541e-01, ELBO: -2.335e+06
# Cur diff delta = 184.04527282714844
# Cur diff sigma = 32.374576568603516
# Cur diff theta = 216.41984939575195
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-720, s/iter: 1.632e-01, ELBO: -2.325e+06
# Cur diff delta = 184.12496948242188
# Cur diff sigma = 32.258766174316406
# Cur diff theta = 216.38373565673828
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-740, s/iter: 1.573e-01, ELBO: -2.324e+06
# Cur diff delta = 184.10089111328125
# Cur diff sigma = 32.26067352294922
# Cur diff theta = 216.36156463623047
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-760, s/iter: 1.558e-01, ELBO: -2.334e+06
# Cur diff delta = 184.1453857421875
# Cur diff sigma = 32.362022399902344
# Cur diff theta = 216.50740814208984
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-780, s/iter: 1.545e-01, ELBO: -2.328e+06
# Cur diff delta = 183.994384765625
# Cur diff sigma = 32.329959869384766
# Cur diff theta = 216.32434463500977
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-800, s/iter: 1.556e-01, ELBO: -2.329e+06
# Cur diff delta = 184.0795135498047
# Cur diff sigma = 32.307090759277344
# Cur diff theta = 216.38660430908203
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-820, s/iter: 1.525e-01, ELBO: -2.324e+06
# Cur diff delta = 184.05517578125
# Cur diff sigma = 32.18657302856445
# Cur diff theta = 216.24174880981445
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-840, s/iter: 1.719e-01, ELBO: -2.330e+06
# Cur diff delta = 183.99203491210938
# Cur diff sigma = 32.40306854248047
# Cur diff theta = 216.39510345458984
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-860, s/iter: 1.581e-01, ELBO: -2.331e+06
# Cur diff delta = 184.06005859375
# Cur diff sigma = 32.38351058959961
# Cur diff theta = 216.4435691833496
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-880, s/iter: 1.569e-01, ELBO: -2.334e+06
# Cur diff delta = 184.14303588867188
# Cur diff sigma = 32.39666748046875
# Cur diff theta = 216.53970336914062
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-900, s/iter: 1.539e-01, ELBO: -2.325e+06
# Cur diff delta = 183.80709838867188
# Cur diff sigma = 32.283790588378906
# Cur diff theta = 216.09088897705078
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-920, s/iter: 1.571e-01, ELBO: -2.330e+06
# Cur diff delta = 184.2128448486328
# Cur diff sigma = 32.333709716796875
# Cur diff theta = 216.5465545654297
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-940, s/iter: 1.555e-01, ELBO: -2.330e+06
# Cur diff delta = 184.62332153320312
# Cur diff sigma = 32.41782760620117
# Cur diff theta = 217.0411491394043
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-960, s/iter: 1.578e-01, ELBO: -2.323e+06
# Cur diff delta = 184.63893127441406
# Cur diff sigma = 32.42313003540039
# Cur diff theta = 217.06206130981445
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-980, s/iter: 1.562e-01, ELBO: -2.335e+06
# Cur diff delta = 184.63790893554688
# Cur diff sigma = 32.380924224853516
# Cur diff theta = 217.0188331604004
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1000, s/iter: 1.536e-01, ELBO: -2.333e+06
# Cur diff delta = 184.89378356933594
# Cur diff sigma = 32.312782287597656
# Cur diff theta = 217.2065658569336
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1020, s/iter: 1.640e-01, ELBO: -2.326e+06
# Cur diff delta = 184.40367126464844
# Cur diff sigma = 32.26213455200195
# Cur diff theta = 216.6658058166504
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1040, s/iter: 1.613e-01, ELBO: -2.329e+06
# Cur diff delta = 184.7709503173828
# Cur diff sigma = 32.393096923828125
# Cur diff theta = 217.16404724121094
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1060, s/iter: 1.520e-01, ELBO: -2.330e+06
# Cur diff delta = 183.87901306152344
# Cur diff sigma = 32.41776657104492
# Cur diff theta = 216.29677963256836
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1080, s/iter: 1.529e-01, ELBO: -2.333e+06
# Cur diff delta = 184.5685272216797
# Cur diff sigma = 32.43354797363281
# Cur diff theta = 217.0020751953125
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1100, s/iter: 1.792e-01, ELBO: -2.336e+06
# Cur diff delta = 184.26492309570312
# Cur diff sigma = 32.39091110229492
# Cur diff theta = 216.65583419799805
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1120, s/iter: 1.742e-01, ELBO: -2.323e+06
# Cur diff delta = 183.91978454589844
# Cur diff sigma = 32.26304626464844
# Cur diff theta = 216.18283081054688
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1140, s/iter: 1.791e-01, ELBO: -2.319e+06
# Cur diff delta = 183.97842407226562
# Cur diff sigma = 32.272098541259766
# Cur diff theta = 216.2505226135254
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1160, s/iter: 1.549e-01, ELBO: -2.328e+06
# Cur diff delta = 184.4895477294922
# Cur diff sigma = 32.200130462646484
# Cur diff theta = 216.68967819213867
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1180, s/iter: 1.701e-01, ELBO: -2.324e+06
# Cur diff delta = 183.93382263183594
# Cur diff sigma = 32.292354583740234
# Cur diff theta = 216.22617721557617
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1200, s/iter: 1.536e-01, ELBO: -2.328e+06
# Cur diff delta = 184.2852783203125
# Cur diff sigma = 32.22450637817383
# Cur diff theta = 216.50978469848633
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1220, s/iter: 1.729e-01, ELBO: -2.336e+06
# Cur diff delta = 184.2360382080078
# Cur diff sigma = 32.408905029296875
# Cur diff theta = 216.6449432373047
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1240, s/iter: 1.660e-01, ELBO: -2.323e+06
# Cur diff delta = 184.193603515625
# Cur diff sigma = 32.29358673095703
# Cur diff theta = 216.48719024658203
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1260, s/iter: 1.553e-01, ELBO: -2.336e+06
# Cur diff delta = 184.45916748046875
# Cur diff sigma = 32.47432327270508
# Cur diff theta = 216.93349075317383
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1280, s/iter: 1.562e-01, ELBO: -2.326e+06
# Cur diff delta = 183.64857482910156
# Cur diff sigma = 32.308937072753906
# Cur diff theta = 215.95751190185547
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1300, s/iter: 1.530e-01, ELBO: -2.331e+06
# Cur diff delta = 184.13217163085938
# Cur diff sigma = 32.35066604614258
# Cur diff theta = 216.48283767700195
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1320, s/iter: 1.545e-01, ELBO: -2.330e+06
# Cur diff delta = 184.26968383789062
# Cur diff sigma = 32.28688430786133
# Cur diff theta = 216.55656814575195
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1340, s/iter: 1.711e-01, ELBO: -2.325e+06
# Cur diff delta = 184.1215362548828
# Cur diff sigma = 32.278663635253906
# Cur diff theta = 216.40019989013672
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1360, s/iter: 1.546e-01, ELBO: -2.334e+06
# Cur diff delta = 184.55654907226562
# Cur diff sigma = 32.450042724609375
# Cur diff theta = 217.006591796875
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1380, s/iter: 1.543e-01, ELBO: -2.326e+06
# Cur diff delta = 183.8306427001953
# Cur diff sigma = 32.32408905029297
# Cur diff theta = 216.15473175048828
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1400, s/iter: 1.693e-01, ELBO: -2.327e+06
# Cur diff delta = 184.1603240966797
# Cur diff sigma = 32.2618293762207
# Cur diff theta = 216.4221534729004
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1420, s/iter: 1.569e-01, ELBO: -2.329e+06
# Cur diff delta = 184.8754119873047
# Cur diff sigma = 32.30610275268555
# Cur diff theta = 217.18151473999023
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1440, s/iter: 1.546e-01, ELBO: -2.327e+06
# Cur diff delta = 184.71441650390625
# Cur diff sigma = 32.25751876831055
# Cur diff theta = 216.9719352722168
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1460, s/iter: 1.628e-01, ELBO: -2.323e+06
# Cur diff delta = 184.5636444091797
# Cur diff sigma = 32.2799186706543
# Cur diff theta = 216.84356307983398
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1480, s/iter: 1.700e-01, ELBO: -2.331e+06
# Cur diff delta = 184.4525909423828
# Cur diff sigma = 32.341468811035156
# Cur diff theta = 216.79405975341797
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1500, s/iter: 1.554e-01, ELBO: -2.329e+06
# Cur diff delta = 184.80117797851562
# Cur diff sigma = 32.35710144042969
# Cur diff theta = 217.1582794189453
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1520, s/iter: 1.573e-01, ELBO: -2.334e+06
# Cur diff delta = 184.66358947753906
# Cur diff sigma = 32.203548431396484
# Cur diff theta = 216.86713790893555
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1540, s/iter: 1.585e-01, ELBO: -2.327e+06
# Cur diff delta = 183.59385681152344
# Cur diff sigma = 32.35102081298828
# Cur diff theta = 215.94487762451172
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1560, s/iter: 1.617e-01, ELBO: -2.326e+06
# Cur diff delta = 184.53125
# Cur diff sigma = 32.23588180541992
# Cur diff theta = 216.76713180541992
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1580, s/iter: 1.580e-01, ELBO: -2.318e+06
# Cur diff delta = 184.53976440429688
# Cur diff sigma = 32.14265060424805
# Cur diff theta = 216.68241500854492
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1600, s/iter: 1.602e-01, ELBO: -2.322e+06
# Cur diff delta = 184.12716674804688
# Cur diff sigma = 32.225521087646484
# Cur diff theta = 216.35268783569336
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1620, s/iter: 1.587e-01, ELBO: -2.332e+06
# Cur diff delta = 184.64865112304688
# Cur diff sigma = 32.44154357910156
# Cur diff theta = 217.09019470214844
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1640, s/iter: 1.822e-01, ELBO: -2.331e+06
# Cur diff delta = 184.7626495361328
# Cur diff sigma = 32.36821746826172
# Cur diff theta = 217.13086700439453
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1660, s/iter: 1.683e-01, ELBO: -2.327e+06
# Cur diff delta = 184.40713500976562
# Cur diff sigma = 32.25811004638672
# Cur diff theta = 216.66524505615234
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1680, s/iter: 1.545e-01, ELBO: -2.331e+06
# Cur diff delta = 183.68893432617188
# Cur diff sigma = 32.40320587158203
# Cur diff theta = 216.0921401977539
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1700, s/iter: 1.578e-01, ELBO: -2.324e+06
# Cur diff delta = 184.35963439941406
# Cur diff sigma = 32.200313568115234
# Cur diff theta = 216.5599479675293
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1720, s/iter: 1.633e-01, ELBO: -2.321e+06
# Cur diff delta = 184.58023071289062
# Cur diff sigma = 32.26438522338867
# Cur diff theta = 216.8446159362793
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1740, s/iter: 1.619e-01, ELBO: -2.329e+06
# Cur diff delta = 184.6334686279297
# Cur diff sigma = 32.321624755859375
# Cur diff theta = 216.95509338378906
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1760, s/iter: 1.568e-01, ELBO: -2.323e+06
# Cur diff delta = 184.5417938232422
# Cur diff sigma = 32.23998260498047
# Cur diff theta = 216.78177642822266
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1780, s/iter: 1.621e-01, ELBO: -2.336e+06
# Cur diff delta = 183.44207763671875
# Cur diff sigma = 32.35551834106445
# Cur diff theta = 215.7975959777832
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1800, s/iter: 1.678e-01, ELBO: -2.324e+06
# Cur diff delta = 183.8508758544922
# Cur diff sigma = 32.32985305786133
# Cur diff theta = 216.18072891235352
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1820, s/iter: 1.550e-01, ELBO: -2.327e+06
# Cur diff delta = 183.82901000976562
# Cur diff sigma = 32.34000015258789
# Cur diff theta = 216.16901016235352
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1840, s/iter: 1.625e-01, ELBO: -2.329e+06
# Cur diff delta = 183.59828186035156
# Cur diff sigma = 32.37097930908203
# Cur diff theta = 215.9692611694336
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1860, s/iter: 1.571e-01, ELBO: -2.332e+06
# Cur diff delta = 184.76100158691406
# Cur diff sigma = 32.38113021850586
# Cur diff theta = 217.14213180541992
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1880, s/iter: 1.558e-01, ELBO: -2.328e+06
# Cur diff delta = 184.18862915039062
# Cur diff sigma = 32.30722427368164
# Cur diff theta = 216.49585342407227
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1900, s/iter: 1.696e-01, ELBO: -2.330e+06
# Cur diff delta = 184.24429321289062
# Cur diff sigma = 32.31294631958008
# Cur diff theta = 216.5572395324707
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1920, s/iter: 1.558e-01, ELBO: -2.331e+06
# Cur diff delta = 184.0399932861328
# Cur diff sigma = 32.297752380371094
# Cur diff theta = 216.3377456665039
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1940, s/iter: 1.546e-01, ELBO: -2.326e+06
# Cur diff delta = 183.8779296875
# Cur diff sigma = 32.21072006225586
# Cur diff theta = 216.08864974975586
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1960, s/iter: 1.594e-01, ELBO: -2.328e+06
# Cur diff delta = 183.84715270996094
# Cur diff sigma = 32.23499298095703
# Cur diff theta = 216.08214569091797
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-1980, s/iter: 1.585e-01, ELBO: -2.323e+06
# Cur diff delta = 183.9671173095703
# Cur diff sigma = 32.32487487792969
# Cur diff theta = 216.2919921875
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 1-2000, s/iter: 1.626e-01, ELBO: -2.328e+06
# Cur diff delta = 183.73350524902344
# Cur diff sigma = 32.3148193359375
# Cur diff theta = 216.04832458496094
# ---------------------------------------
# ------------------------------------------------------
# Test = 1
# ------------------------------------------------------
# Init diff delta = 26666.0
# Init diff sigma = 77495.03125
# Init diff theta = 104161.03125
# HVAE_notemp_1, d: 200, Iter: 2-20, s/iter: 1.571e-01, ELBO: -7.280e+06
# Cur diff delta = 22983.8359375
# Cur diff sigma = 26173.82421875
# Cur diff theta = 49157.66015625
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-40, s/iter: 1.530e-01, ELBO: -6.740e+06
# Cur diff delta = 20190.658203125
# Cur diff sigma = 19717.94921875
# Cur diff theta = 39908.607421875
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-60, s/iter: 1.649e-01, ELBO: -6.291e+06
# Cur diff delta = 17668.96484375
# Cur diff sigma = 16745.732421875
# Cur diff theta = 34414.697265625
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-80, s/iter: 1.592e-01, ELBO: -5.986e+06
# Cur diff delta = 15376.6650390625
# Cur diff sigma = 14475.296875
# Cur diff theta = 29851.9619140625
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-100, s/iter: 1.775e-01, ELBO: -5.497e+06
# Cur diff delta = 13296.9931640625
# Cur diff sigma = 12403.6923828125
# Cur diff theta = 25700.685546875
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-120, s/iter: 1.763e-01, ELBO: -5.198e+06
# Cur diff delta = 11413.107421875
# Cur diff sigma = 10404.5791015625
# Cur diff theta = 21817.6865234375
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-140, s/iter: 1.657e-01, ELBO: -4.916e+06
# Cur diff delta = 9712.044921875
# Cur diff sigma = 8562.2626953125
# Cur diff theta = 18274.3076171875
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-160, s/iter: 1.588e-01, ELBO: -4.648e+06
# Cur diff delta = 8186.212890625
# Cur diff sigma = 6808.59521484375
# Cur diff theta = 14994.80810546875
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-180, s/iter: 1.528e-01, ELBO: -4.383e+06
# Cur diff delta = 6829.0947265625
# Cur diff sigma = 5089.37841796875
# Cur diff theta = 11918.47314453125
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-200, s/iter: 1.731e-01, ELBO: -4.098e+06
# Cur diff delta = 5632.21728515625
# Cur diff sigma = 3438.99365234375
# Cur diff theta = 9071.2109375
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-220, s/iter: 1.540e-01, ELBO: -3.855e+06
# Cur diff delta = 4595.20068359375
# Cur diff sigma = 2242.293701171875
# Cur diff theta = 6837.494384765625
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-240, s/iter: 1.520e-01, ELBO: -3.636e+06
# Cur diff delta = 3701.603515625
# Cur diff sigma = 1383.4703369140625
# Cur diff theta = 5085.0738525390625
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-260, s/iter: 1.521e-01, ELBO: -3.447e+06
# Cur diff delta = 2937.760986328125
# Cur diff sigma = 949.4227905273438
# Cur diff theta = 3887.1837768554688
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-280, s/iter: 1.617e-01, ELBO: -3.281e+06
# Cur diff delta = 2292.012451171875
# Cur diff sigma = 778.0237426757812
# Cur diff theta = 3070.0361938476562
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-300, s/iter: 1.560e-01, ELBO: -3.131e+06
# Cur diff delta = 1753.99853515625
# Cur diff sigma = 577.958740234375
# Cur diff theta = 2331.957275390625
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-320, s/iter: 1.630e-01, ELBO: -2.980e+06
# Cur diff delta = 1317.5755615234375
# Cur diff sigma = 443.3370056152344
# Cur diff theta = 1760.9125671386719
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-340, s/iter: 1.834e-01, ELBO: -2.836e+06
# Cur diff delta = 968.0977783203125
# Cur diff sigma = 326.9863586425781
# Cur diff theta = 1295.0841369628906
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-360, s/iter: 1.562e-01, ELBO: -2.722e+06
# Cur diff delta = 697.5302124023438
# Cur diff sigma = 232.43077087402344
# Cur diff theta = 929.9609832763672
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-380, s/iter: 1.553e-01, ELBO: -2.607e+06
# Cur diff delta = 496.956787109375
# Cur diff sigma = 159.95114135742188
# Cur diff theta = 656.9079284667969
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-400, s/iter: 1.542e-01, ELBO: -2.521e+06
# Cur diff delta = 358.0753173828125
# Cur diff sigma = 107.7232437133789
# Cur diff theta = 465.7985610961914
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-420, s/iter: 1.580e-01, ELBO: -2.441e+06
# Cur diff delta = 269.194580078125
# Cur diff sigma = 73.16805267333984
# Cur diff theta = 342.36263275146484
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-440, s/iter: 1.564e-01, ELBO: -2.389e+06
# Cur diff delta = 216.77493286132812
# Cur diff sigma = 52.912025451660156
# Cur diff theta = 269.6869583129883
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-460, s/iter: 1.583e-01, ELBO: -2.354e+06
# Cur diff delta = 194.02081298828125
# Cur diff sigma = 42.33818817138672
# Cur diff theta = 236.35900115966797
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-480, s/iter: 1.561e-01, ELBO: -2.343e+06
# Cur diff delta = 189.7296142578125
# Cur diff sigma = 36.262203216552734
# Cur diff theta = 225.99181747436523
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-500, s/iter: 1.572e-01, ELBO: -2.333e+06
# Cur diff delta = 192.6043701171875
# Cur diff sigma = 33.38970947265625
# Cur diff theta = 225.99407958984375
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-520, s/iter: 1.610e-01, ELBO: -2.334e+06
# Cur diff delta = 197.0413818359375
# Cur diff sigma = 32.66532516479492
# Cur diff theta = 229.70670700073242
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-540, s/iter: 1.530e-01, ELBO: -2.333e+06
# Cur diff delta = 200.6890869140625
# Cur diff sigma = 32.50337600708008
# Cur diff theta = 233.19246292114258
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-560, s/iter: 1.556e-01, ELBO: -2.324e+06
# Cur diff delta = 204.55992126464844
# Cur diff sigma = 32.36595153808594
# Cur diff theta = 236.92587280273438
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-580, s/iter: 1.658e-01, ELBO: -2.332e+06
# Cur diff delta = 204.9263153076172
# Cur diff sigma = 32.307151794433594
# Cur diff theta = 237.23346710205078
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-600, s/iter: 1.562e-01, ELBO: -2.328e+06
# Cur diff delta = 205.1802215576172
# Cur diff sigma = 32.278114318847656
# Cur diff theta = 237.45833587646484
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-620, s/iter: 1.582e-01, ELBO: -2.331e+06
# Cur diff delta = 205.0940399169922
# Cur diff sigma = 32.238407135009766
# Cur diff theta = 237.33244705200195
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-640, s/iter: 1.705e-01, ELBO: -2.327e+06
# Cur diff delta = 205.6507568359375
# Cur diff sigma = 32.3119010925293
# Cur diff theta = 237.9626579284668
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-660, s/iter: 1.608e-01, ELBO: -2.333e+06
# Cur diff delta = 204.35292053222656
# Cur diff sigma = 32.43609619140625
# Cur diff theta = 236.7890167236328
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-680, s/iter: 1.556e-01, ELBO: -2.327e+06
# Cur diff delta = 204.7380828857422
# Cur diff sigma = 32.26171875
# Cur diff theta = 236.9998016357422
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-700, s/iter: 1.747e-01, ELBO: -2.326e+06
# Cur diff delta = 205.33645629882812
# Cur diff sigma = 32.2823600769043
# Cur diff theta = 237.61881637573242
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-720, s/iter: 1.679e-01, ELBO: -2.326e+06
# Cur diff delta = 205.52328491210938
# Cur diff sigma = 32.42438507080078
# Cur diff theta = 237.94766998291016
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-740, s/iter: 1.523e-01, ELBO: -2.325e+06
# Cur diff delta = 205.99122619628906
# Cur diff sigma = 32.30259323120117
# Cur diff theta = 238.29381942749023
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-760, s/iter: 1.547e-01, ELBO: -2.326e+06
# Cur diff delta = 205.0631103515625
# Cur diff sigma = 32.26947021484375
# Cur diff theta = 237.33258056640625
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-780, s/iter: 1.540e-01, ELBO: -2.332e+06
# Cur diff delta = 204.98960876464844
# Cur diff sigma = 32.45805740356445
# Cur diff theta = 237.4476661682129
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-800, s/iter: 1.533e-01, ELBO: -2.325e+06
# Cur diff delta = 205.15866088867188
# Cur diff sigma = 32.29912567138672
# Cur diff theta = 237.4577865600586
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-820, s/iter: 1.542e-01, ELBO: -2.321e+06
# Cur diff delta = 205.5359649658203
# Cur diff sigma = 32.26801681518555
# Cur diff theta = 237.80398178100586
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-840, s/iter: 1.687e-01, ELBO: -2.322e+06
# Cur diff delta = 205.13331604003906
# Cur diff sigma = 32.219757080078125
# Cur diff theta = 237.3530731201172
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-860, s/iter: 1.533e-01, ELBO: -2.325e+06
# Cur diff delta = 205.00680541992188
# Cur diff sigma = 32.30292510986328
# Cur diff theta = 237.30973052978516
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-880, s/iter: 1.546e-01, ELBO: -2.328e+06
# Cur diff delta = 205.077392578125
# Cur diff sigma = 32.33241271972656
# Cur diff theta = 237.40980529785156
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-900, s/iter: 1.553e-01, ELBO: -2.325e+06
# Cur diff delta = 204.68519592285156
# Cur diff sigma = 32.30049133300781
# Cur diff theta = 236.98568725585938
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-920, s/iter: 1.566e-01, ELBO: -2.324e+06
# Cur diff delta = 205.14486694335938
# Cur diff sigma = 32.35061264038086
# Cur diff theta = 237.49547958374023
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-940, s/iter: 1.562e-01, ELBO: -2.325e+06
# Cur diff delta = 205.5493621826172
# Cur diff sigma = 32.21195983886719
# Cur diff theta = 237.76132202148438
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-960, s/iter: 1.719e-01, ELBO: -2.327e+06
# Cur diff delta = 205.69007873535156
# Cur diff sigma = 32.21394729614258
# Cur diff theta = 237.90402603149414
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-980, s/iter: 1.528e-01, ELBO: -2.332e+06
# Cur diff delta = 205.55966186523438
# Cur diff sigma = 32.39012908935547
# Cur diff theta = 237.94979095458984
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1000, s/iter: 1.657e-01, ELBO: -2.334e+06
# Cur diff delta = 205.01507568359375
# Cur diff sigma = 32.32534408569336
# Cur diff theta = 237.3404197692871
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1020, s/iter: 1.724e-01, ELBO: -2.330e+06
# Cur diff delta = 205.2027587890625
# Cur diff sigma = 32.436405181884766
# Cur diff theta = 237.63916397094727
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1040, s/iter: 1.558e-01, ELBO: -2.327e+06
# Cur diff delta = 205.47137451171875
# Cur diff sigma = 32.23680114746094
# Cur diff theta = 237.7081756591797
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1060, s/iter: 1.573e-01, ELBO: -2.335e+06
# Cur diff delta = 205.4388427734375
# Cur diff sigma = 32.33700180053711
# Cur diff theta = 237.7758445739746
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1080, s/iter: 1.622e-01, ELBO: -2.326e+06
# Cur diff delta = 205.5336151123047
# Cur diff sigma = 32.329681396484375
# Cur diff theta = 237.86329650878906
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1100, s/iter: 1.575e-01, ELBO: -2.334e+06
# Cur diff delta = 205.3728790283203
# Cur diff sigma = 32.396724700927734
# Cur diff theta = 237.76960372924805
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1120, s/iter: 1.595e-01, ELBO: -2.333e+06
# Cur diff delta = 204.74403381347656
# Cur diff sigma = 32.300437927246094
# Cur diff theta = 237.04447174072266
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1140, s/iter: 1.568e-01, ELBO: -2.328e+06
# Cur diff delta = 205.1461944580078
# Cur diff sigma = 32.36356735229492
# Cur diff theta = 237.50976181030273
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1160, s/iter: 1.645e-01, ELBO: -2.330e+06
# Cur diff delta = 205.1181182861328
# Cur diff sigma = 32.28561019897461
# Cur diff theta = 237.40372848510742
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1180, s/iter: 1.598e-01, ELBO: -2.328e+06
# Cur diff delta = 205.3743133544922
# Cur diff sigma = 32.3942756652832
# Cur diff theta = 237.7685890197754
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1200, s/iter: 1.538e-01, ELBO: -2.324e+06
# Cur diff delta = 205.1349334716797
# Cur diff sigma = 32.250125885009766
# Cur diff theta = 237.38505935668945
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1220, s/iter: 1.694e-01, ELBO: -2.325e+06
# Cur diff delta = 205.04702758789062
# Cur diff sigma = 32.199554443359375
# Cur diff theta = 237.24658203125
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1240, s/iter: 1.585e-01, ELBO: -2.322e+06
# Cur diff delta = 205.12921142578125
# Cur diff sigma = 32.2592887878418
# Cur diff theta = 237.38850021362305
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1260, s/iter: 1.582e-01, ELBO: -2.328e+06
# Cur diff delta = 204.6331024169922
# Cur diff sigma = 32.36732482910156
# Cur diff theta = 237.00042724609375
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1280, s/iter: 1.549e-01, ELBO: -2.327e+06
# Cur diff delta = 204.8624725341797
# Cur diff sigma = 32.31425857543945
# Cur diff theta = 237.17673110961914
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1300, s/iter: 1.655e-01, ELBO: -2.326e+06
# Cur diff delta = 204.16555786132812
# Cur diff sigma = 32.27680587768555
# Cur diff theta = 236.44236373901367
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1320, s/iter: 1.600e-01, ELBO: -2.325e+06
# Cur diff delta = 206.0354766845703
# Cur diff sigma = 32.31775665283203
# Cur diff theta = 238.35323333740234
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1340, s/iter: 1.698e-01, ELBO: -2.332e+06
# Cur diff delta = 205.1632843017578
# Cur diff sigma = 32.362342834472656
# Cur diff theta = 237.52562713623047
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1360, s/iter: 1.560e-01, ELBO: -2.327e+06
# Cur diff delta = 205.1361846923828
# Cur diff sigma = 32.363487243652344
# Cur diff theta = 237.49967193603516
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1380, s/iter: 1.594e-01, ELBO: -2.329e+06
# Cur diff delta = 204.7655792236328
# Cur diff sigma = 32.35533142089844
# Cur diff theta = 237.12091064453125
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1400, s/iter: 1.576e-01, ELBO: -2.329e+06
# Cur diff delta = 205.4580078125
# Cur diff sigma = 32.33649826049805
# Cur diff theta = 237.79450607299805
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1420, s/iter: 1.614e-01, ELBO: -2.328e+06
# Cur diff delta = 204.81057739257812
# Cur diff sigma = 32.35417938232422
# Cur diff theta = 237.16475677490234
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1440, s/iter: 1.553e-01, ELBO: -2.325e+06
# Cur diff delta = 205.5108184814453
# Cur diff sigma = 32.32955551147461
# Cur diff theta = 237.84037399291992
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1460, s/iter: 1.565e-01, ELBO: -2.331e+06
# Cur diff delta = 205.66233825683594
# Cur diff sigma = 32.266448974609375
# Cur diff theta = 237.9287872314453
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1480, s/iter: 1.555e-01, ELBO: -2.326e+06
# Cur diff delta = 205.50027465820312
# Cur diff sigma = 32.30270767211914
# Cur diff theta = 237.80298233032227
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1500, s/iter: 1.550e-01, ELBO: -2.321e+06
# Cur diff delta = 205.02828979492188
# Cur diff sigma = 32.245643615722656
# Cur diff theta = 237.27393341064453
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1520, s/iter: 1.674e-01, ELBO: -2.326e+06
# Cur diff delta = 205.2169952392578
# Cur diff sigma = 32.323238372802734
# Cur diff theta = 237.54023361206055
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1540, s/iter: 1.554e-01, ELBO: -2.332e+06
# Cur diff delta = 205.8185272216797
# Cur diff sigma = 32.38877487182617
# Cur diff theta = 238.20730209350586
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1560, s/iter: 1.650e-01, ELBO: -2.330e+06
# Cur diff delta = 205.26913452148438
# Cur diff sigma = 32.411712646484375
# Cur diff theta = 237.68084716796875
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1580, s/iter: 1.573e-01, ELBO: -2.338e+06
# Cur diff delta = 205.31227111816406
# Cur diff sigma = 32.46063995361328
# Cur diff theta = 237.77291107177734
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1600, s/iter: 1.538e-01, ELBO: -2.323e+06
# Cur diff delta = 205.32049560546875
# Cur diff sigma = 32.36975860595703
# Cur diff theta = 237.69025421142578
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1620, s/iter: 1.549e-01, ELBO: -2.330e+06
# Cur diff delta = 205.34645080566406
# Cur diff sigma = 32.35529708862305
# Cur diff theta = 237.7017478942871
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1640, s/iter: 1.554e-01, ELBO: -2.329e+06
# Cur diff delta = 205.4195098876953
# Cur diff sigma = 32.322391510009766
# Cur diff theta = 237.74190139770508
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1660, s/iter: 1.563e-01, ELBO: -2.325e+06
# Cur diff delta = 204.8961639404297
# Cur diff sigma = 32.177913665771484
# Cur diff theta = 237.07407760620117
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1680, s/iter: 1.507e-01, ELBO: -2.329e+06
# Cur diff delta = 205.18716430664062
# Cur diff sigma = 32.30662155151367
# Cur diff theta = 237.4937858581543
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1700, s/iter: 1.514e-01, ELBO: -2.324e+06
# Cur diff delta = 205.2141571044922
# Cur diff sigma = 32.23070526123047
# Cur diff theta = 237.44486236572266
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1720, s/iter: 1.573e-01, ELBO: -2.331e+06
# Cur diff delta = 205.11563110351562
# Cur diff sigma = 32.30188751220703
# Cur diff theta = 237.41751861572266
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1740, s/iter: 1.596e-01, ELBO: -2.325e+06
# Cur diff delta = 204.87228393554688
# Cur diff sigma = 32.311580657958984
# Cur diff theta = 237.18386459350586
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1760, s/iter: 1.491e-01, ELBO: -2.326e+06
# Cur diff delta = 204.86749267578125
# Cur diff sigma = 32.316219329833984
# Cur diff theta = 237.18371200561523
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1780, s/iter: 1.636e-01, ELBO: -2.328e+06
# Cur diff delta = 204.6114501953125
# Cur diff sigma = 32.25194549560547
# Cur diff theta = 236.86339569091797
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1800, s/iter: 1.566e-01, ELBO: -2.332e+06
# Cur diff delta = 205.72987365722656
# Cur diff sigma = 32.36201095581055
# Cur diff theta = 238.0918846130371
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1820, s/iter: 1.556e-01, ELBO: -2.326e+06
# Cur diff delta = 205.41397094726562
# Cur diff sigma = 32.337162017822266
# Cur diff theta = 237.7511329650879
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1840, s/iter: 1.549e-01, ELBO: -2.334e+06
# Cur diff delta = 205.4889373779297
# Cur diff sigma = 32.49993133544922
# Cur diff theta = 237.9888687133789
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1860, s/iter: 1.491e-01, ELBO: -2.327e+06
# Cur diff delta = 205.7173614501953
# Cur diff sigma = 32.27129364013672
# Cur diff theta = 237.98865509033203
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1880, s/iter: 1.577e-01, ELBO: -2.322e+06
# Cur diff delta = 205.1912841796875
# Cur diff sigma = 32.290863037109375
# Cur diff theta = 237.48214721679688
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1900, s/iter: 1.518e-01, ELBO: -2.325e+06
# Cur diff delta = 205.89906311035156
# Cur diff sigma = 32.18317413330078
# Cur diff theta = 238.08223724365234
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1920, s/iter: 1.507e-01, ELBO: -2.334e+06
# Cur diff delta = 205.9794464111328
# Cur diff sigma = 32.452823638916016
# Cur diff theta = 238.43227005004883
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1940, s/iter: 1.579e-01, ELBO: -2.320e+06
# Cur diff delta = 205.2452392578125
# Cur diff sigma = 32.282161712646484
# Cur diff theta = 237.52740097045898
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1960, s/iter: 1.479e-01, ELBO: -2.329e+06
# Cur diff delta = 205.03395080566406
# Cur diff sigma = 32.316551208496094
# Cur diff theta = 237.35050201416016
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-1980, s/iter: 1.582e-01, ELBO: -2.323e+06
# Cur diff delta = 204.57174682617188
# Cur diff sigma = 32.24221420288086
# Cur diff theta = 236.81396102905273
# ---------------------------------------
# HVAE_notemp_1, d: 200, Iter: 2-2000, s/iter: 1.479e-01, ELBO: -2.324e+06
# Cur diff delta = 205.05963134765625
# Cur diff sigma = 32.25682830810547
# Cur diff theta = 237.31645965576172
# ---------------------------------------
# ------------------------------------------------------
# Test = 2
# ------------------------------------------------------
# Init diff delta = 26666.0
# Init diff sigma = 77495.03125
# Init diff theta = 104161.03125
# HVAE_notemp_1, d: 200, Iter: 3-20, s/iter: 1.599e-01, ELBO: -7.260e+06
# Cur diff delta = 22986.806640625
# Cur diff sigma = 25410.388671875
# Cur diff theta = 48397.1953125
# ---------------------------------------
# ...
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-680, s/iter: 4.599e-01, ELBO: -3.029e+06
# Cur diff delta = 200.16456604003906
# Cur diff sigma = 102.8940658569336
# Cur diff theta = 303.05863189697266
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-700, s/iter: 4.409e-01, ELBO: -3.020e+06
# Cur diff delta = 200.17628479003906
# Cur diff sigma = 102.67041015625
# Cur diff theta = 302.84669494628906
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-720, s/iter: 4.412e-01, ELBO: -3.030e+06
# Cur diff delta = 200.24868774414062
# Cur diff sigma = 102.90534973144531
# Cur diff theta = 303.15403747558594
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-740, s/iter: 4.497e-01, ELBO: -3.023e+06
# Cur diff delta = 200.18087768554688
# Cur diff sigma = 102.51909637451172
# Cur diff theta = 302.6999740600586
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-760, s/iter: 4.513e-01, ELBO: -3.020e+06
# Cur diff delta = 200.61671447753906
# Cur diff sigma = 102.41390228271484
# Cur diff theta = 303.0306167602539
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-780, s/iter: 4.570e-01, ELBO: -3.020e+06
# Cur diff delta = 200.95751953125
# Cur diff sigma = 102.4466323852539
# Cur diff theta = 303.4041519165039
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-800, s/iter: 4.511e-01, ELBO: -3.029e+06
# Cur diff delta = 201.09805297851562
# Cur diff sigma = 102.81390380859375
# Cur diff theta = 303.9119567871094
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-820, s/iter: 4.532e-01, ELBO: -3.015e+06
# Cur diff delta = 201.0373077392578
# Cur diff sigma = 102.66890716552734
# Cur diff theta = 303.70621490478516
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-840, s/iter: 4.585e-01, ELBO: -3.018e+06
# Cur diff delta = 200.8105010986328
# Cur diff sigma = 102.76117706298828
# Cur diff theta = 303.5716781616211
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-860, s/iter: 4.467e-01, ELBO: -3.024e+06
# Cur diff delta = 200.9084930419922
# Cur diff sigma = 102.54046630859375
# Cur diff theta = 303.44895935058594
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-880, s/iter: 4.556e-01, ELBO: -3.017e+06
# Cur diff delta = 200.64453125
# Cur diff sigma = 102.28096771240234
# Cur diff theta = 302.92549896240234
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-900, s/iter: 4.504e-01, ELBO: -3.022e+06
# Cur diff delta = 200.49668884277344
# Cur diff sigma = 102.26425170898438
# Cur diff theta = 302.7609405517578
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-920, s/iter: 4.543e-01, ELBO: -3.020e+06
# Cur diff delta = 200.8337860107422
# Cur diff sigma = 102.59333801269531
# Cur diff theta = 303.4271240234375
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-940, s/iter: 4.547e-01, ELBO: -3.018e+06
# Cur diff delta = 200.7748565673828
# Cur diff sigma = 102.57821655273438
# Cur diff theta = 303.3530731201172
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-960, s/iter: 4.795e-01, ELBO: -3.023e+06
# Cur diff delta = 201.4982147216797
# Cur diff sigma = 102.6934814453125
# Cur diff theta = 304.1916961669922
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-980, s/iter: 4.487e-01, ELBO: -3.019e+06
# Cur diff delta = 201.03196716308594
# Cur diff sigma = 102.48870849609375
# Cur diff theta = 303.5206756591797
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1000, s/iter: 4.383e-01, ELBO: -3.020e+06
# Cur diff delta = 200.29684448242188
# Cur diff sigma = 102.64845275878906
# Cur diff theta = 302.94529724121094
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1020, s/iter: 4.511e-01, ELBO: -3.026e+06
# Cur diff delta = 200.50840759277344
# Cur diff sigma = 102.79508972167969
# Cur diff theta = 303.3034973144531
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1040, s/iter: 4.514e-01, ELBO: -3.022e+06
# Cur diff delta = 200.95584106445312
# Cur diff sigma = 102.74185180664062
# Cur diff theta = 303.69769287109375
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1060, s/iter: 4.466e-01, ELBO: -3.021e+06
# Cur diff delta = 200.5087432861328
# Cur diff sigma = 102.45174407958984
# Cur diff theta = 302.96048736572266
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1080, s/iter: 4.446e-01, ELBO: -3.024e+06
# Cur diff delta = 201.4171142578125
# Cur diff sigma = 102.74165344238281
# Cur diff theta = 304.1587677001953
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1100, s/iter: 4.409e-01, ELBO: -3.027e+06
# Cur diff delta = 200.6575469970703
# Cur diff sigma = 102.93559265136719
# Cur diff theta = 303.5931396484375
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1120, s/iter: 4.534e-01, ELBO: -3.020e+06
# Cur diff delta = 201.0183563232422
# Cur diff sigma = 101.95804595947266
# Cur diff theta = 302.97640228271484
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1140, s/iter: 4.404e-01, ELBO: -3.017e+06
# Cur diff delta = 200.46839904785156
# Cur diff sigma = 102.56735229492188
# Cur diff theta = 303.03575134277344
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1160, s/iter: 4.449e-01, ELBO: -3.017e+06
# Cur diff delta = 200.3939971923828
# Cur diff sigma = 102.80583953857422
# Cur diff theta = 303.19983673095703
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1180, s/iter: 4.567e-01, ELBO: -3.022e+06
# Cur diff delta = 200.8752899169922
# Cur diff sigma = 102.72763061523438
# Cur diff theta = 303.60292053222656
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1200, s/iter: 4.494e-01, ELBO: -3.024e+06
# Cur diff delta = 200.75582885742188
# Cur diff sigma = 102.79285430908203
# Cur diff theta = 303.5486831665039
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1220, s/iter: 4.485e-01, ELBO: -3.025e+06
# Cur diff delta = 200.70278930664062
# Cur diff sigma = 102.3221664428711
# Cur diff theta = 303.0249557495117
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1240, s/iter: 4.639e-01, ELBO: -3.025e+06
# Cur diff delta = 201.12428283691406
# Cur diff sigma = 102.4769287109375
# Cur diff theta = 303.60121154785156
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1260, s/iter: 4.421e-01, ELBO: -3.020e+06
# Cur diff delta = 200.4010467529297
# Cur diff sigma = 102.38470458984375
# Cur diff theta = 302.78575134277344
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1280, s/iter: 4.615e-01, ELBO: -3.030e+06
# Cur diff delta = 200.35231018066406
# Cur diff sigma = 102.49779510498047
# Cur diff theta = 302.85010528564453
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1300, s/iter: 4.386e-01, ELBO: -3.015e+06
# Cur diff delta = 200.4656219482422
# Cur diff sigma = 102.50071716308594
# Cur diff theta = 302.9663391113281
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1320, s/iter: 4.269e-01, ELBO: -3.025e+06
# Cur diff delta = 201.49176025390625
# Cur diff sigma = 102.87266540527344
# Cur diff theta = 304.3644256591797
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1340, s/iter: 4.443e-01, ELBO: -3.018e+06
# Cur diff delta = 200.42315673828125
# Cur diff sigma = 102.42462921142578
# Cur diff theta = 302.84778594970703
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1360, s/iter: 4.723e-01, ELBO: -3.014e+06
# Cur diff delta = 200.60076904296875
# Cur diff sigma = 102.31027221679688
# Cur diff theta = 302.9110412597656
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1380, s/iter: 4.363e-01, ELBO: -3.025e+06
# Cur diff delta = 200.0283203125
# Cur diff sigma = 102.85501098632812
# Cur diff theta = 302.8833312988281
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1400, s/iter: 4.359e-01, ELBO: -3.013e+06
# Cur diff delta = 200.94615173339844
# Cur diff sigma = 102.29989624023438
# Cur diff theta = 303.2460479736328
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1420, s/iter: 4.363e-01, ELBO: -3.019e+06
# Cur diff delta = 200.92015075683594
# Cur diff sigma = 102.6598892211914
# Cur diff theta = 303.58003997802734
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1440, s/iter: 4.464e-01, ELBO: -3.026e+06
# Cur diff delta = 200.9791717529297
# Cur diff sigma = 102.6219253540039
# Cur diff theta = 303.6010971069336
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1460, s/iter: 4.442e-01, ELBO: -3.019e+06
# Cur diff delta = 200.64122009277344
# Cur diff sigma = 102.5741958618164
# Cur diff theta = 303.21541595458984
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1480, s/iter: 4.453e-01, ELBO: -3.015e+06
# Cur diff delta = 200.49044799804688
# Cur diff sigma = 102.51148223876953
# Cur diff theta = 303.0019302368164
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1500, s/iter: 4.627e-01, ELBO: -3.016e+06
# Cur diff delta = 200.50494384765625
# Cur diff sigma = 102.48538970947266
# Cur diff theta = 302.9903335571289
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1520, s/iter: 4.485e-01, ELBO: -3.023e+06
# Cur diff delta = 200.56410217285156
# Cur diff sigma = 102.39081573486328
# Cur diff theta = 302.95491790771484
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1540, s/iter: 4.434e-01, ELBO: -3.014e+06
# Cur diff delta = 200.98878479003906
# Cur diff sigma = 102.2541275024414
# Cur diff theta = 303.24291229248047
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1560, s/iter: 4.520e-01, ELBO: -3.022e+06
# Cur diff delta = 200.66830444335938
# Cur diff sigma = 102.3477554321289
# Cur diff theta = 303.0160598754883
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1580, s/iter: 4.858e-01, ELBO: -3.025e+06
# Cur diff delta = 201.44769287109375
# Cur diff sigma = 102.75650787353516
# Cur diff theta = 304.2042007446289
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1600, s/iter: 4.595e-01, ELBO: -3.019e+06
# Cur diff delta = 200.10093688964844
# Cur diff sigma = 102.90809631347656
# Cur diff theta = 303.009033203125
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1620, s/iter: 4.598e-01, ELBO: -3.027e+06
# Cur diff delta = 200.8280029296875
# Cur diff sigma = 102.37069702148438
# Cur diff theta = 303.1986999511719
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1640, s/iter: 4.384e-01, ELBO: -3.018e+06
# Cur diff delta = 200.4060821533203
# Cur diff sigma = 102.34693145751953
# Cur diff theta = 302.75301361083984
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1660, s/iter: 4.703e-01, ELBO: -3.019e+06
# Cur diff delta = 200.75811767578125
# Cur diff sigma = 102.29419708251953
# Cur diff theta = 303.0523147583008
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1680, s/iter: 4.540e-01, ELBO: -3.017e+06
# Cur diff delta = 201.585205078125
# Cur diff sigma = 102.7707290649414
# Cur diff theta = 304.3559341430664
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1700, s/iter: 4.379e-01, ELBO: -3.024e+06
# Cur diff delta = 201.16233825683594
# Cur diff sigma = 102.62677001953125
# Cur diff theta = 303.7891082763672
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1720, s/iter: 4.541e-01, ELBO: -3.024e+06
# Cur diff delta = 200.62860107421875
# Cur diff sigma = 102.66551971435547
# Cur diff theta = 303.2941207885742
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1740, s/iter: 4.373e-01, ELBO: -3.028e+06
# Cur diff delta = 199.8290252685547
# Cur diff sigma = 102.634521484375
# Cur diff theta = 302.4635467529297
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1760, s/iter: 4.236e-01, ELBO: -3.022e+06
# Cur diff delta = 201.14199829101562
# Cur diff sigma = 102.24595642089844
# Cur diff theta = 303.38795471191406
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1780, s/iter: 4.307e-01, ELBO: -3.017e+06
# Cur diff delta = 200.52435302734375
# Cur diff sigma = 102.55897521972656
# Cur diff theta = 303.0833282470703
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1800, s/iter: 4.449e-01, ELBO: -3.022e+06
# Cur diff delta = 200.35536193847656
# Cur diff sigma = 102.83760833740234
# Cur diff theta = 303.1929702758789
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1820, s/iter: 4.367e-01, ELBO: -3.020e+06
# Cur diff delta = 200.54208374023438
# Cur diff sigma = 102.56483459472656
# Cur diff theta = 303.10691833496094
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1840, s/iter: 4.315e-01, ELBO: -3.029e+06
# Cur diff delta = 200.29078674316406
# Cur diff sigma = 102.69542694091797
# Cur diff theta = 302.98621368408203
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1860, s/iter: 4.434e-01, ELBO: -3.018e+06
# Cur diff delta = 200.482421875
# Cur diff sigma = 102.2140884399414
# Cur diff theta = 302.6965103149414
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1880, s/iter: 4.710e-01, ELBO: -3.021e+06
# Cur diff delta = 200.4546661376953
# Cur diff sigma = 102.49822998046875
# Cur diff theta = 302.95289611816406
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1900, s/iter: 4.498e-01, ELBO: -3.017e+06
# Cur diff delta = 200.9783477783203
# Cur diff sigma = 102.40069580078125
# Cur diff theta = 303.37904357910156
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1920, s/iter: 4.490e-01, ELBO: -3.022e+06
# Cur diff delta = 201.0003204345703
# Cur diff sigma = 102.4556655883789
# Cur diff theta = 303.4559860229492
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1940, s/iter: 4.568e-01, ELBO: -3.022e+06
# Cur diff delta = 200.34661865234375
# Cur diff sigma = 102.67061614990234
# Cur diff theta = 303.0172348022461
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1960, s/iter: 4.552e-01, ELBO: -3.018e+06
# Cur diff delta = 200.48606872558594
# Cur diff sigma = 102.58538818359375
# Cur diff theta = 303.0714569091797
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-1980, s/iter: 4.398e-01, ELBO: -3.017e+06
# Cur diff delta = 200.60769653320312
# Cur diff sigma = 102.29747009277344
# Cur diff theta = 302.90516662597656
# ---------------------------------------
# HVAE_notemp_2, d: 200, Iter: 3-2000, s/iter: 4.550e-01, ELBO: -3.023e+06
# Cur diff delta = 200.0677032470703
# Cur diff sigma = 102.77435302734375
# Cur diff theta = 302.84205627441406
# ---------------------------------------
# Model HVAE_notemp_1, test = 0, result delta diff = 183.73350524902344
# Model HVAE_notemp_1, test = 0, result sigma diff = 32.314823150634766
# Model HVAE_notemp_1, test = 0, result theta diff = 216.04832458496094
# Model HVAE_notemp_1, test = 1, result delta diff = 205.05966186523438
# Model HVAE_notemp_1, test = 1, result sigma diff = 32.256832122802734
# Model HVAE_notemp_1, test = 1, result theta diff = 237.31649780273438
# Model HVAE_notemp_1, test = 2, result delta diff = 200.19508361816406
# Model HVAE_notemp_1, test = 2, result sigma diff = 32.263519287109375
# Model HVAE_notemp_1, test = 2, result theta diff = 232.45860290527344
# Model HVAE_notemp_2, test = 0, result delta diff = 183.50814819335938
# Model HVAE_notemp_2, test = 0, result sigma diff = 102.80133056640625
# Model HVAE_notemp_2, test = 0, result theta diff = 286.3094787597656
# Model HVAE_notemp_2, test = 1, result delta diff = 204.95407104492188
# Model HVAE_notemp_2, test = 1, result sigma diff = 102.28044128417969
# Model HVAE_notemp_2, test = 1, result theta diff = 307.2344970703125
# Model HVAE_notemp_2, test = 2, result delta diff = 200.0677032470703
# Model HVAE_notemp_2, test = 2, result sigma diff = 102.77435302734375
# Model HVAE_notemp_2, test = 2, result theta diff = 302.842041015625

# %%
model_names = ['HVAE_notemp_1', 'HVAE_notemp_2']
diff_delta_results = {}
diff_sigma_results = {}
diff_results = {}
for name in model_names:
    diff_delta_tests = np.zeros(params['n_tests'])
    diff_sigma_tests = np.zeros(params['n_tests'])
    diff_tests = np.zeros(params['n_tests'])
    for i in range(params['n_tests']):
        file_name = name + '_train_' + str(i) + '.p'
        diff_path = os.path.join('save', str(params['dims'][0]), file_name)
        with open(diff_path, 'rb') as f:
            data = pickle.load(f)
            elbo = data['elbo']
            diff_delta = data['diff_delta']
            diff_sigma = data['diff_sigma']
            diff = diff_delta + diff_sigma
            diff_delta_is_not_nan = diff_delta[~np.isnan(diff_delta)]
            diff_sigma_is_not_nan = diff_sigma[~np.isnan(diff_sigma)]
            diff_is_not_nan = diff[~np.isnan(diff)]
            diff_delta_tests[i] = diff_delta_is_not_nan[-1]
            diff_sigma_tests[i] = diff_sigma_is_not_nan[-1]
            diff_tests[i] = diff_is_not_nan[-1]
    diff_delta_results[name] = diff_delta_tests
    diff_sigma_results[name] = diff_sigma_tests
    diff_results[name] = diff_tests
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, diff delta = {diff_delta_tests}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, diff sigma = {diff_sigma_tests}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, diff = {diff_tests}")
# Out:
# Model = HVAE_notemp_1, dimensionality = 200, diff delta = [183.73350525 205.05963135 200.19509888]
# Model = HVAE_notemp_1, dimensionality = 200, diff sigma = [32.31481934 32.25682831 32.26351929]
# Model = HVAE_notemp_1, dimensionality = 200, diff = [216.04832458 237.31646729 232.45861816]
# Model = HVAE_notemp_2, dimensionality = 200, diff delta = [183.50814819 204.95404053 200.06770325]
# Model = HVAE_notemp_2, dimensionality = 200, diff sigma = [102.8013382  102.28044128 102.77435303]
# Model = HVAE_notemp_2, dimensionality = 200, diff = [286.30947876 307.23449707 302.84204102]

# %%
for name in model_names:
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, mean diff delta = {diff_delta_results[name].mean()}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, mean diff sigma = {diff_sigma_results[name].mean()}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, mean diff = {diff_results[name].mean()}")
# Out:
# Model = HVAE_notemp_1, dimensionality = 200, mean diff delta = 196.32941182454428
# Model = HVAE_notemp_1, dimensionality = 200, mean diff sigma = 32.27838897705078
# Model = HVAE_notemp_1, dimensionality = 200, mean diff = 228.60780334472656
# Model = HVAE_notemp_2, dimensionality = 200, mean diff delta = 196.17663065592447
# Model = HVAE_notemp_2, dimensionality = 200, mean diff sigma = 102.61871083577473
# Model = HVAE_notemp_2, dimensionality = 200, mean diff = 298.7953389485677

# %%
def run_test(d, params, 
             batch_size=256,
             clip_value=None,
             dtype=torch.float32, 
             device=torch.device("cpu")):
    """ 
    Run the gaussian test with dimension d 
    """

    ######### Problem Specification

    # Data generation parameters
    prior_mu_z = torch.zeros(d, dtype=dtype)    # Prior mean
    prior_sigma_z = torch.eye(d, dtype=dtype)   # Prior covariance matrix

    # True model parameters
    num_range = torch.arange(-(d-1)/2, (d+1)/2, dtype=dtype)

    t_delta =  num_range / 5 

    print(f"true delta = {t_delta.numpy()}")

    if d == 1:
        t_sigma = torch.ones(1, dtype=dtype)
    else: 
        # Allow sigma to range from 0.1 to 1
        t_sigma = 36/(10*(d-1)**2) * num_range**2 + 0.1 
    print(f"true sigma = {t_sigma.numpy()}")

    ######### Variable Initialization

    # Initial model parameters - same across all methods
    init_delta = prior_mu_z.clone().to(device)
    init_log_sigma = 3 * torch.ones(d).to(device)

    # Initial HVAE variational parameters
    init_T = torch.tensor(5., dtype=dtype, device=device)
    init_eps = 0.005 * torch.ones(d, dtype=dtype)
    max_eps = params['max_eps'] * torch.ones(d, dtype=dtype)
    init_logit_eps = torch.log(init_eps/(max_eps - init_eps)).to(device)
    init_log_T_0 = torch.log(init_T - 1)

    # Initial NF variational parameters
    init_u_pre_reparam = torch.tensor(scipy.stats.truncnorm.rvs(-2, 2, 
                                                                scale=0.1, 
                                                                size=d),
                                      dtype=dtype, device=device)
    init_w = torch.tensor(scipy.stats.truncnorm.rvs(-2, 2, scale=0.1, size=d),
                          dtype=dtype, device=device)
    init_b = torch.tensor(0.1, dtype=dtype, device=device)

    # Initial VAE parameters
    init_mu_z = prior_mu_z.clone()
    init_log_sigma_z = torch.ones(d, dtype=dtype)

    ######### Set up models
    init_params = [[init_delta, init_log_sigma, init_logit_eps, init_log_T_0],
                   [init_delta, init_log_sigma, init_logit_eps, init_log_T_0],
                   [init_delta, init_log_sigma, init_u_pre_reparam, init_w, init_b],
                   [init_delta, init_log_sigma, init_u_pre_reparam, init_w, init_b],
                   [init_delta, init_log_sigma, init_mu_z, init_log_sigma_z]]

    VB_model = VB(params,
        ['delta', 'log_sigma', 'mu_z', 'log_sigma_z'], 
        init_params[4], 'VB', d)

    #model_list = [HVAE_model_1, HVAE_model_2, NF_model_1]
    #model_list = [HVAE_model_1, NF_model_1]
    model_list = [VB_model]

    print("Models were initialized!")
    
    ######### Generate Training Data & Save - One for each test

    train_data_list = []

    for i in range(params['n_tests']):
        z = MultivariateNormal(prior_mu_z, prior_sigma_z).sample()
        x = MultivariateNormal(z + t_delta, 
                               torch.diag(t_sigma**2)).sample([params['n_data']])
        x = x.to(device)
        train_data_list.append(x)

    # Folder should have already been created in the initializations
    data_path = os.path.join('save', str(d), 'train_data.p')
    pickle.dump(train_data_list, open(data_path, 'wb')) 

    # Store the final parameter values for all test runs in this dictionary
    final_params = {}

    for i in range(len(model_list)):
        final_values = []
        m = model_list[i]
        model_init_params = init_params[i]

        for j in range(params['n_tests']):
            print("------------------------------------------------------")
            print(f"Test = {j}")
            print("------------------------------------------------------")
            m._reinitialize(model_init_params)
            gaussian_data = gaussian_dataset(train_data_list[j])
            train_dataloader = DataLoader(gaussian_data, batch_size=batch_size,
                                          shuffle=False, num_workers=0)
            (delta, sigma) = m.train(train_dataloader, j, 
                                     t_delta, t_sigma,
                                     clip_value)
            final_values.append((delta, sigma))

        final_params[m.model_name] = final_values.copy()

    ######### Test models using difference between parameters

    param_diffs = {}

    for m in model_list:
        
        diffs = []

        for i in range(params['n_tests']):
            delta = final_params[m.model_name][i][0]
            sigma = final_params[m.model_name][i][1]

            delta_diff = np.sum((delta - t_delta.numpy())**2)
            sigma_diff = np.sum((sigma - t_sigma.numpy())**2)
            theta_diff = delta_diff + sigma_diff
            print(f"Model {m.model_name}, test = {i}, result delta diff = {delta_diff}")
            print(f"Model {m.model_name}, test = {i}, result sigma diff = {sigma_diff}")
            print(f"Model {m.model_name}, test = {i}, result theta diff = {theta_diff}")

            diffs.append((delta_diff, sigma_diff, theta_diff))

        param_diffs[m.model_name] = diffs.copy()

    # Save parameter differences in a pickle file
    diff_path = os.path.join('save', str(d), 'all_diffs.p')
    pickle.dump(param_diffs, open(diff_path, 'wb'))

# %%
device = torch.device("cuda")
dtype = torch.float32
clip_value = None
batch_size = 256

# %%
params = {

    # PROBLEM SPECIFICATION
    #'dims': [1, 2, 3, 5, 11, 25, 51, 101, 201, 301], # Dimensions to test
    'dims': [400],
    'n_data': 10000,                                 # Number of data points

    # TEST HYPERPARAMETERS
    'n_tests': 3,      # Number of experiments to run

    # GLOBAL OPTIMIZATION PARAMETERS
    'n_iter': 5000,    # Number of optimization iterations
    'n_batch': 10,      # Number of points for ELBO estimate
    'rms_eta': 0.001,   # Stepsize for RMSProp
    'save_every': 20,   # Save parameter information every so often
    'print_every': 20, # Print less often than save

    # HVAE HYPERPARAMETERS
    'HVAE_K_1': 1,    # Number of leapfrog/cooling steps for HVAE flow 1
    'HVAE_K_2': 10,   # Number of leapfrog/cooling steps for HVAE flow 2
    'max_eps': 0.5,   # Maximum leapfrog step size per dimension 

    # NF HYPERPARAMETERS
    'NF_K_1': 1,    # Number of flow steps for NF flow 1
    'NF_K_2': 30,   # Number of flow steps for NF flow 2
    
}

# %%
dims = params['dims']
seed = 12345
np.random.seed(seed)
torch.manual_seed(seed)
for d in dims:
    print('**** Running test for d={0:d} ****'.format(d))
    run_test(d, params, batch_size, clip_value, dtype, device)
# Out:
# **** Running test for d=400 ****
# true delta = [-39.9 -39.7 -39.5 -39.3 -39.1 -38.9 -38.7 -38.5 -38.3 -38.1 -37.9 -37.7
#  -37.5 -37.3 -37.1 -36.9 -36.7 -36.5 -36.3 -36.1 -35.9 -35.7 -35.5 -35.3
#  -35.1 -34.9 -34.7 -34.5 -34.3 -34.1 -33.9 -33.7 -33.5 -33.3 -33.1 -32.9
#  -32.7 -32.5 -32.3 -32.1 -31.9 -31.7 -31.5 -31.3 -31.1 -30.9 -30.7 -30.5
#  -30.3 -30.1 -29.9 -29.7 -29.5 -29.3 -29.1 -28.9 -28.7 -28.5 -28.3 -28.1
#  -27.9 -27.7 -27.5 -27.3 -27.1 -26.9 -26.7 -26.5 -26.3 -26.1 -25.9 -25.7
#  -25.5 -25.3 -25.1 -24.9 -24.7 -24.5 -24.3 -24.1 -23.9 -23.7 -23.5 -23.3
#  -23.1 -22.9 -22.7 -22.5 -22.3 -22.1 -21.9 -21.7 -21.5 -21.3 -21.1 -20.9
#  -20.7 -20.5 -20.3 -20.1 -19.9 -19.7 -19.5 -19.3 -19.1 -18.9 -18.7 -18.5
#  -18.3 -18.1 -17.9 -17.7 -17.5 -17.3 -17.1 -16.9 -16.7 -16.5 -16.3 -16.1
#  -15.9 -15.7 -15.5 -15.3 -15.1 -14.9 -14.7 -14.5 -14.3 -14.1 -13.9 -13.7
#  -13.5 -13.3 -13.1 -12.9 -12.7 -12.5 -12.3 -12.1 -11.9 -11.7 -11.5 -11.3
#  -11.1 -10.9 -10.7 -10.5 -10.3 -10.1  -9.9  -9.7  -9.5  -9.3  -9.1  -8.9
#   -8.7  -8.5  -8.3  -8.1  -7.9  -7.7  -7.5  -7.3  -7.1  -6.9  -6.7  -6.5
#   -6.3  -6.1  -5.9  -5.7  -5.5  -5.3  -5.1  -4.9  -4.7  -4.5  -4.3  -4.1
#   -3.9  -3.7  -3.5  -3.3  -3.1  -2.9  -2.7  -2.5  -2.3  -2.1  -1.9  -1.7
#   -1.5  -1.3  -1.1  -0.9  -0.7  -0.5  -0.3  -0.1   0.1   0.3   0.5   0.7
#    0.9   1.1   1.3   1.5   1.7   1.9   2.1   2.3   2.5   2.7   2.9   3.1
#    3.3   3.5   3.7   3.9   4.1   4.3   4.5   4.7   4.9   5.1   5.3   5.5
#    5.7   5.9   6.1   6.3   6.5   6.7   6.9   7.1   7.3   7.5   7.7   7.9
#    8.1   8.3   8.5   8.7   8.9   9.1   9.3   9.5   9.7   9.9  10.1  10.3
#   10.5  10.7  10.9  11.1  11.3  11.5  11.7  11.9  12.1  12.3  12.5  12.7
#   12.9  13.1  13.3  13.5  13.7  13.9  14.1  14.3  14.5  14.7  14.9  15.1
#   15.3  15.5  15.7  15.9  16.1  16.3  16.5  16.7  16.9  17.1  17.3  17.5
#   17.7  17.9  18.1  18.3  18.5  18.7  18.9  19.1  19.3  19.5  19.7  19.9
#   20.1  20.3  20.5  20.7  20.9  21.1  21.3  21.5  21.7  21.9  22.1  22.3
#   22.5  22.7  22.9  23.1  23.3  23.5  23.7  23.9  24.1  24.3  24.5  24.7
#   24.9  25.1  25.3  25.5  25.7  25.9  26.1  26.3  26.5  26.7  26.9  27.1
#   27.3  27.5  27.7  27.9  28.1  28.3  28.5  28.7  28.9  29.1  29.3  29.5
#   29.7  29.9  30.1  30.3  30.5  30.7  30.9  31.1  31.3  31.5  31.7  31.9
#   32.1  32.3  32.5  32.7  32.9  33.1  33.3  33.5  33.7  33.9  34.1  34.3
#   34.5  34.7  34.9  35.1  35.3  35.5  35.7  35.9  36.1  36.3  36.5  36.7
#   36.9  37.1  37.3  37.5  37.7  37.9  38.1  38.3  38.5  38.7  38.9  39.1
#   39.3  39.5  39.7  39.9]
# true sigma = [1.         0.99100006 0.98204535 0.9731359  0.9642716  0.95545256
#  0.94667876 0.93795013 0.9292668  0.92062867 0.91203576 0.90348804
#  0.8949856  0.8865284  0.87811637 0.8697496  0.861428   0.8531517
#  0.8449206  0.8367347  0.8285941  0.82049865 0.81244844 0.8044435
#  0.7964837  0.7885692  0.7806999  0.77287585 0.76509696 0.7573634
#  0.749675   0.7420318  0.7344338  0.72688115 0.71937364 0.7119114
#  0.70449436 0.6971225  0.6897959  0.6825146  0.6752784  0.66808754
#  0.66094184 0.6538414  0.64678615 0.6397762  0.63281137 0.6258918
#  0.6190175  0.6121884  0.6054045  0.59866583 0.5919724  0.5853242
#  0.5787212  0.5721635  0.565651   0.55918366 0.5527616  0.54638475
#  0.5400531  0.53376675 0.5275256  0.52132964 0.5151789  0.50907344
#  0.5030132  0.49699813 0.4910283  0.48510373 0.47922438 0.47339022
#  0.46760133 0.46185765 0.45615917 0.45050594 0.44489795 0.43933517
#  0.43381763 0.4283453  0.4229182  0.41753632 0.41219968 0.40690824
#  0.40166205 0.39646107 0.39130533 0.3861948  0.3811295  0.37610945
#  0.3711346  0.36620498 0.36132059 0.35648143 0.3516875  0.3469388
#  0.3422353  0.33757702 0.332964   0.32839617 0.3238736  0.31939623
#  0.31496412 0.31057718 0.30623552 0.30193907 0.29768783 0.29348183
#  0.28932104 0.28520548 0.28113517 0.27711007 0.2731302  0.26919556
#  0.26530612 0.2614619  0.25766295 0.2539092  0.2502007  0.24653739
#  0.24291933 0.23934647 0.23581886 0.23233649 0.22889933 0.22550738
#  0.22216067 0.21885918 0.21560292 0.21239188 0.20922607 0.2061055
#  0.20303014 0.2        0.19701509 0.1940754  0.19118096 0.18833172
#  0.18552773 0.18276896 0.18005541 0.17738709 0.17476398 0.1721861
#  0.16965346 0.16716604 0.16472384 0.16232687 0.15997513 0.1576686
#  0.15540731 0.15319125 0.15102041 0.14889479 0.1468144  0.14477924
#  0.1427893  0.1408446  0.1389451  0.13709085 0.13528182 0.13351801
#  0.13179943 0.13012607 0.12849794 0.12691504 0.12537736 0.1238849
#  0.12243767 0.12103567 0.1196789  0.11836734 0.11710103 0.11587992
#  0.11470406 0.11357341 0.11248799 0.1114478  0.11045282 0.10950308
#  0.10859857 0.10773928 0.10692521 0.10615637 0.10543276 0.10475437
#  0.10412121 0.10353327 0.10299056 0.10249308 0.10204082 0.10163379
#  0.10127198 0.1009554  0.10068404 0.10045791 0.10027701 0.10014133
#  0.10005088 0.10000566 0.10000566 0.10005088 0.10014133 0.10027701
#  0.10045791 0.10068404 0.1009554  0.10127198 0.10163379 0.10204082
#  0.10249308 0.10299056 0.10353327 0.10412121 0.10475437 0.10543276
#  0.10615637 0.10692521 0.10773928 0.10859857 0.10950308 0.11045282
#  0.1114478  0.11248799 0.11357341 0.11470406 0.11587992 0.11710103
#  0.11836734 0.1196789  0.12103567 0.12243767 0.1238849  0.12537736
#  0.12691504 0.12849794 0.13012607 0.13179943 0.13351801 0.13528182
#  0.13709085 0.1389451  0.1408446  0.1427893  0.14477924 0.1468144
#  0.14889479 0.15102041 0.15319125 0.15540731 0.1576686  0.15997513
#  0.16232687 0.16472384 0.16716604 0.16965346 0.1721861  0.17476398
#  0.17738709 0.18005541 0.18276896 0.18552773 0.18833172 0.19118096
#  0.1940754  0.19701509 0.2        0.20303014 0.2061055  0.20922607
#  0.21239188 0.21560292 0.21885918 0.22216067 0.22550738 0.22889933
#  0.23233649 0.23581886 0.23934647 0.24291933 0.24653739 0.2502007
#  0.2539092  0.25766295 0.2614619  0.26530612 0.26919556 0.2731302
#  0.27711007 0.28113517 0.28520548 0.28932104 0.29348183 0.29768783
#  0.30193907 0.30623552 0.31057718 0.31496412 0.31939623 0.3238736
#  0.32839617 0.332964   0.33757702 0.3422353  0.3469388  0.3516875
#  0.35648143 0.36132059 0.36620498 0.3711346  0.37610945 0.3811295
#  0.3861948  0.39130533 0.39646107 0.40166205 0.40690824 0.41219968
#  0.41753632 0.4229182  0.4283453  0.43381763 0.43933517 0.44489795
#  0.45050594 0.45615917 0.46185765 0.46760133 0.47339022 0.47922438
#  0.48510373 0.4910283  0.49699813 0.5030132  0.50907344 0.5151789
#  0.52132964 0.5275256  0.53376675 0.5400531  0.54638475 0.5527616
#  0.55918366 0.565651   0.5721635  0.5787212  0.5853242  0.5919724
#  0.59866583 0.6054045  0.6121884  0.6190175  0.6258918  0.63281137
#  0.6397762  0.64678615 0.6538414  0.66094184 0.66808754 0.6752784
#  0.6825146  0.6897959  0.6971225  0.70449436 0.7119114  0.71937364
#  0.72688115 0.7344338  0.7420318  0.749675   0.7573634  0.76509696
#  0.77287585 0.7806999  0.7885692  0.7964837  0.8044435  0.81244844
#  0.82049865 0.8285941  0.8367347  0.8449206  0.8531517  0.861428
#  0.8697496  0.87811637 0.8865284  0.8949856  0.90348804 0.91203576
#  0.92062867 0.9292668  0.93795013 0.94667876 0.95545256 0.9642716
#  0.9731359  0.98204535 0.99100006 1.        ]
# Models were initialized!
# ------------------------------------------------------
# Test = 0
# ------------------------------------------------------
# Init diff delta = 213331.984375
# Init diff sigma = 155013.546875
# Init diff theta = 368345.53125
# VB, d: 400, Iter: 1-20, s/iter: 1.164e-01, ELBO: -1.686e+07
# Cur diff delta = 199718.609375
# Cur diff sigma = 188683.578125
# Cur diff theta = 388402.1875
# ---------------------------------------
# VB, d: 400, Iter: 1-40, s/iter: 1.242e-01, ELBO: -1.594e+07
# Cur diff delta = 187819.921875
# Cur diff sigma = 166922.25
# Cur diff theta = 354742.171875
# ---------------------------------------
# VB, d: 400, Iter: 1-60, s/iter: 1.226e-01, ELBO: -1.495e+07
# Cur diff delta = 176336.1875
# Cur diff sigma = 146007.578125
# Cur diff theta = 322343.765625
# ---------------------------------------
# VB, d: 400, Iter: 1-80, s/iter: 1.261e-01, ELBO: -1.379e+07
# Cur diff delta = 165392.6875
# Cur diff sigma = 127567.515625
# Cur diff theta = 292960.203125
# ---------------------------------------
# VB, d: 400, Iter: 1-100, s/iter: 1.385e-01, ELBO: -1.253e+07
# Cur diff delta = 155053.9375
# Cur diff sigma = 110945.1953125
# Cur diff theta = 265999.1328125
# ---------------------------------------
# VB, d: 400, Iter: 1-120, s/iter: 1.285e-01, ELBO: -1.134e+07
# Cur diff delta = 145272.5625
# Cur diff sigma = 95933.890625
# Cur diff theta = 241206.453125
# ---------------------------------------
# VB, d: 400, Iter: 1-140, s/iter: 1.241e-01, ELBO: -1.049e+07
# Cur diff delta = 136027.75
# Cur diff sigma = 82400.1328125
# Cur diff theta = 218427.8828125
# ---------------------------------------
# VB, d: 400, Iter: 1-160, s/iter: 1.211e-01, ELBO: -9.756e+06
# Cur diff delta = 127279.46875
# Cur diff sigma = 70248.7109375
# Cur diff theta = 197528.1796875
# ---------------------------------------
# VB, d: 400, Iter: 1-180, s/iter: 1.169e-01, ELBO: -9.059e+06
# Cur diff delta = 119011.5703125
# Cur diff sigma = 59391.296875
# Cur diff theta = 178402.8671875
# ---------------------------------------
# VB, d: 400, Iter: 1-200, s/iter: 1.168e-01, ELBO: -8.380e+06
# Cur diff delta = 111215.40625
# Cur diff sigma = 49747.90234375
# Cur diff theta = 160963.30859375
# ---------------------------------------
# VB, d: 400, Iter: 1-220, s/iter: 1.190e-01, ELBO: -7.732e+06
# Cur diff delta = 103919.328125
# Cur diff sigma = 41238.1640625
# Cur diff theta = 145157.4921875
# ---------------------------------------
# VB, d: 400, Iter: 1-240, s/iter: 1.187e-01, ELBO: -7.151e+06
# Cur diff delta = 97130.90625
# Cur diff sigma = 33780.71484375
# Cur diff theta = 130911.62109375
# ---------------------------------------
# VB, d: 400, Iter: 1-260, s/iter: 1.201e-01, ELBO: -6.578e+06
# Cur diff delta = 90781.015625
# Cur diff sigma = 27308.998046875
# Cur diff theta = 118090.013671875
# ---------------------------------------
# VB, d: 400, Iter: 1-280, s/iter: 1.169e-01, ELBO: -5.992e+06
# Cur diff delta = 84851.703125
# Cur diff sigma = 21762.74609375
# Cur diff theta = 106614.44921875
# ---------------------------------------
# VB, d: 400, Iter: 1-300, s/iter: 1.175e-01, ELBO: -5.437e+06
# Cur diff delta = 79390.46875
# Cur diff sigma = 17064.876953125
# Cur diff theta = 96455.345703125
# ---------------------------------------
# VB, d: 400, Iter: 1-320, s/iter: 1.255e-01, ELBO: -4.974e+06
# Cur diff delta = 74422.984375
# Cur diff sigma = 13124.244140625
# Cur diff theta = 87547.228515625
# ---------------------------------------
# VB, d: 400, Iter: 1-340, s/iter: 1.155e-01, ELBO: -4.570e+06
# Cur diff delta = 69871.9375
# Cur diff sigma = 9865.0771484375
# Cur diff theta = 79737.0146484375
# ---------------------------------------
# VB, d: 400, Iter: 1-360, s/iter: 1.198e-01, ELBO: -4.119e+06
# Cur diff delta = 65647.1640625
# Cur diff sigma = 7238.11376953125
# Cur diff theta = 72885.27783203125
# ---------------------------------------
# VB, d: 400, Iter: 1-380, s/iter: 1.305e-01, ELBO: -3.696e+06
# Cur diff delta = 61857.00390625
# Cur diff sigma = 5171.98876953125
# Cur diff theta = 67028.99267578125
# ---------------------------------------
# VB, d: 400, Iter: 1-400, s/iter: 1.181e-01, ELBO: -3.345e+06
# Cur diff delta = 58483.40625
# Cur diff sigma = 3574.760498046875
# Cur diff theta = 62058.166748046875
# ---------------------------------------
# VB, d: 400, Iter: 1-420, s/iter: 1.181e-01, ELBO: -3.025e+06
# Cur diff delta = 55462.94921875
# Cur diff sigma = 2374.90185546875
# Cur diff theta = 57837.85107421875
# ---------------------------------------
# VB, d: 400, Iter: 1-440, s/iter: 1.218e-01, ELBO: -2.765e+06
# Cur diff delta = 52809.83203125
# Cur diff sigma = 1496.8870849609375
# Cur diff theta = 54306.71911621094
# ---------------------------------------
# VB, d: 400, Iter: 1-460, s/iter: 1.211e-01, ELBO: -2.544e+06
# Cur diff delta = 50435.83984375
# Cur diff sigma = 875.540771484375
# Cur diff theta = 51311.380615234375
# ---------------------------------------
# VB, d: 400, Iter: 1-480, s/iter: 1.261e-01, ELBO: -2.372e+06
# Cur diff delta = 48338.83984375
# Cur diff sigma = 455.59210205078125
# Cur diff theta = 48794.43194580078
# ---------------------------------------
# VB, d: 400, Iter: 1-500, s/iter: 1.188e-01, ELBO: -2.219e+06
# Cur diff delta = 46431.96484375
# Cur diff sigma = 193.00294494628906
# Cur diff theta = 46624.96778869629
# ---------------------------------------
# VB, d: 400, Iter: 1-520, s/iter: 1.321e-01, ELBO: -2.063e+06
# Cur diff delta = 44676.62109375
# Cur diff sigma = 58.593292236328125
# Cur diff theta = 44735.21438598633
# ---------------------------------------
# VB, d: 400, Iter: 1-540, s/iter: 1.170e-01, ELBO: -1.943e+06
# Cur diff delta = 43119.53515625
# Cur diff sigma = 9.903303146362305
# Cur diff theta = 43129.43845939636
# ---------------------------------------
# VB, d: 400, Iter: 1-560, s/iter: 1.168e-01, ELBO: -1.876e+06
# Cur diff delta = 41745.60546875
# Cur diff sigma = 0.6704584956169128
# Cur diff theta = 41746.27592724562
# ---------------------------------------
# VB, d: 400, Iter: 1-580, s/iter: 1.193e-01, ELBO: -1.845e+06
# Cur diff delta = 40489.75390625
# Cur diff sigma = 0.0051080090925097466
# Cur diff theta = 40489.75901425909
# ---------------------------------------
# VB, d: 400, Iter: 1-600, s/iter: 1.220e-01, ELBO: -1.821e+06
# Cur diff delta = 39279.7578125
# Cur diff sigma = 0.0048300763592123985
# Cur diff theta = 39279.76264257636
# ---------------------------------------
# VB, d: 400, Iter: 1-620, s/iter: 1.227e-01, ELBO: -1.797e+06
# Cur diff delta = 38106.4453125
# Cur diff sigma = 0.00482552032917738
# Cur diff theta = 38106.45013802033
# ---------------------------------------
# VB, d: 400, Iter: 1-640, s/iter: 1.209e-01, ELBO: -1.774e+06
# Cur diff delta = 36970.3828125
# Cur diff sigma = 0.0048210532404482365
# Cur diff theta = 36970.38763355324
# ---------------------------------------
# VB, d: 400, Iter: 1-660, s/iter: 1.176e-01, ELBO: -1.752e+06
# Cur diff delta = 35870.4921875
# Cur diff sigma = 0.004817040637135506
# Cur diff theta = 35870.49700454064
# ---------------------------------------
# VB, d: 400, Iter: 1-680, s/iter: 1.190e-01, ELBO: -1.730e+06
# Cur diff delta = 34805.71875
# Cur diff sigma = 0.004813334904611111
# Cur diff theta = 34805.723563334905
# ---------------------------------------
# VB, d: 400, Iter: 1-700, s/iter: 1.243e-01, ELBO: -1.710e+06
# Cur diff delta = 33775.0078125
# Cur diff sigma = 0.004809378646314144
# Cur diff theta = 33775.012621878646
# ---------------------------------------
# VB, d: 400, Iter: 1-720, s/iter: 1.204e-01, ELBO: -1.690e+06
# Cur diff delta = 32777.37890625
# Cur diff sigma = 0.0048062787391245365
# Cur diff theta = 32777.38371252874
# ---------------------------------------
# VB, d: 400, Iter: 1-740, s/iter: 1.174e-01, ELBO: -1.670e+06
# Cur diff delta = 31811.8125
# Cur diff sigma = 0.004802754148840904
# Cur diff theta = 31811.81730275415
# ---------------------------------------
# VB, d: 400, Iter: 1-760, s/iter: 1.179e-01, ELBO: -1.651e+06
# Cur diff delta = 30877.353515625
# Cur diff sigma = 0.0047995117492973804
# Cur diff theta = 30877.35831513675
# ---------------------------------------
# VB, d: 400, Iter: 1-780, s/iter: 1.212e-01, ELBO: -1.633e+06
# Cur diff delta = 29973.04296875
# Cur diff sigma = 0.004796383436769247
# Cur diff theta = 29973.047765133437
# ---------------------------------------
# VB, d: 400, Iter: 1-800, s/iter: 1.182e-01, ELBO: -1.615e+06
# Cur diff delta = 29097.9609375
# Cur diff sigma = 0.00479339063167572
# Cur diff theta = 29097.96573089063
# ---------------------------------------
# VB, d: 400, Iter: 1-820, s/iter: 1.292e-01, ELBO: -1.598e+06
# Cur diff delta = 28251.203125
# Cur diff sigma = 0.00479055754840374
# Cur diff theta = 28251.20791555755
# ---------------------------------------
# VB, d: 400, Iter: 1-840, s/iter: 1.293e-01, ELBO: -1.582e+06
# Cur diff delta = 27431.865234375
# Cur diff sigma = 0.0047878120094537735
# Cur diff theta = 27431.87002218701
# ---------------------------------------
# VB, d: 400, Iter: 1-860, s/iter: 1.164e-01, ELBO: -1.565e+06
# Cur diff delta = 26639.1015625
# Cur diff sigma = 0.0047853244468569756
# Cur diff theta = 26639.106347824447
# ---------------------------------------
# VB, d: 400, Iter: 1-880, s/iter: 1.196e-01, ELBO: -1.550e+06
# Cur diff delta = 25872.064453125
# Cur diff sigma = 0.004782950505614281
# Cur diff theta = 25872.069236075506
# ---------------------------------------
# VB, d: 400, Iter: 1-900, s/iter: 1.204e-01, ELBO: -1.535e+06
# Cur diff delta = 25129.9296875
# Cur diff sigma = 0.0047808075323700905
# Cur diff theta = 25129.934468307532
# ---------------------------------------
# VB, d: 400, Iter: 1-920, s/iter: 1.178e-01, ELBO: -1.520e+06
# Cur diff delta = 24411.8984375
# Cur diff sigma = 0.004778504371643066
# Cur diff theta = 24411.90321600437
# ---------------------------------------
# VB, d: 400, Iter: 1-940, s/iter: 1.182e-01, ELBO: -1.506e+06
# Cur diff delta = 23717.1875
# Cur diff sigma = 0.0047762165777385235
# Cur diff theta = 23717.192276216578
# ---------------------------------------
# VB, d: 400, Iter: 1-960, s/iter: 1.164e-01, ELBO: -1.493e+06
# Cur diff delta = 23045.052734375
# Cur diff sigma = 0.004774362314492464
# Cur diff theta = 23045.057508737314
# ---------------------------------------
# VB, d: 400, Iter: 1-980, s/iter: 1.245e-01, ELBO: -1.480e+06
# Cur diff delta = 22394.732421875
# Cur diff sigma = 0.004772716201841831
# Cur diff theta = 22394.737194591202
# ---------------------------------------
# VB, d: 400, Iter: 1-1000, s/iter: 1.172e-01, ELBO: -1.467e+06
# Cur diff delta = 21765.52734375
# Cur diff sigma = 0.0047708675265312195
# Cur diff theta = 21765.532114617527
# ---------------------------------------
# VB, d: 400, Iter: 1-1020, s/iter: 1.178e-01, ELBO: -1.455e+06
# Cur diff delta = 21156.744140625
# Cur diff sigma = 0.004769006744027138
# Cur diff theta = 21156.748909631744
# ---------------------------------------
# VB, d: 400, Iter: 1-1040, s/iter: 1.186e-01, ELBO: -1.443e+06
# Cur diff delta = 20567.69140625
# Cur diff sigma = 0.0047674840316176414
# Cur diff theta = 20567.69617373403
# ---------------------------------------
# VB, d: 400, Iter: 1-1060, s/iter: 1.167e-01, ELBO: -1.431e+06
# Cur diff delta = 19997.732421875
# Cur diff sigma = 0.004765984136611223
# Cur diff theta = 19997.737187859137
# ---------------------------------------
# VB, d: 400, Iter: 1-1080, s/iter: 1.178e-01, ELBO: -1.420e+06
# Cur diff delta = 19446.212890625
# Cur diff sigma = 0.0047644954174757
# Cur diff theta = 19446.217655120417
# ---------------------------------------
# VB, d: 400, Iter: 1-1100, s/iter: 1.166e-01, ELBO: -1.409e+06
# Cur diff delta = 18912.51953125
# Cur diff sigma = 0.004763186443597078
# Cur diff theta = 18912.524294436444
# ---------------------------------------
# VB, d: 400, Iter: 1-1120, s/iter: 1.180e-01, ELBO: -1.399e+06
# Cur diff delta = 18396.05078125
# Cur diff sigma = 0.004761622752994299
# Cur diff theta = 18396.055542872753
# ---------------------------------------
# VB, d: 400, Iter: 1-1140, s/iter: 1.280e-01, ELBO: -1.388e+06
# Cur diff delta = 17896.236328125
# Cur diff sigma = 0.004760408774018288
# Cur diff theta = 17896.241088533774
# ---------------------------------------
# VB, d: 400, Iter: 1-1160, s/iter: 1.202e-01, ELBO: -1.379e+06
# Cur diff delta = 17412.501953125
# Cur diff sigma = 0.004759293049573898
# Cur diff theta = 17412.50671241805
# ---------------------------------------
# VB, d: 400, Iter: 1-1180, s/iter: 1.209e-01, ELBO: -1.369e+06
# Cur diff delta = 16944.3125
# Cur diff sigma = 0.004757982678711414
# Cur diff theta = 16944.31725798268
# ---------------------------------------
# VB, d: 400, Iter: 1-1200, s/iter: 1.233e-01, ELBO: -1.360e+06
# Cur diff delta = 16491.1328125
# Cur diff sigma = 0.004757069516927004
# Cur diff theta = 16491.137569569517
# ---------------------------------------
# VB, d: 400, Iter: 1-1220, s/iter: 1.196e-01, ELBO: -1.351e+06
# Cur diff delta = 16052.451171875
# Cur diff sigma = 0.004755998030304909
# Cur diff theta = 16052.45592787303
# ---------------------------------------
# VB, d: 400, Iter: 1-1240, s/iter: 1.181e-01, ELBO: -1.342e+06
# Cur diff delta = 15627.779296875
# Cur diff sigma = 0.0047550564631819725
# Cur diff theta = 15627.784051931463
# ---------------------------------------
# VB, d: 400, Iter: 1-1260, s/iter: 1.269e-01, ELBO: -1.334e+06
# Cur diff delta = 15216.63671875
# Cur diff sigma = 0.0047541409730911255
# Cur diff theta = 15216.641472890973
# ---------------------------------------
# VB, d: 400, Iter: 1-1280, s/iter: 1.203e-01, ELBO: -1.326e+06
# Cur diff delta = 14818.560546875
# Cur diff sigma = 0.004753277637064457
# Cur diff theta = 14818.565300152637
# ---------------------------------------
# VB, d: 400, Iter: 1-1300, s/iter: 1.171e-01, ELBO: -1.318e+06
# Cur diff delta = 14433.103515625
# Cur diff sigma = 0.004752433858811855
# Cur diff theta = 14433.108268058859
# ---------------------------------------
# VB, d: 400, Iter: 1-1320, s/iter: 1.250e-01, ELBO: -1.311e+06
# Cur diff delta = 14059.8349609375
# Cur diff sigma = 0.00475153885781765
# Cur diff theta = 14059.839712476358
# ---------------------------------------
# VB, d: 400, Iter: 1-1340, s/iter: 1.209e-01, ELBO: -1.303e+06
# Cur diff delta = 13698.3427734375
# Cur diff sigma = 0.004750896245241165
# Cur diff theta = 13698.347524333745
# ---------------------------------------
# VB, d: 400, Iter: 1-1360, s/iter: 1.235e-01, ELBO: -1.296e+06
# Cur diff delta = 13348.2177734375
# Cur diff sigma = 0.0047501916997134686
# Cur diff theta = 13348.2225236292
# ---------------------------------------
# VB, d: 400, Iter: 1-1380, s/iter: 1.218e-01, ELBO: -1.289e+06
# Cur diff delta = 13009.06640625
# Cur diff sigma = 0.004749468062072992
# Cur diff theta = 13009.071155718062
# ---------------------------------------
# VB, d: 400, Iter: 1-1400, s/iter: 1.214e-01, ELBO: -1.283e+06
# Cur diff delta = 12680.5244140625
# Cur diff sigma = 0.004748854786157608
# Cur diff theta = 12680.529162917286
# ---------------------------------------
# VB, d: 400, Iter: 1-1420, s/iter: 1.216e-01, ELBO: -1.276e+06
# Cur diff delta = 12362.2138671875
# Cur diff sigma = 0.004748174920678139
# Cur diff theta = 12362.21861536242
# ---------------------------------------
# VB, d: 400, Iter: 1-1440, s/iter: 1.202e-01, ELBO: -1.270e+06
# Cur diff delta = 12053.796875
# Cur diff sigma = 0.004747578874230385
# Cur diff theta = 12053.801622578874
# ---------------------------------------
# VB, d: 400, Iter: 1-1460, s/iter: 1.184e-01, ELBO: -1.264e+06
# Cur diff delta = 11754.9296875
# Cur diff sigma = 0.004747134167701006
# Cur diff theta = 11754.934434634168
# ---------------------------------------
# VB, d: 400, Iter: 1-1480, s/iter: 1.356e-01, ELBO: -1.258e+06
# Cur diff delta = 11465.28515625
# Cur diff sigma = 0.004746456164866686
# Cur diff theta = 11465.289902706165
# ---------------------------------------
# VB, d: 400, Iter: 1-1500, s/iter: 1.203e-01, ELBO: -1.252e+06
# Cur diff delta = 11184.548828125
# Cur diff sigma = 0.004746014252305031
# Cur diff theta = 11184.553574139252
# ---------------------------------------
# VB, d: 400, Iter: 1-1520, s/iter: 1.181e-01, ELBO: -1.247e+06
# Cur diff delta = 10912.4169921875
# Cur diff sigma = 0.004745613783597946
# Cur diff theta = 10912.421737801284
# ---------------------------------------
# VB, d: 400, Iter: 1-1540, s/iter: 1.187e-01, ELBO: -1.241e+06
# Cur diff delta = 10648.5947265625
# Cur diff sigma = 0.004745048936456442
# Cur diff theta = 10648.599471611436
# ---------------------------------------
# VB, d: 400, Iter: 1-1560, s/iter: 1.341e-01, ELBO: -1.236e+06
# Cur diff delta = 10392.794921875
# Cur diff sigma = 0.004744639620184898
# Cur diff theta = 10392.79966651462
# ---------------------------------------
# VB, d: 400, Iter: 1-1580, s/iter: 1.165e-01, ELBO: -1.231e+06
# Cur diff delta = 10144.7509765625
# Cur diff sigma = 0.004744342528283596
# Cur diff theta = 10144.755720905028
# ---------------------------------------
# VB, d: 400, Iter: 1-1600, s/iter: 1.188e-01, ELBO: -1.226e+06
# Cur diff delta = 9904.2001953125
# Cur diff sigma = 0.004743906203657389
# Cur diff theta = 9904.204939218704
# ---------------------------------------
# VB, d: 400, Iter: 1-1620, s/iter: 1.182e-01, ELBO: -1.221e+06
# Cur diff delta = 9670.87890625
# Cur diff sigma = 0.00474353926256299
# Cur diff theta = 9670.883649789263
# ---------------------------------------
# VB, d: 400, Iter: 1-1640, s/iter: 1.224e-01, ELBO: -1.217e+06
# Cur diff delta = 9444.548828125
# Cur diff sigma = 0.0047432249411940575
# Cur diff theta = 9444.553571349941
# ---------------------------------------
# VB, d: 400, Iter: 1-1660, s/iter: 1.181e-01, ELBO: -1.212e+06
# Cur diff delta = 9224.9765625
# Cur diff sigma = 0.004742834251374006
# Cur diff theta = 9224.981305334251
# ---------------------------------------
# VB, d: 400, Iter: 1-1680, s/iter: 1.198e-01, ELBO: -1.208e+06
# Cur diff delta = 9011.927734375
# Cur diff sigma = 0.004742583259940147
# Cur diff theta = 9011.93247695826
# ---------------------------------------
# VB, d: 400, Iter: 1-1700, s/iter: 1.186e-01, ELBO: -1.204e+06
# Cur diff delta = 8805.1884765625
# Cur diff sigma = 0.004742265213280916
# Cur diff theta = 8805.193218827713
# ---------------------------------------
# VB, d: 400, Iter: 1-1720, s/iter: 1.192e-01, ELBO: -1.199e+06
# Cur diff delta = 8604.54296875
# Cur diff sigma = 0.0047418661415576935
# Cur diff theta = 8604.547710616142
# ---------------------------------------
# VB, d: 400, Iter: 1-1740, s/iter: 1.208e-01, ELBO: -1.195e+06
# Cur diff delta = 8409.783203125
# Cur diff sigma = 0.004741725046187639
# Cur diff theta = 8409.787944850046
# ---------------------------------------
# VB, d: 400, Iter: 1-1760, s/iter: 1.202e-01, ELBO: -1.192e+06
# Cur diff delta = 8220.7197265625
# Cur diff sigma = 0.004741430748254061
# Cur diff theta = 8220.724467993248
# ---------------------------------------
# VB, d: 400, Iter: 1-1780, s/iter: 1.187e-01, ELBO: -1.188e+06
# Cur diff delta = 8037.154296875
# Cur diff sigma = 0.004741214215755463
# Cur diff theta = 8037.159038089216
# ---------------------------------------
# VB, d: 400, Iter: 1-1800, s/iter: 1.253e-01, ELBO: -1.184e+06
# Cur diff delta = 7858.9072265625
# Cur diff sigma = 0.004741026554256678
# Cur diff theta = 7858.911967589054
# ---------------------------------------
# VB, d: 400, Iter: 1-1820, s/iter: 1.186e-01, ELBO: -1.181e+06
# Cur diff delta = 7685.8017578125
# Cur diff sigma = 0.0047407909296453
# Cur diff theta = 7685.80649860343
# ---------------------------------------
# VB, d: 400, Iter: 1-1840, s/iter: 1.182e-01, ELBO: -1.177e+06
# Cur diff delta = 7517.66650390625
# Cur diff sigma = 0.004740576259791851
# Cur diff theta = 7517.67124448251
# ---------------------------------------
# VB, d: 400, Iter: 1-1860, s/iter: 1.240e-01, ELBO: -1.174e+06
# Cur diff delta = 7354.34033203125
# Cur diff sigma = 0.004740401636809111
# Cur diff theta = 7354.345072432887
# ---------------------------------------
# VB, d: 400, Iter: 1-1880, s/iter: 1.189e-01, ELBO: -1.171e+06
# Cur diff delta = 7195.66357421875
# Cur diff sigma = 0.004740173928439617
# Cur diff theta = 7195.668314392678
# ---------------------------------------
# VB, d: 400, Iter: 1-1900, s/iter: 1.193e-01, ELBO: -1.167e+06
# Cur diff delta = 7041.4775390625
# Cur diff sigma = 0.004739962052553892
# Cur diff theta = 7041.482279024553
# ---------------------------------------
# VB, d: 400, Iter: 1-1920, s/iter: 1.182e-01, ELBO: -1.164e+06
# Cur diff delta = 6891.64013671875
# Cur diff sigma = 0.004739854484796524
# Cur diff theta = 6891.644876573235
# ---------------------------------------
# VB, d: 400, Iter: 1-1940, s/iter: 1.193e-01, ELBO: -1.161e+06
# Cur diff delta = 6746.00341796875
# Cur diff sigma = 0.004739671014249325
# Cur diff theta = 6746.008157639764
# ---------------------------------------
# VB, d: 400, Iter: 1-1960, s/iter: 1.203e-01, ELBO: -1.158e+06
# Cur diff delta = 6604.439453125
# Cur diff sigma = 0.004739541094750166
# Cur diff theta = 6604.444192666095
# ---------------------------------------
# VB, d: 400, Iter: 1-1980, s/iter: 1.239e-01, ELBO: -1.156e+06
# Cur diff delta = 6466.81103515625
# Cur diff sigma = 0.004739370197057724
# Cur diff theta = 6466.815774526447
# ---------------------------------------
# VB, d: 400, Iter: 1-2000, s/iter: 1.211e-01, ELBO: -1.153e+06
# Cur diff delta = 6332.99169921875
# Cur diff sigma = 0.00473927753046155
# Cur diff theta = 6332.9964384962805
# ---------------------------------------
# VB, d: 400, Iter: 1-2020, s/iter: 1.185e-01, ELBO: -1.150e+06
# Cur diff delta = 6202.857421875
# Cur diff sigma = 0.004739157389849424
# Cur diff theta = 6202.86216103239
# ---------------------------------------
# VB, d: 400, Iter: 1-2040, s/iter: 1.314e-01, ELBO: -1.148e+06
# Cur diff delta = 6076.2880859375
# Cur diff sigma = 0.004739054478704929
# Cur diff theta = 6076.292824991979
# ---------------------------------------
# VB, d: 400, Iter: 1-2060, s/iter: 1.219e-01, ELBO: -1.145e+06
# Cur diff delta = 5953.17041015625
# Cur diff sigma = 0.004738935269415379
# Cur diff theta = 5953.175149091519
# ---------------------------------------
# VB, d: 400, Iter: 1-2080, s/iter: 1.192e-01, ELBO: -1.143e+06
# Cur diff delta = 5833.39208984375
# Cur diff sigma = 0.004738852381706238
# Cur diff theta = 5833.396828696132
# ---------------------------------------
# VB, d: 400, Iter: 1-2100, s/iter: 1.206e-01, ELBO: -1.140e+06
# Cur diff delta = 5716.849609375
# Cur diff sigma = 0.0047386931255459785
# Cur diff theta = 5716.854348068126
# ---------------------------------------
# VB, d: 400, Iter: 1-2120, s/iter: 1.201e-01, ELBO: -1.138e+06
# Cur diff delta = 5603.443359375
# Cur diff sigma = 0.004738681484013796
# Cur diff theta = 5603.448098056484
# ---------------------------------------
# VB, d: 400, Iter: 1-2140, s/iter: 1.217e-01, ELBO: -1.136e+06
# Cur diff delta = 5493.06494140625
# Cur diff sigma = 0.004738572519272566
# Cur diff theta = 5493.069679978769
# ---------------------------------------
# VB, d: 400, Iter: 1-2160, s/iter: 1.210e-01, ELBO: -1.133e+06
# Cur diff delta = 5385.625
# Cur diff sigma = 0.004738423507660627
# Cur diff theta = 5385.629738423508
# ---------------------------------------
# VB, d: 400, Iter: 1-2180, s/iter: 1.331e-01, ELBO: -1.131e+06
# Cur diff delta = 5281.03076171875
# Cur diff sigma = 0.0047384160570800304
# Cur diff theta = 5281.035500134807
# ---------------------------------------
# VB, d: 400, Iter: 1-2200, s/iter: 1.197e-01, ELBO: -1.129e+06
# Cur diff delta = 5179.19287109375
# Cur diff sigma = 0.004738342482596636
# Cur diff theta = 5179.197609436233
# ---------------------------------------
# VB, d: 400, Iter: 1-2220, s/iter: 1.198e-01, ELBO: -1.127e+06
# Cur diff delta = 5080.02734375
# Cur diff sigma = 0.0047382484190166
# Cur diff theta = 5080.032081998419
# ---------------------------------------
# VB, d: 400, Iter: 1-2240, s/iter: 1.202e-01, ELBO: -1.125e+06
# Cur diff delta = 4983.4462890625
# Cur diff sigma = 0.004738208372145891
# Cur diff theta = 4983.451027270872
# ---------------------------------------
# VB, d: 400, Iter: 1-2260, s/iter: 1.181e-01, ELBO: -1.123e+06
# Cur diff delta = 4889.37060546875
# Cur diff sigma = 0.004738096613436937
# Cur diff theta = 4889.375343565363
# ---------------------------------------
# VB, d: 400, Iter: 1-2280, s/iter: 1.216e-01, ELBO: -1.121e+06
# Cur diff delta = 4797.72265625
# Cur diff sigma = 0.004738102201372385
# Cur diff theta = 4797.727394352201
# ---------------------------------------
# VB, d: 400, Iter: 1-2300, s/iter: 1.251e-01, ELBO: -1.120e+06
# Cur diff delta = 4708.42919921875
# Cur diff sigma = 0.004738040268421173
# Cur diff theta = 4708.433937259018
# ---------------------------------------
# VB, d: 400, Iter: 1-2320, s/iter: 1.183e-01, ELBO: -1.118e+06
# Cur diff delta = 4621.41650390625
# Cur diff sigma = 0.00473796809092164
# Cur diff theta = 4621.421241874341
# ---------------------------------------
# VB, d: 400, Iter: 1-2340, s/iter: 1.186e-01, ELBO: -1.116e+06
# Cur diff delta = 4536.61279296875
# Cur diff sigma = 0.00473790755495429
# Cur diff theta = 4536.617530876305
# ---------------------------------------
# VB, d: 400, Iter: 1-2360, s/iter: 1.222e-01, ELBO: -1.114e+06
# Cur diff delta = 4453.97216796875
# Cur diff sigma = 0.0047378577291965485
# Cur diff theta = 4453.976905826479
# ---------------------------------------
# VB, d: 400, Iter: 1-2380, s/iter: 1.213e-01, ELBO: -1.113e+06
# Cur diff delta = 4373.392578125
# Cur diff sigma = 0.0047377548180520535
# Cur diff theta = 4373.397315879818
# ---------------------------------------
# VB, d: 400, Iter: 1-2400, s/iter: 1.185e-01, ELBO: -1.111e+06
# Cur diff delta = 4294.837890625
# Cur diff sigma = 0.004737773910164833
# Cur diff theta = 4294.84262839891
# ---------------------------------------
# VB, d: 400, Iter: 1-2420, s/iter: 1.218e-01, ELBO: -1.109e+06
# Cur diff delta = 4218.2421875
# Cur diff sigma = 0.004737750627100468
# Cur diff theta = 4218.246925250627
# ---------------------------------------
# VB, d: 400, Iter: 1-2440, s/iter: 1.205e-01, ELBO: -1.108e+06
# Cur diff delta = 4143.5419921875
# Cur diff sigma = 0.004737683571875095
# Cur diff theta = 4143.546729871072
# ---------------------------------------
# VB, d: 400, Iter: 1-2460, s/iter: 1.275e-01, ELBO: -1.106e+06
# Cur diff delta = 4070.68017578125
# Cur diff sigma = 0.004737652372568846
# Cur diff theta = 4070.6849134336226
# ---------------------------------------
# VB, d: 400, Iter: 1-2480, s/iter: 1.181e-01, ELBO: -1.105e+06
# Cur diff delta = 3999.609130859375
# Cur diff sigma = 0.0047376505099236965
# Cur diff theta = 3999.613868509885
# ---------------------------------------
# VB, d: 400, Iter: 1-2500, s/iter: 1.180e-01, ELBO: -1.103e+06
# Cur diff delta = 3930.274658203125
# Cur diff sigma = 0.00473759276792407
# Cur diff theta = 3930.279395795893
# ---------------------------------------
# VB, d: 400, Iter: 1-2520, s/iter: 1.280e-01, ELBO: -1.102e+06
# Cur diff delta = 3862.623046875
# Cur diff sigma = 0.004737598821520805
# Cur diff theta = 3862.6277844738215
# ---------------------------------------
# VB, d: 400, Iter: 1-2540, s/iter: 1.236e-01, ELBO: -1.101e+06
# Cur diff delta = 3796.598388671875
# Cur diff sigma = 0.004737549461424351
# Cur diff theta = 3796.6031262213364
# ---------------------------------------
# VB, d: 400, Iter: 1-2560, s/iter: 1.309e-01, ELBO: -1.099e+06
# Cur diff delta = 3732.16748046875
# Cur diff sigma = 0.004737480077892542
# Cur diff theta = 3732.172217948828
# ---------------------------------------
# VB, d: 400, Iter: 1-2580, s/iter: 1.186e-01, ELBO: -1.098e+06
# Cur diff delta = 3669.2734375
# Cur diff sigma = 0.004737448878586292
# Cur diff theta = 3669.2781749488786
# ---------------------------------------
# VB, d: 400, Iter: 1-2600, s/iter: 1.181e-01, ELBO: -1.097e+06
# Cur diff delta = 3607.873779296875
# Cur diff sigma = 0.00473741814494133
# Cur diff theta = 3607.87851671502
# ---------------------------------------
# VB, d: 400, Iter: 1-2620, s/iter: 1.194e-01, ELBO: -1.096e+06
# Cur diff delta = 3547.927734375
# Cur diff sigma = 0.00473739905282855
# Cur diff theta = 3547.932471774053
# ---------------------------------------
# VB, d: 400, Iter: 1-2640, s/iter: 1.335e-01, ELBO: -1.094e+06
# Cur diff delta = 3489.397216796875
# Cur diff sigma = 0.004737351555377245
# Cur diff theta = 3489.4019541484304
# ---------------------------------------
# VB, d: 400, Iter: 1-2660, s/iter: 1.196e-01, ELBO: -1.093e+06
# Cur diff delta = 3432.235595703125
# Cur diff sigma = 0.004737365059554577
# Cur diff theta = 3432.2403330681846
# ---------------------------------------
# VB, d: 400, Iter: 1-2680, s/iter: 1.198e-01, ELBO: -1.092e+06
# Cur diff delta = 3376.39892578125
# Cur diff sigma = 0.004737332928925753
# Cur diff theta = 3376.403663114179
# ---------------------------------------
# VB, d: 400, Iter: 1-2700, s/iter: 1.192e-01, ELBO: -1.091e+06
# Cur diff delta = 3321.85791015625
# Cur diff sigma = 0.004737285431474447
# Cur diff theta = 3321.8626474416815
# ---------------------------------------
# VB, d: 400, Iter: 1-2720, s/iter: 1.292e-01, ELBO: -1.090e+06
# Cur diff delta = 3268.57421875
# Cur diff sigma = 0.004737283103168011
# Cur diff theta = 3268.578956033103
# ---------------------------------------
# VB, d: 400, Iter: 1-2740, s/iter: 1.210e-01, ELBO: -1.089e+06
# Cur diff delta = 3216.5126953125
# Cur diff sigma = 0.00473731430247426
# Cur diff theta = 3216.5174326268025
# ---------------------------------------
# VB, d: 400, Iter: 1-2760, s/iter: 1.213e-01, ELBO: -1.088e+06
# Cur diff delta = 3165.64013671875
# Cur diff sigma = 0.004737270995974541
# Cur diff theta = 3165.644873989746
# ---------------------------------------
# VB, d: 400, Iter: 1-2780, s/iter: 1.222e-01, ELBO: -1.087e+06
# Cur diff delta = 3115.918701171875
# Cur diff sigma = 0.004737260285764933
# Cur diff theta = 3115.9234384321608
# ---------------------------------------
# VB, d: 400, Iter: 1-2800, s/iter: 1.334e-01, ELBO: -1.086e+06
# Cur diff delta = 3067.323974609375
# Cur diff sigma = 0.0047372388653457165
# Cur diff theta = 3067.3287118482403
# ---------------------------------------
# VB, d: 400, Iter: 1-2820, s/iter: 1.242e-01, ELBO: -1.085e+06
# Cur diff delta = 3019.822998046875
# Cur diff sigma = 0.0047372495755553246
# Cur diff theta = 3019.8277352964506
# ---------------------------------------
# VB, d: 400, Iter: 1-2840, s/iter: 1.253e-01, ELBO: -1.084e+06
# Cur diff delta = 2973.380859375
# Cur diff sigma = 0.0047372132539749146
# Cur diff theta = 2973.385596588254
# ---------------------------------------
# VB, d: 400, Iter: 1-2860, s/iter: 1.191e-01, ELBO: -1.083e+06
# Cur diff delta = 2927.96923828125
# Cur diff sigma = 0.004737211391329765
# Cur diff theta = 2927.9739754926413
# ---------------------------------------
# VB, d: 400, Iter: 1-2880, s/iter: 1.181e-01, ELBO: -1.082e+06
# Cur diff delta = 2883.5654296875
# Cur diff sigma = 0.0047372085973620415
# Cur diff theta = 2883.5701668960974
# ---------------------------------------
# VB, d: 400, Iter: 1-2900, s/iter: 1.307e-01, ELBO: -1.081e+06
# Cur diff delta = 2840.14013671875
# Cur diff sigma = 0.004737167619168758
# Cur diff theta = 2840.144873886369
# ---------------------------------------
# VB, d: 400, Iter: 1-2920, s/iter: 1.215e-01, ELBO: -1.080e+06
# Cur diff delta = 2797.6650390625
# Cur diff sigma = 0.004737182054668665
# Cur diff theta = 2797.6697762445547
# ---------------------------------------
# VB, d: 400, Iter: 1-2940, s/iter: 1.197e-01, ELBO: -1.079e+06
# Cur diff delta = 2756.11376953125
# Cur diff sigma = 0.0047371829859912395
# Cur diff theta = 2756.118506714236
# ---------------------------------------
# VB, d: 400, Iter: 1-2960, s/iter: 1.333e-01, ELBO: -1.078e+06
# Cur diff delta = 2715.4609375
# Cur diff sigma = 0.0047371950931847095
# Cur diff theta = 2715.465674695093
# ---------------------------------------
# VB, d: 400, Iter: 1-2980, s/iter: 1.276e-01, ELBO: -1.077e+06
# Cur diff delta = 2675.685791015625
# Cur diff sigma = 0.004737169481813908
# Cur diff theta = 2675.690528185107
# ---------------------------------------
# VB, d: 400, Iter: 1-3000, s/iter: 1.425e-01, ELBO: -1.077e+06
# Cur diff delta = 2636.771240234375
# Cur diff sigma = 0.004737149924039841
# Cur diff theta = 2636.775977384299
# ---------------------------------------
# VB, d: 400, Iter: 1-3020, s/iter: 1.192e-01, ELBO: -1.076e+06
# Cur diff delta = 2598.685302734375
# Cur diff sigma = 0.004737148992717266
# Cur diff theta = 2598.6900398833677
# ---------------------------------------
# VB, d: 400, Iter: 1-3040, s/iter: 1.185e-01, ELBO: -1.075e+06
# Cur diff delta = 2561.40673828125
# Cur diff sigma = 0.004737135488539934
# Cur diff theta = 2561.4114754167385
# ---------------------------------------
# VB, d: 400, Iter: 1-3060, s/iter: 1.196e-01, ELBO: -1.074e+06
# Cur diff delta = 2524.9169921875
# Cur diff sigma = 0.004737155046314001
# Cur diff theta = 2524.9217293425463
# ---------------------------------------
# VB, d: 400, Iter: 1-3080, s/iter: 1.322e-01, ELBO: -1.074e+06
# Cur diff delta = 2489.19091796875
# Cur diff sigma = 0.004737131763249636
# Cur diff theta = 2489.1956551005132
# ---------------------------------------
# VB, d: 400, Iter: 1-3100, s/iter: 1.202e-01, ELBO: -1.073e+06
# Cur diff delta = 2454.217041015625
# Cur diff sigma = 0.004737136885523796
# Cur diff theta = 2454.2217781525105
# ---------------------------------------
# VB, d: 400, Iter: 1-3120, s/iter: 1.248e-01, ELBO: -1.072e+06
# Cur diff delta = 2419.968505859375
# Cur diff sigma = 0.004737101960927248
# Cur diff theta = 2419.973242961336
# ---------------------------------------
# VB, d: 400, Iter: 1-3140, s/iter: 1.198e-01, ELBO: -1.071e+06
# Cur diff delta = 2386.4326171875
# Cur diff sigma = 0.004737131763249636
# Cur diff theta = 2386.4373543192632
# ---------------------------------------
# VB, d: 400, Iter: 1-3160, s/iter: 1.178e-01, ELBO: -1.071e+06
# Cur diff delta = 2353.588134765625
# Cur diff sigma = 0.004737133160233498
# Cur diff theta = 2353.5928718987852
# ---------------------------------------
# VB, d: 400, Iter: 1-3180, s/iter: 1.197e-01, ELBO: -1.070e+06
# Cur diff delta = 2321.416748046875
# Cur diff sigma = 0.0047371466644108295
# Cur diff theta = 2321.4214851935394
# ---------------------------------------
# VB, d: 400, Iter: 1-3200, s/iter: 1.174e-01, ELBO: -1.069e+06
# Cur diff delta = 2289.90673828125
# Cur diff sigma = 0.004737135488539934
# Cur diff theta = 2289.9114754167385
# ---------------------------------------
# VB, d: 400, Iter: 1-3220, s/iter: 1.319e-01, ELBO: -1.069e+06
# Cur diff delta = 2259.032470703125
# Cur diff sigma = 0.004737106151878834
# Cur diff theta = 2259.037207809277
# ---------------------------------------
# VB, d: 400, Iter: 1-3240, s/iter: 1.190e-01, ELBO: -1.068e+06
# Cur diff delta = 2228.783935546875
# Cur diff sigma = 0.00473712058737874
# Cur diff theta = 2228.7886726674624
# ---------------------------------------
# VB, d: 400, Iter: 1-3260, s/iter: 1.183e-01, ELBO: -1.068e+06
# Cur diff delta = 2199.146484375
# Cur diff sigma = 0.0047371056862175465
# Cur diff theta = 2199.151221480686
# ---------------------------------------
# VB, d: 400, Iter: 1-3280, s/iter: 1.243e-01, ELBO: -1.067e+06
# Cur diff delta = 2170.104248046875
# Cur diff sigma = 0.004737127106636763
# Cur diff theta = 2170.1089851739816
# ---------------------------------------
# VB, d: 400, Iter: 1-3300, s/iter: 1.206e-01, ELBO: -1.066e+06
# Cur diff delta = 2141.634765625
# Cur diff sigma = 0.004737130831927061
# Cur diff theta = 2141.639502755832
# ---------------------------------------
# VB, d: 400, Iter: 1-3320, s/iter: 1.187e-01, ELBO: -1.066e+06
# Cur diff delta = 2113.732421875
# Cur diff sigma = 0.004737121518701315
# Cur diff theta = 2113.7371589965187
# ---------------------------------------
# VB, d: 400, Iter: 1-3340, s/iter: 1.202e-01, ELBO: -1.065e+06
# Cur diff delta = 2086.3828125
# Cur diff sigma = 0.004737109411507845
# Cur diff theta = 2086.3875496094115
# ---------------------------------------
# VB, d: 400, Iter: 1-3360, s/iter: 1.185e-01, ELBO: -1.065e+06
# Cur diff delta = 2059.572998046875
# Cur diff sigma = 0.004737123381346464
# Cur diff theta = 2059.5777351702563
# ---------------------------------------
# VB, d: 400, Iter: 1-3380, s/iter: 1.191e-01, ELBO: -1.064e+06
# Cur diff delta = 2033.2884521484375
# Cur diff sigma = 0.004737126175314188
# Cur diff theta = 2033.2931892746128
# ---------------------------------------
# VB, d: 400, Iter: 1-3400, s/iter: 1.435e-01, ELBO: -1.064e+06
# Cur diff delta = 2007.5107421875
# Cur diff sigma = 0.004737124778330326
# Cur diff theta = 2007.5154793122783
# ---------------------------------------
# VB, d: 400, Iter: 1-3420, s/iter: 1.190e-01, ELBO: -1.063e+06
# Cur diff delta = 1982.2354736328125
# Cur diff sigma = 0.004737136419862509
# Cur diff theta = 1982.2402107692324
# ---------------------------------------
# VB, d: 400, Iter: 1-3440, s/iter: 1.265e-01, ELBO: -1.062e+06
# Cur diff delta = 1957.4471435546875
# Cur diff sigma = 0.004737104754894972
# Cur diff theta = 1957.4518806594424
# ---------------------------------------
# VB, d: 400, Iter: 1-3460, s/iter: 1.195e-01, ELBO: -1.062e+06
# Cur diff delta = 1933.130615234375
# Cur diff sigma = 0.004737108945846558
# Cur diff theta = 1933.1353523433208
# ---------------------------------------
# VB, d: 400, Iter: 1-3480, s/iter: 1.196e-01, ELBO: -1.061e+06
# Cur diff delta = 1909.2818603515625
# Cur diff sigma = 0.00473711546510458
# Cur diff theta = 1909.2865974670276
# ---------------------------------------
# VB, d: 400, Iter: 1-3500, s/iter: 1.211e-01, ELBO: -1.061e+06
# Cur diff delta = 1885.89111328125
# Cur diff sigma = 0.004737111274152994
# Cur diff theta = 1885.8958503925242
# ---------------------------------------
# VB, d: 400, Iter: 1-3520, s/iter: 1.199e-01, ELBO: -1.061e+06
# Cur diff delta = 1862.9462890625
# Cur diff sigma = 0.004737109877169132
# Cur diff theta = 1862.9510261723772
# ---------------------------------------
# VB, d: 400, Iter: 1-3540, s/iter: 1.186e-01, ELBO: -1.060e+06
# Cur diff delta = 1840.4320068359375
# Cur diff sigma = 0.004737099166959524
# Cur diff theta = 1840.4367439351045
# ---------------------------------------
# VB, d: 400, Iter: 1-3560, s/iter: 1.187e-01, ELBO: -1.060e+06
# Cur diff delta = 1818.337890625
# Cur diff sigma = 0.004737101495265961
# Cur diff theta = 1818.3426277264953
# ---------------------------------------
# VB, d: 400, Iter: 1-3580, s/iter: 1.240e-01, ELBO: -1.059e+06
# Cur diff delta = 1796.657470703125
# Cur diff sigma = 0.00473711546510458
# Cur diff theta = 1796.66220781859
# ---------------------------------------
# VB, d: 400, Iter: 1-3600, s/iter: 1.244e-01, ELBO: -1.059e+06
# Cur diff delta = 1775.3792724609375
# Cur diff sigma = 0.004737118724733591
# Cur diff theta = 1775.3840095796622
# ---------------------------------------
# VB, d: 400, Iter: 1-3620, s/iter: 1.197e-01, ELBO: -1.058e+06
# Cur diff delta = 1754.49658203125
# Cur diff sigma = 0.004737116862088442
# Cur diff theta = 1754.501319148112
# ---------------------------------------
# VB, d: 400, Iter: 1-3640, s/iter: 1.200e-01, ELBO: -1.058e+06
# Cur diff delta = 1733.99609375
# Cur diff sigma = 0.004737159702926874
# Cur diff theta = 1734.000830909703
# ---------------------------------------
# VB, d: 400, Iter: 1-3660, s/iter: 1.201e-01, ELBO: -1.057e+06
# Cur diff delta = 1713.869873046875
# Cur diff sigma = 0.004737117327749729
# Cur diff theta = 1713.8746101642027
# ---------------------------------------
# VB, d: 400, Iter: 1-3680, s/iter: 1.244e-01, ELBO: -1.057e+06
# Cur diff delta = 1694.114013671875
# Cur diff sigma = 0.004737106617540121
# Cur diff theta = 1694.1187507784925
# ---------------------------------------
# VB, d: 400, Iter: 1-3700, s/iter: 1.224e-01, ELBO: -1.057e+06
# Cur diff delta = 1674.7200927734375
# Cur diff sigma = 0.004737112671136856
# Cur diff theta = 1674.7248298861086
# ---------------------------------------
# VB, d: 400, Iter: 1-3720, s/iter: 1.201e-01, ELBO: -1.056e+06
# Cur diff delta = 1655.6822509765625
# Cur diff sigma = 0.004737128037959337
# Cur diff theta = 1655.6869881046005
# ---------------------------------------
# VB, d: 400, Iter: 1-3740, s/iter: 1.279e-01, ELBO: -1.056e+06
# Cur diff delta = 1636.987060546875
# Cur diff sigma = 0.0047371103428304195
# Cur diff theta = 1636.9917976572178
# ---------------------------------------
# VB, d: 400, Iter: 1-3760, s/iter: 1.238e-01, ELBO: -1.055e+06
# Cur diff delta = 1618.6243896484375
# Cur diff sigma = 0.004737118259072304
# Cur diff theta = 1618.6291267666966
# ---------------------------------------
# VB, d: 400, Iter: 1-3780, s/iter: 1.186e-01, ELBO: -1.055e+06
# Cur diff delta = 1600.58740234375
# Cur diff sigma = 0.00473712058737874
# Cur diff theta = 1600.5921394643374
# ---------------------------------------
# VB, d: 400, Iter: 1-3800, s/iter: 1.165e-01, ELBO: -1.055e+06
# Cur diff delta = 1582.8724365234375
# Cur diff sigma = 0.004737108945846558
# Cur diff theta = 1582.8771736323833
# ---------------------------------------
# VB, d: 400, Iter: 1-3820, s/iter: 1.154e-01, ELBO: -1.054e+06
# Cur diff delta = 1565.4713134765625
# Cur diff sigma = 0.004737145733088255
# Cur diff theta = 1565.4760506222956
# ---------------------------------------
# VB, d: 400, Iter: 1-3840, s/iter: 1.170e-01, ELBO: -1.054e+06
# Cur diff delta = 1548.376953125
# Cur diff sigma = 0.0047371466644108295
# Cur diff theta = 1548.3816902716644
# ---------------------------------------
# VB, d: 400, Iter: 1-3860, s/iter: 1.197e-01, ELBO: -1.054e+06
# Cur diff delta = 1531.58544921875
# Cur diff sigma = 0.0047371406108140945
# Cur diff theta = 1531.5901863593608
# ---------------------------------------
# VB, d: 400, Iter: 1-3880, s/iter: 1.192e-01, ELBO: -1.053e+06
# Cur diff delta = 1515.089111328125
# Cur diff sigma = 0.004737142473459244
# Cur diff theta = 1515.0938484705985
# ---------------------------------------
# VB, d: 400, Iter: 1-3900, s/iter: 1.202e-01, ELBO: -1.053e+06
# Cur diff delta = 1498.879638671875
# Cur diff sigma = 0.004737130831927061
# Cur diff theta = 1498.884375802707
# ---------------------------------------
# VB, d: 400, Iter: 1-3920, s/iter: 1.325e-01, ELBO: -1.053e+06
# Cur diff delta = 1482.95458984375
# Cur diff sigma = 0.004737146198749542
# Cur diff theta = 1482.9593269899487
# ---------------------------------------
# VB, d: 400, Iter: 1-3940, s/iter: 1.282e-01, ELBO: -1.052e+06
# Cur diff delta = 1467.303955078125
# Cur diff sigma = 0.004737145267426968
# Cur diff theta = 1467.3086922233924
# ---------------------------------------
# ...
# Cur diff theta = 1906.7207118305378
# ---------------------------------------
# VB, d: 400, Iter: 3-3560, s/iter: 1.195e-01, ELBO: -1.060e+06
# Cur diff delta = 1884.052490234375
# Cur diff sigma = 0.0057460470125079155
# Cur diff theta = 1884.0582362813875
# ---------------------------------------
# VB, d: 400, Iter: 3-3580, s/iter: 1.232e-01, ELBO: -1.060e+06
# Cur diff delta = 1861.8056640625
# Cur diff sigma = 0.005746057257056236
# Cur diff theta = 1861.811410119757
# ---------------------------------------
# VB, d: 400, Iter: 3-3600, s/iter: 1.198e-01, ELBO: -1.059e+06
# Cur diff delta = 1839.9683837890625
# Cur diff sigma = 0.005746057257056236
# Cur diff theta = 1839.9741298463196
# ---------------------------------------
# VB, d: 400, Iter: 3-3620, s/iter: 1.192e-01, ELBO: -1.059e+06
# Cur diff delta = 1818.5302734375
# Cur diff sigma = 0.005746102891862392
# Cur diff theta = 1818.5360195403919
# ---------------------------------------
# VB, d: 400, Iter: 3-3640, s/iter: 1.173e-01, ELBO: -1.058e+06
# Cur diff delta = 1797.47998046875
# Cur diff sigma = 0.005746104754507542
# Cur diff theta = 1797.4857265735045
# ---------------------------------------
# VB, d: 400, Iter: 3-3660, s/iter: 1.189e-01, ELBO: -1.058e+06
# Cur diff delta = 1776.81103515625
# Cur diff sigma = 0.0057460833340883255
# Cur diff theta = 1776.816781239584
# ---------------------------------------
# VB, d: 400, Iter: 3-3680, s/iter: 1.190e-01, ELBO: -1.057e+06
# Cur diff delta = 1756.512451171875
# Cur diff sigma = 0.0057461499236524105
# Cur diff theta = 1756.5181973217987
# ---------------------------------------
# VB, d: 400, Iter: 3-3700, s/iter: 1.168e-01, ELBO: -1.057e+06
# Cur diff delta = 1736.5799560546875
# Cur diff sigma = 0.005746169947087765
# Cur diff theta = 1736.5857022246346
# ---------------------------------------
# VB, d: 400, Iter: 3-3720, s/iter: 1.164e-01, ELBO: -1.057e+06
# Cur diff delta = 1717.0020751953125
# Cur diff sigma = 0.005746185779571533
# Cur diff theta = 1717.007821381092
# ---------------------------------------
# VB, d: 400, Iter: 3-3740, s/iter: 1.196e-01, ELBO: -1.056e+06
# Cur diff delta = 1697.771240234375
# Cur diff sigma = 0.00574619323015213
# Cur diff theta = 1697.7769864276052
# ---------------------------------------
# VB, d: 400, Iter: 3-3760, s/iter: 1.248e-01, ELBO: -1.056e+06
# Cur diff delta = 1678.880126953125
# Cur diff sigma = 0.005746220704168081
# Cur diff theta = 1678.8858731738292
# ---------------------------------------
# VB, d: 400, Iter: 3-3780, s/iter: 1.315e-01, ELBO: -1.055e+06
# Cur diff delta = 1660.3236083984375
# Cur diff sigma = 0.005746226292103529
# Cur diff theta = 1660.3293546247296
# ---------------------------------------
# VB, d: 400, Iter: 3-3800, s/iter: 1.172e-01, ELBO: -1.055e+06
# Cur diff delta = 1642.09326171875
# Cur diff sigma = 0.005746234208345413
# Cur diff theta = 1642.0990079529583
# ---------------------------------------
# VB, d: 400, Iter: 3-3820, s/iter: 1.307e-01, ELBO: -1.055e+06
# Cur diff delta = 1624.1802978515625
# Cur diff sigma = 0.005746247712522745
# Cur diff theta = 1624.186044099275
# ---------------------------------------
# VB, d: 400, Iter: 3-3840, s/iter: 1.201e-01, ELBO: -1.054e+06
# Cur diff delta = 1606.579833984375
# Cur diff sigma = 0.005746270529925823
# Cur diff theta = 1606.585580254905
# ---------------------------------------
# VB, d: 400, Iter: 3-3860, s/iter: 1.225e-01, ELBO: -1.054e+06
# Cur diff delta = 1589.2855224609375
# Cur diff sigma = 0.005746282171458006
# Cur diff theta = 1589.291268743109
# ---------------------------------------
# VB, d: 400, Iter: 3-3880, s/iter: 1.194e-01, ELBO: -1.054e+06
# Cur diff delta = 1572.294189453125
# Cur diff sigma = 0.0057463133707642555
# Cur diff theta = 1572.2999357664958
# ---------------------------------------
# VB, d: 400, Iter: 3-3900, s/iter: 1.219e-01, ELBO: -1.053e+06
# Cur diff delta = 1555.591796875
# Cur diff sigma = 0.005746310576796532
# Cur diff theta = 1555.5975431855768
# ---------------------------------------
# VB, d: 400, Iter: 3-3920, s/iter: 1.215e-01, ELBO: -1.053e+06
# Cur diff delta = 1539.17431640625
# Cur diff sigma = 0.00574632128700614
# Cur diff theta = 1539.180062727537
# ---------------------------------------
# VB, d: 400, Iter: 3-3940, s/iter: 1.165e-01, ELBO: -1.053e+06
# Cur diff delta = 1523.033203125
# Cur diff sigma = 0.005746341310441494
# Cur diff theta = 1523.0389494663104
# ---------------------------------------
# VB, d: 400, Iter: 3-3960, s/iter: 1.208e-01, ELBO: -1.052e+06
# Cur diff delta = 1507.16455078125
# Cur diff sigma = 0.005746342707425356
# Cur diff theta = 1507.1702971239574
# ---------------------------------------
# VB, d: 400, Iter: 3-3980, s/iter: 1.212e-01, ELBO: -1.052e+06
# Cur diff delta = 1491.5634765625
# Cur diff sigma = 0.00574636971578002
# Cur diff theta = 1491.5692229322158
# ---------------------------------------
# VB, d: 400, Iter: 3-4000, s/iter: 1.172e-01, ELBO: -1.052e+06
# Cur diff delta = 1476.2265625
# Cur diff sigma = 0.005746382288634777
# Cur diff theta = 1476.2323088822886
# ---------------------------------------
# VB, d: 400, Iter: 3-4020, s/iter: 1.199e-01, ELBO: -1.051e+06
# Cur diff delta = 1461.1456298828125
# Cur diff sigma = 0.005746410693973303
# Cur diff theta = 1461.1513762935065
# ---------------------------------------
# VB, d: 400, Iter: 3-4040, s/iter: 1.185e-01, ELBO: -1.051e+06
# Cur diff delta = 1446.31787109375
# Cur diff sigma = 0.005746403243392706
# Cur diff theta = 1446.3236174969934
# ---------------------------------------
# VB, d: 400, Iter: 3-4060, s/iter: 1.331e-01, ELBO: -1.051e+06
# Cur diff delta = 1431.7333984375
# Cur diff sigma = 0.005746413953602314
# Cur diff theta = 1431.7391448514536
# ---------------------------------------
# VB, d: 400, Iter: 3-4080, s/iter: 1.329e-01, ELBO: -1.050e+06
# Cur diff delta = 1417.3912353515625
# Cur diff sigma = 0.005746415350586176
# Cur diff theta = 1417.396981766913
# ---------------------------------------
# VB, d: 400, Iter: 3-4100, s/iter: 1.184e-01, ELBO: -1.050e+06
# Cur diff delta = 1403.28515625
# Cur diff sigma = 0.0057464223355054855
# Cur diff theta = 1403.2909026723355
# ---------------------------------------
# VB, d: 400, Iter: 3-4120, s/iter: 1.201e-01, ELBO: -1.050e+06
# Cur diff delta = 1389.4088134765625
# Cur diff sigma = 0.005746442824602127
# Cur diff theta = 1389.414559919387
# ---------------------------------------
# VB, d: 400, Iter: 3-4140, s/iter: 1.196e-01, ELBO: -1.049e+06
# Cur diff delta = 1375.7608642578125
# Cur diff sigma = 0.005746460985392332
# Cur diff theta = 1375.766610718798
# ---------------------------------------
# VB, d: 400, Iter: 3-4160, s/iter: 1.213e-01, ELBO: -1.049e+06
# Cur diff delta = 1362.3365478515625
# Cur diff sigma = 0.005746453069150448
# Cur diff theta = 1362.3422943046317
# ---------------------------------------
# VB, d: 400, Iter: 3-4180, s/iter: 1.211e-01, ELBO: -1.049e+06
# Cur diff delta = 1349.128173828125
# Cur diff sigma = 0.005746491719037294
# Cur diff theta = 1349.133920319844
# ---------------------------------------
# VB, d: 400, Iter: 3-4200, s/iter: 1.216e-01, ELBO: -1.049e+06
# Cur diff delta = 1336.1336669921875
# Cur diff sigma = 0.005746492184698582
# Cur diff theta = 1336.1394134843722
# ---------------------------------------
# VB, d: 400, Iter: 3-4220, s/iter: 1.242e-01, ELBO: -1.048e+06
# Cur diff delta = 1323.3480224609375
# Cur diff sigma = 0.0057464963756501675
# Cur diff theta = 1323.3537689573132
# ---------------------------------------
# VB, d: 400, Iter: 3-4240, s/iter: 1.387e-01, ELBO: -1.048e+06
# Cur diff delta = 1310.7667236328125
# Cur diff sigma = 0.005746516864746809
# Cur diff theta = 1310.7724701496772
# ---------------------------------------
# VB, d: 400, Iter: 3-4260, s/iter: 1.198e-01, ELBO: -1.048e+06
# Cur diff delta = 1298.38818359375
# Cur diff sigma = 0.005746515467762947
# Cur diff theta = 1298.3939301092178
# ---------------------------------------
# VB, d: 400, Iter: 3-4280, s/iter: 1.230e-01, ELBO: -1.048e+06
# Cur diff delta = 1286.20556640625
# Cur diff sigma = 0.005746534559875727
# Cur diff theta = 1286.2113129408099
# ---------------------------------------
# VB, d: 400, Iter: 3-4300, s/iter: 1.339e-01, ELBO: -1.047e+06
# Cur diff delta = 1274.2191162109375
# Cur diff sigma = 0.0057465313002467155
# Cur diff theta = 1274.2248627422377
# ---------------------------------------
# VB, d: 400, Iter: 3-4320, s/iter: 1.161e-01, ELBO: -1.047e+06
# Cur diff delta = 1262.424560546875
# Cur diff sigma = 0.005746562499552965
# Cur diff theta = 1262.4303071093746
# ---------------------------------------
# VB, d: 400, Iter: 3-4340, s/iter: 1.178e-01, ELBO: -1.047e+06
# Cur diff delta = 1250.814697265625
# Cur diff sigma = 0.005746560636907816
# Cur diff theta = 1250.820443826262
# ---------------------------------------
# VB, d: 400, Iter: 3-4360, s/iter: 1.326e-01, ELBO: -1.047e+06
# Cur diff delta = 1239.3841552734375
# Cur diff sigma = 0.00574658066034317
# Cur diff theta = 1239.3899018540978
# ---------------------------------------
# VB, d: 400, Iter: 3-4380, s/iter: 1.288e-01, ELBO: -1.046e+06
# Cur diff delta = 1228.128662109375
# Cur diff sigma = 0.005746591370552778
# Cur diff theta = 1228.1344087007456
# ---------------------------------------
# VB, d: 400, Iter: 3-4400, s/iter: 1.223e-01, ELBO: -1.046e+06
# Cur diff delta = 1217.0458984375
# Cur diff sigma = 0.005746607668697834
# Cur diff theta = 1217.0516450451687
# ---------------------------------------
# VB, d: 400, Iter: 3-4420, s/iter: 1.267e-01, ELBO: -1.046e+06
# Cur diff delta = 1206.13671875
# Cur diff sigma = 0.0057465992867946625
# Cur diff theta = 1206.1424653492868
# ---------------------------------------
# VB, d: 400, Iter: 3-4440, s/iter: 1.154e-01, ELBO: -1.046e+06
# Cur diff delta = 1195.3968505859375
# Cur diff sigma = 0.005746619775891304
# Cur diff theta = 1195.4025972057134
# ---------------------------------------
# VB, d: 400, Iter: 3-4460, s/iter: 1.193e-01, ELBO: -1.045e+06
# Cur diff delta = 1184.82373046875
# Cur diff sigma = 0.005746619775891304
# Cur diff theta = 1184.829477088526
# ---------------------------------------
# VB, d: 400, Iter: 3-4480, s/iter: 1.294e-01, ELBO: -1.045e+06
# Cur diff delta = 1174.4119873046875
# Cur diff sigma = 0.0057466356083750725
# Cur diff theta = 1174.4177339402959
# ---------------------------------------
# VB, d: 400, Iter: 3-4500, s/iter: 1.178e-01, ELBO: -1.045e+06
# Cur diff delta = 1164.158935546875
# Cur diff sigma = 0.005746630486100912
# Cur diff theta = 1164.164682177361
# ---------------------------------------
# VB, d: 400, Iter: 3-4520, s/iter: 1.197e-01, ELBO: -1.045e+06
# Cur diff delta = 1154.0614013671875
# Cur diff sigma = 0.005746654234826565
# Cur diff theta = 1154.0671480214223
# ---------------------------------------
# VB, d: 400, Iter: 3-4540, s/iter: 1.191e-01, ELBO: -1.045e+06
# Cur diff delta = 1144.1162109375
# Cur diff sigma = 0.005746649112552404
# Cur diff theta = 1144.1219575866126
# ---------------------------------------
# VB, d: 400, Iter: 3-4560, s/iter: 1.187e-01, ELBO: -1.044e+06
# Cur diff delta = 1134.3201904296875
# Cur diff sigma = 0.0057466584257781506
# Cur diff theta = 1134.3259370881133
# ---------------------------------------
# VB, d: 400, Iter: 3-4580, s/iter: 1.200e-01, ELBO: -1.044e+06
# Cur diff delta = 1124.67236328125
# Cur diff sigma = 0.005746668670326471
# Cur diff theta = 1124.6781099499203
# ---------------------------------------
# VB, d: 400, Iter: 3-4600, s/iter: 1.187e-01, ELBO: -1.044e+06
# Cur diff delta = 1115.167724609375
# Cur diff sigma = 0.005746675655245781
# Cur diff theta = 1115.1734712850302
# ---------------------------------------
# VB, d: 400, Iter: 3-4620, s/iter: 1.269e-01, ELBO: -1.044e+06
# Cur diff delta = 1105.8065185546875
# Cur diff sigma = 0.0057467082515358925
# Cur diff theta = 1105.812265262939
# ---------------------------------------
# VB, d: 400, Iter: 3-4640, s/iter: 1.206e-01, ELBO: -1.044e+06
# Cur diff delta = 1096.58642578125
# Cur diff sigma = 0.005746693816035986
# Cur diff theta = 1096.592172475066
# ---------------------------------------
# VB, d: 400, Iter: 3-4660, s/iter: 1.199e-01, ELBO: -1.043e+06
# Cur diff delta = 1087.50390625
# Cur diff sigma = 0.005746697541326284
# Cur diff theta = 1087.5096529475413
# ---------------------------------------
# VB, d: 400, Iter: 3-4680, s/iter: 1.180e-01, ELBO: -1.043e+06
# Cur diff delta = 1078.5557861328125
# Cur diff sigma = 0.005746707320213318
# Cur diff theta = 1078.5615328401327
# ---------------------------------------
# VB, d: 400, Iter: 3-4700, s/iter: 1.183e-01, ELBO: -1.043e+06
# Cur diff delta = 1069.7388916015625
# Cur diff sigma = 0.005746707785874605
# Cur diff theta = 1069.7446383093484
# ---------------------------------------
# VB, d: 400, Iter: 3-4720, s/iter: 1.297e-01, ELBO: -1.043e+06
# Cur diff delta = 1061.051513671875
# Cur diff sigma = 0.0057467143051326275
# Cur diff theta = 1061.0572603861801
# ---------------------------------------
# VB, d: 400, Iter: 3-4740, s/iter: 1.214e-01, ELBO: -1.043e+06
# Cur diff delta = 1052.4925537109375
# Cur diff sigma = 0.005746709182858467
# Cur diff theta = 1052.4983004201204
# ---------------------------------------
# VB, d: 400, Iter: 3-4760, s/iter: 1.186e-01, ELBO: -1.042e+06
# Cur diff delta = 1044.0599365234375
# Cur diff sigma = 0.005746729671955109
# Cur diff theta = 1044.0656832531095
# ---------------------------------------
# VB, d: 400, Iter: 3-4780, s/iter: 1.205e-01, ELBO: -1.042e+06
# Cur diff delta = 1035.7491455078125
# Cur diff sigma = 0.005746742710471153
# Cur diff theta = 1035.754892250523
# ---------------------------------------
# VB, d: 400, Iter: 3-4800, s/iter: 1.221e-01, ELBO: -1.042e+06
# Cur diff delta = 1027.55810546875
# Cur diff sigma = 0.005746746901422739
# Cur diff theta = 1027.5638522156514
# ---------------------------------------
# VB, d: 400, Iter: 3-4820, s/iter: 1.192e-01, ELBO: -1.042e+06
# Cur diff delta = 1019.4852294921875
# Cur diff sigma = 0.005746735725551844
# Cur diff theta = 1019.490976227913
# ---------------------------------------
# VB, d: 400, Iter: 3-4840, s/iter: 1.198e-01, ELBO: -1.042e+06
# Cur diff delta = 1011.5291137695312
# Cur diff sigma = 0.005746742244809866
# Cur diff theta = 1011.5348605117761
# ---------------------------------------
# VB, d: 400, Iter: 3-4860, s/iter: 1.199e-01, ELBO: -1.042e+06
# Cur diff delta = 1003.6871948242188
# Cur diff sigma = 0.005746735259890556
# Cur diff theta = 1003.6929415594786
# ---------------------------------------
# VB, d: 400, Iter: 3-4880, s/iter: 1.246e-01, ELBO: -1.041e+06
# Cur diff delta = 995.9569702148438
# Cur diff sigma = 0.00574675016105175
# Cur diff theta = 995.9627169650048
# ---------------------------------------
# VB, d: 400, Iter: 3-4900, s/iter: 1.275e-01, ELBO: -1.041e+06
# Cur diff delta = 988.3363037109375
# Cur diff sigma = 0.005746754352003336
# Cur diff theta = 988.3420504652895
# ---------------------------------------
# VB, d: 400, Iter: 3-4920, s/iter: 1.171e-01, ELBO: -1.041e+06
# Cur diff delta = 980.8236083984375
# Cur diff sigma = 0.005746763665229082
# Cur diff theta = 980.8293551621027
# ---------------------------------------
# VB, d: 400, Iter: 3-4940, s/iter: 1.184e-01, ELBO: -1.041e+06
# Cur diff delta = 973.4179077148438
# Cur diff sigma = 0.005746760871261358
# Cur diff theta = 973.423654475715
# ---------------------------------------
# VB, d: 400, Iter: 3-4960, s/iter: 1.209e-01, ELBO: -1.041e+06
# Cur diff delta = 966.1182250976562
# Cur diff sigma = 0.00574676226824522
# Cur diff theta = 966.1239718599245
# ---------------------------------------
# VB, d: 400, Iter: 3-4980, s/iter: 1.231e-01, ELBO: -1.041e+06
# Cur diff delta = 958.921630859375
# Cur diff sigma = 0.005746772978454828
# Cur diff theta = 958.9273776323535
# ---------------------------------------
# VB, d: 400, Iter: 3-5000, s/iter: 1.185e-01, ELBO: -1.041e+06
# Cur diff delta = 951.8283081054688
# Cur diff sigma = 0.0057467687875032425
# Cur diff theta = 951.8340548742563
# ---------------------------------------
# Model VB, test = 0, result delta diff = 917.8204345703125
# Model VB, test = 0, result sigma diff = 0.004737171810120344
# Model VB, test = 0, result theta diff = 917.8251953125
# Model VB, test = 1, result delta diff = 909.8404541015625
# Model VB, test = 1, result sigma diff = 0.005408890545368195
# Model VB, test = 1, result theta diff = 909.8458862304688
# Model VB, test = 2, result delta diff = 951.8282470703125
# Model VB, test = 2, result sigma diff = 0.005746771115809679
# Model VB, test = 2, result theta diff = 951.833984375

# %%
model_names = ['VB']
diff_delta_results = {}
diff_sigma_results = {}
diff_results = {}
for name in model_names:
    diff_delta_tests = np.zeros(params['n_tests'])
    diff_sigma_tests = np.zeros(params['n_tests'])
    diff_tests = np.zeros(params['n_tests'])
    for i in range(params['n_tests']):
        file_name = name + '_train_' + str(i) + '.p'
        diff_path = os.path.join('save', str(params['dims'][0]), file_name)
        with open(diff_path, 'rb') as f:
            data = pickle.load(f)
            elbo = data['elbo']
            diff_delta = data['diff_delta']
            diff_sigma = data['diff_sigma']
            diff = diff_delta + diff_sigma
            diff_delta_is_not_nan = diff_delta[~np.isnan(diff_delta)]
            diff_sigma_is_not_nan = diff_sigma[~np.isnan(diff_sigma)]
            diff_is_not_nan = diff[~np.isnan(diff)]
            diff_delta_tests[i] = diff_delta_is_not_nan[-1]
            diff_sigma_tests[i] = diff_sigma_is_not_nan[-1]
            diff_tests[i] = diff_is_not_nan[-1]
    diff_delta_results[name] = diff_delta_tests
    diff_sigma_results[name] = diff_sigma_tests
    diff_results[name] = diff_tests
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, diff delta = {diff_delta_tests}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, diff sigma = {diff_sigma_tests}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, diff = {diff_tests}")
# Out:
# Model = VB, dimensionality = 400, diff delta = [917.82025146 909.840271   951.82830811]
# Model = VB, dimensionality = 400, diff sigma = [0.00473717 0.00540889 0.00574677]
# Model = VB, dimensionality = 400, diff = [917.82501221 909.84570312 951.83404541]

# %%
for name in model_names:
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, mean diff delta = {diff_delta_results[name].mean()}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, mean diff sigma = {diff_sigma_results[name].mean()}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, mean diff = {diff_results[name].mean()}")
# Out:
# Model = VB, dimensionality = 400, mean diff delta = 926.4962768554688
# Model = VB, dimensionality = 400, mean diff sigma = 0.005297609294454257
# Model = VB, dimensionality = 400, mean diff = 926.5015869140625

# %%
def run_test(d, params, 
             batch_size=256,
             clip_value=None,
             dtype=torch.float32, 
             device=torch.device("cpu")):
    """ 
    Run the gaussian test with dimension d 
    """

    ######### Problem Specification

    # Data generation parameters
    prior_mu_z = torch.zeros(d, dtype=dtype)    # Prior mean
    prior_sigma_z = torch.eye(d, dtype=dtype)   # Prior covariance matrix

    # True model parameters
    num_range = torch.arange(-(d-1)/2, (d+1)/2, dtype=dtype)

    t_delta =  num_range / 5 

    print(f"true delta = {t_delta.numpy()}")

    if d == 1:
        t_sigma = torch.ones(1, dtype=dtype)
    else: 
        # Allow sigma to range from 0.1 to 1
        t_sigma = 36/(10*(d-1)**2) * num_range**2 + 0.1 
    print(f"true sigma = {t_sigma.numpy()}")

    ######### Variable Initialization

    # Initial model parameters - same across all methods
    init_delta = prior_mu_z.clone().to(device)
    init_log_sigma = 3 * torch.ones(d).to(device)

    # Initial HVAE variational parameters
    init_T = torch.tensor(5., dtype=dtype, device=device)
    init_eps = 0.005 * torch.ones(d, dtype=dtype)
    max_eps = params['max_eps'] * torch.ones(d, dtype=dtype)
    init_logit_eps = torch.log(init_eps/(max_eps - init_eps)).to(device)
    init_log_T_0 = torch.log(init_T - 1)

    # Initial NF variational parameters
    init_u_pre_reparam = torch.tensor(scipy.stats.truncnorm.rvs(-2, 2, 
                                                                scale=0.1, 
                                                                size=d),
                                      dtype=dtype, device=device)
    init_w = torch.tensor(scipy.stats.truncnorm.rvs(-2, 2, scale=0.1, size=d),
                          dtype=dtype, device=device)
    init_b = torch.tensor(0.1, dtype=dtype, device=device)

    # Initial VAE parameters
    init_mu_z = prior_mu_z.clone()
    init_log_sigma_z = torch.ones(d, dtype=dtype)

    ######### Set up models
    init_params = [[init_delta, init_log_sigma],
                   [init_delta, init_log_sigma]]
    
    hid_dim = d + 100
    IAF_model = IAF(params,
        ['delta', 'log_sigma'],
        init_params[0], 
        'IAF', d, 1, hid_dim)

    #model_list = [HVAE_model_1, HVAE_model_2, NF_model_1]
    #model_list = [HVAE_model_1, NF_model_1]
    model_list = [IAF_model]

    print("Models were initialized!")
    
    ######### Generate Training Data & Save - One for each test

    train_data_list = []

    for i in range(params['n_tests']):
        z = MultivariateNormal(prior_mu_z, prior_sigma_z).sample()
        x = MultivariateNormal(z + t_delta, 
                               torch.diag(t_sigma**2)).sample([params['n_data']])
        x = x.to(device)
        train_data_list.append(x)

    # Folder should have already been created in the initializations
    data_path = os.path.join('save', str(d), 'train_data.p')
    pickle.dump(train_data_list, open(data_path, 'wb')) 

    # Store the final parameter values for all test runs in this dictionary
    final_params = {}

    for i in range(len(model_list)):
        final_values = []
        m = model_list[i]
        model_init_params = init_params[i]

        for j in range(params['n_tests']):
            print("------------------------------------------------------")
            print(f"Test = {j}")
            print("------------------------------------------------------")
            m._reinitialize(model_init_params)
            gaussian_data = gaussian_dataset(train_data_list[j])
            train_dataloader = DataLoader(gaussian_data, batch_size=batch_size,
                                          shuffle=False, num_workers=0)
            (delta, sigma) = m.train(train_dataloader, j, 
                                     t_delta, t_sigma,
                                     clip_value)
            final_values.append((delta, sigma))

        final_params[m.model_name] = final_values.copy()

    ######### Test models using difference between parameters

    param_diffs = {}

    for m in model_list:
        
        diffs = []

        for i in range(params['n_tests']):
            delta = final_params[m.model_name][i][0]
            sigma = final_params[m.model_name][i][1]

            delta_diff = np.sum((delta - t_delta.numpy())**2)
            sigma_diff = np.sum((sigma - t_sigma.numpy())**2)
            theta_diff = delta_diff + sigma_diff
            print(f"Model {m.model_name}, test = {i}, result delta diff = {delta_diff}")
            print(f"Model {m.model_name}, test = {i}, result sigma diff = {sigma_diff}")
            print(f"Model {m.model_name}, test = {i}, result theta diff = {theta_diff}")

            diffs.append((delta_diff, sigma_diff, theta_diff))

        param_diffs[m.model_name] = diffs.copy()

    # Save parameter differences in a pickle file
    diff_path = os.path.join('save', str(d), 'all_diffs.p')
    pickle.dump(param_diffs, open(diff_path, 'wb'))

# %%
device = torch.device("cpu")
dtype = torch.float32
clip_value = None
batch_size = 256

# %%
params = {

    # PROBLEM SPECIFICATION
    #'dims': [1, 2, 3, 5, 11, 25, 51, 101, 201, 301], # Dimensions to test
    'dims': [25],
    'n_data': 10000,                                 # Number of data points

    # TEST HYPERPARAMETERS
    'n_tests': 3,      # Number of experiments to run

    # GLOBAL OPTIMIZATION PARAMETERS
    'n_iter': 2000,    # Number of optimization iterations
    'n_batch': 10,      # Number of points for ELBO estimate
    'rms_eta': 0.001,   # Stepsize for RMSProp
    'save_every': 20,   # Save parameter information every so often
    'print_every': 20, # Print less often than save

    # HVAE HYPERPARAMETERS
    'HVAE_K_1': 1,    # Number of leapfrog/cooling steps for HVAE flow 1
    'HVAE_K_2': 10,   # Number of leapfrog/cooling steps for HVAE flow 2
    'max_eps': 0.5,   # Maximum leapfrog step size per dimension 

    # NF HYPERPARAMETERS
    'NF_K_1': 1,    # Number of flow steps for NF flow 1
    'NF_K_2': 30,   # Number of flow steps for NF flow 2
    
}

# %%
dims = params['dims']
seed = 12345
np.random.seed(seed)
torch.manual_seed(seed)
for d in dims:
    print('**** Running test for d={0:d} ****'.format(d))
    run_test(d, params, batch_size, clip_value, dtype, device)
# Out:
# **** Running test for d=25 ****
# true delta = [-2.4 -2.2 -2.  -1.8 -1.6 -1.4 -1.2 -1.  -0.8 -0.6 -0.4 -0.2  0.   0.2
#   0.4  0.6  0.8  1.   1.2  1.4  1.6  1.8  2.   2.2  2.4]
# true sigma = [1.         0.85625005 0.725      0.60625005 0.5        0.40625
#  0.32500002 0.25625    0.2        0.15625    0.125      0.10625
#  0.1        0.10625    0.125      0.15625    0.2        0.25625
#  0.32500002 0.40625    0.5        0.60625005 0.725      0.85625005
#  1.        ]
# Models were initialized!
# ------------------------------------------------------
# Test = 0
# ------------------------------------------------------
# Init diff delta = 52.0
# Init diff sigma = 9665.5205078125
# Init diff theta = 9717.5205078125
# IAF, d: 25, Iter: 1-20, s/iter: 8.105e-02, ELBO: -7.605e+05
# Cur diff delta = 26.17352867126465
# Cur diff sigma = 1461.0028076171875
# Cur diff theta = 1487.1763362884521
# ---------------------------------------
# IAF, d: 25, Iter: 1-40, s/iter: 8.028e-02, ELBO: -5.676e+05
# Cur diff delta = 22.280956268310547
# Cur diff sigma = 264.5251159667969
# Cur diff theta = 286.8060722351074
# ---------------------------------------
# IAF, d: 25, Iter: 1-60, s/iter: 8.686e-02, ELBO: -3.894e+05
# Cur diff delta = 25.28591537475586
# Cur diff sigma = 41.400089263916016
# Cur diff theta = 66.68600463867188
# ---------------------------------------
# IAF, d: 25, Iter: 1-80, s/iter: 7.723e-02, ELBO: -2.613e+05
# Cur diff delta = 25.86309814453125
# Cur diff sigma = 5.810615062713623
# Cur diff theta = 31.673713207244873
# ---------------------------------------
# IAF, d: 25, Iter: 1-100, s/iter: 7.658e-02, ELBO: -1.902e+05
# Cur diff delta = 25.859647750854492
# Cur diff sigma = 1.533596158027649
# Cur diff theta = 27.39324390888214
# ---------------------------------------
# IAF, d: 25, Iter: 1-120, s/iter: 7.699e-02, ELBO: -1.660e+05
# Cur diff delta = 25.867206573486328
# Cur diff sigma = 1.1501880884170532
# Cur diff theta = 27.01739466190338
# ---------------------------------------
# IAF, d: 25, Iter: 1-140, s/iter: 7.781e-02, ELBO: -1.652e+05
# Cur diff delta = 25.86159896850586
# Cur diff sigma = 1.1403374671936035
# Cur diff theta = 27.001936435699463
# ---------------------------------------
# IAF, d: 25, Iter: 1-160, s/iter: 8.145e-02, ELBO: -1.652e+05
# Cur diff delta = 25.862051010131836
# Cur diff sigma = 1.1401184797286987
# Cur diff theta = 27.002169489860535
# ---------------------------------------
# IAF, d: 25, Iter: 1-180, s/iter: 7.817e-02, ELBO: -1.652e+05
# Cur diff delta = 25.86290168762207
# Cur diff sigma = 1.1399855613708496
# Cur diff theta = 27.00288724899292
# ---------------------------------------
# IAF, d: 25, Iter: 1-200, s/iter: 7.990e-02, ELBO: -1.652e+05
# Cur diff delta = 25.86206817626953
# Cur diff sigma = 1.1400858163833618
# Cur diff theta = 27.002153992652893
# ---------------------------------------
# IAF, d: 25, Iter: 1-220, s/iter: 8.466e-02, ELBO: -1.652e+05
# Cur diff delta = 25.864789962768555
# Cur diff sigma = 1.139835238456726
# Cur diff theta = 27.00462520122528
# ---------------------------------------
# IAF, d: 25, Iter: 1-240, s/iter: 8.435e-02, ELBO: -1.652e+05
# Cur diff delta = 25.86745262145996
# Cur diff sigma = 1.140015959739685
# Cur diff theta = 27.007468581199646
# ---------------------------------------
# IAF, d: 25, Iter: 1-260, s/iter: 8.257e-02, ELBO: -1.652e+05
# Cur diff delta = 25.870182037353516
# Cur diff sigma = 1.1398361921310425
# Cur diff theta = 27.010018229484558
# ---------------------------------------
# IAF, d: 25, Iter: 1-280, s/iter: 7.821e-02, ELBO: -1.651e+05
# Cur diff delta = 25.868444442749023
# Cur diff sigma = 1.140505313873291
# Cur diff theta = 27.008949756622314
# ---------------------------------------
# IAF, d: 25, Iter: 1-300, s/iter: 7.867e-02, ELBO: -1.652e+05
# Cur diff delta = 25.869823455810547
# Cur diff sigma = 1.1399105787277222
# Cur diff theta = 27.00973403453827
# ---------------------------------------
# IAF, d: 25, Iter: 1-320, s/iter: 7.944e-02, ELBO: -1.651e+05
# Cur diff delta = 25.873212814331055
# Cur diff sigma = 1.1397831439971924
# Cur diff theta = 27.012995958328247
# ---------------------------------------
# IAF, d: 25, Iter: 1-340, s/iter: 8.351e-02, ELBO: -1.651e+05
# Cur diff delta = 25.867773056030273
# Cur diff sigma = 1.1400312185287476
# Cur diff theta = 27.00780427455902
# ---------------------------------------
# IAF, d: 25, Iter: 1-360, s/iter: 8.136e-02, ELBO: -1.651e+05
# Cur diff delta = 25.86634635925293
# Cur diff sigma = 1.1396331787109375
# Cur diff theta = 27.005979537963867
# ---------------------------------------
# IAF, d: 25, Iter: 1-380, s/iter: 8.188e-02, ELBO: -1.652e+05
# Cur diff delta = 25.873287200927734
# Cur diff sigma = 1.1403470039367676
# Cur diff theta = 27.013634204864502
# ---------------------------------------
# IAF, d: 25, Iter: 1-400, s/iter: 9.465e-02, ELBO: -1.651e+05
# Cur diff delta = 25.864355087280273
# Cur diff sigma = 1.1392598152160645
# Cur diff theta = 27.003614902496338
# ---------------------------------------
# IAF, d: 25, Iter: 1-420, s/iter: 9.017e-02, ELBO: -1.651e+05
# Cur diff delta = 25.869461059570312
# Cur diff sigma = 1.1401586532592773
# Cur diff theta = 27.00961971282959
# ---------------------------------------
# IAF, d: 25, Iter: 1-440, s/iter: 8.470e-02, ELBO: -1.651e+05
# Cur diff delta = 25.868610382080078
# Cur diff sigma = 1.1401511430740356
# Cur diff theta = 27.008761525154114
# ---------------------------------------
# IAF, d: 25, Iter: 1-460, s/iter: 1.007e-01, ELBO: -1.651e+05
# Cur diff delta = 25.870954513549805
# Cur diff sigma = 1.139543890953064
# Cur diff theta = 27.01049840450287
# ---------------------------------------
# IAF, d: 25, Iter: 1-480, s/iter: 9.662e-02, ELBO: -1.651e+05
# Cur diff delta = 25.86473274230957
# Cur diff sigma = 1.1395840644836426
# Cur diff theta = 27.004316806793213
# ---------------------------------------
# IAF, d: 25, Iter: 1-500, s/iter: 8.460e-02, ELBO: -1.651e+05
# Cur diff delta = 25.866018295288086
# Cur diff sigma = 1.1397074460983276
# Cur diff theta = 27.005725741386414
# ---------------------------------------
# IAF, d: 25, Iter: 1-520, s/iter: 8.687e-02, ELBO: -1.651e+05
# Cur diff delta = 25.869434356689453
# Cur diff sigma = 1.1393206119537354
# Cur diff theta = 27.00875496864319
# ---------------------------------------
# IAF, d: 25, Iter: 1-540, s/iter: 8.534e-02, ELBO: -1.651e+05
# Cur diff delta = 25.86246681213379
# Cur diff sigma = 1.1396886110305786
# Cur diff theta = 27.002155423164368
# ---------------------------------------
# IAF, d: 25, Iter: 1-560, s/iter: 8.457e-02, ELBO: -1.651e+05
# Cur diff delta = 25.86943244934082
# Cur diff sigma = 1.1394239664077759
# Cur diff theta = 27.008856415748596
# ---------------------------------------
# IAF, d: 25, Iter: 1-580, s/iter: 8.373e-02, ELBO: -1.651e+05
# Cur diff delta = 25.867313385009766
# Cur diff sigma = 1.1395844221115112
# Cur diff theta = 27.006897807121277
# ---------------------------------------
# IAF, d: 25, Iter: 1-600, s/iter: 8.647e-02, ELBO: -1.651e+05
# Cur diff delta = 25.86810302734375
# Cur diff sigma = 1.1391748189926147
# Cur diff theta = 27.007277846336365
# ---------------------------------------
# IAF, d: 25, Iter: 1-620, s/iter: 8.553e-02, ELBO: -1.651e+05
# Cur diff delta = 25.869342803955078
# Cur diff sigma = 1.139467716217041
# Cur diff theta = 27.00881052017212
# ---------------------------------------
# IAF, d: 25, Iter: 1-640, s/iter: 8.702e-02, ELBO: -1.651e+05
# Cur diff delta = 25.86863136291504
# Cur diff sigma = 1.139465570449829
# Cur diff theta = 27.008096933364868
# ---------------------------------------
# IAF, d: 25, Iter: 1-660, s/iter: 8.666e-02, ELBO: -1.651e+05
# Cur diff delta = 25.865488052368164
# Cur diff sigma = 1.1396642923355103
# Cur diff theta = 27.005152344703674
# ---------------------------------------
# IAF, d: 25, Iter: 1-680, s/iter: 8.699e-02, ELBO: -1.651e+05
# Cur diff delta = 25.87342071533203
# Cur diff sigma = 1.139625072479248
# Cur diff theta = 27.01304578781128
# ---------------------------------------
# IAF, d: 25, Iter: 1-700, s/iter: 8.716e-02, ELBO: -1.651e+05
# Cur diff delta = 25.864683151245117
# Cur diff sigma = 1.139565110206604
# Cur diff theta = 27.00424826145172
# ---------------------------------------
# IAF, d: 25, Iter: 1-720, s/iter: 8.628e-02, ELBO: -1.651e+05
# Cur diff delta = 25.87023162841797
# Cur diff sigma = 1.139143466949463
# Cur diff theta = 27.00937509536743
# ---------------------------------------
# IAF, d: 25, Iter: 1-740, s/iter: 8.688e-02, ELBO: -1.651e+05
# Cur diff delta = 25.87478256225586
# Cur diff sigma = 1.1394635438919067
# Cur diff theta = 27.014246106147766
# ---------------------------------------
# IAF, d: 25, Iter: 1-760, s/iter: 9.783e-02, ELBO: -1.651e+05
# Cur diff delta = 25.8691349029541
# Cur diff sigma = 1.1395602226257324
# Cur diff theta = 27.008695125579834
# ---------------------------------------
# IAF, d: 25, Iter: 1-780, s/iter: 9.506e-02, ELBO: -1.651e+05
# Cur diff delta = 25.869054794311523
# Cur diff sigma = 1.139688491821289
# Cur diff theta = 27.008743286132812
# ---------------------------------------
# IAF, d: 25, Iter: 1-800, s/iter: 8.648e-02, ELBO: -1.651e+05
# Cur diff delta = 25.876312255859375
# Cur diff sigma = 1.139639973640442
# Cur diff theta = 27.015952229499817
# ---------------------------------------
# IAF, d: 25, Iter: 1-820, s/iter: 9.013e-02, ELBO: -1.651e+05
# Cur diff delta = 25.86433219909668
# Cur diff sigma = 1.1396496295928955
# Cur diff theta = 27.003981828689575
# ---------------------------------------
# IAF, d: 25, Iter: 1-840, s/iter: 9.348e-02, ELBO: -1.651e+05
# Cur diff delta = 25.867769241333008
# Cur diff sigma = 1.1393091678619385
# Cur diff theta = 27.007078409194946
# ---------------------------------------
# IAF, d: 25, Iter: 1-860, s/iter: 9.095e-02, ELBO: -1.651e+05
# Cur diff delta = 25.870471954345703
# Cur diff sigma = 1.1394882202148438
# Cur diff theta = 27.009960174560547
# ---------------------------------------
# IAF, d: 25, Iter: 1-880, s/iter: 9.711e-02, ELBO: -1.651e+05
# Cur diff delta = 25.8640193939209
# Cur diff sigma = 1.1395156383514404
# Cur diff theta = 27.00353503227234
# ---------------------------------------
# IAF, d: 25, Iter: 1-900, s/iter: 9.904e-02, ELBO: -1.651e+05
# Cur diff delta = 25.88405990600586
# Cur diff sigma = 1.1392310857772827
# Cur diff theta = 27.023290991783142
# ---------------------------------------
# IAF, d: 25, Iter: 1-920, s/iter: 8.488e-02, ELBO: -1.651e+05
# Cur diff delta = 25.857791900634766
# Cur diff sigma = 1.1392308473587036
# Cur diff theta = 26.99702274799347
# ---------------------------------------
# IAF, d: 25, Iter: 1-940, s/iter: 9.475e-02, ELBO: -1.651e+05
# Cur diff delta = 25.870824813842773
# Cur diff sigma = 1.1395548582077026
# Cur diff theta = 27.010379672050476
# ---------------------------------------
# IAF, d: 25, Iter: 1-960, s/iter: 9.871e-02, ELBO: -1.651e+05
# Cur diff delta = 25.869028091430664
# Cur diff sigma = 1.139371633529663
# Cur diff theta = 27.008399724960327
# ---------------------------------------
# IAF, d: 25, Iter: 1-980, s/iter: 8.791e-02, ELBO: -1.651e+05
# Cur diff delta = 25.869016647338867
# Cur diff sigma = 1.1394362449645996
# Cur diff theta = 27.008452892303467
# ---------------------------------------
# IAF, d: 25, Iter: 1-1000, s/iter: 8.692e-02, ELBO: -1.651e+05
# Cur diff delta = 25.862884521484375
# Cur diff sigma = 1.1394784450531006
# Cur diff theta = 27.002362966537476
# ---------------------------------------
# IAF, d: 25, Iter: 1-1020, s/iter: 8.522e-02, ELBO: -1.651e+05
# Cur diff delta = 25.879453659057617
# Cur diff sigma = 1.1390169858932495
# Cur diff theta = 27.018470644950867
# ---------------------------------------
# IAF, d: 25, Iter: 1-1040, s/iter: 8.745e-02, ELBO: -1.651e+05
# Cur diff delta = 25.874269485473633
# Cur diff sigma = 1.139801263809204
# Cur diff theta = 27.014070749282837
# ---------------------------------------
# IAF, d: 25, Iter: 1-1060, s/iter: 8.763e-02, ELBO: -1.651e+05
# Cur diff delta = 25.866445541381836
# Cur diff sigma = 1.139387845993042
# Cur diff theta = 27.005833387374878
# ---------------------------------------
# IAF, d: 25, Iter: 1-1080, s/iter: 9.317e-02, ELBO: -1.651e+05
# Cur diff delta = 25.87261199951172
# Cur diff sigma = 1.1392157077789307
# Cur diff theta = 27.01182770729065
# ---------------------------------------
# IAF, d: 25, Iter: 1-1100, s/iter: 9.091e-02, ELBO: -1.651e+05
# Cur diff delta = 25.866012573242188
# Cur diff sigma = 1.1394399404525757
# Cur diff theta = 27.005452513694763
# ---------------------------------------
# IAF, d: 25, Iter: 1-1120, s/iter: 9.191e-02, ELBO: -1.651e+05
# Cur diff delta = 25.868179321289062
# Cur diff sigma = 1.1394037008285522
# Cur diff theta = 27.007583022117615
# ---------------------------------------
# IAF, d: 25, Iter: 1-1140, s/iter: 8.604e-02, ELBO: -1.651e+05
# Cur diff delta = 25.862468719482422
# Cur diff sigma = 1.139419436454773
# Cur diff theta = 27.001888155937195
# ---------------------------------------
# IAF, d: 25, Iter: 1-1160, s/iter: 8.605e-02, ELBO: -1.651e+05
# Cur diff delta = 25.867008209228516
# Cur diff sigma = 1.1392472982406616
# Cur diff theta = 27.006255507469177
# ---------------------------------------
# IAF, d: 25, Iter: 1-1180, s/iter: 9.664e-02, ELBO: -1.651e+05
# Cur diff delta = 25.875473022460938
# Cur diff sigma = 1.13927161693573
# Cur diff theta = 27.014744639396667
# ---------------------------------------
# IAF, d: 25, Iter: 1-1200, s/iter: 8.644e-02, ELBO: -1.651e+05
# Cur diff delta = 25.869915008544922
# Cur diff sigma = 1.1391234397888184
# Cur diff theta = 27.00903844833374
# ---------------------------------------
# IAF, d: 25, Iter: 1-1220, s/iter: 9.621e-02, ELBO: -1.651e+05
# Cur diff delta = 25.86385726928711
# Cur diff sigma = 1.1389689445495605
# Cur diff theta = 27.00282621383667
# ---------------------------------------
# IAF, d: 25, Iter: 1-1240, s/iter: 8.568e-02, ELBO: -1.651e+05
# Cur diff delta = 25.86835479736328
# Cur diff sigma = 1.1392961740493774
# Cur diff theta = 27.00765097141266
# ---------------------------------------
# IAF, d: 25, Iter: 1-1260, s/iter: 8.635e-02, ELBO: -1.651e+05
# Cur diff delta = 25.889095306396484
# Cur diff sigma = 1.1392276287078857
# Cur diff theta = 27.02832293510437
# ---------------------------------------
# IAF, d: 25, Iter: 1-1280, s/iter: 8.615e-02, ELBO: -1.651e+05
# Cur diff delta = 25.872150421142578
# Cur diff sigma = 1.1394153833389282
# Cur diff theta = 27.011565804481506
# ---------------------------------------
# IAF, d: 25, Iter: 1-1300, s/iter: 9.178e-02, ELBO: -1.651e+05
# Cur diff delta = 25.874053955078125
# Cur diff sigma = 1.1392652988433838
# Cur diff theta = 27.01331925392151
# ---------------------------------------
# IAF, d: 25, Iter: 1-1320, s/iter: 9.328e-02, ELBO: -1.651e+05
# Cur diff delta = 25.864376068115234
# Cur diff sigma = 1.139373540878296
# Cur diff theta = 27.00374960899353
# ---------------------------------------
# IAF, d: 25, Iter: 1-1340, s/iter: 8.704e-02, ELBO: -1.651e+05
# Cur diff delta = 25.867816925048828
# Cur diff sigma = 1.139648675918579
# Cur diff theta = 27.007465600967407
# ---------------------------------------
# IAF, d: 25, Iter: 1-1360, s/iter: 8.593e-02, ELBO: -1.651e+05
# Cur diff delta = 25.872949600219727
# Cur diff sigma = 1.1392719745635986
# Cur diff theta = 27.012221574783325
# ---------------------------------------
# IAF, d: 25, Iter: 1-1380, s/iter: 8.811e-02, ELBO: -1.651e+05
# Cur diff delta = 25.864152908325195
# Cur diff sigma = 1.138666033744812
# Cur diff theta = 27.002818942070007
# ---------------------------------------
# IAF, d: 25, Iter: 1-1400, s/iter: 8.863e-02, ELBO: -1.651e+05
# Cur diff delta = 25.86578369140625
# Cur diff sigma = 1.13869047164917
# Cur diff theta = 27.00447416305542
# ---------------------------------------
# IAF, d: 25, Iter: 1-1420, s/iter: 8.649e-02, ELBO: -1.651e+05
# Cur diff delta = 25.860584259033203
# Cur diff sigma = 1.139561414718628
# Cur diff theta = 27.00014567375183
# ---------------------------------------
# IAF, d: 25, Iter: 1-1440, s/iter: 9.867e-02, ELBO: -1.651e+05
# Cur diff delta = 25.863367080688477
# Cur diff sigma = 1.1397191286087036
# Cur diff theta = 27.00308620929718
# ---------------------------------------
# IAF, d: 25, Iter: 1-1460, s/iter: 8.699e-02, ELBO: -1.651e+05
# Cur diff delta = 25.862476348876953
# Cur diff sigma = 1.139193058013916
# Cur diff theta = 27.00166940689087
# ---------------------------------------
# IAF, d: 25, Iter: 1-1480, s/iter: 8.630e-02, ELBO: -1.651e+05
# Cur diff delta = 25.866796493530273
# Cur diff sigma = 1.1396900415420532
# Cur diff theta = 27.006486535072327
# ---------------------------------------
# IAF, d: 25, Iter: 1-1500, s/iter: 8.811e-02, ELBO: -1.651e+05
# Cur diff delta = 25.866729736328125
# Cur diff sigma = 1.1393697261810303
# Cur diff theta = 27.006099462509155
# ---------------------------------------
# IAF, d: 25, Iter: 1-1520, s/iter: 8.952e-02, ELBO: -1.651e+05
# Cur diff delta = 25.863033294677734
# Cur diff sigma = 1.1390467882156372
# Cur diff theta = 27.00208008289337
# ---------------------------------------
# IAF, d: 25, Iter: 1-1540, s/iter: 8.942e-02, ELBO: -1.651e+05
# Cur diff delta = 25.861604690551758
# Cur diff sigma = 1.1390323638916016
# Cur diff theta = 27.00063705444336
# ---------------------------------------
# IAF, d: 25, Iter: 1-1560, s/iter: 1.096e-01, ELBO: -1.651e+05
# Cur diff delta = 25.87897491455078
# Cur diff sigma = 1.139564871788025
# Cur diff theta = 27.018539786338806
# ---------------------------------------
# IAF, d: 25, Iter: 1-1580, s/iter: 1.012e-01, ELBO: -1.651e+05
# Cur diff delta = 25.871362686157227
# Cur diff sigma = 1.139326810836792
# Cur diff theta = 27.01068949699402
# ---------------------------------------
# IAF, d: 25, Iter: 1-1600, s/iter: 9.912e-02, ELBO: -1.651e+05
# Cur diff delta = 25.87767791748047
# Cur diff sigma = 1.1388400793075562
# Cur diff theta = 27.016517996788025
# ---------------------------------------
# IAF, d: 25, Iter: 1-1620, s/iter: 8.662e-02, ELBO: -1.651e+05
# Cur diff delta = 25.862407684326172
# Cur diff sigma = 1.1393624544143677
# Cur diff theta = 27.00177013874054
# ---------------------------------------
# IAF, d: 25, Iter: 1-1640, s/iter: 9.005e-02, ELBO: -1.651e+05
# Cur diff delta = 25.87153434753418
# Cur diff sigma = 1.1389954090118408
# Cur diff theta = 27.01052975654602
# ---------------------------------------
# IAF, d: 25, Iter: 1-1660, s/iter: 8.958e-02, ELBO: -1.651e+05
# Cur diff delta = 25.866802215576172
# Cur diff sigma = 1.1395817995071411
# Cur diff theta = 27.006384015083313
# ---------------------------------------
# IAF, d: 25, Iter: 1-1680, s/iter: 9.056e-02, ELBO: -1.651e+05
# Cur diff delta = 25.88067054748535
# Cur diff sigma = 1.1394444704055786
# Cur diff theta = 27.02011501789093
# ---------------------------------------
# IAF, d: 25, Iter: 1-1700, s/iter: 9.658e-02, ELBO: -1.651e+05
# Cur diff delta = 25.871196746826172
# Cur diff sigma = 1.139400839805603
# Cur diff theta = 27.010597586631775
# ---------------------------------------
# IAF, d: 25, Iter: 1-1720, s/iter: 8.833e-02, ELBO: -1.651e+05
# Cur diff delta = 25.86856460571289
# Cur diff sigma = 1.1393630504608154
# Cur diff theta = 27.007927656173706
# ---------------------------------------
# IAF, d: 25, Iter: 1-1740, s/iter: 8.675e-02, ELBO: -1.651e+05
# Cur diff delta = 25.85951042175293
# Cur diff sigma = 1.1395304203033447
# Cur diff theta = 26.999040842056274
# ---------------------------------------
# IAF, d: 25, Iter: 1-1760, s/iter: 8.615e-02, ELBO: -1.651e+05
# Cur diff delta = 25.868053436279297
# Cur diff sigma = 1.1390246152877808
# Cur diff theta = 27.007078051567078
# ---------------------------------------
# IAF, d: 25, Iter: 1-1780, s/iter: 9.081e-02, ELBO: -1.651e+05
# Cur diff delta = 25.866470336914062
# Cur diff sigma = 1.1396386623382568
# Cur diff theta = 27.00610899925232
# ---------------------------------------
# IAF, d: 25, Iter: 1-1800, s/iter: 8.893e-02, ELBO: -1.651e+05
# Cur diff delta = 25.87040901184082
# Cur diff sigma = 1.1390186548233032
# Cur diff theta = 27.009427666664124
# ---------------------------------------
# IAF, d: 25, Iter: 1-1820, s/iter: 8.922e-02, ELBO: -1.651e+05
# Cur diff delta = 25.87190055847168
# Cur diff sigma = 1.139318585395813
# Cur diff theta = 27.011219143867493
# ---------------------------------------
# IAF, d: 25, Iter: 1-1840, s/iter: 8.782e-02, ELBO: -1.651e+05
# Cur diff delta = 25.87572479248047
# Cur diff sigma = 1.1390578746795654
# Cur diff theta = 27.014782667160034
# ---------------------------------------
# IAF, d: 25, Iter: 1-1860, s/iter: 8.692e-02, ELBO: -1.651e+05
# Cur diff delta = 25.872495651245117
# Cur diff sigma = 1.1396484375
# Cur diff theta = 27.012144088745117
# ---------------------------------------
# IAF, d: 25, Iter: 1-1880, s/iter: 8.654e-02, ELBO: -1.651e+05
# Cur diff delta = 25.87331199645996
# Cur diff sigma = 1.1393474340438843
# Cur diff theta = 27.012659430503845
# ---------------------------------------
# IAF, d: 25, Iter: 1-1900, s/iter: 8.592e-02, ELBO: -1.651e+05
# Cur diff delta = 25.865049362182617
# Cur diff sigma = 1.1391870975494385
# Cur diff theta = 27.004236459732056
# ---------------------------------------
# IAF, d: 25, Iter: 1-1920, s/iter: 8.698e-02, ELBO: -1.651e+05
# Cur diff delta = 25.86618423461914
# Cur diff sigma = 1.1397463083267212
# Cur diff theta = 27.005930542945862
# ---------------------------------------
# IAF, d: 25, Iter: 1-1940, s/iter: 8.847e-02, ELBO: -1.651e+05
# Cur diff delta = 25.866458892822266
# Cur diff sigma = 1.139180302619934
# Cur diff theta = 27.0056391954422
# ---------------------------------------
# IAF, d: 25, Iter: 1-1960, s/iter: 8.721e-02, ELBO: -1.651e+05
# Cur diff delta = 25.867326736450195
# Cur diff sigma = 1.1392544507980347
# Cur diff theta = 27.00658118724823
# ---------------------------------------
# IAF, d: 25, Iter: 1-1980, s/iter: 8.720e-02, ELBO: -1.651e+05
# Cur diff delta = 25.872459411621094
# Cur diff sigma = 1.1391156911849976
# Cur diff theta = 27.01157510280609
# ---------------------------------------
# IAF, d: 25, Iter: 1-2000, s/iter: 8.827e-02, ELBO: -1.651e+05
# Cur diff delta = 25.88096809387207
# Cur diff sigma = 1.1393389701843262
# Cur diff theta = 27.020307064056396
# ---------------------------------------
# ------------------------------------------------------
# Test = 1
# ------------------------------------------------------
# Init diff delta = 52.0
# Init diff sigma = 9665.5205078125
# Init diff theta = 9717.5205078125
# IAF, d: 25, Iter: 2-20, s/iter: 8.111e-02, ELBO: -7.608e+05
# Cur diff delta = 22.7154483795166
# Cur diff sigma = 1461.434814453125
# Cur diff theta = 1484.1502628326416
# ---------------------------------------
# IAF, d: 25, Iter: 2-40, s/iter: 7.800e-02, ELBO: -5.681e+05
# Cur diff delta = 16.9912109375
# Cur diff sigma = 264.707763671875
# Cur diff theta = 281.698974609375
# ---------------------------------------
# IAF, d: 25, Iter: 2-60, s/iter: 7.833e-02, ELBO: -3.897e+05
# Cur diff delta = 19.24750328063965
# Cur diff sigma = 41.43399429321289
# Cur diff theta = 60.68149757385254
# ---------------------------------------
# IAF, d: 25, Iter: 2-80, s/iter: 7.720e-02, ELBO: -2.613e+05
# Cur diff delta = 20.49776268005371
# Cur diff sigma = 5.798086166381836
# Cur diff theta = 26.295848846435547
# ---------------------------------------
# IAF, d: 25, Iter: 2-100, s/iter: 7.874e-02, ELBO: -1.903e+05
# Cur diff delta = 20.54735565185547
# Cur diff sigma = 1.5196352005004883
# Cur diff theta = 22.066990852355957
# ---------------------------------------
# IAF, d: 25, Iter: 2-120, s/iter: 7.726e-02, ELBO: -1.662e+05
# Cur diff delta = 20.54900550842285
# Cur diff sigma = 1.1374573707580566
# Cur diff theta = 21.686462879180908
# ---------------------------------------
# IAF, d: 25, Iter: 2-140, s/iter: 7.770e-02, ELBO: -1.653e+05
# Cur diff delta = 20.55638885498047
# Cur diff sigma = 1.1275520324707031
# Cur diff theta = 21.683940887451172
# ---------------------------------------
# IAF, d: 25, Iter: 2-160, s/iter: 7.677e-02, ELBO: -1.653e+05
# Cur diff delta = 20.55020523071289
# Cur diff sigma = 1.1271463632583618
# Cur diff theta = 21.677351593971252
# ---------------------------------------
# IAF, d: 25, Iter: 2-180, s/iter: 7.642e-02, ELBO: -1.653e+05
# Cur diff delta = 20.547319412231445
# Cur diff sigma = 1.1275140047073364
# Cur diff theta = 21.67483341693878
# ---------------------------------------
# IAF, d: 25, Iter: 2-200, s/iter: 8.878e-02, ELBO: -1.653e+05
# Cur diff delta = 20.550443649291992
# Cur diff sigma = 1.126957654953003
# Cur diff theta = 21.677401304244995
# ---------------------------------------
# IAF, d: 25, Iter: 2-220, s/iter: 7.785e-02, ELBO: -1.653e+05
# Cur diff delta = 20.55132484436035
# Cur diff sigma = 1.1270323991775513
# Cur diff theta = 21.678357243537903
# ---------------------------------------
# IAF, d: 25, Iter: 2-240, s/iter: 7.829e-02, ELBO: -1.653e+05
# Cur diff delta = 20.544042587280273
# Cur diff sigma = 1.1276178359985352
# Cur diff theta = 21.67166042327881
# ---------------------------------------
# IAF, d: 25, Iter: 2-260, s/iter: 8.170e-02, ELBO: -1.653e+05
# Cur diff delta = 20.556455612182617
# Cur diff sigma = 1.1268761157989502
# Cur diff theta = 21.683331727981567
# ---------------------------------------
# IAF, d: 25, Iter: 2-280, s/iter: 8.014e-02, ELBO: -1.653e+05
# Cur diff delta = 20.552337646484375
# Cur diff sigma = 1.1267813444137573
# Cur diff theta = 21.679118990898132
# ---------------------------------------
# IAF, d: 25, Iter: 2-300, s/iter: 7.944e-02, ELBO: -1.653e+05
# Cur diff delta = 20.554431915283203
# Cur diff sigma = 1.1270626783370972
# Cur diff theta = 21.6814945936203
# ---------------------------------------
# IAF, d: 25, Iter: 2-320, s/iter: 9.018e-02, ELBO: -1.653e+05
# Cur diff delta = 20.557552337646484
# Cur diff sigma = 1.126760721206665
# Cur diff theta = 21.68431305885315
# ---------------------------------------
# IAF, d: 25, Iter: 2-340, s/iter: 8.265e-02, ELBO: -1.653e+05
# Cur diff delta = 20.552907943725586
# Cur diff sigma = 1.1266390085220337
# Cur diff theta = 21.67954695224762
# ---------------------------------------
# IAF, d: 25, Iter: 2-360, s/iter: 8.238e-02, ELBO: -1.652e+05
# Cur diff delta = 20.55019760131836
# Cur diff sigma = 1.1264569759368896
# Cur diff theta = 21.67665457725525
# ---------------------------------------
# IAF, d: 25, Iter: 2-380, s/iter: 8.063e-02, ELBO: -1.652e+05
# Cur diff delta = 20.549598693847656
# Cur diff sigma = 1.126569390296936
# Cur diff theta = 21.676168084144592
# ---------------------------------------
# IAF, d: 25, Iter: 2-400, s/iter: 9.219e-02, ELBO: -1.652e+05
# Cur diff delta = 20.548280715942383
# Cur diff sigma = 1.1264443397521973
# Cur diff theta = 21.67472505569458
# ---------------------------------------
# IAF, d: 25, Iter: 2-420, s/iter: 8.347e-02, ELBO: -1.652e+05
# Cur diff delta = 20.559139251708984
# Cur diff sigma = 1.1267192363739014
# Cur diff theta = 21.685858488082886
# ---------------------------------------
# IAF, d: 25, Iter: 2-440, s/iter: 9.590e-02, ELBO: -1.652e+05
# Cur diff delta = 20.54729652404785
# Cur diff sigma = 1.126663327217102
# Cur diff theta = 21.673959851264954
# ---------------------------------------
# IAF, d: 25, Iter: 2-460, s/iter: 8.403e-02, ELBO: -1.652e+05
# Cur diff delta = 20.565000534057617
# Cur diff sigma = 1.1271793842315674
# Cur diff theta = 21.692179918289185
# ---------------------------------------
# IAF, d: 25, Iter: 2-480, s/iter: 8.528e-02, ELBO: -1.652e+05
# Cur diff delta = 20.551799774169922
# Cur diff sigma = 1.1265718936920166
# Cur diff theta = 21.67837166786194
# ---------------------------------------
# IAF, d: 25, Iter: 2-500, s/iter: 9.114e-02, ELBO: -1.652e+05
# Cur diff delta = 20.55843734741211
# Cur diff sigma = 1.1263856887817383
# Cur diff theta = 21.684823036193848
# ---------------------------------------
# IAF, d: 25, Iter: 2-520, s/iter: 8.829e-02, ELBO: -1.652e+05
# Cur diff delta = 20.564199447631836
# Cur diff sigma = 1.126630425453186
# Cur diff theta = 21.690829873085022
# ---------------------------------------
# IAF, d: 25, Iter: 2-540, s/iter: 8.428e-02, ELBO: -1.652e+05
# Cur diff delta = 20.556865692138672
# Cur diff sigma = 1.1264022588729858
# Cur diff theta = 21.683267951011658
# ---------------------------------------
# IAF, d: 25, Iter: 2-560, s/iter: 8.576e-02, ELBO: -1.652e+05
# Cur diff delta = 20.550159454345703
# Cur diff sigma = 1.1268366575241089
# Cur diff theta = 21.676996111869812
# ---------------------------------------
# IAF, d: 25, Iter: 2-580, s/iter: 8.899e-02, ELBO: -1.652e+05
# Cur diff delta = 20.557390213012695
# Cur diff sigma = 1.126220941543579
# Cur diff theta = 21.683611154556274
# ---------------------------------------
# IAF, d: 25, Iter: 2-600, s/iter: 8.618e-02, ELBO: -1.652e+05
# Cur diff delta = 20.554353713989258
# Cur diff sigma = 1.1261045932769775
# Cur diff theta = 21.680458307266235
# ---------------------------------------
# IAF, d: 25, Iter: 2-620, s/iter: 8.507e-02, ELBO: -1.652e+05
# Cur diff delta = 20.553579330444336
# Cur diff sigma = 1.1264592409133911
# Cur diff theta = 21.680038571357727
# ---------------------------------------
# IAF, d: 25, Iter: 2-640, s/iter: 8.489e-02, ELBO: -1.652e+05
# Cur diff delta = 20.558834075927734
# Cur diff sigma = 1.1259665489196777
# Cur diff theta = 21.684800624847412
# ---------------------------------------
# IAF, d: 25, Iter: 2-660, s/iter: 8.597e-02, ELBO: -1.652e+05
# Cur diff delta = 20.550840377807617
# Cur diff sigma = 1.1263647079467773
# Cur diff theta = 21.677205085754395
# ---------------------------------------
# IAF, d: 25, Iter: 2-680, s/iter: 8.550e-02, ELBO: -1.652e+05
# Cur diff delta = 20.550729751586914
# Cur diff sigma = 1.1263070106506348
# Cur diff theta = 21.67703676223755
# ---------------------------------------
# IAF, d: 25, Iter: 2-700, s/iter: 8.716e-02, ELBO: -1.652e+05
# Cur diff delta = 20.55862808227539
# Cur diff sigma = 1.1261142492294312
# Cur diff theta = 21.684742331504822
# ---------------------------------------
# IAF, d: 25, Iter: 2-720, s/iter: 1.009e-01, ELBO: -1.652e+05
# Cur diff delta = 20.55146598815918
# Cur diff sigma = 1.1263905763626099
# Cur diff theta = 21.67785656452179
# ---------------------------------------
# IAF, d: 25, Iter: 2-740, s/iter: 8.433e-02, ELBO: -1.652e+05
# Cur diff delta = 20.549781799316406
# Cur diff sigma = 1.1266372203826904
# Cur diff theta = 21.676419019699097
# ---------------------------------------
# IAF, d: 25, Iter: 2-760, s/iter: 8.477e-02, ELBO: -1.652e+05
# Cur diff delta = 20.551273345947266
# Cur diff sigma = 1.1265063285827637
# Cur diff theta = 21.67777967453003
# ---------------------------------------
# IAF, d: 25, Iter: 2-780, s/iter: 8.631e-02, ELBO: -1.652e+05
# Cur diff delta = 20.565542221069336
# Cur diff sigma = 1.1263701915740967
# Cur diff theta = 21.691912412643433
# ---------------------------------------
# IAF, d: 25, Iter: 2-800, s/iter: 9.164e-02, ELBO: -1.652e+05
# Cur diff delta = 20.550941467285156
# Cur diff sigma = 1.1262296438217163
# Cur diff theta = 21.677171111106873
# ---------------------------------------
# IAF, d: 25, Iter: 2-820, s/iter: 8.850e-02, ELBO: -1.652e+05
# Cur diff delta = 20.549375534057617
# Cur diff sigma = 1.1262069940567017
# Cur diff theta = 21.67558252811432
# ---------------------------------------
# IAF, d: 25, Iter: 2-840, s/iter: 8.650e-02, ELBO: -1.652e+05
# Cur diff delta = 20.549318313598633
# Cur diff sigma = 1.1265840530395508
# Cur diff theta = 21.675902366638184
# ---------------------------------------
# IAF, d: 25, Iter: 2-860, s/iter: 8.488e-02, ELBO: -1.652e+05
# Cur diff delta = 20.555225372314453
# Cur diff sigma = 1.1264503002166748
# Cur diff theta = 21.681675672531128
# ---------------------------------------
# IAF, d: 25, Iter: 2-880, s/iter: 9.269e-02, ELBO: -1.652e+05
# Cur diff delta = 20.559688568115234
# Cur diff sigma = 1.1266359090805054
# Cur diff theta = 21.68632447719574
# ---------------------------------------
# IAF, d: 25, Iter: 2-900, s/iter: 8.993e-02, ELBO: -1.652e+05
# Cur diff delta = 20.552724838256836
# Cur diff sigma = 1.1260881423950195
# Cur diff theta = 21.678812980651855
# ---------------------------------------
# IAF, d: 25, Iter: 2-920, s/iter: 8.484e-02, ELBO: -1.652e+05
# Cur diff delta = 20.569059371948242
# Cur diff sigma = 1.1263771057128906
# Cur diff theta = 21.695436477661133
# ---------------------------------------
# IAF, d: 25, Iter: 2-940, s/iter: 8.505e-02, ELBO: -1.652e+05
# Cur diff delta = 20.54943084716797
# Cur diff sigma = 1.1264042854309082
# Cur diff theta = 21.675835132598877
# ---------------------------------------
# IAF, d: 25, Iter: 2-960, s/iter: 1.023e-01, ELBO: -1.652e+05
# Cur diff delta = 20.552101135253906
# Cur diff sigma = 1.1265190839767456
# Cur diff theta = 21.678620219230652
# ---------------------------------------
# IAF, d: 25, Iter: 2-980, s/iter: 8.965e-02, ELBO: -1.652e+05
# Cur diff delta = 20.548389434814453
# Cur diff sigma = 1.126509428024292
# Cur diff theta = 21.674898862838745
# ---------------------------------------
# IAF, d: 25, Iter: 2-1000, s/iter: 8.535e-02, ELBO: -1.652e+05
# Cur diff delta = 20.545047760009766
# Cur diff sigma = 1.1269118785858154
# Cur diff theta = 21.67195963859558
# ---------------------------------------
# IAF, d: 25, Iter: 2-1020, s/iter: 8.717e-02, ELBO: -1.652e+05
# Cur diff delta = 20.55942153930664
# Cur diff sigma = 1.1260040998458862
# Cur diff theta = 21.685425639152527
# ---------------------------------------
# IAF, d: 25, Iter: 2-1040, s/iter: 8.710e-02, ELBO: -1.652e+05
# Cur diff delta = 20.54892349243164
# Cur diff sigma = 1.1265137195587158
# Cur diff theta = 21.675437211990356
# ---------------------------------------
# IAF, d: 25, Iter: 2-1060, s/iter: 9.018e-02, ELBO: -1.652e+05
# Cur diff delta = 20.55098533630371
# Cur diff sigma = 1.1261394023895264
# Cur diff theta = 21.677124738693237
# ---------------------------------------
# IAF, d: 25, Iter: 2-1080, s/iter: 9.153e-02, ELBO: -1.652e+05
# Cur diff delta = 20.5512638092041
# Cur diff sigma = 1.126440167427063
# Cur diff theta = 21.677703976631165
# ---------------------------------------
# IAF, d: 25, Iter: 2-1100, s/iter: 9.412e-02, ELBO: -1.652e+05
# Cur diff delta = 20.553016662597656
# Cur diff sigma = 1.126339316368103
# Cur diff theta = 21.67935597896576
# ---------------------------------------
# IAF, d: 25, Iter: 2-1120, s/iter: 8.768e-02, ELBO: -1.652e+05
# Cur diff delta = 20.562280654907227
# Cur diff sigma = 1.1261608600616455
# Cur diff theta = 21.688441514968872
# ---------------------------------------
# IAF, d: 25, Iter: 2-1140, s/iter: 8.831e-02, ELBO: -1.652e+05
# Cur diff delta = 20.557031631469727
# Cur diff sigma = 1.1264042854309082
# Cur diff theta = 21.683435916900635
# ---------------------------------------
# IAF, d: 25, Iter: 2-1160, s/iter: 9.081e-02, ELBO: -1.652e+05
# Cur diff delta = 20.558059692382812
# Cur diff sigma = 1.1258044242858887
# Cur diff theta = 21.6838641166687
# ---------------------------------------
# IAF, d: 25, Iter: 2-1180, s/iter: 9.897e-02, ELBO: -1.652e+05
# Cur diff delta = 20.56118392944336
# Cur diff sigma = 1.1266058683395386
# Cur diff theta = 21.687789797782898
# ---------------------------------------
# IAF, d: 25, Iter: 2-1200, s/iter: 8.923e-02, ELBO: -1.652e+05
# Cur diff delta = 20.55014419555664
# Cur diff sigma = 1.1266117095947266
# Cur diff theta = 21.676755905151367
# ---------------------------------------
# IAF, d: 25, Iter: 2-1220, s/iter: 8.691e-02, ELBO: -1.652e+05
# Cur diff delta = 20.552085876464844
# Cur diff sigma = 1.1264946460723877
# Cur diff theta = 21.67858052253723
# ---------------------------------------
# IAF, d: 25, Iter: 2-1240, s/iter: 8.868e-02, ELBO: -1.652e+05
# Cur diff delta = 20.55689811706543
# Cur diff sigma = 1.1263234615325928
# Cur diff theta = 21.683221578598022
# ---------------------------------------
# IAF, d: 25, Iter: 2-1260, s/iter: 9.049e-02, ELBO: -1.652e+05
# Cur diff delta = 20.552980422973633
# Cur diff sigma = 1.1260825395584106
# Cur diff theta = 21.679062962532043
# ---------------------------------------
# IAF, d: 25, Iter: 2-1280, s/iter: 9.791e-02, ELBO: -1.652e+05
# Cur diff delta = 20.557064056396484
# Cur diff sigma = 1.1262154579162598
# Cur diff theta = 21.683279514312744
# ---------------------------------------
# IAF, d: 25, Iter: 2-1300, s/iter: 9.820e-02, ELBO: -1.652e+05
# Cur diff delta = 20.557172775268555
# Cur diff sigma = 1.1263320446014404
# Cur diff theta = 21.683504819869995
# ---------------------------------------
# IAF, d: 25, Iter: 2-1320, s/iter: 9.756e-02, ELBO: -1.652e+05
# Cur diff delta = 20.558727264404297
# Cur diff sigma = 1.1267751455307007
# Cur diff theta = 21.685502409934998
# ---------------------------------------
# IAF, d: 25, Iter: 2-1340, s/iter: 9.056e-02, ELBO: -1.652e+05
# Cur diff delta = 20.55489730834961
# Cur diff sigma = 1.1264839172363281
# Cur diff theta = 21.681381225585938
# ---------------------------------------
# IAF, d: 25, Iter: 2-1360, s/iter: 8.937e-02, ELBO: -1.652e+05
# Cur diff delta = 20.553741455078125
# Cur diff sigma = 1.1260180473327637
# Cur diff theta = 21.67975950241089
# ---------------------------------------
# IAF, d: 25, Iter: 2-1380, s/iter: 8.783e-02, ELBO: -1.652e+05
# Cur diff delta = 20.54783821105957
# Cur diff sigma = 1.1265944242477417
# Cur diff theta = 21.674432635307312
# ---------------------------------------
# IAF, d: 25, Iter: 2-1400, s/iter: 8.880e-02, ELBO: -1.652e+05
# Cur diff delta = 20.55518341064453
# Cur diff sigma = 1.1262022256851196
# Cur diff theta = 21.68138563632965
# ---------------------------------------
# IAF, d: 25, Iter: 2-1420, s/iter: 8.826e-02, ELBO: -1.652e+05
# Cur diff delta = 20.556489944458008
# Cur diff sigma = 1.1261883974075317
# Cur diff theta = 21.68267834186554
# ---------------------------------------
# IAF, d: 25, Iter: 2-1440, s/iter: 8.930e-02, ELBO: -1.652e+05
# Cur diff delta = 20.5548095703125
# Cur diff sigma = 1.1264384984970093
# Cur diff theta = 21.68124806880951
# ---------------------------------------
# IAF, d: 25, Iter: 2-1460, s/iter: 8.768e-02, ELBO: -1.652e+05
# Cur diff delta = 20.539024353027344
# Cur diff sigma = 1.126703143119812
# Cur diff theta = 21.665727496147156
# ---------------------------------------
# IAF, d: 25, Iter: 2-1480, s/iter: 8.683e-02, ELBO: -1.652e+05
# Cur diff delta = 20.55371856689453
# Cur diff sigma = 1.125767469406128
# Cur diff theta = 21.67948603630066
# ---------------------------------------
# IAF, d: 25, Iter: 2-1500, s/iter: 8.618e-02, ELBO: -1.652e+05
# Cur diff delta = 20.557636260986328
# Cur diff sigma = 1.1255515813827515
# Cur diff theta = 21.68318784236908
# ---------------------------------------
# IAF, d: 25, Iter: 2-1520, s/iter: 9.580e-02, ELBO: -1.652e+05
# Cur diff delta = 20.54583740234375
# Cur diff sigma = 1.126220941543579
# Cur diff theta = 21.67205834388733
# ---------------------------------------
# IAF, d: 25, Iter: 2-1540, s/iter: 9.042e-02, ELBO: -1.652e+05
# Cur diff delta = 20.553359985351562
# Cur diff sigma = 1.1261242628097534
# Cur diff theta = 21.679484248161316
# ---------------------------------------
# IAF, d: 25, Iter: 2-1560, s/iter: 8.519e-02, ELBO: -1.652e+05
# Cur diff delta = 20.55049705505371
# Cur diff sigma = 1.1260473728179932
# Cur diff theta = 21.676544427871704
# ---------------------------------------
# IAF, d: 25, Iter: 2-1580, s/iter: 8.680e-02, ELBO: -1.652e+05
# Cur diff delta = 20.559419631958008
# Cur diff sigma = 1.126084804534912
# Cur diff theta = 21.68550443649292
# ---------------------------------------
# IAF, d: 25, Iter: 2-1600, s/iter: 8.906e-02, ELBO: -1.652e+05
# Cur diff delta = 20.555631637573242
# Cur diff sigma = 1.1258111000061035
# Cur diff theta = 21.681442737579346
# ---------------------------------------
# IAF, d: 25, Iter: 2-1620, s/iter: 9.593e-02, ELBO: -1.652e+05
# Cur diff delta = 20.564159393310547
# Cur diff sigma = 1.1264599561691284
# Cur diff theta = 21.690619349479675
# ---------------------------------------
# IAF, d: 25, Iter: 2-1640, s/iter: 8.947e-02, ELBO: -1.652e+05
# Cur diff delta = 20.553884506225586
# Cur diff sigma = 1.1267021894454956
# Cur diff theta = 21.68058669567108
# ---------------------------------------
# IAF, d: 25, Iter: 2-1660, s/iter: 8.467e-02, ELBO: -1.652e+05
# Cur diff delta = 20.55491065979004
# Cur diff sigma = 1.1264283657073975
# Cur diff theta = 21.681339025497437
# ---------------------------------------
# IAF, d: 25, Iter: 2-1680, s/iter: 9.487e-02, ELBO: -1.652e+05
# Cur diff delta = 20.553056716918945
# Cur diff sigma = 1.1258702278137207
# Cur diff theta = 21.678926944732666
# ---------------------------------------
# IAF, d: 25, Iter: 2-1700, s/iter: 1.005e-01, ELBO: -1.652e+05
# Cur diff delta = 20.553552627563477
# Cur diff sigma = 1.1265192031860352
# Cur diff theta = 21.68007183074951
# ---------------------------------------
# IAF, d: 25, Iter: 2-1720, s/iter: 8.587e-02, ELBO: -1.652e+05
# Cur diff delta = 20.550949096679688
# Cur diff sigma = 1.12588632106781
# Cur diff theta = 21.676835417747498
# ---------------------------------------
# IAF, d: 25, Iter: 2-1740, s/iter: 8.572e-02, ELBO: -1.652e+05
# Cur diff delta = 20.548521041870117
# Cur diff sigma = 1.126192569732666
# Cur diff theta = 21.674713611602783
# ---------------------------------------
# IAF, d: 25, Iter: 2-1760, s/iter: 8.565e-02, ELBO: -1.652e+05
# Cur diff delta = 20.551870346069336
# Cur diff sigma = 1.1260024309158325
# Cur diff theta = 21.67787277698517
# ---------------------------------------
# IAF, d: 25, Iter: 2-1780, s/iter: 8.705e-02, ELBO: -1.652e+05
# Cur diff delta = 20.5578670501709
# Cur diff sigma = 1.125746726989746
# Cur diff theta = 21.683613777160645
# ---------------------------------------
# IAF, d: 25, Iter: 2-1800, s/iter: 8.620e-02, ELBO: -1.652e+05
# Cur diff delta = 20.55290985107422
# Cur diff sigma = 1.1258703470230103
# Cur diff theta = 21.67878019809723
# ---------------------------------------
# IAF, d: 25, Iter: 2-1820, s/iter: 8.890e-02, ELBO: -1.652e+05
# Cur diff delta = 20.550390243530273
# Cur diff sigma = 1.1265575885772705
# Cur diff theta = 21.676947832107544
# ---------------------------------------
# IAF, d: 25, Iter: 2-1840, s/iter: 8.601e-02, ELBO: -1.652e+05
# Cur diff delta = 20.554059982299805
# Cur diff sigma = 1.1262097358703613
# Cur diff theta = 21.680269718170166
# ---------------------------------------
# IAF, d: 25, Iter: 2-1860, s/iter: 8.772e-02, ELBO: -1.652e+05
# Cur diff delta = 20.547361373901367
# Cur diff sigma = 1.1264640092849731
# Cur diff theta = 21.67382538318634
# ---------------------------------------
# IAF, d: 25, Iter: 2-1880, s/iter: 8.673e-02, ELBO: -1.652e+05
# Cur diff delta = 20.558839797973633
# Cur diff sigma = 1.1262128353118896
# Cur diff theta = 21.685052633285522
# ---------------------------------------
# IAF, d: 25, Iter: 2-1900, s/iter: 8.671e-02, ELBO: -1.652e+05
# Cur diff delta = 20.553512573242188
# Cur diff sigma = 1.1267205476760864
# Cur diff theta = 21.680233120918274
# ---------------------------------------
# IAF, d: 25, Iter: 2-1920, s/iter: 8.979e-02, ELBO: -1.652e+05
# Cur diff delta = 20.55360221862793
# Cur diff sigma = 1.1258760690689087
# Cur diff theta = 21.67947828769684
# ---------------------------------------
# IAF, d: 25, Iter: 2-1940, s/iter: 9.865e-02, ELBO: -1.652e+05
# Cur diff delta = 20.551740646362305
# Cur diff sigma = 1.1263952255249023
# Cur diff theta = 21.678135871887207
# ---------------------------------------
# IAF, d: 25, Iter: 2-1960, s/iter: 9.069e-02, ELBO: -1.652e+05
# Cur diff delta = 20.56655502319336
# Cur diff sigma = 1.125842571258545
# Cur diff theta = 21.692397594451904
# ---------------------------------------
# IAF, d: 25, Iter: 2-1980, s/iter: 8.859e-02, ELBO: -1.652e+05
# Cur diff delta = 20.544971466064453
# Cur diff sigma = 1.1262550354003906
# Cur diff theta = 21.671226501464844
# ---------------------------------------
# IAF, d: 25, Iter: 2-2000, s/iter: 8.887e-02, ELBO: -1.652e+05
# Cur diff delta = 20.546804428100586
# Cur diff sigma = 1.1264591217041016
# Cur diff theta = 21.673263549804688
# ---------------------------------------
# ------------------------------------------------------
# Test = 2
# ------------------------------------------------------
# Init diff delta = 52.0
# Init diff sigma = 9665.5205078125
# Init diff theta = 9717.5205078125
# IAF, d: 25, Iter: 3-20, s/iter: 8.042e-02, ELBO: -7.613e+05
# Cur diff delta = 21.04986000061035
# Cur diff sigma = 1461.66455078125
# Cur diff theta = 1482.7144107818604
# ---------------------------------------
# IAF, d: 25, Iter: 3-40, s/iter: 9.571e-02, ELBO: -5.693e+05
# Cur diff delta = 14.115928649902344
# Cur diff sigma = 265.0689392089844
# Cur diff theta = 279.1848678588867
# ---------------------------------------
# IAF, d: 25, Iter: 3-60, s/iter: 7.933e-02, ELBO: -3.915e+05
# Cur diff delta = 16.568004608154297
# Cur diff sigma = 41.609840393066406
# Cur diff theta = 58.1778450012207
# ---------------------------------------
# IAF, d: 25, Iter: 3-80, s/iter: 7.768e-02, ELBO: -2.620e+05
# Cur diff delta = 19.247997283935547
# Cur diff sigma = 5.839988708496094
# Cur diff theta = 25.08798599243164
# ---------------------------------------
# IAF, d: 25, Iter: 3-100, s/iter: 7.755e-02, ELBO: -1.910e+05
# Cur diff delta = 19.6962833404541
# Cur diff sigma = 1.5530281066894531
# Cur diff theta = 21.249311447143555
# ---------------------------------------
# IAF, d: 25, Iter: 3-120, s/iter: 7.842e-02, ELBO: -1.667e+05
# Cur diff delta = 19.701108932495117
# Cur diff sigma = 1.170304536819458
# Cur diff theta = 20.871413469314575
# ---------------------------------------
# IAF, d: 25, Iter: 3-140, s/iter: 7.982e-02, ELBO: -1.659e+05
# Cur diff delta = 19.70095443725586
# Cur diff sigma = 1.1601707935333252
# Cur diff theta = 20.861125230789185
# ---------------------------------------
# IAF, d: 25, Iter: 3-160, s/iter: 8.350e-02, ELBO: -1.658e+05
# Cur diff delta = 19.702125549316406
# Cur diff sigma = 1.159759521484375
# Cur diff theta = 20.86188507080078
# ---------------------------------------
# IAF, d: 25, Iter: 3-180, s/iter: 7.752e-02, ELBO: -1.659e+05
# Cur diff delta = 19.699491500854492
# Cur diff sigma = 1.1596325635910034
# Cur diff theta = 20.859124064445496
# ---------------------------------------
# IAF, d: 25, Iter: 3-200, s/iter: 7.759e-02, ELBO: -1.658e+05
# Cur diff delta = 19.697885513305664
# Cur diff sigma = 1.159764051437378
# Cur diff theta = 20.857649564743042
# ---------------------------------------
# IAF, d: 25, Iter: 3-220, s/iter: 7.745e-02, ELBO: -1.658e+05
# Cur diff delta = 19.698381423950195
# Cur diff sigma = 1.1592251062393188
# Cur diff theta = 20.857606530189514
# ---------------------------------------
# IAF, d: 25, Iter: 3-240, s/iter: 7.890e-02, ELBO: -1.658e+05
# Cur diff delta = 19.702457427978516
# Cur diff sigma = 1.159328818321228
# Cur diff theta = 20.861786246299744
# ---------------------------------------
# IAF, d: 25, Iter: 3-260, s/iter: 8.102e-02, ELBO: -1.658e+05
# Cur diff delta = 19.69890785217285
# Cur diff sigma = 1.159589409828186
# Cur diff theta = 20.858497262001038
# ---------------------------------------
# IAF, d: 25, Iter: 3-280, s/iter: 8.119e-02, ELBO: -1.658e+05
# Cur diff delta = 19.69839859008789
# Cur diff sigma = 1.1591260433197021
# Cur diff theta = 20.857524633407593
# ---------------------------------------
# IAF, d: 25, Iter: 3-300, s/iter: 8.060e-02, ELBO: -1.658e+05
# Cur diff delta = 19.70020866394043
# Cur diff sigma = 1.1594057083129883
# Cur diff theta = 20.859614372253418
# ---------------------------------------
# IAF, d: 25, Iter: 3-320, s/iter: 8.145e-02, ELBO: -1.658e+05
# Cur diff delta = 19.695154190063477
# Cur diff sigma = 1.158889651298523
# Cur diff theta = 20.854043841362
# ---------------------------------------
# IAF, d: 25, Iter: 3-340, s/iter: 9.329e-02, ELBO: -1.658e+05
# Cur diff delta = 19.701406478881836
# Cur diff sigma = 1.1599366664886475
# Cur diff theta = 20.861343145370483
# ---------------------------------------
# IAF, d: 25, Iter: 3-360, s/iter: 8.537e-02, ELBO: -1.658e+05
# Cur diff delta = 19.693742752075195
# Cur diff sigma = 1.1590547561645508
# Cur diff theta = 20.852797508239746
# ---------------------------------------
# IAF, d: 25, Iter: 3-380, s/iter: 8.371e-02, ELBO: -1.658e+05
# Cur diff delta = 19.701234817504883
# Cur diff sigma = 1.159246802330017
# Cur diff theta = 20.8604816198349
# ---------------------------------------
# IAF, d: 25, Iter: 3-400, s/iter: 8.282e-02, ELBO: -1.658e+05
# Cur diff delta = 19.713356018066406
# Cur diff sigma = 1.1594301462173462
# Cur diff theta = 20.872786164283752
# ---------------------------------------
# IAF, d: 25, Iter: 3-420, s/iter: 8.383e-02, ELBO: -1.658e+05
# Cur diff delta = 19.706756591796875
# Cur diff sigma = 1.1593706607818604
# Cur diff theta = 20.866127252578735
# ---------------------------------------
# IAF, d: 25, Iter: 3-440, s/iter: 8.230e-02, ELBO: -1.658e+05
# Cur diff delta = 19.708356857299805
# Cur diff sigma = 1.159287691116333
# Cur diff theta = 20.867644548416138
# ---------------------------------------
# IAF, d: 25, Iter: 3-460, s/iter: 8.599e-02, ELBO: -1.658e+05
# Cur diff delta = 19.700237274169922
# Cur diff sigma = 1.159104347229004
# Cur diff theta = 20.859341621398926
# ---------------------------------------
# IAF, d: 25, Iter: 3-480, s/iter: 9.323e-02, ELBO: -1.658e+05
# Cur diff delta = 19.701568603515625
# Cur diff sigma = 1.1590704917907715
# Cur diff theta = 20.860639095306396
# ---------------------------------------
# IAF, d: 25, Iter: 3-500, s/iter: 8.580e-02, ELBO: -1.658e+05
# Cur diff delta = 19.699974060058594
# Cur diff sigma = 1.1589298248291016
# Cur diff theta = 20.858903884887695
# ---------------------------------------
# ...
# IAF, d: 25, Iter: 3-540, s/iter: 1.014e-01, ELBO: -1.658e+05
# Cur diff delta = 19.702125549316406
# Cur diff sigma = 1.159203052520752
# Cur diff theta = 20.861328601837158
# ---------------------------------------
# IAF, d: 25, Iter: 3-560, s/iter: 9.094e-02, ELBO: -1.658e+05
# Cur diff delta = 19.70751190185547
# Cur diff sigma = 1.1587141752243042
# Cur diff theta = 20.866226077079773
# ---------------------------------------
# IAF, d: 25, Iter: 3-580, s/iter: 8.380e-02, ELBO: -1.658e+05
# Cur diff delta = 19.701393127441406
# Cur diff sigma = 1.1586993932724
# Cur diff theta = 20.860092520713806
# ---------------------------------------
# IAF, d: 25, Iter: 3-600, s/iter: 8.411e-02, ELBO: -1.658e+05
# Cur diff delta = 19.702102661132812
# Cur diff sigma = 1.1591240167617798
# Cur diff theta = 20.861226677894592
# ---------------------------------------
# IAF, d: 25, Iter: 3-620, s/iter: 8.318e-02, ELBO: -1.658e+05
# Cur diff delta = 19.711206436157227
# Cur diff sigma = 1.1586544513702393
# Cur diff theta = 20.869860887527466
# ---------------------------------------
# IAF, d: 25, Iter: 3-640, s/iter: 8.426e-02, ELBO: -1.658e+05
# Cur diff delta = 19.707763671875
# Cur diff sigma = 1.1590580940246582
# Cur diff theta = 20.866821765899658
# ---------------------------------------
# IAF, d: 25, Iter: 3-660, s/iter: 8.610e-02, ELBO: -1.658e+05
# Cur diff delta = 19.70095443725586
# Cur diff sigma = 1.1588555574417114
# Cur diff theta = 20.85980999469757
# ---------------------------------------
# IAF, d: 25, Iter: 3-680, s/iter: 8.576e-02, ELBO: -1.658e+05
# Cur diff delta = 19.704517364501953
# Cur diff sigma = 1.1590003967285156
# Cur diff theta = 20.86351776123047
# ---------------------------------------
# IAF, d: 25, Iter: 3-700, s/iter: 8.491e-02, ELBO: -1.658e+05
# Cur diff delta = 19.698734283447266
# Cur diff sigma = 1.158614993095398
# Cur diff theta = 20.857349276542664
# ---------------------------------------
# IAF, d: 25, Iter: 3-720, s/iter: 9.530e-02, ELBO: -1.658e+05
# Cur diff delta = 19.696529388427734
# Cur diff sigma = 1.1589730978012085
# Cur diff theta = 20.855502486228943
# ---------------------------------------
# IAF, d: 25, Iter: 3-740, s/iter: 9.537e-02, ELBO: -1.657e+05
# Cur diff delta = 19.702556610107422
# Cur diff sigma = 1.1586586236953735
# Cur diff theta = 20.861215233802795
# ---------------------------------------
# IAF, d: 25, Iter: 3-760, s/iter: 8.837e-02, ELBO: -1.657e+05
# Cur diff delta = 19.697906494140625
# Cur diff sigma = 1.158964991569519
# Cur diff theta = 20.856871485710144
# ---------------------------------------
# IAF, d: 25, Iter: 3-780, s/iter: 9.928e-02, ELBO: -1.658e+05
# Cur diff delta = 19.697040557861328
# Cur diff sigma = 1.1590046882629395
# Cur diff theta = 20.856045246124268
# ---------------------------------------
# IAF, d: 25, Iter: 3-800, s/iter: 8.662e-02, ELBO: -1.658e+05
# Cur diff delta = 19.70338249206543
# Cur diff sigma = 1.1587039232254028
# Cur diff theta = 20.862086415290833
# ---------------------------------------
# IAF, d: 25, Iter: 3-820, s/iter: 9.085e-02, ELBO: -1.658e+05
# Cur diff delta = 19.704910278320312
# Cur diff sigma = 1.1588391065597534
# Cur diff theta = 20.863749384880066
# ---------------------------------------
# IAF, d: 25, Iter: 3-840, s/iter: 9.227e-02, ELBO: -1.657e+05
# Cur diff delta = 19.703018188476562
# Cur diff sigma = 1.1583001613616943
# Cur diff theta = 20.861318349838257
# ---------------------------------------
# IAF, d: 25, Iter: 3-860, s/iter: 8.580e-02, ELBO: -1.658e+05
# Cur diff delta = 19.70270347595215
# Cur diff sigma = 1.159246563911438
# Cur diff theta = 20.861950039863586
# ---------------------------------------
# IAF, d: 25, Iter: 3-880, s/iter: 8.725e-02, ELBO: -1.658e+05
# Cur diff delta = 19.701663970947266
# Cur diff sigma = 1.1587364673614502
# Cur diff theta = 20.860400438308716
# ---------------------------------------
# IAF, d: 25, Iter: 3-900, s/iter: 8.532e-02, ELBO: -1.658e+05
# Cur diff delta = 19.703083038330078
# Cur diff sigma = 1.1592856645584106
# Cur diff theta = 20.86236870288849
# ---------------------------------------
# IAF, d: 25, Iter: 3-920, s/iter: 8.646e-02, ELBO: -1.658e+05
# Cur diff delta = 19.70393180847168
# Cur diff sigma = 1.1590681076049805
# Cur diff theta = 20.86299991607666
# ---------------------------------------
# IAF, d: 25, Iter: 3-940, s/iter: 8.552e-02, ELBO: -1.657e+05
# Cur diff delta = 19.701251983642578
# Cur diff sigma = 1.1583342552185059
# Cur diff theta = 20.859586238861084
# ---------------------------------------
# IAF, d: 25, Iter: 3-960, s/iter: 9.422e-02, ELBO: -1.658e+05
# Cur diff delta = 19.703144073486328
# Cur diff sigma = 1.1590317487716675
# Cur diff theta = 20.862175822257996
# ---------------------------------------
# IAF, d: 25, Iter: 3-980, s/iter: 8.792e-02, ELBO: -1.658e+05
# Cur diff delta = 19.701091766357422
# Cur diff sigma = 1.158950924873352
# Cur diff theta = 20.860042691230774
# ---------------------------------------
# IAF, d: 25, Iter: 3-1000, s/iter: 8.493e-02, ELBO: -1.658e+05
# Cur diff delta = 19.701330184936523
# Cur diff sigma = 1.1587495803833008
# Cur diff theta = 20.860079765319824
# ---------------------------------------
# IAF, d: 25, Iter: 3-1020, s/iter: 8.519e-02, ELBO: -1.658e+05
# Cur diff delta = 19.701953887939453
# Cur diff sigma = 1.1592271327972412
# Cur diff theta = 20.861181020736694
# ---------------------------------------
# IAF, d: 25, Iter: 3-1040, s/iter: 8.742e-02, ELBO: -1.658e+05
# Cur diff delta = 19.708404541015625
# Cur diff sigma = 1.158582329750061
# Cur diff theta = 20.866986870765686
# ---------------------------------------
# IAF, d: 25, Iter: 3-1060, s/iter: 8.548e-02, ELBO: -1.657e+05
# Cur diff delta = 19.705570220947266
# Cur diff sigma = 1.1584118604660034
# Cur diff theta = 20.86398208141327
# ---------------------------------------
# IAF, d: 25, Iter: 3-1080, s/iter: 8.779e-02, ELBO: -1.658e+05
# Cur diff delta = 19.702899932861328
# Cur diff sigma = 1.158982515335083
# Cur diff theta = 20.86188244819641
# ---------------------------------------
# IAF, d: 25, Iter: 3-1100, s/iter: 8.667e-02, ELBO: -1.658e+05
# Cur diff delta = 19.70404815673828
# Cur diff sigma = 1.158482551574707
# Cur diff theta = 20.86253070831299
# ---------------------------------------
# IAF, d: 25, Iter: 3-1120, s/iter: 8.663e-02, ELBO: -1.657e+05
# Cur diff delta = 19.70409393310547
# Cur diff sigma = 1.1583454608917236
# Cur diff theta = 20.862439393997192
# ---------------------------------------
# IAF, d: 25, Iter: 3-1140, s/iter: 9.299e-02, ELBO: -1.658e+05
# Cur diff delta = 19.70571517944336
# Cur diff sigma = 1.159153699874878
# Cur diff theta = 20.864868879318237
# ---------------------------------------
# IAF, d: 25, Iter: 3-1160, s/iter: 9.574e-02, ELBO: -1.658e+05
# Cur diff delta = 19.706317901611328
# Cur diff sigma = 1.158787488937378
# Cur diff theta = 20.865105390548706
# ---------------------------------------
# IAF, d: 25, Iter: 3-1180, s/iter: 1.040e-01, ELBO: -1.658e+05
# Cur diff delta = 19.707237243652344
# Cur diff sigma = 1.159311294555664
# Cur diff theta = 20.866548538208008
# ---------------------------------------
# IAF, d: 25, Iter: 3-1200, s/iter: 9.650e-02, ELBO: -1.657e+05
# Cur diff delta = 19.69455337524414
# Cur diff sigma = 1.1588592529296875
# Cur diff theta = 20.853412628173828
# ---------------------------------------
# IAF, d: 25, Iter: 3-1220, s/iter: 9.094e-02, ELBO: -1.658e+05
# Cur diff delta = 19.700477600097656
# Cur diff sigma = 1.1586581468582153
# Cur diff theta = 20.85913574695587
# ---------------------------------------
# IAF, d: 25, Iter: 3-1240, s/iter: 8.776e-02, ELBO: -1.658e+05
# Cur diff delta = 19.704771041870117
# Cur diff sigma = 1.1588821411132812
# Cur diff theta = 20.8636531829834
# ---------------------------------------
# IAF, d: 25, Iter: 3-1260, s/iter: 8.909e-02, ELBO: -1.657e+05
# Cur diff delta = 19.70802879333496
# Cur diff sigma = 1.1582640409469604
# Cur diff theta = 20.86629283428192
# ---------------------------------------
# IAF, d: 25, Iter: 3-1280, s/iter: 8.836e-02, ELBO: -1.657e+05
# Cur diff delta = 19.705869674682617
# Cur diff sigma = 1.1584339141845703
# Cur diff theta = 20.864303588867188
# ---------------------------------------
# IAF, d: 25, Iter: 3-1300, s/iter: 8.904e-02, ELBO: -1.657e+05
# Cur diff delta = 19.709070205688477
# Cur diff sigma = 1.158692717552185
# Cur diff theta = 20.86776292324066
# ---------------------------------------
# IAF, d: 25, Iter: 3-1320, s/iter: 8.666e-02, ELBO: -1.658e+05
# Cur diff delta = 19.70132827758789
# Cur diff sigma = 1.1586010456085205
# Cur diff theta = 20.85992932319641
# ---------------------------------------
# IAF, d: 25, Iter: 3-1340, s/iter: 9.656e-02, ELBO: -1.658e+05
# Cur diff delta = 19.70096206665039
# Cur diff sigma = 1.158894419670105
# Cur diff theta = 20.859856486320496
# ---------------------------------------
# IAF, d: 25, Iter: 3-1360, s/iter: 8.693e-02, ELBO: -1.658e+05
# Cur diff delta = 19.703933715820312
# Cur diff sigma = 1.1586257219314575
# Cur diff theta = 20.86255943775177
# ---------------------------------------
# IAF, d: 25, Iter: 3-1380, s/iter: 8.704e-02, ELBO: -1.658e+05
# Cur diff delta = 19.706966400146484
# Cur diff sigma = 1.1590405702590942
# Cur diff theta = 20.86600697040558
# ---------------------------------------
# IAF, d: 25, Iter: 3-1400, s/iter: 8.582e-02, ELBO: -1.657e+05
# Cur diff delta = 19.69043731689453
# Cur diff sigma = 1.1586226224899292
# Cur diff theta = 20.84905993938446
# ---------------------------------------
# IAF, d: 25, Iter: 3-1420, s/iter: 8.719e-02, ELBO: -1.658e+05
# Cur diff delta = 19.710979461669922
# Cur diff sigma = 1.1587424278259277
# Cur diff theta = 20.86972188949585
# ---------------------------------------
# IAF, d: 25, Iter: 3-1440, s/iter: 8.634e-02, ELBO: -1.657e+05
# Cur diff delta = 19.69684600830078
# Cur diff sigma = 1.1581737995147705
# Cur diff theta = 20.85501980781555
# ---------------------------------------
# IAF, d: 25, Iter: 3-1460, s/iter: 8.617e-02, ELBO: -1.658e+05
# Cur diff delta = 19.699270248413086
# Cur diff sigma = 1.1586694717407227
# Cur diff theta = 20.85793972015381
# ---------------------------------------
# IAF, d: 25, Iter: 3-1480, s/iter: 8.660e-02, ELBO: -1.658e+05
# Cur diff delta = 19.69831657409668
# Cur diff sigma = 1.1586389541625977
# Cur diff theta = 20.856955528259277
# ---------------------------------------
# IAF, d: 25, Iter: 3-1500, s/iter: 8.655e-02, ELBO: -1.658e+05
# Cur diff delta = 19.694555282592773
# Cur diff sigma = 1.1580692529678345
# Cur diff theta = 20.852624535560608
# ---------------------------------------
# IAF, d: 25, Iter: 3-1520, s/iter: 8.630e-02, ELBO: -1.657e+05
# Cur diff delta = 19.70325469970703
# Cur diff sigma = 1.1584481000900269
# Cur diff theta = 20.861702799797058
# ---------------------------------------
# IAF, d: 25, Iter: 3-1540, s/iter: 1.006e-01, ELBO: -1.658e+05
# Cur diff delta = 19.698169708251953
# Cur diff sigma = 1.1587460041046143
# Cur diff theta = 20.856915712356567
# ---------------------------------------
# IAF, d: 25, Iter: 3-1560, s/iter: 9.080e-02, ELBO: -1.658e+05
# Cur diff delta = 19.70401382446289
# Cur diff sigma = 1.1587001085281372
# Cur diff theta = 20.862713932991028
# ---------------------------------------
# IAF, d: 25, Iter: 3-1580, s/iter: 9.328e-02, ELBO: -1.658e+05
# Cur diff delta = 19.69904136657715
# Cur diff sigma = 1.1583619117736816
# Cur diff theta = 20.85740327835083
# ---------------------------------------
# IAF, d: 25, Iter: 3-1600, s/iter: 8.905e-02, ELBO: -1.658e+05
# Cur diff delta = 19.697235107421875
# Cur diff sigma = 1.158810019493103
# Cur diff theta = 20.856045126914978
# ---------------------------------------
# IAF, d: 25, Iter: 3-1620, s/iter: 8.723e-02, ELBO: -1.657e+05
# Cur diff delta = 19.70171546936035
# Cur diff sigma = 1.1583127975463867
# Cur diff theta = 20.86002826690674
# ---------------------------------------
# IAF, d: 25, Iter: 3-1640, s/iter: 8.675e-02, ELBO: -1.658e+05
# Cur diff delta = 19.69373893737793
# Cur diff sigma = 1.1585478782653809
# Cur diff theta = 20.85228681564331
# ---------------------------------------
# IAF, d: 25, Iter: 3-1660, s/iter: 8.643e-02, ELBO: -1.657e+05
# Cur diff delta = 19.70353889465332
# Cur diff sigma = 1.1587525606155396
# Cur diff theta = 20.86229145526886
# ---------------------------------------
# IAF, d: 25, Iter: 3-1680, s/iter: 8.593e-02, ELBO: -1.657e+05
# Cur diff delta = 19.69646453857422
# Cur diff sigma = 1.15879225730896
# Cur diff theta = 20.85525679588318
# ---------------------------------------
# IAF, d: 25, Iter: 3-1700, s/iter: 8.650e-02, ELBO: -1.658e+05
# Cur diff delta = 19.702468872070312
# Cur diff sigma = 1.1585745811462402
# Cur diff theta = 20.861043453216553
# ---------------------------------------
# IAF, d: 25, Iter: 3-1720, s/iter: 8.640e-02, ELBO: -1.657e+05
# Cur diff delta = 19.705276489257812
# Cur diff sigma = 1.1587250232696533
# Cur diff theta = 20.864001512527466
# ---------------------------------------
# IAF, d: 25, Iter: 3-1740, s/iter: 8.735e-02, ELBO: -1.658e+05
# Cur diff delta = 19.69794273376465
# Cur diff sigma = 1.1584937572479248
# Cur diff theta = 20.856436491012573
# ---------------------------------------
# IAF, d: 25, Iter: 3-1760, s/iter: 8.627e-02, ELBO: -1.658e+05
# Cur diff delta = 19.70549201965332
# Cur diff sigma = 1.1589409112930298
# Cur diff theta = 20.86443293094635
# ---------------------------------------
# IAF, d: 25, Iter: 3-1780, s/iter: 8.638e-02, ELBO: -1.658e+05
# Cur diff delta = 19.70415687561035
# Cur diff sigma = 1.1583951711654663
# Cur diff theta = 20.862552046775818
# ---------------------------------------
# IAF, d: 25, Iter: 3-1800, s/iter: 9.481e-02, ELBO: -1.658e+05
# Cur diff delta = 19.70159339904785
# Cur diff sigma = 1.1585530042648315
# Cur diff theta = 20.860146403312683
# ---------------------------------------
# IAF, d: 25, Iter: 3-1820, s/iter: 9.622e-02, ELBO: -1.658e+05
# Cur diff delta = 19.698591232299805
# Cur diff sigma = 1.1587188243865967
# Cur diff theta = 20.8573100566864
# ---------------------------------------
# IAF, d: 25, Iter: 3-1840, s/iter: 8.712e-02, ELBO: -1.658e+05
# Cur diff delta = 19.700197219848633
# Cur diff sigma = 1.1588513851165771
# Cur diff theta = 20.85904860496521
# ---------------------------------------
# IAF, d: 25, Iter: 3-1860, s/iter: 8.740e-02, ELBO: -1.658e+05
# Cur diff delta = 19.702117919921875
# Cur diff sigma = 1.1587163209915161
# Cur diff theta = 20.86083424091339
# ---------------------------------------
# IAF, d: 25, Iter: 3-1880, s/iter: 8.980e-02, ELBO: -1.658e+05
# Cur diff delta = 19.697269439697266
# Cur diff sigma = 1.1588057279586792
# Cur diff theta = 20.856075167655945
# ---------------------------------------
# IAF, d: 25, Iter: 3-1900, s/iter: 8.664e-02, ELBO: -1.657e+05
# Cur diff delta = 19.69706916809082
# Cur diff sigma = 1.1585160493850708
# Cur diff theta = 20.85558521747589
# ---------------------------------------
# IAF, d: 25, Iter: 3-1920, s/iter: 1.007e-01, ELBO: -1.657e+05
# Cur diff delta = 19.704408645629883
# Cur diff sigma = 1.1581922769546509
# Cur diff theta = 20.862600922584534
# ---------------------------------------
# IAF, d: 25, Iter: 3-1940, s/iter: 9.331e-02, ELBO: -1.658e+05
# Cur diff delta = 19.704607009887695
# Cur diff sigma = 1.1589187383651733
# Cur diff theta = 20.86352574825287
# ---------------------------------------
# IAF, d: 25, Iter: 3-1960, s/iter: 8.788e-02, ELBO: -1.657e+05
# Cur diff delta = 19.706653594970703
# Cur diff sigma = 1.1585743427276611
# Cur diff theta = 20.865227937698364
# ---------------------------------------
# IAF, d: 25, Iter: 3-1980, s/iter: 8.581e-02, ELBO: -1.657e+05
# Cur diff delta = 19.707664489746094
# Cur diff sigma = 1.1585086584091187
# Cur diff theta = 20.866173148155212
# ---------------------------------------
# IAF, d: 25, Iter: 3-2000, s/iter: 9.776e-02, ELBO: -1.658e+05
# Cur diff delta = 19.69295883178711
# Cur diff sigma = 1.158778429031372
# Cur diff theta = 20.85173726081848
# ---------------------------------------
# Model IAF, test = 0, result delta diff = 25.880970001220703
# Model IAF, test = 0, result sigma diff = 1.1393389701843262
# Model IAF, test = 0, result theta diff = 27.020309448242188
# Model IAF, test = 1, result delta diff = 20.54680633544922
# Model IAF, test = 1, result sigma diff = 1.1264591217041016
# Model IAF, test = 1, result theta diff = 21.67326545715332
# Model IAF, test = 2, result delta diff = 19.692956924438477
# Model IAF, test = 2, result sigma diff = 1.158778429031372
# Model IAF, test = 2, result theta diff = 20.851736068725586

# %%
model_names = ['IAF']
diff_delta_results = {}
diff_sigma_results = {}
diff_results = {}
for name in model_names:
    diff_delta_tests = np.zeros(params['n_tests'])
    diff_sigma_tests = np.zeros(params['n_tests'])
    diff_tests = np.zeros(params['n_tests'])
    for i in range(params['n_tests']):
        file_name = name + '_train_' + str(i) + '.p'
        diff_path = os.path.join('save', str(params['dims'][0]), file_name)
        with open(diff_path, 'rb') as f:
            data = pickle.load(f)
            elbo = data['elbo']
            diff_delta = data['diff_delta']
            diff_sigma = data['diff_sigma']
            diff = diff_delta + diff_sigma
            diff_delta_is_not_nan = diff_delta[~np.isnan(diff_delta)]
            diff_sigma_is_not_nan = diff_sigma[~np.isnan(diff_sigma)]
            diff_is_not_nan = diff[~np.isnan(diff)]
            diff_delta_tests[i] = diff_delta_is_not_nan[-1]
            diff_sigma_tests[i] = diff_sigma_is_not_nan[-1]
            diff_tests[i] = diff_is_not_nan[-1]
    diff_delta_results[name] = diff_delta_tests
    diff_sigma_results[name] = diff_sigma_tests
    diff_results[name] = diff_tests
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, diff delta = {diff_delta_tests}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, diff sigma = {diff_sigma_tests}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, diff = {diff_tests}")
# Out:
# Model = IAF, dimensionality = 25, diff delta = [25.88096809 20.54680443 19.69295883]
# Model = IAF, dimensionality = 25, diff sigma = [1.13933897 1.12645912 1.15877843]
# Model = IAF, dimensionality = 25, diff = [27.02030754 21.67326355 20.85173798]

# %%
for name in model_names:
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, mean diff delta = {diff_delta_results[name].mean()}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, mean diff sigma = {diff_sigma_results[name].mean()}")
    print(f"Model = {name}, dimensionality = {params['dims'][0]}, mean diff = {diff_results[name].mean()}")
# Out:
# Model = IAF, dimensionality = 25, mean diff delta = 22.04024378458659
# Model = IAF, dimensionality = 25, mean diff sigma = 1.1415255069732666
# Model = IAF, dimensionality = 25, mean diff = 23.181769688924152
